# %% [markdown]
# ## Parsing REPBULIC hOCR Files
#
# The scans of the printed RSG volumes have the following characteristics
#
# - all scans:
#   - have two pages per scan
#   - have up to 4 columns per scan, 2 per page
#   - full scan is around 4800 pixels wide, left page is up to pixel 2400, right page is from pixel 2400 (roughly)
# - scans of index pages
#   - have no page numbers
# - scans of resolution pages
#   - have page numbers (left-side page is even, right-side page is odd)
#
# ### Columns
#
# The scans are normalized such that the columns are straight. The text width should be around 1000 pixels. Some columns are not cut out properly, resulting in columns that are either to small (some of the column text is missing), or too wide (the hOCR output contains partial texts from two columns)
#
# ### Index pages
#
# - start of entry:
#   - start left alignment
# - end of entry:
#   - end of line possibly before end of text column.
#   - One or more page numbers
#
#
# ### Resolution pages
#
# - header:
#   - next top of page (less than 350 pixels from the top)
#   - page has header with:
#     - even numbered pages: date page_number year
#     - odd numbered pages: year page_number date
#   - columns have half of page header, e.g.:
#     - even numbered pages:
#       - first column: date left aligned and part of page_number right aligned
#       - second column: part of page_number left aligned and year right aligned
#     - odd numbered pages:
#       - first column: year left aligned and part of page_number right aligned
#       - second column: part of page_number left aligned and date right aligned
#
# ### Viewer
#
# - page viewer: https://images.huygens.knaw.nl/assets/argos/index.html
# - list of page URLs: https://images.huygens.knaw.nl/api/argos

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import json
import os
import re
from collections import defaultdict
from parse_hocr_files import make_hocr_page
from parse_republic_hocr_files import get_files, get_page_types, count_page_ref_lines, get_index_entry_lines
from elasticsearch import Elasticsearch

# ../hocr/NL-HaNA_1.01.02_3780_0016.jpg-0-251-98--0.40.hocr

# %% [markdown]
# ### Reading column scans for a single volume
#
# 1. get scan file info
#     - scan number, page number, page side, column number, slant, page
# 2. iterate over pages
#     - create hocr_page
#     - determine page type: index, resolution, other

# %%
data_dir = "../../../Data/Projects/REPUBLIC/hocr/1725/"

scan_files = get_files(data_dir)
scan_files.sort(key = lambda x: x["scan_num_column_num"])
print("Number of scan files:", len(scan_files))
#print(json.dumps(scan_files[0:11], indent=2))

scan_columns = defaultdict(list)
for scan_file in scan_files:
    scan_columns[scan_file["scan_num"]]


hocr_page = make_hocr_page(scan_files[10]["filepath"], scan_files[10]["scan_num"], remove_line_numbers=False, remove_tiny_words=True, tiny_word_width=15)
#print(scan_files[10]["filepath"])
#hocr_page.lines
# Out:
# Number of scan files: 1887

# %% [markdown]
# ### Determining Page Type
#
# We want to parse index pages differently from resolution pages and filter out non-text pages and pages where the columns are not properly identified.

# %%
index_scans, resolution_scans = get_page_types(scan_files, max_scan_num=70)
print("index_scans:", index_scans)
print("resolution_scans:", resolution_scans)
# Out:
# scan: 4 	scan_id: scan-4-even-0
# 	COLUMN IMPROPERLY CUT
# scan: 4 	scan_id: scan-4-odd-1
# 	COLUMN IMPROPERLY CUT
# scan: 5 	scan_id: scan-5-even-0
# \OTHER PAGE
# scan: 5 	scan_id: scan-5-odd-1
# \OTHER PAGE
# scan: 6 	scan_id: scan-6-even-0
# 	COLUMN IMPROPERLY CUT
# scan: 6 	scan_id: scan-6-even-1
# 	INDEX PAGE
# scan: 6 	scan_id: scan-6-odd-2
# 	INDEX PAGE
# scan: 6 	scan_id: scan-6-odd-3
# 	INDEX PAGE
# scan: 7 	scan_id: scan-7-even-0
# 	INDEX PAGE
# scan: 7 	scan_id: scan-7-even-1
# 	INDEX PAGE
# scan: 7 	scan_id: scan-7-odd-2
# 	INDEX PAGE
# scan: 7 	scan_id: scan-7-odd-3
# 	INDEX PAGE
# scan: 8 	scan_id: scan-8-even-0
# 	INDEX PAGE
# scan: 8 	scan_id: scan-8-even-1
# 	INDEX PAGE
# scan: 8 	scan_id: scan-8-odd-2
# 	INDEX PAGE
# scan: 8 	scan_id: scan-8-odd-3
# 	INDEX PAGE
# scan: 9 	scan_id: scan-9-even-0
# 	INDEX PAGE
# scan: 9 	scan_id: scan-9-even-1
# 	COLUMN IMPROPERLY CUT
# scan: 9 	scan_id: scan-9-odd-2
# 	INDEX PAGE
# scan: 9 	scan_id: scan-9-odd-3
# 	INDEX PAGE
# scan: 10 	scan_id: scan-10-even-0
# 	INDEX PAGE
# scan: 10 	scan_id: scan-10-odd-2
# 	INDEX PAGE
# scan: 10 	scan_id: scan-10-odd-3
# 	INDEX PAGE
# scan: 11 	scan_id: scan-11-even-0
# 	COLUMN IMPROPERLY CUT
# scan: 11 	scan_id: scan-11-even-1
# 	INDEX PAGE
# scan: 11 	scan_id: scan-11-odd-3
# 	INDEX PAGE
# scan: 12 	scan_id: scan-12-even-1
# 	INDEX PAGE
# scan: 12 	scan_id: scan-12-odd-2
# 	INDEX PAGE
# scan: 12 	scan_id: scan-12-odd-3
# 	INDEX PAGE
# scan: 13 	scan_id: scan-13-even-0
# 	INDEX PAGE
# scan: 13 	scan_id: scan-13-odd-2
# 	INDEX PAGE
# scan: 14 	scan_id: scan-14-even-1
# 	INDEX PAGE
# scan: 14 	scan_id: scan-14-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 14 	scan_id: scan-14-odd-3
# 	INDEX PAGE
# scan: 15 	scan_id: scan-15-even-1
# \OTHER PAGE
# scan: 15 	scan_id: scan-15-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 15 	scan_id: scan-15-odd-3
# 	INDEX PAGE
# scan: 16 	scan_id: scan-16-even-0
# 	INDEX PAGE
# scan: 16 	scan_id: scan-16-even-1
# 	INDEX PAGE
# scan: 16 	scan_id: scan-16-odd-2
# 	INDEX PAGE
# scan: 16 	scan_id: scan-16-odd-3
# 	INDEX PAGE
# scan: 17 	scan_id: scan-17-even-0
# 	INDEX PAGE
# scan: 17 	scan_id: scan-17-odd-2
# 	INDEX PAGE
# scan: 17 	scan_id: scan-17-odd-3
# 	INDEX PAGE
# scan: 18 	scan_id: scan-18-even-0
# 	INDEX PAGE
# scan: 18 	scan_id: scan-18-even-1
# 	INDEX PAGE
# scan: 18 	scan_id: scan-18-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 18 	scan_id: scan-18-odd-3
# 	COLUMN IMPROPERLY CUT
# scan: 18 	scan_id: scan-18-odd-4
# 	INDEX PAGE
# scan: 19 	scan_id: scan-19-even-0
# 	INDEX PAGE
# scan: 19 	scan_id: scan-19-even-1
# 	INDEX PAGE
# scan: 19 	scan_id: scan-19-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 19 	scan_id: scan-19-odd-3
# 	COLUMN IMPROPERLY CUT
# scan: 19 	scan_id: scan-19-odd-4
# 	INDEX PAGE
# scan: 20 	scan_id: scan-20-even-0
# 	INDEX PAGE
# scan: 20 	scan_id: scan-20-even-1
# 	INDEX PAGE
# scan: 20 	scan_id: scan-20-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 20 	scan_id: scan-20-odd-3
# \OTHER PAGE
# scan: 21 	scan_id: scan-21-even-0
# 	INDEX PAGE
# scan: 21 	scan_id: scan-21-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 21 	scan_id: scan-21-odd-3
# 	COLUMN IMPROPERLY CUT
# scan: 21 	scan_id: scan-21-odd-4
# 	INDEX PAGE
# scan: 22 	scan_id: scan-22-even-0
# 	INDEX PAGE
# scan: 22 	scan_id: scan-22-even-1
# 	INDEX PAGE
# scan: 22 	scan_id: scan-22-odd-2
# 	INDEX PAGE
# scan: 22 	scan_id: scan-22-odd-3
# 	INDEX PAGE
# scan: 23 	scan_id: scan-23-even-0
# 	INDEX PAGE
# scan: 23 	scan_id: scan-23-even-1
# 	INDEX PAGE
# scan: 23 	scan_id: scan-23-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 24 	scan_id: scan-24-even-0
# 	INDEX PAGE
# scan: 24 	scan_id: scan-24-even-1
# \OTHER PAGE
# scan: 24 	scan_id: scan-24-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 24 	scan_id: scan-24-odd-3
# 	INDEX PAGE
# scan: 25 	scan_id: scan-25-even-0
# \OTHER PAGE
# scan: 25 	scan_id: scan-25-odd-2
# \OTHER PAGE
# scan: 25 	scan_id: scan-25-odd-3
# 	INDEX PAGE
# scan: 26 	scan_id: scan-26-even-0
# \OTHER PAGE
# scan: 26 	scan_id: scan-26-even-1
# \OTHER PAGE
# scan: 26 	scan_id: scan-26-odd-2
# 	INDEX PAGE
# scan: 26 	scan_id: scan-26-odd-3
# 	INDEX PAGE
# scan: 27 	scan_id: scan-27-even-0
# 	INDEX PAGE
# scan: 27 	scan_id: scan-27-odd-3
# 	INDEX PAGE
# scan: 28 	scan_id: scan-28-even-0
# \OTHER PAGE
# scan: 28 	scan_id: scan-28-even-1
# 	INDEX PAGE
# scan: 28 	scan_id: scan-28-odd-2
# 	INDEX PAGE
# scan: 28 	scan_id: scan-28-odd-3
# 	INDEX PAGE
# scan: 29 	scan_id: scan-29-even-0
# 	INDEX PAGE
# scan: 29 	scan_id: scan-29-even-1
# 	INDEX PAGE
# scan: 29 	scan_id: scan-29-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 29 	scan_id: scan-29-odd-3
# 	COLUMN IMPROPERLY CUT
# scan: 29 	scan_id: scan-29-odd-4
# \OTHER PAGE
# scan: 30 	scan_id: scan-30-even-0
# 	INDEX PAGE
# scan: 30 	scan_id: scan-30-even-1
# 	INDEX PAGE
# scan: 30 	scan_id: scan-30-odd-2
# 	INDEX PAGE
# scan: 30 	scan_id: scan-30-odd-3
# 	INDEX PAGE
# scan: 31 	scan_id: scan-31-even-0
# \OTHER PAGE
# scan: 31 	scan_id: scan-31-odd-2
# 	COLUMN IMPROPERLY CUT
# scan: 31 	scan_id: scan-31-odd-3
# 	INDEX PAGE
# scan: 32 	scan_id: scan-32-even-0
# 	INDEX PAGE
# scan: 32 	scan_id: scan-32-even-1
# 	INDEX PAGE
# scan: 32 	scan_id: scan-32-odd-2
# 	INDEX PAGE
# scan: 32 	scan_id: scan-32-odd-3
# 	INDEX PAGE
# scan: 33 	scan_id: scan-33-even-0
# \OTHER PAGE
# scan: 33 	scan_id: scan-33-odd-2
# 	INDEX PAGE
# scan: 33 	scan_id: scan-33-odd-3
# 	INDEX PAGE
# scan: 34 	scan_id: scan-34-even-0
# 	INDEX PAGE
# scan: 34 	scan_id: scan-34-odd-2
# 	INDEX PAGE
# scan: 34 	scan_id: scan-34-odd-3
# 	INDEX PAGE
# scan: 35 	scan_id: scan-35-even-0
# \OTHER PAGE
# scan: 35 	scan_id: scan-35-even-1
# 	INDEX PAGE
# scan: 35 	scan_id: scan-35-odd-2
# 	INDEX PAGE
# scan: 35 	scan_id: scan-35-odd-3
# 	INDEX PAGE
# scan: 36 	scan_id: scan-36-even-0
# \OTHER PAGE
# scan: 36 	scan_id: scan-36-even-1
# 	INDEX PAGE
# scan: 36 	scan_id: scan-36-odd-2
# 	INDEX PAGE
# scan: 36 	scan_id: scan-36-odd-3
# 	INDEX PAGE
# scan: 37 	scan_id: scan-37-even-1
# 	INDEX PAGE
# scan: 37 	scan_id: scan-37-odd-2
# 	INDEX PAGE
# scan: 37 	scan_id: scan-37-odd-3
# \OTHER PAGE
# scan: 38 	scan_id: scan-38-even-1
# 	INDEX PAGE
# scan: 38 	scan_id: scan-38-odd-2
# 	INDEX PAGE
# scan: 38 	scan_id: scan-38-odd-3
# 	INDEX PAGE
# scan: 39 	scan_id: scan-39-even-0
# 	INDEX PAGE
# scan: 39 	scan_id: scan-39-even-1
# 	INDEX PAGE
# scan: 39 	scan_id: scan-39-odd-2
# 	INDEX PAGE
# scan: 39 	scan_id: scan-39-odd-3
# 	INDEX PAGE
# scan: 40 	scan_id: scan-40-even-0
# 	INDEX PAGE
# scan: 40 	scan_id: scan-40-even-1
# 	INDEX PAGE
# scan: 40 	scan_id: scan-40-odd-2
# 	INDEX PAGE
# scan: 40 	scan_id: scan-40-odd-3
# 	INDEX PAGE
# scan: 41 	scan_id: scan-41-even-0
# 	INDEX PAGE
# scan: 41 	scan_id: scan-41-even-1
# 	INDEX PAGE
# scan: 41 	scan_id: scan-41-odd-2
# 	INDEX PAGE
# scan: 42 	scan_id: scan-42-even-0
# 	INDEX PAGE
# scan: 42 	scan_id: scan-42-even-1
# 	INDEX PAGE
# scan: 42 	scan_id: scan-42-odd-3
# 	INDEX PAGE
# scan: 43 	scan_id: scan-43-even-0
# 	INDEX PAGE
# scan: 43 	scan_id: scan-43-even-1
# 	INDEX PAGE
# scan: 43 	scan_id: scan-43-odd-2
# 	INDEX PAGE
# scan: 43 	scan_id: scan-43-odd-3
# 	INDEX PAGE
# scan: 44 	scan_id: scan-44-even-0
# 	INDEX PAGE
# scan: 44 	scan_id: scan-44-even-1
# 	INDEX PAGE
# scan: 44 	scan_id: scan-44-odd-2
# 	INDEX PAGE
# scan: 44 	scan_id: scan-44-odd-3
# 	INDEX PAGE
# scan: 45 	scan_id: scan-45-even-0
# 	COLUMN IMPROPERLY CUT
# scan: 45 	scan_id: scan-45-even-1
# 	COLUMN IMPROPERLY CUT
# scan: 45 	scan_id: scan-45-odd-3
# 	RESOLUTION PAGE
# scan: 46 	scan_id: scan-46-even-0
# 	RESOLUTION PAGE
# scan: 46 	scan_id: scan-46-even-1
# \OTHER PAGE
# scan: 46 	scan_id: scan-46-odd-2
# 	RESOLUTION PAGE
# scan: 46 	scan_id: scan-46-odd-3
# \OTHER PAGE
# scan: 47 	scan_id: scan-47-even-0
# 	RESOLUTION PAGE
# scan: 47 	scan_id: scan-47-even-1
# 	RESOLUTION PAGE
# scan: 47 	scan_id: scan-47-odd-2
# \OTHER PAGE
# scan: 47 	scan_id: scan-47-odd-3
# \OTHER PAGE
# scan: 48 	scan_id: scan-48-even-0
# \OTHER PAGE
# scan: 48 	scan_id: scan-48-even-1
# 	RESOLUTION PAGE
# scan: 48 	scan_id: scan-48-odd-2
# 	RESOLUTION PAGE
# scan: 48 	scan_id: scan-48-odd-3
# \OTHER PAGE
# scan: 49 	scan_id: scan-49-even-0
# \OTHER PAGE
# scan: 49 	scan_id: scan-49-even-1
# \OTHER PAGE
# scan: 49 	scan_id: scan-49-odd-2
# 	RESOLUTION PAGE
# scan: 49 	scan_id: scan-49-odd-3
# 	RESOLUTION PAGE
# scan: 50 	scan_id: scan-50-even-0
# 	RESOLUTION PAGE
# scan: 50 	scan_id: scan-50-even-1
# 	RESOLUTION PAGE
# scan: 50 	scan_id: scan-50-odd-2
# 	RESOLUTION PAGE
# scan: 50 	scan_id: scan-50-odd-3
# \OTHER PAGE
# scan: 51 	scan_id: scan-51-even-0
# \OTHER PAGE
# scan: 51 	scan_id: scan-51-even-1
# 	RESOLUTION PAGE
# scan: 51 	scan_id: scan-51-odd-2
# \OTHER PAGE
# scan: 51 	scan_id: scan-51-odd-3
# \OTHER PAGE
# scan: 52 	scan_id: scan-52-odd-2
# \OTHER PAGE
# scan: 52 	scan_id: scan-52-odd-3
# \OTHER PAGE
# scan: 53 	scan_id: scan-53-even-0
# \OTHER PAGE
# scan: 53 	scan_id: scan-53-even-1
# \OTHER PAGE
# scan: 53 	scan_id: scan-53-odd-2
# 	RESOLUTION PAGE
# scan: 53 	scan_id: scan-53-odd-3
# 	RESOLUTION PAGE
# scan: 54 	scan_id: scan-54-even-0
# \OTHER PAGE
# scan: 54 	scan_id: scan-54-even-1
# 	RESOLUTION PAGE
# scan: 54 	scan_id: scan-54-odd-2
# \OTHER PAGE
# scan: 54 	scan_id: scan-54-odd-3
# 	RESOLUTION PAGE
# scan: 55 	scan_id: scan-55-even-0
# \OTHER PAGE
# scan: 55 	scan_id: scan-55-even-1
# \OTHER PAGE
# scan: 55 	scan_id: scan-55-odd-2
# \OTHER PAGE
# scan: 55 	scan_id: scan-55-odd-3
# 	RESOLUTION PAGE
# scan: 56 	scan_id: scan-56-even-0
# 	RESOLUTION PAGE
# scan: 56 	scan_id: scan-56-even-1
# 	RESOLUTION PAGE
# scan: 56 	scan_id: scan-56-odd-2
# 	RESOLUTION PAGE
# scan: 56 	scan_id: scan-56-odd-3
# 	RESOLUTION PAGE
# scan: 57 	scan_id: scan-57-even-0
# 	RESOLUTION PAGE
# scan: 57 	scan_id: scan-57-odd-2
# \OTHER PAGE
# scan: 57 	scan_id: scan-57-odd-3
# \OTHER PAGE
# scan: 58 	scan_id: scan-58-even-0
# 	RESOLUTION PAGE
# scan: 58 	scan_id: scan-58-even-1
# \OTHER PAGE
# scan: 58 	scan_id: scan-58-odd-2
# 	RESOLUTION PAGE
# scan: 59 	scan_id: scan-59-even-0
# 	RESOLUTION PAGE
# scan: 59 	scan_id: scan-59-even-1
# 	RESOLUTION PAGE
# scan: 59 	scan_id: scan-59-odd-3
# \OTHER PAGE
# scan: 60 	scan_id: scan-60-even-1
# 	RESOLUTION PAGE
# scan: 60 	scan_id: scan-60-odd-2
# 	RESOLUTION PAGE
# scan: 61 	scan_id: scan-61-even-1
# \OTHER PAGE
# scan: 61 	scan_id: scan-61-odd-2
# \OTHER PAGE
# scan: 61 	scan_id: scan-61-odd-3
# \OTHER PAGE
# scan: 62 	scan_id: scan-62-even-0
# \OTHER PAGE
# scan: 62 	scan_id: scan-62-even-1
# \OTHER PAGE
# scan: 62 	scan_id: scan-62-odd-2
# \OTHER PAGE
# scan: 63 	scan_id: scan-63-even-1
# \OTHER PAGE
# scan: 63 	scan_id: scan-63-odd-3
# 	RESOLUTION PAGE
# scan: 64 	scan_id: scan-64-even-0
# 	RESOLUTION PAGE
# scan: 64 	scan_id: scan-64-even-1
# 	RESOLUTION PAGE
# scan: 64 	scan_id: scan-64-odd-2
# 	RESOLUTION PAGE
# scan: 64 	scan_id: scan-64-odd-3
# 	RESOLUTION PAGE
# scan: 65 	scan_id: scan-65-even-0
# \OTHER PAGE
# scan: 65 	scan_id: scan-65-even-1
# \OTHER PAGE
# scan: 65 	scan_id: scan-65-odd-2
# \OTHER PAGE
# scan: 66 	scan_id: scan-66-even-0
# \OTHER PAGE
# scan: 66 	scan_id: scan-66-even-1
# \OTHER PAGE
# scan: 66 	scan_id: scan-66-odd-2
# \OTHER PAGE
# scan: 66 	scan_id: scan-66-odd-3
# 	RESOLUTION PAGE
# scan: 67 	scan_id: scan-67-even-1
# \OTHER PAGE
# scan: 67 	scan_id: scan-67-odd-3
# 	RESOLUTION PAGE
# scan: 68 	scan_id: scan-68-even-1
# \OTHER PAGE
# scan: 68 	scan_id: scan-68-odd-3
# 	RESOLUTION PAGE
# scan: 69 	scan_id: scan-69-even-0
# 	RESOLUTION PAGE
# scan: 69 	scan_id: scan-69-even-1
# \OTHER PAGE
# scan: 69 	scan_id: scan-69-odd-3
# \OTHER PAGE
# scan: 70 	scan_id: scan-70-even-0
# \OTHER PAGE
# scan: 70 	scan_id: scan-70-odd-2
# \OTHER PAGE
# scan: 70 	scan_id: scan-70-odd-3
# \OTHER PAGE
# index_scans: {6.3, 7.1, 7.0, 6.1, 6.2, 11.3, 7.2, 7.3, 8.0, 8.1, 8.2, 8.3, 9.0, 10.0, 11.1, 12.1, 13.0, 14.1, 15.3, 16.0, 26.3, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.3, 26.2, 27.0, 28.1, 29.0, 30.0, 32.0, 33.2, 33.3, 34.0, 35.1, 36.1, 37.1, 38.1, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 16.1, 17.0, 18.1, 18.4, 19.1, 19.4, 20.1, 21.4, 22.1, 23.1, 29.1, 30.1, 32.2, 32.3, 32.1, 34.2, 34.3, 35.2, 35.3, 36.2, 36.3, 37.2, 38.2, 38.3, 39.1, 39.2, 39.3, 40.1, 40.2, 40.3, 41.1, 41.2, 42.1, 42.3, 43.1, 43.2, 43.3, 44.1, 44.2, 44.3, 9.2, 9.3, 10.2, 10.3, 12.2, 12.3, 13.2, 14.3, 16.2, 16.3, 17.2, 17.3, 22.2, 22.3, 24.3, 27.3, 28.3, 28.2, 30.2, 30.3, 31.3}
# resolution_scans: {60.2, 54.3, 58.2, 59.1, 45.3, 46.2, 47.1, 46.0, 47.0, 48.1, 48.2, 49.2, 49.3, 50.0, 50.1, 56.0, 56.2, 56.1, 50.2, 51.1, 53.2, 53.3, 54.1, 55.3, 56.3, 57.0, 58.0, 59.0, 60.1, 63.3, 64.0, 64.1, 64.2, 64.3, 66.3, 67.3, 68.3, 69.0}

# %%
print(sorted(index_scans))

print(sorted(resolution_scans))

# %% [markdown]
# ### Parsing and Preprocessing Index Pages
#
# - filter tiny and huge text elements (i.e. deviating from average character/word width and height
# - extract page lines that are part of the main text body containing index entries
# - insert and clean up repetition symbols in index entries
#     - determine length of repetition symbol
#     - identify and replace mis-recognized repetition symbols

# %%
hocr_index_pages = []

for scan_file in scan_files:
    if scan_file["scan_num_column_num"] not in index_scans or scan_file["scan_num_column_num"] in resolution_scans:
        continue
    column_id = "{}-{}".format(scan_file["scan_num"], scan_file["scan_column"])
    hocr_index_page = make_hocr_page(scan_file["filepath"], column_id, remove_line_numbers=False, remove_tiny_words=True, tiny_word_width=6)
    hocr_index_page.scan_info = scan_file
    hocr_index_page.scan_info["num_page_ref_lines"] = count_page_ref_lines(hocr_page)
    hocr_index_pages += [hocr_index_page]



first_line = {}
index_header_found = {}
index_entry_lines = defaultdict(list)

for hocr_index_page in hocr_index_pages:
    lines = get_index_entry_lines(hocr_index_page)
    index_entry_lines[hocr_index_page.scan_info["scan_num_column_num"]] = lines
    first_line[hocr_index_page.scan_info["scan_num_column_num"]] = lines[0]
# Out:
# 6.1
# 	IS INDEX HEADER: 0 241 	## D           E           X.
# 6.2
# 	IS INDEX HEADER: 0 223 	##                        I           N           l
# 6.3
# 	IS INDEX HEADER: 0 204 	##           E           Xx.
# 7.0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 240 	##                      I           N.         l
# 7.1
# 	IS INDEX HEADER: 0 246 	##            E           Xx.
# 7.2
# 	IS INDEX HEADER: 0 230 	##                        Ï           N
# 7.3
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 231 	## )           Ë           x7
# 8.0
# 	IS INDEX HEADER: 0 278 	##                         I           N
# 8.1
# 	IS INDEX HEADER: 0 271 	## D           È           X.
# 8.2
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 254 	##               id           N           |
# 8.3
# 	IS INDEX HEADER: 0 260 	##            E           p.
# 9.0
# 	IS INDEX HEADER: 0 251 	##                      I           N           I
# 9.2
# 	IS INDEX HEADER: 0 225 	##    *                     Í           N           I
# 9.3
# 	IS INDEX HEADER: 0 206 	## D           E           Xx.
# 10.0
# 	IS INDEX HEADER: 0 236 	##                       1           N
# 10.2
# 	IS INDEX HEADER: 0 220 	##                    1           N           1
# 10.3
# 	IS INDEX HEADER: 0 201 	## )           E           Xx.
# 11.1
# 	IS INDEX HEADER: 0 221 	##           É           KX.
# 11.3
# 	IS INDEX HEADER: 0 226 	##            E           Xx.
# 12.1
# 	IS INDEX HEADER: 0 263 	##   D           E'
# 12.2
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 226 	##                   L           N           I
# 12.3
# 	IS INDEX HEADER: 0 202 	## )           E           x
# 13.0
# 	IS INDEX HEADER: 0 195 	##                     I           N           D
# 13.2
# 	IS INDEX HEADER: 0 224 	##                     I           N
# 14.1
# 	IS INDEX HEADER: 0 242 	## ETS          Xx.
# 14.3
# 	IS INDEX HEADER: 0 223 	## )           E           XxX.
# 15.3
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 215 	## 7          Ë           Xx,
# 16.0
# 	IS INDEX HEADER: 0 233 	##                        I           N
# 16.1
# 	IS INDEX HEADER: 0 225 	## )          E           Xx.
# 16.2
# 	IS INDEX HEADER: 0 218 	##                   el           N
# 16.3
# 	IS INDEX HEADER: 0 196 	##           E           X.
# 17.0
# 	IS INDEX HEADER: 0 211 	##                       ï           Ni.
# 17.2
# 	IS INDEX HEADER: 0 235 	##                   [          N
# 17.3
# 	IS INDEX HEADER: 0 223 	## >           É           Xx;
# 18.0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 273 	##                         Í           N           ‘
# 18.1
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 264 	## D           É           KX.
# 18.4
# 	IS INDEX HEADER: 0 232 	##           E           X.
# 19.0
# 	IS INDEX HEADER: 0 232 	##                     [          N:
# 19.1
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 242 	## )          É           X.
# 19.4
# 	IS INDEX HEADER: 0 220 	##           E          x.
# 20.0
# 	IS INDEX HEADER: 0 239 	##                        I           N         N
# 20.1
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 247 	## :          E         t X.
# 21.0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 301 	##                           I           N           C
# 21.4
# 	IS INDEX HEADER: 0 180 	##   GG        E           Xx.
# 22.0
# 	IS INDEX HEADER: 0 276 	##                          Ï           N           D
# 22.1
# 	IS IN TOP MARGIN
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 2 252 	## )           E           Xx.
# 22.2
# 	IS INDEX HEADER: 0 234 	##                            Î           N           L
# 22.3
# 	IS INDEX HEADER: 0 199 	## D           É           X.
# 23.0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 249 	##                        Ï          N;          c
# 23.1
# 	IS INDEX HEADER: 0 236 	## )          E           X.
# 24.0
# 	IS INDEX HEADER: 0 255 	##                    I           N.
# 24.3
# 	IS INDEX HEADER: 0 248 	##            E           X.
# 25.3
# 	IS INDEX HEADER: 0 249 	##            E           Xx
# 26.2
# 	IS INDEX HEADER: 0 245 	##                        I           N
# 26.3
# 	IS INDEX HEADER: 0 233 	##           È           Xx.
# 27.0
# 	IS INDEX HEADER: 0 240 	##     ee                 D          N'          |
# 27.3
# 	IS INDEX HEADER: 0 217 	## D           E              ee
# 28.1
# 	IS INDEX HEADER: 0 230 	## ï          E          XxX.
# 28.2
# 	IS INDEX HEADER: 0 237 	##                      FE           N
# 28.3
# 	IS INDEX HEADER: 0 224 	##           E&           X,
# 29.0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 2 241 	##                      p-       N           ]
# 29.1
# 	IS INDEX HEADER: 0 227 	##           Em.           xXx
# 30.0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 214 	##     ee.               Ï           N*.        ï
# 30.1
# 	IS INDEX HEADER: 0 227 	## )           É           X.
# 30.2
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 238 	##                    I           N           D
# 30.3
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 282 	## D           E           X.
# 31.3
# 	IS INDEX HEADER: 0 310 	##              …             -
# 32.0
# 	IS INDEX HEADER: 0 292 	##                       1           N
# 32.1
# 	IS INDEX HEADER: 0 291 	## )           E           u
# 32.2
# 	IS INDEX HEADER: 0 286 	##                    I           N           D
# 32.3
# 	IS IN TOP MARGIN
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 2 256 	## D           E:         Xx.
# 33.2
# 	IS INDEX HEADER: 0 233 	##                     1           N           D
# 33.3
# 	IS INDEX HEADER: 0 182 	##  D           E           X.
# 34.0
# 	IS INDEX HEADER: 0 238 	##                       I           N
# 34.2
# 	IS INDEX HEADER: 0 233 	##                         IE           ON
# 34.3
# 	IS INDEX HEADER: 0 227 	##          É           X:
# 35.1
# 	IS INDEX HEADER: 0 248 	##            É           Xx.
# 35.2
# 	IS INDEX HEADER: 0 246 	##                             KX        N           [
# 35.3
# 	IS INDEX HEADER: 0 208 	##   D           E           x.
# 36.1
# 	IS INDEX HEADER: 0 240 	##            E           X.
# 36.2
# 	IS INDEX HEADER: 0 246 	##                  ‘w           N
# 36.3
# 	IS INDEX HEADER: 0 235 	##            iJ           Xx.
# 37.1
# 	IS INDEX HEADER: 0 252 	## D           E           Xx!
# 37.2
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 258 	##                         I           N           Î
# 38.1
# 	IS INDEX HEADER: 0 278 	## )           F           Kx         &
# 38.2
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 276 	##                           I           N
# 38.3
# 	IS INDEX HEADER: 0 242 	## )          E           X:
# 39.0
# 	IS INDEX HEADER: 0 272 	##                       a           N
# 39.1
# 	IS INDEX HEADER: 0 274 	##           E           Xx.
# 39.2
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 267 	##                            I           N           |
# 39.3
# 	IS INDEX HEADER: 1 238 	## )           É           Xx.
# 40.0
# 	IS INDEX HEADER: 0 238 	##                       Ï           N
# 40.1
# 	IS INDEX HEADER: 0 254 	##            E           XJ
# 40.2
# 	IS INDEX HEADER: 0 249 	##                            Í           N           D
# 40.3
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 215 	## )           Ea         X:                   ‘
# 41.0
# 	IS INDEX HEADER: 0 252 	##                         ï           N
# 41.1
# 	IS INDEX HEADER: 0 255 	##              !           <
# 41.2
# 	IS INDEX HEADER: 0 230 	##                         I           N
# 42.0
# 	IS INDEX HEADER: 0 272 	##                       I          N
# 42.1
# 	IS INDEX HEADER: 0 261 	##            Ë           Xx.
# 42.3
# 	IS INDEX HEADER: 0 237 	## )           E           xl
# 43.0
# 	IS INDEX HEADER: 0 204 	##                         hb          NG
# 43.1
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 262 	## >           E           X.
# 43.2
# 	IS INDEX HEADER: 0 226 	##                      I           N
# 43.3
# 	IS INDEX HEADER: 0 217 	##           É           X.
# 44.0
# 	IS INDEX HEADER: 0 243 	##                        I           N
# 44.1
# 	IS INDEX HEADER: 0 240 	## D           E          @
# 44.2
# 	IS INDEX HEADER: 0 231 	##                        I           N           l
# 44.3
# 	IS INDEX HEADER: 0 199 	##            E           X.

# %%
from parse_republic_hocr_files import index_lemmata
avg_left = 0
lemma_index = defaultdict(list)
curr_lemma = None

    
for scan_id in index_entry_lines:
    print(scan_id, len(index_entry_lines[scan_id]))
    index_lemmata(scan_id, index_entry_lines[scan_id], lemma_index, curr_lemma)
# Out:
# 6.1 61
# 0 116 -20 start 	      ——  Scheepen tot  de  Equipagie   gereedt.
# 	PAGE_REFS: [185]
# 1 172 40 continue_stop 	         185.
# 	PAGE_REFS: [213]
# 2 115 -22 start_stop 	      —— (Gy/en aange[telt tot Capiteyn.  213.
# 3 115 -19 start 	      —— Commijie wegens Hollandt  voor den’
# 	PAGE_REFS: [260]
# 4 162 25 continue_stop 	         Heere Gallas.   260.
# 5 113 -29 start 	      —  confideratien  op  het  kleyn  Zegel.
# 	PAGE_REFS: [275]
# 6 166 31 continue_stop 	         275.
# 7 113 -27 start 	      —— Carrier  aangefteldt  tot  Contrerolleur
# 8 162 22 continue 	         van  de  Convoyen  en  Licenten  te  Venlo,
# 	PAGE_REFS: [320]
# 9 165 26 continue_stop 	         320.
# 10 112 -27 start 	      —— Commiie wegens Hollandt voor den
# 	PAGE_REFS: [367]
# 11 159 21 continue_stop 	         Heere van Leyden.   367.
# 12 109 -28 start 	      ——— gepermitteert  het  Schip  Overy(el te
# 	PAGE_REFS: [383]
# 13 158 23 continue_stop 	         verkoopen.  383.
# 14 110 -24 start 	      —_— bericht op de Memorie van den Mar-
# 	PAGE_REFS: [443]
# 15 157 24 continue_stop 	        quis de Fenelon.  443.
# 16 106 -26 start 	      —— van Sommelsdijck gelaft fteker Fluyt-
# 17 143 12 continue 	        Schip met fijn Ladinge  te mogen verkoopen.
# 	PAGE_REFS: [670]
# 18 155 24 continue_stop 	        670.
# 19 103 -26 start 	      —— Commiie  voor den Heer  Schildhou=
# 	PAGE_REFS: [696]
# 20 151 22 continue_stop 	        wer wegens Hollandt.  696.
# 21 104 -24 start 	      — item wegens Vrieslandt voor den Heer
# 	PAGE_REFS: [701]
# 22 150 22 continue_stop 	        van Haarsma.   701.
# 23 100 -22 start 	      — ygkende de adminiftratie van ’t kleyn
# 	PAGE_REFS: [716]
# 24 149 23 continue_stop 	        Zegel, te examineeren.   716.
# 25 101 -15 start 	      —  Lijfe  van  inkoomend  Rundvee  en
# 	PAGE_REFS: [717]
# 26 145 25 continue_stop 	        Varckens, te examineeren.  717.
# 27 96 -23 start 	     — rakende de  vafte refidentie der Offi-
# 	PAGE_REFS: [717]
# 28 144 26 continue_stop 	        cianten , te examineren.  717.
# 29 60 -57 start 	    mn ——  klaghte over feytelijckheden te Lillo,
# 30 141 20 continue 	        de  Admiraliteyt  in  Zeelandt  te berichten.
# 	PAGE_REFS: [724]
# 31 142 22 continue_stop 	        724.
# 32 91 -29 start 	     —_——  gelaft te berichten uyt wat hoofde door
# 33 138 19 continue 	       bare Bedienden te Vlaardingen gegeven zijn
# 34 138 11 continue 	       Pa/porten tot den aytvoer van Goederen die
# 	PAGE_REFS: [742]
# 35 138 18 continue_stop 	       verboden zijn.  742.
# 36 90 -29 start 	     —— klaghten over de Collegie in’t Noors
# 37 134 16 continue 	       der  Quartier  ,  het  felve  te  berichten,
# 	PAGE_REFS: [760]
# 38 133 16 continue_stop 	       760.
# 39 84 -27 start 	     — om verklaringe  op feekere Re[olutie ,
# 	PAGE_REFS: [771]
# 40 131 21 continue_stop 	       te examineeren.  771.
# 41 81 -33 start 	     — remarques  op  het nieuw Placaat en
# 	PAGE_REFS: [807]
# 42 129 22 continue_stop 	       Lijfte, te examineeren.  807.
# 43 81 -26 start 	     — wegens de Lakenen  uyt  ’s Hertogen-
# 44 128 22 continue 	       bofch en Breda na Leyden gebraght werden-
# 	PAGE_REFS: [808]
# 45 126 21 continue_stop 	       de en te rugge, te examineren.  808.
# 46 77 -33 start 	    — wegens Pa(]agiegeldt van feekere Kar-
# 	PAGE_REFS: [809]
# 47 130 27 continue_stop 	       ren, by Zeelandt overgenomen.   809.
# 48 74 -33 start 	    — repport  en refolutie  op haar remar-
# 49 122 21 continue 	       ques  op  het  nieuw  Placaat  en  Lijfte.
# 50 123 23 continue 	       SIL.
# 51 74 -30 start 	    —— rapport en refolutie wegens het Pa/]a-
# 	PAGE_REFS: [813]
# 52 114 12 continue_stop 	      giegeldt van Karren.   813.
# 53 75 -27 start 	    _—       te advifeeren op het ver[oek van Beug-
# 54 116 15 continue 	      holt‚ Bafecour en Vechoven ,  om [oo veel
# 55 116 17 continue 	      te declareeren en te genieten als tot nogh toe
# 	PAGE_REFS: [814]
# 56 112 14 continue_stop 	      gehadt hebben.   814.
# 57 68 -28 start 	    —— bericht van de ÁAdmiraliteyt in  Zee-
# 58 112 12 continue 	      landt op de klaghten , rakende de Bedienden
# 	PAGE_REFS: [815]
# 59 110 13 continue_stop 	      te Lillo.   815.
# 60 66 -27 start 	    mente He berigten op de Reque[te van Rees om de
# 6.2 60
# 7 Gap between line start and first word: 101 162 de na Zeelandt , te examineeren. 827.
# 16 Gap between line start and first word: 114 154 Oftober nogh voor drie weecken te [urcheren.
# 24 Gap between line start and first word: 92 152 936.
# 31 Gap between line start and first word: 45 139 pagie, te verftercken met vijftigh koppen.
# 0 108 -37 start 	     reghten van het Zout op den ouden voet fe
# 1 169 29 continue 	       betalen.  BIS.                            |
# 2 118 -25 start 	     —aange[fchreven  de  Refòlutie  van den
# 3 165 20 continue 	       den drie en twintighften  by provifie niet te
# 	PAGE_REFS: [822]
# 4 165 23 continue_stop 	       executeren. 822.
# 5 115 -31 start 	  —— Om  om ordes of ’s Landts reghten [ullen
# 6 164 27 continue 	       vorderen van Goederen komende uyt of gaan-
# 	PAGE_REFS: [827]
# 7 162 20 continue_stop 	       de na Zeelandt, te examineeren.   827.
# 8 115 -21 start 	     — advis op bet verfoerk van Rees,  en
# 	PAGE_REFS: [841]
# 9 142 9 continue_stop 	      afgewefen.   841.
# 10 93 -43 start 	   n___ advis en refolutie, rakende de Bedien-
# 	PAGE_REFS: [850]
# 11 157 28 continue_stop 	       den van het Zegel.   850.
# 12 114 -15 start 	     —— van Alblaferdam aangeftelt tot Ont-
# 13 135 2 continue 	     fanger van de Convoyen en Licenten te Eyndt-
# 14 146 17 continue 	      hoven. “ 85 s
# 15 105 -30 start 	    —_——— Refolutie van den drie en twistighften
# 16 154 19 continue 	      Oftober nogh voor drie weecken te [urcheren.
# 	PAGE_REFS: [889]
# 17 152 13 continue_stop 	      889.
# 18 110 -25 start 	     —— om  interpretatie wegens  Manufattu-
# 19 149 14 continue 	      ven ,  te  examineeren ,  en  Naaldens  ende
# 20 150 9 continue 	      Meen onder gemaakt Yerwerck begreepen.
# 	PAGE_REFS: [919]
# 21 150 15 continue_stop 	      919.
# 22 104 -31 start 	     —— geauthorifeert  boven [eekere premie,
# 23 149 18 continue 	      impuniteyt aan de Medeplightige te beloven.
# 	PAGE_REFS: [936]
# 24 152 21 continue_stop 	      936.
# HAS LEMMA: Admiraliteyt tot Amfterdam , Oatfanger
# LEMMA: Admiraliteyt tot Amfterdam
# 25 102 -29 start 	    Admiraliteyt  tot  Amfterdam  ,  Oatfanger
# 26 150 25 continue 	      Groeninx gelaft Jcekere penningen te betalen.
# 27 81 -48 start 	   —— te berichten op het ver(oek van Schry-
# 28 147 18 continue 	      ver wegens premie van veroverde Turck[che
# 29 146 23 continue 	      Rovers.   $9.
# 30 98 -30 start 	    ___— gelaft het grootfte Schip tot de Equi-
# 31 139 17 continue 	      pagie, te  verftercken  met  vijftigh  koppen.
# 	PAGE_REFS: [75]
# 32 146 17 continue_stop 	      75:
# 33 105 -19 start 	    —— te berichten op het ver[oeck van Rogh,
# 	PAGE_REFS: [79]
# 34 147 24 continue_stop 	      cum Íuis.   79.
# 35 97 -26 start 	    —— bericht op de Memorie van Grijs, te
# 	PAGE_REFS: [81]
# 36 143 19 continue_stop 	      examineeren.  81,
# 37 95 -24 start 	   —— rakende  het  heffen  van  het middel
# 	PAGE_REFS: [94]
# 38 145 22 continue_stop 	      van het kleyn Zegel, te examineeren.   94.
# 39 97 -26 start 	    —____— Lijft van het Rundvee, te examine-
# 40 146 19 continue 	      ren.  O1.
# 41 97 -25 start 	    —— notificerende, dat het haar ondoenlijck
# 42 145 17 continue 	      is ‚  haar Hoogh Mog. te berichten of vol-
# 43 144 16 continue 	      gens de Placaten te procederen tegens Schip-
# 	PAGE_REFS: [138]
# 44 137 9 continue_stop 	      per Statema.   138.
# 45 100 -27 start 	    —— advis op het verfoeck van Schrijvers,
# 46 142 15 continue 	      Provintien aangenomen haar  te verklaaren.
# 	PAGE_REFS: [45]
# 47 148 22 continue_stop 	      45.
# 48 98 -22 start 	    ——  Toeftant van de Schepen  onder haar
# 	PAGE_REFS: [237]
# 49 139 18 continue_stop 	      effort.   237.
# 50 92 -28 start 	   __—_— Commiie  voor  de  Heer  van  Laar
# 	PAGE_REFS: [277]
# 51 140 20 continue_stop 	      wegens Overy(el.   277.
# 52 91 -22 start 	   ——  confideratien  op  het  kleyn  Zegel.
# 	PAGE_REFS: [299]
# 53 142 24 continue_stop 	      299.
# 54 90 -23 start 	   —— commijfie voor den Heere van Haaren
# 	PAGE_REFS: [329]
# 55 141 23 continue_stop 	      wegens Vrieslandt.   329.
# 56 91 -24 start 	   —— bericht op de Memorie van den Mar-
# 	PAGE_REFS: [450]
# 57 139 20 continue_stop 	      quis de Fenelon.  450.
# 58 92 -23 start 	   —— de Bruyn aangeftelt tot Capiteyn  ter
# 59 141 21 continue 	      Zee.   454.                                |
# 6.3 61
# 41 Gap between line start and first word: 0 101 de Convoyen en Licenten tot Swolle. 169. :
# 48 Gap between line start and first word: 49 106 Heer Jelius. 304.
# 0 49 -16 start 	   —— fe advifeeren  op  de Mijfive  van de
# 1 81 22 continue 	     Hochepied wegens [ceker Engeljch  Schip de
# 	PAGE_REFS: [461]
# 2 80 18 continue_stop 	     Fenny Galley.   461.
# 3 35 -30 start 	   —— gdvis dien  aangaande ,  by Hollandt
# 	PAGE_REFS: [486]
# 4 81 20 continue_stop 	     overgenomen.  486.
# 5 33 -32 start 	   _——— notificeerende ,  dat  het  voorfchreevé
# 6 79 20 continue 	     Schip aldaar binnen gevallen was zen ordres.
# 	PAGE_REFS: [525]
# 7 82 23 continue_stop 	     525:
# 8 33 -26 start 	   —____ gakende  bet Schip de Jenny Galley4
# 	PAGE_REFS: [587]
# 9 82 23 continue_stop 	     te examineeren.   587:
# 10 33 -26 start 	   —— aangefchreven de Jenny Galley te Tas
# 	PAGE_REFS: [591]
# 11 78 18 continue_stop 	     ten loen.   591.
# 12 36 -19 start 	   —— propofitie vm twee Commien Generaal
# 	PAGE_REFS: [637]
# 13 81 20 continue_stop 	     aan te tellen, geaccordeert.  637.
# 14 34 -22 start 	   ——— Buys en vander Meulen aangeftelt tot
# 	PAGE_REFS: [639]
# 15 86 24 continue_stop 	     Commifen Generaal.  639.
# 16 36 -23 start 	   ——— commijie  wegens  Hollandt voor den
# 	PAGE_REFS: [716]
# 17 84 19 continue_stop 	     Heer vander Waeyen.   716.
# 18 37 -24 start 	   ——— Lijfte  van  inkoomende  Rundvee  en
# 	PAGE_REFS: [786]
# 19 87 20 continue_stop 	     Varckens.  786,
# 20 54 -13 start 	    —— Torck, belofte op  den  eedt ten aaR-
# 	PAGE_REFS: [896]
# 21 88 15 continue_stop 	     vangh van fijn bedieninge gedaan.  896.
# 22 45 -24 start 	   —_      #6 advifteren op de Miffive van Aar (èn
# 23 90 20 continue 	     van Sommelsdijck om feeker hernomen Schip
# 24 89 19 continue 	     en Laadinge  tot Cadix te mogen verkoöpen.
# 	PAGE_REFS: [908]
# 25 91 16 continue_stop 	      908.
# 	PAGE_REFS: [916]
# 26 44 -31 start_stop 	   —— bericht ‘en geaccordeerf.  916.
# HAS LEMMA: Admiraliteyt in het Noorder Quartier ; amf=
# LEMMA: Admiraliteyt in het Noorder Quartier
# 27 45 -31 start 	   Admiraliteyt in het Noorder Quartier; amf=
# 28 92 16 continue 	      woordt  op  de Miffive  van vanden Boch,
# 29 93 22 continue 	      rakende  de Vaart van  Borkom op Áltena.
# 	PAGE_REFS: [49]
# 30 94 22 continue_stop 	      49:
# 31 47 -25 start 	   —— Lift van inkomend Rundvee en Vat-
# 	PAGE_REFS: [61]
# 32 94 16 continue_stop 	      kens.  61.
# 33 46 -27 start 	   — vrapport, rakende de Vaart van Böf-
# 	PAGE_REFS: [67]
# 34 93 19 continue_stop 	      kom op Altena.  67.
# 35 49 -26 start 	   —— rakende de adminiftratie van het klejn
# 	PAGE_REFS: [131]
# 36 98 22 continue_stop 	      Zegel, te examineeren.  131.
# 37 50 -26 start 	   —— Ramhorft  aangefteldt. tot  Ontfanger
# 38 99 20 continue 	      van  de  Convoyen  en  Licenten tot  Ha{el.
# 	PAGE_REFS: [169]
# 39 103 24 continue_stop 	      169.
# 40 52 -28 start 	    —— Golts  aangefteldt  tot Ontfanger vam
# 41 101 20 continue 	      de Convoyen en Licenten tot Swolle.   169. :
# 42 66 -21 start 	    —— wegens  aangevinge  van Rundvee én
# 	PAGE_REFS: [178]
# 43 100 17 continue_stop 	      Varckens.   178.
# 44 55 -28 start 	    ———— Greveftein  aangefteldt  tot  Contrerol-
# 45 108 24 continue 	      leur van de Comvoyen en Licenten tot Ha(fel.
# 	PAGE_REFS: [256]
# 46 107 22 continue_stop 	      256.
# 47 56 -28 start 	    ——— commijfie  wegens  Hollandt  voor  de
# 	PAGE_REFS: [304]
# 48 106 29 continue_stop 	      Heer Jelius.   304.
# 49 61 -17 start 	    — iten voor de Heer Aylua wegens Pries-
# 	PAGE_REFS: [310]
# 50 106 28 continue_stop 	      landt.   310.
# 51 62 -11 start 	    ——  Akerlaken  aangefteldt  zot  Capiteyn,
# 52 37 -42 start 	   uw  35
# 53 59 -24 start 	    and    Houttuyn aangefteldt  tot Capiteya op
# 	PAGE_REFS: [361]
# 54 110 29 continue_stop 	       den Uytlegger van het Collegie.   361.
# 55 67 -18 start 	    —— de  Zee  aangefteldt  tot  Contrerolleus
# 56 111 27 continue 	       van de Convoyen en Licenten t0t Medenblick.
# 	PAGE_REFS: [80]
# 57 137 47 continue_stop 	        80.
# 58 47 -48 start 	   ——   van Schaak aangefteldt  tot Capiteyn.
# 	PAGE_REFS: [92]
# 59 140 48 continue_stop 	        92.
# 60 54 -43 start 	    pa       wegens fraudes van  de Middelen tof
# 7.0 61
# 27 Gap between line start and first word: 4 105 genten van Aardenbergh om ‘exemptie van
# 0 103 18 continue 	      OveryjJel , Staaten verfoght  woorfieninge te
# 	PAGE_REFS: [414]
# 1 100 20 continue_stop 	      doen.  414.
# 2 54 -29 start 	   — Lifte  van  inkoomende  Rundvee  en
# 	PAGE_REFS: [440, 688]
# 3 104 25 continue_stop 	      Varkens.   440. 688.
# 	PAGE_REFS: [456]
# 4 66 -15 start_stop 	     —— antwoordt van Overyfel.  456.
# 5 58 -18 start 	    —— antwoordt  op  de  Memorie  van den
# 	PAGE_REFS: [487]
# 6 99 23 continue_stop 	      Marquis de Fenclon.  487.
# 7 52 -25 start 	   ——_— tegens het Schip van Cornelis Otter
# 	PAGE_REFS: [616]
# 8 99 22 continue_stop 	      te examineeren.  616.
# 9 56 -20 start 	    ——  te  berichten  op  de klaghtem. van de
# 	PAGE_REFS: [760]
# 10 104 22 continue_stop 	      Admmiraliteyt op de Maze.  760.
# 11 57 -21 start 	    ——  rakende de meetinge der Koopvaardye
# 	PAGE_REFS: [772]
# 12 107 22 continue_stop 	      Schepen, te examineeren.  772.
# 13 59 -27 start 	    —— vemarqgues  op  ‘het nieuw Placaat cn
# 	PAGE_REFS: [807]
# 14 113 27 continue_stop 	      Lijfte.   807.
# 15 63 -24 start 	    — om het Schip het Wapen van Alck-
# 16 108 22 continue 	      maar te mogen verkoopen, by Hollandt over-
# 	PAGE_REFS: [808]
# 17 109 22 continue_stop 	      genoomen.   808.
# 18 60 -27 start 	    — rapport en refolutie-op haar remarques
# 	PAGE_REFS: [812]
# 19 110 23 continue_stop 	      op het nieuw Placaat en Lijfte.   812.
# 20 52 -39 start 	   ——— gepermitteert  het  Schip bet  Wapen
# 	PAGE_REFS: [901]
# 21 111 19 continue_stop 	      van Alckmaar te mogen verkoopen,  901.
# HAS LEMMA: Admiralteyt in Zeelandt „ ‘inftantien van
# LEMMA: Admiralteyt in Zeelandt
# 22 62 -25 start 	    Admiralteyt  in  Zeelandt „  ‘inftantien  van
# 23 112 20 continue 	      Kooplieden.  tot  den  uytwoer  van  goude en
# 24 100 8 continue 	      Jilvere  Specien, ‘de.  Tetroafta  ‘ma  te fen.
# 	PAGE_REFS: [167]
# 25 116 18 continue_stop 	       167.
# 26 61 -32 start 	    — #6 advifeeren op het verfoeck van Re-
# 27 105 12 continue 	      genten van  Aardenbergh  om  ‘exemptie van
# 28 110 17 continue 	      bet Placaat wegens belaftinge wan OJen en
# 	PAGE_REFS: [296]
# 29 111 22 continue_stop 	      Koeyen,   296.
# 	PAGE_REFS: [305]
# 30 62 -27 start_stop 	    —— gereet Schip tot het E/quadre. 305.
# 31 63 -33 start 	    — Stokke  aangefteldt  tot  Capiteyn.
# 	PAGE_REFS: [491]
# 32 112 16 continue_stop 	      491.
# 33 65 -31 start 	    ——  van  Hoorn  aangefteldt  ‘als  Commis
# 	PAGE_REFS: [658]
# 34 112 21 continue_stop 	      Generaal.  658.
# 35 129 32 continue 	        —— berichten wegens  klaghten van ‘de
# 36 103 6 continue 	      Admiraliteyt op de Maze wegens feytelijck-
# 37 113 26 continue 	      beden te Lillo.   724   \
# 38 66 -21 start 	      —— aangefchreven met moderatie te proce-
# 39 112 25 continue 	      deren tegens Schipper Schollaart.   741."
# 40 66 -12 start 	    —  grdre  om  het  nieuwe  Placaat  en
# 	PAGE_REFS: [743]
# 41 24 -55 start_stop 	  *     Lijfte niet te executeren en refolttie. 743.
# 42 64 -15 start 	    — aangefchreven dat haar Hoogh Mog.
# 	PAGE_REFS: [792, 802]
# 43 114 34 continue_stop 	       de excufe niet aannemen.   792. 802.
# 44 46 -34 start 	   —— bericht op de klaghtén ‘van de Admi-
# 45 114 26 continue 	       raliteyt op de Maze, rakende de Bedienden
# 	PAGE_REFS: [815]
# 46 113 21 continue_stop 	      te Lillo.   815.
# 47 69 -29 start 	    ——— Slicher en Backer belofte ‘op den eedt
# 48 114 21 continue 	       To  aanvangh van haar bedieninge gedaan.
# 	PAGE_REFS: [17]
# 49 139 40 continue_stop 	        17.
# 50 63 -31 start 	  —— ns  item van Na(auw, Heér van Drie-
# 	PAGE_REFS: [827]
# 51 113 19 continue_stop 	      bergen.   827.
# 52 66 -29 start 	    — gepermitteert de oude Lijfte nogh vobn
# 	PAGE_REFS: [829]
# 53 108 14 continue_stop 	      drie weecken te continueren.   829.
# 54 63 -23 start 	    —— gepermitteert de gerequireerde verkla-
# 	PAGE_REFS: [956]
# 55 116 24 continue_stop 	       vinge Jchriftelijck te mogen. doen.   956.
# 56 73 -19 start 	     —— met de voor[z verklaringe by provifie
# 	PAGE_REFS: [966]
# 57 107 12 continue_stop 	      genoegen genomen.  966.
# HAS LEMMA: Admiraliteyt in Vrieslandt, :advis ‘op de Me-
# LEMMA: Admiraliteyt in Vrieslandt
# 58 67 -26 start 	    Admiraliteyt in Vrieslandt, :advis ‘op de Me-
# 59 115 17 continue 	       morie van Greis ,  raakende  het  opreghten
# 60 115 20 continue 	       van twee  Vuurbaacken op  de Kuften van
# 7.1 60
# 8 Gap between line start and first word: 0 100 en Hamburgh , by Hollandt overgenomen.
# 12 Gap between line start and first word: 57 154 LD rapport wegens Rundvee ‘en Varckens,
# 0 93 28 continue 	      Noorweegen ‚  by  Hollandt  overgenoomen.
# 	PAGE_REFS: [1540]
# 1 100 38 continue_stop 	      1540.
# 2 45 -22 start 	   —— antwoordt op baar Hoogh Mog. -Re-
# 3 87 17 continue 	     folutie werens Lijfte van Rundveeen Varc-
# 	PAGE_REFS: [150]
# 4 1 -73 start_stop 	 …    kens   te examineeren. * 150.
# 5 48 -27 start 	   —  gdvis  op  de  Mifive  van  vanden
# 6 100 30 continue 	      Bofch,  rakende de aangroey van de Sthip-
# 7 93 16 continue 	      pers  van  het Eylandt Borkum. op   Akuna
# 8 100 15 continue 	      en Hamburgh ,  by  Hollandt overgenomen.
# 	PAGE_REFS: [150]
# 9 108 12 continue_stop 	      150.
# 10 54 -48 start 	    —____ akende de adminiftratie van ’t kleyn
# 11 108 10 continue 	      Zegel, te examineeren.   15T,
# 12 154 55 continue 	         LD  rapport wegens Rundvee ‘en Varckens,
# 13 101 0 start 	      geauthorifeert [eekere  pie
# 14 107 6 continue 	      bliceeren en ter executie te leggen.
# 15 59 -48 start 	    —— deduêtie van het recht waar op funm-
# 16 108 6 continue 	      doeren hare pretenfien ‘ende grieven tot het
# 17 111 14 continue 	       beffen van  de Convoyen  en Licentemop de
# 18 111 18 continue 	       Middelgronden en aan den Abt, te exami-
# 	PAGE_REFS: [178]
# 19 110 16 continue_stop 	       ueeren.   178.
# 20 62 -33 start 	    ——— Commifie wegens  Utrecht woor den
# 	PAGE_REFS: [236]
# 21 112 18 continue_stop 	       Heer de Leeuw.  236.
# 22 63 -26 start 	    ——  Burmania  aangefteldt 101 Gapiteyn.
# 	PAGE_REFS: [258]
# 23 115 24 continue_stop 	       258.
# 24 65 -21 start 	    —— Commmijfie wegens Vrieslandt voor Pe-
# 	PAGE_REFS: [76]
# 25 105 19 continue_stop 	      gelin van Claarbergen.   76.
# 26 66 -21 start 	    —— item  wegens Vrieslandt voor Bìncke
# 	PAGE_REFS: [280]
# 27 121 28 continue_stop 	       Symons.   280.
# 28 66 -27 start 	    — item wegens Frieslandt voor Rengers.
# 29 65 -29 start 	    —— te berichten op de klaghtenvan Mey-
# 30 118 22 continue 	       aertshagen, nopenie bet aanhouden van vier
# 31 117 20 continue 	       hondert vijf en dertich ftucken Nooteboomen
# 	PAGE_REFS: [313]
# 32 119 22 continue_stop 	       Hout.   313.
# 33 72 -25 start 	     ——— Comimijie voor de Heer Gruys wegens
# 	PAGE_REFS: [317]
# 34 121 18 continue_stop 	       Stadt en Lande.   317.
# 35 74 -26 start 	     ——  Mifive  in [aveur van Bovwmans.,
# 	PAGE_REFS: [346]
# 36 122 21 continue_stop 	       de retroafta na te fien.  346.
# 37 73 -28 start 	     —— gepermitteert  te accorderen ‘de vryen
# 	PAGE_REFS: [346]
# 38 119 18 continue_stop 	       uyt- en invoer van Paarden.   346.
# 39 88 -14 start 	     —— te berichten  op  de klaghten van-de
# 40 123 15 continue 	       Staaten ’s Landts van Drenthe wegens’exe-
# 	PAGE_REFS: [384]
# 41 120 17 continue_stop 	       cutien te Rooswinckel.   384.
# 42 77 -32 start 	     —— bericht op de Memorie van Meynerts-
# 43 123 18 continue 	       hagen, rakende bet Nooteboomen Hout €
# 	PAGE_REFS: [399]
# 44 127 19 continue_stop 	       re[olutie.  399.
# 45 78 -26 start 	     ——— [Lijfte van bet inkomende Rundtvee,
# 	PAGE_REFS: [399]
# 46 128 23 continue_stop 	       te oxamineeren.   399.
# 47 81 -27 start 	     ——— Commijfie voor de Heer Schultens we-
# 48 121 12 continue 	       gens Stadt ‘en Lande.  437
# 49 85 -27 start 	     — gelaft de aangehaalde fucken Noote-
# 	PAGE_REFS: [481]
# 50 131 13 continue_stop 	        boomen Hout te ontflaan.  481.
# 51 99 -20 start 	      _—       de Haan aangefteldt als ‘Contrerolleur
# 52 132 7 continue 	        van de Convoyen ‘en Licenten in :de Lemmer.
# 	PAGE_REFS: [37]
# 53 160 34 continue_stop 	         37.
# 54 133 1 continue 	        ee    rakende de adminiftreatie van ’ttleyn
# 	PAGE_REFS: [667]
# 55 134 2 continue_stop 	        Zegel, te examineren.   667.
# 56 132 -4 start 	       —— Tyfte van ‘de inkomende Rundvee en
# 	PAGE_REFS: [667]
# HAS LEMMA: Varckens. 667.
# LEMMA: Varckens
# 57 135 -2 start_stop 	        Varckens.  667.
# 58 132 -1 start 	      —— op Haar ‘geweccordeerde fb fidie “van
# 59 136 3 continue 	        vyf en dertigh duy/ent guldens “sjaarsyPro-
# 7.2 62
# 3 Gap between line start and first word: 77 110 beloften als nu te doen in plaats van op den
# DEVIATING LINE: 111 [107, 109, 63, 110, 111, 70, 108, 34, 0] 815.
# avg_repeat_symbol_length: 143
# DEVIATING LINE: 108 [63, 110, 0, 70, 108, 34, 0, 61, 59] meefters, te examineeren. 816.
# avg_repeat_symbol_length: 143
# 0 112 11 continue 	       vincien  aangenoomen  haar  te  verklaaren.
# 	PAGE_REFS: [675]
# 1 111 17 continue_stop 	       675.
# 2 64 -32 start 	    pmne  Gecommitteerden geadmitteert  op  de
# 3 110 18 continue 	       beloften als nu te doen in plaats van op den
# 4 109 15 continue 	      vierden Oftober 685.     ee
# 5 62 -31 start 	    —— Commijie wegens Vrieslandt voor den
# 	PAGE_REFS: [787]
# 6 109 21 continue_stop 	      Heere Lyclama a Nyeholt.   787.
# 7 62 -31 start 	    ——— bericht op de klaghten van de Admi-
# 8 107 26 continue 	      valiteyt op de Maze over den Convoymeefter
# 	PAGE_REFS: [810]
# 9 109 33 continue_stop 	      tot Swolle , te examinceren.   810.
# 10 63 -7 start 	    — advis op het verfoeck van Beugholt,
# 11 110 49 continue 	       Ba(ccour  en  Vechoven ,  te  examineren.
# 	PAGE_REFS: [815]
# 12 0 -54 start_stop 	       —— 815.
# 13 70 21 continue 	     —— advis wegens Reglement voor de Yck-
# 	PAGE_REFS: [816]
# 14 0 -44 start_stop 	      —— meefters, te examineeren.   816.
# 15 34 -3 start 	   —— rapport wegens Bedienden van ’t kleyn
# 	PAGE_REFS: [843]
# 16 0 -24 start_stop 	      —— Zegel en refolutie.   843.
# 17 61 30 continue 	    Siet verder Zeefaken.
# 18 59 35 continue 	    Advocaten  van het Landt  te advifteren in
# 19 0 -24 start 	      —— de fake van den Prince van Hornes tegens
# 	PAGE_REFS: [15]
# 20 0 -27 start_stop 	      —— la Motte.   15.
# 	PAGE_REFS: [127]
# 21 62 27 continue_stop 	    — advis en refolutie.   127.
# 22 0 -28 start 	 —— 6  advifeeren  op het  difput  tu(chen
# 	PAGE_REFS: [400]
# 23 0 -28 start_stop 	      —— Benthem en de Prez.  400.
# 	PAGE_REFS: [513]
# 24 69 41 continue_stop 	     —— advis dien aangaande.   513.
# 25 68 33 continue 	     —— fe berichten op de Requcfte van Rey:
# 	PAGE_REFS: [617]
# 26 0 -28 start_stop 	      —— gersman.  617.
# 27 60 25 continue 	    —— Regquefie van Collard ter handen, ge-
# 	PAGE_REFS: [860]
# 28 0 -35 start_stop 	      —— fteldt.  860.
# 29 61 27 continue 	    ____—_— Heuft aangefteldt tot ’s Landts Ad-
# 	PAGE_REFS: [875]
# 30 0 -33 start_stop 	      —— vocaat.   875.
# 31 59 26 continue 	    —  gdvis  in de [aaken  van  Collard.
# 	PAGE_REFS: [916]
# 32 0 -27 start_stop 	      —— 916.
# 	PAGE_REFS: [526]
# 33 61 27 continue_stop 	    van Affelen, executoriaal.   526.
# 34 64 37 continue 	    _—       die  van  den Leenbove  van Water-
# 35 0 -34 start 	      —— vliedt gelaft hun [onder uytftel te ftellen in
# 	PAGE_REFS: [641, 726]
# 36 0 -27 start_stop 	      —— Erve van [eeker Leengoedt.  641. 726.
# 37 61 34 continue 	    —— belangh van die van Woatervliedt niet
# 	PAGE_REFS: [742]
# 38 0 -20 start_stop 	       —— voldoende.  742.
# 39 63 43 continue 	    ——  Raadt van Flaanderen aange[chreven
# 40 0 -20 start 	       —— om by defett van den Leenhove van Water-
# 41 0 -20 start 	       —— wliedt, en in het voorfz Leengoedt  te doen
# 	PAGE_REFS: [865]
# 42 0 -22 start_stop 	       —— erven.  865.
# 43 64 42 continue 	    van Afferden, zotificeerende, dat Reiners mids
# 44 0 -15 start 	       —— del  hadde gevonden om uyt  cen venter te
# 	PAGE_REFS: [122]
# 45 0 -23 start_stop 	       —— [bringen en te ontvlughten.   122,
# 46 75 52 continue 	     —— te berichten op het verfoeck van Re-
# 47 0 -23 start 	       —— genten  van  Venlo  om [eekere  impoften  te
# 	PAGE_REFS: [604]
# 48 0 -24 start_stop 	       —— verhoogen.  604.
# 49 70 46 continue 	     —— item  op het verfoeck van de Magi-
# 50 0 -32 start 	      —— Araat van Venlo , om [urcheantie van [ee-
# 	PAGE_REFS: [760]
# 51 0 -24 start_stop 	       —— kere executie.   760.
# 52 77 53 continue 	     —— af te waghten fijn nader bericht om-
# 	PAGE_REFS: [800]
# 53 0 -32 start_stop 	       —— trent de nieuwe belaftinge.  800.
# 54 70 46 continue 	     Akerlaken aangefteldt  tot Capiteyn  onder het
# 55 0 -24 start 	       —— Collegie  ter  Admiraliteyt  in  het  Noorder
# 	PAGE_REFS: [352]
# 56 0 -32 start_stop 	       —— Quartier.   352.
# 57 71 47 continue 	     van  Alblaflerdam aangefteldt  tot  Ontfanger
# 58 0 -27 start 	       —— van  de Convoyen  en Licenten  te Eyndtho-
# 	PAGE_REFS: [852]
# 59 0 -21 start_stop 	       —— 852.
# 60 77 53 continue 	     Altona ,  ver/oeck  om  afiftentie ‚  afgewee[en.
# 	PAGE_REFS: [688]
# 61 0 -29 start_stop 	       —— 688.
# 7.3 59
# 44 Gap between line start and first word: 0 54 de Bacqaere om execuriaal den Raadt van
# HAS LEMMA: Amiot ; cum fuis ‚ Brieven van voor [chrijs
# LEMMA: Amiot
# 0 48 -28 start 	   Amiot ;  cum fuis‚ Brieven van voor [chrijs
# 	PAGE_REFS: [693]
# 1 97 25 continue_stop 	      vens aan het Hof van Spaigne.   693.
# HAS LEMMA: Ardes , A/aghten over nieuwigheden door den
# LEMMA: Ardes
# 2 49 -19 start 	   Ardes ,  A/aghten over nieuwigheden  door den
# 3 95 23 continue 	      Monboir  Junckers geïntroduceert  werdendé
# 	PAGE_REFS: [71]
# 4 95 26 continue_stop 	      defelve te berichten.  71.
# 	PAGE_REFS: [626]
# 5 49 -23 start_stop 	    —— vier maanden verlof.  626,
# HAS LEMMA: Arnols, ver/oeck om Goederen in tocht bezees
# LEMMA: Arnols
# 6 48 -24 start 	   Arnols, ver/oeck om Goederen in tocht bezees
# 	PAGE_REFS: [40]
# 7 95 23 continue_stop 	      ten te mogen verkoopen, afgewefen. 40:
# 8 46 -25 start 	   van Afperen, cúm {uis,  Brieven van voors
# 9 80 14 continue 	     Schrijvens aan het Hof van baare Czaarfè
# 	PAGE_REFS: [699, 791]
# 10 95 24 continue_stop 	      Majefteyt.   699. 791.
# 11 45 -31 start 	   van  Aflendelft ,  Brieven  van voor[chrijvens
# 	PAGE_REFS: [623]
# 12 93 17 continue_stop 	      aan bet Hof van Sweeden.  623.
# 13 46 -30 start 	   d'Averóult ‚  Heer van Guincourt, aangeftelt
# 14 92 20 continue 	      als Drofard van de Stadt en Baronnye van
# 15 94 28 continue 	      Breda, mits ter The[aurie fonrneerende vijf
# 	PAGE_REFS: [186]
# 16 93 21 continue_stop 	      en veertigh duy/ent guldens.   186.
# 	PAGE_REFS: [197]
# 17 46 -21 start_stop 	   —— eedt van [uyveringe.   197.
# 	PAGE_REFS: [880]
# HAS LEMMA: Ayen, Oftroy om ie dijponeeren. 880:
# LEMMA: Ayen
# 18 47 -25 start_stop 	   Ayen, Oftroy om ie dijponeeren.   880:
# HAS LEMMA: Aylua wegens Vrieslandt gecommitteert ter Ads
# 19 46 -29 start 	   Aylua wegens Vrieslandt gecommitteert ter Ads
# 	PAGE_REFS: [310]
# 20 94 24 continue_stop 	      miraliteyt in het Noorder Quartier.  310.
# 21 46 -24 start 	   d’'Ayrolles ‚  Pa/port  om eenige Bagagie van
# 22 95 25 continue 	      Camerik  naar Engelanat  te  tran[pörteeren;
# 	PAGE_REFS: [66]
# 23 118 43 continue_stop 	       66.
# 24 46 -30 start 	   —— Pa[port om dertien Paarden na Has
# 	PAGE_REFS: [411]
# 25 96 20 continue_stop 	      nover te mogen voeren.   411.
# 26 49 -26 start 	   —— Pafport  om de Meubilen en Bágagie
# 	PAGE_REFS: [432]
# 27 93 19 continue_stop 	      voor den Heer Finck in te voeren.   432.
# 28 50 -16 start 	    —— item om  aght  Paarden na Hanover
# 	PAGE_REFS: [448]
# 29 96 30 continue_stop 	      te tran[porteren.  448.
# 30 36 -28 start 	   ——— ‘item  om drie Paarden na Spa te m0:
# 	PAGE_REFS: [505]
# 31 86 22 continue_stop 	     gen uytvoeren.   505.
# 	PAGE_REFS: [728]
# 32 44 -15 start_stop 	   —— verwellekomt.  728.
# 33 46 -12 start 	   —— om cftorte voer fijn Majefteyten ges
# 	PAGE_REFS: [962]
# 34 77 18 continue_stop 	     ‘accordeert.  962,
# 35 53 -7 start 	    ——  Marckgraave, creditif op  de Ïá
# 36 44 -13 start 	 —— Divere als Refident ,  en niet geadmit-
# 37 44 -19 start 	 —— teert, als zijnde een Onderdaan van den
# 	PAGE_REFS: [996]
# 38 101 37 continue_stop 	      Staat.  996.
# 	PAGE_REFS: [158]
# HAS LEMMA: Baake , Brieven requifitoir verleent. 158.
# LEMMA: Baake
# 39 52 -13 start_stop 	    Baake, Brieven requifitoir verleent.   158.
# 40 52 -13 start 	    van Baayen wegens Gelderlandt ter Generalis
# 41 102 30 continue 	      teyt gecommittesrt.   $05.
# HAS LEMMA: Backer, belofte op den eedt ten aanvangh van
# LEMMA: Backer
# 42 54 -20 start 	    Backer, belofte op den eedt ten aanvangh van
# 	PAGE_REFS: [817]
# 43 90 16 continue_stop 	     /ijn ladinge gedaen.   817.
# 44 54 -20 start 	    de Bacqaere  om  execuriaal den Raadt  van
# 	PAGE_REFS: [956]
# 45 105 25 continue_stop 	      Staate te advifgeren.   956.
# HAS LEMMA: Barbut Brieven van voorfchryvens aan ’t Hof
# 46 57 -24 start 	    Barbut Brieven van voorfchryvens aan ’t Hof
# 	PAGE_REFS: [477]
# 47 102 15 continue_stop 	      van Engelandt.  477.
# HAS LEMMA: Baffecour 9% 00 veel te moogen genieten €n
# 48 56 -22 start 	    Baffecour  9% 00 veel te moogen genieten €n
# 49 104 20 continue 	      declareren als tot mogh toe genooten, en des
# 50 107 28 continue 	      clareert heeft, de Admiraliteyt te adviferen.
# 	PAGE_REFS: [814]
# 51 108 23 continue_stop 	      814.
# 52 13 -67 start 	  ——   advis van de Admiraliteyt in Pries:
# 	PAGE_REFS: [815]
# 53 107 19 continue_stop 	      landt, te examineeren.   815.
# 54 61 -28 start 	    — gepermitteert  nogh  twee maanden op
# 55 108 22 continue 	      den voet te continueren.  977À
# HAS LEMMA: Baftie ‚ Weduwe , twee hondert guldens toes
# LEMMA: Baftie ‚ Weduwe
# 56 62 -21 start 	    Baftie ‚ Weduwe ,  twee hondert  guldens toes
# 	PAGE_REFS: [462]
# 57 129 34 continue_stop 	       eleghte    462,
# 58 106 13 continue 	      gees     4      B                    de
# 8.0 60
# 0 Gap between line start and first word: 31 107 de Baudous om de Doêtorsplaats van ’s Lands
# 15 Gap between line start and first word: 4 98  Bededagh geproponeert. 123.
# DEVIATING LINE: 155 [107, 156, 155, 107, 147, 56, 49] ten. 266.
# avg_repeat_symbol_length: 151
# DEVIATING LINE: 104 [107, 147, 56, 49, 104, 49, 3, 3, 3] Becker, creditif van den Furft van Ooftvries-
# avg_repeat_symbol_length: 151
# 0 107 -6 start 	      de Baudous om de Doêtorsplaats van ’s Lands
# 1 156 53 continue 	         Vloot, de [elve voor eerft omvergeven te la-
# 	PAGE_REFS: [266]
# 2 49 -46 start_stop 	         —— ten.   266.
# 3 107 23 continue 	      Beaufort aangefteldt tot Secretaris, Schoolmee-
# 4 147 67 continue 	        fer  en  Kofter van  de Heerlijkheden  van
# 5 56 -12 start 	    .        Ei   en Zoelmont ‚  midts vier duy[ent
# 	PAGE_REFS: [166]
# 6 49 -2 start_stop 	        —— gulden ter The[aurie fourneerende.   166.
# 7 3 -43 start 	      —— Becker, creditif van den Furft van Ooftvries-
# 	PAGE_REFS: [31]
# 8 49 9 continue_stop 	        —— landt.   31.
# 	PAGE_REFS: [96]
# 9 3 -21 start_stop 	      —— —— creditif en aangenaam.  96.
# 10 3 -25 start 	      —— —— Memorie tegens  de afgefette  admini-
# 	PAGE_REFS: [126]
# 11 3 -31 start_stop 	        —— fratoiren, te examineeren.   126.
# 12 49 4 continue 	   —— rapport  en  refolutie  dien aangaande.
# 	PAGE_REFS: [137]
# 13 3 -36 start_stop 	         —— 137.
# 	PAGE_REFS: [199]
# 14 98 59 continue_stop 	      Becker 07% afiftentie, afgeweftn.   199,
# 	PAGE_REFS: [123]
# 15 98 48 continue_stop 	       Bededagh geproponeert.   123.
# 	PAGE_REFS: [134]
# 16 99 49 continue_stop 	      ——gearrefteert.   134.
# 17 3 -42 start 	 ‚    Beelt{nyder devoir te doen in faveur van Hal-
# 	PAGE_REFS: [74]
# 18 3 -52 start_stop 	        —— maal en Roeters.   74.
# 19 97 53 continue 	      Bel om beralinge van vermift Servetgoedt op’t
# 20 3 -41 start 	        —— defroyement  van  den Marquis de Fenelon,
# 	PAGE_REFS: [862]
# 21 3 -30 start_stop 	        —— te examineeren.   862.
# 22 94 61 continue 	      —— rapport, de Raadt van Stats te ad-
# 	PAGE_REFS: [929]
# 23 3 -40 start_stop 	        —— vieren.  929.
# 24 95 62 continue 	      de Bel, Pa/port tot den uytvoer van Monte-
# 25 3 -39 start 	        —— vinge voor  het Regiment  van Keppel  naar
# 	PAGE_REFS: [120]
# 26 3 -39 start_stop 	        —— Namen.   120.
# 27 90 49 continue 	     —— tiem voor het Regiment van d’ Aba-
# 	PAGE_REFS: [136]
# 28 3 -38 start_stop 	        —— die naar Stevenswaart.   136.
# 29 88 57 continue 	     Belvis  de  Seville  hondert guldens  toegeleght.
# 	PAGE_REFS: [426, 964]
# 30 3 -28 start_stop 	        —— 426. 964.
# 31 86 46 continue 	     van Bentheim-Steinfurt, Grave , notificeren-
# 32 3 -27 start 	       —— de de geboorte  van een Doghtertje  met re-
# 33 3 -27 start 	       —— Scripte van  congratulatie‚ in  civile termen
# 	PAGE_REFS: [326]
# 34 3 -26 start_stop 	       —— beantwoordt.   326.
# 35 83 46 continue 	     Benthem ,  Pa/port , ’s Landts Advocaten te
# 36 3 -25 start 	       —— advifeeren  op  lijn  dijpat  met  de  Prez.
# 	PAGE_REFS: [400]
# 37 3 -25 start_stop 	       —— 400.
# 38 79 51 continue 	     — advis.   $13.
# 39 77 41 continue 	     vanden Berch , Pa/port om naar Vranckrijsk
# 40 3 -24 start 	       —— uyt te voeren voor drie hondert duyfent gal-
# 41 3 -24 start 	       —— dens  Americaan[che  fiucken  van  Achten.
# 	PAGE_REFS: [261]
# 42 3 -24 start_stop 	       —— 261.
# 43 73 47 continue 	     de Bere, Magiftraat van Bergen op Zoom gelaft
# 44 3 -15 start 	       —— lijn intere(Jen tol de ver[chijndagh ten wollen te
# 45 3 -15 start 	       —— betalen, en na den ver[chijndagh de reduttie
# 	PAGE_REFS: [275]
# 46 3 -15 start_stop 	      —— Subjell.   275.
# 47 68 39 continue 	    Bergen op den Zoom ,  Regenten van Hal-
# 48 3 -24 start 	      —— Seren en Noordgeeft gelaft op de  aan[chrij-
# 49 3 -24 start 	      —— vinge van den Droffard Reygersman, gecom-
# 50 3 -33 start 	       —— mitteerde  op  de  Ouartiers  vwergaderimge te
# 	PAGE_REFS: [25]
# 51 103 67 continue_stop 	      fenden.  25.
# 52 62 33 continue 	    —— Dro(ará te berichten op de Requefte
# 53 3 -31 start 	      —— van Regenten van Halfteren dien aangaande.
# 54 78 38 continue 	     —— van  Braams  om  permijie  om  tot
# 55 3 -47 start 	      —— Bergen te  woonen ,  (Dc.  te  examinceren.
# 	PAGE_REFS: [54]
# 56 3 -41 start_stop 	      —— 54.
# 	PAGE_REFS: [63]
# 57 54 13 continue_stop 	    —— Reglement /alaris Secretarien.  63.
# 58 55 7 continue 	    — verfoeck van den Prince ,  ten  eynde
# 59 95 53 continue 	      den Dro(ard  de Groot magh werden gelaft
# 8.1 61
# 0 135 13 continue 	        cen voorhlagh van Perfoonen te doen, die hy
# 1 136 20 continue 	        oordeelt de bequaamfle te wefen, den Dro[-
# 2 125 7 continue 	       Jard de Groot te berichten.   152.      —
# 3 85 -35 start 	     — Magiftraat gelaft 'Groveftins fijn ach-
# 4 133 17 continue 	       terftallen te voldoen.    T76.          si
# 5 86 -29 start 	     ——  different  tufiben  den  Marquis en
# 6 131 17 continue 	       den Drofard aan  de ordinaris Juflitie ge-
# 	PAGE_REFS: [181, 255]
# 7 130 15 continue_stop 	       renvoyeert.   181. 255.
# 8 84 -30 start 	     ——— Regenten van Stant daar Buyten we-
# 9 127 14 continue 	       gens  het  vinden  van  crimineele  onkofen,
# 10 129 11 continue 	       de  Raadt  van  Staate ,  ‘te  advifteren.
# 	PAGE_REFS: [202]
# 11 130 13 continue_stop 	       202.
# 12 83 -28 start 	     — Regenten  van  Halteren  en Noordt-
# 13 124 8 continue 	       geeft gelaft te dupliceeren binnen drie weec-
# 14 129 13 continue 	       ken op de  Requefte van den Drofard Rij-
# 	PAGE_REFS: [216]
# 15 123 12 continue_stop 	       gersman.  216.
# 16 78 -32 start 	     ——— Bere, Magift. gelaft fijn intere(Jen tot den
# 17 127 18 continue 	       verfchijndagh ten vollen te betalen, en na de
# 	PAGE_REFS: [275]
# 18 126 17 continue_stop 	       verfchijndagh de reduêtie fubjett.   275.
# 19 80 -23 start 	     ———  Regenten van Put om  remie, de
# 	PAGE_REFS: [281]
# 20 125 22 continue_stop 	       Raadt van Staate te advifeeren.   281.
# 21 76 -32 start 	     —— bericht op de klaghten van Groveftins
# 	PAGE_REFS: [291]
# 22 125 23 continue_stop 	       om achterftallen , te examineeren.   291.
# 23 73 -28 start 	    — Regenten van bet Overguartier , be-
# 24 122 16 continue 	       langh op de Requefte van Groveftins, te exa=
# 	PAGE_REFS: [308]
# 25 120 21 continue_stop 	       mineeren.   308.
# 26 74 -29 start 	     — item Regenten van het Ooftquartier
# 27 122 20 continue 	       belangh op de Requefte van Groveflins, te
# 	PAGE_REFS: [312]
# 28 117 10 continue_stop 	       examineeren.   312.
# 29 69 -32 start 	    —— Regenten  van  Halfteren en Noordt=
# 30 111 11 continue 	      geeft duplicy  op de Requefte van  Reygers-
# 31 115 7 continue 	       man  te flellen  in  handen  van  Partyen.
# 	PAGE_REFS: [331]
# 32 118 16 continue_stop 	       331.
# 33 67 -34 start 	    ——— Regenten  van  Nieuwgaftel ,  bericht
# 34 113 8 continue 	      op  de  Requefte  van Kip,  te examineeren.
# 	PAGE_REFS: [49]
# 35 140 35 continue_stop 	        49.
# 36 69 -30 start 	     —— bericht van den Raadt van Brabant
# 37 111 15 continue 	      op  het  verfoeck  van  Regenten  van Stant
# 38 109 9 continue 	      daar Buyten ,  wegens  apprebendeeren  van
# 	PAGE_REFS: [375]
# 39 109 15 continue_stop 	      Moordenaars en refolutie.   375.
# 40 61 -28 start 	    ——  Jorvoeren om  betalinge van  intere[-
# HAS LEMMA: Je de Raadt van Staate te advifeeren.
# LEMMA: Je de Raadt van Staate te advifeeren
# 41 85 -2 start 	     Je    de  Raadt  van Staate  te advifeeren.
# 	PAGE_REFS: [370]
# 42 109 23 continue_stop 	      370.
# 43 57 -24 start 	    ——— rapport  op het  verfoeck van Grover
# 	PAGE_REFS: [3883]
# 44 95 15 continue_stop 	      fins en refolutie.   3883.
# 45 55 -24 start 	    — verfoght de aghterftallen aan de Wed.
# 	PAGE_REFS: [392]
# 46 102 21 continue_stop 	      Wa(enaar te voldoen.   392.
# 47 59 -15 start 	    —— Regenten van Put, remijie verleent.
# 	PAGE_REFS: [459]
# 48 100 22 continue_stop 	      459.
# 49 57 -21 start 	    —— ordre aan den Drofard wegens Hey-
# 	PAGE_REFS: [496]
# 50 97 14 continue_stop 	      dens en Landtloopers.  496.
# 51 49 -28 start 	   —— Drofard Kip te berichten op de klag-
# 52 96 16 continue 	      ten van Regenten  van Nieuwgaftel wegens”
# 53 95 22 continue 	      aanftellinge van een Paap[che Colleêteur al-
# 54 93 16 continue 	     daar.   $37.
# 55 47 -29 start 	   ——___ van Braams gepermilteert binnen Bet-
# 	PAGE_REFS: [681]
# 56 89 13 continue_stop 	     gen te blijven woonen.  681.
# 57 42 -31 start 	   ——— Drofard aangefchreven ordre tot op-
# 58 91 21 continue 	     vangen of verjagen van Heydens en Landt-
# 	PAGE_REFS: [692]
# 59 87 20 continue_stop 	     loopers te tellen.  692.
# 60 47 -24 start 	   —— Regenten  van  het  Oofiquartier  om
# 8.2 61
# 17 Gap between line start and first word: 0 74 ns nader Requefte, afgeweftn. 157.
# 0 35 9 continue 	   te negotieren, de Raadt van Staate te ad-
# 	PAGE_REFS: [733]
# 1 33 11 continue_stop 	   vifteren.  733.
# 2 0 -18 start 	 —— Vervoeren wegens refolutie aan die van
# 3 33 13 continue 	   Butz verleent ‚ de Raadt van Staate te ad-
# 	PAGE_REFS: [757]
# 4 31 8 continue_stop 	   vifeeren.  757.
# 	PAGE_REFS: [806]
# 5 0 -19 start_stop 	 — advis en afgeweefèn.   806,
# 6 0 -21 start 	 —— Regenten van Rucphen om te  mogen
# 7 28 7 continue 	  UDNe  de Raadt van Staate te adviferen.
# 	PAGE_REFS: [47]
# 8 51 31 continue_stop 	    47.
# 9 1 -16 start 	 anden  Bergh  achtien  guldens  toegeleght.
# 	PAGE_REFS: [8]
# 10 52 33 continue_stop 	    8.
# 11 0 -19 start 	 —— aanzefteldt tot Bode  ter General:-
# 12 22 5 continue 	  teyt. _121.
# 13 0 -20 start 	 — fes  en  dertigh guldens  toegeleght tot
# 	PAGE_REFS: [150]
# 14 21 1 continue_stop 	  bet maken van cen Reysbu{je.   150.
# 15 0 -16 start 	 crloo, Reque/te antidotaal ter Griffie te [e-
# 	PAGE_REFS: [18, 124]
# 16 14 -3 start_stop 	  poneeren.   18.  124.
# 	PAGE_REFS: [157]
# 17 74 57 continue_stop 	     ns  nader Requefte, afgeweftn.   157.
# 18 0 -17 start 	 —— Ghyfen en Panhuys gecommitteert om:
# 19 18 2 continue 	  als  haar  Hoogh  Mog.  CommijJarijen  de
# HAS LEMMA: Jaak tuichen Berlo en Thielen te decideeren.
# LEMMA: Jaak tuichen Berlo en Thielen te decideeren
# 20 8 -8 start 	 Jaak tuichen Berlo en Thielen te decideeren.
# 	PAGE_REFS: [165]
# 21 24 8 continue_stop 	  165.
# 22 0 -8 start 	 ee  ‚ Wedewe, Ordonnantie van hondert
# 	PAGE_REFS: [30]
# 23 12 4 continue_stop 	  guldens gedepeftheert.   30.
# 24 0 -8 start 	 ertlingh, creditif wegens Ooft-Vrieslandt en
# 	PAGE_REFS: [109]
# 25 16 8 continue_stop 	  aangenaam.   109.
# 	PAGE_REFS: [264]
# 26 0 -6 start_stop 	 mn Brieven van voor[chryvens.   264.
# 27 0 -6 start 	 ertolf 07: baar Mofelen mede in bet Canaal
# 28 12 6 continue 	  van Zas van Gent te mogen  verver[chen,
# 	PAGE_REFS: [199]
# 29 14 8 continue_stop 	  de Magiftraat te  berichten.   199.
# 	PAGE_REFS: [310]
# 30 0 -6 start_stop 	 —— bericht en geaccordeert.   310.
# 31 0 -7 start 	 —_—— gelaft baar fiptelijck aan  haar per-
# 32 14 7 continue 	  mijie te houden.  414.              :
# 33 0 -6 start 	 nn klaghte over de Nete{Jones ,  gedepu-
# 34 14 8 continue 	  teert  maar  Vlaanderen ,  te  difponeeren.
# 35 16 9 continue 	  447. :
# 	PAGE_REFS: [8]
# 36 0 -9 start_stop 	 efcheyt, declaratie.   8.
# 37 0 -7 start 	 efendinge na Zeelandt, Mi{jive van Gecom-
# 38 13 6 continue 	  mitteerde Rade van Zeelandt, met ver[oeck
# 39 13 7 continue 	  de [elve voor eenige dagen uyt te flellen, en
# 	PAGE_REFS: [212]
# 40 12 7 continue_stop 	  antwoordt.   212.
# 	PAGE_REFS: [511]
# 41 0 -6 start_stop 	 etmans 02 Pa/port, afgeweefen,   511.
# 	PAGE_REFS: [406]
# 42 0 -6 start_stop 	 evers, Oétroy om te dijponeeren.  406.
# 43 0 -6 start 	 eugholt 07: {do veel te genieten en te decla-
# 44 11 7 continue 	  veeren als tot nogh toe gehad heeft, de Ad-
# 	PAGE_REFS: [814]
# 45 11 7 continue_stop 	  miraliteyten te adviferen.   814.
# 46 0 -4 start 	 mn advis van de Admiraliteyt in Pries-
# 	PAGE_REFS: [815]
# 47 9 4 continue_stop 	 landt.   815.
# 48 0 -6 start 	 ne gepermitteert  nogh twee  maanden op
# 	PAGE_REFS: [977]
# 49 9 4 continue_stop 	 den ouden voet te continueren.  977.
# 50 0 -4 start 	 urfTen aangaande, vander Horft om appro-
# 51 7 3 continue 	 batie van feekere collatie ‚  den Rentmeefter
# 	PAGE_REFS: [97]
# 52 9 5 continue_stop 	 ’sGrave[ande te advifeeren.   97.
# 53 0 -5 start 	 ___— advis dien aangaande ,  de Generali-
# 	PAGE_REFS: [94]
# 54 6 -3 start_stop 	 teyts Reekenkamer te berichten.  94.
# 55 0 -10 start 	 _—— Boeteman  om approbatie  van fceke-
# 56 6 -5 start 	 ve collatie ‚  den  Rentmeefter te  advifeeren.
# 	PAGE_REFS: [103]
# 57 9 -2 start_stop 	 103.
# 58 45 33 continue 	   D bericht van  de  Reekenkamer  op bet
# 59 11 -3 start 	  ver[oeck van vander Horft, en geapprobeert,
# 60 13 -3 start 	  194.                                      9
# 8.3 61
# 4 Gap between line start and first word: 0 104 van fekere collatie, den Rentmeefter Teng=
# 5 Gap between line start and first word: 0 106 nagel te advijeeren, 713.
# 0 57 -29 start 	    meen Bronckhorft  om  approbatie  van fez _
# 1 103 13 continue 	      kere collatie , de Generaliteyts Reekenkämer
# 	PAGE_REFS: [196]
# 2 104 19 continue_stop 	      te advifeeren.   196.
# 3 66 -22 start 	    —— Pelgrom  Engelbreght om  approbatië
# 4 104 14 continue 	      van fekere collatie, den Rentmeefter Teng=
# 	PAGE_REFS: [713]
# 5 106 16 continue_stop 	      nagel te advijeeren,   713.
# 6 59 -30 start 	    ——  Draack  om  approbatie  van  feekeré
# 7 106 15 continue 	      collatie, den Rentmeefter de Tombes te ad.
# 	PAGE_REFS: [866]
# 8 105 15 continue_stop 	      vifeeren.  866.
# HAS LEMMA: Beyeren , rakende betalinge van vier aghters
# LEMMA: Beyeren
# 9 60 -25 start 	    Beyeren ,  rakende betalinge van vier aghters
# 10 99 19 continue 	      ftallige jaaren  intere(Jen ,  1e  examineren.
# 11 114 28 continue 	       If4.
# 	PAGE_REFS: [269]
# 12 62 -25 start_stop 	    ——  rapport en antwoordt.   269.
# 	PAGE_REFS: [369]
# HAS LEMMA: Beyer, Pa/port ad omnes Populos. 369.
# LEMMA: Beyer
# 13 61 -27 start_stop 	    Beyer, Pa/port ad omnes Populos.   369.
# 	PAGE_REFS: [1, 19, 31, 49, 46]
# HAS LEMMA: Bilderbeeck , advertentie. 1. 19: 31. 49. 46.
# LEMMA: Bilderbeeck
# 14 61 -33 start_stop 	    Bilderbeeck, advertentie.  1. 19:  31. 49. 46.
# 	PAGE_REFS: [77, 84, 100, 110, 134, 153, 170, 185]
# 15 112 16 continue_stop 	       77. 84:  100.  110.  134.  153.  170.  185.
# 	PAGE_REFS: [203, 214, 232, 235, 318, 339]
# 16 116 20 continue_stop 	       203. 214. 232. 235.  261  z09. 318. 339.
# 	PAGE_REFS: [350, 356, 369, 376, 382, 385, 396, 430]
# 17 115 13 continue_stop 	       350,  356. 369. 376. 382. 385. 396. 430.
# 	PAGE_REFS: [435, 466, 473, 487, 519]
# 18 111 3 continue_stop 	       435: 495 466. 473. 487. 499.507. 519:
# 	PAGE_REFS: [531, 535, 631, 642, 655, 659]
# 19 115 6 continue_stop 	       531. 535. Got. GIS. 631. 642. 655. 659:
# 	PAGE_REFS: [669, 678, 744, 755, 763, 774]
# 20 113 9 continue_stop 	       669. 678. 702.725. 744. 755. 763. 774:
# 	PAGE_REFS: [788, 843, 858, 875, 897, 907]
# 21 114 10 continue_stop 	       788. Sit. £38. 843.  858. 875. 897. 907.
# 	PAGE_REFS: [909, 939, 945, 958, 977]
# 22 116 16 continue_stop 	       909. 939. 945. 958. 977.
# 	PAGE_REFS: [13, 281, 606]
# 23 70 -31 start_stop 	     —— declaratie.   13. 281. 606.
# 24 69 -32 start 	    —— gelaft figh te in[ormeeren wegens fees
# 	PAGE_REFS: [60]
# 25 119 22 continue_stop 	       keren nieuwe Landtol.   60.
# 26 80 -18 start 	     —— om  ordre  hoe fiqh  te gedragen  we:
# 27 114 15 continue 	       gens reyskoften been en weder, te examines
# 	PAGE_REFS: [98]
# 28 121 22 continue_stop 	       ven.  98.
# 29 73 -32 start 	     ——_—— gepermitteert  voor  eenige dagen naay
# 30 123 18 continue 	       Neufted en [oo nodi:h is na Keulen te gaan.
# 	PAGE_REFS: [209]
# 31 122 12 continue_stop 	       209.
# 32 77 -29 start 	     —— bericht  van het gepaffverde in confes
# 33 122 15 continue 	       rentie over de differenten tu(fchen de Chhr-
# 34 117 9 continue 	       furften  van  Mentz  cn  van  de  Paltz.
# 	PAGE_REFS: [422]
# 35 127 18 continue_stop 	       422.
# 36 79 -20 start 	     _—— Wegers ;  refolatie  wegens het werck
# 	PAGE_REFS: [591]
# 37 128 27 continue_stop 	       van Polen genomen en welgevallen.   591.
# 38 83 -8 start 	     ——  gepermitteert  aam  arme  Pa(agiers
# 39 130 42 continue 	       bonderdt  ‘vyftigh  guldens  uyt  te  keeren.
# 	PAGE_REFS: [633]
# 40 31 -46 start_stop 	        —— 633.
# 41 96 24 continue 	      er    gepermitteert den vouw te declareeren
# 	PAGE_REFS: [859]
# 42 31 -30 start_stop 	        —— over den Hertogh van Aofta.   859.
# 43 87 32 continue 	     ——  hondert  vyftigh  guldens  toegeleght.
# 	PAGE_REFS: [60]
# 44 31 -20 start_stop 	 —— 60.
# 45 31 -20 start 	   e  ———  Brieven  toegefonden  om  aan  den
# 46 31 -19 start 	        —— Churfurft  van  de  Paltz  over te geeven.
# 	PAGE_REFS: [945]
# 47 31 -26 start_stop 	        —— 945:
# 48 91 40 continue 	      —— gepermitteert den rouw te declareren:
# 	PAGE_REFS: [964]
# 49 31 -27 start_stop 	        —— 964.
# 	PAGE_REFS: [892, 907, 939]
# 50 93 35 continue_stop 	      Binkhorft, advertentie.   892. 907. 939.
# 51 95 37 continue 	      —— gelaft figh gereet te houden om in Zee
# 	PAGE_REFS: [77]
# 52 31 -35 start_stop 	        —— te gaan.   77.
# 53 96 37 continue 	      Berckenfeldt ‚ Paltsgraviane om achter fallen,
# 54 31 -37 start 	        —— Provincie van Stadt en Lande verfoght de-
# 	PAGE_REFS: [167, 348]
# 55 31 -30 start_stop 	        —— felve te voldoen.   167. 348.
# 56 98 36 continue 	      ——— nader Requeft, de retroafla mate fien.
# 	PAGE_REFS: [40]
# 57 31 -35 start_stop 	 —— 40.
# 58 110 48 continue 	       ei   eendaal aangeftelt tot Schepen vans Her-
# 	PAGE_REFS: [732]
# 59 31 -36 start_stop 	        —— togenbofth.   732.
# 60 103 29 continue 	      Bleskensgrave, Erfgenaam, notificeerende fijn
# 9.0 60
# 7 Gap between line start and first word: 39 123 ge, de Magiftraat van Venlo , te advifee-
# ...
# 41 119 -2 start 	       mw  omme  ‘voorfieninge 3 1e examineeren.
# 	PAGE_REFS: [182]
# 42 140 19 continue_stop 	        182.
# 43 109 -13 start 	      —_      om alâaar op fijn poft te mogen bly-
# 	PAGE_REFS: [314]
# 44 140 18 continue_stop 	        ven, te examineeren.   314.
# 	PAGE_REFS: [395, 613]
# 45 90 -28 start_stop 	     —— advertentie.   395. 613.
# HAS LEMMA: Venetien, Republicg , om haar Hoogh Mo.
# LEMMA: Venetien
# 46 90 -30 start 	     Venetien, Republicg ,  om haar Hoogh Mo.
# 47 141 26 continue 	        interce(jie tegens de foogenaamde Bijjchop van
# 	PAGE_REFS: [303]
# 48 141 28 continue_stop 	        Utrecht en antwoordt.   303.
# HAS LEMMA: Verbrugge aaugefteldt tot Raadtsheer in den
# 49 94 -19 start 	      Verbrugge aaugefteldt tot Raadtsheer  in den
# 	PAGE_REFS: [656]
# 50 141 27 continue_stop 	        Raadt van Brabandt.  656.
# 	PAGE_REFS: [349]
# 51 92 -29 start_stop 	      Verhaatt tien ducatons toegeleght.  349.
# HAS LEMMA: Verhage, Patkneght , vijftigh guldens toege-
# LEMMA: Verhage
# 52 93 -28 start 	     Verhage, Patkneght , vijftigh guldens toege-
# 	PAGE_REFS: [748]
# 53 143 24 continue_stop 	        leght.  748.
# HAS LEMMA: Verhoef Pasport om de Monteeringe voor het
# 54 98 -24 start 	      Verhoef Pasport om de Monteeringe voor het
# 55 146 27 continue 	        Regiment van Reghteren na Yperen  uyt te
# 	PAGE_REFS: [295]
# 56 146 21 continue_stop 	        voeren.  295.
# 42.0 61
# 0 Gap between line start and first word: 47 118 cen Nieuïmuyden wegens het getal der Rooms
# 22 Gap between line start and first word: 30 123  Kerckmeefters van Sas van Gent te exami-
# 55 Gap between line start and first word: 74 106 op de klaghten van de Claffis: van Walche-
# 0 118 7 continue 	      cen Nieuïmuyden wegens het getal der Rooms
# 1 91 -23 start 	     Catbolijcke ,  cn de Armen  by haar onder-
# 2 131 22 continue 	      bouden werdende, Gedeputeerden na Vlaan-
# 3 131 24 continue 	      deren te informeeren. * 1T.
# 4 87 -25 start 	    — Regenten  van  Hulft  en Halfteram-
# 	PAGE_REFS: [28]
# 5 127 19 continue_stop 	      baght approbatie op feeker Contraft. 28.
# 6 83 -29 start 	    ———  Kerckenraadt  van  Ooftburgh gelaft
# 7 93 -19 start 	      feecker  arme  Doghter  te  alimenteeren.
# 	PAGE_REFS: [120]
# 8 150 44 continue_stop 	       120.
# 9 82 -29 start 	    —— Jngelanden  van  oudt en jonch Bres-
# 10 128 17 continue 	      kens om prolongatie van [ceker Oëlroy ,  de
# 	PAGE_REFS: [143]
# 11 130 14 continue_stop 	      Raadt van Staate ‘te advifeeren.  143.
# 12 81 -35 start 	    —— Room[chgefinde Ingezeetenen van Sluys
# 13 127 12 continue 	      in Vlaanderen wegens onderhouden van baar
# 14 127 12 continue 	      eygen Armen , Gedeputeerden haar te infor-
# 	PAGE_REFS: [149]
# 15 127 12 continue_stop 	      mmeeren en rapport te doen.   149.
# 16 100 -9 start 	     —— Brieven  ‘reguifitoir woor de  Groote.
# 	PAGE_REFS: [158]
# 17 137 24 continue_stop 	       158.
# 18 80 -33 start 	    ——  Brieven  requifitoir  voor  de  Baake.
# 	PAGE_REFS: [159]
# 19 132 19 continue_stop 	       159.
# 20 75 -32 start 	    —__— Gedeputeerden gelaft de [aak van Nag-
# 21 120 11 continue 	      tegaal, Weduwe van de Mandere ,  contra
# 22 123 15 continue 	       Kerckmeefters van Sas van Gent te exami-
# 	PAGE_REFS: [168]
# 23 123 16 continue_stop 	      neeren en decideeren.”   168.
# 24 76 -29 start 	    —— Regenten  van de  Vrye te Sluys om
# 25 123 13 continue 	      vry acces en reces tot en van de Stadt op
# 	PAGE_REFS: [179]
# 26 124 14 continue_stop 	      Sondagen, Ê5e. te examineren.   179.
# 27 72 -32 start 	   —_——— Taghtgeright tot Sluys te berighten op
# 28 117 12 continue 	      het verfoeck  van  die van den Raadt van
# 29 120 16 continue 	      Vlaanderen om te zijn en blijven gequalifi-
# 	PAGE_REFS: [200]
# 30 120 17 continue_stop 	      ceert tot de Jaght.   200.
# 31 67 -29 start 	   —_—  Fingntie  der  Stadt  Half  ontlaft.
# 	PAGE_REFS: [268]
# 32 127 27 continue_stop 	      268.
# 33 69 -31 start 	   —— Helvetins aangefteldt tot Schepen van
# 	PAGE_REFS: [277]
# 34 113 15 continue_stop 	      den Jrye.  277.
# 35 66 -26 start 	   —— Regenten van Aardenburgh om excm-
# 36 108 12 continue 	     plie van  bet Placaat  op de belaftinge van
# 37 113 18 continue 	      Ofen en Koeyen , de Admiraliteyt in Zee-
# 	PAGE_REFS: [296]
# 38 100 6 continue_stop 	     .Jandt te advijeren.  296.
# 39 65 -28 start 	   —_       [ngelanden van oudt en jonsh  Bres-
# 40 105 6 continue 	     ‘kens 5 Odtroy, vijftien jaaren geprolongeert.
# 41 116 22 continue 	      97: \
# 42 63 -30 start 	   —— Regenten van den Prye notsficeerende
# 43 109 15 continue 	     bet overlijden  ‘van  den  Scheepen Beaufort.
# 	PAGE_REFS: [297]
# 44 114 20 continue_stop 	      297.
# 45 62 -32 start 	   —— Regenten van Sluys,  Waterreght en’
# 46 111 18 continue 	     Nieumuyden gepermitteert Copie van Jeeckere
# 	PAGE_REFS: [305]
# 47 109 17 continue_stop 	     Reque[te ter Griffie te lighten.   305.
# 48 57 -34 start 	   — Kerkenraadt van Biervliet gelaft van
# 49 108 18 continue 	     Vlaanderen in den Huwelijcken [taat te be-
# 	PAGE_REFS: [331]
# 50 106 17 continue_stop 	     veftigen.   331.
# 51 53 -36 start 	   ——  Regenten  van.  den  Vrye  te Sluys,
# 52 104 16 continue 	     klaghten over de Mey. d Haatage den: felven
# 	PAGE_REFS: [348]
# 53 105 12 continue_stop 	     te berichten.   348.
# 54 54 -33 start 	   —— Magiftraat van Biervliet teberichten
# 55 106 20 continue 	     op de klaghten van de Claffis: van Walche-
# 56 107 16 continue 	     ven wegens ver[chil in het beroepen van cen
# 	PAGE_REFS: [360]
# 57 99 10 continue_stop 	     Predikant aldaar.  360:
# 58 51 -36 start 	  — Báillinw van Yferdijcke bericht op de
# 59 99 6 continue 	     Mifive van de Heduwe Boot, Gedepateer-
# 	PAGE_REFS: [410]
# 60 96 6 continue_stop 	     den na Vlaanderen te dijponeeren.  410.
# 42.1 61
# 9 Gap between line start and first word: 0 28 oo Magiftraat van Sluys te berichten op
# 0 85 58 continue 	     —— de  Pau  aangeftelat  tot  Notaris.
# 	PAGE_REFS: [462]
# 1 0 -32 start_stop 	      —— 462.
# 2 54 27 continue 	    ——— TFaghtgericht tot Sluys, bericht op de
# 3 0 -24 start 	      —— Memorie aan die van den Raad van Vlaan-
# 	PAGE_REFS: [479]
# 4 0 -21 start_stop 	      —— deren, te examineeren.  479.
# 5 55 40 continue 	    ——  Regenten  van Hulflerambaght om te
# 6 0 -15 start 	      —— mogen omflaan ,  de  Raadt van Staale  te
# 	PAGE_REFS: [525]
# 7 0 -9 start_stop 	      —— advifeeren.   525.
# 	PAGE_REFS: [526]
# 8 0 -20 start_stop 	  ——nygn Afjelen executoriaal.   526.
# 9 28 1 continue 	  oo        Magiftraat van Sluys te berichten op
# 10 0 -27 start 	      —— de Mifive van Collegium, Oualificatum te
# 11 0 -27 start 	      —— Osftburgh , houdende redenen waarom wey-
# 12 98 71 continue 	      geren Jeekere Judith Prent  tot  haar lafte
# 13 70 37 continue 	     ‚te nemen.   $37.
# 14 55 25 continue 	    ——  Ingelanden van den Vryen Polder om
# 15 0 -38 start 	      —— by [teker Oftroy gemaintineert te werden ,
# 	PAGE_REFS: [599]
# 16 0 -38 start_stop 	      —— den Refident Peters te berichten.   599.
# 17 54 16 continue 	    — Regenten van  Hulfterambaght geper-
# 	PAGE_REFS: [622]
# 18 0 -31 start_stop 	      —— mitteert te mogen om[laan.  622.
# 19 71 42 continue 	    —— bericht ‘van Regenten van den Vrye
# 20 0 -40 start 	      —— vaakende  het  onderhoudt van [tekere arme
# 21 100 49 continue 	      Dogbter Judith Prent genaamt , Te exami-
# 	PAGE_REFS: [654]
# 22 0 -50 start_stop 	      —— neeren.  654.
# 23 42 -19 start 	   ——  Regenten  van  groot en kleyn Baar-
# 24 95 31 continue 	      /ande om executoriaal ‚ de Raad van Staate
# 	PAGE_REFS: [664]
# 25 98 22 continue_stop 	      te advifeeren.  664.
# 26 49 -27 start 	   — rapport wegens onderhoudenge van Ju-
# 27 98 12 continue 	      dith Prent ‚  de Raadt van Vlaanderen te
# 	PAGE_REFS: [668]
# 28 97 10 continue_stop 	      advifeeren.  668.
# 29 112 24 continue 	       —   Regenten van Biervliet om te mogen
# 30 95 5 continue 	      omflaan, de Raadt van Staate te advifee-
# 	PAGE_REFS: [688]
# 31 95 6 continue_stop 	      ven.  688.
# 32 49 -40 start 	   ———  Regenten  van groot en kleyn Baar-
# 33 105 17 continue 	      /ande  gepermitteert  te  moogen  omflaan.
# 	PAGE_REFS: [697]
# 34 110 24 continue_stop 	       697.
# 35 46 -35 start 	   — Ingelanden van de Clara Polder om
# 36 96 15 continue 	      continuatie  van  [ubfidie  van  drie  duy[ent
# 37 91 6 continue 	      guldens ’sjaars ,  ae  Raadt  van Staate te
# 	PAGE_REFS: [707]
# 38 94 11 continue_stop 	      advijeeren.  707.
# 39 47 -29 start 	   —— Regenten van Axel klaghten over den
# 40 92 11 continue 	      Kerkenraadt wegens beroepen vaneen Voor-
# 41 84 5 continue 	     /anger ;  den Kerkenraadt  van Axel te be-
# 	PAGE_REFS: [712]
# 42 93 19 continue_stop 	      richten.   712.
# 43 46 -27 start 	   — Magiftraat van den Vrye toegefonden
# 44 89 12 continue 	     da Refolutie van den twintighften September
# 	PAGE_REFS: [724]
# 45 81 9 continue_stop 	     Seventien hondert vyf en twintigh.  724.
# 46 43 -29 start 	   ———  Collegium  gualificarum  ot  Ooft-
# 47 90 18 continue 	     burgh te berighten wegens onderhoudingevan
# 	PAGE_REFS: [726]
# 48 80 9 continue_stop 	     Scekere Judith Prent.  726.
# 49 42 -29 start 	   — Ingelanden van de Dyckagie, de Groe-
# 50 90 18 continue 	     de om remijie ‚  de  Raadt  van  Staate te
# 	PAGE_REFS: [757]
# 51 90 19 continue_stop 	     advijeeren.  757.
# 52 40 -30 start 	   —— Regenten van Hult notificeerende het
# 53 88 25 continue 	     overlyden  van  den  Scheepen  van  Lith.
# 	PAGE_REFS: [766]
# 54 86 18 continue_stop 	     766.
# 55 36 -30 start 	   ——     Schoorman  aangefteldt  tot Scheepen.
# 	PAGE_REFS: [766]
# 56 84 19 continue_stop 	     766.
# 57 16 -52 start 	  — ——   Kerckenraadt van Axel bericht op de
# 58 82 16 continue 	     Mijive  van  Regenten,  raakende het aan-
# 59 75 13 continue 	     flellen van een Voorzanger, 1e examineeren.
# 	PAGE_REFS: [788]
# 60 83 15 continue_stop 	     788.
# 42.3 61
# 32 Gap between line start and first word: 88 123 Jent guldens van de Admiralitejt , te exa
# DEVIATING LINE: 142 [90, 142, 173, 96, 142, 96, 142, 103, 27] in den Raadt van Staate. 319.
# avg_repeat_symbol_length: 144
# DEVIATING LINE: 142 [173, 96, 27, 96, 142, 103, 27, 98, 27] ter Generaliteyt. 321.
# avg_repeat_symbol_length: 144
# 0 132 11 continue 	        den; en te berichten by wat gelegentheyt òf
# 1 133 18 continue 	        toeval geraakt  zijn uyt de exercitie en het
# 	PAGE_REFS: [947]
# 2 127 10 continue_stop 	       genot van het [elve.  947.
# 3 84 -35 start 	     ——— rapport ende  refolutie ‚  raakende de
# 4 132 17 continue 	        Finantie der Stadt Hult.  -948.
# 5 85 -29 start 	     — Matiftraat  van  Sluys  òm ordre hoe
# 6 131 17 continue 	        met den Priefter te handelen , te examinet=
# 	PAGE_REFS: [975]
# 7 129 20 continue_stop 	       ren.  975.
# 8 82 -32 start 	     van Vlimmeren gepermitteert Copie van [èece
# 9 129 21 continue 	       ker  Ottroy  ter  Grifjie  te  moogen  lighten.
# 	PAGE_REFS: [976]
# 10 133 22 continue_stop 	        976.
# HAS LEMMA: Umbgroeve wegens Gelderlandt ter Generali»
# 11 83 -23 start 	     Umbgroeve wegens Gelderlandt ter Generali»
# 12 130 25 continue 	       teyt gecommittecrt.   431.       ì
# HAS LEMMA: Voorfchryvens , {iet Brieven van Voorlchry-
# LEMMA: Voorfchryvens
# 13 74 -37 start 	     Voorfchryvens , {iet Brieven van Voorlchry-
# 14 113 9 continue 	       vens.
# 15 84 -19 start 	     vander Vorft, cum {uis , Brieven van Voor
# 16 123 21 continue 	       Schryvens  aan  de   Abdijfe  van  Thorn.
# 	PAGE_REFS: [497]
# 17 131 29 continue_stop 	        497:
# HAS LEMMA: Vreede creditif op deu Marquis de Fe:
# 18 65 -45 start 	    Vreede  creditif op deu Marquis de Fe:
# 	PAGE_REFS: [164]
# 19 132 26 continue_stop 	        melon en aangenaam.   164.
# 20 72 -40 start 	     ‘Vrieslandt ,  Refolutie  op  de  propofitie  van
# 21 132 19 continue 	        Heeren  Gedeputeerden  aldaar geweeft zijn=
# 	PAGE_REFS: [111]
# 22 138 30 continue_stop 	        de.   111,
# 23 84 -32 start 	     ——  confent  in  den  Staat.  van  Oorlogh
# 24 134 22 continue 	        voor den jaart feventien hondert vyf en twin-
# 	PAGE_REFS: [204]
# 25 134 17 continue_stop 	        tigh.   204.
# 26 86 -32 start 	     ———— Refòlutie wegens de Aften:  van des
# 	PAGE_REFS: [205]
# 27 134 22 continue_stop 	        charge.   205.
# 28 94 -22 start 	      —— antwoordt op baar Hoogh Mog. Re:
# 29 125 9 continue 	       Solutie ‚ raakende de defeftueusheyt, te exa-
# 	PAGE_REFS: [228]
# 30 133 23 continue_stop 	        mineeren.   228.
# 31 85 -31 start 	     —_— propofitie wegens de vyf dertigh duy-
# 32 123 8 continue 	       Jent guldens van de Admiralitejt ,  te exa
# 	PAGE_REFS: [246, 415]
# 33 132 17 continue_stop 	        mineeren.   246. 415.
# 34 86 -30 start 	     ——_—  om patent  voor  de  Compagnie vak
# 35 136 19 continue 	        Haarfma ,  de Raadt van Staate te advi-
# 	PAGE_REFS: [263]
# 36 127 9 continue_stop 	       Jesren.   263.
# 37 90 -30 start 	     —__—— gertet op het projet Reglement op de
# 38 139 24 continue 	        Revijien van fententieh van den Ra4dt van
# 	PAGE_REFS: [265]
# 39 141 25 continue_stop 	        Staate.   265.
# 40 90 -21 start 	     —  Commifie  voor  den  Heer  Bincke
# 41 139 27 continue 	        Symons  tot  Admiraliteyt  in  Vrieslaudt.
# 42 91 -30 start 	      ‘280.                        5
# 	PAGE_REFS: [308]
# 43 92 -25 start_stop 	      ——— item voor de Heer Rengers.  308.
# 44 90 -14 start 	   —— ss  item. voor  den Heer van Aylua ter
# 45 142 37 continue 	        Admiraliteyt  in  het  Noorder.  Ouortier.
# 	PAGE_REFS: [10]
# 46 173 81 continue_stop 	          10.
# 47 96 2 continue 	      ——  item voor  den Heer van  Haarfolté.
# 	PAGE_REFS: [319]
# 48 27 -59 start_stop 	        —— in den Raadt van Staate.   319.
# 49 96 9 continue 	      ——  item  voor  den Heer  van Heeïmjtrá
# 	PAGE_REFS: [321]
# 50 27 -47 start_stop 	        —— ter Generaliteyt.   321.
# 51 103 36 continue 	      —— tem voor den Heer van Haaren ter
# 	PAGE_REFS: [329]
# 52 27 -32 start_stop 	        —— Admiraliteyt tot Ainfterdam.   329.
# 53 98 31 continue 	      —— item voor den Heer Ports ia Vlaan-
# 	PAGE_REFS: [334]
# 54 27 -32 start_stop 	        —— deren.   334.
# 55 104 37 continue 	      —— item voor den Heer de Kempenaar tef
# 	PAGE_REFS: [342]
# 56 27 -32 start_stop 	        —— Generaliteyt.   342.
# 57 98 35 continue 	      —— item voor de Heer Burmania iù den
# 	PAGE_REFS: [344]
# 58 27 -31 start_stop 	 —— Raadt van Staale.   344.
# 59 96 33 continue 	      —— tem voor de Heer Sminia in des Ge-
# 	PAGE_REFS: [386]
# 60 27 -28 start_stop 	  j      neraliteyts Reekenkamer.   386.
# 43.0 61
# 1 Gap between line start and first word: 104 160 Genergliteyts Reekenkamer. 386.
# 7 Gap between line start and first word: 12 152 de en inkoomende rechten van Schepen , den
# 18 Gap between line start and first word: 98 148 aldaar. 728.
# 30 Gap between line start and first word: 116 140 Hoorn, de retroafta na te fien. 299.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-c6a3614d82a0> in <module>()
#       7 for scan_id in index_entry_lines:
#       8     print(scan_id, len(index_entry_lines[scan_id]))
# ----> 9     index_lemmata(scan_id, index_entry_lines[scan_id], lemma_index, curr_lemma)
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in index_lemmata(scan_id, lines, lemma_index, curr_lemma)
#     402     if len(lines) == 0:
#     403         return True
# --> 404     fix_repeat_symbols(lines)
#     405     find_missing_repeat_symbols(lines)
#     406     for line_index, line in enumerate(lines):
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in fix_repeat_symbols(lines)
#     286 def fix_repeat_symbols(lines):
#     287     for line_index, line in enumerate(lines):
# --> 288         if has_repeat_symbol(line):
#     289             continue
#     290         first_word = line["filtered"]["words"][0]
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in has_repeat_symbol(line)
#     273
#     274 def has_repeat_symbol(line):
# --> 275     if re.match(r"^[\-_—]+$", line["filtered"]["words"][0]["word_text"]):
#     276         return True
#     277     else:
#
# IndexError: list index out of range

# %%
for lemma in lemma_index:
    print("Lemma:", lemma)
    print("\tPages:", ", ".join([str(page_ref) for page_ref in lemma_index[lemma]]))

# %% [markdown]
# <span>
# <img src="../../../Data/Projects/REPUBLIC/images/1725/NL-HaNA_1.01.02_3780_0007.jpg-0-245-75--0.00.png" alt="Drawing" style="width: 400px; display: inline;"/>
# <img src="../../../Data/Projects/REPUBLIC/images/1725/NL-HaNA_1.01.02_3780_0007.jpg-1-1226-75-0.60.png" alt="Drawing" style="width: 400px; display: inline;"/>
# </span>
