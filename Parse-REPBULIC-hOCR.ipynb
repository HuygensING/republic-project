# %% [markdown]
# ## Parsing REPBULIC hOCR Files
#
# The scans of the printed RSG volumes have the following characteristics
#
# - all scans:
#   - have two pages per scan
#   - have up to 4 columns per scan, 2 per page
#   - full scan is around 4800 pixels wide, left page is up to pixel 2400, right page is from pixel 2400 (roughly)
# - scans of index pages
#   - have no page numbers
# - scans of resolution pages
#   - have page numbers (left-side page is even, right-side page is odd)
#
# ### Columns
#
# The scans are normalized such that the columns are straight. The text width should be around 1000 pixels. Some columns are not cut out properly, resulting in columns that are either to small (some of the column text is missing), or too wide (the hOCR output contains partial texts from two columns)
#
# ### Index pages
#
# - start of entry:
#   - start left alignment
# - end of entry:
#   - end of line possibly before end of text column.
#   - One or more page numbers
#
#
# ### Resolution pages
#
# - header:
#   - next top of page (less than 350 pixels from the top)
#   - page has header with:
#     - even numbered pages: date page_number year
#     - odd numbered pages: year page_number date
#   - columns have half of page header, e.g.:
#     - even numbered pages:
#       - first column: date left aligned and part of page_number right aligned
#       - second column: part of page_number left aligned and year right aligned
#     - odd numbered pages:
#       - first column: year left aligned and part of page_number right aligned
#       - second column: part of page_number left aligned and date right aligned
#
# ### Viewer
#
# - page viewer: https://images.huygens.knaw.nl/assets/argos/index.html
# - list of page URLs: https://images.huygens.knaw.nl/api/argos
#
#
# ### National Archive site
#
# - search in the archive: https://www.nationaalarchief.nl/onderzoeken/index/nt00444?searchTerm=
# - search the index: https://www.nationaalarchief.nl/onderzoeken/zoekhulpen/voc-opvarenden
# - example page: https://www.nationaalarchief.nl/onderzoeken/index/nt00444/d110980c-c864-11e6-9d8b-00505693001d

# %%
# This reload library is just used for developing the REPUBLIC hOCR parser 
# and can be removed once this module is stable.
# %reload_ext autoreload
# %autoreload 2

# %%
import json
import os
import re
from collections import defaultdict
from parse_hocr_files import make_hocr_page
#from parse_republic_hocr_files import get_files, get_page_types, count_page_ref_lines, get_index_entry_lines, gather_page_columns
from elasticsearch import Elasticsearch
import parse_republic_hocr_files as rep_parser

# The hOCR file name contains relevant information for parsing. Here's an example:
# NL-HaNA_1.01.02_3780_0016.jpg-0-251-98--0.40.hocr

# NL-HaNA_1.01.02 is the name of the archive
# 3780_0016 identifies the specific page with a specific contract
# 0-251-98--0.40 identifies four aspects:
#   1. the number of the column (0)
#   2. the offset from the left (251)
#   3. the offset from the top (98)
#   4. and the slant (-0.40)

# %% [markdown]
# ### Reading column scans for a single volume
#
# 1. get scan file info
#     - scan number, page number, page side, column number, slant, page
# 2. iterate over pages
#     - create hocr_page
#     - determine page type: index, resolution, other

# %%
import copy

data_dir = "../../../Data/Projects/REPUBLIC/hocr/1725/"

scan_files = rep_parser.get_files(data_dir)
scan_files.sort(key = lambda x: x["scan_num_column_num"])
print("Number of scan files:", len(scan_files))
#print(json.dumps(scan_files[0:11], indent=2))

scan_columns = defaultdict(list)
for scan_file in scan_files:
    scan_columns[scan_file["scan_num"]]

config = {
    "tiny_word_width": 15, # pixel width
    "avg_char_width": 20,
    "remove_tiny_words": True,
    "remove_line_numbers": False,
}

pages_info = rep_parser.gather_page_columns(scan_files)
# Out:
# Number of scan files: 1887

# %% [markdown]
# ### Indexing Page Data in Elasticsearch

# %%
index = "republic_hocr_pages"
doc_type = "page"

es = Elasticsearch()
if es.indices.exists(index=index):
    print("exists, deleting")
    es.indices.delete(index=index)

def create_es_doc(page_info):
    doc = copy.deepcopy(page_info)
    for column_info in doc["columns"]:
        if "column_hocr" in column_info:
            column_info["column_hocr"] = json.dumps(column_info["column_hocr"])
    return doc

def parse_es_doc(doc):
    for column_info in doc["columns"]:
        if "column_hocr" in column_info:
            column_info["column_hocr"] = json.loads(column_info["column_hocr"])
    return doc

for page_id in pages_info:
    if pages_info[page_id]["scan_num"] >= 7000:
        continue
    print(page_id)
    page_info = copy.deepcopy(pages_info[page_id])
    for column_info in page_info["columns"]:
        try:
            column_info["column_hocr"] = rep_parser.get_column_hocr(column_info, config)
        except TypeError:
            print("Error parsing file", column_info["filepath"])
    doc = create_es_doc(page_info)
    es.index(index=index, doc_type=doc_type, id=page_id, body=doc)
        
    #pages_hocr[page_id] = rep_parser.get_page_columns_hocr(pages_info[page_id], config)
#print(json.dumps(pages_info["scan-6-even"], indent=2))
#print(json.dumps(pages_hocr["scan-6-even"], indent=2))
# Out:
# exists, deleting
# scan-4-even
# scan-4-odd
# scan-5-even
# scan-5-odd
# scan-6-even
# scan-6-odd
# scan-7-even
# scan-7-odd
# scan-8-even
# scan-8-odd
# scan-9-even
# scan-9-odd
# scan-10-even
# scan-10-odd
# scan-11-even
# scan-11-odd
# scan-12-even
# scan-12-odd
# scan-13-even
# scan-13-odd
# scan-14-even
# scan-14-odd
# scan-15-even
# scan-15-odd
# scan-16-even
# scan-16-odd
# scan-17-even
# scan-17-odd
# scan-18-even
# scan-18-odd
# scan-19-even
# scan-19-odd
# scan-20-even
# scan-20-odd
# scan-21-even
# scan-21-odd
# scan-22-even
# scan-22-odd
# scan-23-even
# scan-23-odd
# scan-24-even
# scan-24-odd
# scan-25-even
# scan-25-odd
# scan-26-even
# scan-26-odd
# scan-27-even
# scan-27-odd
# scan-28-even
# scan-28-odd
# scan-29-even
# scan-29-odd
# scan-30-even
# scan-30-odd
# scan-31-even
# scan-31-odd
# scan-32-even
# scan-32-odd
# scan-33-even
# scan-33-odd
# scan-34-even
# scan-34-odd
# scan-35-even
# scan-35-odd
# scan-36-even
# scan-36-odd
# scan-37-even
# scan-37-odd
# scan-38-even
# scan-38-odd
# scan-39-even
# scan-39-odd
# scan-40-even
# scan-40-odd
# scan-41-even
# scan-41-odd
# scan-42-even
# scan-42-odd
# scan-43-even
# scan-43-odd
# scan-44-even
# scan-44-odd
# scan-45-even
# scan-45-odd
# scan-46-even
# scan-46-odd
# scan-47-even
# scan-47-odd
# scan-48-even
# scan-48-odd
# scan-49-even
# scan-49-odd
# scan-50-even
# scan-50-odd
# scan-51-even
# scan-51-odd
# scan-52-odd
# scan-53-even
# scan-53-odd
# scan-54-even
# scan-54-odd
# scan-55-even
# scan-55-odd
# scan-56-even
# scan-56-odd
# scan-57-even
# scan-57-odd
# scan-58-even
# scan-58-odd
# scan-59-even
# scan-59-odd
# scan-60-even
# scan-60-odd
# scan-61-even
# scan-61-odd
# scan-62-even
# scan-62-odd
# scan-63-even
# scan-63-odd
# scan-64-even
# scan-64-odd
# scan-65-even
# scan-65-odd
# scan-66-even
# scan-66-odd
# scan-67-even
# scan-67-odd
# scan-68-even
# scan-68-odd
# scan-69-even
# scan-69-odd
# scan-70-even
# scan-70-odd
# scan-71-even
# scan-71-odd
# scan-72-even
# scan-72-odd
# scan-73-even
# scan-73-odd
# scan-74-even
# scan-74-odd
# scan-75-even
# scan-75-odd
# scan-76-even
# scan-76-odd
# scan-77-even
# scan-77-odd
# scan-78-even
# scan-78-odd
# scan-79-even
# scan-79-odd
# scan-80-even
# scan-80-odd
# scan-81-even
# scan-81-odd
# scan-82-even
# scan-82-odd
# scan-83-even
# scan-83-odd
# scan-84-even
# scan-84-odd
# scan-85-even
# scan-85-odd
# scan-86-even
# scan-86-odd
# scan-87-even
# scan-87-odd
# scan-88-even
# scan-88-odd
# scan-89-even
# scan-89-odd
# scan-90-even
# scan-90-odd
# scan-91-even
# scan-91-odd
# scan-92-even
# scan-92-odd
# scan-93-even
# scan-93-odd
# scan-94-even
# scan-94-odd
# scan-95-even
# scan-95-odd
# scan-96-even
# scan-96-odd
# scan-97-even
# scan-97-odd
# scan-98-even
# scan-98-odd
# scan-99-even
# scan-99-odd
# scan-100-even
# scan-100-odd
# scan-101-even
# scan-102-even
# scan-102-odd
# scan-103-odd
# scan-104-even
# scan-104-odd
# scan-105-even
# scan-105-odd
# scan-106-even
# scan-106-odd
# scan-107-even
# scan-107-odd
# scan-108-even
# scan-108-odd
# scan-109-even
# scan-109-odd
# scan-110-even
# scan-110-odd
# scan-111-even
# scan-111-odd
# scan-112-even
# scan-112-odd
# scan-113-even
# scan-113-odd
# scan-114-even
# scan-114-odd
# scan-115-even
# scan-115-odd
# scan-116-even
# scan-116-odd
# scan-117-even
# scan-117-odd
# scan-118-even
# scan-118-odd
# scan-119-even
# scan-119-odd
# scan-120-even
# scan-120-odd
# scan-121-even
# scan-121-odd
# scan-122-even
# scan-122-odd
# scan-123-even
# scan-123-odd
# scan-124-even
# scan-124-odd
# scan-125-even
# scan-125-odd
# scan-126-even
# scan-126-odd
# scan-127-even
# scan-127-odd
# scan-128-even
# scan-128-odd
# scan-129-even
# scan-129-odd
# scan-130-even
# scan-130-odd
# scan-131-even
# scan-131-odd
# scan-132-even
# scan-132-odd
# scan-133-even
# scan-133-odd
# scan-134-even
# scan-134-odd
# scan-135-even
# scan-135-odd
# scan-136-even
# scan-136-odd
# scan-137-even
# scan-137-odd
# scan-138-even
# scan-138-odd
# scan-139-even
# scan-139-odd
# scan-140-even
# scan-140-odd
# scan-141-even
# scan-141-odd
# scan-142-even
# scan-142-odd
# scan-143-even
# scan-143-odd
# scan-144-even
# scan-144-odd
# scan-145-odd
# scan-146-even
# scan-146-odd
# scan-147-even
# scan-147-odd
# scan-148-even
# scan-148-odd
# scan-149-even
# scan-149-odd
# scan-150-even
# scan-150-odd
# scan-151-even
# scan-151-odd
# scan-152-even
# scan-152-odd
# scan-153-even
# scan-153-odd
# scan-154-even
# scan-154-odd
# scan-155-even
# scan-155-odd
# scan-156-even
# scan-156-odd
# scan-157-odd
# scan-158-even
# scan-158-odd
# scan-159-even
# scan-159-odd
# scan-160-even
# scan-160-odd
# scan-161-even
# scan-161-odd
# scan-162-even
# scan-162-odd
# scan-163-even
# scan-163-odd
# scan-164-even
# scan-164-odd
# scan-165-even
# scan-165-odd
# scan-166-even
# scan-166-odd
# scan-167-even
# scan-167-odd
# scan-168-even
# scan-168-odd
# scan-169-even
# scan-169-odd
# scan-170-even
# scan-170-odd
# scan-171-even
# scan-171-odd
# scan-172-even
# scan-172-odd
# scan-173-even
# scan-173-odd
# scan-174-even
# scan-174-odd
# scan-175-even
# scan-175-odd
# scan-176-even
# scan-176-odd
# scan-177-even
# scan-177-odd
# scan-178-even
# scan-178-odd
# scan-179-even
# scan-179-odd
# scan-180-even
# scan-180-odd
# scan-181-even
# scan-181-odd
# scan-182-even
# scan-182-odd
# scan-183-even
# scan-183-odd
# scan-184-even
# scan-184-odd
# scan-185-even
# scan-185-odd
# scan-186-even
# scan-186-odd
# scan-187-even
# scan-187-odd
# scan-188-even
# scan-188-odd
# scan-189-even
# scan-189-odd
# scan-190-even
# scan-190-odd
# scan-191-even
# scan-191-odd
# scan-192-even
# scan-192-odd
# scan-193-even
# scan-193-odd
# scan-194-even
# scan-194-odd
# scan-195-even
# scan-195-odd
# scan-196-even
# scan-196-odd
# scan-197-even
# scan-197-odd
# scan-198-even
# scan-198-odd
# scan-199-even
# scan-199-odd
# scan-200-even
# scan-200-odd
# scan-201-even
# scan-201-odd
# scan-202-even
# scan-202-odd
# scan-203-even
# scan-203-odd
# scan-204-even
# scan-204-odd
# scan-205-even
# scan-205-odd
# scan-206-even
# scan-206-odd
# scan-207-even
# scan-207-odd
# scan-208-even
# scan-208-odd
# scan-209-even
# scan-209-odd
# scan-210-even
# scan-210-odd
# scan-211-even
# scan-211-odd
# scan-212-even
# scan-212-odd
# scan-213-even
# scan-213-odd
# scan-214-even
# scan-214-odd
# scan-215-even
# scan-215-odd
# scan-216-even
# scan-216-odd
# scan-217-even
# scan-217-odd
# scan-218-even
# scan-218-odd
# scan-219-even
# scan-219-odd
# scan-220-even
# scan-220-odd
# scan-221-even
# scan-221-odd
# scan-222-even
# scan-222-odd
# scan-223-even
# scan-223-odd
# scan-224-even
# scan-224-odd
# scan-225-even
# scan-225-odd
# scan-226-even
# scan-226-odd
# scan-227-even
# scan-227-odd
# scan-228-even
# scan-228-odd
# scan-229-even
# scan-229-odd
# scan-230-even
# scan-230-odd
# scan-231-even
# scan-231-odd
# scan-232-even
# scan-232-odd
# scan-233-even
# scan-233-odd
# scan-234-even
# scan-234-odd
# scan-235-odd
# scan-236-even
# scan-236-odd
# scan-237-even
# scan-237-odd
# scan-238-even
# scan-238-odd
# scan-239-even
# scan-239-odd
# scan-240-even
# scan-240-odd
# scan-241-even
# scan-241-odd
# scan-242-even
# scan-242-odd
# scan-243-even
# scan-244-even
# scan-244-odd
# scan-245-odd
# scan-246-even
# scan-246-odd
# scan-247-even
# scan-247-odd
# scan-248-even
# scan-248-odd
# scan-249-even
# scan-249-odd
# scan-250-even
# scan-250-odd
# scan-251-even
# scan-251-odd
# scan-252-even
# scan-252-odd
# scan-253-even
# scan-253-odd
# scan-254-even
# scan-254-odd
# scan-255-even
# scan-255-odd
# scan-256-even
# scan-256-odd
# scan-257-even
# scan-257-odd
# scan-258-even
# scan-258-odd
# scan-259-even
# scan-259-odd
# scan-260-even
# scan-260-odd
# scan-261-even
# scan-261-odd
# scan-262-even
# scan-262-odd
# scan-263-even
# scan-263-odd
# scan-264-even
# scan-264-odd
# scan-265-even
# scan-265-odd
# scan-266-even
# scan-266-odd
# scan-267-even
# scan-267-odd
# scan-268-even
# scan-268-odd
# scan-270-even
# scan-270-odd
# scan-271-even
# scan-271-odd
# scan-272-even
# scan-272-odd
# scan-273-even
# scan-273-odd
# scan-274-even
# scan-274-odd
# scan-275-even
# scan-275-odd
# scan-276-even
# scan-276-odd
# scan-277-even
# scan-277-odd
# scan-278-even
# scan-278-odd
# scan-279-even
# scan-279-odd
# scan-280-even
# scan-280-odd
# scan-281-even
# scan-281-odd
# scan-282-odd
# scan-283-odd
# scan-284-even
# scan-284-odd
# scan-285-even
# scan-285-odd
# scan-286-even
# scan-286-odd
# scan-287-even
# scan-287-odd
# scan-288-even
# scan-288-odd
# scan-289-even
# scan-289-odd
# scan-290-even
# scan-290-odd
# scan-291-odd
# scan-292-even
# scan-292-odd
# scan-293-even
# scan-293-odd
# scan-294-even
# scan-294-odd
# scan-295-even
# scan-295-odd
# scan-296-even
# scan-296-odd
# scan-297-even
# scan-297-odd
# scan-298-even
# scan-298-odd
# scan-299-even
# scan-299-odd
# scan-300-even
# scan-300-odd
# scan-301-even
# scan-301-odd
# scan-302-even
# scan-302-odd
# scan-303-even
# scan-303-odd
# scan-304-even
# scan-304-odd
# scan-305-odd
# scan-306-even
# scan-306-odd
# scan-307-even
# scan-307-odd
# scan-308-even
# scan-308-odd
# scan-309-even
# scan-309-odd
# scan-310-even
# scan-310-odd
# scan-311-even
# scan-312-even
# scan-312-odd
# scan-313-even
# scan-313-odd
# scan-314-even
# scan-314-odd
# scan-315-even
# scan-315-odd
# scan-316-even
# scan-316-odd
# scan-317-even
# scan-317-odd
# scan-318-even
# scan-318-odd
# scan-319-even
# scan-319-odd
# scan-320-even
# scan-320-odd
# scan-321-even
# scan-321-odd
# scan-322-even
# scan-322-odd
# scan-323-even
# scan-323-odd
# scan-324-even
# scan-324-odd
# scan-325-odd
# scan-326-even
# scan-326-odd
# scan-327-even
# scan-327-odd
# scan-328-even
# scan-328-odd
# scan-329-even
# scan-329-odd
# scan-330-even
# scan-330-odd
# scan-331-even
# scan-331-odd
# scan-332-even
# scan-332-odd
# scan-333-even
# scan-333-odd
# scan-334-even
# Error parsing file ../../../Data/Projects/REPUBLIC/hocr/1725/NL-HaNA_1.01.02_3780_0334.jpg-2-2253-75--0.00.hocr
# scan-334-odd
# scan-335-even
# scan-335-odd
# scan-336-even
# scan-336-odd
# scan-337-even
# scan-337-odd
# scan-338-even
# scan-338-odd
# scan-339-even
# scan-339-odd
# scan-340-even
# scan-340-odd
# scan-341-even
# scan-341-odd
# scan-342-even
# scan-342-odd
# scan-343-even
# scan-343-odd
# scan-344-even
# scan-344-odd
# scan-345-even
# scan-345-odd
# scan-346-even
# scan-346-odd
# scan-347-even
# scan-347-odd
# scan-348-even
# scan-348-odd
# scan-349-even
# scan-350-even
# scan-350-odd
# scan-351-even
# scan-351-odd
# scan-352-even
# scan-352-odd
# scan-353-even
# scan-353-odd
# scan-354-even
# scan-354-odd
# scan-355-even
# scan-355-odd
# scan-356-even
# scan-356-odd
# scan-357-even
# scan-357-odd
# scan-358-even
# scan-358-odd
# scan-359-even
# scan-359-odd
# scan-360-even
# scan-360-odd
# scan-361-even
# scan-361-odd
# scan-362-even
# scan-362-odd
# scan-363-even
# scan-363-odd
# scan-364-even
# scan-364-odd
# scan-365-even
# scan-365-odd
# scan-366-even
# scan-366-odd
# scan-367-even
# scan-367-odd
# scan-368-even
# scan-369-even
# scan-369-odd
# scan-370-even
# scan-370-odd
# scan-371-even
# scan-371-odd
# scan-372-even
# scan-372-odd
# scan-373-even
# scan-373-odd
# scan-374-even
# scan-374-odd
# scan-375-even
# scan-375-odd
# scan-376-even
# scan-376-odd
# scan-377-even
# scan-377-odd
# scan-378-even
# scan-378-odd
# scan-379-even
# scan-379-odd
# scan-380-even
# scan-380-odd
# scan-381-even
# scan-381-odd
# scan-382-even
# scan-382-odd
# scan-383-even
# scan-383-odd
# scan-384-even
# scan-384-odd
# scan-385-even
# scan-385-odd
# scan-386-even
# scan-386-odd
# scan-387-even
# scan-387-odd
# scan-388-even
# scan-388-odd
# scan-389-even
# scan-389-odd
# scan-390-even
# scan-390-odd
# scan-391-even
# scan-391-odd
# scan-392-even
# scan-392-odd
# scan-393-even
# scan-393-odd
# scan-394-even
# scan-394-odd
# scan-395-even
# scan-395-odd
# scan-396-even
# scan-396-odd
# scan-397-even
# scan-397-odd
# scan-398-even
# scan-398-odd
# scan-399-even
# scan-399-odd
# scan-400-even
# scan-400-odd
# scan-401-even
# scan-401-odd
# scan-402-even
# scan-402-odd
# scan-403-even
# scan-403-odd
# scan-404-even
# scan-404-odd
# scan-405-even
# scan-405-odd
# scan-406-even
# scan-406-odd
# scan-407-even
# scan-407-odd
# scan-408-even
# scan-408-odd
# scan-409-even
# scan-409-odd
# scan-410-even
# scan-410-odd
# scan-411-even
# scan-411-odd
# scan-412-even
# scan-412-odd
# scan-413-even
# scan-413-odd
# scan-414-even
# scan-414-odd
# scan-415-even
# scan-415-odd
# scan-416-even
# scan-416-odd
# scan-417-even
# scan-417-odd
# scan-418-even
# scan-418-odd
# scan-419-even
# scan-419-odd
# scan-420-even
# scan-420-odd
# scan-421-even
# scan-421-odd
# scan-422-even
# scan-422-odd
# scan-423-even
# scan-423-odd
# scan-424-even
# scan-424-odd
# scan-425-even
# scan-425-odd
# scan-426-even
# scan-426-odd
# scan-427-even
# scan-427-odd
# scan-428-even
# scan-428-odd
# scan-429-even
# scan-429-odd
# scan-430-even
# scan-430-odd
# scan-431-even
# scan-431-odd
# scan-432-even
# scan-432-odd
# scan-433-even
# scan-433-odd
# scan-434-even
# scan-434-odd
# scan-435-even
# scan-435-odd
# scan-436-even
# scan-436-odd
# scan-437-even
# scan-438-even
# scan-438-odd
# scan-439-even
# scan-439-odd
# scan-440-even
# scan-440-odd
# scan-441-even
# scan-441-odd
# scan-442-even
# scan-443-even
# scan-443-odd
# scan-444-even
# scan-445-even
# scan-446-even
# scan-447-even
# scan-448-even
# scan-448-odd
# scan-449-even
# scan-450-even
# scan-450-odd
# scan-451-even
# scan-451-odd
# scan-452-even
# scan-452-odd
# scan-453-even
# scan-453-odd
# scan-454-even
# scan-454-odd
# scan-455-even
# scan-455-odd
# scan-456-even
# scan-456-odd
# scan-457-even
# scan-458-even
# scan-458-odd
# scan-459-even
# scan-459-odd
# scan-460-even
# scan-460-odd
# scan-461-even
# scan-461-odd
# scan-462-even
# scan-462-odd
# scan-463-even
# scan-463-odd
# scan-464-even
# scan-464-odd
# scan-465-even
# scan-465-odd
# scan-466-even
# scan-466-odd
# scan-467-even
# scan-468-even
# scan-468-odd
# scan-469-even
# scan-469-odd
# scan-470-even
# scan-471-even
# scan-472-even
# scan-472-odd
# scan-473-even
# scan-473-odd
# scan-474-even
# scan-474-odd
# scan-475-even
# scan-475-odd
# scan-476-even
# scan-476-odd
# scan-477-even
# scan-477-odd
# scan-478-even
# scan-478-odd
# scan-479-even
# scan-479-odd
# scan-480-even
# scan-480-odd
# scan-481-even
# scan-482-even
# scan-482-odd
# scan-483-even
# scan-483-odd
# scan-484-even
# scan-485-even
# scan-485-odd
# scan-486-even
# scan-486-odd
# scan-487-even
# scan-488-even
# scan-488-odd
# scan-489-even
# scan-489-odd
# scan-490-even
# scan-490-odd
# scan-491-even
# scan-491-odd
# scan-492-even
# scan-492-odd
# scan-493-even
# scan-493-odd
# scan-494-even
# scan-494-odd
# scan-495-even
# scan-495-odd
# scan-496-even
# scan-496-odd
# scan-497-even
# scan-497-odd
# scan-498-even
# scan-498-odd
# scan-499-even
# scan-499-odd
# scan-500-even
# scan-500-odd
# scan-501-even
# scan-501-odd
# scan-502-even
# scan-502-odd
# scan-503-even
# scan-504-even
# scan-504-odd
# scan-505-even
# scan-505-odd
# scan-506-even
# scan-506-odd
# scan-507-even
# scan-507-odd
# scan-508-even
# scan-508-odd
# scan-509-even
# scan-509-odd
# scan-510-even
# scan-510-odd
# scan-511-even
# scan-511-odd
# scan-512-even
# scan-512-odd
# scan-513-even
# scan-513-odd
# scan-514-even
# scan-514-odd
# scan-515-even
# scan-515-odd
# scan-516-even
# scan-516-odd
# scan-517-odd
# scan-518-even
# scan-518-odd
# scan-519-even
# scan-519-odd
# scan-520-even
# scan-520-odd
# scan-521-even
# scan-521-odd
# scan-522-even
# scan-522-odd
# scan-523-even
# scan-523-odd
# scan-524-even
# scan-524-odd
# scan-525-even
# scan-525-odd
# scan-526-even
# scan-526-odd
# scan-527-even
# scan-527-odd
# scan-528-even
# scan-528-odd
# scan-529-even
# scan-529-odd
# scan-530-even
# scan-530-odd
# scan-531-even
# scan-531-odd
# scan-532-even
# scan-532-odd
# scan-533-even
# scan-533-odd
# scan-534-even
# scan-534-odd
# scan-535-even
# scan-535-odd
# scan-536-even
# scan-536-odd
# scan-537-even
# scan-537-odd
# scan-538-even
# scan-542-even

# %% [markdown]
# ### Determining Page Type
#
# We want to parse index pages differently from resolution pages and filter out non-text pages and pages where the columns are not properly identified.

# %%
def retrieve_page_doc(page_id):
    response = es.get(index=index, doc_type=doc_type, id=page_id)
    if "_source" in response:
        page_doc = parse_es_doc(response["_source"])
        return page_doc
    else:
        return None
    

for page_id in pages_info:
    #if pages_info[page_id]["scan_num"] < 14 or  pages_info[page_id]["scan_num"] > 318:
    #    continue
    page_doc = retrieve_page_doc(page_id)
    #print(json.dumps(page_info, indent=2))
    #print(pages_hocr[page_id]['scan-4-even-0'])
    rep_parser.calculate_left_jumps(page_doc)
    pages_info[page_id]["page_type"] = rep_parser.get_page_type(page_doc, config, DEBUG=False)
    print(page_id, "\t", pages_info[page_id]["page_type"])
# Out:
# scan-4-even 	 bad_page
# scan-4-odd 	 bad_page
# 		NO HEADER LINE for column id scan-5-even-0
# scan-5-even 	 index_page
# scan-5-odd 	 index_page
# scan-6-even 	 bad_page
# scan-6-odd 	 index_page
# scan-7-even 	 index_page
# scan-7-odd 	 index_page
# scan-8-even 	 index_page
# scan-8-odd 	 index_page
# scan-9-even 	 bad_page
# scan-9-odd 	 index_page
# scan-10-even 	 index_page
# scan-10-odd 	 index_page
# scan-11-even 	 bad_page
# scan-11-odd 	 index_page
# scan-12-even 	 index_page
# scan-12-odd 	 index_page
# scan-13-even 	 index_page
# scan-13-odd 	 index_page
# scan-14-even 	 index_page
# scan-14-odd 	 bad_page
# 		NO HEADER LINE for column id scan-15-even-1
# scan-15-even 	 index_page
# scan-15-odd 	 bad_page
# scan-16-even 	 index_page
# scan-16-odd 	 index_page
# scan-17-even 	 index_page
# scan-17-odd 	 index_page
# scan-18-even 	 index_page
# scan-18-odd 	 bad_page
# scan-19-even 	 index_page
# scan-19-odd 	 bad_page
# scan-20-even 	 index_page
# scan-20-odd 	 bad_page
# scan-21-even 	 index_page
# scan-21-odd 	 bad_page
# scan-22-even 	 index_page
# scan-22-odd 	 index_page
# scan-23-even 	 index_page
# scan-23-odd 	 bad_page
# 		NO HEADER LINE for column id scan-24-even-1
# scan-24-even 	 index_page
# scan-24-odd 	 bad_page
# 		NO HEADER LINE for column id scan-25-even-0
# scan-25-even 	 index_page
# 		NO HEADER LINE for column id scan-25-odd-2
# scan-25-odd 	 index_page
# 		NO HEADER LINE for column id scan-26-even-0
# 		NO HEADER LINE for column id scan-26-even-1
# scan-26-even 	 index_page
# scan-26-odd 	 index_page
# scan-27-even 	 index_page
# scan-27-odd 	 index_page
# 		NO HEADER LINE for column id scan-28-even-0
# scan-28-even 	 index_page
# scan-28-odd 	 index_page
# scan-29-even 	 index_page
# scan-29-odd 	 bad_page
# scan-30-even 	 index_page
# scan-30-odd 	 index_page
# 		NO HEADER LINE for column id scan-31-even-0
# scan-31-even 	 index_page
# scan-31-odd 	 bad_page
# scan-32-even 	 index_page
# scan-32-odd 	 index_page
# 		NO HEADER LINE for column id scan-33-even-0
# scan-33-even 	 index_page
# scan-33-odd 	 index_page
# scan-34-even 	 index_page
# scan-34-odd 	 index_page
# scan-35-even 	 index_page
# scan-35-odd 	 index_page
# scan-36-even 	 index_page
# scan-36-odd 	 index_page
# scan-37-even 	 index_page
# 		NO HEADER LINE for column id scan-37-odd-3
# scan-37-odd 	 index_page
# scan-38-even 	 index_page
# scan-38-odd 	 index_page
# scan-39-even 	 index_page
# scan-39-odd 	 index_page
# scan-40-even 	 index_page
# scan-40-odd 	 index_page
# scan-41-even 	 index_page
# scan-41-odd 	 index_page
# scan-42-even 	 index_page
# scan-42-odd 	 index_page
# scan-43-even 	 index_page
# scan-43-odd 	 index_page
# scan-44-even 	 index_page
# scan-44-odd 	 index_page
# scan-45-even 	 bad_page
# scan-45-odd 	 resolution_page
# scan-46-even 	 resolution_page
# scan-46-odd 	 resolution_page
# scan-47-even 	 resolution_page
# 		NO HEADER LINE for column id scan-47-odd-2
# scan-47-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-48-even-0
# scan-48-even 	 resolution_page
# scan-48-odd 	 resolution_page
# scan-49-even 	 resolution_page
# scan-49-odd 	 resolution_page
# scan-50-even 	 resolution_page
# scan-50-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-51-even-0
# scan-51-even 	 resolution_page
# scan-51-odd 	 resolution_page
# scan-52-odd 	 resolution_page
# scan-53-even 	 resolution_page
# scan-53-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-54-even-0
# scan-54-even 	 resolution_page
# scan-54-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-55-even-0
# scan-55-even 	 resolution_page
# scan-55-odd 	 resolution_page
# scan-56-even 	 resolution_page
# scan-56-odd 	 resolution_page
# scan-57-even 	 resolution_page
# scan-57-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-58-even-1
# scan-58-even 	 resolution_page
# scan-58-odd 	 resolution_page
# scan-59-even 	 resolution_page
# scan-59-odd 	 resolution_page
# scan-60-even 	 resolution_page
# scan-60-odd 	 resolution_page
# scan-61-even 	 resolution_page
# scan-61-odd 	 resolution_page
# scan-62-even 	 resolution_page
# scan-62-odd 	 resolution_page
# scan-63-even 	 resolution_page
# scan-63-odd 	 resolution_page
# scan-64-even 	 resolution_page
# scan-64-odd 	 resolution_page
# scan-65-even 	 resolution_page
# scan-65-odd 	 resolution_page
# scan-66-even 	 resolution_page
# scan-66-odd 	 resolution_page
# scan-67-even 	 resolution_page
# scan-67-odd 	 resolution_page
# scan-68-even 	 resolution_page
# scan-68-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-69-even-1
# scan-69-even 	 resolution_page
# scan-69-odd 	 resolution_page
# scan-70-even 	 resolution_page
# scan-70-odd 	 resolution_page
# scan-71-even 	 resolution_page
# scan-71-odd 	 resolution_page
# scan-72-even 	 resolution_page
# scan-72-odd 	 resolution_page
# scan-73-even 	 resolution_page
# scan-73-odd 	 resolution_page
# scan-74-even 	 resolution_page
# scan-74-odd 	 resolution_page
# scan-75-even 	 resolution_page
# scan-75-odd 	 resolution_page
# scan-76-even 	 resolution_page
# scan-76-odd 	 resolution_page
# scan-77-even 	 bad_page
# 		NO HEADER LINE for column id scan-77-odd-2
# scan-77-odd 	 resolution_page
# scan-78-even 	 resolution_page
# scan-78-odd 	 resolution_page
# scan-79-even 	 resolution_page
# scan-79-odd 	 resolution_page
# scan-80-even 	 resolution_page
# scan-80-odd 	 resolution_page
# scan-81-even 	 resolution_page
# scan-81-odd 	 resolution_page
# scan-82-even 	 resolution_page
# scan-82-odd 	 resolution_page
# scan-83-even 	 resolution_page
# scan-83-odd 	 resolution_page
# scan-84-even 	 resolution_page
# scan-84-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-85-even-0
# scan-85-even 	 resolution_page
# scan-85-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-86-even-1
# scan-86-even 	 resolution_page
# scan-86-odd 	 resolution_page
# scan-87-even 	 resolution_page
# scan-87-odd 	 resolution_page
# scan-88-even 	 resolution_page
# scan-88-odd 	 resolution_page
# scan-89-even 	 resolution_page
# scan-89-odd 	 resolution_page
# scan-90-even 	 resolution_page
# scan-90-odd 	 resolution_page
# scan-91-even 	 resolution_page
# scan-91-odd 	 resolution_page
# scan-92-even 	 resolution_page
# scan-92-odd 	 resolution_page
# scan-93-even 	 resolution_page
# scan-93-odd 	 resolution_page
# scan-94-even 	 resolution_page
# scan-94-odd 	 resolution_page
# scan-95-even 	 resolution_page
# scan-95-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-96-even-0
# scan-96-even 	 resolution_page
# scan-96-odd 	 resolution_page
# scan-97-even 	 resolution_page
# scan-97-odd 	 resolution_page
# scan-98-even 	 resolution_page
# scan-98-odd 	 resolution_page
# scan-99-even 	 resolution_page
# scan-99-odd 	 resolution_page
# scan-100-even 	 resolution_page
# scan-100-odd 	 resolution_page
# scan-101-even 	 resolution_page
# scan-102-even 	 resolution_page
# scan-102-odd 	 resolution_page
# scan-103-odd 	 resolution_page
# scan-104-even 	 resolution_page
# scan-104-odd 	 resolution_page
# scan-105-even 	 resolution_page
# 		NO HEADER LINE for column id scan-105-odd-2
# scan-105-odd 	 resolution_page
# scan-106-even 	 resolution_page
# scan-106-odd 	 resolution_page
# scan-107-even 	 resolution_page
# scan-107-odd 	 resolution_page
# scan-108-even 	 resolution_page
# scan-108-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-109-even-0
# scan-109-even 	 resolution_page
# scan-109-odd 	 resolution_page
# scan-110-even 	 resolution_page
# scan-110-odd 	 resolution_page
# scan-111-even 	 resolution_page
# scan-111-odd 	 resolution_page
# scan-112-even 	 resolution_page
# scan-112-odd 	 resolution_page
# scan-113-even 	 resolution_page
# scan-113-odd 	 resolution_page
# scan-114-even 	 resolution_page
# scan-114-odd 	 resolution_page
# scan-115-even 	 resolution_page
# scan-115-odd 	 resolution_page
# scan-116-even 	 resolution_page
# scan-116-odd 	 resolution_page
# scan-117-even 	 resolution_page
# scan-117-odd 	 resolution_page
# scan-118-even 	 resolution_page
# scan-118-odd 	 resolution_page
# scan-119-even 	 resolution_page
# scan-119-odd 	 resolution_page
# scan-120-even 	 resolution_page
# scan-120-odd 	 resolution_page
# scan-121-even 	 resolution_page
# scan-121-odd 	 resolution_page
# scan-122-even 	 resolution_page
# scan-122-odd 	 resolution_page
# scan-123-even 	 resolution_page
# scan-123-odd 	 resolution_page
# scan-124-even 	 resolution_page
# scan-124-odd 	 resolution_page
# scan-125-even 	 resolution_page
# scan-125-odd 	 resolution_page
# scan-126-even 	 resolution_page
# scan-126-odd 	 resolution_page
# scan-127-even 	 resolution_page
# scan-127-odd 	 resolution_page
# scan-128-even 	 resolution_page
# scan-128-odd 	 resolution_page
# scan-129-even 	 resolution_page
# scan-129-odd 	 resolution_page
# scan-130-even 	 resolution_page
# scan-130-odd 	 resolution_page
# scan-131-even 	 resolution_page
# scan-131-odd 	 resolution_page
# scan-132-even 	 resolution_page
# scan-132-odd 	 resolution_page
# scan-133-even 	 resolution_page
# scan-133-odd 	 resolution_page
# scan-134-even 	 resolution_page
# scan-134-odd 	 resolution_page
# scan-135-even 	 resolution_page
# scan-135-odd 	 resolution_page
# scan-136-even 	 resolution_page
# scan-136-odd 	 resolution_page
# scan-137-even 	 resolution_page
# scan-137-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-138-even-0
# scan-138-even 	 resolution_page
# scan-138-odd 	 resolution_page
# scan-139-even 	 resolution_page
# scan-139-odd 	 resolution_page
# scan-140-even 	 resolution_page
# scan-140-odd 	 resolution_page
# scan-141-even 	 resolution_page
# scan-141-odd 	 resolution_page
# scan-142-even 	 resolution_page
# scan-142-odd 	 resolution_page
# scan-143-even 	 resolution_page
# scan-143-odd 	 resolution_page
# scan-144-even 	 resolution_page
# scan-144-odd 	 resolution_page
# scan-145-odd 	 resolution_page
# scan-146-even 	 resolution_page
# scan-146-odd 	 resolution_page
# scan-147-even 	 resolution_page
# scan-147-odd 	 resolution_page
# scan-148-even 	 resolution_page
# scan-148-odd 	 resolution_page
# scan-149-even 	 resolution_page
# scan-149-odd 	 resolution_page
# scan-150-even 	 resolution_page
# scan-150-odd 	 resolution_page
# scan-151-even 	 resolution_page
# scan-151-odd 	 resolution_page
# scan-152-even 	 resolution_page
# scan-152-odd 	 resolution_page
# scan-153-even 	 resolution_page
# scan-153-odd 	 resolution_page
# scan-154-even 	 resolution_page
# scan-154-odd 	 resolution_page
# scan-155-even 	 resolution_page
# scan-155-odd 	 resolution_page
# scan-156-even 	 resolution_page
# scan-156-odd 	 resolution_page
# scan-157-odd 	 resolution_page
# scan-158-even 	 resolution_page
# scan-158-odd 	 resolution_page
# scan-159-even 	 resolution_page
# scan-159-odd 	 resolution_page
# scan-160-even 	 resolution_page
# scan-160-odd 	 resolution_page
# scan-161-even 	 resolution_page
# scan-161-odd 	 resolution_page
# scan-162-even 	 resolution_page
# scan-162-odd 	 resolution_page
# scan-163-even 	 resolution_page
# scan-163-odd 	 resolution_page
# scan-164-even 	 resolution_page
# scan-164-odd 	 resolution_page
# scan-165-even 	 resolution_page
# scan-165-odd 	 resolution_page
# scan-166-even 	 resolution_page
# scan-166-odd 	 resolution_page
# scan-167-even 	 resolution_page
# scan-167-odd 	 resolution_page
# scan-168-even 	 resolution_page
# scan-168-odd 	 resolution_page
# scan-169-even 	 resolution_page
# scan-169-odd 	 resolution_page
# scan-170-even 	 resolution_page
# scan-170-odd 	 resolution_page
# scan-171-even 	 resolution_page
# scan-171-odd 	 resolution_page
# scan-172-even 	 resolution_page
# scan-172-odd 	 resolution_page
# scan-173-even 	 resolution_page
# scan-173-odd 	 resolution_page
# scan-174-even 	 resolution_page
# scan-174-odd 	 resolution_page
# scan-175-even 	 resolution_page
# scan-175-odd 	 resolution_page
# scan-176-even 	 resolution_page
# scan-176-odd 	 resolution_page
# scan-177-even 	 resolution_page
# scan-177-odd 	 resolution_page
# scan-178-even 	 resolution_page
# scan-178-odd 	 resolution_page
# scan-179-even 	 resolution_page
# scan-179-odd 	 resolution_page
# scan-180-even 	 resolution_page
# scan-180-odd 	 resolution_page
# scan-181-even 	 resolution_page
# scan-181-odd 	 resolution_page
# scan-182-even 	 resolution_page
# scan-182-odd 	 resolution_page
# scan-183-even 	 resolution_page
# scan-183-odd 	 resolution_page
# scan-184-even 	 resolution_page
# scan-184-odd 	 resolution_page
# scan-185-even 	 resolution_page
# scan-185-odd 	 resolution_page
# scan-186-even 	 resolution_page
# scan-186-odd 	 resolution_page
# scan-187-even 	 resolution_page
# scan-187-odd 	 resolution_page
# scan-188-even 	 resolution_page
# scan-188-odd 	 resolution_page
# scan-189-even 	 resolution_page
# scan-189-odd 	 resolution_page
# scan-190-even 	 resolution_page
# scan-190-odd 	 resolution_page
# scan-191-even 	 resolution_page
# scan-191-odd 	 resolution_page
# scan-192-even 	 resolution_page
# scan-192-odd 	 resolution_page
# scan-193-even 	 resolution_page
# scan-193-odd 	 resolution_page
# scan-194-even 	 resolution_page
# scan-194-odd 	 resolution_page
# scan-195-even 	 resolution_page
# scan-195-odd 	 resolution_page
# scan-196-even 	 resolution_page
# scan-196-odd 	 resolution_page
# scan-197-even 	 bad_page
# scan-197-odd 	 resolution_page
# scan-198-even 	 resolution_page
# scan-198-odd 	 resolution_page
# scan-199-even 	 resolution_page
# scan-199-odd 	 resolution_page
# scan-200-even 	 resolution_page
# scan-200-odd 	 resolution_page
# scan-201-even 	 resolution_page
# scan-201-odd 	 resolution_page
# scan-202-even 	 resolution_page
# scan-202-odd 	 resolution_page
# scan-203-even 	 resolution_page
# scan-203-odd 	 resolution_page
# scan-204-even 	 resolution_page
# scan-204-odd 	 resolution_page
# scan-205-even 	 resolution_page
# scan-205-odd 	 resolution_page
# scan-206-even 	 resolution_page
# scan-206-odd 	 resolution_page
# scan-207-even 	 resolution_page
# scan-207-odd 	 resolution_page
# scan-208-even 	 resolution_page
# scan-208-odd 	 resolution_page
# scan-209-even 	 resolution_page
# scan-209-odd 	 resolution_page
# scan-210-even 	 resolution_page
# scan-210-odd 	 resolution_page
# scan-211-even 	 resolution_page
# scan-211-odd 	 resolution_page
# scan-212-even 	 resolution_page
# scan-212-odd 	 resolution_page
# scan-213-even 	 resolution_page
# scan-213-odd 	 resolution_page
# scan-214-even 	 resolution_page
# scan-214-odd 	 resolution_page
# scan-215-even 	 resolution_page
# scan-215-odd 	 resolution_page
# scan-216-even 	 resolution_page
# scan-216-odd 	 resolution_page
# scan-217-even 	 resolution_page
# scan-217-odd 	 resolution_page
# scan-218-even 	 resolution_page
# scan-218-odd 	 resolution_page
# scan-219-even 	 resolution_page
# scan-219-odd 	 resolution_page
# scan-220-even 	 resolution_page
# 		NO HEADER LINE for column id scan-220-odd-2
# scan-220-odd 	 resolution_page
# scan-221-even 	 resolution_page
# scan-221-odd 	 resolution_page
# scan-222-even 	 resolution_page
# scan-222-odd 	 resolution_page
# scan-223-even 	 resolution_page
# scan-223-odd 	 resolution_page
# scan-224-even 	 resolution_page
# scan-224-odd 	 resolution_page
# scan-225-even 	 resolution_page
# scan-225-odd 	 resolution_page
# scan-226-even 	 resolution_page
# scan-226-odd 	 resolution_page
# scan-227-even 	 resolution_page
# scan-227-odd 	 resolution_page
# scan-228-even 	 resolution_page
# scan-228-odd 	 resolution_page
# scan-229-even 	 resolution_page
# scan-229-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-230-even-0
# scan-230-even 	 resolution_page
# scan-230-odd 	 resolution_page
# scan-231-even 	 resolution_page
# scan-231-odd 	 resolution_page
# scan-232-even 	 resolution_page
# scan-232-odd 	 resolution_page
# scan-233-even 	 resolution_page
# scan-233-odd 	 resolution_page
# scan-234-even 	 resolution_page
# scan-234-odd 	 resolution_page
# scan-235-odd 	 resolution_page
# scan-236-even 	 resolution_page
# scan-236-odd 	 resolution_page
# scan-237-even 	 resolution_page
# scan-237-odd 	 resolution_page
# scan-238-even 	 resolution_page
# scan-238-odd 	 resolution_page
# scan-239-even 	 resolution_page
# scan-239-odd 	 resolution_page
# scan-240-even 	 resolution_page
# scan-240-odd 	 resolution_page
# scan-241-even 	 resolution_page
# scan-241-odd 	 resolution_page
# scan-242-even 	 resolution_page
# scan-242-odd 	 resolution_page
# scan-243-even 	 resolution_page
# scan-244-even 	 resolution_page
# scan-244-odd 	 resolution_page
# scan-245-odd 	 resolution_page
# scan-246-even 	 resolution_page
# scan-246-odd 	 resolution_page
# scan-247-even 	 resolution_page
# scan-247-odd 	 resolution_page
# scan-248-even 	 resolution_page
# scan-248-odd 	 resolution_page
# scan-249-even 	 resolution_page
# scan-249-odd 	 resolution_page
# scan-250-even 	 resolution_page
# scan-250-odd 	 resolution_page
# scan-251-even 	 resolution_page
# scan-251-odd 	 resolution_page
# scan-252-even 	 resolution_page
# scan-252-odd 	 resolution_page
# scan-253-even 	 resolution_page
# scan-253-odd 	 resolution_page
# scan-254-even 	 resolution_page
# scan-254-odd 	 resolution_page
# scan-255-even 	 resolution_page
# scan-255-odd 	 resolution_page
# scan-256-even 	 resolution_page
# scan-256-odd 	 resolution_page
# scan-257-even 	 resolution_page
# scan-257-odd 	 resolution_page
# scan-258-even 	 resolution_page
# scan-258-odd 	 resolution_page
# scan-259-even 	 resolution_page
# scan-259-odd 	 resolution_page
# scan-260-even 	 resolution_page
# scan-260-odd 	 resolution_page
# scan-261-even 	 resolution_page
# scan-261-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-262-even-0
# scan-262-even 	 resolution_page
# scan-262-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-263-even-0
# scan-263-even 	 resolution_page
# scan-263-odd 	 resolution_page
# scan-264-even 	 resolution_page
# scan-264-odd 	 resolution_page
# scan-265-even 	 resolution_page
# scan-265-odd 	 resolution_page
# scan-266-even 	 resolution_page
# 		NO HEADER LINE for column id scan-266-odd-2
# scan-266-odd 	 resolution_page
# scan-267-even 	 resolution_page
# scan-267-odd 	 resolution_page
# scan-268-even 	 resolution_page
# scan-268-odd 	 resolution_page
# scan-270-even 	 resolution_page
# scan-270-odd 	 resolution_page
# scan-271-even 	 resolution_page
# scan-271-odd 	 resolution_page
# scan-272-even 	 resolution_page
# scan-272-odd 	 resolution_page
# scan-273-even 	 resolution_page
# scan-273-odd 	 resolution_page
# scan-274-even 	 resolution_page
# scan-274-odd 	 resolution_page
# scan-275-even 	 resolution_page
# scan-275-odd 	 resolution_page
# scan-276-even 	 resolution_page
# scan-276-odd 	 resolution_page
# scan-277-even 	 resolution_page
# scan-277-odd 	 resolution_page
# scan-278-even 	 resolution_page
# scan-278-odd 	 resolution_page
# scan-279-even 	 resolution_page
# scan-279-odd 	 resolution_page
# scan-280-even 	 resolution_page
# scan-280-odd 	 resolution_page
# scan-281-even 	 resolution_page
# scan-281-odd 	 resolution_page
# scan-282-odd 	 bad_page
# scan-283-odd 	 resolution_page
# scan-284-even 	 resolution_page
# scan-284-odd 	 resolution_page
# scan-285-even 	 resolution_page
# scan-285-odd 	 resolution_page
# scan-286-even 	 resolution_page
# scan-286-odd 	 resolution_page
# scan-287-even 	 resolution_page
# scan-287-odd 	 resolution_page
# scan-288-even 	 resolution_page
# scan-288-odd 	 resolution_page
# scan-289-even 	 resolution_page
# scan-289-odd 	 resolution_page
# scan-290-even 	 resolution_page
# scan-290-odd 	 resolution_page
# scan-291-odd 	 resolution_page
# scan-292-even 	 resolution_page
# scan-292-odd 	 resolution_page
# scan-293-even 	 resolution_page
# scan-293-odd 	 resolution_page
# scan-294-even 	 resolution_page
# scan-294-odd 	 resolution_page
# scan-295-even 	 resolution_page
# scan-295-odd 	 resolution_page
# scan-296-even 	 resolution_page
# scan-296-odd 	 resolution_page
# scan-297-even 	 resolution_page
# scan-297-odd 	 resolution_page
# scan-298-even 	 bad_page
# scan-298-odd 	 resolution_page
# scan-299-even 	 resolution_page
# scan-299-odd 	 resolution_page
# scan-300-even 	 resolution_page
# scan-300-odd 	 resolution_page
# scan-301-even 	 resolution_page
# scan-301-odd 	 resolution_page
# scan-302-even 	 resolution_page
# scan-302-odd 	 resolution_page
# scan-303-even 	 resolution_page
# scan-303-odd 	 resolution_page
# scan-304-even 	 resolution_page
# scan-304-odd 	 resolution_page
# scan-305-odd 	 resolution_page
# scan-306-even 	 resolution_page
# scan-306-odd 	 resolution_page
# scan-307-even 	 resolution_page
# scan-307-odd 	 resolution_page
# scan-308-even 	 resolution_page
# scan-308-odd 	 resolution_page
# scan-309-even 	 resolution_page
# scan-309-odd 	 resolution_page
# scan-310-even 	 resolution_page
# scan-310-odd 	 resolution_page
# scan-311-even 	 resolution_page
# scan-312-even 	 resolution_page
# scan-312-odd 	 resolution_page
# scan-313-even 	 resolution_page
# scan-313-odd 	 resolution_page
# scan-314-even 	 resolution_page
# scan-314-odd 	 resolution_page
# scan-315-even 	 resolution_page
# scan-315-odd 	 resolution_page
# scan-316-even 	 resolution_page
# scan-316-odd 	 resolution_page
# scan-317-even 	 resolution_page
# scan-317-odd 	 resolution_page
# scan-318-even 	 resolution_page
# scan-318-odd 	 resolution_page
# scan-319-even 	 resolution_page
# scan-319-odd 	 resolution_page
# scan-320-even 	 resolution_page
# scan-320-odd 	 resolution_page
# scan-321-even 	 resolution_page
# scan-321-odd 	 resolution_page
# scan-322-even 	 resolution_page
# scan-322-odd 	 resolution_page
# scan-323-even 	 resolution_page
# scan-323-odd 	 resolution_page
# scan-324-even 	 resolution_page
# scan-324-odd 	 resolution_page
# scan-325-odd 	 resolution_page
# scan-326-even 	 resolution_page
# scan-326-odd 	 resolution_page
# scan-327-even 	 resolution_page
# scan-327-odd 	 resolution_page
# scan-328-even 	 resolution_page
# scan-328-odd 	 resolution_page
# scan-329-even 	 resolution_page
# scan-329-odd 	 resolution_page
# scan-330-even 	 resolution_page
# scan-330-odd 	 resolution_page
# scan-331-even 	 resolution_page
# scan-331-odd 	 resolution_page
# scan-332-even 	 resolution_page
# scan-332-odd 	 bad_page
# scan-333-even 	 bad_page
# scan-333-odd 	 bad_page
# scan-334-even 	 bad_page
# scan-334-odd 	 bad_page
# scan-335-even 	 bad_page
# scan-335-odd 	 bad_page
# scan-336-even 	 bad_page
# scan-336-odd 	 bad_page
# scan-337-even 	 bad_page
# scan-337-odd 	 bad_page
# scan-338-even 	 bad_page
# scan-338-odd 	 bad_page
# scan-339-even 	 bad_page
# scan-339-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-340-even-0
# scan-340-even 	 resolution_page
# scan-340-odd 	 resolution_page
# scan-341-even 	 resolution_page
# scan-341-odd 	 resolution_page
# scan-342-even 	 resolution_page
# scan-342-odd 	 resolution_page
# scan-343-even 	 resolution_page
# scan-343-odd 	 resolution_page
# scan-344-even 	 resolution_page
# scan-344-odd 	 resolution_page
# scan-345-even 	 resolution_page
# scan-345-odd 	 resolution_page
# scan-346-even 	 resolution_page
# scan-346-odd 	 resolution_page
# scan-347-even 	 resolution_page
# scan-347-odd 	 resolution_page
# scan-348-even 	 resolution_page
# scan-348-odd 	 resolution_page
# scan-349-even 	 resolution_page
# scan-350-even 	 resolution_page
# scan-350-odd 	 resolution_page
# scan-351-even 	 resolution_page
# scan-351-odd 	 resolution_page
# scan-352-even 	 resolution_page
# scan-352-odd 	 resolution_page
# scan-353-even 	 resolution_page
# scan-353-odd 	 resolution_page
# scan-354-even 	 resolution_page
# scan-354-odd 	 bad_page
# scan-355-even 	 resolution_page
# scan-355-odd 	 resolution_page
# scan-356-even 	 resolution_page
# scan-356-odd 	 bad_page
# scan-357-even 	 resolution_page
# scan-357-odd 	 resolution_page
# scan-358-even 	 resolution_page
# scan-358-odd 	 resolution_page
# scan-359-even 	 resolution_page
# scan-359-odd 	 resolution_page
# scan-360-even 	 resolution_page
# scan-360-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-361-even-2
# scan-361-even 	 resolution_page
# scan-361-odd 	 resolution_page
# scan-362-even 	 resolution_page
# scan-362-odd 	 resolution_page
# scan-363-even 	 resolution_page
# scan-363-odd 	 resolution_page
# scan-364-even 	 resolution_page
# scan-364-odd 	 resolution_page
# scan-365-even 	 resolution_page
# scan-365-odd 	 resolution_page
# scan-366-even 	 resolution_page
# scan-366-odd 	 resolution_page
# scan-367-even 	 resolution_page
# scan-367-odd 	 resolution_page
# scan-368-even 	 resolution_page
# scan-369-even 	 resolution_page
# scan-369-odd 	 resolution_page
# scan-370-even 	 resolution_page
# scan-370-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-371-even-0
# scan-371-even 	 resolution_page
# scan-371-odd 	 resolution_page
# scan-372-even 	 resolution_page
# scan-372-odd 	 resolution_page
# scan-373-even 	 resolution_page
# scan-373-odd 	 resolution_page
# scan-374-even 	 resolution_page
# scan-374-odd 	 resolution_page
# scan-375-even 	 resolution_page
# scan-375-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-376-even-0
# scan-376-even 	 resolution_page
# scan-376-odd 	 resolution_page
# scan-377-even 	 resolution_page
# scan-377-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-378-even-2
# scan-378-even 	 resolution_page
# scan-378-odd 	 resolution_page
# scan-379-even 	 resolution_page
# scan-379-odd 	 resolution_page
# scan-380-even 	 resolution_page
# scan-380-odd 	 resolution_page
# scan-381-even 	 resolution_page
# scan-381-odd 	 resolution_page
# scan-382-even 	 resolution_page
# scan-382-odd 	 resolution_page
# scan-383-even 	 resolution_page
# scan-383-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-384-even-1
# 		NO HEADER LINE for column id scan-384-even-2
# scan-384-even 	 resolution_page
# scan-384-odd 	 resolution_page
# scan-385-even 	 resolution_page
# scan-385-odd 	 resolution_page
# scan-386-even 	 resolution_page
# scan-386-odd 	 resolution_page
# scan-387-even 	 resolution_page
# scan-387-odd 	 resolution_page
# scan-388-even 	 resolution_page
# scan-388-odd 	 resolution_page
# scan-389-even 	 resolution_page
# scan-389-odd 	 resolution_page
# scan-390-even 	 resolution_page
# scan-390-odd 	 resolution_page
# scan-391-even 	 resolution_page
# scan-391-odd 	 resolution_page
# scan-392-even 	 resolution_page
# scan-392-odd 	 resolution_page
# scan-393-even 	 resolution_page
# scan-393-odd 	 resolution_page
# scan-394-even 	 resolution_page
# scan-394-odd 	 resolution_page
# scan-395-even 	 resolution_page
# scan-395-odd 	 resolution_page
# scan-396-even 	 resolution_page
# scan-396-odd 	 resolution_page
# scan-397-even 	 resolution_page
# scan-397-odd 	 resolution_page
# scan-398-even 	 resolution_page
# scan-398-odd 	 resolution_page
# scan-399-even 	 resolution_page
# scan-399-odd 	 resolution_page
# scan-400-even 	 resolution_page
# scan-400-odd 	 resolution_page
# scan-401-even 	 resolution_page
# scan-401-odd 	 resolution_page
# scan-402-even 	 resolution_page
# scan-402-odd 	 resolution_page
# scan-403-even 	 resolution_page
# scan-403-odd 	 resolution_page
# scan-404-even 	 resolution_page
# scan-404-odd 	 resolution_page
# scan-405-even 	 resolution_page
# scan-405-odd 	 resolution_page
# scan-406-even 	 resolution_page
# scan-406-odd 	 resolution_page
# scan-407-even 	 resolution_page
# scan-407-odd 	 resolution_page
# scan-408-even 	 resolution_page
# scan-408-odd 	 resolution_page
# scan-409-even 	 resolution_page
# scan-409-odd 	 resolution_page
# scan-410-even 	 resolution_page
# scan-410-odd 	 resolution_page
# scan-411-even 	 resolution_page
# scan-411-odd 	 resolution_page
# scan-412-even 	 resolution_page
# scan-412-odd 	 resolution_page
# scan-413-even 	 resolution_page
# scan-413-odd 	 resolution_page
# scan-414-even 	 resolution_page
# scan-414-odd 	 resolution_page
# scan-415-even 	 resolution_page
# scan-415-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-416-even-0
# scan-416-even 	 resolution_page
# scan-416-odd 	 resolution_page
# scan-417-even 	 resolution_page
# scan-417-odd 	 resolution_page
# scan-418-even 	 resolution_page
# scan-418-odd 	 resolution_page
# scan-419-even 	 resolution_page
# scan-419-odd 	 resolution_page
# scan-420-even 	 resolution_page
# scan-420-odd 	 resolution_page
# scan-421-even 	 resolution_page
# scan-421-odd 	 resolution_page
# scan-422-even 	 resolution_page
# scan-422-odd 	 resolution_page
# scan-423-even 	 resolution_page
# scan-423-odd 	 resolution_page
# scan-424-even 	 resolution_page
# scan-424-odd 	 resolution_page
# scan-425-even 	 resolution_page
# scan-425-odd 	 resolution_page
# scan-426-even 	 resolution_page
# scan-426-odd 	 resolution_page
# scan-427-even 	 resolution_page
# scan-427-odd 	 resolution_page
# scan-428-even 	 resolution_page
# scan-428-odd 	 resolution_page
# scan-429-even 	 resolution_page
# scan-429-odd 	 resolution_page
# scan-430-even 	 resolution_page
# scan-430-odd 	 resolution_page
# scan-431-even 	 resolution_page
# scan-431-odd 	 resolution_page
# scan-432-even 	 resolution_page
# scan-432-odd 	 resolution_page
# scan-433-even 	 resolution_page
# scan-433-odd 	 resolution_page
# scan-434-even 	 resolution_page
# scan-434-odd 	 resolution_page
# scan-435-even 	 resolution_page
# scan-435-odd 	 resolution_page
# scan-436-even 	 resolution_page
# scan-436-odd 	 resolution_page
# scan-437-even 	 resolution_page
# scan-438-even 	 resolution_page
# scan-438-odd 	 resolution_page
# scan-439-even 	 resolution_page
# scan-439-odd 	 resolution_page
# scan-440-even 	 resolution_page
# scan-440-odd 	 resolution_page
# scan-441-even 	 resolution_page
# scan-441-odd 	 resolution_page
# scan-442-even 	 resolution_page
# scan-443-even 	 resolution_page
# scan-443-odd 	 resolution_page
# scan-444-even 	 resolution_page
# scan-445-even 	 resolution_page
# scan-446-even 	 resolution_page
# scan-447-even 	 resolution_page
# scan-448-even 	 resolution_page
# scan-448-odd 	 resolution_page
# scan-449-even 	 resolution_page
# scan-450-even 	 resolution_page
# scan-450-odd 	 resolution_page
# scan-451-even 	 resolution_page
# scan-451-odd 	 resolution_page
# scan-452-even 	 resolution_page
# scan-452-odd 	 resolution_page
# scan-453-even 	 resolution_page
# scan-453-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-454-even-0
# scan-454-even 	 resolution_page
# scan-454-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-455-even-1
# scan-455-even 	 resolution_page
# scan-455-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-456-even-2
# scan-456-even 	 resolution_page
# scan-456-odd 	 resolution_page
# scan-457-even 	 resolution_page
# scan-458-even 	 resolution_page
# scan-458-odd 	 resolution_page
# scan-459-even 	 resolution_page
# scan-459-odd 	 resolution_page
# 		NO HEADER LINE for column id scan-460-even-1
# scan-460-even 	 resolution_page
# scan-460-odd 	 resolution_page
# scan-461-even 	 resolution_page
# scan-461-odd 	 resolution_page
# scan-462-even 	 resolution_page
# scan-462-odd 	 resolution_page
# scan-463-even 	 resolution_page
# scan-463-odd 	 resolution_page
# scan-464-even 	 resolution_page
# scan-464-odd 	 resolution_page
# scan-465-even 	 bad_page
# scan-465-odd 	 bad_page
# scan-466-even 	 bad_page
# scan-466-odd 	 bad_page
# scan-467-even 	 bad_page
# scan-468-even 	 resolution_page
# scan-468-odd 	 resolution_page
# scan-469-even 	 resolution_page
# scan-469-odd 	 resolution_page
# scan-470-even 	 resolution_page
# scan-471-even 	 resolution_page
# scan-472-even 	 resolution_page
# scan-472-odd 	 resolution_page
# scan-473-even 	 resolution_page
# scan-473-odd 	 resolution_page
# scan-474-even 	 resolution_page
# scan-474-odd 	 resolution_page
# scan-475-even 	 resolution_page
# scan-475-odd 	 resolution_page
# scan-476-even 	 resolution_page
# scan-476-odd 	 resolution_page
# scan-477-even 	 resolution_page
# scan-477-odd 	 resolution_page
# scan-478-even 	 resolution_page
# scan-478-odd 	 resolution_page
# scan-479-even 	 resolution_page
# scan-479-odd 	 resolution_page
# scan-480-even 	 resolution_page
# scan-480-odd 	 resolution_page
# scan-481-even 	 resolution_page
# scan-482-even 	 resolution_page
# scan-482-odd 	 resolution_page
# scan-483-even 	 resolution_page
# scan-483-odd 	 resolution_page
# scan-484-even 	 resolution_page
# scan-485-even 	 resolution_page
# scan-485-odd 	 resolution_page
# scan-486-even 	 resolution_page
# scan-486-odd 	 resolution_page
# scan-487-even 	 resolution_page
# scan-488-even 	 resolution_page
# scan-488-odd 	 resolution_page
# scan-489-even 	 resolution_page
# scan-489-odd 	 resolution_page
# scan-490-even 	 bad_page
# scan-490-odd 	 bad_page
# scan-491-even 	 bad_page
# scan-491-odd 	 bad_page
# scan-492-even 	 bad_page
# scan-492-odd 	 bad_page
# scan-493-even 	 bad_page
# scan-493-odd 	 bad_page
# scan-494-even 	 bad_page
# scan-494-odd 	 resolution_page
# scan-495-even 	 resolution_page
# scan-495-odd 	 resolution_page
# scan-496-even 	 resolution_page
# scan-496-odd 	 resolution_page
# scan-497-even 	 resolution_page
# scan-497-odd 	 resolution_page
# scan-498-even 	 resolution_page
# scan-498-odd 	 resolution_page
# scan-499-even 	 resolution_page
# scan-499-odd 	 resolution_page
# scan-500-even 	 resolution_page
# scan-500-odd 	 resolution_page
# scan-501-even 	 resolution_page
# scan-501-odd 	 resolution_page
# scan-502-even 	 resolution_page
# scan-502-odd 	 resolution_page
# scan-503-even 	 resolution_page
# scan-504-even 	 resolution_page
# scan-504-odd 	 resolution_page
# scan-505-even 	 resolution_page
# scan-505-odd 	 resolution_page
# scan-506-even 	 resolution_page
# scan-506-odd 	 resolution_page
# scan-507-even 	 resolution_page
# scan-507-odd 	 resolution_page
# scan-508-even 	 resolution_page
# scan-508-odd 	 resolution_page
# scan-509-even 	 resolution_page
# scan-509-odd 	 resolution_page
# scan-510-even 	 resolution_page
# scan-510-odd 	 resolution_page
# scan-511-even 	 resolution_page
# scan-511-odd 	 resolution_page
# scan-512-even 	 resolution_page
# scan-512-odd 	 resolution_page
# scan-513-even 	 resolution_page
# scan-513-odd 	 resolution_page
# scan-514-even 	 resolution_page
# scan-514-odd 	 resolution_page
# scan-515-even 	 resolution_page
# scan-515-odd 	 resolution_page
# scan-516-even 	 resolution_page
# scan-516-odd 	 resolution_page
# scan-517-odd 	 resolution_page
# scan-518-even 	 resolution_page
# scan-518-odd 	 resolution_page
# scan-519-even 	 resolution_page
# scan-519-odd 	 resolution_page
# scan-520-even 	 bad_page
# scan-520-odd 	 resolution_page
# scan-521-even 	 resolution_page
# scan-521-odd 	 resolution_page
# scan-522-even 	 resolution_page
# scan-522-odd 	 resolution_page
# scan-523-even 	 resolution_page
# scan-523-odd 	 resolution_page
# scan-524-even 	 resolution_page
# scan-524-odd 	 resolution_page
# scan-525-even 	 resolution_page
# scan-525-odd 	 resolution_page
# scan-526-even 	 bad_page
# scan-526-odd 	 bad_page
# scan-527-even 	 bad_page
# scan-527-odd 	 resolution_page
# scan-528-even 	 resolution_page
# scan-528-odd 	 resolution_page
# scan-529-even 	 resolution_page
# scan-529-odd 	 resolution_page
# scan-530-even 	 resolution_page
# scan-530-odd 	 resolution_page
# scan-531-even 	 resolution_page
# scan-531-odd 	 resolution_page
# scan-532-even 	 resolution_page
# scan-532-odd 	 resolution_page
# scan-533-even 	 resolution_page
# scan-533-odd 	 resolution_page
# scan-534-even 	 resolution_page
# scan-534-odd 	 resolution_page
# scan-535-even 	 resolution_page
# scan-535-odd 	 resolution_page
# scan-536-even 	 resolution_page
# scan-536-odd 	 resolution_page
# scan-537-even 	 resolution_page
# 		NO HEADER LINE for column id scan-537-odd-3
# scan-537-odd 	 resolution_page
# scan-538-even 	 bad_page
# scan-542-even 	 bad_page

# %% [markdown]
# ### Parsing and Preprocessing Index Pages
#
# - filter tiny and huge text elements (i.e. deviating from average character/word width and height
# - extract page lines that are part of the main text body containing index entries
# - insert and clean up repetition symbols in index entries
#     - determine length of repetition symbol
#     - identify and replace mis-recognized repetition symbols

# %%
from parse_republic_hocr_files import index_lemmata
avg_left = 0
lemma_index = defaultdict(list)
curr_lemma = None
    

for page_id in pages_info:
    print("\n\n", page_id)
    if pages_info[page_id]["page_type"] != "index_page":
        print("skipping non-index page")
        continue
    page_doc = retrieve_page_doc(page_id)
    pages_info[page_id]["num_page_ref_lines"] = rep_parser.count_page_ref_lines(page_doc)
    for column_info in page_doc["columns"]:
        print("\n\n", column_info["column_id"])
        column_hocr = column_info["column_hocr"]
        lines = rep_parser.get_index_entry_lines(column_hocr)
        curr_lemma = index_lemmata(column_id, lines, lemma_index, curr_lemma)
# Out:
#  scan-4-even
# skipping non-index page
#
#
#  scan-4-odd
# skipping non-index page
#
#
#  scan-5-even
# skipping non-index page
#
#
#  scan-5-odd
#
#
#  scan-5-odd-1
# Header: LE        Kn
# 	scan: don't know line: 0 top: 244 0 1004 1004
# 	FIRST BODY LINE: 9 1903 	##            gejaf} Fabritius te'Cadix eh Courcamp
# possibly misrecognised repeat symbol: 145 mn
# DEVIATING LINE: 227 [227, 108, 63, 112, 169] gejaf} Fabritius te'Cadix eh Courcamp
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 169 [227, 108, 63, 112, 169, 114, 116, 113, 113] ee juftificatie van de conduites ‘gehouden
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 237 [114, 116, 113, 113, 237, 110, 114, 60, 116] redenen waarom het Schip van Zee-
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 240 [114, 60, 116, 108, 240, 69, 115, 72, 119] gevis en geaccordeert. “916.
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 247 [115, 72, 119, 122, 247, 122, 260, 124, 131] Re{olutie ‘wegens de adminiftratie van
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 260 [119, 122, 247, 122, 260, 124, 131, 250, 252] te examineren wegens ‘de vafte refi-
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 250 [122, 260, 124, 131, 250, 252, 128] pgpport en refolutie. 374.
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 252 [260, 124, 131, 250, 252, 128] te berichten op de Memorie van ‘den
# avg_repeat_symbol_length: 145
# 0 63 -18 start 	    —— gejaf} Fabritius te'Cadix eh Courcamp
# 	PAGE_REFS: [284] 	CURR LEMMA: None
# 1 108 21 continue_stop 	      te Lijfabon te brengen.  284.
# 2 63 -28 start 	    —— gelaft feeker Huytfchip met fijn Lar
# 	PAGE_REFS: [670] 	CURR LEMMA: None
# 3 112 18 continue_stop 	       dinge te ‘verkoopen.  670.
# 4 63 -33 start 	 —— ee  juftificatie van de conduites ‘gehouden
# 5 114 17 continue 	       door ‘de 'Capiteynen MWittenborfl, Boudaan-s
# 6 116 19 continue 	       Fronfel en  Elias,  wegens  ‘rencontre en ge=
# 7 113 10 continue 	       veght  met  twee Roofjcheepen  van  Algiers.
# 	PAGE_REFS: [755] 	CURR LEMMA: None
# 8 113 16 continue_stop 	       755:
# 9 72 -31 start 	     —— redenen waarom het Schip van Zee-
# 10 110 8 continue 	       Jandt  ‘opvefönden ‘hadt  ls  onbeguaam ons
# 	PAGE_REFS: [788] 	CURR LEMMA: None
# 11 114 17 continue_stop 	       dien[t te doen.  788.
# 12 60 -33 start 	    me       gn feeker ‘hernomen Schip tot Gadise
# 13 116 23 continue 	       te mogen verkoopen, de ÄAdmiraliteyt te gm-
# 14 108 15 continue 	      terdam te advifteren.   ‘ge8.
# 15 75 -19 start 	     —— gevis en geaccordeert.  “916.
# 16 69 -26 start 	    —gelaft nogh  twee maanden’    Zee fe
# 	PAGE_REFS: [973] 	CURR LEMMA: None
# 17 115 18 continue_stop 	       blijven.   973.
# HAS LEMMA: Admiraliteyten in het gemeen aangefchreven
# 18 72 -26 start 	     Admiraliteyten in het gemeen  aangefchreven
# 19 119 20 continue 	       Lijfen van ‘inkoment Rundvee en Varckens
# 	PAGE_REFS: [33] 	CURR LEMMA: Admiraliteyten
# 20 122 18 continue_stop 	       over te [enden.   33.
# 21 82 -29 start 	     —— Re{olutie ‘wegens de adminiftratie van
# 	PAGE_REFS: [69] 	CURR LEMMA: Admiraliteyten
# 22 122 10 continue_stop 	       bet ‘kleyn Zegel.  69.
# 23 119 1 continue 	      —— te examineren wegens ‘de vafte refi-
# 24 124 5 continue 	       dentie  wan  Bedienden  wan  de  Convoyen.
# 	PAGE_REFS: [175] 	CURR LEMMA: Admiraliteyten
# 25 131 12 continue_stop 	        175.
# 	PAGE_REFS: [374] 	CURR LEMMA: Admiraliteyten
# 26 122 -2 start_stop 	     —— pgpport en refolutie.   374.
# 27 124 0 start 	      —— te berichten  op de Memorie van ‘den
# 28 128 3 continue 	       Marquis de Fenelon, houdende klaghten over
#
#
#  scan-6-even
# skipping non-index page
#
#
#  scan-6-odd
#
#
#  scan-6-odd-2
# 	IS INDEX HEADER: 0 227 	##                        I           N
# possibly misrecognised repeat symbol: 171 eee
# possibly misrecognised repeat symbol: 122 aki
# possibly misrecognised repeat symbol: 149 mn
# possibly misrecognised repeat symbol: 143 mn
# DEVIATING LINE: 219 [169, 118, 165, 165, 219, 164, 162, 286, 142] Om om ordes of ’s Landts reghten [ullen
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 286 [165, 219, 164, 162, 286, 142, 287, 157, 281] advis op bet verfoerk van Rees, en
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 287 [164, 162, 286, 142, 287, 157, 281, 135, 146] advis en refolutie, rakende de Bedien-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 281 [286, 142, 287, 157, 281, 135, 146, 280, 154] van Alblaferdam aangeftelt tot Ont-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 280 [157, 281, 135, 146, 280, 154, 152, 277, 149] Refolutie van den drie en twistighften
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 277 [146, 280, 154, 152, 277, 149, 150, 150, 271] om interpretatie wegens Manufattu-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 271 [277, 149, 150, 150, 271, 149, 152, 102, 150]  geauthorifeert boven [eekere premie,
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 266 [150, 81, 147, 146, 266, 139, 146, 272, 147] gelaft het grootfte Schip tot de Equi-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 272 [146, 266, 139, 146, 272, 147, 270, 143, 269] te berichten op het ver[oeck van Rogh,
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 270 [139, 146, 272, 147, 270, 143, 269, 145, 268] bericht op de Memorie van Grijs, te
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 269 [272, 147, 270, 143, 269, 145, 268, 146, 270] rakende het heffen van het middel
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 268 [270, 143, 269, 145, 268, 146, 270, 145, 144] Lijft van het Rundvee, te examine-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 270 [269, 145, 268, 146, 270, 145, 144, 137, 267] notificerende , dat het haar ondoenlijck
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 267 [270, 145, 144, 137, 267, 142, 148, 98, 139] advis op het verfoeck van Schrijvers,
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 266 [142, 148, 98, 139, 266, 140, 91, 142, 262] Commiie voor de Heer van Laar
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 262 [266, 140, 91, 142, 262, 141, 263, 139, 92] commijfie voor den Heere van Haaren
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 263 [91, 142, 262, 141, 263, 139, 92, 141] bericht op de Memorie van den Mar-
# avg_repeat_symbol_length: 146
# 0 108 -37 start 	     reghten van het Zout op den ouden voet fe
# 1 169 29 continue 	       betalen.  BIS.
# 2 118 -25 start 	     —aange[fchreven  de  Refòlutie  van den
# 3 165 19 continue 	       den drie en twintighften  by provifie niet te
# 	PAGE_REFS: [822] 	CURR LEMMA: Admiraliteyten
# 4 165 20 continue_stop 	       executeren. 822.
# 5 118 -31 start 	  —— Om  om ordes of ’s Landts reghten [ullen
# 6 164 19 continue 	       vorderen van Goederen komende uyt of gaan-
# 	PAGE_REFS: [827] 	CURR LEMMA: Admiraliteyten
# 7 162 12 continue_stop 	       de na Zeelandt, te examineeren.   827.
# 8 142 -4 start 	     —— advis op bet verfoerk van Rees,  en
# 	PAGE_REFS: [841] 	CURR LEMMA: Admiraliteyten
# 9 142 -1 start_stop 	      afgewefen.   841.
# 10 135 -11 start 	     —— advis en refolutie, rakende de Bedien-
# 	PAGE_REFS: [850] 	CURR LEMMA: Admiraliteyten
# 11 157 14 continue_stop 	       den van het Zegel.   850.
# 12 135 -7 start 	     —— van Alblaferdam aangeftelt tot Ont-
# 13 135 -8 start 	     fanger van de Convoyen en Licenten te Eyndt-
# 14 146 3 continue 	      hoven.  85 s
# 15 135 -10 start 	     —— Refolutie van den drie en twistighften
# 16 154 10 continue 	      Oftober nogh voor drie weecken te [urcheren.
# 	PAGE_REFS: [889] 	CURR LEMMA: Admiraliteyten
# 17 152 6 continue_stop 	      889.
# 18 146 3 continue 	     —— om  interpretatie wegens  Manufattu-
# 19 149 6 continue 	      ven   te  examineeren   en  Naaldens  ende
# 20 150 5 continue 	      Meen onder gemaakt Yerwerck begreepen.
# 	PAGE_REFS: [919] 	CURR LEMMA: Admiraliteyten
# 21 150 11 continue_stop 	      919.
# 22 105 -34 start 	     —— geauthorifeert  boven [eekere premie,
# 23 149 17 continue 	      impuniteyt aan de Medeplightige te beloven.
# 	PAGE_REFS: [936] 	CURR LEMMA: Admiraliteyten
# 24 152 21 continue_stop 	      936.
# HAS LEMMA: Admiraliteyt tot Amfterdam Oatfanger
# 25 102 -29 start 	    Admiraliteyt  tot  Amfterdam     Oatfanger
# 26 150 25 continue 	      Groeninx gelaft Jcekere penningen te betalen.
# 27 81 -48 start 	   —— te berichten op het ver(oek van Schry-
# 28 147 18 continue 	      ver wegens premie van veroverde Turck[che
# 29 146 19 continue 	      Rovers.   $9.
# 30 100 -32 start 	    —— gelaft het grootfte Schip tot de Equi-
# 31 139 8 continue 	      pagie, te  verftercken  met  vijftigh  koppen.
# 	PAGE_REFS: [75] 	CURR LEMMA: Admiraliteyt
# 32 146 8 continue_stop 	      75:
# 33 139 1 continue 	    —— te berichten op het ver[oeck van Rogh,
# 	PAGE_REFS: [79] 	CURR LEMMA: Admiraliteyt
# 34 147 10 continue_stop 	      cum Íuis.   79.
# 35 139 -3 start 	    —— bericht op de Memorie van Grijs, te
# 	PAGE_REFS: [81] 	CURR LEMMA: Admiraliteyt
# 36 143 0 start_stop 	      examineeren.  81,
# 37 143 1 continue 	    —— rakende  het  heffen  van  het middel
# 	PAGE_REFS: [94] 	CURR LEMMA: Admiraliteyt
# 38 145 2 continue_stop 	      van het kleyn Zegel, te examineeren.   94.
# 39 143 1 continue 	    —— Lijft van het Rundvee, te examine-
# 40 146 4 continue 	      ren.  O1.
# 41 137 0 start 	    —— notificerende, dat het haar ondoenlijck
# 42 145 8 continue 	      is   haar Hoogh Mog. te berichten of vol-
# 43 144 6 continue 	      gens de Placaten te procederen tegens Schip-
# 	PAGE_REFS: [138] 	CURR LEMMA: Admiraliteyt
# 44 137 4 continue_stop 	      per Statema.   138.
# 45 101 -31 start 	    —— advis op het verfoeck van Schrijvers,
# 46 142 14 continue 	      Provintien aangenomen haar  te verklaaren.
# 	PAGE_REFS: [45] 	CURR LEMMA: Admiraliteyt
# 47 148 21 continue_stop 	      45.
# 48 98 -23 start 	    ——  Toeftant van de Schepen  onder haar
# 	PAGE_REFS: [237] 	CURR LEMMA: Admiraliteyt
# 49 139 17 continue_stop 	      effort.   237.
# 50 100 -21 start 	    —— Commiie  voor  de  Heer  van  Laar
# 	PAGE_REFS: [277] 	CURR LEMMA: Admiraliteyt
# 51 140 19 continue_stop 	      wegens Overy(el.   277.
# 52 91 -25 start 	   ——  confideratien  op  het  kleyn  Zegel.
# 	PAGE_REFS: [299] 	CURR LEMMA: Admiraliteyt
# 53 142 22 continue_stop 	      299.
# 54 96 -19 start 	    —— commijfie voor den Heere van Haaren
# 	PAGE_REFS: [329] 	CURR LEMMA: Admiraliteyt
# 55 141 22 continue_stop 	      wegens Vrieslandt.   329.
# 56 97 -20 start 	    —— bericht op de Memorie van den Mar-
# 	PAGE_REFS: [450] 	CURR LEMMA: Admiraliteyt
# 57 139 18 continue_stop 	      quis de Fenelon.  450.
# 58 92 -25 start 	   —— de Bruyn aangeftelt tot Capiteyn  ter
# 	PAGE_REFS: [454] 	CURR LEMMA: Admiraliteyt
# 59 141 19 continue_stop 	      Zee.   454.
#
#
#  scan-6-odd-3
# 	IS INDEX HEADER: 0 204 	##           E           Xx.
# possibly misrecognised repeat symbol: 141 mn
# possibly misrecognised repeat symbol: 125 ee
# DEVIATING LINE: 207 [207, 81, 80, 204, 81] fe advifeeren op de Mijfive van de
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 204 [207, 81, 80, 204, 81, 203, 79, 82] gdvis dien aangaande by Hollandt
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 203 [81, 80, 204, 81, 203, 79, 82, 201, 82] notificeerende dat het voorfchreevé
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 201 [81, 203, 79, 82, 201, 82, 204, 78, 200] gakende bet Schip de Jenny Galley 4
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 204 [79, 82, 201, 82, 204, 78, 200, 81, 206] aangefchreven de Jenny Galley te Tas
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 200 [201, 82, 204, 78, 200, 81, 206, 86, 205] propofitie vm twee Commien Generaal
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 206 [204, 78, 200, 81, 206, 86, 205, 84, 214] Buys en vander Meulen aangeftelt tot
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 205 [200, 81, 206, 86, 205, 84, 214, 87, 212] commijie wegens Hollandt voor den
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 214 [206, 86, 205, 84, 214, 87, 212, 88, 45] Lijfte van inkoomende Rundvee en
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 212 [205, 84, 214, 87, 212, 88, 45, 90, 89] Torck, belofte op den eedt ten aaR-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 215 [45, 90, 89, 91, 215, 45, 92, 93, 94] bericht ‘en geaccordeerf. 916.
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 216 [93, 94, 47, 94, 216, 93, 218, 98, 221] vrapport , rakende de Vaart van Böf-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 218 [47, 94, 216, 93, 218, 98, 221, 99, 103] rakende de adminiftratie van het klejn
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 221 [216, 93, 218, 98, 221, 99, 103, 225, 101] Ramhorft aangefteldt. tot Ontfanger
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 225 [98, 221, 99, 103, 225, 101, 224, 100, 228] Golts aangefteldt tot Ontfanger vam
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 224 [99, 103, 225, 101, 224, 100, 228, 108, 107] wegens aangevinge van Rundvee én
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 228 [225, 101, 224, 100, 228, 108, 107, 226, 106] Greveftein aangefteldt tot Contrerol-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 226 [100, 228, 108, 107, 226, 106, 228, 106, 238] commijfie wegens Hollandt voor de
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 228 [108, 107, 226, 106, 228, 106, 238, 37, 59] iten voor de Heer Aylua wegens Pries-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 238 [226, 106, 228, 106, 238, 37, 59, 110, 67] Akerlaken aangefteldt zot Capiteyn,
# avg_repeat_symbol_length: 110
# 0 80 0 start 	     —— fe advifeeren  op  de Mijfive  van de
# 1 81 1 continue 	     Hochepied wegens [ceker Engeljch  Schip de
# 	PAGE_REFS: [461] 	CURR LEMMA: Admiraliteyt
# 2 80 1 continue_stop 	     Fenny Galley.   461.
# 3 79 -1 start 	     —— gdvis dien  aangaande   by Hollandt
# 	PAGE_REFS: [486] 	CURR LEMMA: Admiraliteyt
# 4 81 2 continue_stop 	     overgenomen.  486.
# 5 79 -1 start 	     —— notificeerende   dat  het  voorfchreevé
# HAS LEMMA: Schip aldaar binnen gevallen was zen ordres.
# LEMMA: Schip aldaar binnen gevallen was zen ordres
# 6 79 0 start 	     Schip aldaar binnen gevallen was zen ordres.
# 	PAGE_REFS: [525] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 7 82 3 continue_stop 	     525:
# 8 78 -1 start 	     —— gakende  bet Schip de Jenny Galley4
# 	PAGE_REFS: [587] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 9 82 3 continue_stop 	     te examineeren.   587:
# 10 78 -1 start 	     —— aangefchreven de Jenny Galley te Tas
# 	PAGE_REFS: [591] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 11 78 -2 start_stop 	     ten loen.   591.
# 12 78 -2 start 	     —— propofitie vm twee Commien Generaal
# 	PAGE_REFS: [637] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 13 81 1 continue_stop 	     aan te tellen, geaccordeert.  637.
# 14 78 -2 start 	     —— Buys en vander Meulen aangeftelt tot
# 	PAGE_REFS: [639] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 15 86 5 continue_stop 	     Commifen Generaal.  639.
# 16 81 -1 start 	     —— commijie  wegens  Hollandt voor den
# 	PAGE_REFS: [716] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 17 84 1 continue_stop 	     Heer vander Waeyen.   716.
# 18 84 5 continue 	      —— Lijfte  van  inkoomende  Rundvee  en
# 	PAGE_REFS: [786] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 19 87 7 continue_stop 	     Varckens.  786,
# 20 82 1 continue 	      —— Torck, belofte op  den  eedt ten aaR-
# 	PAGE_REFS: [896] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 21 88 6 continue_stop 	     vangh van fijn bedieninge gedaan.  896.
# 22 45 -37 start 	   —_      #6 advifteren op de Miffive van Aar (èn
# 23 90 12 continue 	     van Sommelsdijck om feeker hernomen Schip
# 24 89 11 continue 	     en Laadinge  tot Cadix te mogen verkoöpen.
# 	PAGE_REFS: [908] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 25 91 12 continue_stop 	      908.
# 	PAGE_REFS: [916] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 26 85 5 continue_stop 	      —— bericht ‘en geaccordeerf.  916.
# HAS LEMMA: Admiraliteyt in het Noorder Quartier ; amf=
# LEMMA: Admiraliteyt in het Noorder Quartier
# 27 45 -35 start 	   Admiraliteyt in het Noorder Quartier; amf=
# 28 92 11 continue 	      woordt  op  de Miffive  van vanden Boch,
# 29 93 13 continue 	      rakende  de Vaart van  Borkom op Áltena.
# 	PAGE_REFS: [49] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 30 94 13 continue_stop 	      49:
# 31 47 -34 start 	   —— Lift van inkomend Rundvee en Vat-
# 	PAGE_REFS: [61] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 32 94 7 continue_stop 	      kens.  61.
# 33 86 -1 start 	      —— vrapport, rakende de Vaart van Böf-
# 	PAGE_REFS: [67] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 34 93 5 continue_stop 	      kom op Altena.  67.
# 35 88 -1 start 	      —— rakende de adminiftratie van het klejn
# 	PAGE_REFS: [131] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 36 98 4 continue_stop 	      Zegel, te examineeren.  131.
# 37 93 -2 start 	      —— Ramhorft  aangefteldt. tot  Ontfanger
# 38 99 3 continue 	      van  de  Convoyen  en  Licenten tot  Ha{el.
# 	PAGE_REFS: [169] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 39 103 6 continue_stop 	      169.
# 40 98 -1 start 	      —— Golts  aangefteldt  tot Ontfanger vam
# 	PAGE_REFS: [169] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 41 101 1 continue_stop 	      de Convoyen en Licenten tot Swolle.   169.
# 42 99 -2 start 	      —— wegens  aangevinge  van Rundvee én
# 	PAGE_REFS: [178] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# HAS LEMMA: Varckens. 178.
# LEMMA: Varckens
# 43 100 -1 start_stop 	      Varckens.   178.
# 44 100 -2 start 	      —— Greveftein  aangefteldt  tot  Contrerol-
# 45 108 6 continue 	      leur van de Comvoyen en Licenten tot Ha(fel.
# 	PAGE_REFS: [256] 	CURR LEMMA: Varckens
# 46 107 5 continue_stop 	      256.
# 47 100 -3 start 	      —— commijfie  wegens  Hollandt  voor  de
# 	PAGE_REFS: [304] 	CURR LEMMA: Varckens
# 48 106 10 continue_stop 	      Heer Jelius.   304.
# 49 98 6 continue 	      —— iten voor de Heer Aylua wegens Pries-
# 	PAGE_REFS: [310] 	CURR LEMMA: Varckens
# 50 106 14 continue_stop 	      landt.   310.
# 51 108 21 continue 	 —— Akerlaken  aangefteldt  zot  Capiteyn,
# 52 37 -52 start 	   uw  35
# 53 59 -33 start 	    and    Houttuyn aangefteldt  tot Capiteya op
# 	PAGE_REFS: [361] 	CURR LEMMA: Varckens
# 54 110 24 continue_stop 	       den Uytlegger van het Collegie.   361.
# 55 67 -23 start 	    —— de  Zee  aangefteldt  tot  Contrerolleus
# 56 111 27 continue 	       van de Convoyen en Licenten t0t Medenblick.
# 	PAGE_REFS: [80] 	CURR LEMMA: Varckens
# 57 137 47 continue_stop 	        80.
# 58 47 -48 start 	   ——   van Schaak aangefteldt  tot Capiteyn.
# 	PAGE_REFS: [92] 	CURR LEMMA: Varckens
# 59 140 48 continue_stop 	        92.
# 60 54 -43 start 	    pa       wegens fraudes van  de Middelen tof
#
#
#  scan-7-even
#
#
#  scan-7-even-0
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 240 	##                      I           N.
# possibly misrecognised repeat symbol: 164 mn
# possibly misrecognised repeat symbol: 152 me
# DEVIATING LINE: 234 [103, 100, 54, 104, 234, 226, 99, 52, 99] antwoordt van Overyfel. 456.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 226 [100, 54, 104, 234, 226, 99, 52, 99, 236] antwoordt op de Memorie van den
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 236 [226, 99, 52, 99, 236, 104, 228, 107, 231] te berichten op de klaghtem. van de
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 228 [52, 99, 236, 104, 228, 107, 231, 113, 234] rakende de meetinge der Koopvaardye
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 231 [236, 104, 228, 107, 231, 113, 234, 108, 109] vemarqgues op ‘het nieuw Placaat cn
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 234 [228, 107, 231, 113, 234, 108, 109, 231, 110] om het Schip het Wapen van Alck-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 231 [113, 234, 108, 109, 231, 110, 52, 111, 62] rapport en refolutie-op haar remarques
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 238 [62, 112, 100, 116, 238, 105, 110, 111, 230] #6 advifeeren op het verfoeck van Re-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 230 [238, 105, 110, 111, 230, 236, 112, 241, 112] gereet Schip tot het E/quadre. 305.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 236 [105, 110, 111, 230, 236, 112, 241, 112, 297] Stokke aangefteldt tot Capiteyn.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 241 [111, 230, 236, 112, 241, 112, 297, 103, 113] van Hoorn aangefteldt ‘als Commis
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 297 [236, 112, 241, 112, 297, 103, 113, 234, 112] berichten wegens klaghten van ‘de
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 234 [112, 297, 103, 113, 234, 112, 66, 113, 236]  aangefchreven met moderatie te proce-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 236 [234, 112, 66, 113, 236, 114, 46, 114, 113] aangefchreven dat haar Hoogh Mog.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 244 [114, 46, 114, 113, 244, 114, 139, 234, 113] Slicher en Backer belofte ‘op den eedt
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 234 [113, 244, 114, 139, 234, 113, 232, 108, 63] item van Na(auw, Heér van Drie-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 232 [114, 139, 234, 113, 232, 108, 63, 116, 241] gepermitteert de oude Lijfte nogh vobn
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 241 [232, 108, 63, 116, 241, 107, 67, 115, 115] met de voor[z verklaringe by provifie
# avg_repeat_symbol_length: 149
# 0 103 18 continue 	      OveryjJel  Staaten verfoght  woorfieninge te
# 	PAGE_REFS: [414] 	CURR LEMMA: Varckens
# 1 100 20 continue_stop 	      doen.  414.
# 2 54 -29 start 	   — Lifte  van  inkoomende  Rundvee  en
# 	PAGE_REFS: [440, 688] 	CURR LEMMA: Varckens
# 3 104 25 continue_stop 	      Varkens.   440. 688.
# 	PAGE_REFS: [456] 	CURR LEMMA: Varckens
# 4 65 -16 start_stop 	     —— antwoordt van Overyfel.  456.
# 5 57 -20 start 	    —— antwoordt  op  de  Memorie  van den
# 	PAGE_REFS: [487] 	CURR LEMMA: Varckens
# 6 99 22 continue_stop 	      Marquis de Fenclon.  487.
# 7 52 -26 start 	   ——_— tegens het Schip van Cornelis Otter
# 	PAGE_REFS: [616] 	CURR LEMMA: Varckens
# 8 99 21 continue_stop 	      te examineeren.  616.
# 9 67 -16 start 	     —— te  berichten  op  de klaghtem. van de
# 	PAGE_REFS: [760] 	CURR LEMMA: Varckens
# 10 104 15 continue_stop 	      Admmiraliteyt op de Maze.  760.
# 11 59 -31 start 	    —— rakende de meetinge der Koopvaardye
# 	PAGE_REFS: [772] 	CURR LEMMA: Varckens
# 12 107 11 continue_stop 	      Schepen, te examineeren.  772.
# 13 104 7 continue 	    —— vemarqgues  op  ‘het nieuw Placaat cn
# 	PAGE_REFS: [807] 	CURR LEMMA: Varckens
# 14 113 16 continue_stop 	      Lijfte.   807.
# 15 107 10 continue 	     —— om het Schip het Wapen van Alck-
# 16 108 12 continue 	      maar te mogen verkoopen, by Hollandt over-
# 	PAGE_REFS: [808] 	CURR LEMMA: Varckens
# 17 109 12 continue_stop 	      genoomen.   808.
# 18 62 -30 start 	    —— rapport en refolutie-op haar remarques
# 	PAGE_REFS: [812] 	CURR LEMMA: Varckens
# 19 110 18 continue_stop 	      op het nieuw Placaat en Lijfte.   812.
# 20 52 -39 start 	   ——— gepermitteert  het  Schip bet  Wapen
# 	PAGE_REFS: [901] 	CURR LEMMA: Varckens
# 21 111 19 continue_stop 	      van Alckmaar te mogen verkoopen,  901.
# HAS LEMMA: Admiralteyt in Zeelandt ‘inftantien van
# 22 62 -26 start 	    Admiralteyt  in  Zeelandt   ‘inftantien  van
# 23 112 19 continue 	      Kooplieden.  tot  den  uytwoer  van  goude en
# 24 100 7 continue 	      Jilvere  Specien, ‘de.  Tetroafta  ‘ma  te fen.
# 	PAGE_REFS: [167] 	CURR LEMMA: Admiralteyt
# 25 116 17 continue_stop 	       167.
# 26 69 -29 start 	     —— #6 advifeeren op het verfoeck van Re-
# 27 105 2 continue 	      genten van  Aardenbergh  om  ‘exemptie van
# 28 110 7 continue 	      bet Placaat wegens belaftinge wan OJen en
# 	PAGE_REFS: [296] 	CURR LEMMA: Admiralteyt
# 29 111 7 continue_stop 	      Koeyen,   296.
# 	PAGE_REFS: [305] 	CURR LEMMA: Admiralteyt
# 30 105 2 continue_stop 	    —— gereet Schip tot het E/quadre. 305.
# 31 105 -5 start 	     —— Stokke  aangefteldt  tot  Capiteyn.
# 	PAGE_REFS: [491] 	CURR LEMMA: Admiralteyt
# 32 112 3 continue_stop 	      491.
# 33 103 -7 start 	     —— van  Hoorn  aangefteldt  ‘als  Commis
# 	PAGE_REFS: [658] 	CURR LEMMA: Admiralteyt
# 34 112 7 continue_stop 	      Generaal.  658.
# 35 128 22 continue 	        —— berichten wegens  klaghten van ‘de
# 36 103 2 continue 	      Admiraliteyt op de Maze wegens feytelijck-
# 37 113 12 continue 	      beden te Lillo.   724   \
# 38 66 -31 start 	      —— aangefchreven met moderatie te proce-
# 39 112 14 continue 	      deren tegens Schipper Schollaart.   741."
# 40 66 -22 start 	    —  grdre  om  het  nieuwe  Placaat  en
# 	PAGE_REFS: [743] 	CURR LEMMA: Admiralteyt
# 41 113 23 continue_stop 	       Lijfte niet te executeren en refolttie. 743.
# 42 67 -23 start 	     —— aangefchreven dat haar Hoogh Mog.
# 	PAGE_REFS: [792, 802] 	CURR LEMMA: Admiralteyt
# 43 114 23 continue_stop 	       de excufe niet aannemen.   792. 802.
# 44 46 -45 start 	   —— bericht op de klaghtén ‘van de Admi-
# 45 114 15 continue 	       raliteyt op de Maze, rakende de Bedienden
# 	PAGE_REFS: [815] 	CURR LEMMA: Admiralteyt
# 46 113 19 continue_stop 	      te Lillo.   815.
# 47 75 -24 start 	     —— Slicher en Backer belofte ‘op den eedt
# 48 114 21 continue 	       To  aanvangh van haar bedieninge gedaan.
# 	PAGE_REFS: [17] 	CURR LEMMA: Admiralteyt
# 49 139 39 continue_stop 	        17.
# 50 65 -29 start 	     —— item van Na(auw, Heér van Drie-
# 	PAGE_REFS: [827] 	CURR LEMMA: Admiralteyt
# 51 113 18 continue_stop 	      bergen.   827.
# 52 63 -31 start 	    —— gepermitteert de oude Lijfte nogh vobn
# 	PAGE_REFS: [829] 	CURR LEMMA: Admiralteyt
# 53 108 14 continue_stop 	      drie weecken te continueren.   829.
# 54 63 -23 start 	    —— gepermitteert de gerequireerde verkla-
# 	PAGE_REFS: [956] 	CURR LEMMA: Admiralteyt
# 55 116 25 continue_stop 	       vinge Jchriftelijck te mogen. doen.   956.
# 56 72 -19 start 	     —— met de voor[z verklaringe by provifie
# 	PAGE_REFS: [966] 	CURR LEMMA: Admiralteyt
# 57 107 12 continue_stop 	      genoegen genomen.  966.
# HAS LEMMA: Admiraliteyt in Vrieslandt, :advis ‘op de Me-
# LEMMA: Admiraliteyt in Vrieslandt
# 58 67 -26 start 	    Admiraliteyt in Vrieslandt, :advis ‘op de Me-
# 59 115 17 continue 	       morie van Greis    raakende  het  opreghten
# 60 115 20 continue 	       van twee  Vuurbaacken op  de Kuften van
#
#
#  scan-7-even-1
# 	IS INDEX HEADER: 0 246 	##            E           Xx.
# possibly misrecognised repeat symbol: 147 Ea
# possibly misrecognised repeat symbol: 151 kee
# DEVIATING LINE: 227 [100, 45, 87, 97, 227, 100, 93, 100, 108] gdvis op de Mifive van vanden
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 226 [100, 93, 100, 108, 226, 108, 154, 101, 107] akende de adminiftratie van ’t kleyn
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 230 [108, 154, 101, 107, 230, 108, 111, 111, 110] deduêtie van het recht waar op funm-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 235 [108, 111, 111, 110, 235, 112, 259, 115, 233] Commifie wegens Utrecht woor den
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 259 [111, 110, 235, 112, 259, 115, 233, 105, 231] Burmania aangefteldt 101 Gapiteyn.
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 233 [235, 112, 259, 115, 233, 105, 231, 121, 66] Commmijfie wegens Vrieslandt voor Pe-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 231 [259, 115, 233, 105, 231, 121, 66, 65, 118] item wegens Vrieslandt voor Bìncke
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 237 [65, 118, 117, 119, 237, 121, 242, 122, 239] Comimijie voor de Heer Gruys wegens
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 242 [117, 119, 237, 121, 242, 122, 239, 119, 246] Mifive in [aveur van Bovwmans.,
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 239 [237, 121, 242, 122, 239, 119, 246, 123, 120] gepermitteert te accorderen ‘de vryen
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 246 [242, 122, 239, 119, 246, 123, 120, 242, 123] te berichten op de klaghten van-de
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 242 [119, 246, 123, 120, 242, 123, 127, 249, 128] bericht op de Memorie van Meynerts-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 249 [120, 242, 123, 127, 249, 128, 254, 121, 250] [Lijfte van bet inkomende Rundtvee,
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 254 [123, 127, 249, 128, 254, 121, 250, 131, 99] Commijfie voor de Heer Schultens we-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 250 [249, 128, 254, 121, 250, 131, 99, 132, 160] gelaft de aangehaalde fucken Noote-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 256 [132, 160, 133, 134, 256, 135, 251, 136]  Tyfte van ‘de inkomende Rundvee en
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 251 [133, 134, 256, 135, 251, 136] op Haar ‘geweccordeerde fb fidie “van
# avg_repeat_symbol_length: 115
# 0 93 9 continue 	      Noorweegen ‚  by  Hollandt  overgenoomen.
# 	PAGE_REFS: [1540] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 1 100 15 continue_stop 	      1540.
# 2 45 -42 start 	   —— antwoordt op baar Hoogh Mog. -Re-
# 3 87 -1 start 	     folutie werens Lijfte van Rundveeen Varc-
# 	PAGE_REFS: [150] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 4 97 8 continue_stop 	      kens   te examineeren. * 150.
# 5 92 1 continue 	     —— gdvis  op  de  Mifive  van  vanden
# 6 100 10 continue 	      Bofch,  rakende de aangroey van de Sthip-
# 7 93 -4 start 	      pers  van  het Eylandt Borkum. op   Akuna
# 8 100 -5 start 	      en Hamburgh    by  Hollandt overgenomen.
# 	PAGE_REFS: [150] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 9 108 3 continue_stop 	      150.
# 10 93 -14 start 	     —— akende de adminiftratie van ’t kleyn
# 11 108 1 continue 	      Zegel, te examineeren.   15T,
# 12 154 46 continue 	         LD  rapport wegens Rundvee ‘en Varckens,
# 13 101 -9 start 	      geauthorifeert [eekere  pie
# 14 107 -3 start 	      bliceeren en ter executie te leggen.
# 15 101 -11 start 	      —— deduêtie van het recht waar op funm-
# 16 108 -4 start 	      doeren hare pretenfien ‘ende grieven tot het
# 17 111 4 continue 	       beffen van  de Convoyen  en Licentemop de
# 18 111 1 continue 	       Middelgronden en aan den Abt, te exami-
# 	PAGE_REFS: [178] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 19 110 -1 start_stop 	       ueeren.   178.
# 20 108 -2 start 	      —— Commifie wegens  Utrecht woor den
# 	PAGE_REFS: [236] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 21 112 2 continue_stop 	       Heer de Leeuw.  236.
# 22 124 16 continue 	       —— Burmania  aangefteldt 101 Gapiteyn.
# 	PAGE_REFS: [258] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 23 115 6 continue_stop 	       258.
# 24 98 -7 start 	      —— Commmijfie wegens Vrieslandt voor Pe-
# 	PAGE_REFS: [76] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 25 105 5 continue_stop 	      gelin van Claarbergen.   76.
# 26 96 -4 start 	      —— item  wegens Vrieslandt voor Bìncke
# 	PAGE_REFS: [280] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 27 121 21 continue_stop 	       Symons.   280.
# 28 66 -34 start 	    — item wegens Frieslandt voor Rengers.
# 29 65 -36 start 	    —— te berichten op de klaghtenvan Mey-
# 30 118 16 continue 	       aertshagen, nopenie bet aanhouden van vier
# 31 117 12 continue 	       hondert vijf en dertich ftucken Nooteboomen
# 	PAGE_REFS: [313] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 32 119 14 continue_stop 	       Hout.   313.
# 33 102 -9 start 	      —— Comimijie voor de Heer Gruys wegens
# 	PAGE_REFS: [317] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 34 121 4 continue_stop 	       Stadt en Lande.   317.
# 35 117 0 start 	      —— Mifive  in [aveur van Bovwmans.,
# 	PAGE_REFS: [346] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 36 122 5 continue_stop 	       de retroafta na te fien.  346.
# 37 119 1 continue 	      —— gepermitteert  te accorderen ‘de vryen
# 	PAGE_REFS: [346] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 38 119 0 start_stop 	       uyt- en invoer van Paarden.   346.
# 39 119 -1 start 	      —— te berichten  op  de klaghten van-de
# 40 123 2 continue 	       Staaten ’s Landts van Drenthe wegens’exe-
# 	PAGE_REFS: [384] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 41 120 -1 start_stop 	       cutien te Rooswinckel.   384.
# 42 119 -3 start 	      —— bericht op de Memorie van Meynerts-
# 43 123 1 continue 	       hagen, rakende bet Nooteboomen Hout €
# 	PAGE_REFS: [399] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 44 127 5 continue_stop 	       re[olutie.  399.
# 45 120 -1 start 	      —— [Lijfte van bet inkomende Rundtvee,
# 	PAGE_REFS: [399] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 46 128 6 continue_stop 	       te oxamineeren.   399.
# 47 119 -1 start 	       —— Commijfie voor de Heer Schultens we-
# 48 121 0 start 	       gens Stadt ‘en Lande.  437
# 49 115 -10 start 	      —— gelaft de aangehaalde fucken Noote-
# 	PAGE_REFS: [481] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 50 131 5 continue_stop 	        boomen Hout te ontflaan.  481.
# 51 99 -28 start 	      _—       de Haan aangefteldt als ‘Contrerolleur
# 52 132 4 continue 	        van de Convoyen ‘en Licenten in :de Lemmer.
# 	PAGE_REFS: [37] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 53 160 30 continue_stop 	         37.
# 54 133 1 continue 	        ee    rakende de adminiftreatie van ’ttleyn
# 	PAGE_REFS: [667] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 55 134 2 continue_stop 	        Zegel, te examineren.   667.
# 56 132 -4 start 	 —— Tyfte van ‘de inkomende Rundvee en
# 	PAGE_REFS: [667] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# HAS LEMMA: Varckens. 667.
# LEMMA: Varckens
# 57 135 -2 start_stop 	        Varckens.  667.
# 58 133 0 start 	       —— op Haar ‘geweccordeerde fb fidie “van
# 59 136 2 continue 	        vyf en dertigh duy/ent guldens “sjaarsyPro-
#
#
#  scan-7-odd
#
#
#  scan-7-odd-2
# 	IS INDEX HEADER: 0 230 	##                        Ï           N
# possibly misrecognised repeat symbol: 204 mn
# DEVIATING LINE: 235 [111, 64, 110, 109, 235, 109, 231, 107, 109] Commijie wegens Vrieslandt voor den
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 231 [110, 109, 235, 109, 231, 107, 109, 233, 110] bericht op de klaghten van de Admi-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 233 [109, 231, 107, 109, 233, 110, 111, 233, 108] advis op het verfoeck van Beugholt,
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 233 [109, 233, 110, 111, 233, 108, 231, 109, 61] advis wegens Reglement voor de Yck-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 231 [110, 111, 233, 108, 231, 109, 61, 59, 107] rapport wegens Bedienden van ’t kleyn
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 107 [231, 109, 61, 59, 107, 108, 234, 0, 107] de fake van den Prince van Hornes tegens
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 108 [109, 61, 59, 107, 108, 234, 0, 107, 232] la Motte. 15.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 234 [61, 59, 107, 108, 234, 0, 107, 232, 231] advis en refolutie. 127.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 107 [107, 108, 234, 0, 107, 232, 231, 103, 234] Benthem en de Prez. 400.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 232 [108, 234, 0, 107, 232, 231, 103, 234, 102] advis dien aangaande. 513.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 231 [234, 0, 107, 232, 231, 103, 234, 102, 234] fe berichten op de Requcfte van Rey:
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 103 [0, 107, 232, 231, 103, 234, 102, 234, 108] gersman. 617.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 234 [107, 232, 231, 103, 234, 102, 234, 108, 246] Regquefie van Collard ter handen, ge-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 234 [231, 103, 234, 102, 234, 108, 246, 109, 61] Heuft aangefteldt tot ’s Landts Ad-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 246 [234, 102, 234, 108, 246, 109, 61, 64, 107] gdvis in de [aaken van Collard.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 232 [61, 64, 107, 109, 232, 111, 232, 111, 111] belangh van die van Woatervliedt niet
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 232 [107, 109, 232, 111, 232, 111, 111, 113, 64] Raadt van Flaanderen aange[chreven
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 238 [113, 64, 113, 113, 238, 110, 114, 247, 104] te berichten op het verfoeck van Re-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 247 [113, 238, 110, 114, 247, 104, 116, 240, 117] item op het verfoeck van de Magi-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 240 [114, 247, 104, 116, 240, 117, 70, 118, 119] af te waghten fijn nader bericht om-
# avg_repeat_symbol_length: 116
# 0 112 11 continue 	       vincien  aangenoomen  haar  te  verklaaren.
# 	PAGE_REFS: [675] 	CURR LEMMA: Varckens
# 1 111 11 continue_stop 	       675.
# 2 64 -38 start 	    pmne  Gecommitteerden geadmitteert  op  de
# 3 110 8 continue 	       beloften als nu te doen in plaats van op den
# 4 109 6 continue 	      vierden Oftober 685.     ee
# 5 99 -3 start 	      —— Commijie wegens Vrieslandt voor den
# 	PAGE_REFS: [787] 	CURR LEMMA: Varckens
# 6 109 7 continue_stop 	      Heere Lyclama a Nyeholt.   787.
# 7 107 0 start 	      —— bericht op de klaghten van de Admi-
# 8 107 0 start 	      valiteyt op de Maze over den Convoymeefter
# 	PAGE_REFS: [810] 	CURR LEMMA: Varckens
# 9 109 3 continue_stop 	      tot Swolle  te examinceren.   810.
# 10 107 0 start 	      —— advis op het verfoeck van Beugholt,
# 11 110 5 continue 	       Ba(ccour  en  Vechoven   te  examineren.
# 	PAGE_REFS: [815] 	CURR LEMMA: Varckens
# 12 111 6 continue_stop 	       815.
# 13 97 -3 start 	      —— advis wegens Reglement voor de Yck-
# 	PAGE_REFS: [816] 	CURR LEMMA: Varckens
# 14 108 13 continue_stop 	      meefters, te examineeren.   816.
# 15 95 12 continue 	      —— rapport wegens Bedienden van ’t kleyn
# 	PAGE_REFS: [843] 	CURR LEMMA: Varckens
# 16 109 38 continue_stop 	      Zegel en refolutie.   843.
# HAS LEMMA: Siet verder Zeefaken.
# LEMMA: Siet verder Zeefaken
# 17 61 -8 start 	    Siet verder Zeefaken.
# 18 59 1 continue 	    Advocaten  van het Landt  te advifteren in
# 19 0 -46 start 	      —— de fake van den Prince van Hornes tegens
# 	PAGE_REFS: [15] 	CURR LEMMA: Siet verder Zeefaken
# 20 0 -47 start_stop 	      —— la Motte.   15.
# 	PAGE_REFS: [127] 	CURR LEMMA: Siet verder Zeefaken
# 21 98 53 continue_stop 	      —— advis en refolutie.   127.
# 22 0 -38 start 	 —— 6  advifeeren  op het  difput  tu(chen
# 	PAGE_REFS: [400] 	CURR LEMMA: Siet verder Zeefaken
# 23 0 -43 start_stop 	      —— Benthem en de Prez.  400.
# 	PAGE_REFS: [513] 	CURR LEMMA: Siet verder Zeefaken
# 24 96 42 continue_stop 	      —— advis dien aangaande.   513.
# 25 95 30 continue 	      —— fe berichten op de Requcfte van Rey:
# 	PAGE_REFS: [617] 	CURR LEMMA: Siet verder Zeefaken
# 26 0 -66 start_stop 	      —— gersman.  617.
# 27 102 23 continue 	      —— Regquefie van Collard ter handen, ge-
# 	PAGE_REFS: [860] 	CURR LEMMA: Siet verder Zeefaken
# 28 102 11 continue_stop 	      fteldt.  860.
# 29 98 11 continue 	      —— Heuft aangefteldt tot ’s Landts Ad-
# 	PAGE_REFS: [875] 	CURR LEMMA: Siet verder Zeefaken
# 30 108 25 continue_stop 	      vocaat.   875.
# 31 110 15 continue 	      —— gdvis  in de [aaken  van  Collard.
# 	PAGE_REFS: [916] 	CURR LEMMA: Siet verder Zeefaken
# 32 109 13 continue_stop 	      916.
# 	PAGE_REFS: [526] 	CURR LEMMA: Siet verder Zeefaken
# 33 61 -34 start_stop 	    van Affelen, executoriaal.   526.
# 34 64 -33 start 	    _—       die  van  den Leenbove  van Water-
# 35 107 12 continue 	      vliedt gelaft hun [onder uytftel te ftellen in
# 	PAGE_REFS: [641, 726] 	CURR LEMMA: Siet verder Zeefaken
# 36 109 13 continue_stop 	      Erve van [eeker Leengoedt.  641. 726.
# 37 96 0 start 	      —— belangh van die van Woatervliedt niet
# 	PAGE_REFS: [742] 	CURR LEMMA: Siet verder Zeefaken
# 38 111 9 continue_stop 	       voldoende.  742.
# 39 96 -6 start 	      —— Raadt van Flaanderen aange[chreven
# 40 111 9 continue 	       om by defett van den Leenhove van Water-
# 41 111 8 continue 	       wliedt, en in het voorfz Leengoedt  te doen
# 	PAGE_REFS: [865] 	CURR LEMMA: Siet verder Zeefaken
# 42 113 10 continue_stop 	       erven.  865.
# 43 64 -39 start 	    van Afferden, zotificeerende, dat Reiners mids
# 44 113 8 continue 	       del  hadde gevonden om uyt  cen venter te
# 	PAGE_REFS: [122] 	CURR LEMMA: Siet verder Zeefaken
# 45 113 8 continue_stop 	       [bringen en te ontvlughten.   122,
# 46 102 -2 start 	      —— te berichten op het verfoeck van Re-
# 47 110 5 continue 	       genten  van  Venlo  om [eekere  impoften  te
# 	PAGE_REFS: [604] 	CURR LEMMA: Siet verder Zeefaken
# 48 114 5 continue_stop 	       verhoogen.  604.
# 49 111 1 continue 	      —— item  op het verfoeck van de Magi-
# HAS LEMMA: Araat van Venlo om [urcheantie van [ee-
# 50 104 -1 start 	      Araat van Venlo   om [urcheantie van [ee-
# 	PAGE_REFS: [760] 	CURR LEMMA: Araat
# 51 116 9 continue_stop 	       kere executie.   760.
# 52 104 -4 start 	      —— af te waghten fijn nader bericht om-
# 	PAGE_REFS: [800] 	CURR LEMMA: Araat
# 53 117 14 continue_stop 	       trent de nieuwe belaftinge.  800.
# HAS LEMMA: Akerlaken aangefteldt tot Capiteyn onder het
# 54 70 -34 start 	     Akerlaken aangefteldt  tot Capiteyn  onder het
# 55 118 12 continue 	       Collegie  ter  Admiraliteyt  in  het  Noorder
# 	PAGE_REFS: [352] 	CURR LEMMA: Akerlaken
# 56 119 17 continue_stop 	       Quartier.   352.
# 57 71 -31 start 	     van  Alblaflerdam aangefteldt  tot  Ontfanger
# 58 120 19 continue 	       van  de Convoyen  en Licenten  te Eyndtho-
# 	PAGE_REFS: [852] 	CURR LEMMA: Akerlaken
# 59 123 18 continue_stop 	       852.
# HAS LEMMA: Altona ver/oeck om afiftentie afgewee[en.
# LEMMA: Altona ver/oeck om afiftentie afgewee[en
# 60 77 -26 start 	     Altona   ver/oeck  om  afiftentie   afgewee[en.
# 	PAGE_REFS: [688] 	CURR LEMMA: Altona ver/oeck om afiftentie afgewee[en
# 61 110 10 continue_stop 	       688.
#
#
#  scan-7-odd-3
# 	IS IN TOP MARGIN
# 	IS INDEX HEADER: 1 231 	## )           Ë           x7
# possibly misrecognised repeat symbol: 146 a
# possibly misrecognised repeat symbol: 185 De
# possibly misrecognised repeat symbol: 149 Kei
# DEVIATING LINE: 218 [97, 49, 95, 95, 218, 48, 95, 46, 80] vier maanden verlof. 626,
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 194 [46, 92, 94, 93, 194, 47, 46, 94, 46] eedt van [uyveringe. 197.
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 215 [95, 118, 46, 96, 215, 93, 219, 96, 36] Pafport om de Meubilen en Bágagie
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 219 [46, 96, 215, 93, 219, 96, 36, 86, 217] item om aght Paarden na Hanover
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 217 [219, 96, 36, 86, 217, 214, 77, 53, 168] verwellekomt. 728.
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 214 [96, 36, 86, 217, 214, 77, 53, 168, 167] om cftorte voer fijn Majefteyt en ges
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 168 [217, 214, 77, 53, 168, 167, 101, 52, 52] Divere als Refident en niet geadmit-
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 167 [214, 77, 53, 168, 167, 101, 52, 52, 102] teert, als zijnde een Onderdaan van den
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 225 [107, 108, 13, 107, 225, 108, 62, 129, 106] gepermitteert nogh twee maanden op
# avg_repeat_symbol_length: 156
# HAS LEMMA: Amiot cum fuis ‚ Brieven van voor [chrijs
# 0 48 -28 start 	   Amiot   cum fuis‚ Brieven van voor [chrijs
# 	PAGE_REFS: [693] 	CURR LEMMA: Amiot
# 1 97 26 continue_stop 	      vens aan het Hof van Spaigne.   693.
# HAS LEMMA: Ardes A/aghten over nieuwigheden door den
# 2 49 -19 start 	   Ardes   A/aghten over nieuwigheden  door den
# 3 95 24 continue 	      Monboir  Junckers geïntroduceert  werdendé
# 	PAGE_REFS: [71] 	CURR LEMMA: Ardes
# 4 95 27 continue_stop 	      defelve te berichten.  71.
# 	PAGE_REFS: [626] 	CURR LEMMA: Ardes
# 5 46 -26 start_stop 	   —— vier maanden verlof.  626,
# HAS LEMMA: Arnols, ver/oeck om Goederen in tocht bezees
# LEMMA: Arnols
# 6 48 -24 start 	   Arnols, ver/oeck om Goederen in tocht bezees
# 	PAGE_REFS: [40] 	CURR LEMMA: Arnols
# 7 95 24 continue_stop 	      ten te mogen verkoopen, afgewefen. 40:
# 8 46 -25 start 	   van Afperen, cúm {uis,  Brieven van voors
# 9 80 14 continue 	     Schrijvens aan het Hof van baare Czaarfè
# 	PAGE_REFS: [699, 791] 	CURR LEMMA: Arnols
# 10 95 24 continue_stop 	      Majefteyt.   699. 791.
# 11 45 -31 start 	   van  Aflendelft   Brieven  van voor[chrijvens
# 	PAGE_REFS: [623] 	CURR LEMMA: Arnols
# 12 93 17 continue_stop 	      aan bet Hof van Sweeden.  623.
# 13 46 -30 start 	   d'Averóult   Heer van Guincourt, aangeftelt
# 14 92 20 continue 	      als Drofard van de Stadt en Baronnye van
# 15 94 28 continue 	      Breda, mits ter The[aurie fonrneerende vijf
# 	PAGE_REFS: [186] 	CURR LEMMA: Arnols
# 16 93 21 continue_stop 	      en veertigh duy/ent guldens.   186.
# 	PAGE_REFS: [197] 	CURR LEMMA: Arnols
# 17 46 -21 start_stop 	  —— eedt van [uyveringe.   197.
# 	PAGE_REFS: [880] 	CURR LEMMA: Arnols
# HAS LEMMA: Ayen, Oftroy om ie dijponeeren. 880:
# LEMMA: Ayen
# 18 47 -25 start_stop 	   Ayen, Oftroy om ie dijponeeren.   880:
# HAS LEMMA: Aylua wegens Vrieslandt gecommitteert ter Ads
# 19 46 -29 start 	   Aylua wegens Vrieslandt gecommitteert ter Ads
# 	PAGE_REFS: [310] 	CURR LEMMA: Aylua
# 20 94 24 continue_stop 	      miraliteyt in het Noorder Quartier.  310.
# 21 46 -24 start 	   d’'Ayrolles   Pa/port  om eenige Bagagie van
# 22 95 26 continue 	      Camerik  naar Engelanat  te  tran[pörteeren;
# 	PAGE_REFS: [66] 	CURR LEMMA: Aylua
# 23 118 44 continue_stop 	       66.
# 24 46 -28 start 	   —— Pa[port om dertien Paarden na Has
# 	PAGE_REFS: [411] 	CURR LEMMA: Aylua
# 25 96 22 continue_stop 	      nover te mogen voeren.   411.
# 26 39 -34 start 	   —— Pafport  om de Meubilen en Bágagie
# 	PAGE_REFS: [432] 	CURR LEMMA: Aylua
# 27 93 21 continue_stop 	      voor den Heer Finck in te voeren.   432.
# 28 43 -21 start 	   —— item om  aght  Paarden na Hanover
# 	PAGE_REFS: [448] 	CURR LEMMA: Aylua
# 29 96 33 continue_stop 	      te tran[porteren.  448.
# 30 36 -25 start 	   ——— ‘item  om drie Paarden na Spa te m0:
# 	PAGE_REFS: [505] 	CURR LEMMA: Aylua
# 31 86 24 continue_stop 	     gen uytvoeren.   505.
# 	PAGE_REFS: [728] 	CURR LEMMA: Aylua
# 32 41 -17 start_stop 	   —— verwellekomt.  728.
# 33 38 -21 start 	   —— om cftorte voer fijn Majefteyten ges
# 	PAGE_REFS: [962] 	CURR LEMMA: Aylua
# 34 77 18 continue_stop 	     ‘accordeert.  962,
# 35 53 -8 start 	    ——  Marckgraave, creditif op  de Ïá
# 36 52 -5 start 	         —— Divere als Refident   en niet geadmit-
# 37 52 -12 start 	         —— teert, als zijnde een Onderdaan van den
# 	PAGE_REFS: [996] 	CURR LEMMA: Aylua
# 38 101 35 continue_stop 	      Staat.  996.
# 	PAGE_REFS: [158] 	CURR LEMMA: Aylua
# HAS LEMMA: Baake , Brieven requifitoir verleent. 158.
# LEMMA: Baake
# 39 52 -15 start_stop 	    Baake, Brieven requifitoir verleent.   158.
# 40 52 -15 start 	    van Baayen wegens Gelderlandt ter Generalis
# 41 102 29 continue 	      teyt gecommittesrt.   $05.
# HAS LEMMA: Backer, belofte op den eedt ten aanvangh van
# LEMMA: Backer
# 42 54 -20 start 	    Backer, belofte op den eedt ten aanvangh van
# 	PAGE_REFS: [817] 	CURR LEMMA: Backer
# 43 90 16 continue_stop 	     /ijn ladinge gedaen.   817.
# 44 54 -20 start 	    de Bacqaere  om  execuriaal den Raadt  van
# 	PAGE_REFS: [956] 	CURR LEMMA: Backer
# 45 105 25 continue_stop 	      Staate te advifgeren.   956.
# HAS LEMMA: Barbut Brieven van voorfchryvens aan ’t Hof
# 46 57 -24 start 	    Barbut Brieven van voorfchryvens aan ’t Hof
# 	PAGE_REFS: [477] 	CURR LEMMA: Barbut
# 47 102 15 continue_stop 	      van Engelandt.  477.
# HAS LEMMA: Baffecour 9% 00 veel te moogen genieten €n
# 48 56 -22 start 	    Baffecour  9% 00 veel te moogen genieten €n
# 49 104 20 continue 	      declareren als tot mogh toe genooten, en des
# 50 107 29 continue 	      clareert heeft, de Admiraliteyt te adviferen.
# 	PAGE_REFS: [814] 	CURR LEMMA: Baffecour
# 51 108 25 continue_stop 	      814.
# 52 13 -66 start 	  ——   advis van de Admiraliteyt in Pries:
# 	PAGE_REFS: [815] 	CURR LEMMA: Baffecour
# 53 107 20 continue_stop 	      landt, te examineeren.   815.
# 54 49 -38 start 	   —— gepermitteert  nogh  twee maanden op
# 55 108 23 continue 	      den voet te continueren.  977À
# HAS LEMMA: Baftie Weduwe twee hondert guldens toes
# 56 62 -20 start 	    Baftie  Weduwe   twee hondert  guldens toes
# 	PAGE_REFS: [462] 	CURR LEMMA: Baftie
# 57 129 36 continue_stop 	       eleghte    462,
# 58 106 16 continue 	      gees     4      B                    de
#
#
#  scan-8-even
#
#
#  scan-8-even-0
# 	IS INDEX HEADER: 0 278 	##                         I           N
# possibly misrecognised repeat symbol: 149 ne
# possibly misrecognised repeat symbol: 198 o_O
# possibly misrecognised repeat symbol: 134 in
# DEVIATING LINE: 234 [156, 155, 107, 147, 234, 150, 104, 150, 277] Ei en Zoelmont midts vier duy[ent
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 150 [147, 234, 150, 104, 150, 277, 105, 141, 49] landt. 31.
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 277 [234, 150, 104, 150, 277, 105, 141, 49, 153] creditif en aangenaam. 96.
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 153 [277, 105, 141, 49, 153, 98, 98, 99, 98] 137.
# avg_repeat_symbol_length: 156
# DEVIATING LINE: 266 [147, 97, 144, 141, 266, 143, 95, 141, 139] rapport, de Raadt van Stats te ad-
# avg_repeat_symbol_length: 156
# ...
# skipping non-index page
#
#
#  scan-136-even
# skipping non-index page
#
#
#  scan-136-odd
# skipping non-index page
#
#
#  scan-137-even
# skipping non-index page
#
#
#  scan-137-odd
# skipping non-index page
#
#
#  scan-138-even
# skipping non-index page
#
#
#  scan-138-odd
# skipping non-index page
#
#
#  scan-139-even
# skipping non-index page
#
#
#  scan-139-odd
# skipping non-index page
#
#
#  scan-140-even
# skipping non-index page
#
#
#  scan-140-odd
# skipping non-index page
#
#
#  scan-141-even
# skipping non-index page
#
#
#  scan-141-odd
# skipping non-index page
#
#
#  scan-142-even
# skipping non-index page
#
#
#  scan-142-odd
# skipping non-index page
#
#
#  scan-143-even
# skipping non-index page
#
#
#  scan-143-odd
# skipping non-index page
#
#
#  scan-144-even
# skipping non-index page
#
#
#  scan-144-odd
# skipping non-index page
#
#
#  scan-145-odd
# skipping non-index page
#
#
#  scan-146-even
# skipping non-index page
#
#
#  scan-146-odd
# skipping non-index page
#
#
#  scan-147-even
# skipping non-index page
#
#
#  scan-147-odd
# skipping non-index page
#
#
#  scan-148-even
# skipping non-index page
#
#
#  scan-148-odd
# skipping non-index page
#
#
#  scan-149-even
# skipping non-index page
#
#
#  scan-149-odd
# skipping non-index page
#
#
#  scan-150-even
# skipping non-index page
#
#
#  scan-150-odd
# skipping non-index page
#
#
#  scan-151-even
# skipping non-index page
#
#
#  scan-151-odd
# skipping non-index page
#
#
#  scan-152-even
# skipping non-index page
#
#
#  scan-152-odd
# skipping non-index page
#
#
#  scan-153-even
# skipping non-index page
#
#
#  scan-153-odd
# skipping non-index page
#
#
#  scan-154-even
# skipping non-index page
#
#
#  scan-154-odd
# skipping non-index page
#
#
#  scan-155-even
# skipping non-index page
#
#
#  scan-155-odd
# skipping non-index page
#
#
#  scan-156-even
# skipping non-index page
#
#
#  scan-156-odd
# skipping non-index page
#
#
#  scan-157-odd
# skipping non-index page
#
#
#  scan-158-even
# skipping non-index page
#
#
#  scan-158-odd
# skipping non-index page
#
#
#  scan-159-even
# skipping non-index page
#
#
#  scan-159-odd
# skipping non-index page
#
#
#  scan-160-even
# skipping non-index page
#
#
#  scan-160-odd
# skipping non-index page
#
#
#  scan-161-even
# skipping non-index page
#
#
#  scan-161-odd
# skipping non-index page
#
#
#  scan-162-even
# skipping non-index page
#
#
#  scan-162-odd
# skipping non-index page
#
#
#  scan-163-even
# skipping non-index page
#
#
#  scan-163-odd
# skipping non-index page
#
#
#  scan-164-even
# skipping non-index page
#
#
#  scan-164-odd
# skipping non-index page
#
#
#  scan-165-even
# skipping non-index page
#
#
#  scan-165-odd
# skipping non-index page
#
#
#  scan-166-even
# skipping non-index page
#
#
#  scan-166-odd
# skipping non-index page
#
#
#  scan-167-even
# skipping non-index page
#
#
#  scan-167-odd
# skipping non-index page
#
#
#  scan-168-even
# skipping non-index page
#
#
#  scan-168-odd
# skipping non-index page
#
#
#  scan-169-even
# skipping non-index page
#
#
#  scan-169-odd
# skipping non-index page
#
#
#  scan-170-even
# skipping non-index page
#
#
#  scan-170-odd
# skipping non-index page
#
#
#  scan-171-even
# skipping non-index page
#
#
#  scan-171-odd
# skipping non-index page
#
#
#  scan-172-even
# skipping non-index page
#
#
#  scan-172-odd
# skipping non-index page
#
#
#  scan-173-even
# skipping non-index page
#
#
#  scan-173-odd
# skipping non-index page
#
#
#  scan-174-even
# skipping non-index page
#
#
#  scan-174-odd
# skipping non-index page
#
#
#  scan-175-even
# skipping non-index page
#
#
#  scan-175-odd
# skipping non-index page
#
#
#  scan-176-even
# skipping non-index page
#
#
#  scan-176-odd
# skipping non-index page
#
#
#  scan-177-even
# skipping non-index page
#
#
#  scan-177-odd
# skipping non-index page
#
#
#  scan-178-even
# skipping non-index page
#
#
#  scan-178-odd
# skipping non-index page
#
#
#  scan-179-even
# skipping non-index page
#
#
#  scan-179-odd
# skipping non-index page
#
#
#  scan-180-even
# skipping non-index page
#
#
#  scan-180-odd
# skipping non-index page
#
#
#  scan-181-even
# skipping non-index page
#
#
#  scan-181-odd
# skipping non-index page
#
#
#  scan-182-even
# skipping non-index page
#
#
#  scan-182-odd
# skipping non-index page
#
#
#  scan-183-even
# skipping non-index page
#
#
#  scan-183-odd
# skipping non-index page
#
#
#  scan-184-even
# skipping non-index page
#
#
#  scan-184-odd
# skipping non-index page
#
#
#  scan-185-even
# skipping non-index page
#
#
#  scan-185-odd
# skipping non-index page
#
#
#  scan-186-even
# skipping non-index page
#
#
#  scan-186-odd
# skipping non-index page
#
#
#  scan-187-even
# skipping non-index page
#
#
#  scan-187-odd
# skipping non-index page
#
#
#  scan-188-even
# skipping non-index page
#
#
#  scan-188-odd
# skipping non-index page
#
#
#  scan-189-even
# skipping non-index page
#
#
#  scan-189-odd
# skipping non-index page
#
#
#  scan-190-even
# skipping non-index page
#
#
#  scan-190-odd
# skipping non-index page
#
#
#  scan-191-even
# skipping non-index page
#
#
#  scan-191-odd
# skipping non-index page
#
#
#  scan-192-even
# skipping non-index page
#
#
#  scan-192-odd
# skipping non-index page
#
#
#  scan-193-even
# skipping non-index page
#
#
#  scan-193-odd
# skipping non-index page
#
#
#  scan-194-even
# skipping non-index page
#
#
#  scan-194-odd
# skipping non-index page
#
#
#  scan-195-even
# skipping non-index page
#
#
#  scan-195-odd
# skipping non-index page
#
#
#  scan-196-even
# skipping non-index page
#
#
#  scan-196-odd
# skipping non-index page
#
#
#  scan-197-even
# skipping non-index page
#
#
#  scan-197-odd
# skipping non-index page
#
#
#  scan-198-even
# skipping non-index page
#
#
#  scan-198-odd
# skipping non-index page
#
#
#  scan-199-even
# skipping non-index page
#
#
#  scan-199-odd
# skipping non-index page
#
#
#  scan-200-even
# skipping non-index page
#
#
#  scan-200-odd
# skipping non-index page
#
#
#  scan-201-even
# skipping non-index page
#
#
#  scan-201-odd
# skipping non-index page
#
#
#  scan-202-even
# skipping non-index page
#
#
#  scan-202-odd
# skipping non-index page
#
#
#  scan-203-even
# skipping non-index page
#
#
#  scan-203-odd
# skipping non-index page
#
#
#  scan-204-even
# skipping non-index page
#
#
#  scan-204-odd
# skipping non-index page
#
#
#  scan-205-even
# skipping non-index page
#
#
#  scan-205-odd
# skipping non-index page
#
#
#  scan-206-even
# skipping non-index page
#
#
#  scan-206-odd
# skipping non-index page
#
#
#  scan-207-even
# skipping non-index page
#
#
#  scan-207-odd
# skipping non-index page
#
#
#  scan-208-even
# skipping non-index page
#
#
#  scan-208-odd
# skipping non-index page
#
#
#  scan-209-even
# skipping non-index page
#
#
#  scan-209-odd
# skipping non-index page
#
#
#  scan-210-even
# skipping non-index page
#
#
#  scan-210-odd
# skipping non-index page
#
#
#  scan-211-even
# skipping non-index page
#
#
#  scan-211-odd
# skipping non-index page
#
#
#  scan-212-even
# skipping non-index page
#
#
#  scan-212-odd
# skipping non-index page
#
#
#  scan-213-even
# skipping non-index page
#
#
#  scan-213-odd
# skipping non-index page
#
#
#  scan-214-even
# skipping non-index page
#
#
#  scan-214-odd
# skipping non-index page
#
#
#  scan-215-even
# skipping non-index page
#
#
#  scan-215-odd
# skipping non-index page
#
#
#  scan-216-even
# skipping non-index page
#
#
#  scan-216-odd
# skipping non-index page
#
#
#  scan-217-even
# skipping non-index page
#
#
#  scan-217-odd
# skipping non-index page
#
#
#  scan-218-even
# skipping non-index page
#
#
#  scan-218-odd
# skipping non-index page
#
#
#  scan-219-even
# skipping non-index page
#
#
#  scan-219-odd
# skipping non-index page
#
#
#  scan-220-even
# skipping non-index page
#
#
#  scan-220-odd
# skipping non-index page
#
#
#  scan-221-even
# skipping non-index page
#
#
#  scan-221-odd
# skipping non-index page
#
#
#  scan-222-even
# skipping non-index page
#
#
#  scan-222-odd
# skipping non-index page
#
#
#  scan-223-even
# skipping non-index page
#
#
#  scan-223-odd
# skipping non-index page
#
#
#  scan-224-even
# skipping non-index page
#
#
#  scan-224-odd
# skipping non-index page
#
#
#  scan-225-even
# skipping non-index page
#
#
#  scan-225-odd
# skipping non-index page
#
#
#  scan-226-even
# skipping non-index page
#
#
#  scan-226-odd
# skipping non-index page
#
#
#  scan-227-even
# skipping non-index page
#
#
#  scan-227-odd
# skipping non-index page
#
#
#  scan-228-even
# skipping non-index page
#
#
#  scan-228-odd
# skipping non-index page
#
#
#  scan-229-even
# skipping non-index page
#
#
#  scan-229-odd
# skipping non-index page
#
#
#  scan-230-even
# skipping non-index page
#
#
#  scan-230-odd
# skipping non-index page
#
#
#  scan-231-even
# skipping non-index page
#
#
#  scan-231-odd
# skipping non-index page
#
#
#  scan-232-even
# skipping non-index page
#
#
#  scan-232-odd
# skipping non-index page
#
#
#  scan-233-even
# skipping non-index page
#
#
#  scan-233-odd
# skipping non-index page
#
#
#  scan-234-even
# skipping non-index page
#
#
#  scan-234-odd
# skipping non-index page
#
#
#  scan-235-odd
# skipping non-index page
#
#
#  scan-236-even
# skipping non-index page
#
#
#  scan-236-odd
# skipping non-index page
#
#
#  scan-237-even
# skipping non-index page
#
#
#  scan-237-odd
# skipping non-index page
#
#
#  scan-238-even
# skipping non-index page
#
#
#  scan-238-odd
# skipping non-index page
#
#
#  scan-239-even
# skipping non-index page
#
#
#  scan-239-odd
# skipping non-index page
#
#
#  scan-240-even
# skipping non-index page
#
#
#  scan-240-odd
# skipping non-index page
#
#
#  scan-241-even
# skipping non-index page
#
#
#  scan-241-odd
# skipping non-index page
#
#
#  scan-242-even
# skipping non-index page
#
#
#  scan-242-odd
# skipping non-index page
#
#
#  scan-243-even
# skipping non-index page
#
#
#  scan-244-even
# skipping non-index page
#
#
#  scan-244-odd
# skipping non-index page
#
#
#  scan-245-odd
# skipping non-index page
#
#
#  scan-246-even
# skipping non-index page
#
#
#  scan-246-odd
# skipping non-index page
#
#
#  scan-247-even
# skipping non-index page
#
#
#  scan-247-odd
# skipping non-index page
#
#
#  scan-248-even
# skipping non-index page
#
#
#  scan-248-odd
# skipping non-index page
#
#
#  scan-249-even
# skipping non-index page
#
#
#  scan-249-odd
# skipping non-index page
#
#
#  scan-250-even
# skipping non-index page
#
#
#  scan-250-odd
# skipping non-index page
#
#
#  scan-251-even
# skipping non-index page
#
#
#  scan-251-odd
# skipping non-index page
#
#
#  scan-252-even
# skipping non-index page
#
#
#  scan-252-odd
# skipping non-index page
#
#
#  scan-253-even
# skipping non-index page
#
#
#  scan-253-odd
# skipping non-index page
#
#
#  scan-254-even
# skipping non-index page
#
#
#  scan-254-odd
# skipping non-index page
#
#
#  scan-255-even
# skipping non-index page
#
#
#  scan-255-odd
# skipping non-index page
#
#
#  scan-256-even
# skipping non-index page
#
#
#  scan-256-odd
# skipping non-index page
#
#
#  scan-257-even
# skipping non-index page
#
#
#  scan-257-odd
# skipping non-index page
#
#
#  scan-258-even
# skipping non-index page
#
#
#  scan-258-odd
# skipping non-index page
#
#
#  scan-259-even
# skipping non-index page
#
#
#  scan-259-odd
# skipping non-index page
#
#
#  scan-260-even
# skipping non-index page
#
#
#  scan-260-odd
# skipping non-index page
#
#
#  scan-261-even
# skipping non-index page
#
#
#  scan-261-odd
# skipping non-index page
#
#
#  scan-262-even
# skipping non-index page
#
#
#  scan-262-odd
# skipping non-index page
#
#
#  scan-263-even
# skipping non-index page
#
#
#  scan-263-odd
# skipping non-index page
#
#
#  scan-264-even
# skipping non-index page
#
#
#  scan-264-odd
# skipping non-index page
#
#
#  scan-265-even
# skipping non-index page
#
#
#  scan-265-odd
# skipping non-index page
#
#
#  scan-266-even
# skipping non-index page
#
#
#  scan-266-odd
# skipping non-index page
#
#
#  scan-267-even
# skipping non-index page
#
#
#  scan-267-odd
# skipping non-index page
#
#
#  scan-268-even
# skipping non-index page
#
#
#  scan-268-odd
# skipping non-index page
#
#
#  scan-270-even
# skipping non-index page
#
#
#  scan-270-odd
# skipping non-index page
#
#
#  scan-271-even
# skipping non-index page
#
#
#  scan-271-odd
# skipping non-index page
#
#
#  scan-272-even
# skipping non-index page
#
#
#  scan-272-odd
# skipping non-index page
#
#
#  scan-273-even
# skipping non-index page
#
#
#  scan-273-odd
# skipping non-index page
#
#
#  scan-274-even
# skipping non-index page
#
#
#  scan-274-odd
# skipping non-index page
#
#
#  scan-275-even
# skipping non-index page
#
#
#  scan-275-odd
# skipping non-index page
#
#
#  scan-276-even
# skipping non-index page
#
#
#  scan-276-odd
# skipping non-index page
#
#
#  scan-277-even
# skipping non-index page
#
#
#  scan-277-odd
# skipping non-index page
#
#
#  scan-278-even
# skipping non-index page
#
#
#  scan-278-odd
# skipping non-index page
#
#
#  scan-279-even
# skipping non-index page
#
#
#  scan-279-odd
# skipping non-index page
#
#
#  scan-280-even
# skipping non-index page
#
#
#  scan-280-odd
# skipping non-index page
#
#
#  scan-281-even
# skipping non-index page
#
#
#  scan-281-odd
# skipping non-index page
#
#
#  scan-282-odd
# skipping non-index page
#
#
#  scan-283-odd
# skipping non-index page
#
#
#  scan-284-even
# skipping non-index page
#
#
#  scan-284-odd
# skipping non-index page
#
#
#  scan-285-even
# skipping non-index page
#
#
#  scan-285-odd
# skipping non-index page
#
#
#  scan-286-even
# skipping non-index page
#
#
#  scan-286-odd
# skipping non-index page
#
#
#  scan-287-even
# skipping non-index page
#
#
#  scan-287-odd
# skipping non-index page
#
#
#  scan-288-even
# skipping non-index page
#
#
#  scan-288-odd
# skipping non-index page
#
#
#  scan-289-even
# skipping non-index page
#
#
#  scan-289-odd
# skipping non-index page
#
#
#  scan-290-even
# skipping non-index page
#
#
#  scan-290-odd
# skipping non-index page
#
#
#  scan-291-odd
# skipping non-index page
#
#
#  scan-292-even
# skipping non-index page
#
#
#  scan-292-odd
# skipping non-index page
#
#
#  scan-293-even
# skipping non-index page
#
#
#  scan-293-odd
# skipping non-index page
#
#
#  scan-294-even
# skipping non-index page
#
#
#  scan-294-odd
# skipping non-index page
#
#
#  scan-295-even
# skipping non-index page
#
#
#  scan-295-odd
# skipping non-index page
#
#
#  scan-296-even
# skipping non-index page
#
#
#  scan-296-odd
# skipping non-index page
#
#
#  scan-297-even
# skipping non-index page
#
#
#  scan-297-odd
# skipping non-index page
#
#
#  scan-298-even
# skipping non-index page
#
#
#  scan-298-odd
# skipping non-index page
#
#
#  scan-299-even
# skipping non-index page
#
#
#  scan-299-odd
# skipping non-index page
#
#
#  scan-300-even
# skipping non-index page
#
#
#  scan-300-odd
# skipping non-index page
#
#
#  scan-301-even
# skipping non-index page
#
#
#  scan-301-odd
# skipping non-index page
#
#
#  scan-302-even
# skipping non-index page
#
#
#  scan-302-odd
# skipping non-index page
#
#
#  scan-303-even
# skipping non-index page
#
#
#  scan-303-odd
# skipping non-index page
#
#
#  scan-304-even
# skipping non-index page
#
#
#  scan-304-odd
# skipping non-index page
#
#
#  scan-305-odd
# skipping non-index page
#
#
#  scan-306-even
# skipping non-index page
#
#
#  scan-306-odd
# skipping non-index page
#
#
#  scan-307-even
# skipping non-index page
#
#
#  scan-307-odd
# skipping non-index page
#
#
#  scan-308-even
# skipping non-index page
#
#
#  scan-308-odd
# skipping non-index page
#
#
#  scan-309-even
# skipping non-index page
#
#
#  scan-309-odd
# skipping non-index page
#
#
#  scan-310-even
# skipping non-index page
#
#
#  scan-310-odd
# skipping non-index page
#
#
#  scan-311-even
# skipping non-index page
#
#
#  scan-312-even
# skipping non-index page
#
#
#  scan-312-odd
# skipping non-index page
#
#
#  scan-313-even
# skipping non-index page
#
#
#  scan-313-odd
# skipping non-index page
#
#
#  scan-314-even
#
#
#  scan-314-even-1
# Header: u)                                ‚5
# 	scan: don't know line: 0 top: 232 0 904 904
# 	FIRST BODY LINE: 1 325 	##   twintighften der voorlede maandt:  WAAR
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-341-c21018be8632> in <module>()
#      16         column_hocr = column_info["column_hocr"]
#      17         lines = rep_parser.get_index_entry_lines(column_hocr)
# ---> 18         curr_lemma = index_lemmata(column_id, lines, lemma_index, curr_lemma)
#      19
#      20
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in index_lemmata(column_id, lines, lemma_index, curr_lemma)
#     499         return True
#     500     description = ""
# --> 501     fixed_lines = fix_repeat_symbols(lines)
#     502     for line_index, line in enumerate(fixed_lines):
#     503         if len(line["words"]) == 0:
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in fix_repeat_symbols(lines)
#     493 def fix_repeat_symbols(lines):
#     494     fixed_lines = fix_repeat_symbols_lines(lines)
# --> 495     return find_missing_repeat_symbols(fixed_lines)
#     496
#     497 def index_lemmata(column_id, lines, lemma_index, curr_lemma):
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in find_missing_repeat_symbols(lines)
#     399
#     400 def find_missing_repeat_symbols(lines):
# --> 401     avg_repeat_symbol_length = get_repeat_symbol_length(lines)
#     402     fixed_lines = []
#     403     for line_index, curr_line in enumerate(lines):
#
# ~/Code/Huygens/republic-hocr-parser/parse_republic_hocr_files.py in get_repeat_symbol_length(lines)
#     371         if has_repeat_symbol(line):
#     372             repeat_symbol_lengths += [line["words"][0]["width"]]
# --> 373     return int(sum(repeat_symbol_lengths) / len(repeat_symbol_lengths))
#     374
#     375 def add_repeat_symbol(line, avg_repeat_symbol_length, minimum_start):
#
# ZeroDivisionError: division by zero

# %%
for lemma in lemma_index:
    print("\nTrefwoord:", lemma)
    #print(lemma_index[lemma])
    for entry in lemma_index[lemma]:
        pages = ", ".join([str(page_ref) for page_ref in entry["page_refs"]])
        description = entry["description"][:70]
        print("\tPagina:", pages, "\tBeschrijving:", description)

# %%
# scan 45 uneven is first resolution page
# page num: 91

from fuzzy_context_searcher import FuzzyContextSearcher
import pandas as pd

config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 3,
    "skip_size": 0,
}

fuzzy_searcher = FuzzyContextSearcher(config)

keywords = [
    "Admiraliteyt tot Amfterdam", 
    "Admiraliteyt in het Noorder Quartier", 
    "Admiraliteyt in Vrieslandt", 
    "Admiralteyt in Zeelandt",
    "Varckens"
]

distractor_terms = {
    "Admiraliteyt tot Amfterdam": {
        "Admiraliteyt in het Noorder Quartier", "Admiraliteyt in Vrieslandt", "Admiralteyt in Zeelandt"
    },
    "Admiraliteyt in het Noorder Quartier": {
        "Admiraliteyt tot Amfterdam", "Admiraliteyt in Vrieslandt", "Admiralteyt in Zeelandt"
    },
    "Admiraliteyt in Vrieslandt": {
        "Admiraliteyt tot Amfterdam", "Admiraliteyt in het Noorder Quartier", "Admiralteyt in Zeelandt"
    },
    "Admiralteyt in Zeelandt": {
        "Admiraliteyt tot Amfterdam", "Admiraliteyt in het Noorder Quartier", "Admiraliteyt in Vrieslandt"
    },
}
fuzzy_searcher.index_keywords(keywords)
fuzzy_searcher.index_distractor_terms(distractor_terms)

hocr_resolution_pages = []

# %% [markdown]
# ### Fuzzy Searching of Keywords in the Resolutions
#
# Knowing which keywords should appear in the text, possibly with some spelling variation and OCR errors, we can use a fuzzy search algorithm to find candidate matches.
#
# Keywords that are similar to each other are registered as distractor terms, so matches are assigned as candidates to the nearest of sets of similar keywords.

# %%
from parse_republic_hocr_files import merge_text_lines, read_hocr_scan

lemma_matches = defaultdict(list)

def add_context(match, page_text):
    context = fuzzy_searcher.get_term_context(page_text, match, context_size=40)
    match["match_term_in_context"] = context["match_term_in_context"]
    match["context_start_offset"] = context["start_offset"]
    match["context_end_offset"] = context["end_offset"]

for scan_file in scan_files:
    resolution_page_num = scan_file["scan_page_num"] - 90
    if scan_file["scan_page_num"] <= 90:
        continue
    print(scan_file["scan_page_num"], resolution_page_num)
    hocr_page = read_hocr_scan(scan_file)
    page_text = merge_text_lines(hocr_page)
    matches = fuzzy_searcher.find_candidates(page_text)
    for match in matches:
        lemma_matches[match["match_keyword"]] += [match]
        add_context(match, page_text)
        match["page_num"] = scan_file["scan_page_num"]
        print(match["match_keyword"], "\t", match)
    #break

# %%
for lemma in sorted(lemma_matches):
    print("\n", lemma, "\tAantal kandidaten:", len(lemma_matches[lemma]), "\n")
    for match in lemma_matches[lemma]:
        print("\tKandidaat:", match["match_string"])
        print("\tPagina:", match["page_num"])
        print("\tContext:", match["match_term_in_context"][5:-5])
        print()

# %% [markdown]
# ### Extracting Resolutions From Pages
#
# Identify:
#
# - resolution dates
# - resolution participant lists
# - resolution text blocks

# %%
from fuzzy_context_searcher import FuzzyContextSearcher
from fuzzy_person_name_searcher import FuzzyPersonNameSearcher

config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
}

keywords = [
    #"Is ter Vergaderinge gelefen",
    #"Ontvangen een miffive van",
    #"WAAR op gedelibereert zijnde",
    #"WAAR op geen refolutie is gevallen",
    #"De Resolutien, gifteren genomen",
    #"Nihil actum eft.",
    #"PRAESIDE",
    "PRAESENTIBUS",
    #"Januarii"
]

week_days = [
    "Lunae",
    "Martis",
    "Mercurii",
    "Jovis",
    "Veneris",
    "Sabbathi",
    "Dominica"
]

months = [
    "Januarii",
    "Februarii",
    "Maart",
    "April",
    "Mey",
    "Junii",
    "Juli",
    "Augufti",
    "September",
    "October",
    "November",
    "December"
]

spelling_variants = {
    "Ontvangen een miffive van": [
        "ON een miffive van",
    ],
    "PRAESENTIBUS": [
        "PRASENTIBUS",
        "PRESENTIBUS"
    ]
}

fuzzy_searcher = FuzzyContextSearcher(config)
fuzzy_person_searcher = FuzzyPersonNameSearcher(config)

fuzzy_searcher.index_keywords(keywords)
#fuzzy_searcher.index_spelling_variants(spelling_variants)
#fuzzy_searcher.index_distractor_terms(distractor_terms)

def is_empty_line(line):
    return len(line["words"]) == 0

def get_resolution_page_paragraphs(page_info):
    paragraphs = []
    for column_info in page_doc["columns"]:
        paragraph = []
        prev_line_bottom = None
        for line in column_info["column_hocr"]["lines"]:
            boundary = False
            if is_empty_line(line):
                continue
            if prev_line_bottom == None:
                prev_line_bottom = line["bottom"]
                paragraph.append(line)
                continue
            line_gap = line["top"] - prev_line_bottom
            if line_gap > 30:
                boundary = True
            elif line_gap > 10 and line_is_centered_date(line):
                boundary = True
            if boundary and prev_line_bottom < 400:
                paragraph = [] # start new paragraph, ignore header line
            elif boundary:
                paragraphs.append(paragraph)
                paragraph = []
            paragraph.append(line)
            prev_line_bottom = line["bottom"]
        if len(paragraph) > 0:
            paragraphs.append(paragraph)
    return paragraphs

def line_has_weekday(line):
    return line_has_word_from_list(line, week_days)

def line_has_month(line):
    return line_has_word_from_list(line, months)

def line_has_word_from_list(line, word_list):
    for line_word in line["words"]:
        best_match = None
        best_score = 1
        for list_word in word_list:
            score = score_levenshtein_distance(line_word["word_text"], list_word)
            relative_score = score / len(list_word)
            if relative_score < 0.4:
                if relative_score < best_score:
                    best_match = list_word
                    best_score = relative_score
        if best_match:
            print("#{}# #{}#".format(line_word["word_text"], best_match), best_score)
            return True
    return False

def line_is_centered_date(line):
    # line is centered
    if line["words"][0]["left"] < 200 or line["words"][-1]["right"] > 800:
        return False
    if line_has_weekday(line) and line_has_month(line):
        print("\n\tCentered date line:\t", line["line_text"])
        return True
    # line has weekday den number month
    return False

def paragraph_starts_with_centered_date(paragraph):
    if line_is_centered_date(paragraph[0]):
        return True
    return False

def merge_paragraph_lines(paragraph):
    paragraph_text = ""
    for line in paragraph:
        if line["line_text"][-1] == "-":
            paragraph_text += line["line_text"][:-1]
        else:
            paragraph_text += line["line_text"] + " "
    return paragraph_text

for page_id in pages_info:
    if pages_info[page_id]["page_type"] != "resolution_page":
        continue
    if pages_info[page_id]["scan_num"] < 264 or  pages_info[page_id]["scan_num"] > 280:
        continue
    print(page_id, pages_info[page_id]["page_type"])
    page_doc = retrieve_page_doc(page_id)
    for paragraph in get_resolution_page_paragraphs(page_doc):
        paragraph_text = merge_paragraph_lines(paragraph)
        matches = fuzzy_searcher.find_candidates(paragraph_text, include_variants=True)
        if len(matches) == 0 and paragraph_starts_with_centered_date(paragraph):
            print("DATE LINE:", paragraph_text)
        #    print("paragraph_text:", paragraph_text)
        for match in matches:
            #print("\t", match)
            if match["match_term"] == "PRAESENTIBUS":
                print("DAY START:", paragraph_text)
            context_match = fuzzy_searcher.get_term_context(paragraph_text, match, context_size=200)
            #print(context_match)
            person_matches = fuzzy_person_searcher.find_person_names_in_text(context_match["match_term_in_context"])
            #person_matches = fuzzy_person_searcher.find_person_names_in_context(context_match)
            #for person_match in person_matches:
            #    print("\t", person_match)
        #print("\n\n\n")
# Out:
# scan-264-even resolution_page
# scan-264-odd resolution_page
# #Martis# #Martis# 0.0
# #Junit# #Junii# 0.2
#
# 	Centered date line:	 Martis den 19, Junit
# DAY START: Martis den 19, Junit 1725. PRASIDE, Den Heere Van Maasdam. PRASENTIBUS. De Heeren Jan Welderen van Heucketom , Singendonck , ván Heeckeren, Umibgroeven met een extraordinaris Gedeputeerde uyt de Provincie van Gelderlandt. Vanden Boetzelaar Raadtpenfionaris van Hoornbeeck. Ocker(Je. Van Voor. Van Schwartzenbergty Rou[e , Vriefen. Emmen, Tamminga.
# scan-265-even resolution_page
# scan-265-odd resolution_page
# scan-266-even resolution_page
# scan-266-odd resolution_page
# DAY START: Mercuri: den 210. Junii 4725. PRASTDE, Den Heere Zan Maasdam. PRASENTIBUS, De Heeren’ Van Welderen van Heuckts lom van Heeckeren Umbgroeven met een extraordinaris Gedeputeerde uyt dé Provincie van Gelderlandt. Panden Boetzelaar Eelbo van Marfeveen, Boon Raadtpen/ionaris van Hoornbeeck. OckerJe, met een extraordinaris Gedeputeerde uyt de Provincie van Zeelandt. Van Voorft , met cen extraordinaris Gedeputeerde uyt de Provincie van Utrecht. Van Schwartzenbergh de Kempenaar. Rou[e , Vrie[en. Emmen , Tamminga.
# scan-267-even resolution_page
# scan-267-odd resolution_page
# scan-268-even resolution_page
# scan-268-odd resolution_page
# scan-270-even resolution_page
# DAY START: Vencris den 22. Juni 1725. wust 1,46 5 1 DE, Den Heere 7an Maasdam. PRASENTIBUS, De Heeren Van Welderen , van Heuckes lom, Singendonck, van Heeckeren Umbgroeven met een extraordinaris Gedeputeerde uyt de Provincie van Gelderlandt. Ocker(fe. Van Voort. De Kempenaar. Re Den Emmen.
# scan-270-odd resolution_page
# scan-271-even resolution_page
# scan-271-odd resolution_page
# #Sabbathi# #Sabbathi# 0.0
# #Junit# #Junii# 0.2
#
# 	Centered date line:	 Sabbathi den 23. Junit
# DATE LINE: Sabbathi den 23. Junit 1725.
# DAY START: Den Heere Jan Maasdam. PRA&SENTIEUS, De Heeren Zan Welderen van Heuckes lom, Singendonck , van Heeckeren Umbe groeven. Raadtpen/ionaris van Hoornbeeck. Ocker(e. Van Voor met een extraordinafis Gedeputeerde uyt de Provincie van Otrecht, Van Schwartzenhergh, de Kempenaar, Roue Prie[en. Emmen.
# scan-272-even resolution_page
# scan-272-odd resolution_page
# scan-273-even resolution_page
# scan-273-odd resolution_page
# scan-274-even resolution_page
# scan-274-odd resolution_page
# DAY START: Martis den 26. Junii 17254. PRASIDE, Den Heere Ocker(e. PRASENTIBUS. De Heeren Jan Welderen van Heucke» lom, Singendonck , van Heeckeren, Umbs groeven met een extraordinaris GedeT puteerde
# scan-275-even resolution_page
# #Sabdathi# #Sabbathi# 0.125
# #Junit# #Junii# 0.2
#
# 	Centered date line:	 Sabdathi den. 16. Junit 1725
# DATE LINE: Sabdathi den. 16. Junit 1725
# scan-275-odd resolution_page
# #Sabbathi# #Sabbathi# 0.0
# #Juni# #Junii# 0.2
#
# 	Centered date line:	 Sabbathi den 16. Juni 17258.
# DATE LINE: Sabbathi den 16. Juni 17258.
# scan-276-even resolution_page
# #Sabhatbhi# #Sabbathi# 0.25
# #Junii# #Junii# 0.0
#
# 	Centered date line:	 Sabhatbhi den 16. Junii 1725.
# DATE LINE: Sabhatbhi den 16. Junii 1725.
# scan-276-odd resolution_page
# DAY START: Mercuri: den 27. Junit 1725, PRASIDE, Den Heere Ocker(Je. PRASENTIBUS, De Heeren Zan Heuckelom Singendonck van Heeckeren Umbgroeven met een  extraordinarts Gedeputeerde uyt de Provincie van Gelderlandt. Boon Raadtpenfionaris van Hoornbeeck. Taats van Amerongen, van Voorf. Van Schwartzenbergh de Kempenaar. Rou[e , Vriefen. Emmen. PEI
# scan-277-even resolution_page
# scan-277-odd resolution_page
# #Jovis# #Jovis# 0.0
# #Janii# #Junii# 0.2
#
# 	Centered date line:	 Jovis den 28, Janii
# DAY START: Jovis den 28, Janii 1725. PRASIDE, Den Heere Ocker(e. PRAESENTIBUS, De Heeren Van Welderen van Heucketom, van Heeckeren Umbgroeven met een extraordinaris Gedeputeerde uyt de Provincie van Gelderlandt. Vanden Boetzelaar Eelbo van Marfeveen, Boon, Raadtpenfionaris van Hoornbeeck. Een extraordinaris Gedeputeerde uyt de Provincie van Zeelandt. Taats van Amerongen, van Voorft. Ven Schwartzenbergh, de Kempenaar. Roufe , Vriefen. Emmen.
# scan-278-even resolution_page
# scan-278-odd resolution_page
# scan-279-even resolution_page
# scan-279-odd resolution_page
# scan-280-even resolution_page
# DAY START: Veneris den 29. Tunii 1725. PRA 35.1D4, Den Heere Ocker{e. PRASENTIBUS, De Heeren an Welderen van Heucke» dom, van Heeckeren Umbgroeven met een extraordinaris Gedeputeerde uyt de Provincie van Gelderlandt. Van Maasdam Raadtpenfionaris van Hoorndeeck. Taats van Amerongen van Voort. Van Schwartzenbergh, de Kempenaar. Roue, Vriefen. Emmen.
# scan-280-odd resolution_page

# %% [markdown]
# ## Experimental Corner
#
# Playground for trying fuzzy searching algorithms.

# %%
def score_levenshtein_distance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1
    distances = range(len(s1) + 1)
    #distances = [0] * (len(s1) + 1)
    #print("distances initial:",distances)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        #print("distances_:", distances_)
        #print("i2:", i2, "c2:", c2)
        for i1, c1 in enumerate(s1):
            #print("i1:", i1, "c1:", c1)
            if c1 == c2:
                distances_.append(distances[i1])
                #print(distances_, "equal")
            else:
                #print("\tminimum of:", distances[i1], distances[i1 + 1], distances_[-1])
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
                #print(distances_, "unequal")
        distances = distances_
        #distances = distances_
        #print("distances:", distances, s2[i2:i2+len(s1)])
    return distances[-1]

def get_match(matrix, T):
    match = ""
    col_index = len(matrix) - 1
    distance = matrix[-1][-1]
    row_index = len(matrix[-1]) - 1
    while row_index > 0:
        if col_index < 0:
            print("BREAKING")
            break
        #print("col_index:", col_index, "row_index:", row_index, "distance:", distance)
        if matrix[col_index-1][row_index-1] < distance:
            #print("replacing")
            match = T[col_index] + match
            distance = matrix[col_index-1][row_index-1]
            col_index -= 1
            row_index -= 1
        elif matrix[col_index][row_index-1] < distance:
            #print("inserting")
            #match = T[col_index-1] + match
            distance = matrix[col_index][row_index-1]
            row_index -= 1
        elif matrix[col_index-1][row_index] < distance:
            #print("deleting")
            match = T[col_index] + match
            distance = matrix[col_index-1][row_index]
            col_index -= 1
        elif matrix[col_index-1][row_index-1] == distance:
            #print("copying")
            match = T[col_index] + match
            col_index -= 1
            row_index -= 1
        else:
            print("This should never be printed")
        #print("row_index:", row_index)
        #print("match:", match)
    #print("returning match:", match)
    return (match, col_index+1, matrix[-1][-1])

def search_levenshtein_distance(P, T, threshold=2):
    if len(P) > len(T):
        P, T = T, P
    distances = range(len(P) + 1)
    matches = []
    matrix = []
    #distances = [0] * (len(T) + 1)
    #print("distances initial:",distances)
    for t_j, T_j in enumerate(T):
        distances_ = [0]
        #print("distances_:", distances_)
        #print("t_j:", t_j, "T_j:", T_j)
        for p_i, P_i in enumerate(P):
            #print("p_i:", p_i, "P_i:", P_i)
            if P_i == T_j:
                distances_.append(distances[p_i])
                #print(distances_, "equal")
            else:
                #print("\tminimum of:", distances[p_i], distances[p_i + 1], distances_[-1])
                distances_.append(1 + min((distances[p_i], distances[p_i + 1], distances_[-1])))
                #print(distances_, "unequal")
        distances = distances_
        #distances = distances_
        #print("distances:", distances, T[t_j-len(P):t_j])
        matrix += [distances]
        distance = distances[-1]
        if distance <= threshold:
            match = get_match(matrix, T)
            #print(T[:match[1]])
            #print(T[match[1]:match[1]+len(match[0])])
            #print(T[match[1]+len(match[0]):])
            matches.append(match)
    #for row in matrix:
    #    print(row)
    #for col_index, distance in enumerate(distances):
    return matches

target = "survey"
context = "surgery"
matches = search_levenshtein_distance(target, context)
print(matches)

target = "survey"
context = "the doctor is specialised in surgery of the heart"
matches = search_levenshtein_distance(target, context)
print(matches)
# Out:
# [('surge', 0, 2), ('surger', 0, 2), ('surgery', 0, 2)]
# [('surge', 29, 2), ('surger', 29, 2), ('surgery', 29, 2)]

# %%
texts = [
    "B. dr Bofch Mikelaer, zal op den 11 May , in de Keyzers Kroon verkopen , een uvrmuntënde pirty Schilderyen van de voornaernfte M;efter«; ils van de Oude Pslma extra goed , A'exander Veronecs, Pluweele Breugel , Wouwerman, J. vander Heydc, Laireffe, Bril en ancVc. Nagelaten door een voon.aem Liefhcbb.T ; als mede een fraye parry Teekenmgen en Miniatuur fchoone D'ukke Prenten van de voorn-emfte Mcefters. De Citilogu-zal ir.tyds te bekomen zyn by Jicób Carpi Konft Schilder, en by de gsm. Mikelaer. B. SÜgtenborff Mikelaer, za' op Woensdag den 25- Miy, t'Amft. in 't Oude Heeren Logement verkopen, een pirty Engelfche Manuft-Uuren et Wmkclw ren , beftaende in Lakend diverfe fbrteering vin * en 9 quart breed , Biyen, Kirfayen, Drogetreu,.Sergies, gcfc»om-c en gj'lrcepre Kalamankcn, S.urynen, diverfe Grynen en Stoften, Ssycn, Chitzen , Catoenenen Neteldoekeu , divetfc Kouffen,-1 !___. witte gebleekte. Li.inens„cn andere Goederen meer ;, alle* dacgj ïoer <k Verkoping te zien.. '",
    "Plülippus van d:r Land Makelaer, za! op d:.i : 5 May verkopen , een uytmuntend ko1 fti- Kabinet Schilderyen; als vin Pb. Woaverman, A. vin O.tilc, Rottenhimcr, G. Metzu, G. dc LairefTc, D. van Deeien, |. Srccn, D. Teniers, de- Oude Griffier. ]. en 4. Bcth, M. ds Hond-koere-, J. do Heem, J. Lingelbigh.en andere Mecfterj meer; nagelaten door den £J. Heer Secretaris Lambert Witzen , wier van de Citalogus by den gen*. Mikelaer te bekomen zullen zyn. Alte de gee-.e die iers te prereideeren hebben of verfftiulcKgt zyn op de mgchten Boedel vin Pieter Engels , tot Warmer overleden, gelieven luc prerenficn binr.e.-yden tyd vaa 5 weeleen 1:1 te leveren leo Wccsvi-lers rn Armvoogden tot Wormer ; dew-'ke de Penningen vm de y;em. Boedel geprovenieert binnen korre , na verloop van de ge.eyde C weken , by preferentie en concurrentie zulten diftri- MSfctti foi.nig als zy zu'ten vmdc.i te be'nojren,",
    "Jac. Torner Junior Mikelaer, prefènteert tegens primo May.of wel eerder :e verbuurcn, een zeer vermakelyke en welgelege Herberg genaemt RUSTENBURG ; gelegen buyten dc Urregtfj Poort op 't Ruften!., rger par! , met zyn tnodicufe Huyzinge , fraye Thuyn en Tuynhuy», Kolfoaen.Troktafel &o; aiwaer de neering veel jiren met fueces il gcoaen en nog werd gecontinueert, laetft bewoont dexr wylen Dirk He Lange. N ider onderngtinge bv gem. Makelae-. Alle de eeene die eenig regt, aélie of pretenfie beeft, of iets fchal lig zyn a-.n den r.eabindonneerden Boedel .-an Dirk van Schaik en Ja -metje Theuniffe, geweezene Herbe-g er in de Oude Loosdregt, werden-verzoet zulks op en aen ce geven ter Secretary aldaer, uyterlyk voor primo April 1745 , op potne vau eeuwig ftilfwygen en verftek.",
    "ArnoHns van Sprang-Mikelaer, zal op Maendag d-n 27 Vnny.t'Amfteid. in 't Oude Heeten Logement vetkopen, een wel ter nerinc 4_endc Hoys, In de Crom elboo»ftee» 't rte huvs -an den\"Dim,»rnaemt het Mo huys, daer de Baftille uythangt ; breeJet byßiljettr Vermeld : lemant nadet ondetrigi begreiende of genegen zynde dit Perceel uyt de hand te-koopen , fpieeke met de gem. Makelaet, by van eygendom «dagen voet de Veikoopdag te zien tullen zyn. Ajnüld:. s- au Spiang.M.kc!aei, zal op Maendag den 2- lünv , t'Aml. in 't Ó.de tfeeien Logement vetku. en, drie hegre, fterkeen weC-doortt üsnefde Huvfcn, ftaende nieft mi'k.nrlrien in deGroore aen dl-Vtoord-vde by de dwirsftiact • bieede by 3i,;**rte**i vermeld: lefnanrna-e.'onderri.ti.ig begeerende of geneegen z.ynie degemPi'tcedriaTt ie.__.ad.teko.pen,fpi?eke mei yucru, Mak_liei, by wien de bewyzen .van cyi*j_d-_- S dagen voot de:yeikoop_ag.tc _iea zullen ü\", cv",
    "Job. Haverkamp Mikelaer, zal op Maendag den 11 January 1745, t Amft. in t Oude Heere Logement verkopen, No. 1. Een hegt en fterk Huys; ftaende op de Weesperftraet tuffchen de Hect:n en Keyzersgragt. No.1. Eén dito Huys.ftaende naeft 't voorgaende. No. 3. Een Sdepart in een we! ter nering ftaende Huys en Erve op de N. Z. van de Agterburgwal op de hoek van de Pottebakkersfteeg. Breder by Biüetten gefpecifkeert. De bewyzen van eygendom en de Vylconditien zullen 8 dagen voor en op de Verkoopdag voormiddag» tot J 2 uuren toe te zien zyn ten Compt. van den Notaris E. Haverkamp. Uyt dé huni te Koop een wel beklante Banket en Confiturier» Winkel met deszelfs Gereetfchappen , waer in die affaire» circa SS jaeren met c.\".cd fucces zyn gecontinueert: Te bevragen by Hendrik Bofch en Gomp., in de Kalverftract, tuflehen de Öjjes-flaysen Olyfiigers-fteeg\" t'Amfterdam. Als meede het Huys te hu*r.",
    "J. van Zutphen Mikelaer , zal op Maendag den 14 September , t'Amft. in 't Oude Heeren Logement verkopen , een extra wel geleegen 3-ftreeksLiken-Raem , met zyn Thuyn , Huyzinge en Droogfcheevders Winkel, eertyts genaemt het Varken, en nu Buyren-Ruft, ftaende en aeleegen buyten de Raem-Pooit ren eynde het eerfte Sceene-Pad , zynde Stads Grond , en geteekent met. No! 27, 28 en 29, Alles breder by Biljetten en dagelyks te zien , de bewyzen van Eygendom zullen 8 dagen voor en op de verkoopdag te zien zyn '. ten Compt. van den Nots. Arnoud Roermond in de Krom-Elleboogfteeg , en nader onderrigting by gem. Makelaer. ; Alle die iets te pretendeeren mogten hebben ten.laften van wylen Jean Fredrik Bernard , in zyn Leven Boekverkoper t'Amft. v of die eenige Engagementen met dezelve hebben lopende , uyr wat hoofde het o:)-_zoude mogen zyn, als mede die aen der Boedel fchuJdig mogten wezen , of ook eenige Goederen van hem onder zig hebben , werden verzogt zulks op voor tieu ïsOitcber 1744. .;ten Compt. vanden Notaris Jan Ardinois , op de Cingel t'Amfterdam.",    
]

target = "Makelaar"
target = "Oude Heere Logement"
for text in texts:
    matches = search_levenshtein_distance(target, text)
    print(matches)
# Out:
# [('Oude Heeren Logemen', 568, 2), ('Oude Heeren Logement', 568, 1), ('Oude Heeren Logement ', 568, 2)]
# []
# []
# [('Oude Heeten Logement', 73, 2)]
# [('Oude Heere Logeme', 74, 2), ('Oude Heere Logemen', 74, 1), ('Oude Heere Logement', 74, 0), ('Oude Heere Logement ', 74, 1), ('Oude Heere Logement v', 74, 2)]
# [('Oude Heeren Logemen', 74, 2), ('Oude Heeren Logement', 74, 1), ('Oude Heeren Logement ', 74, 2)]
