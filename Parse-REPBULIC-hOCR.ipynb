# %% [markdown]
# ## Parsing REPBULIC hOCR Files
#
# The scans of the printed RSG volumes have the following characteristics
#
# - all scans:
#   - have two pages per scan
#   - have up to 4 columns per scan, 2 per page
#   - full scan is around 4800 pixels wide, left page is up to pixel 2400, right page is from pixel 2400 (roughly)
# - scans of index pages
#   - have no page numbers
# - scans of resolution pages
#   - have page numbers (left-side page is even, right-side page is odd)
#
# ### Columns
#
# The scans are normalized such that the columns are straight. The text width should be around 1000 pixels. Some columns are not cut out properly, resulting in columns that are either to small (some of the column text is missing), or too wide (the hOCR output contains partial texts from two columns)
#
# ### Index pages
#
# - start of entry:
#   - start left alignment
# - end of entry:
#   - end of line possibly before end of text column.
#   - One or more page numbers
#
#
# ### Resolution pages
#
# - header:
#   - next top of page (less than 350 pixels from the top)
#   - page has header with:
#     - even numbered pages: date page_number year
#     - odd numbered pages: year page_number date
#   - columns have half of page header, e.g.:
#     - even numbered pages:
#       - first column: date left aligned and part of page_number right aligned
#       - second column: part of page_number left aligned and year right aligned
#     - odd numbered pages:
#       - first column: year left aligned and part of page_number right aligned
#       - second column: part of page_number left aligned and date right aligned
#
# ### Viewer
#
# - page viewer: https://images.huygens.knaw.nl/assets/argos/index.html
# - list of page URLs: https://images.huygens.knaw.nl/api/argos
#
#
# ### National Archive site
#
# - search in the archive: https://www.nationaalarchief.nl/onderzoeken/index/nt00444?searchTerm=
# - search the index: https://www.nationaalarchief.nl/onderzoeken/zoekhulpen/voc-opvarenden
# - example page: https://www.nationaalarchief.nl/onderzoeken/index/nt00444/d110980c-c864-11e6-9d8b-00505693001d

# %%
# This reload library is just used for developing the REPUBLIC hOCR parser 
# and can be removed once this module is stable.
# %reload_ext autoreload
# %autoreload 2

# %%
import json
import os
import re
from collections import defaultdict
from parse_hocr_files import make_hocr_page
#from parse_republic_hocr_files import get_files, get_page_types, count_page_ref_lines, get_index_entry_lines, gather_page_columns
#from elasticsearch import Elasticsearch
import republic_page_parser as page_parser
import republic_paragraph_parser as paragraph_parser
import republic_file_parser as file_parser

# The hOCR file name contains relevant information for parsing. Here's an example:
# NL-HaNA_1.01.02_3780_0016.jpg-0-251-98--0.40.hocr

# NL-HaNA_1.01.02 is the name of the archive
# 3780_0016 identifies the specific page with a specific contract
# 0-251-98--0.40 identifies four aspects:
#   1. the number of the column (0)
#   2. the offset from the left (251)
#   3. the offset from the top (98)
#   4. and the slant (-0.40)

# %% [markdown]
# ### Reading column scans for a single volume
#
# 1. get scan file info
#     - scan number, page number, page side, column number, slant, page
# 2. iterate over pages
#     - create hocr_page
#     - determine page type: index, resolution, other

# %%
from parse_hocr_files import make_hocr_page
#from parse_republic_hocr_files import get_files, get_page_types, count_page_ref_lines, get_index_entry_lines, gather_page_columns
#from elasticsearch import Elasticsearch
import republic_page_parser as page_parser
import republic_paragraph_parser as paragraph_parser
import republic_file_parser as file_parser

import copy

year = 1725
base_config = {
    "year": year,
    "base_dir": "../../../Data/Projects/REPUBLIC/hocr/",
    "page_index": "republic_hocr_pages",
    "page_doc_type": "page",
    "tiny_word_width": 15, # pixel width
    "avg_char_width": 20,
    "remove_tiny_words": True,
    "remove_line_numbers": False,
}


def get_pages_info(config):
    scan_files = file_parser.get_files(config["data_dir"])
    print("Number of scan files:", len(scan_files))
    return file_parser.gather_page_columns(scan_files)

def set_config_year(base_config, year):
    config = copy.deepcopy(base_config)
    config["year"] = year
    config["data_dir"] = config["base_dir"] + "{}/".format(year)
    return config

year_config = set_config_year(base_config, year)
pages_info = get_pages_info(year_config)
# Out:
# Number of scan files: 2161

# %% [markdown]
# ## Indexing Page Data in Elasticsearch
#
# Index the resolution volumes at the page level.
#
# Every scan contains two pages. Since index terms reference page numbers, we want to be able to access individual pages for later matching.
#
# ### Determining Page Type
#
# We want to parse index pages differently from resolution pages and filter out non-text pages and pages where the columns are not properly identified.
#
# So a first step is to use the page layout and content to distinguish pages containing indices from pages containing resolution summaries. There are also title pages, that indicate where a new part starts (e.g. indices, resolutions of the first half of the year, resolutions of the second half of the year).
#
# For examples of title pages, see: https://www.nationaalarchief.nl/onderzoeken/archief/1.01.02/inventaris?inventarisnr=3780&scans-inventarispagina=43&activeTab=gahetnascans#tab-heading

# %%
special_pages = {
    154: {
        "scan_num": 77,
        "page_num": 154,
        "type_page_num": 64,
        "special_type": "table",
    },
    155: {
        "scan_num": 77,
        "page_num": 155,
        "type_page_num": 65,
        "special_type": "table",
    },
    156: {
        "scan_num": 78,
        "page_num": 156,
        "type_page_num": 66,
        "special_type": "table",
    },
}

# %%
for page_id in pages_info:
    if pages_info[page_id]["scan_num"] > 6 or pages_info[page_id]["scan_num"] < 6:
        continue
    print(page_id)
    for column_info in pages_info[page_id]["columns"]:
        column_hocr = page_parser.get_column_hocr(column_info, year_config)
    print(pages_info[page_id])
# Out:
# year-1725-scan-6-even
#
# tiny word: {'bbox': [187, 503, 189, 505], 'width': 2, 'height': 2, 'left': 187, 'right': 189, 'top': 503, 'bottom': 505, 'word_text': '.', 'word_conf': 30}
#
#
# tiny word: {'bbox': [0, 3658, 15, 3659], 'width': 15, 'height': 1, 'left': 0, 'right': 15, 'top': 3658, 'bottom': 3659, 'word_text': '5', 'word_conf': 22}
#
#
# tiny word: {'bbox': [619, 617, 622, 621], 'width': 3, 'height': 4, 'left': 619, 'right': 622, 'top': 617, 'bottom': 621, 'word_text': 'ì', 'word_conf': 22}
#
#
# tiny word: {'bbox': [901, 619, 904, 622], 'width': 3, 'height': 3, 'left': 901, 'right': 904, 'top': 619, 'bottom': 622, 'word_text': ':', 'word_conf': 0}
#
#
# tiny word: {'bbox': [449, 1182, 451, 1185], 'width': 2, 'height': 3, 'left': 449, 'right': 451, 'top': 1182, 'bottom': 1185, 'word_text': '|', 'word_conf': 39}
#
#
# tiny word: {'bbox': [859, 1486, 862, 1492], 'width': 3, 'height': 6, 'left': 859, 'right': 862, 'top': 1486, 'bottom': 1492, 'word_text': ':', 'word_conf': 26}
#
# {'scan_num': 6, 'inventory_num': 3780, 'inventory_year': 1725, 'inventory_period': ['1725-01-01', '1725-12-31'], 'page_id': 'year-1725-scan-6-even', 'page_num': 12, 'page_side': 'even', 'columns': [{'scan_num': 6, 'scan_column': 0, 'scan_num_column_num': 6.0, 'inventory_num': 3780, 'inventory_year': 1725, 'inventory_period': ['1725-01-01', '1725-12-31'], 'page_id': 'year-1725-scan-6-even', 'page_num': 12, 'page_side': 'even', 'slant': -1.0, 'column_id': 'scan-6-even-0', 'filepath': '../../../Data/Projects/REPUBLIC/hocr/1725/NL-HaNA_1.01.02_3780_0006.jpg-0-657-131--1.10.hocr'}, {'scan_num': 6, 'scan_column': 1, 'scan_num_column_num': 6.1, 'inventory_num': 3780, 'inventory_year': 1725, 'inventory_period': ['1725-01-01', '1725-12-31'], 'page_id': 'year-1725-scan-6-even', 'page_num': 12, 'page_side': 'even', 'slant': -1.0, 'column_id': 'scan-6-even-1', 'filepath': '../../../Data/Projects/REPUBLIC/hocr/1725/NL-HaNA_1.01.02_3780_0006.jpg-1-1238-131--1.30.hocr'}]}
# year-1725-scan-6-odd
#
# tiny word: {'bbox': [101, 661, 103, 663], 'width': 2, 'height': 2, 'left': 101, 'right': 103, 'top': 661, 'bottom': 663, 'word_text': '_', 'word_conf': 39}
#
#
# tiny word: {'bbox': [279, 990, 290, 1002], 'width': 11, 'height': 12, 'left': 279, 'right': 290, 'top': 990, 'bottom': 1002, 'word_text': '“', 'word_conf': 0}
#
#
# tiny word: {'bbox': [114, 1083, 116, 1085], 'width': 2, 'height': 2, 'left': 114, 'right': 116, 'top': 1083, 'bottom': 1085, 'word_text': '-', 'word_conf': 0}
#
#
# tiny word: {'bbox': [758, 1335, 761, 1337], 'width': 3, 'height': 2, 'left': 758, 'right': 761, 'top': 1335, 'bottom': 1337, 'word_text': '|', 'word_conf': 23}
#
#
# tiny word: {'bbox': [92, 1474, 94, 1476], 'width': 2, 'height': 2, 'left': 92, 'right': 94, 'top': 1474, 'bottom': 1476, 'word_text': '-', 'word_conf': 63}
#
#
# tiny word: {'bbox': [533, 1776, 536, 1781], 'width': 3, 'height': 5, 'left': 533, 'right': 536, 'top': 1776, 'bottom': 1781, 'word_text': '|', 'word_conf': 14}
#
#
# tiny word: {'bbox': [45, 1860, 47, 1862], 'width': 2, 'height': 2, 'left': 45, 'right': 47, 'top': 1860, 'bottom': 1862, 'word_text': '_', 'word_conf': 0}
#
#
# tiny word: {'bbox': [1003, 697, 1011, 703], 'width': 8, 'height': 6, 'left': 1003, 'right': 1011, 'top': 697, 'bottom': 703, 'word_text': '|', 'word_conf': 48}
#
#
# tiny word: {'bbox': [615, 2174, 618, 2178], 'width': 3, 'height': 4, 'left': 615, 'right': 618, 'top': 2174, 'bottom': 2178, 'word_text': 'd', 'word_conf': 33}
#
#
# tiny word: {'bbox': [0, 2274, 2, 2281], 'width': 2, 'height': 7, 'left': 0, 'right': 2, 'top': 2274, 'bottom': 2281, 'word_text': '|', 'word_conf': 80}
#
#
# tiny word: {'bbox': [923, 2244, 930, 2253], 'width': 7, 'height': 9, 'left': 923, 'right': 930, 'top': 2244, 'bottom': 2253, 'word_text': ':', 'word_conf': 59}
#
#
# tiny word: {'bbox': [49, 2584, 52, 2588], 'width': 3, 'height': 4, 'left': 49, 'right': 52, 'top': 2584, 'bottom': 2588, 'word_text': '_', 'word_conf': 11}
#
# {'scan_num': 6, 'inventory_num': 3780, 'inventory_year': 1725, 'inventory_period': ['1725-01-01', '1725-12-31'], 'page_id': 'year-1725-scan-6-odd', 'page_num': 13, 'page_side': 'odd', 'columns': [{'scan_num': 6, 'scan_column': 2, 'scan_num_column_num': 6.2, 'inventory_num': 3780, 'inventory_year': 1725, 'inventory_period': ['1725-01-01', '1725-12-31'], 'page_id': 'year-1725-scan-6-odd', 'page_num': 13, 'page_side': 'odd', 'slant': -1.0, 'column_id': 'scan-6-odd-2', 'filepath': '../../../Data/Projects/REPUBLIC/hocr/1725/NL-HaNA_1.01.02_3780_0006.jpg-2-2542-131--1.10.hocr'}, {'scan_num': 6, 'scan_column': 3, 'scan_num_column_num': 6.3, 'inventory_num': 3780, 'inventory_year': 1725, 'inventory_period': ['1725-01-01', '1725-12-31'], 'page_id': 'year-1725-scan-6-odd', 'page_num': 13, 'page_side': 'odd', 'slant': 0.0, 'column_id': 'scan-6-odd-3', 'filepath': '../../../Data/Projects/REPUBLIC/hocr/1725/NL-HaNA_1.01.02_3780_0006.jpg-3-3531-131-0.20.hocr'}]}

# %%
import republic_page_parser as page_parser

page_parser.do_page_indexing(pages_info, year_config, delete_index=True)
# Out:
# exists, deleting
# year-1725-scan-1-odd bad_page 1
# year-1725-scan-4-odd bad_page 1
# year-1725-scan-5-odd index_page 1
# year-1725-scan-6-even bad_page 2
# year-1725-scan-6-odd index_page 3
# year-1725-scan-7-even index_page 4
# year-1725-scan-7-odd index_page 5
# year-1725-scan-8-even index_page 6
# year-1725-scan-8-odd index_page 7
# year-1725-scan-9-even bad_page 8
# year-1725-scan-9-odd index_page 9
# year-1725-scan-10-even index_page 10
# year-1725-scan-10-odd index_page 11
# year-1725-scan-11-even bad_page 12
# year-1725-scan-11-odd bad_page 13
# year-1725-scan-12-even index_page 14
# year-1725-scan-12-odd index_page 15
# year-1725-scan-13-even index_page 16
# year-1725-scan-13-odd index_page 17
# year-1725-scan-14-even index_page 18
# year-1725-scan-14-odd bad_page 19
# year-1725-scan-15-even index_page 20
# year-1725-scan-15-odd bad_page 21
# year-1725-scan-16-even index_page 22
# year-1725-scan-16-odd index_page 23
# year-1725-scan-17-even index_page 24
# year-1725-scan-17-odd index_page 25
# year-1725-scan-18-even index_page 26
# year-1725-scan-18-odd bad_page 27
# year-1725-scan-19-even index_page 28
# year-1725-scan-19-odd bad_page 29
# year-1725-scan-20-even index_page 30
# year-1725-scan-20-odd bad_page 31
# year-1725-scan-21-even index_page 32
# year-1725-scan-21-odd bad_page 33
# year-1725-scan-22-even index_page 34
# year-1725-scan-22-odd index_page 35
# year-1725-scan-23-even index_page 36
# year-1725-scan-23-odd bad_page 37
# year-1725-scan-24-even index_page 38
# year-1725-scan-24-odd bad_page 39
# year-1725-scan-25-even index_page 40
# year-1725-scan-25-odd index_page 41
# year-1725-scan-26-even index_page 42
# year-1725-scan-26-odd index_page 43
# year-1725-scan-27-even index_page 44
# year-1725-scan-27-odd index_page 45
# year-1725-scan-28-even index_page 46
# year-1725-scan-28-odd index_page 47
# year-1725-scan-29-even index_page 48
# year-1725-scan-29-odd bad_page 49
# year-1725-scan-30-even index_page 50
# year-1725-scan-30-odd index_page 51
# year-1725-scan-31-even index_page 52
# year-1725-scan-31-odd bad_page 53
# year-1725-scan-32-even index_page 54
# year-1725-scan-32-odd index_page 55
# year-1725-scan-33-even index_page 56
# year-1725-scan-33-odd index_page 57
# year-1725-scan-34-even index_page 58
# year-1725-scan-34-odd index_page 59
# year-1725-scan-35-even index_page 60
# year-1725-scan-35-odd index_page 61
# year-1725-scan-36-even index_page 62
# year-1725-scan-36-odd index_page 63
# year-1725-scan-37-even index_page 64
# year-1725-scan-37-odd index_page 65
# year-1725-scan-38-even index_page 66
# year-1725-scan-38-odd index_page 67
# year-1725-scan-39-even index_page 68
# year-1725-scan-39-odd index_page 69
# year-1725-scan-40-even index_page 70
# year-1725-scan-40-odd index_page 71
# year-1725-scan-41-even index_page 72
# year-1725-scan-41-odd index_page 73
# year-1725-scan-42-even index_page 74
# year-1725-scan-42-odd index_page 75
# year-1725-scan-43-even index_page 76
# year-1725-scan-43-odd index_page 77
# year-1725-scan-44-even index_page 78
# year-1725-scan-44-odd index_page 79
# year-1725-scan-45-even bad_page 80
# year-1725-scan-45-odd resolution_page 1
# year-1725-scan-46-even resolution_page 2
# year-1725-scan-46-odd resolution_page 3
# year-1725-scan-47-even resolution_page 4
# year-1725-scan-47-odd resolution_page 5
# year-1725-scan-48-even resolution_page 6
# year-1725-scan-48-odd resolution_page 7
# year-1725-scan-49-even resolution_page 8
# year-1725-scan-49-odd resolution_page 9
# year-1725-scan-50-even resolution_page 10
# year-1725-scan-50-odd resolution_page 11
# year-1725-scan-51-even resolution_page 12
# year-1725-scan-51-odd resolution_page 13
# year-1725-scan-52-even resolution_page 14
# year-1725-scan-52-odd resolution_page 15
# year-1725-scan-53-even resolution_page 16
# year-1725-scan-53-odd resolution_page 17
# year-1725-scan-54-even resolution_page 18
# year-1725-scan-54-odd resolution_page 19
# year-1725-scan-55-even resolution_page 20
# year-1725-scan-55-odd resolution_page 21
# year-1725-scan-56-even resolution_page 22
# year-1725-scan-56-odd resolution_page 23
# year-1725-scan-57-even resolution_page 24
# year-1725-scan-57-odd resolution_page 25
# year-1725-scan-58-even resolution_page 26
# year-1725-scan-58-odd resolution_page 27
# year-1725-scan-59-even resolution_page 28
# year-1725-scan-59-odd resolution_page 29
# year-1725-scan-60-even resolution_page 30
# year-1725-scan-60-odd resolution_page 31
# year-1725-scan-61-even resolution_page 32
# year-1725-scan-61-odd resolution_page 33
# year-1725-scan-62-even resolution_page 34
# year-1725-scan-62-odd resolution_page 35
# year-1725-scan-63-even resolution_page 36
# year-1725-scan-63-odd resolution_page 37
# year-1725-scan-64-even resolution_page 38
# year-1725-scan-64-odd resolution_page 39
# year-1725-scan-65-even resolution_page 40
# year-1725-scan-65-odd resolution_page 41
# year-1725-scan-66-even resolution_page 42
# year-1725-scan-66-odd resolution_page 43
# year-1725-scan-67-even resolution_page 44
# year-1725-scan-67-odd resolution_page 45
# year-1725-scan-68-even resolution_page 46
# year-1725-scan-68-odd resolution_page 47
# year-1725-scan-69-even resolution_page 48
# year-1725-scan-69-odd resolution_page 49
# year-1725-scan-70-even resolution_page 50
# year-1725-scan-70-odd resolution_page 51
# year-1725-scan-71-even resolution_page 52
# year-1725-scan-71-odd resolution_page 53
# year-1725-scan-72-even resolution_page 54
# year-1725-scan-72-odd resolution_page 55
# year-1725-scan-73-even resolution_page 56
# year-1725-scan-73-odd resolution_page 57
# year-1725-scan-74-even resolution_page 58
# year-1725-scan-74-odd resolution_page 59
# year-1725-scan-75-even resolution_page 60
# year-1725-scan-75-odd resolution_page 61
# year-1725-scan-76-even resolution_page 62
# year-1725-scan-76-odd resolution_page 63
# year-1725-scan-77-even bad_page 64
# year-1725-scan-77-odd resolution_page 65
# year-1725-scan-78-even resolution_page 66
# year-1725-scan-78-odd resolution_page 67
# year-1725-scan-79-even resolution_page 68
# year-1725-scan-79-odd resolution_page 69
# year-1725-scan-80-even resolution_page 70
# year-1725-scan-80-odd resolution_page 71
# year-1725-scan-81-even resolution_page 72
# year-1725-scan-81-odd resolution_page 73
# year-1725-scan-82-even resolution_page 74
# year-1725-scan-82-odd resolution_page 75
# year-1725-scan-83-even resolution_page 76
# year-1725-scan-83-odd resolution_page 77
# year-1725-scan-84-even resolution_page 78
# year-1725-scan-84-odd resolution_page 79
# year-1725-scan-85-even resolution_page 80
# year-1725-scan-85-odd resolution_page 81
# year-1725-scan-86-even resolution_page 82
# year-1725-scan-86-odd resolution_page 83
# year-1725-scan-87-even resolution_page 84
# year-1725-scan-87-odd resolution_page 85
# year-1725-scan-88-even resolution_page 86
# year-1725-scan-88-odd resolution_page 87
# year-1725-scan-89-even resolution_page 88
# year-1725-scan-89-odd resolution_page 89
# year-1725-scan-90-even resolution_page 90
# year-1725-scan-90-odd resolution_page 91
# year-1725-scan-91-even resolution_page 92
# year-1725-scan-91-odd resolution_page 93
# year-1725-scan-92-even resolution_page 94
# year-1725-scan-92-odd resolution_page 95
# year-1725-scan-93-even resolution_page 96
# year-1725-scan-93-odd resolution_page 97
# year-1725-scan-94-even resolution_page 98
# year-1725-scan-94-odd resolution_page 99
# year-1725-scan-95-even resolution_page 100
# year-1725-scan-95-odd resolution_page 101
# year-1725-scan-96-even resolution_page 102
# year-1725-scan-96-odd resolution_page 103
# year-1725-scan-97-even resolution_page 104
# year-1725-scan-97-odd resolution_page 105
# year-1725-scan-98-even resolution_page 106
# year-1725-scan-98-odd resolution_page 107
# year-1725-scan-99-even resolution_page 108
# year-1725-scan-99-odd resolution_page 109
# year-1725-scan-100-even resolution_page 110
# year-1725-scan-100-odd resolution_page 111
# year-1725-scan-101-even resolution_page 112
# year-1725-scan-101-odd resolution_page 113
# year-1725-scan-102-even resolution_page 114
# year-1725-scan-102-odd resolution_page 115
# year-1725-scan-103-even resolution_page 116
# year-1725-scan-103-odd resolution_page 117
# year-1725-scan-104-even resolution_page 118
# year-1725-scan-104-odd resolution_page 119
# year-1725-scan-105-even resolution_page 120
# year-1725-scan-105-odd resolution_page 121
# year-1725-scan-106-even resolution_page 122
# year-1725-scan-106-odd resolution_page 123
# year-1725-scan-107-even resolution_page 124
# year-1725-scan-107-odd resolution_page 125
# year-1725-scan-108-even resolution_page 126
# year-1725-scan-108-odd resolution_page 127
# year-1725-scan-109-even resolution_page 128
# year-1725-scan-109-odd resolution_page 129
# year-1725-scan-110-even resolution_page 130
# year-1725-scan-110-odd resolution_page 131
# year-1725-scan-111-even resolution_page 132
# year-1725-scan-111-odd resolution_page 133
# year-1725-scan-112-even resolution_page 134
# year-1725-scan-112-odd resolution_page 135
# year-1725-scan-113-even resolution_page 136
# year-1725-scan-113-odd resolution_page 137
# year-1725-scan-114-even resolution_page 138
# year-1725-scan-114-odd resolution_page 139
# year-1725-scan-115-even resolution_page 140
# year-1725-scan-115-odd resolution_page 141
# year-1725-scan-116-even resolution_page 142
# year-1725-scan-116-odd resolution_page 143
# year-1725-scan-117-even resolution_page 144
# year-1725-scan-117-odd resolution_page 145
# year-1725-scan-118-even resolution_page 146
# year-1725-scan-118-odd resolution_page 147
# year-1725-scan-119-even resolution_page 148
# year-1725-scan-119-odd resolution_page 149
# year-1725-scan-120-even resolution_page 150
# year-1725-scan-120-odd resolution_page 151
# year-1725-scan-121-even resolution_page 152
# year-1725-scan-121-odd resolution_page 153
# year-1725-scan-122-even resolution_page 154
# year-1725-scan-122-odd resolution_page 155
# year-1725-scan-123-even resolution_page 156
# year-1725-scan-123-odd resolution_page 157
# year-1725-scan-124-even resolution_page 158
# year-1725-scan-124-odd resolution_page 159
# year-1725-scan-125-even resolution_page 160
# year-1725-scan-125-odd resolution_page 161
# year-1725-scan-126-even resolution_page 162
# year-1725-scan-126-odd resolution_page 163
# year-1725-scan-127-even resolution_page 164
# year-1725-scan-127-odd resolution_page 165
# year-1725-scan-128-even resolution_page 166
# year-1725-scan-128-odd resolution_page 167
# year-1725-scan-129-even resolution_page 168
# year-1725-scan-129-odd resolution_page 169
# year-1725-scan-130-even resolution_page 170
# year-1725-scan-130-odd resolution_page 171
# year-1725-scan-131-even resolution_page 172
# year-1725-scan-131-odd resolution_page 173
# year-1725-scan-132-even resolution_page 174
# year-1725-scan-132-odd resolution_page 175
# year-1725-scan-133-even resolution_page 176
# year-1725-scan-133-odd resolution_page 177
# year-1725-scan-134-even resolution_page 178
# year-1725-scan-134-odd resolution_page 179
# year-1725-scan-135-even resolution_page 180
# year-1725-scan-135-odd resolution_page 181
# year-1725-scan-136-even resolution_page 182
# year-1725-scan-136-odd resolution_page 183
# year-1725-scan-137-even resolution_page 184
# year-1725-scan-137-odd resolution_page 185
# year-1725-scan-138-even resolution_page 186
# year-1725-scan-138-odd resolution_page 187
# year-1725-scan-139-even resolution_page 188
# year-1725-scan-139-odd resolution_page 189
# year-1725-scan-140-even resolution_page 190
# year-1725-scan-140-odd resolution_page 191
# year-1725-scan-141-even resolution_page 192
# year-1725-scan-141-odd resolution_page 193
# year-1725-scan-142-even resolution_page 194
# year-1725-scan-142-odd resolution_page 195
# year-1725-scan-143-even resolution_page 196
# year-1725-scan-143-odd resolution_page 197
# year-1725-scan-144-even resolution_page 198
# year-1725-scan-144-odd resolution_page 199
# year-1725-scan-145-even resolution_page 200
# year-1725-scan-145-odd resolution_page 201
# year-1725-scan-146-even resolution_page 202
# year-1725-scan-146-odd resolution_page 203
# year-1725-scan-147-even resolution_page 204
# year-1725-scan-147-odd resolution_page 205
# year-1725-scan-148-even resolution_page 206
# year-1725-scan-148-odd resolution_page 207
# year-1725-scan-149-even resolution_page 208
# year-1725-scan-149-odd resolution_page 209
# year-1725-scan-150-even resolution_page 210
# year-1725-scan-150-odd resolution_page 211
# year-1725-scan-151-even resolution_page 212
# year-1725-scan-151-odd resolution_page 213
# year-1725-scan-152-even resolution_page 214
# year-1725-scan-152-odd resolution_page 215
# year-1725-scan-153-even resolution_page 216
# year-1725-scan-153-odd resolution_page 217
# year-1725-scan-154-even resolution_page 218
# year-1725-scan-154-odd resolution_page 219
# year-1725-scan-155-even resolution_page 220
# year-1725-scan-155-odd resolution_page 221
# year-1725-scan-156-even resolution_page 222
# year-1725-scan-156-odd resolution_page 223
# year-1725-scan-157-even resolution_page 224
# year-1725-scan-157-odd resolution_page 225
# year-1725-scan-158-even resolution_page 226
# year-1725-scan-158-odd resolution_page 227
# year-1725-scan-159-even resolution_page 228
# year-1725-scan-159-odd resolution_page 229
# year-1725-scan-160-even resolution_page 230
# year-1725-scan-160-odd resolution_page 231
# year-1725-scan-161-even resolution_page 232
# year-1725-scan-161-odd resolution_page 233
# year-1725-scan-162-even resolution_page 234
# year-1725-scan-162-odd resolution_page 235
# year-1725-scan-163-even resolution_page 236
# year-1725-scan-163-odd resolution_page 237
# year-1725-scan-164-even resolution_page 238
# year-1725-scan-164-odd resolution_page 239
# year-1725-scan-165-even resolution_page 240
# year-1725-scan-165-odd resolution_page 241
# year-1725-scan-166-even resolution_page 242
# year-1725-scan-166-odd resolution_page 243
# year-1725-scan-167-even resolution_page 244
# year-1725-scan-167-odd resolution_page 245
# year-1725-scan-168-even resolution_page 246
# year-1725-scan-168-odd resolution_page 247
# year-1725-scan-169-even resolution_page 248
# year-1725-scan-169-odd resolution_page 249
# year-1725-scan-170-even resolution_page 250
# year-1725-scan-170-odd resolution_page 251
# year-1725-scan-171-even resolution_page 252
# year-1725-scan-171-odd resolution_page 253
# year-1725-scan-172-even resolution_page 254
# year-1725-scan-172-odd resolution_page 255
# year-1725-scan-173-even resolution_page 256
# year-1725-scan-173-odd resolution_page 257
# year-1725-scan-174-even resolution_page 258
# year-1725-scan-174-odd resolution_page 259
# year-1725-scan-175-even resolution_page 260
# year-1725-scan-175-odd resolution_page 261
# year-1725-scan-176-even resolution_page 262
# year-1725-scan-176-odd resolution_page 263
# year-1725-scan-177-even resolution_page 264
# year-1725-scan-177-odd resolution_page 265
# year-1725-scan-178-even resolution_page 266
# year-1725-scan-178-odd resolution_page 267
# year-1725-scan-179-even resolution_page 268
# year-1725-scan-179-odd resolution_page 269
# year-1725-scan-180-even resolution_page 270
# year-1725-scan-180-odd resolution_page 271
# year-1725-scan-181-even resolution_page 272
# year-1725-scan-181-odd resolution_page 273
# year-1725-scan-182-even resolution_page 274
# year-1725-scan-182-odd resolution_page 275
# year-1725-scan-183-even resolution_page 276
# year-1725-scan-183-odd resolution_page 277
# year-1725-scan-184-even resolution_page 278
# year-1725-scan-184-odd resolution_page 279
# year-1725-scan-185-even resolution_page 280
# year-1725-scan-185-odd resolution_page 281
# year-1725-scan-186-even resolution_page 282
# year-1725-scan-186-odd resolution_page 283
# year-1725-scan-187-even resolution_page 284
# year-1725-scan-187-odd resolution_page 285
# year-1725-scan-188-even resolution_page 286
# year-1725-scan-188-odd resolution_page 287
# year-1725-scan-189-even resolution_page 288
# year-1725-scan-189-odd resolution_page 289
# year-1725-scan-190-even resolution_page 290
# year-1725-scan-190-odd resolution_page 291
# year-1725-scan-191-even resolution_page 292
# year-1725-scan-191-odd resolution_page 293
# year-1725-scan-192-even resolution_page 294
# year-1725-scan-192-odd resolution_page 295
# year-1725-scan-193-even resolution_page 296
# year-1725-scan-193-odd resolution_page 297
# year-1725-scan-194-even resolution_page 298
# year-1725-scan-194-odd resolution_page 299
# year-1725-scan-195-even resolution_page 300
# year-1725-scan-195-odd resolution_page 301
# year-1725-scan-196-even resolution_page 302
# year-1725-scan-196-odd resolution_page 303
# year-1725-scan-197-even bad_page 304
# year-1725-scan-197-odd resolution_page 305
# year-1725-scan-198-even resolution_page 306
# year-1725-scan-198-odd resolution_page 307
# year-1725-scan-199-even resolution_page 308
# year-1725-scan-199-odd resolution_page 309
# year-1725-scan-200-even resolution_page 310
# year-1725-scan-200-odd resolution_page 311
# year-1725-scan-201-even resolution_page 312
# year-1725-scan-201-odd resolution_page 313
# year-1725-scan-202-even resolution_page 314
# year-1725-scan-202-odd resolution_page 315
# year-1725-scan-203-even resolution_page 316
# year-1725-scan-203-odd resolution_page 317
# year-1725-scan-204-even resolution_page 318
# year-1725-scan-204-odd resolution_page 319
# year-1725-scan-205-even resolution_page 320
# year-1725-scan-205-odd resolution_page 321
# year-1725-scan-206-even resolution_page 322
# year-1725-scan-206-odd resolution_page 323
# year-1725-scan-207-even resolution_page 324
# year-1725-scan-207-odd resolution_page 325
# year-1725-scan-208-even resolution_page 326
# year-1725-scan-208-odd resolution_page 327
# year-1725-scan-209-even resolution_page 328
# year-1725-scan-209-odd resolution_page 329
# year-1725-scan-210-even resolution_page 330
# year-1725-scan-210-odd resolution_page 331
# year-1725-scan-211-even resolution_page 332
# year-1725-scan-211-odd resolution_page 333
# year-1725-scan-212-even resolution_page 334
# year-1725-scan-212-odd resolution_page 335
# year-1725-scan-213-even resolution_page 336
# year-1725-scan-213-odd resolution_page 337
# year-1725-scan-214-even resolution_page 338
# year-1725-scan-214-odd resolution_page 339
# year-1725-scan-215-even resolution_page 340
# year-1725-scan-215-odd resolution_page 341
# year-1725-scan-216-even resolution_page 342
# year-1725-scan-216-odd resolution_page 343
# year-1725-scan-217-even resolution_page 344
# year-1725-scan-217-odd resolution_page 345
# year-1725-scan-218-even resolution_page 346
# year-1725-scan-218-odd resolution_page 347
# year-1725-scan-219-even resolution_page 348
# year-1725-scan-219-odd resolution_page 349
# year-1725-scan-220-even resolution_page 350
# year-1725-scan-220-odd resolution_page 351
# year-1725-scan-221-even resolution_page 352
# year-1725-scan-221-odd resolution_page 353
# year-1725-scan-222-even resolution_page 354
# year-1725-scan-222-odd resolution_page 355
# year-1725-scan-223-even resolution_page 356
# year-1725-scan-223-odd resolution_page 357
# year-1725-scan-224-even resolution_page 358
# year-1725-scan-224-odd resolution_page 359
# year-1725-scan-225-even resolution_page 360
# year-1725-scan-225-odd resolution_page 361
# year-1725-scan-226-even resolution_page 362
# year-1725-scan-226-odd resolution_page 363
# year-1725-scan-227-even resolution_page 364
# year-1725-scan-227-odd resolution_page 365
# year-1725-scan-228-even resolution_page 366
# year-1725-scan-228-odd resolution_page 367
# year-1725-scan-229-even resolution_page 368
# year-1725-scan-229-odd resolution_page 369
# year-1725-scan-230-even resolution_page 370
# year-1725-scan-230-odd resolution_page 371
# year-1725-scan-231-even resolution_page 372
# year-1725-scan-231-odd resolution_page 373
# year-1725-scan-232-even resolution_page 374
# year-1725-scan-232-odd resolution_page 375
# year-1725-scan-233-even resolution_page 376
# year-1725-scan-233-odd resolution_page 377
# year-1725-scan-234-even resolution_page 378
# year-1725-scan-234-odd resolution_page 379
# year-1725-scan-235-even resolution_page 380
# year-1725-scan-235-odd resolution_page 381
# year-1725-scan-236-even resolution_page 382
# year-1725-scan-236-odd resolution_page 383
# year-1725-scan-237-even resolution_page 384
# year-1725-scan-237-odd resolution_page 385
# year-1725-scan-238-even resolution_page 386
# year-1725-scan-238-odd resolution_page 387
# year-1725-scan-239-even resolution_page 388
# year-1725-scan-239-odd resolution_page 389
# year-1725-scan-240-even resolution_page 390
# year-1725-scan-240-odd resolution_page 391
# year-1725-scan-241-even resolution_page 392
# year-1725-scan-241-odd resolution_page 393
# year-1725-scan-242-even resolution_page 394
# year-1725-scan-242-odd resolution_page 395
# year-1725-scan-243-even resolution_page 396
# year-1725-scan-243-odd resolution_page 397
# year-1725-scan-244-even resolution_page 398
# year-1725-scan-244-odd resolution_page 399
# year-1725-scan-245-even resolution_page 400
# year-1725-scan-245-odd resolution_page 401
# year-1725-scan-246-even resolution_page 402
# year-1725-scan-246-odd resolution_page 403
# year-1725-scan-247-even resolution_page 404
# year-1725-scan-247-odd resolution_page 405
# year-1725-scan-248-even resolution_page 406
# year-1725-scan-248-odd resolution_page 407
# year-1725-scan-249-even resolution_page 408
# year-1725-scan-249-odd resolution_page 409
# year-1725-scan-250-even resolution_page 410
# year-1725-scan-250-odd resolution_page 411
# year-1725-scan-251-even resolution_page 412
# year-1725-scan-251-odd resolution_page 413
# year-1725-scan-252-even resolution_page 414
# year-1725-scan-252-odd resolution_page 415
# year-1725-scan-253-even resolution_page 416
# year-1725-scan-253-odd resolution_page 417
# year-1725-scan-254-even resolution_page 418
# year-1725-scan-254-odd resolution_page 419
# year-1725-scan-255-even resolution_page 420
# year-1725-scan-255-odd resolution_page 421
# year-1725-scan-256-even resolution_page 422
# year-1725-scan-256-odd resolution_page 423
# year-1725-scan-257-even resolution_page 424
# year-1725-scan-257-odd resolution_page 425
# year-1725-scan-258-even resolution_page 426
# year-1725-scan-258-odd resolution_page 427
# year-1725-scan-259-even resolution_page 428
# year-1725-scan-259-odd resolution_page 429
# year-1725-scan-260-even resolution_page 430
# year-1725-scan-260-odd resolution_page 431
# year-1725-scan-261-even resolution_page 432
# year-1725-scan-261-odd resolution_page 433
# year-1725-scan-262-even resolution_page 434
# year-1725-scan-262-odd resolution_page 435
# year-1725-scan-263-even resolution_page 436
# year-1725-scan-263-odd resolution_page 437
# year-1725-scan-264-even resolution_page 438
# year-1725-scan-264-odd resolution_page 439
# year-1725-scan-265-even resolution_page 440
# year-1725-scan-265-odd resolution_page 441
# year-1725-scan-266-even resolution_page 442
# year-1725-scan-266-odd resolution_page 443
# year-1725-scan-267-even resolution_page 444
# year-1725-scan-267-odd resolution_page 445
# year-1725-scan-268-even resolution_page 446
# year-1725-scan-268-odd resolution_page 447
# year-1725-scan-269-even resolution_page 448
# year-1725-scan-269-odd resolution_page 449
# year-1725-scan-270-even resolution_page 450
# year-1725-scan-270-odd resolution_page 451
# year-1725-scan-271-even resolution_page 452
# year-1725-scan-271-odd resolution_page 453
# year-1725-scan-272-even resolution_page 454
# year-1725-scan-272-odd resolution_page 455
# year-1725-scan-273-even resolution_page 456
# year-1725-scan-273-odd resolution_page 457
# year-1725-scan-274-even resolution_page 458
# year-1725-scan-274-odd resolution_page 459
# year-1725-scan-275-even resolution_page 460
# year-1725-scan-275-odd resolution_page 461
# year-1725-scan-276-even resolution_page 462
# year-1725-scan-276-odd resolution_page 463
# year-1725-scan-277-even resolution_page 464
# year-1725-scan-277-odd resolution_page 465
# year-1725-scan-278-even resolution_page 466
# year-1725-scan-278-odd resolution_page 467
# year-1725-scan-279-even resolution_page 468
# year-1725-scan-279-odd resolution_page 469
# year-1725-scan-280-even resolution_page 470
# year-1725-scan-280-odd resolution_page 471
# year-1725-scan-281-even resolution_page 472
# year-1725-scan-281-odd resolution_page 473
# year-1725-scan-282-odd bad_page 1
# year-1725-scan-283-odd resolution_page 1
# year-1725-scan-284-even resolution_page 2
# year-1725-scan-284-odd resolution_page 3
# year-1725-scan-285-even resolution_page 4
# year-1725-scan-285-odd resolution_page 5
# year-1725-scan-286-even resolution_page 6
# year-1725-scan-286-odd resolution_page 7
# year-1725-scan-287-even resolution_page 8
# year-1725-scan-287-odd resolution_page 9
# year-1725-scan-288-even resolution_page 10
# year-1725-scan-288-odd resolution_page 11
# year-1725-scan-289-even resolution_page 12
# year-1725-scan-289-odd resolution_page 13
# year-1725-scan-290-even resolution_page 14
# year-1725-scan-290-odd resolution_page 15
# year-1725-scan-291-even resolution_page 16
# year-1725-scan-291-odd resolution_page 17
# year-1725-scan-292-even resolution_page 18
# year-1725-scan-292-odd resolution_page 19
# year-1725-scan-293-even resolution_page 20
# year-1725-scan-293-odd resolution_page 21
# year-1725-scan-294-even resolution_page 22
# year-1725-scan-294-odd resolution_page 23
# year-1725-scan-295-even resolution_page 24
# year-1725-scan-295-odd resolution_page 25
# year-1725-scan-296-even resolution_page 26
# year-1725-scan-296-odd resolution_page 27
# year-1725-scan-297-even resolution_page 28
# year-1725-scan-297-odd resolution_page 29
# year-1725-scan-298-even bad_page 30
# year-1725-scan-298-odd resolution_page 31
# year-1725-scan-299-even resolution_page 32
# year-1725-scan-299-odd resolution_page 33
# year-1725-scan-300-even resolution_page 34
# year-1725-scan-300-odd resolution_page 35
# year-1725-scan-301-even resolution_page 36
# year-1725-scan-301-odd resolution_page 37
# year-1725-scan-302-even resolution_page 38
# year-1725-scan-302-odd resolution_page 39
# year-1725-scan-303-even resolution_page 40
# year-1725-scan-303-odd resolution_page 41
# year-1725-scan-304-even resolution_page 42
# year-1725-scan-304-odd resolution_page 43
# year-1725-scan-305-even resolution_page 44
# year-1725-scan-305-odd resolution_page 45
# year-1725-scan-306-even resolution_page 46
# year-1725-scan-306-odd resolution_page 47
# year-1725-scan-307-even resolution_page 48
# year-1725-scan-307-odd resolution_page 49
# year-1725-scan-308-even resolution_page 50
# year-1725-scan-308-odd resolution_page 51
# year-1725-scan-309-even resolution_page 52
# year-1725-scan-309-odd resolution_page 53
# year-1725-scan-310-even resolution_page 54
# year-1725-scan-310-odd resolution_page 55
# year-1725-scan-311-even resolution_page 56
# year-1725-scan-311-odd resolution_page 57
# year-1725-scan-312-even resolution_page 58
# year-1725-scan-312-odd resolution_page 59
# year-1725-scan-313-even resolution_page 60
# year-1725-scan-313-odd resolution_page 61
# year-1725-scan-314-even resolution_page 62
# year-1725-scan-314-odd resolution_page 63
# year-1725-scan-315-even resolution_page 64
# year-1725-scan-315-odd resolution_page 65
# year-1725-scan-316-even resolution_page 66
# year-1725-scan-316-odd resolution_page 67
# year-1725-scan-317-even resolution_page 68
# year-1725-scan-317-odd resolution_page 69
# year-1725-scan-318-even resolution_page 70
# year-1725-scan-318-odd resolution_page 71
# year-1725-scan-319-even resolution_page 72
# year-1725-scan-319-odd resolution_page 73
# year-1725-scan-320-even resolution_page 74
# year-1725-scan-320-odd resolution_page 75
# year-1725-scan-321-even resolution_page 76
# year-1725-scan-321-odd resolution_page 77
# year-1725-scan-322-even resolution_page 78
# year-1725-scan-322-odd resolution_page 79
# year-1725-scan-323-even resolution_page 80
# year-1725-scan-323-odd resolution_page 81
# year-1725-scan-324-even resolution_page 82
# year-1725-scan-324-odd resolution_page 83
# year-1725-scan-325-even resolution_page 84
# year-1725-scan-325-odd resolution_page 85
# year-1725-scan-326-even resolution_page 86
# year-1725-scan-326-odd resolution_page 87
# year-1725-scan-327-even resolution_page 88
# year-1725-scan-327-odd resolution_page 89
# year-1725-scan-328-even resolution_page 90
# year-1725-scan-328-odd resolution_page 91
# year-1725-scan-329-even resolution_page 92
# year-1725-scan-329-odd resolution_page 93
# year-1725-scan-330-even resolution_page 94
# year-1725-scan-330-odd resolution_page 95
# year-1725-scan-331-even resolution_page 96
# year-1725-scan-331-odd resolution_page 97
# year-1725-scan-332-even resolution_page 98
# year-1725-scan-332-odd bad_page 99
# year-1725-scan-333-even bad_page 100
# year-1725-scan-333-odd bad_page 101
# year-1725-scan-334-even bad_page 102
# Error parsing file ../../../Data/Projects/REPUBLIC/hocr/1725/NL-HaNA_1.01.02_3780_0334.jpg-2-2253-75--0.00.hocr
# year-1725-scan-334-odd bad_page 103
# year-1725-scan-335-even bad_page 104
# year-1725-scan-335-odd bad_page 105
# year-1725-scan-336-even bad_page 106
# year-1725-scan-336-odd bad_page 107
# year-1725-scan-337-even bad_page 108
# year-1725-scan-337-odd bad_page 109
# year-1725-scan-338-even bad_page 110
# year-1725-scan-338-odd bad_page 111
# year-1725-scan-339-even bad_page 112
# year-1725-scan-339-odd resolution_page 113
# year-1725-scan-340-even resolution_page 114
# year-1725-scan-340-odd resolution_page 115
# year-1725-scan-341-even resolution_page 116
# year-1725-scan-341-odd resolution_page 117
# year-1725-scan-342-even resolution_page 118
# year-1725-scan-342-odd resolution_page 119
# year-1725-scan-343-even resolution_page 120
# year-1725-scan-343-odd resolution_page 121
# year-1725-scan-344-even resolution_page 122
# year-1725-scan-344-odd resolution_page 123
# year-1725-scan-345-even resolution_page 124
# year-1725-scan-345-odd resolution_page 125
# year-1725-scan-346-even resolution_page 126
# year-1725-scan-346-odd resolution_page 127
# year-1725-scan-347-even resolution_page 128
# year-1725-scan-347-odd resolution_page 129
# year-1725-scan-348-even resolution_page 130
# year-1725-scan-348-odd resolution_page 131
# year-1725-scan-349-even resolution_page 132
# year-1725-scan-349-odd resolution_page 133
# year-1725-scan-350-even resolution_page 134
# year-1725-scan-350-odd resolution_page 135
# year-1725-scan-351-even resolution_page 136
# year-1725-scan-351-odd resolution_page 137
# year-1725-scan-352-even resolution_page 138
# year-1725-scan-352-odd resolution_page 139
# year-1725-scan-353-even resolution_page 140
# year-1725-scan-353-odd resolution_page 141
# year-1725-scan-354-even resolution_page 142
# year-1725-scan-354-odd bad_page 143
# year-1725-scan-355-even resolution_page 144
# year-1725-scan-355-odd resolution_page 145
# year-1725-scan-356-even resolution_page 146
# year-1725-scan-356-odd bad_page 147
# year-1725-scan-357-even resolution_page 148
# year-1725-scan-357-odd resolution_page 149
# year-1725-scan-358-even resolution_page 150
# year-1725-scan-358-odd resolution_page 151
# year-1725-scan-359-even resolution_page 152
# year-1725-scan-359-odd resolution_page 153
# year-1725-scan-360-even resolution_page 154
# year-1725-scan-360-odd resolution_page 155
# year-1725-scan-361-even resolution_page 156
# year-1725-scan-361-odd resolution_page 157
# year-1725-scan-362-even resolution_page 158
# year-1725-scan-362-odd resolution_page 159
# year-1725-scan-363-even resolution_page 160
# year-1725-scan-363-odd resolution_page 161
# year-1725-scan-364-even resolution_page 162
# year-1725-scan-364-odd resolution_page 163
# year-1725-scan-365-even resolution_page 164
# year-1725-scan-365-odd resolution_page 165
# year-1725-scan-366-even resolution_page 166
# year-1725-scan-366-odd resolution_page 167
# year-1725-scan-367-even resolution_page 168
# year-1725-scan-367-odd resolution_page 169
# year-1725-scan-368-even resolution_page 170
# year-1725-scan-368-odd resolution_page 171
# year-1725-scan-369-even resolution_page 172
# year-1725-scan-369-odd resolution_page 173
# year-1725-scan-370-even resolution_page 174
# year-1725-scan-370-odd resolution_page 175
# year-1725-scan-371-even resolution_page 176
# year-1725-scan-371-odd resolution_page 177
# year-1725-scan-372-even resolution_page 178
# year-1725-scan-372-odd resolution_page 179
# year-1725-scan-373-even resolution_page 180
# year-1725-scan-373-odd resolution_page 181
# year-1725-scan-374-even resolution_page 182
# year-1725-scan-374-odd resolution_page 183
# year-1725-scan-375-even resolution_page 184
# year-1725-scan-375-odd resolution_page 185
# year-1725-scan-376-even resolution_page 186
# year-1725-scan-376-odd resolution_page 187
# year-1725-scan-377-even resolution_page 188
# year-1725-scan-377-odd resolution_page 189
# year-1725-scan-378-even resolution_page 190
# year-1725-scan-378-odd resolution_page 191
# year-1725-scan-379-even resolution_page 192
# year-1725-scan-379-odd resolution_page 193
# year-1725-scan-380-even resolution_page 194
# year-1725-scan-380-odd resolution_page 195
# year-1725-scan-381-even resolution_page 196
# year-1725-scan-381-odd resolution_page 197
# year-1725-scan-382-even resolution_page 198
# year-1725-scan-382-odd resolution_page 199
# year-1725-scan-383-even resolution_page 200
# year-1725-scan-383-odd resolution_page 201
# year-1725-scan-384-even resolution_page 202
# year-1725-scan-384-odd resolution_page 203
# year-1725-scan-385-even resolution_page 204
# year-1725-scan-385-odd resolution_page 205
# year-1725-scan-386-even resolution_page 206
# year-1725-scan-386-odd resolution_page 207
# year-1725-scan-387-even resolution_page 208
# year-1725-scan-387-odd resolution_page 209
# year-1725-scan-388-even resolution_page 210
# year-1725-scan-388-odd resolution_page 211
# year-1725-scan-389-even resolution_page 212
# year-1725-scan-389-odd resolution_page 213
# year-1725-scan-390-even resolution_page 214
# year-1725-scan-390-odd resolution_page 215
# year-1725-scan-391-even resolution_page 216
# year-1725-scan-391-odd resolution_page 217
# year-1725-scan-392-even resolution_page 218
# year-1725-scan-392-odd resolution_page 219
# year-1725-scan-393-even resolution_page 220
# year-1725-scan-393-odd resolution_page 221
# year-1725-scan-394-even resolution_page 222
# year-1725-scan-394-odd resolution_page 223
# year-1725-scan-395-even resolution_page 224
# year-1725-scan-395-odd resolution_page 225
# year-1725-scan-396-even resolution_page 226
# year-1725-scan-396-odd resolution_page 227
# year-1725-scan-397-even resolution_page 228
# year-1725-scan-397-odd resolution_page 229
# year-1725-scan-398-even resolution_page 230
# year-1725-scan-398-odd resolution_page 231
# year-1725-scan-399-even resolution_page 232
# year-1725-scan-399-odd resolution_page 233
# year-1725-scan-400-even resolution_page 234
# year-1725-scan-438-even resolution_page 310
# year-1725-scan-438-odd resolution_page 311
# year-1725-scan-439-even resolution_page 312
# year-1725-scan-439-odd resolution_page 313
# year-1725-scan-440-even resolution_page 314
# year-1725-scan-440-odd resolution_page 315
# year-1725-scan-441-even resolution_page 316
# year-1725-scan-441-odd resolution_page 317
# year-1725-scan-442-even resolution_page 318
# year-1725-scan-442-odd resolution_page 319
# year-1725-scan-443-even resolution_page 320
# year-1725-scan-443-odd resolution_page 321
# year-1725-scan-444-even resolution_page 322
# year-1725-scan-444-odd resolution_page 323
# year-1725-scan-445-even resolution_page 324
# year-1725-scan-445-odd resolution_page 325
# year-1725-scan-446-even resolution_page 326
# year-1725-scan-446-odd resolution_page 327
# year-1725-scan-447-even resolution_page 328
# year-1725-scan-447-odd resolution_page 329
# year-1725-scan-448-even resolution_page 330
# year-1725-scan-448-odd resolution_page 331
# year-1725-scan-449-even resolution_page 332
# year-1725-scan-449-odd resolution_page 333
# year-1725-scan-450-even resolution_page 334
# year-1725-scan-450-odd resolution_page 335
# year-1725-scan-451-even resolution_page 336
# year-1725-scan-451-odd resolution_page 337
# year-1725-scan-452-even resolution_page 338
# year-1725-scan-452-odd resolution_page 339
# year-1725-scan-453-even resolution_page 340
# year-1725-scan-453-odd resolution_page 341
# year-1725-scan-454-even resolution_page 342
# year-1725-scan-454-odd resolution_page 343
# year-1725-scan-455-even resolution_page 344
# year-1725-scan-455-odd resolution_page 345
# year-1725-scan-456-even resolution_page 346
# year-1725-scan-456-odd resolution_page 347
# year-1725-scan-457-even resolution_page 348
# year-1725-scan-457-odd resolution_page 349
# year-1725-scan-458-even resolution_page 350
# year-1725-scan-458-odd resolution_page 351
# year-1725-scan-459-even resolution_page 352
# year-1725-scan-459-odd resolution_page 353
# year-1725-scan-460-even resolution_page 354
# year-1725-scan-460-odd resolution_page 355
# year-1725-scan-461-even resolution_page 356
# year-1725-scan-461-odd resolution_page 357
# year-1725-scan-462-even resolution_page 358
# year-1725-scan-462-odd resolution_page 359
# year-1725-scan-463-even resolution_page 360
# year-1725-scan-463-odd resolution_page 361
# year-1725-scan-464-even resolution_page 362
# year-1725-scan-464-odd resolution_page 363
# year-1725-scan-465-even resolution_page 364
# year-1725-scan-465-odd bad_page 365
# year-1725-scan-466-even bad_page 366
# year-1725-scan-466-odd bad_page 367
# year-1725-scan-467-even bad_page 368
# year-1725-scan-467-odd bad_page 369
# year-1725-scan-468-even resolution_page 370
# year-1725-scan-468-odd resolution_page 371
# year-1725-scan-469-even resolution_page 372
# year-1725-scan-469-odd resolution_page 373
# year-1725-scan-470-even resolution_page 374
# year-1725-scan-470-odd resolution_page 375
# year-1725-scan-471-even resolution_page 376
# year-1725-scan-471-odd resolution_page 377
# year-1725-scan-472-even resolution_page 378
# year-1725-scan-472-odd resolution_page 379
# year-1725-scan-473-even resolution_page 380
# year-1725-scan-473-odd resolution_page 381
# year-1725-scan-474-even resolution_page 382
# year-1725-scan-474-odd resolution_page 383
# year-1725-scan-475-even resolution_page 384
# year-1725-scan-475-odd resolution_page 385
# year-1725-scan-476-even resolution_page 386
# year-1725-scan-476-odd resolution_page 387
# year-1725-scan-477-even resolution_page 388
# year-1725-scan-477-odd resolution_page 389
# year-1725-scan-478-even resolution_page 390
# year-1725-scan-478-odd resolution_page 391
# year-1725-scan-479-even resolution_page 392
# year-1725-scan-479-odd resolution_page 393
# year-1725-scan-480-even resolution_page 394
# year-1725-scan-480-odd resolution_page 395
# year-1725-scan-481-even resolution_page 396
# year-1725-scan-481-odd resolution_page 397
# year-1725-scan-482-even resolution_page 398
# year-1725-scan-482-odd resolution_page 399
# year-1725-scan-483-even resolution_page 400
# year-1725-scan-483-odd resolution_page 401
# year-1725-scan-484-even resolution_page 402
# year-1725-scan-484-odd resolution_page 403
# year-1725-scan-485-even resolution_page 404
# year-1725-scan-485-odd resolution_page 405
# year-1725-scan-486-even resolution_page 406
# year-1725-scan-486-odd resolution_page 407
# year-1725-scan-487-even resolution_page 408
# year-1725-scan-487-odd resolution_page 409
# year-1725-scan-488-even resolution_page 410
# year-1725-scan-488-odd resolution_page 411
# year-1725-scan-489-even resolution_page 412
# year-1725-scan-489-odd resolution_page 413
# year-1725-scan-490-even bad_page 414
# year-1725-scan-490-odd bad_page 415
# year-1725-scan-491-even bad_page 416
# year-1725-scan-491-odd bad_page 417
# year-1725-scan-492-even bad_page 418
# year-1725-scan-492-odd bad_page 419
# year-1725-scan-493-even bad_page 420
# year-1725-scan-493-odd bad_page 421
# year-1725-scan-494-even bad_page 422
# year-1725-scan-494-odd resolution_page 423
# year-1725-scan-495-even resolution_page 424
# year-1725-scan-495-odd resolution_page 425
# year-1725-scan-496-even resolution_page 426
# year-1725-scan-496-odd resolution_page 427
# year-1725-scan-497-even resolution_page 428
# year-1725-scan-497-odd resolution_page 429
# year-1725-scan-498-even resolution_page 430
# year-1725-scan-498-odd resolution_page 431
# year-1725-scan-499-even resolution_page 432
# year-1725-scan-499-odd resolution_page 433
# year-1725-scan-500-even resolution_page 434
# year-1725-scan-500-odd resolution_page 435
# year-1725-scan-501-even resolution_page 436
# year-1725-scan-501-odd resolution_page 437
# year-1725-scan-502-even resolution_page 438
# year-1725-scan-502-odd resolution_page 439
# year-1725-scan-503-even resolution_page 440
# year-1725-scan-503-odd resolution_page 441
# year-1725-scan-504-even resolution_page 442
# year-1725-scan-504-odd resolution_page 443
# year-1725-scan-505-even resolution_page 444
# year-1725-scan-505-odd resolution_page 445
# year-1725-scan-506-even resolution_page 446
# year-1725-scan-506-odd resolution_page 447
# year-1725-scan-507-even resolution_page 448
# year-1725-scan-507-odd resolution_page 449
# year-1725-scan-508-even resolution_page 450
# year-1725-scan-508-odd resolution_page 451
# year-1725-scan-509-even resolution_page 452
# year-1725-scan-509-odd bad_page 453
# year-1725-scan-510-even resolution_page 454
# year-1725-scan-510-odd resolution_page 455
# year-1725-scan-511-even resolution_page 456
# year-1725-scan-511-odd resolution_page 457
# year-1725-scan-512-even resolution_page 458
# year-1725-scan-512-odd resolution_page 459
# year-1725-scan-513-even resolution_page 460
# year-1725-scan-513-odd resolution_page 461
# year-1725-scan-514-even resolution_page 462
# year-1725-scan-514-odd resolution_page 463
# year-1725-scan-515-even resolution_page 464
# year-1725-scan-515-odd resolution_page 465
# year-1725-scan-516-even resolution_page 466
# year-1725-scan-516-odd resolution_page 467
# year-1725-scan-517-even resolution_page 468
# year-1725-scan-517-odd resolution_page 469
# year-1725-scan-518-even resolution_page 470
# year-1725-scan-518-odd resolution_page 471
# year-1725-scan-519-even resolution_page 472
# year-1725-scan-519-odd resolution_page 473
# year-1725-scan-520-even bad_page 474
# year-1725-scan-520-odd resolution_page 475
# year-1725-scan-521-even resolution_page 476
# year-1725-scan-521-odd resolution_page 477
# year-1725-scan-522-even resolution_page 478
# year-1725-scan-522-odd resolution_page 479
# year-1725-scan-523-even resolution_page 480
# year-1725-scan-523-odd resolution_page 481
# year-1725-scan-524-even resolution_page 482
# year-1725-scan-524-odd resolution_page 483
# year-1725-scan-525-even resolution_page 484
# year-1725-scan-525-odd resolution_page 485
# year-1725-scan-526-even bad_page 486
# year-1725-scan-526-odd bad_page 487
# year-1725-scan-527-even bad_page 488
# year-1725-scan-527-odd resolution_page 489
# year-1725-scan-528-even resolution_page 490
# year-1725-scan-528-odd resolution_page 491
# year-1725-scan-529-even resolution_page 492
# year-1725-scan-529-odd resolution_page 493
# year-1725-scan-530-even resolution_page 494
# year-1725-scan-530-odd resolution_page 495
# year-1725-scan-531-even resolution_page 496
# year-1725-scan-531-odd resolution_page 497
# year-1725-scan-532-even resolution_page 498
# year-1725-scan-532-odd resolution_page 499
# year-1725-scan-533-even resolution_page 500
# year-1725-scan-533-odd resolution_page 501
# year-1725-scan-534-even resolution_page 502
# year-1725-scan-534-odd resolution_page 503
# year-1725-scan-535-even resolution_page 504
# year-1725-scan-535-odd resolution_page 505
# year-1725-scan-536-even resolution_page 506
# year-1725-scan-536-odd resolution_page 507
# year-1725-scan-537-even resolution_page 508
# year-1725-scan-537-odd resolution_page 509
# year-1725-scan-538-even bad_page 510
# year-1725-scan-542-even bad_page 1

# %% [markdown]
# ### Adjusting Incorrect Page Type Assignments and Numbered Page Numbers
#
# **Problem 1**: For some pages the page type may be incorrectly identified (e.g. an index page identified as a resolution page or vice versa). This mainly happens on pages with little text content or pages where the columns are misidentified.
#
# **Solution**: Using the title pages as part separators, and knowing that the indices precede the resolution pages, we can identify misclassified page and correct their labels.
#
# **Problem 2**: Some pages are duplicates of the preceding scan. When the page turning mechanism fails, subsequent scans are images of the same two pages. Duplicates page should therefore come in pairs, that is, even and odd side of scan $n$ are duplicates of even and odd side of scan $n-1$. Shingling or straightforward text tiling won't work because of OCR variation. Many words may be recognized slightly different and lines and words may not align.
#
# **Solution**: Compare each pair of even+odd pages against preceding pair of even+odd pages, using Levenshtein distance. This deals with slight character-level variations due to OCR. Most pairs will be very dissimilar. Use a heuristic threshold to determine whether pages are duplicates.
#
# **Problem 3**: A second problem is that page numbers of numbered pages are reset per part, starting from page 1, but the title page separating the first and second halves of the year should not reset the page numbering.
#
# **Solution**: Iterate over the pages, using a flag to keep track of whether we're in the indices part or a resolution part. If the title page is within the resolution part, update the page numbers by incrementing from the previous page.

# %%
import republic_page_checks

republic_page_checks.correct_page_types(year_config)
# Out:
# correcting: year-1725-scan-1-odd None bad_page False
# Switching to part index_page
# correcting: year-1725-scan-4-odd index_page bad_page False
# correcting: year-1725-scan-6-even index_page bad_page False
# correcting: year-1725-scan-9-even index_page bad_page False
# correcting: year-1725-scan-11-even index_page bad_page False
# correcting: year-1725-scan-11-odd index_page bad_page False
# correcting: year-1725-scan-14-odd index_page bad_page False
# correcting: year-1725-scan-15-odd index_page bad_page False
# correcting: year-1725-scan-18-odd index_page bad_page False
# correcting: year-1725-scan-19-odd index_page bad_page False
# correcting: year-1725-scan-20-odd index_page bad_page False
# correcting: year-1725-scan-21-odd index_page bad_page False
# correcting: year-1725-scan-23-odd index_page bad_page False
# correcting: year-1725-scan-24-odd index_page bad_page False
# correcting: year-1725-scan-29-odd index_page bad_page False
# correcting: year-1725-scan-31-odd index_page bad_page False
# correcting: year-1725-scan-45-even index_page bad_page False
# Switching to part resolution_page
# correcting: year-1725-scan-77-even resolution_page bad_page False
# correcting: year-1725-scan-197-even resolution_page bad_page False
# Switching to part resolution_page
# correcting: year-1725-scan-282-odd resolution_page bad_page False
# correcting: year-1725-scan-298-even resolution_page bad_page False
# correcting: year-1725-scan-332-odd resolution_page bad_page False
# correcting: year-1725-scan-333-even resolution_page bad_page False
# correcting: year-1725-scan-333-odd resolution_page bad_page False
# correcting: year-1725-scan-334-even resolution_page bad_page False
# correcting: year-1725-scan-334-odd resolution_page bad_page False
# correcting: year-1725-scan-335-even resolution_page bad_page False
# correcting: year-1725-scan-335-odd resolution_page bad_page False
# correcting: year-1725-scan-336-even resolution_page bad_page False
# correcting: year-1725-scan-336-odd resolution_page bad_page False
# correcting: year-1725-scan-337-even resolution_page bad_page False
# correcting: year-1725-scan-337-odd resolution_page bad_page False
# correcting: year-1725-scan-338-even resolution_page bad_page False
# correcting: year-1725-scan-338-odd resolution_page bad_page False
# correcting: year-1725-scan-339-even resolution_page bad_page False
# correcting: year-1725-scan-354-odd resolution_page bad_page False
# correcting: year-1725-scan-356-odd resolution_page bad_page False
# correcting: year-1725-scan-465-odd resolution_page bad_page False
# correcting: year-1725-scan-466-even resolution_page bad_page False
# correcting: year-1725-scan-466-odd resolution_page bad_page False
# correcting: year-1725-scan-467-even resolution_page bad_page False
# correcting: year-1725-scan-467-odd resolution_page bad_page False
# correcting: year-1725-scan-490-even resolution_page bad_page False
# correcting: year-1725-scan-490-odd resolution_page bad_page False
# correcting: year-1725-scan-491-even resolution_page bad_page False
# correcting: year-1725-scan-491-odd resolution_page bad_page False
# correcting: year-1725-scan-492-even resolution_page bad_page False
# correcting: year-1725-scan-492-odd resolution_page bad_page False
# correcting: year-1725-scan-493-even resolution_page bad_page False
# correcting: year-1725-scan-493-odd resolution_page bad_page False
# correcting: year-1725-scan-494-even resolution_page bad_page False
# correcting: year-1725-scan-509-odd resolution_page bad_page False
# correcting: year-1725-scan-520-even resolution_page bad_page False
# correcting: year-1725-scan-526-even resolution_page bad_page False
# correcting: year-1725-scan-526-odd resolution_page bad_page False
# correcting: year-1725-scan-527-even resolution_page bad_page False
# correcting: year-1725-scan-538-even resolution_page bad_page False
# Switching to part resolution_page
# correcting: year-1725-scan-542-even resolution_page bad_page False
#
# Done!

# %%
republic_page_checks.detect_duplicate_scans(year_config)
# Out:
# Page year-1725-scan-139-even is duplicate of page year-1725-scan-138-even
# Page year-1725-scan-139-odd is duplicate of page year-1725-scan-138-odd
# Page year-1725-scan-279-even is duplicate of page year-1725-scan-278-even
# Page year-1725-scan-279-odd is duplicate of page year-1725-scan-278-odd
# Page year-1725-scan-286-even is duplicate of page year-1725-scan-285-even
# Page year-1725-scan-286-odd is duplicate of page year-1725-scan-285-odd
# Page year-1725-scan-492-even is duplicate of page year-1725-scan-491-even
# Page year-1725-scan-492-odd is duplicate of page year-1725-scan-491-odd
#
# Done!

# %%
republic_page_checks.correct_page_numbers(year_config)
# Out:
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-139-even 188 186
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-139-odd 189 187
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-140-even FROM 190 TO 188:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-140-odd FROM 191 TO 189:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-141-even FROM 192 TO 190:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-141-odd FROM 193 TO 191:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-142-even FROM 194 TO 192:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-142-odd FROM 195 TO 193:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-143-even FROM 196 TO 194:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-143-odd FROM 197 TO 195:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-144-even FROM 198 TO 196:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-144-odd FROM 199 TO 197:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-145-even FROM 200 TO 198:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-145-odd FROM 201 TO 199:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-146-even FROM 202 TO 200:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-146-odd FROM 203 TO 201:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-147-even FROM 204 TO 202:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-147-odd FROM 205 TO 203:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-148-even FROM 206 TO 204:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-148-odd FROM 207 TO 205:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-149-even FROM 208 TO 206:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-149-odd FROM 209 TO 207:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-150-even FROM 210 TO 208:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-150-odd FROM 211 TO 209:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-151-even FROM 212 TO 210:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-151-odd FROM 213 TO 211:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-152-even FROM 214 TO 212:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-152-odd FROM 215 TO 213:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-153-even FROM 216 TO 214:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-153-odd FROM 217 TO 215:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-154-even FROM 218 TO 216:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-154-odd FROM 219 TO 217:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-155-even FROM 220 TO 218:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-155-odd FROM 221 TO 219:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-156-even FROM 222 TO 220:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-156-odd FROM 223 TO 221:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-157-even FROM 224 TO 222:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-157-odd FROM 225 TO 223:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-158-even FROM 226 TO 224:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-158-odd FROM 227 TO 225:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-159-even FROM 228 TO 226:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-159-odd FROM 229 TO 227:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-160-even FROM 230 TO 228:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-160-odd FROM 231 TO 229:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-161-even FROM 232 TO 230:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-161-odd FROM 233 TO 231:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-162-even FROM 234 TO 232:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-162-odd FROM 235 TO 233:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-163-even FROM 236 TO 234:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-163-odd FROM 237 TO 235:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-164-even FROM 238 TO 236:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-164-odd FROM 239 TO 237:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-165-even FROM 240 TO 238:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-165-odd FROM 241 TO 239:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-166-even FROM 242 TO 240:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-166-odd FROM 243 TO 241:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-167-even FROM 244 TO 242:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-167-odd FROM 245 TO 243:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-168-even FROM 246 TO 244:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-168-odd FROM 247 TO 245:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-169-even FROM 248 TO 246:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-169-odd FROM 249 TO 247:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-170-even FROM 250 TO 248:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-170-odd FROM 251 TO 249:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-171-even FROM 252 TO 250:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-171-odd FROM 253 TO 251:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-172-even FROM 254 TO 252:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-172-odd FROM 255 TO 253:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-173-even FROM 256 TO 254:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-173-odd FROM 257 TO 255:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-174-even FROM 258 TO 256:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-174-odd FROM 259 TO 257:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-175-even FROM 260 TO 258:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-175-odd FROM 261 TO 259:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-176-even FROM 262 TO 260:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-176-odd FROM 263 TO 261:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-177-even FROM 264 TO 262:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-177-odd FROM 265 TO 263:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-178-even FROM 266 TO 264:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-178-odd FROM 267 TO 265:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-179-even FROM 268 TO 266:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-179-odd FROM 269 TO 267:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-180-even FROM 270 TO 268:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-180-odd FROM 271 TO 269:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-181-even FROM 272 TO 270:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-181-odd FROM 273 TO 271:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-182-even FROM 274 TO 272:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-182-odd FROM 275 TO 273:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-183-even FROM 276 TO 274:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-183-odd FROM 277 TO 275:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-184-even FROM 278 TO 276:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-184-odd FROM 279 TO 277:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-185-even FROM 280 TO 278:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-185-odd FROM 281 TO 279:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-186-even FROM 282 TO 280:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-186-odd FROM 283 TO 281:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-187-even FROM 284 TO 282:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-187-odd FROM 285 TO 283:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-188-even FROM 286 TO 284:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-188-odd FROM 287 TO 285:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-189-even FROM 288 TO 286:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-189-odd FROM 289 TO 287:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-190-even FROM 290 TO 288:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-190-odd FROM 291 TO 289:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-191-even FROM 292 TO 290:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-191-odd FROM 293 TO 291:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-192-even FROM 294 TO 292:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-192-odd FROM 295 TO 293:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-193-even FROM 296 TO 294:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-193-odd FROM 297 TO 295:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-194-even FROM 298 TO 296:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-194-odd FROM 299 TO 297:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-195-even FROM 300 TO 298:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-195-odd FROM 301 TO 299:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-196-even FROM 302 TO 300:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-196-odd FROM 303 TO 301:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-197-even FROM 304 TO 302:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-197-odd FROM 305 TO 303:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-198-even FROM 306 TO 304:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-198-odd FROM 307 TO 305:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-199-even FROM 308 TO 306:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-199-odd FROM 309 TO 307:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-200-even FROM 310 TO 308:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-200-odd FROM 311 TO 309:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-201-even FROM 312 TO 310:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-201-odd FROM 313 TO 311:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-202-even FROM 314 TO 312:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-202-odd FROM 315 TO 313:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-203-even FROM 316 TO 314:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-203-odd FROM 317 TO 315:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-204-even FROM 318 TO 316:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-204-odd FROM 319 TO 317:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-205-even FROM 320 TO 318:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-205-odd FROM 321 TO 319:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-206-even FROM 322 TO 320:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-206-odd FROM 323 TO 321:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-207-even FROM 324 TO 322:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-207-odd FROM 325 TO 323:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-208-even FROM 326 TO 324:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-208-odd FROM 327 TO 325:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-209-even FROM 328 TO 326:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-209-odd FROM 329 TO 327:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-210-even FROM 330 TO 328:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-210-odd FROM 331 TO 329:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-211-even FROM 332 TO 330:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-211-odd FROM 333 TO 331:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-212-even FROM 334 TO 332:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-212-odd FROM 335 TO 333:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-213-even FROM 336 TO 334:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-213-odd FROM 337 TO 335:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-214-even FROM 338 TO 336:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-214-odd FROM 339 TO 337:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-215-even FROM 340 TO 338:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-215-odd FROM 341 TO 339:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-216-even FROM 342 TO 340:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-216-odd FROM 343 TO 341:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-217-even FROM 344 TO 342:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-217-odd FROM 345 TO 343:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-218-even FROM 346 TO 344:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-218-odd FROM 347 TO 345:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-219-even FROM 348 TO 346:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-219-odd FROM 349 TO 347:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-220-even FROM 350 TO 348:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-220-odd FROM 351 TO 349:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-221-even FROM 352 TO 350:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-221-odd FROM 353 TO 351:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-222-even FROM 354 TO 352:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-222-odd FROM 355 TO 353:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-223-even FROM 356 TO 354:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-223-odd FROM 357 TO 355:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-224-even FROM 358 TO 356:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-224-odd FROM 359 TO 357:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-225-even FROM 360 TO 358:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-225-odd FROM 361 TO 359:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-226-even FROM 362 TO 360:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-226-odd FROM 363 TO 361:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-227-even FROM 364 TO 362:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-227-odd FROM 365 TO 363:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-228-even FROM 366 TO 364:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-228-odd FROM 367 TO 365:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-229-even FROM 368 TO 366:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-229-odd FROM 369 TO 367:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-230-even FROM 370 TO 368:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-230-odd FROM 371 TO 369:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-231-even FROM 372 TO 370:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-231-odd FROM 373 TO 371:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-232-even FROM 374 TO 372:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-232-odd FROM 375 TO 373:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-233-even FROM 376 TO 374:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-233-odd FROM 377 TO 375:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-234-even FROM 378 TO 376:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-234-odd FROM 379 TO 377:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-235-even FROM 380 TO 378:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-235-odd FROM 381 TO 379:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-236-even FROM 382 TO 380:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-236-odd FROM 383 TO 381:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-237-even FROM 384 TO 382:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-237-odd FROM 385 TO 383:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-238-even FROM 386 TO 384:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-238-odd FROM 387 TO 385:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-239-even FROM 388 TO 386:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-239-odd FROM 389 TO 387:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-240-even FROM 390 TO 388:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-240-odd FROM 391 TO 389:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-241-even FROM 392 TO 390:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-241-odd FROM 393 TO 391:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-242-even FROM 394 TO 392:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-242-odd FROM 395 TO 393:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-243-even FROM 396 TO 394:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-243-odd FROM 397 TO 395:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-244-even FROM 398 TO 396:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-244-odd FROM 399 TO 397:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-245-even FROM 400 TO 398:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-245-odd FROM 401 TO 399:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-246-even FROM 402 TO 400:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-246-odd FROM 403 TO 401:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-247-even FROM 404 TO 402:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-247-odd FROM 405 TO 403:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-248-even FROM 406 TO 404:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-248-odd FROM 407 TO 405:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-249-even FROM 408 TO 406:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-249-odd FROM 409 TO 407:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-250-even FROM 410 TO 408:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-250-odd FROM 411 TO 409:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-251-even FROM 412 TO 410:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-251-odd FROM 413 TO 411:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-252-even FROM 414 TO 412:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-252-odd FROM 415 TO 413:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-253-even FROM 416 TO 414:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-253-odd FROM 417 TO 415:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-254-even FROM 418 TO 416:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-254-odd FROM 419 TO 417:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-255-even FROM 420 TO 418:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-255-odd FROM 421 TO 419:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-256-even FROM 422 TO 420:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-256-odd FROM 423 TO 421:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-257-even FROM 424 TO 422:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-257-odd FROM 425 TO 423:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-258-even FROM 426 TO 424:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-258-odd FROM 427 TO 425:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-259-even FROM 428 TO 426:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-259-odd FROM 429 TO 427:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-260-even FROM 430 TO 428:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-260-odd FROM 431 TO 429:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-261-even FROM 432 TO 430:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-261-odd FROM 433 TO 431:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-262-even FROM 434 TO 432:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-262-odd FROM 435 TO 433:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-263-even FROM 436 TO 434:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-263-odd FROM 437 TO 435:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-264-even FROM 438 TO 436:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-264-odd FROM 439 TO 437:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-265-even FROM 440 TO 438:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-265-odd FROM 441 TO 439:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-266-even FROM 442 TO 440:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-266-odd FROM 443 TO 441:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-267-even FROM 444 TO 442:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-267-odd FROM 445 TO 443:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-268-even FROM 446 TO 444:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-268-odd FROM 447 TO 445:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-269-even FROM 448 TO 446:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-269-odd FROM 449 TO 447:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-270-even FROM 450 TO 448:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-270-odd FROM 451 TO 449:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-271-even FROM 452 TO 450:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-271-odd FROM 453 TO 451:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-272-even FROM 454 TO 452:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-272-odd FROM 455 TO 453:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-273-even FROM 456 TO 454:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-273-odd FROM 457 TO 455:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-274-even FROM 458 TO 456:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-274-odd FROM 459 TO 457:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-275-even FROM 460 TO 458:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-275-odd FROM 461 TO 459:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-276-even FROM 462 TO 460:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-276-odd FROM 463 TO 461:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-277-even FROM 464 TO 462:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-277-odd FROM 465 TO 463:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-278-even FROM 466 TO 464:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-278-odd FROM 467 TO 465:
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-279-even 468 464
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-279-odd 469 465
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-280-even FROM 470 TO 466:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-280-odd FROM 471 TO 467:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-281-even FROM 472 TO 468:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-281-odd FROM 473 TO 469:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-282-odd FROM 1 TO 470:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-283-odd FROM 1 TO 471:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-284-even FROM 2 TO 472:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-284-odd FROM 3 TO 473:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-285-even FROM 4 TO 474:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-285-odd FROM 5 TO 475:
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-286-even 6 474
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-286-odd 7 475
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-287-even FROM 8 TO 476:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-287-odd FROM 9 TO 477:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-288-even FROM 10 TO 478:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-288-odd FROM 11 TO 479:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-289-even FROM 12 TO 480:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-289-odd FROM 13 TO 481:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-290-even FROM 14 TO 482:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-290-odd FROM 15 TO 483:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-291-even FROM 16 TO 484:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-291-odd FROM 17 TO 485:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-292-even FROM 18 TO 486:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-292-odd FROM 19 TO 487:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-293-even FROM 20 TO 488:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-293-odd FROM 21 TO 489:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-294-even FROM 22 TO 490:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-294-odd FROM 23 TO 491:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-295-even FROM 24 TO 492:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-295-odd FROM 25 TO 493:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-296-even FROM 26 TO 494:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-296-odd FROM 27 TO 495:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-297-even FROM 28 TO 496:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-297-odd FROM 29 TO 497:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-298-even FROM 30 TO 498:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-298-odd FROM 31 TO 499:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-299-even FROM 32 TO 500:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-299-odd FROM 33 TO 501:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-300-even FROM 34 TO 502:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-300-odd FROM 35 TO 503:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-301-even FROM 36 TO 504:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-301-odd FROM 37 TO 505:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-302-even FROM 38 TO 506:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-302-odd FROM 39 TO 507:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-303-even FROM 40 TO 508:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-303-odd FROM 41 TO 509:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-304-even FROM 42 TO 510:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-304-odd FROM 43 TO 511:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-305-even FROM 44 TO 512:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-305-odd FROM 45 TO 513:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-306-even FROM 46 TO 514:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-306-odd FROM 47 TO 515:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-307-even FROM 48 TO 516:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-307-odd FROM 49 TO 517:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-308-even FROM 50 TO 518:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-308-odd FROM 51 TO 519:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-309-even FROM 52 TO 520:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-309-odd FROM 53 TO 521:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-310-even FROM 54 TO 522:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-310-odd FROM 55 TO 523:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-311-even FROM 56 TO 524:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-311-odd FROM 57 TO 525:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-312-even FROM 58 TO 526:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-312-odd FROM 59 TO 527:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-313-even FROM 60 TO 528:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-313-odd FROM 61 TO 529:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-314-even FROM 62 TO 530:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-314-odd FROM 63 TO 531:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-315-even FROM 64 TO 532:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-315-odd FROM 65 TO 533:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-316-even FROM 66 TO 534:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-316-odd FROM 67 TO 535:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-317-even FROM 68 TO 536:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-317-odd FROM 69 TO 537:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-318-even FROM 70 TO 538:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-318-odd FROM 71 TO 539:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-319-even FROM 72 TO 540:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-319-odd FROM 73 TO 541:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-320-even FROM 74 TO 542:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-320-odd FROM 75 TO 543:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-321-even FROM 76 TO 544:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-321-odd FROM 77 TO 545:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-322-even FROM 78 TO 546:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-322-odd FROM 79 TO 547:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-323-even FROM 80 TO 548:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-323-odd FROM 81 TO 549:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-324-even FROM 82 TO 550:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-324-odd FROM 83 TO 551:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-325-even FROM 84 TO 552:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-325-odd FROM 85 TO 553:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-326-even FROM 86 TO 554:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-326-odd FROM 87 TO 555:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-327-even FROM 88 TO 556:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-327-odd FROM 89 TO 557:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-328-even FROM 90 TO 558:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-328-odd FROM 91 TO 559:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-329-even FROM 92 TO 560:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-329-odd FROM 93 TO 561:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-330-even FROM 94 TO 562:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-330-odd FROM 95 TO 563:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-331-even FROM 96 TO 564:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-331-odd FROM 97 TO 565:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-332-even FROM 98 TO 566:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-332-odd FROM 99 TO 567:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-333-even FROM 100 TO 568:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-333-odd FROM 101 TO 569:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-334-even FROM 102 TO 570:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-334-odd FROM 103 TO 571:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-335-even FROM 104 TO 572:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-335-odd FROM 105 TO 573:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-336-even FROM 106 TO 574:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-336-odd FROM 107 TO 575:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-337-even FROM 108 TO 576:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-337-odd FROM 109 TO 577:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-338-even FROM 110 TO 578:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-338-odd FROM 111 TO 579:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-339-even FROM 112 TO 580:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-339-odd FROM 113 TO 581:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-340-even FROM 114 TO 582:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-340-odd FROM 115 TO 583:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-341-even FROM 116 TO 584:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-341-odd FROM 117 TO 585:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-342-even FROM 118 TO 586:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-342-odd FROM 119 TO 587:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-343-even FROM 120 TO 588:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-343-odd FROM 121 TO 589:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-344-even FROM 122 TO 590:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-344-odd FROM 123 TO 591:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-345-even FROM 124 TO 592:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-345-odd FROM 125 TO 593:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-346-even FROM 126 TO 594:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-346-odd FROM 127 TO 595:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-347-even FROM 128 TO 596:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-347-odd FROM 129 TO 597:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-348-even FROM 130 TO 598:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-348-odd FROM 131 TO 599:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-349-even FROM 132 TO 600:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-349-odd FROM 133 TO 601:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-350-even FROM 134 TO 602:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-350-odd FROM 135 TO 603:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-351-even FROM 136 TO 604:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-351-odd FROM 137 TO 605:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-352-even FROM 138 TO 606:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-352-odd FROM 139 TO 607:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-353-even FROM 140 TO 608:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-353-odd FROM 141 TO 609:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-354-even FROM 142 TO 610:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-354-odd FROM 143 TO 611:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-355-even FROM 144 TO 612:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-355-odd FROM 145 TO 613:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-356-even FROM 146 TO 614:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-356-odd FROM 147 TO 615:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-357-even FROM 148 TO 616:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-357-odd FROM 149 TO 617:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-358-even FROM 150 TO 618:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-358-odd FROM 151 TO 619:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-359-even FROM 152 TO 620:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-359-odd FROM 153 TO 621:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-360-even FROM 154 TO 622:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-360-odd FROM 155 TO 623:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-361-even FROM 156 TO 624:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-361-odd FROM 157 TO 625:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-362-even FROM 158 TO 626:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-362-odd FROM 159 TO 627:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-363-even FROM 160 TO 628:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-363-odd FROM 161 TO 629:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-364-even FROM 162 TO 630:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-364-odd FROM 163 TO 631:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-365-even FROM 164 TO 632:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-365-odd FROM 165 TO 633:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-366-even FROM 166 TO 634:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-366-odd FROM 167 TO 635:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-367-even FROM 168 TO 636:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-367-odd FROM 169 TO 637:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-368-even FROM 170 TO 638:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-368-odd FROM 171 TO 639:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-369-even FROM 172 TO 640:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-369-odd FROM 173 TO 641:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-370-even FROM 174 TO 642:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-370-odd FROM 175 TO 643:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-371-even FROM 176 TO 644:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-371-odd FROM 177 TO 645:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-372-even FROM 178 TO 646:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-372-odd FROM 179 TO 647:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-373-even FROM 180 TO 648:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-373-odd FROM 181 TO 649:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-374-even FROM 182 TO 650:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-374-odd FROM 183 TO 651:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-375-even FROM 184 TO 652:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-375-odd FROM 185 TO 653:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-376-even FROM 186 TO 654:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-376-odd FROM 187 TO 655:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-377-even FROM 188 TO 656:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-377-odd FROM 189 TO 657:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-378-even FROM 190 TO 658:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-378-odd FROM 191 TO 659:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-379-even FROM 192 TO 660:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-379-odd FROM 193 TO 661:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-380-even FROM 194 TO 662:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-380-odd FROM 195 TO 663:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-381-even FROM 196 TO 664:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-381-odd FROM 197 TO 665:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-382-even FROM 198 TO 666:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-382-odd FROM 199 TO 667:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-383-even FROM 200 TO 668:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-383-odd FROM 201 TO 669:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-384-even FROM 202 TO 670:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-384-odd FROM 203 TO 671:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-385-even FROM 204 TO 672:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-385-odd FROM 205 TO 673:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-386-even FROM 206 TO 674:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-386-odd FROM 207 TO 675:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-387-even FROM 208 TO 676:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-387-odd FROM 209 TO 677:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-388-even FROM 210 TO 678:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-388-odd FROM 211 TO 679:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-389-even FROM 212 TO 680:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-389-odd FROM 213 TO 681:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-390-even FROM 214 TO 682:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-390-odd FROM 215 TO 683:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-391-even FROM 216 TO 684:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-391-odd FROM 217 TO 685:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-392-even FROM 218 TO 686:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-392-odd FROM 219 TO 687:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-393-even FROM 220 TO 688:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-393-odd FROM 221 TO 689:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-394-even FROM 222 TO 690:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-394-odd FROM 223 TO 691:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-395-even FROM 224 TO 692:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-395-odd FROM 225 TO 693:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-396-even FROM 226 TO 694:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-396-odd FROM 227 TO 695:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-397-even FROM 228 TO 696:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-397-odd FROM 229 TO 697:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-398-even FROM 230 TO 698:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-398-odd FROM 231 TO 699:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-399-even FROM 232 TO 700:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-399-odd FROM 233 TO 701:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-400-even FROM 234 TO 702:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-400-odd FROM 235 TO 703:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-401-even FROM 236 TO 704:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-401-odd FROM 237 TO 705:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-402-even FROM 238 TO 706:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-402-odd FROM 239 TO 707:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-403-even FROM 240 TO 708:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-403-odd FROM 241 TO 709:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-404-even FROM 242 TO 710:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-404-odd FROM 243 TO 711:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-405-even FROM 244 TO 712:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-405-odd FROM 245 TO 713:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-406-even FROM 246 TO 714:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-406-odd FROM 247 TO 715:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-407-even FROM 248 TO 716:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-407-odd FROM 249 TO 717:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-408-even FROM 250 TO 718:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-408-odd FROM 251 TO 719:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-409-even FROM 252 TO 720:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-409-odd FROM 253 TO 721:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-410-even FROM 254 TO 722:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-410-odd FROM 255 TO 723:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-411-even FROM 256 TO 724:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-411-odd FROM 257 TO 725:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-412-even FROM 258 TO 726:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-412-odd FROM 259 TO 727:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-413-even FROM 260 TO 728:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-413-odd FROM 261 TO 729:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-414-even FROM 262 TO 730:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-414-odd FROM 263 TO 731:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-415-even FROM 264 TO 732:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-415-odd FROM 265 TO 733:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-416-even FROM 266 TO 734:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-416-odd FROM 267 TO 735:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-417-even FROM 268 TO 736:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-417-odd FROM 269 TO 737:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-418-even FROM 270 TO 738:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-418-odd FROM 271 TO 739:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-419-even FROM 272 TO 740:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-419-odd FROM 273 TO 741:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-420-even FROM 274 TO 742:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-420-odd FROM 275 TO 743:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-421-even FROM 276 TO 744:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-421-odd FROM 277 TO 745:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-422-even FROM 278 TO 746:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-422-odd FROM 279 TO 747:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-423-even FROM 280 TO 748:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-423-odd FROM 281 TO 749:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-424-even FROM 282 TO 750:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-424-odd FROM 283 TO 751:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-425-even FROM 284 TO 752:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-425-odd FROM 285 TO 753:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-426-even FROM 286 TO 754:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-426-odd FROM 287 TO 755:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-427-even FROM 288 TO 756:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-427-odd FROM 289 TO 757:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-428-even FROM 290 TO 758:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-428-odd FROM 291 TO 759:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-429-even FROM 292 TO 760:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-429-odd FROM 293 TO 761:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-430-even FROM 294 TO 762:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-430-odd FROM 295 TO 763:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-431-even FROM 296 TO 764:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-431-odd FROM 297 TO 765:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-432-even FROM 298 TO 766:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-432-odd FROM 299 TO 767:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-433-even FROM 300 TO 768:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-433-odd FROM 301 TO 769:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-434-even FROM 302 TO 770:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-434-odd FROM 303 TO 771:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-435-even FROM 304 TO 772:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-435-odd FROM 305 TO 773:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-436-even FROM 306 TO 774:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-436-odd FROM 307 TO 775:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-437-even FROM 308 TO 776:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-437-odd FROM 309 TO 777:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-438-even FROM 310 TO 778:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-438-odd FROM 311 TO 779:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-439-even FROM 312 TO 780:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-439-odd FROM 313 TO 781:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-440-even FROM 314 TO 782:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-440-odd FROM 315 TO 783:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-441-even FROM 316 TO 784:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-441-odd FROM 317 TO 785:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-442-even FROM 318 TO 786:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-442-odd FROM 319 TO 787:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-443-even FROM 320 TO 788:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-443-odd FROM 321 TO 789:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-444-even FROM 322 TO 790:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-444-odd FROM 323 TO 791:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-445-even FROM 324 TO 792:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-445-odd FROM 325 TO 793:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-446-even FROM 326 TO 794:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-446-odd FROM 327 TO 795:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-447-even FROM 328 TO 796:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-447-odd FROM 329 TO 797:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-448-even FROM 330 TO 798:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-448-odd FROM 331 TO 799:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-449-even FROM 332 TO 800:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-449-odd FROM 333 TO 801:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-450-even FROM 334 TO 802:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-450-odd FROM 335 TO 803:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-451-even FROM 336 TO 804:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-451-odd FROM 337 TO 805:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-452-even FROM 338 TO 806:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-452-odd FROM 339 TO 807:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-453-even FROM 340 TO 808:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-453-odd FROM 341 TO 809:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-454-even FROM 342 TO 810:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-454-odd FROM 343 TO 811:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-455-even FROM 344 TO 812:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-455-odd FROM 345 TO 813:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-456-even FROM 346 TO 814:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-456-odd FROM 347 TO 815:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-457-even FROM 348 TO 816:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-457-odd FROM 349 TO 817:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-458-even FROM 350 TO 818:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-458-odd FROM 351 TO 819:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-459-even FROM 352 TO 820:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-459-odd FROM 353 TO 821:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-460-even FROM 354 TO 822:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-460-odd FROM 355 TO 823:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-461-even FROM 356 TO 824:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-461-odd FROM 357 TO 825:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-462-even FROM 358 TO 826:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-462-odd FROM 359 TO 827:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-463-even FROM 360 TO 828:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-463-odd FROM 361 TO 829:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-464-even FROM 362 TO 830:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-464-odd FROM 363 TO 831:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-465-even FROM 364 TO 832:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-465-odd FROM 365 TO 833:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-466-even FROM 366 TO 834:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-466-odd FROM 367 TO 835:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-467-even FROM 368 TO 836:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-467-odd FROM 369 TO 837:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-468-even FROM 370 TO 838:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-468-odd FROM 371 TO 839:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-469-even FROM 372 TO 840:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-469-odd FROM 373 TO 841:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-470-even FROM 374 TO 842:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-470-odd FROM 375 TO 843:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-471-even FROM 376 TO 844:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-471-odd FROM 377 TO 845:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-472-even FROM 378 TO 846:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-472-odd FROM 379 TO 847:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-473-even FROM 380 TO 848:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-473-odd FROM 381 TO 849:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-474-even FROM 382 TO 850:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-474-odd FROM 383 TO 851:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-475-even FROM 384 TO 852:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-475-odd FROM 385 TO 853:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-476-even FROM 386 TO 854:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-476-odd FROM 387 TO 855:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-477-even FROM 388 TO 856:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-477-odd FROM 389 TO 857:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-478-even FROM 390 TO 858:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-478-odd FROM 391 TO 859:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-479-even FROM 392 TO 860:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-479-odd FROM 393 TO 861:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-480-even FROM 394 TO 862:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-480-odd FROM 395 TO 863:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-481-even FROM 396 TO 864:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-481-odd FROM 397 TO 865:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-482-even FROM 398 TO 866:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-482-odd FROM 399 TO 867:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-483-even FROM 400 TO 868:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-483-odd FROM 401 TO 869:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-484-even FROM 402 TO 870:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-484-odd FROM 403 TO 871:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-485-even FROM 404 TO 872:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-485-odd FROM 405 TO 873:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-486-even FROM 406 TO 874:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-486-odd FROM 407 TO 875:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-487-even FROM 408 TO 876:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-487-odd FROM 409 TO 877:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-488-even FROM 410 TO 878:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-488-odd FROM 411 TO 879:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-489-even FROM 412 TO 880:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-489-odd FROM 413 TO 881:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-490-even FROM 414 TO 882:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-490-odd FROM 415 TO 883:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-491-even FROM 416 TO 884:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-491-odd FROM 417 TO 885:
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-492-even 418 884
# CORRECTING FOR DUPLICATE SCAN: year-1725-scan-492-odd 419 885
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-493-even FROM 420 TO 886:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-493-odd FROM 421 TO 887:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-494-even FROM 422 TO 888:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-494-odd FROM 423 TO 889:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-495-even FROM 424 TO 890:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-495-odd FROM 425 TO 891:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-496-even FROM 426 TO 892:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-496-odd FROM 427 TO 893:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-497-even FROM 428 TO 894:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-497-odd FROM 429 TO 895:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-498-even FROM 430 TO 896:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-498-odd FROM 431 TO 897:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-499-even FROM 432 TO 898:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-499-odd FROM 433 TO 899:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-500-even FROM 434 TO 900:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-500-odd FROM 435 TO 901:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-501-even FROM 436 TO 902:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-501-odd FROM 437 TO 903:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-502-even FROM 438 TO 904:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-502-odd FROM 439 TO 905:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-503-even FROM 440 TO 906:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-503-odd FROM 441 TO 907:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-504-even FROM 442 TO 908:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-504-odd FROM 443 TO 909:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-505-even FROM 444 TO 910:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-505-odd FROM 445 TO 911:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-506-even FROM 446 TO 912:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-506-odd FROM 447 TO 913:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-507-even FROM 448 TO 914:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-507-odd FROM 449 TO 915:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-508-even FROM 450 TO 916:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-508-odd FROM 451 TO 917:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-509-even FROM 452 TO 918:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-509-odd FROM 453 TO 919:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-510-even FROM 454 TO 920:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-510-odd FROM 455 TO 921:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-511-even FROM 456 TO 922:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-511-odd FROM 457 TO 923:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-512-even FROM 458 TO 924:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-512-odd FROM 459 TO 925:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-513-even FROM 460 TO 926:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-513-odd FROM 461 TO 927:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-514-even FROM 462 TO 928:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-514-odd FROM 463 TO 929:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-515-even FROM 464 TO 930:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-515-odd FROM 465 TO 931:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-516-even FROM 466 TO 932:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-516-odd FROM 467 TO 933:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-517-even FROM 468 TO 934:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-517-odd FROM 469 TO 935:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-518-even FROM 470 TO 936:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-518-odd FROM 471 TO 937:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-519-even FROM 472 TO 938:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-519-odd FROM 473 TO 939:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-520-even FROM 474 TO 940:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-520-odd FROM 475 TO 941:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-521-even FROM 476 TO 942:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-521-odd FROM 477 TO 943:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-522-even FROM 478 TO 944:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-522-odd FROM 479 TO 945:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-523-even FROM 480 TO 946:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-523-odd FROM 481 TO 947:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-524-even FROM 482 TO 948:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-524-odd FROM 483 TO 949:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-525-even FROM 484 TO 950:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-525-odd FROM 485 TO 951:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-526-even FROM 486 TO 952:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-526-odd FROM 487 TO 953:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-527-even FROM 488 TO 954:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-527-odd FROM 489 TO 955:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-528-even FROM 490 TO 956:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-528-odd FROM 491 TO 957:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-529-even FROM 492 TO 958:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-529-odd FROM 493 TO 959:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-530-even FROM 494 TO 960:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-530-odd FROM 495 TO 961:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-531-even FROM 496 TO 962:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-531-odd FROM 497 TO 963:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-532-even FROM 498 TO 964:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-532-odd FROM 499 TO 965:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-533-even FROM 500 TO 966:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-533-odd FROM 501 TO 967:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-534-even FROM 502 TO 968:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-534-odd FROM 503 TO 969:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-535-even FROM 504 TO 970:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-535-odd FROM 505 TO 971:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-536-even FROM 506 TO 972:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-536-odd FROM 507 TO 973:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-537-even FROM 508 TO 974:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-537-odd FROM 509 TO 975:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-538-even FROM 510 TO 976:
# CORRECTING PAGE NUMBER OF PAGE year-1725-scan-542-even FROM 1 TO 977:
#
# Done!

# %% [markdown]
# ### Parsing and Preprocessing Index Pages
#
# - filter tiny and huge text elements (i.e. deviating from average character/word width and height
# - extract page lines that are part of the main text body containing index entries
# - insert and clean up repetition symbols in index entries
#     - determine length of repetition symbol
#     - identify and replace mis-recognized repetition symbols

# %%
#from republic_index_page_parser import index_lemmata
from collections import defaultdict
import republic_index_page_parser as index_parser
import republic_elasticsearch as rep_es

avg_left = 0
lemma_index = defaultdict(list)
curr_lemma = None
    

for page_id in pages_info:
    page_doc = rep_es.retrieve_page_doc(page_id, year_config)
    print("\n\n", page_id)
    if page_doc["page_type"] != "index_page":
        print("skipping non-index page")
        continue
    page_doc["num_page_ref_lines"] = index_parser.count_page_ref_lines(page_doc)
    for column_info in page_doc["columns"]:
        print("\n\n", column_info["column_id"])
        column_hocr = column_info["column_hocr"]
        lines = index_parser.get_index_entry_lines(column_hocr)
        curr_lemma = index_parser.index_lemmata(column_info["column_id"], lines, lemma_index, curr_lemma)
        print("returned lemma:", curr_lemma)
# Out:
#  year-1725-scan-1-odd
# skipping non-index page
#
#
#  year-1725-scan-4-odd
#
#
#  scan-4-odd-0
# returned lemma: None
#
#
#  scan-4-odd-1
# returned lemma: None
#
#
#  year-1725-scan-5-odd
#
#
#  scan-5-odd-0
# possibly misrecognised repeat symbol: 132 SNE
# possibly misrecognised repeat symbol: 356 OE
# possibly misrecognised repeat symbol: 137 mm
# DEVIATING LINE: 213 [99, 213, 229, 215, 261, 218] AM Uae re aan Conrmijari/-
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 229 [99, 213, 229, 215, 261, 218, 113] NN A YA fen Inftructeurs áf-
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 215 [99, 213, 229, 215, 261, 218, 113, 272] va EON  rewecen. 361. 4T9.
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 261 [99, 213, 229, 215, 261, 218, 113, 272, 146] | VN WW, Aannemers van Fortif-
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 218 [213, 229, 215, 261, 218, 113, 272, 146, 282] —— Ef catien, Temet om [ub-
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 272 [215, 261, 218, 113, 272, 146, 282, 169, 85] om betilinge van achterftallen, Pro=
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 282 [218, 113, 272, 146, 282, 169, 85, 272, 144] de Haas ‘om ‘a(fijtertie ‘afgeweefen.
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 272 [146, 282, 169, 85, 272, 144, 98, 140, 144] jn Vetalige ‘van achterflallen Te
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 264 [140, 144, 97, 144, 264, 133, 146, 270, 133] elaft fijn ‘ovdres ‘omtrent het “uytivo=
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 270 [144, 264, 133, 146, 270, 133, 147, 150, 274]  aangefchreven lat in Spaitne: Schepen
# avg_repeat_symbol_length: 208
# DEVIATING LINE: 274 [270, 133, 147, 150, 274, 146] Staat ‘van de Schepen ‘ter Admirali=
# avg_repeat_symbol_length: 208
# 0 99 0 start 	      vn  Hut  Maag Alken, verfovck om or-
# 1 99 -2 start 	 —— AM  Uae   re aan Conrmijari/-
# 2 99 -4 start 	 —— NN  A YA   fen Inftructeurs   áf-
# 3 99 -1 start 	 —— va   EON         rewecen. 361. 4T9.
# 4 99 -6 start 	   —— | VN WW, Aannemersvan Fortif-
# 5 113 9 continue 	 —— ——      Ef    catien, Temet om [ub-
# 6 113 1 continue 	       ——    Jiflenitie   afgeweefen.
# 7 85 -25 start 	    —— om betilinge van achterftallen, Pro=
# 	PAGE_REFS: [256] 	CURR LEMMA: None
# 8 146 38 continue_stop 	        vincien ver/ocht ‘confentenYe prefleeren.  256.
# 9 85 -28 start 	    —— de  Haas  ‘om  ‘a(fijtertie  ‘afgeweefen.
# 	PAGE_REFS: [10] 	CURR LEMMA: None
# 10 169 57 continue_stop 	         10,
# 	PAGE_REFS: [455] 	CURR LEMMA: None
# 11 85 -30 start_stop 	     wiet    Tien Atcatons ‘toegeleght.   455.
# 12 85 -36 start 	    —— jn Vetalige  ‘van  achterflallen    Te
# 13 144 28 continue 	        examinteren.  ‘516.
# HAS LEMMA: van Aarlen van Sommelsdyck advertentie.
# LEMMA: van Aarlen van Sommelsdyck advertentie
# LEMMA: van Aarlen van Sommelsdyck advertentie
# setting lemma: van Aarlen van Sommelsdyck advertentie
# 14 98 -24 start 	      van Aarlen van Sommelsdyck   advertentie.
# 	PAGE_REFS: [266, 278, 417, 430, 448, 417, 393, 738] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 15 140 26 continue_stop 	        266. 278. 417. 430. 448. 417. 393. 738.
# 16 144 24 continue 	        788. 853.  9f8.              Ee
# 17 97 -30 start 	      ——  Setrotgris Binckhorft gelaft figh gereet
# 	PAGE_REFS: [77] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 18 144 19 continue_stop 	        te maken en te houden.  77.
# 19 97 -32 start 	   —— elaft fijn ‘ovdres  ‘omtrent  het “uytivo=
# 20 133 3 continue 	        pen en Tendevots te geven ‘aan  de Schepen
# 	PAGE_REFS: [185] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 21 146 15 continue_stop 	        van de Aümiraliteyt op de Mize.  185.
# 22 133 -2 start 	     —— aangefchreven lat in Spaitne: Schepen
# 23 133 -2 start 	        gëguipeert  “werden om concert ‘met die ven
# 24 147 7 continue 	        den  Staat  Te  agecren  tegens  de Algierfche
# 	PAGE_REFS: [201] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 25 150 9 continue_stop 	         Rovers.   201.
# 26 133 -7 start 	    —— Staat ‘van de Schepen ‘ter Admirali=
# 	PAGE_REFS: [237] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 27 146 5 continue_stop 	        weyt tot Amfterdam.   237.
# returned lemma: van Aarlen van Sommelsdyck advertentie
#
#
#  scan-5-odd-1
# possibly misrecognised repeat symbol: 145 mn
# DEVIATING LINE: 227 [227, 108, 63, 112, 169] gejaf} Fabritius te'Cadix eh Courcamp
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 169 [227, 108, 63, 112, 169, 114, 116, 113, 113] ee juftificatie van de conduites ‘gehouden
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 237 [114, 116, 113, 113, 237, 110, 114, 60, 116] redenen waarom het Schip van Zee-
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 240 [114, 60, 116, 108, 240, 69, 115, 72, 119] gevis en geaccordeert. “916.
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 247 [115, 72, 119, 122, 247, 122, 260, 124, 131] Re{olutie ‘wegens de adminiftratie van
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 260 [119, 122, 247, 122, 260, 124, 131, 250, 252] te examineren wegens ‘de vafte refi-
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 250 [122, 260, 124, 131, 250, 252, 128] pgpport en refolutie. 374.
# avg_repeat_symbol_length: 145
# DEVIATING LINE: 252 [260, 124, 131, 250, 252, 128] te berichten op de Memorie van ‘den
# avg_repeat_symbol_length: 145
# 0 63 -18 start 	    —— gejaf} Fabritius te'Cadix eh Courcamp
# 	PAGE_REFS: [284] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 1 108 21 continue_stop 	      te Lijfabon te brengen.  284.
# 2 63 -28 start 	    —— gelaft feeker Huytfchip met fijn Lar
# 	PAGE_REFS: [670] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 3 112 18 continue_stop 	       dinge te ‘verkoopen.  670.
# 4 63 -33 start 	 —— ee  juftificatie van de conduites ‘gehouden
# 5 114 17 continue 	       door ‘de 'Capiteynen MWittenborfl, Boudaan-s
# 6 116 19 continue 	       Fronfel en  Elias,  wegens  ‘rencontre en ge=
# 7 113 10 continue 	       veght  met  twee Roofjcheepen  van  Algiers.
# 	PAGE_REFS: [755] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 8 113 16 continue_stop 	       755:
# 9 72 -31 start 	     —— redenen waarom het Schip van Zee-
# 10 110 8 continue 	       Jandt  ‘opvefönden ‘hadt  ls  onbeguaam ons
# 	PAGE_REFS: [788] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 11 114 17 continue_stop 	       dien[t te doen.  788.
# 12 60 -33 start 	    me       gn feeker ‘hernomen Schip tot Gadise
# 13 116 23 continue 	       te mogen verkoopen, de ÄAdmiraliteyt te gm-
# 14 108 15 continue 	      terdam te advifteren.   ‘ge8.
# 15 75 -19 start 	     —— gevis en geaccordeert.  “916.
# 16 69 -26 start 	    —gelaft nogh  twee maanden’    Zee fe
# 	PAGE_REFS: [973] 	CURR LEMMA: van Aarlen van Sommelsdyck advertentie
# 17 115 18 continue_stop 	       blijven.   973.
# HAS LEMMA: Admiraliteyten in het gemeen aangefchreven
# setting lemma: Admiraliteyten
# 18 72 -26 start 	     Admiraliteyten in het gemeen  aangefchreven
# 19 119 20 continue 	       Lijfen van ‘inkoment Rundvee en Varckens
# 	PAGE_REFS: [33] 	CURR LEMMA: Admiraliteyten
# 20 122 18 continue_stop 	       over te [enden.   33.
# 21 82 -29 start 	     —— Re{olutie ‘wegens de adminiftratie van
# 	PAGE_REFS: [69] 	CURR LEMMA: Admiraliteyten
# 22 122 10 continue_stop 	       bet ‘kleyn Zegel.  69.
# 23 119 1 continue 	      —— te examineren wegens ‘de vafte refi-
# 24 124 5 continue 	       dentie  wan  Bedienden  wan  de  Convoyen.
# 	PAGE_REFS: [175] 	CURR LEMMA: Admiraliteyten
# 25 131 12 continue_stop 	        175.
# 	PAGE_REFS: [374] 	CURR LEMMA: Admiraliteyten
# 26 122 -2 start_stop 	     —— pgpport en refolutie.   374.
# 27 124 0 start 	      —— te berichten  op de Memorie van ‘den
# 28 128 3 continue 	       Marquis de Fenelon, houdende klaghten over
# returned lemma: Admiraliteyten
#
#
#  year-1725-scan-6-even
#
#
#  scan-6-even-0
# returned lemma: Admiraliteyten
#
#
#  scan-6-even-1
# DEVIATING LINE: 298 [298, 172, 288, 288, 162] Scheepen tot de Equipagie  gereedt.
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 288 [298, 172, 288, 288, 162, 113, 166] (Gy/en aange[telt tot Capiteyn. 213.
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 288 [298, 172, 288, 288, 162, 113, 166, 287] Commijie wegens Hollandt voor den’
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 287 [288, 162, 113, 166, 287, 162, 165, 285, 159] Carrier aangefteldt tot Contrerolleur
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 285 [166, 287, 162, 165, 285, 159, 276, 158, 279] Commiie wegens Hollandt voor den
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 276 [162, 165, 285, 159, 276, 158, 279, 157, 277] gepermitteert het Schip Overy(el te
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 279 [285, 159, 276, 158, 279, 157, 277, 143, 155] bericht op de Memorie van den Mar-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 277 [276, 158, 279, 157, 277, 143, 155, 276, 151] van Sommelsdijck gelaft fteker Fluyt-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 276 [157, 277, 143, 155, 276, 151, 276, 150, 264] Commiie voor den Heer Schildhou=
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 276 [143, 155, 276, 151, 276, 150, 264, 149, 280] item wegens Vrieslandt voor den Heer
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 264 [276, 151, 276, 150, 264, 149, 280, 145, 266] ygkende de adminiftratie van ’t kleyn
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 280 [276, 150, 264, 149, 280, 145, 266, 144, 60] Lijfe van inkoomend Rundvee en
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 266 [264, 149, 280, 145, 266, 144, 60, 141, 142] rakende de vafte refidentie der Offi-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 256 [144, 60, 141, 142, 256, 138, 138, 138, 257]  gelaft te berichten uyt wat hoofde door
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 257 [256, 138, 138, 138, 257, 134, 133, 254, 131] klaghten over de Collegie in’t Noors
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 254 [138, 257, 134, 133, 254, 131, 251, 129, 251] om verklaringe op feekere Re[olutie
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 251 [134, 133, 254, 131, 251, 129, 251, 128, 126] remarques op het nieuw Placaat en
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 251 [254, 131, 251, 129, 251, 128, 126, 247, 130] wegens de Lakenen uyt ’s Hertogen-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 247 [129, 251, 128, 126, 247, 130, 246, 122, 123] wegens Pa(]agiegeldt van feekere Kar-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 246 [128, 126, 247, 130, 246, 122, 123, 244, 114] repport en refolutie op haar remar-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 244 [130, 246, 122, 123, 244, 114, 75, 116, 116] rapport en refolutie wegens het Pa/]a-
# avg_repeat_symbol_length: 87
# DEVIATING LINE: 234 [75, 116, 116, 112, 234, 112, 110, 66] bericht van de ÁAdmiraliteyt in Zee-
# avg_repeat_symbol_length: 87
# 0 191 14 continue 	     —— Scheepen tot  de  Equipagie   gereedt.
# 	PAGE_REFS: [185] 	CURR LEMMA: Admiraliteyten
# 1 172 6 continue_stop 	         185.
# 	PAGE_REFS: [213] 	CURR LEMMA: Admiraliteyten
# 2 181 15 continue_stop 	     —— (Gy/en aange[telt tot Capiteyn.  213.
# 3 181 13 continue 	     —— Commijie wegens Hollandt  voor den’
# 	PAGE_REFS: [260] 	CURR LEMMA: Admiraliteyten
# HAS LEMMA: Heere Gallas. 260.
# LEMMA: Heere Gallas
# LEMMA: Heere Gallas
# setting lemma: Heere Gallas
# 4 162 -5 start_stop 	         Heere Gallas.   260.
# 5 113 -51 start 	      —  confideratien  op  het  kleyn  Zegel.
# 	PAGE_REFS: [275] 	CURR LEMMA: Heere Gallas
# 6 166 1 continue_stop 	         275.
# 7 180 18 continue 	     —— Carrier  aangefteldt  tot  Contrerolleur
# 8 162 1 continue 	         van  de  Convoyen  en  Licenten  te  Venlo,
# 	PAGE_REFS: [320] 	CURR LEMMA: Heere Gallas
# 9 165 4 continue_stop 	         320.
# 10 178 11 continue 	     —— Commiie wegens Hollandt voor den
# 	PAGE_REFS: [367] 	CURR LEMMA: Heere Gallas
# HAS LEMMA: Heere van Leyden. 367.
# LEMMA: Heere van Leyden
# LEMMA: Heere van Leyden
# setting lemma: Heere van Leyden
# 11 159 -7 start_stop 	         Heere van Leyden.   367.
# 12 169 4 continue 	    —— gepermitteert  het  Schip  Overy(el te
# 	PAGE_REFS: [383] 	CURR LEMMA: Heere van Leyden
# 13 158 -5 start_stop 	         verkoopen.  383.
# 14 172 10 continue 	     —— bericht op de Memorie van den Mar-
# 	PAGE_REFS: [443] 	CURR LEMMA: Heere van Leyden
# 15 157 -4 start_stop 	        quis de Fenelon.  443.
# 16 170 10 continue 	    —— van Sommelsdijck gelaft fteker Fluyt-
# HAS LEMMA: Schip met fijn Ladinge te mogen verkoopen.
# LEMMA: Schip met fijn Ladinge te mogen verkoopen
# LEMMA: Schip met fijn Ladinge te mogen verkoopen
# setting lemma: Schip met fijn Ladinge te mogen verkoopen
# 17 143 -17 start 	        Schip met fijn Ladinge  te mogen verkoopen.
# 	PAGE_REFS: [670] 	CURR LEMMA: Schip met fijn Ladinge te mogen verkoopen
# 18 155 -4 start_stop 	        670.
# 19 169 12 continue 	    —— Commiie  voor den Heer  Schildhou=
# 	PAGE_REFS: [696] 	CURR LEMMA: Schip met fijn Ladinge te mogen verkoopen
# 20 151 -6 start_stop 	        wer wegens Hollandt.  696.
# 21 169 12 continue 	    —— item wegens Vrieslandt voor den Heer
# 	PAGE_REFS: [701] 	CURR LEMMA: Schip met fijn Ladinge te mogen verkoopen
# HAS LEMMA: van Haarsma. 701.
# LEMMA: van Haarsma
# LEMMA: van Haarsma
# setting lemma: van Haarsma
# 22 150 -7 start_stop 	        van Haarsma.   701.
# 23 157 -1 start 	    —— ygkende de adminiftratie van ’t kleyn
# 	PAGE_REFS: [716] 	CURR LEMMA: van Haarsma
# HAS LEMMA: Zegel, te examineeren. 716.
# LEMMA: Zegel
# LEMMA: Zegel
# setting lemma: Zegel
# 24 149 -6 start_stop 	        Zegel, te examineeren.   716.
# 25 173 28 continue 	     —— Lijfe  van  inkoomend  Rundvee  en
# 	PAGE_REFS: [717] 	CURR LEMMA: Zegel
# 26 145 3 continue_stop 	        Varckens, te examineeren.  717.
# 27 159 18 continue 	    —— rakende de  vafte refidentie der Offi-
# 	PAGE_REFS: [717] 	CURR LEMMA: Zegel
# 28 144 4 continue_stop 	        cianten  te examineren.  717.
# 29 60 -79 start 	    mn ——  klaghte over feytelijckheden te Lillo,
# 30 141 6 continue 	        de  Admiraliteyt  in  Zeelandt  te berichten.
# 	PAGE_REFS: [724] 	CURR LEMMA: Zegel
# 31 142 8 continue_stop 	        724.
# 32 149 16 continue 	    —— gelaft te berichten uyt wat hoofde door
# 33 138 6 continue 	       bare Bedienden te Vlaardingen gegeven zijn
# HAS LEMMA: Pa/porten tot den aytvoer van Goederen die
# setting lemma: Pa/porten
# 34 138 -2 start 	       Pa/porten tot den aytvoer van Goederen die
# 	PAGE_REFS: [742] 	CURR LEMMA: Pa/porten
# 35 138 -3 start_stop 	       verboden zijn.  742.
# 36 150 11 continue 	   —— klaghten over de Collegie in’t Noors
# HAS LEMMA: der Quartier het felve te berichten,
# LEMMA: der Quartier het felve te berichten
# LEMMA: der Quartier het felve te berichten
# setting lemma: der Quartier het felve te berichten
# 37 134 -5 start 	       der  Quartier    het  felve  te  berichten,
# 	PAGE_REFS: [760] 	CURR LEMMA: der Quartier het felve te berichten
# 38 133 -5 start_stop 	       760.
# 39 147 9 continue 	   —— om verklaringe  op feekere Re[olutie
# 	PAGE_REFS: [771] 	CURR LEMMA: der Quartier het felve te berichten
# 40 131 -6 start_stop 	       te examineeren.  771.
# 41 144 9 continue 	   —— remarques  op  het nieuw Placaat en
# 	PAGE_REFS: [807] 	CURR LEMMA: der Quartier het felve te berichten
# HAS LEMMA: Lijfte, te examineeren. 807.
# LEMMA: Lijfte
# LEMMA: Lijfte
# setting lemma: Lijfte
# 42 129 -6 start_stop 	       Lijfte, te examineeren.  807.
# 43 144 9 continue 	   —— wegens de Lakenen  uyt  ’s Hertogen-
# 44 128 -6 start 	       bofch en Breda na Leyden gebraght werden-
# 	PAGE_REFS: [808] 	CURR LEMMA: Lijfte
# 45 126 -7 start_stop 	       de en te rugge, te examineren.  808.
# 46 140 9 continue 	   —— wegens Pa(]agiegeldt van feekere Kar-
# 	PAGE_REFS: [809] 	CURR LEMMA: Lijfte
# 47 130 -2 start_stop 	       ren, by Zeelandt overgenomen.   809.
# 48 139 11 continue 	   —— repport  en refolutie  op haar remar-
# 49 122 0 start 	       ques  op  het  nieuw  Placaat  en  Lijfte.
# 50 123 2 continue 	       SIL.
# 51 137 18 continue 	   —— rapport en refolutie wegens het Pa/]a-
# 	PAGE_REFS: [813] 	CURR LEMMA: Lijfte
# 52 114 -3 start_stop 	      giegeldt van Karren.   813.
# 53 75 -40 start 	    _—       te advifeeren op het ver[oek van Beug-
# 54 116 2 continue 	      holt‚ Bafecour en Vechoven   om [oo veel
# 55 116 3 continue 	      te declareeren en te genieten als tot nogh toe
# 	PAGE_REFS: [814] 	CURR LEMMA: Lijfte
# 56 112 7 continue_stop 	      gehadt hebben.   814.
# 57 127 23 continue 	  —— bericht van de ÁAdmiraliteyt in  Zee-
# 58 112 4 continue 	      landt op de klaghten  rakende de Bedienden
# 	PAGE_REFS: [815] 	CURR LEMMA: Lijfte
# 59 110 3 continue_stop 	      te Lillo.   815.
# 60 66 -39 start 	    mente He berigten op de Reque[te van Rees om de
# returned lemma: Lijfte
#
#
#  year-1725-scan-6-odd
#
#
#  scan-6-odd-2
# possibly misrecognised repeat symbol: 171 eee
# possibly misrecognised repeat symbol: 122 aki
# possibly misrecognised repeat symbol: 149 mn
# possibly misrecognised repeat symbol: 143 mn
# DEVIATING LINE: 219 [169, 118, 165, 165, 219, 164, 162, 286, 142] Om om ordes of ’s Landts reghten [ullen
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 286 [165, 219, 164, 162, 286, 142, 287, 157, 281] advis op bet verfoerk van Rees, en
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 287 [164, 162, 286, 142, 287, 157, 281, 135, 146] advis en refolutie, rakende de Bedien-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 281 [286, 142, 287, 157, 281, 135, 146, 280, 154] van Alblaferdam aangeftelt tot Ont-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 280 [157, 281, 135, 146, 280, 154, 152, 277, 149] Refolutie van den drie en twistighften
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 277 [146, 280, 154, 152, 277, 149, 150, 150, 271] om interpretatie wegens Manufattu-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 271 [277, 149, 150, 150, 271, 149, 152, 102, 150]  geauthorifeert boven [eekere premie,
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 266 [150, 81, 147, 146, 266, 139, 146, 272, 147] gelaft het grootfte Schip tot de Equi-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 272 [146, 266, 139, 146, 272, 147, 270, 143, 269] te berichten op het ver[oeck van Rogh,
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 270 [139, 146, 272, 147, 270, 143, 269, 145, 268] bericht op de Memorie van Grijs, te
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 269 [272, 147, 270, 143, 269, 145, 268, 146, 270] rakende het heffen van het middel
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 268 [270, 143, 269, 145, 268, 146, 270, 145, 144] Lijft van het Rundvee, te examine-
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 270 [269, 145, 268, 146, 270, 145, 144, 137, 267] notificerende , dat het haar ondoenlijck
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 267 [270, 145, 144, 137, 267, 142, 148, 98, 139] advis op het verfoeck van Schrijvers,
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 266 [142, 148, 98, 139, 266, 140, 91, 142, 262] Commiie voor de Heer van Laar
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 262 [266, 140, 91, 142, 262, 141, 263, 139, 92] commijfie voor den Heere van Haaren
# avg_repeat_symbol_length: 146
# DEVIATING LINE: 263 [91, 142, 262, 141, 263, 139, 92, 141] bericht op de Memorie van den Mar-
# avg_repeat_symbol_length: 146
# 0 108 -37 start 	     reghten van het Zout op den ouden voet fe
# 1 169 29 continue 	       betalen.  BIS.
# 2 118 -25 start 	     —aange[fchreven  de  Refòlutie  van den
# 3 165 19 continue 	       den drie en twintighften  by provifie niet te
# 	PAGE_REFS: [822] 	CURR LEMMA: Lijfte
# 4 165 20 continue_stop 	       executeren. 822.
# 5 118 -31 start 	  —— Om  om ordes of ’s Landts reghten [ullen
# 6 164 19 continue 	       vorderen van Goederen komende uyt of gaan-
# 	PAGE_REFS: [827] 	CURR LEMMA: Lijfte
# 7 162 12 continue_stop 	       de na Zeelandt, te examineeren.   827.
# 8 142 -4 start 	     —— advis op bet verfoerk van Rees,  en
# 	PAGE_REFS: [841] 	CURR LEMMA: Lijfte
# 9 142 -1 start_stop 	      afgewefen.   841.
# 10 135 -11 start 	     —— advis en refolutie, rakende de Bedien-
# 	PAGE_REFS: [850] 	CURR LEMMA: Lijfte
# 11 157 14 continue_stop 	       den van het Zegel.   850.
# 12 135 -7 start 	     —— van Alblaferdam aangeftelt tot Ont-
# 13 135 -8 start 	     fanger van de Convoyen en Licenten te Eyndt-
# 14 146 3 continue 	      hoven.  85 s
# 15 135 -10 start 	     —— Refolutie van den drie en twistighften
# 16 154 10 continue 	      Oftober nogh voor drie weecken te [urcheren.
# 	PAGE_REFS: [889] 	CURR LEMMA: Lijfte
# 17 152 6 continue_stop 	      889.
# 18 146 3 continue 	     —— om  interpretatie wegens  Manufattu-
# 19 149 6 continue 	      ven   te  examineeren   en  Naaldens  ende
# 20 150 5 continue 	      Meen onder gemaakt Yerwerck begreepen.
# 	PAGE_REFS: [919] 	CURR LEMMA: Lijfte
# 21 150 11 continue_stop 	      919.
# 22 105 -34 start 	     —— geauthorifeert  boven [eekere premie,
# 23 149 17 continue 	      impuniteyt aan de Medeplightige te beloven.
# 	PAGE_REFS: [936] 	CURR LEMMA: Lijfte
# 24 152 21 continue_stop 	      936.
# HAS LEMMA: Admiraliteyt tot Amfterdam Oatfanger
# setting lemma: Admiraliteyt
# 25 102 -29 start 	    Admiraliteyt  tot  Amfterdam     Oatfanger
# 26 150 25 continue 	      Groeninx gelaft Jcekere penningen te betalen.
# 27 81 -48 start 	   —— te berichten op het ver(oek van Schry-
# 28 147 18 continue 	      ver wegens premie van veroverde Turck[che
# 29 146 19 continue 	      Rovers.   $9.
# 30 100 -32 start 	    —— gelaft het grootfte Schip tot de Equi-
# 31 139 8 continue 	      pagie, te  verftercken  met  vijftigh  koppen.
# 	PAGE_REFS: [75] 	CURR LEMMA: Admiraliteyt
# 32 146 8 continue_stop 	      75:
# 33 139 1 continue 	    —— te berichten op het ver[oeck van Rogh,
# 	PAGE_REFS: [79] 	CURR LEMMA: Admiraliteyt
# 34 147 10 continue_stop 	      cum Íuis.   79.
# 35 139 -3 start 	    —— bericht op de Memorie van Grijs, te
# 	PAGE_REFS: [81] 	CURR LEMMA: Admiraliteyt
# 36 143 0 start_stop 	      examineeren.  81,
# 37 143 1 continue 	    —— rakende  het  heffen  van  het middel
# 	PAGE_REFS: [94] 	CURR LEMMA: Admiraliteyt
# 38 145 2 continue_stop 	      van het kleyn Zegel, te examineeren.   94.
# 39 143 1 continue 	    —— Lijft van het Rundvee, te examine-
# 40 146 4 continue 	      ren.  O1.
# 41 137 0 start 	    —— notificerende, dat het haar ondoenlijck
# 42 145 8 continue 	      is   haar Hoogh Mog. te berichten of vol-
# 43 144 6 continue 	      gens de Placaten te procederen tegens Schip-
# 	PAGE_REFS: [138] 	CURR LEMMA: Admiraliteyt
# 44 137 4 continue_stop 	      per Statema.   138.
# 45 101 -31 start 	    —— advis op het verfoeck van Schrijvers,
# 46 142 14 continue 	      Provintien aangenomen haar  te verklaaren.
# 	PAGE_REFS: [45] 	CURR LEMMA: Admiraliteyt
# 47 148 21 continue_stop 	      45.
# 48 98 -23 start 	    ——  Toeftant van de Schepen  onder haar
# 	PAGE_REFS: [237] 	CURR LEMMA: Admiraliteyt
# 49 139 17 continue_stop 	      effort.   237.
# 50 100 -21 start 	    —— Commiie  voor  de  Heer  van  Laar
# 	PAGE_REFS: [277] 	CURR LEMMA: Admiraliteyt
# 51 140 19 continue_stop 	      wegens Overy(el.   277.
# 52 91 -25 start 	   ——  confideratien  op  het  kleyn  Zegel.
# 	PAGE_REFS: [299] 	CURR LEMMA: Admiraliteyt
# 53 142 22 continue_stop 	      299.
# 54 96 -19 start 	    —— commijfie voor den Heere van Haaren
# 	PAGE_REFS: [329] 	CURR LEMMA: Admiraliteyt
# 55 141 22 continue_stop 	      wegens Vrieslandt.   329.
# 56 97 -20 start 	    —— bericht op de Memorie van den Mar-
# 	PAGE_REFS: [450] 	CURR LEMMA: Admiraliteyt
# 57 139 18 continue_stop 	      quis de Fenelon.  450.
# 58 92 -25 start 	   —— de Bruyn aangeftelt tot Capiteyn  ter
# 	PAGE_REFS: [454] 	CURR LEMMA: Admiraliteyt
# 59 141 19 continue_stop 	      Zee.   454.
# returned lemma: Admiraliteyt
#
#
#  scan-6-odd-3
# possibly misrecognised repeat symbol: 141 mn
# possibly misrecognised repeat symbol: 125 ee
# DEVIATING LINE: 207 [207, 81, 80, 204, 81] fe advifeeren op de Mijfive van de
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 204 [207, 81, 80, 204, 81, 203, 79, 82] gdvis dien aangaande by Hollandt
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 203 [81, 80, 204, 81, 203, 79, 82, 201, 82] notificeerende dat het voorfchreevé
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 201 [81, 203, 79, 82, 201, 82, 204, 78, 200] gakende bet Schip de Jenny Galley 4
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 204 [79, 82, 201, 82, 204, 78, 200, 81, 206] aangefchreven de Jenny Galley te Tas
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 200 [201, 82, 204, 78, 200, 81, 206, 86, 205] propofitie vm twee Commien Generaal
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 206 [204, 78, 200, 81, 206, 86, 205, 84, 214] Buys en vander Meulen aangeftelt tot
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 205 [200, 81, 206, 86, 205, 84, 214, 87, 212] commijie wegens Hollandt voor den
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 214 [206, 86, 205, 84, 214, 87, 212, 88, 45] Lijfte van inkoomende Rundvee en
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 212 [205, 84, 214, 87, 212, 88, 45, 90, 89] Torck, belofte op den eedt ten aaR-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 215 [45, 90, 89, 91, 215, 45, 92, 93, 94] bericht ‘en geaccordeerf. 916.
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 216 [93, 94, 47, 94, 216, 93, 218, 98, 221] vrapport , rakende de Vaart van Böf-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 218 [47, 94, 216, 93, 218, 98, 221, 99, 103] rakende de adminiftratie van het klejn
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 221 [216, 93, 218, 98, 221, 99, 103, 225, 101] Ramhorft aangefteldt. tot Ontfanger
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 225 [98, 221, 99, 103, 225, 101, 224, 100, 228] Golts aangefteldt tot Ontfanger vam
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 224 [99, 103, 225, 101, 224, 100, 228, 108, 107] wegens aangevinge van Rundvee én
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 228 [225, 101, 224, 100, 228, 108, 107, 226, 106] Greveftein aangefteldt tot Contrerol-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 226 [100, 228, 108, 107, 226, 106, 228, 106, 238] commijfie wegens Hollandt voor de
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 228 [108, 107, 226, 106, 228, 106, 238, 37, 59] iten voor de Heer Aylua wegens Pries-
# avg_repeat_symbol_length: 110
# DEVIATING LINE: 238 [226, 106, 228, 106, 238, 37, 59, 110, 67] Akerlaken aangefteldt zot Capiteyn,
# avg_repeat_symbol_length: 110
# 0 80 0 start 	     —— fe advifeeren  op  de Mijfive  van de
# 1 81 1 continue 	     Hochepied wegens [ceker Engeljch  Schip de
# 	PAGE_REFS: [461] 	CURR LEMMA: Admiraliteyt
# 2 80 1 continue_stop 	     Fenny Galley.   461.
# 3 79 -1 start 	     —— gdvis dien  aangaande   by Hollandt
# 	PAGE_REFS: [486] 	CURR LEMMA: Admiraliteyt
# 4 81 2 continue_stop 	     overgenomen.  486.
# 5 79 -1 start 	     —— notificeerende   dat  het  voorfchreevé
# HAS LEMMA: Schip aldaar binnen gevallen was zen ordres.
# LEMMA: Schip aldaar binnen gevallen was zen ordres
# LEMMA: Schip aldaar binnen gevallen was zen ordres
# setting lemma: Schip aldaar binnen gevallen was zen ordres
# 6 79 0 start 	     Schip aldaar binnen gevallen was zen ordres.
# 	PAGE_REFS: [525] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 7 82 3 continue_stop 	     525:
# 8 78 -1 start 	     —— gakende  bet Schip de Jenny Galley4
# 	PAGE_REFS: [587] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 9 82 3 continue_stop 	     te examineeren.   587:
# 10 78 -1 start 	     —— aangefchreven de Jenny Galley te Tas
# 	PAGE_REFS: [591] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 11 78 -2 start_stop 	     ten loen.   591.
# 12 78 -2 start 	     —— propofitie vm twee Commien Generaal
# 	PAGE_REFS: [637] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 13 81 1 continue_stop 	     aan te tellen, geaccordeert.  637.
# 14 78 -2 start 	     —— Buys en vander Meulen aangeftelt tot
# 	PAGE_REFS: [639] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 15 86 5 continue_stop 	     Commifen Generaal.  639.
# 16 81 -1 start 	     —— commijie  wegens  Hollandt voor den
# 	PAGE_REFS: [716] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 17 84 1 continue_stop 	     Heer vander Waeyen.   716.
# 18 84 5 continue 	      —— Lijfte  van  inkoomende  Rundvee  en
# 	PAGE_REFS: [786] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 19 87 7 continue_stop 	     Varckens.  786,
# 20 82 1 continue 	      —— Torck, belofte op  den  eedt ten aaR-
# 	PAGE_REFS: [896] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 21 88 6 continue_stop 	     vangh van fijn bedieninge gedaan.  896.
# 22 45 -37 start 	   —_      #6 advifteren op de Miffive van Aar (èn
# 23 90 12 continue 	     van Sommelsdijck om feeker hernomen Schip
# 24 89 11 continue 	     en Laadinge  tot Cadix te mogen verkoöpen.
# 	PAGE_REFS: [908] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 25 91 12 continue_stop 	      908.
# 	PAGE_REFS: [916] 	CURR LEMMA: Schip aldaar binnen gevallen was zen ordres
# 26 85 5 continue_stop 	      —— bericht ‘en geaccordeerf.  916.
# HAS LEMMA: Admiraliteyt in het Noorder Quartier ; amf=
# LEMMA: Admiraliteyt in het Noorder Quartier
# LEMMA: Admiraliteyt in het Noorder Quartier
# setting lemma: Admiraliteyt in het Noorder Quartier
# 27 45 -35 start 	   Admiraliteyt in het Noorder Quartier; amf=
# 28 92 11 continue 	      woordt  op  de Miffive  van vanden Boch,
# 29 93 13 continue 	      rakende  de Vaart van  Borkom op Áltena.
# 	PAGE_REFS: [49] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 30 94 13 continue_stop 	      49:
# 31 47 -34 start 	   —— Lift van inkomend Rundvee en Vat-
# 	PAGE_REFS: [61] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 32 94 7 continue_stop 	      kens.  61.
# 33 86 -1 start 	      —— vrapport, rakende de Vaart van Böf-
# 	PAGE_REFS: [67] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 34 93 5 continue_stop 	      kom op Altena.  67.
# 35 88 -1 start 	      —— rakende de adminiftratie van het klejn
# 	PAGE_REFS: [131] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 36 98 4 continue_stop 	      Zegel, te examineeren.  131.
# 37 93 -2 start 	      —— Ramhorft  aangefteldt. tot  Ontfanger
# 38 99 3 continue 	      van  de  Convoyen  en  Licenten tot  Ha{el.
# 	PAGE_REFS: [169] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 39 103 6 continue_stop 	      169.
# 40 98 -1 start 	      —— Golts  aangefteldt  tot Ontfanger vam
# 	PAGE_REFS: [169] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# 41 101 1 continue_stop 	      de Convoyen en Licenten tot Swolle.   169.
# 42 99 -2 start 	      —— wegens  aangevinge  van Rundvee én
# 	PAGE_REFS: [178] 	CURR LEMMA: Admiraliteyt in het Noorder Quartier
# HAS LEMMA: Varckens. 178.
# LEMMA: Varckens
# LEMMA: Varckens
# setting lemma: Varckens
# 43 100 -1 start_stop 	      Varckens.   178.
# 44 100 -2 start 	      —— Greveftein  aangefteldt  tot  Contrerol-
# 45 108 6 continue 	      leur van de Comvoyen en Licenten tot Ha(fel.
# 	PAGE_REFS: [256] 	CURR LEMMA: Varckens
# 46 107 5 continue_stop 	      256.
# 47 100 -3 start 	      —— commijfie  wegens  Hollandt  voor  de
# 	PAGE_REFS: [304] 	CURR LEMMA: Varckens
# 48 106 10 continue_stop 	      Heer Jelius.   304.
# 49 98 6 continue 	      —— iten voor de Heer Aylua wegens Pries-
# 	PAGE_REFS: [310] 	CURR LEMMA: Varckens
# 50 106 14 continue_stop 	      landt.   310.
# 51 108 21 continue 	 —— Akerlaken  aangefteldt  zot  Capiteyn,
# 52 37 -52 start 	   uw  35
# 53 59 -33 start 	    and    Houttuyn aangefteldt  tot Capiteya op
# 	PAGE_REFS: [361] 	CURR LEMMA: Varckens
# 54 110 24 continue_stop 	       den Uytlegger van het Collegie.   361.
# 55 67 -23 start 	    —— de  Zee  aangefteldt  tot  Contrerolleus
# 56 111 27 continue 	       van de Convoyen en Licenten t0t Medenblick.
# 	PAGE_REFS: [80] 	CURR LEMMA: Varckens
# 57 137 47 continue_stop 	        80.
# 58 47 -48 start 	   ——   van Schaak aangefteldt  tot Capiteyn.
# 	PAGE_REFS: [92] 	CURR LEMMA: Varckens
# 59 140 48 continue_stop 	        92.
# 60 54 -43 start 	    pa       wegens fraudes van  de Middelen tof
# returned lemma: Varckens
#
#
#  year-1725-scan-7-even
#
#
#  scan-7-even-0
# possibly misrecognised repeat symbol: 164 mn
# possibly misrecognised repeat symbol: 152 me
# DEVIATING LINE: 234 [103, 100, 54, 104, 234, 226, 99, 52, 99] antwoordt van Overyfel. 456.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 226 [100, 54, 104, 234, 226, 99, 52, 99, 236] antwoordt op de Memorie van den
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 236 [226, 99, 52, 99, 236, 104, 228, 107, 231] te berichten op de klaghtem. van de
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 228 [52, 99, 236, 104, 228, 107, 231, 113, 234] rakende de meetinge der Koopvaardye
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 231 [236, 104, 228, 107, 231, 113, 234, 108, 109] vemarqgues op ‘het nieuw Placaat cn
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 234 [228, 107, 231, 113, 234, 108, 109, 231, 110] om het Schip het Wapen van Alck-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 231 [113, 234, 108, 109, 231, 110, 52, 111, 62] rapport en refolutie-op haar remarques
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 238 [62, 112, 100, 116, 238, 105, 110, 111, 230] #6 advifeeren op het verfoeck van Re-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 230 [238, 105, 110, 111, 230, 236, 112, 241, 112] gereet Schip tot het E/quadre. 305.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 236 [105, 110, 111, 230, 236, 112, 241, 112, 297] Stokke aangefteldt tot Capiteyn.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 241 [111, 230, 236, 112, 241, 112, 297, 103, 113] van Hoorn aangefteldt ‘als Commis
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 297 [236, 112, 241, 112, 297, 103, 113, 234, 112] berichten wegens klaghten van ‘de
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 234 [112, 297, 103, 113, 234, 112, 66, 113, 236]  aangefchreven met moderatie te proce-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 236 [234, 112, 66, 113, 236, 114, 46, 114, 113] aangefchreven dat haar Hoogh Mog.
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 244 [114, 46, 114, 113, 244, 114, 139, 234, 113] Slicher en Backer belofte ‘op den eedt
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 234 [113, 244, 114, 139, 234, 113, 232, 108, 63] item van Na(auw, Heér van Drie-
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 232 [114, 139, 234, 113, 232, 108, 63, 116, 241] gepermitteert de oude Lijfte nogh vobn
# avg_repeat_symbol_length: 149
# DEVIATING LINE: 241 [232, 108, 63, 116, 241, 107, 67, 115, 115] met de voor[z verklaringe by provifie
# avg_repeat_symbol_length: 149
# 0 103 18 continue 	      OveryjJel  Staaten verfoght  woorfieninge te
# 	PAGE_REFS: [414] 	CURR LEMMA: Varckens
# 1 100 20 continue_stop 	      doen.  414.
# 2 54 -29 start 	   — Lifte  van  inkoomende  Rundvee  en
# 	PAGE_REFS: [440, 688] 	CURR LEMMA: Varckens
# 3 104 25 continue_stop 	      Varkens.   440. 688.
# 	PAGE_REFS: [456] 	CURR LEMMA: Varckens
# 4 65 -16 start_stop 	     —— antwoordt van Overyfel.  456.
# 5 57 -20 start 	    —— antwoordt  op  de  Memorie  van den
# 	PAGE_REFS: [487] 	CURR LEMMA: Varckens
# 6 99 22 continue_stop 	      Marquis de Fenclon.  487.
# 7 52 -26 start 	   ——_— tegens het Schip van Cornelis Otter
# 	PAGE_REFS: [616] 	CURR LEMMA: Varckens
# 8 99 21 continue_stop 	      te examineeren.  616.
# 9 67 -16 start 	     —— te  berichten  op  de klaghtem. van de
# 	PAGE_REFS: [760] 	CURR LEMMA: Varckens
# 10 104 15 continue_stop 	      Admmiraliteyt op de Maze.  760.
# 11 59 -31 start 	    —— rakende de meetinge der Koopvaardye
# 	PAGE_REFS: [772] 	CURR LEMMA: Varckens
# 12 107 11 continue_stop 	      Schepen, te examineeren.  772.
# 13 104 7 continue 	    —— vemarqgues  op  ‘het nieuw Placaat cn
# 	PAGE_REFS: [807] 	CURR LEMMA: Varckens
# 14 113 16 continue_stop 	      Lijfte.   807.
# 15 107 10 continue 	     —— om het Schip het Wapen van Alck-
# 16 108 12 continue 	      maar te mogen verkoopen, by Hollandt over-
# 	PAGE_REFS: [808] 	CURR LEMMA: Varckens
# 17 109 12 continue_stop 	      genoomen.   808.
# 18 62 -30 start 	    —— rapport en refolutie-op haar remarques
# 	PAGE_REFS: [812] 	CURR LEMMA: Varckens
# 19 110 18 continue_stop 	      op het nieuw Placaat en Lijfte.   812.
# 20 52 -39 start 	   ——— gepermitteert  het  Schip bet  Wapen
# 	PAGE_REFS: [901] 	CURR LEMMA: Varckens
# 21 111 19 continue_stop 	      van Alckmaar te mogen verkoopen,  901.
# HAS LEMMA: Admiralteyt in Zeelandt ‘inftantien van
# setting lemma: Admiralteyt
# 22 62 -26 start 	    Admiralteyt  in  Zeelandt   ‘inftantien  van
# 23 112 19 continue 	      Kooplieden.  tot  den  uytwoer  van  goude en
# 24 100 7 continue 	      Jilvere  Specien, ‘de.  Tetroafta  ‘ma  te fen.
# 	PAGE_REFS: [167] 	CURR LEMMA: Admiralteyt
# 25 116 17 continue_stop 	       167.
# 26 69 -29 start 	     —— #6 advifeeren op het verfoeck van Re-
# 27 105 2 continue 	      genten van  Aardenbergh  om  ‘exemptie van
# 28 110 7 continue 	      bet Placaat wegens belaftinge wan OJen en
# 	PAGE_REFS: [296] 	CURR LEMMA: Admiralteyt
# 29 111 7 continue_stop 	      Koeyen,   296.
# 	PAGE_REFS: [305] 	CURR LEMMA: Admiralteyt
# 30 105 2 continue_stop 	    —— gereet Schip tot het E/quadre. 305.
# 31 105 -5 start 	     —— Stokke  aangefteldt  tot  Capiteyn.
# 	PAGE_REFS: [491] 	CURR LEMMA: Admiralteyt
# 32 112 3 continue_stop 	      491.
# 33 103 -7 start 	     —— van  Hoorn  aangefteldt  ‘als  Commis
# 	PAGE_REFS: [658] 	CURR LEMMA: Admiralteyt
# 34 112 7 continue_stop 	      Generaal.  658.
# 35 128 22 continue 	        —— berichten wegens  klaghten van ‘de
# 36 103 2 continue 	      Admiraliteyt op de Maze wegens feytelijck-
# 37 113 12 continue 	      beden te Lillo.   724   \
# 38 66 -31 start 	      —— aangefchreven met moderatie te proce-
# 39 112 14 continue 	      deren tegens Schipper Schollaart.   741."
# 40 66 -22 start 	    —  grdre  om  het  nieuwe  Placaat  en
# 	PAGE_REFS: [743] 	CURR LEMMA: Admiralteyt
# 41 113 23 continue_stop 	       Lijfte niet te executeren en refolttie. 743.
# 42 67 -23 start 	     —— aangefchreven dat haar Hoogh Mog.
# 	PAGE_REFS: [792, 802] 	CURR LEMMA: Admiralteyt
# 43 114 23 continue_stop 	       de excufe niet aannemen.   792. 802.
# 44 46 -45 start 	   —— bericht op de klaghtén ‘van de Admi-
# 45 114 15 continue 	       raliteyt op de Maze, rakende de Bedienden
# 	PAGE_REFS: [815] 	CURR LEMMA: Admiralteyt
# 46 113 19 continue_stop 	      te Lillo.   815.
# 47 75 -24 start 	     —— Slicher en Backer belofte ‘op den eedt
# 48 114 21 continue 	       To  aanvangh van haar bedieninge gedaan.
# 	PAGE_REFS: [17] 	CURR LEMMA: Admiralteyt
# 49 139 39 continue_stop 	        17.
# 50 65 -29 start 	     —— item van Na(auw, Heér van Drie-
# 	PAGE_REFS: [827] 	CURR LEMMA: Admiralteyt
# 51 113 18 continue_stop 	      bergen.   827.
# 52 63 -31 start 	    —— gepermitteert de oude Lijfte nogh vobn
# 	PAGE_REFS: [829] 	CURR LEMMA: Admiralteyt
# 53 108 14 continue_stop 	      drie weecken te continueren.   829.
# 54 63 -23 start 	    —— gepermitteert de gerequireerde verkla-
# 	PAGE_REFS: [956] 	CURR LEMMA: Admiralteyt
# 55 116 25 continue_stop 	       vinge Jchriftelijck te mogen. doen.   956.
# 56 72 -19 start 	     —— met de voor[z verklaringe by provifie
# 	PAGE_REFS: [966] 	CURR LEMMA: Admiralteyt
# 57 107 12 continue_stop 	      genoegen genomen.  966.
# HAS LEMMA: Admiraliteyt in Vrieslandt, :advis ‘op de Me-
# LEMMA: Admiraliteyt in Vrieslandt
# LEMMA: Admiraliteyt in Vrieslandt
# setting lemma: Admiraliteyt in Vrieslandt
# 58 67 -26 start 	    Admiraliteyt in Vrieslandt, :advis ‘op de Me-
# 59 115 17 continue 	       morie van Greis    raakende  het  opreghten
# 60 115 20 continue 	       van twee  Vuurbaacken op  de Kuften van
# returned lemma: Admiraliteyt in Vrieslandt
#
#
#  scan-7-even-1
# possibly misrecognised repeat symbol: 147 Ea
# possibly misrecognised repeat symbol: 151 kee
# DEVIATING LINE: 227 [100, 45, 87, 97, 227, 100, 93, 100, 108] gdvis op de Mifive van vanden
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 226 [100, 93, 100, 108, 226, 108, 154, 101, 107] akende de adminiftratie van ’t kleyn
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 230 [108, 154, 101, 107, 230, 108, 111, 111, 110] deduêtie van het recht waar op funm-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 235 [108, 111, 111, 110, 235, 112, 259, 115, 233] Commifie wegens Utrecht woor den
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 259 [111, 110, 235, 112, 259, 115, 233, 105, 231] Burmania aangefteldt 101 Gapiteyn.
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 233 [235, 112, 259, 115, 233, 105, 231, 121, 66] Commmijfie wegens Vrieslandt voor Pe-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 231 [259, 115, 233, 105, 231, 121, 66, 65, 118] item wegens Vrieslandt voor Bìncke
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 237 [65, 118, 117, 119, 237, 121, 242, 122, 239] Comimijie voor de Heer Gruys wegens
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 242 [117, 119, 237, 121, 242, 122, 239, 119, 246] Mifive in [aveur van Bovwmans.,
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 239 [237, 121, 242, 122, 239, 119, 246, 123, 120] gepermitteert te accorderen ‘de vryen
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 246 [242, 122, 239, 119, 246, 123, 120, 242, 123] te berichten op de klaghten van-de
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 242 [119, 246, 123, 120, 242, 123, 127, 249, 128] bericht op de Memorie van Meynerts-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 249 [120, 242, 123, 127, 249, 128, 254, 121, 250] [Lijfte van bet inkomende Rundtvee,
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 254 [123, 127, 249, 128, 254, 121, 250, 131, 99] Commijfie voor de Heer Schultens we-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 250 [249, 128, 254, 121, 250, 131, 99, 132, 160] gelaft de aangehaalde fucken Noote-
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 256 [132, 160, 133, 134, 256, 135, 251, 136]  Tyfte van ‘de inkomende Rundvee en
# avg_repeat_symbol_length: 115
# DEVIATING LINE: 251 [133, 134, 256, 135, 251, 136] op Haar ‘geweccordeerde fb fidie “van
# avg_repeat_symbol_length: 115
# 0 93 9 continue 	      Noorweegen ‚  by  Hollandt  overgenoomen.
# 	PAGE_REFS: [1540] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 1 100 15 continue_stop 	      1540.
# 2 45 -42 start 	   —— antwoordt op baar Hoogh Mog. -Re-
# 3 87 -1 start 	     folutie werens Lijfte van Rundveeen Varc-
# 	PAGE_REFS: [150] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 4 97 8 continue_stop 	      kens   te examineeren. * 150.
# 5 92 1 continue 	     —— gdvis  op  de  Mifive  van  vanden
# 6 100 10 continue 	      Bofch,  rakende de aangroey van de Sthip-
# 7 93 -4 start 	      pers  van  het Eylandt Borkum. op   Akuna
# 8 100 -5 start 	      en Hamburgh    by  Hollandt overgenomen.
# 	PAGE_REFS: [150] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 9 108 3 continue_stop 	      150.
# 10 93 -14 start 	     —— akende de adminiftratie van ’t kleyn
# 11 108 1 continue 	      Zegel, te examineeren.   15T,
# 12 154 46 continue 	         LD  rapport wegens Rundvee ‘en Varckens,
# 13 101 -9 start 	      geauthorifeert [eekere  pie
# 14 107 -3 start 	      bliceeren en ter executie te leggen.
# 15 101 -11 start 	      —— deduêtie van het recht waar op funm-
# 16 108 -4 start 	      doeren hare pretenfien ‘ende grieven tot het
# 17 111 4 continue 	       beffen van  de Convoyen  en Licentemop de
# 18 111 1 continue 	       Middelgronden en aan den Abt, te exami-
# 	PAGE_REFS: [178] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 19 110 -1 start_stop 	       ueeren.   178.
# 20 108 -2 start 	      —— Commifie wegens  Utrecht woor den
# 	PAGE_REFS: [236] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 21 112 2 continue_stop 	       Heer de Leeuw.  236.
# 22 124 16 continue 	       —— Burmania  aangefteldt 101 Gapiteyn.
# 	PAGE_REFS: [258] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 23 115 6 continue_stop 	       258.
# 24 98 -7 start 	      —— Commmijfie wegens Vrieslandt voor Pe-
# 	PAGE_REFS: [76] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 25 105 5 continue_stop 	      gelin van Claarbergen.   76.
# 26 96 -4 start 	      —— item  wegens Vrieslandt voor Bìncke
# 	PAGE_REFS: [280] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 27 121 21 continue_stop 	       Symons.   280.
# 28 66 -34 start 	    — item wegens Frieslandt voor Rengers.
# 29 65 -36 start 	    —— te berichten op de klaghtenvan Mey-
# 30 118 16 continue 	       aertshagen, nopenie bet aanhouden van vier
# 31 117 12 continue 	       hondert vijf en dertich ftucken Nooteboomen
# 	PAGE_REFS: [313] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 32 119 14 continue_stop 	       Hout.   313.
# 33 102 -9 start 	      —— Comimijie voor de Heer Gruys wegens
# 	PAGE_REFS: [317] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 34 121 4 continue_stop 	       Stadt en Lande.   317.
# 35 117 0 start 	      —— Mifive  in [aveur van Bovwmans.,
# 	PAGE_REFS: [346] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 36 122 5 continue_stop 	       de retroafta na te fien.  346.
# 37 119 1 continue 	      —— gepermitteert  te accorderen ‘de vryen
# 	PAGE_REFS: [346] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 38 119 0 start_stop 	       uyt- en invoer van Paarden.   346.
# 39 119 -1 start 	      —— te berichten  op  de klaghten van-de
# 40 123 2 continue 	       Staaten ’s Landts van Drenthe wegens’exe-
# 	PAGE_REFS: [384] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 41 120 -1 start_stop 	       cutien te Rooswinckel.   384.
# 42 119 -3 start 	      —— bericht op de Memorie van Meynerts-
# 43 123 1 continue 	       hagen, rakende bet Nooteboomen Hout €
# 	PAGE_REFS: [399] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 44 127 5 continue_stop 	       re[olutie.  399.
# 45 120 -1 start 	      —— [Lijfte van bet inkomende Rundtvee,
# 	PAGE_REFS: [399] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 46 128 6 continue_stop 	       te oxamineeren.   399.
# 47 119 -1 start 	       —— Commijfie voor de Heer Schultens we-
# 48 121 0 start 	       gens Stadt ‘en Lande.  437
# 49 115 -10 start 	      —— gelaft de aangehaalde fucken Noote-
# 	PAGE_REFS: [481] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 50 131 5 continue_stop 	        boomen Hout te ontflaan.  481.
# 51 99 -28 start 	      _—       de Haan aangefteldt als ‘Contrerolleur
# 52 132 4 continue 	        van de Convoyen ‘en Licenten in :de Lemmer.
# 	PAGE_REFS: [37] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 53 160 30 continue_stop 	         37.
# 54 133 1 continue 	        ee    rakende de adminiftreatie van ’ttleyn
# 	PAGE_REFS: [667] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# 55 134 2 continue_stop 	        Zegel, te examineren.   667.
# 56 132 -4 start 	 —— Tyfte van ‘de inkomende Rundvee en
# 	PAGE_REFS: [667] 	CURR LEMMA: Admiraliteyt in Vrieslandt
# HAS LEMMA: Varckens. 667.
# LEMMA: Varckens
# LEMMA: Varckens
# setting lemma: Varckens
# 57 135 -2 start_stop 	        Varckens.  667.
# 58 133 0 start 	       —— op Haar ‘geweccordeerde fb fidie “van
# 59 136 2 continue 	        vyf en dertigh duy/ent guldens “sjaarsyPro-
# returned lemma: Varckens
#
#
#  year-1725-scan-7-odd
#
#
#  scan-7-odd-2
# possibly misrecognised repeat symbol: 204 mn
# DEVIATING LINE: 235 [111, 64, 110, 109, 235, 109, 231, 107, 109] Commijie wegens Vrieslandt voor den
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 231 [110, 109, 235, 109, 231, 107, 109, 233, 110] bericht op de klaghten van de Admi-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 233 [109, 231, 107, 109, 233, 110, 111, 233, 108] advis op het verfoeck van Beugholt,
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 233 [109, 233, 110, 111, 233, 108, 231, 109, 61] advis wegens Reglement voor de Yck-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 231 [110, 111, 233, 108, 231, 109, 61, 59, 107] rapport wegens Bedienden van ’t kleyn
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 107 [231, 109, 61, 59, 107, 108, 234, 0, 107] de fake van den Prince van Hornes tegens
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 108 [109, 61, 59, 107, 108, 234, 0, 107, 232] la Motte. 15.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 234 [61, 59, 107, 108, 234, 0, 107, 232, 231] advis en refolutie. 127.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 107 [107, 108, 234, 0, 107, 232, 231, 103, 234] Benthem en de Prez. 400.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 232 [108, 234, 0, 107, 232, 231, 103, 234, 102] advis dien aangaande. 513.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 231 [234, 0, 107, 232, 231, 103, 234, 102, 234] fe berichten op de Requcfte van Rey:
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 103 [0, 107, 232, 231, 103, 234, 102, 234, 108] gersman. 617.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 234 [107, 232, 231, 103, 234, 102, 234, 108, 246] Regquefie van Collard ter handen, ge-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 234 [231, 103, 234, 102, 234, 108, 246, 109, 61] Heuft aangefteldt tot ’s Landts Ad-
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 246 [234, 102, 234, 108, 246, 109, 61, 64, 107] gdvis in de [aaken van Collard.
# avg_repeat_symbol_length: 116
# DEVIATING LINE: 232 [61, 64, 107, 109, 232, 111, 232, 111, 111] belangh van die van Woatervliedt niet
# avg_repeat_symbol_length: 116
# ...
# 	PAGE_REFS: [504] 	CURR LEMMA: in Vlaanderen
# 9 275 100 continue_stop 	             voor de Caffemajor.   504.
# 	PAGE_REFS: [517] 	CURR LEMMA: in Vlaanderen
# 10 278 92 continue_stop 	              voorde Bye.   517.
# 11 276 79 continue 	              woor van Affelen   $26.
# 12 273 65 continue 	             voor Ktgenten van Maaslandt.  '$219.
# 	PAGE_REFS: [641] 	CURR LEMMA: in Vlaanderen
# 13 155 -53 start_stop 	              —— oor de Lange.   641.
# 	PAGE_REFS: [654] 	CURR LEMMA: in Vlaanderen
# 14 155 -40 start_stop 	              —— voor Ginbove.  654.
# 	PAGE_REFS: [805] 	CURR LEMMA: in Vlaanderen
# 15 155 -26 start_stop 	              —— voor Regenten van Waalwyck. 805.
# 16 155 -12 start 	             —— voo Ingelanden van de fwarte Pol:
# 	PAGE_REFS: [891] 	CURR LEMMA: in Vlaanderen
# 17 155 1 continue_stop 	       der.   891,
# 18 154 0 start 	              —— van felicitatie aan den Koningh van
# 	PAGE_REFS: [20] 	CURR LEMMA: in Vlaanderen
# 19 156 3 continue_stop 	        Groot-Brittannien.  20.
# 	PAGE_REFS: [126] 	CURR LEMMA: in Vlaanderen
# 20 151 -2 start_stop 	              —— aan den Grave van Daun.   126:
# 21 151 0 start 	             —— gan  de  Keyferinne  van  Ruslandt.
# 	PAGE_REFS: [223] 	CURR LEMMA: in Vlaanderen
# 22 154 3 continue_stop 	       223.
# 23 151 1 continue 	              —— aan  den  Koningh  van  Vranckryck.
# 	PAGE_REFS: [649] 	CURR LEMMA: in Vlaanderen
# 24 151 2 continue_stop 	       649.
# 25 144 -4 start 	              —— van  naturalifatie  voor  MWeyherrn,
# 26 152 5 continue 	       534-
# 27 144 -2 start 	              —— van  ontflaginge  van  fidei-commis
# 	PAGE_REFS: [963] 	CURR LEMMA: in Vlaanderen
# 28 144 -1 start_stop 	       voor van Beven.  963.
# 29 144 -1 start 	             —— van pardon voor Martin.   $22.
# 	PAGE_REFS: [333] 	CURR LEMMA: in Vlaanderen
# 30 144 -1 start_stop 	              —— voor de Vaines.   333.
# 	PAGE_REFS: [767] 	CURR LEMMA: in Vlaanderen
# 31 144 -1 start_stop 	             —— vo Vaillant.   767.
# 32 144 -2 start 	             —— van  rappel  voor  den  Amba(Jadeur
# 	PAGE_REFS: [684] 	CURR LEMMA: in Vlaanderen
# 33 148 2 continue_stop 	       Hop.   684.
# 34 148 1 continue 	             —— van recredentie  voor  Gedeputeerden
# 	PAGE_REFS: [397] 	CURR LEMMA: in Vlaanderen
# 35 152 4 continue_stop 	       van Oofl-Vrieslaadt:   397.
# 	PAGE_REFS: [97] 	CURR LEMMA: in Vlaanderen
# 36 148 -1 start_stop 	              —— voor Hefelingh.   97.
# 	PAGE_REFS: [611] 	CURR LEMMA: in Vlaanderen
# 37 148 -3 start_stop 	             —— voor Windisgratz.   611.
# 	PAGE_REFS: [867] 	CURR LEMMA: in Vlaanderen
# 38 152 0 start_stop 	              —— voor Kourakin.  867.
# 	PAGE_REFS: [925] 	CURR LEMMA: in Vlaanderen
# 39 152 0 start_stop 	             —— voor Monteleon.  925.
# 40 154 2 continue 	              —— wan  relif  voor  Thys  pro] Deo.
# 	PAGE_REFS: [364] 	CURR LEMMA: in Vlaanderen
# 41 160 7 continue_stop 	        364.
# 	PAGE_REFS: [538] 	CURR LEMMA: in Vlaanderen
# 42 154 0 start_stop 	              —— voor Machiels.   538.
# 43 154 0 start 	              —— oor Deeken en Capittel van St. Kruys
# 	PAGE_REFS: [950] 	CURR LEMMA: in Vlaanderen
# 44 154 0 start_stop 	       tot Luyck.  950.
# 	PAGE_REFS: [957] 	CURR LEMMA: in Vlaanderen
# 45 154 -1 start_stop 	             —— oor Hendricks.  957.
# 46 154 0 start 	              —— van remi(lie voor Regenten van Ros:
# 	PAGE_REFS: [194] 	CURR LEMMA: in Vlaanderen
# 47 156 2 continue_stop 	        malen.   194.
# 48 154 -1 start 	              —— voor Regenten van Berlicum en Mid-
# 	PAGE_REFS: [319] 	CURR LEMMA: in Vlaanderen
# 49 156 1 continue_stop 	        delroode.   319.
# 	PAGE_REFS: [320] 	CURR LEMMA: in Vlaanderen
# 50 156 0 start_stop 	              —— voor Regenten van Maaren.   320.
# 	PAGE_REFS: [363] 	CURR LEMMA: in Vlaanderen
# 51 156 0 start_stop 	              —— voor Regenten van Oerle.   363.
# 	PAGE_REFS: [458] 	CURR LEMMA: in Vlaanderen
# 52 156 -1 start_stop 	              —— voor Regenten van Put.  458.
# 53 156 -1 start 	              —— voor Regenten van Heeswijk en Dins
# 	PAGE_REFS: [463] 	CURR LEMMA: in Vlaanderen
# 54 161 4 continue_stop 	        ther.  463.
# 	PAGE_REFS: [464] 	CURR LEMMA: in Vlaanderen
# 55 159 1 continue_stop 	              —— voor Regenten van Berchem. 464.
# 	PAGE_REFS: [465] 	CURR LEMMA: in Vlaanderen
# 56 159 1 continue_stop 	              —— voor Regenten van Miftelroy.  465.
# 57 159 -8 start 	              —— voor  Regenten van Hoogemierden, La=
# 	PAGE_REFS: [480] 	CURR LEMMA: in Vlaanderen
# 58 159 -9 start_stop 	        gemierden en Hulfel.   480.
# 59 159 -10 start 	              —— voor Regenten van Nuland.   $34.
# 	PAGE_REFS: [534] 	CURR LEMMA: in Vlaanderen
# 60 159 -12 start_stop 	              —— oor Regenten van Geffen.   534:
# 61 233 60 continue 	           ——              eee
# returned lemma: in Vlaanderen
#
#
#  year-1725-scan-10-even
#
#
#  scan-10-even-0
# possibly misrecognised repeat symbol: 127 ee
# possibly misrecognised repeat symbol: 125 mn
# DEVIATING LINE: 260 [117, 119, 260, 259, 257, 258, 257] voor Regenten van Ooftelbeers. 488.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 259 [117, 119, 260, 259, 257, 258, 257, 117] voor Reventen van Waalre. 589.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 257 [117, 119, 260, 259, 257, 258, 257, 117, 256] voor Regenten van Reufel. 589.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 258 [119, 260, 259, 257, 258, 257, 117, 256, 253] voor Regenten van Neterfel. 590.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 257 [260, 259, 257, 258, 257, 117, 256, 253, 252] voor Regenten van Heech. 645.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 256 [257, 258, 257, 117, 256, 253, 252, 252, 249] voor Regenten van Vellem. 64.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 253 [258, 257, 117, 256, 253, 252, 252, 249, 248] voor Regenten van Udenhout. 654.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 252 [257, 117, 256, 253, 252, 252, 249, 248, 128] voor Regenten van Helvosrt. 796.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 252 [117, 256, 253, 252, 252, 249, 248, 128, 154] voor Regenten van Drunen, 756.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 249 [256, 253, 252, 252, 249, 248, 128, 154, 247] voor Regenten van Moergeftel. 757.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 248 [253, 252, 252, 249, 248, 128, 154, 247, 158] voor Regenten van Die{en. 767.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 247 [249, 248, 128, 154, 247, 158, 238, 240, 151] voor Regenten van Merfeldboven en
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 238 [128, 154, 247, 158, 238, 240, 151, 243, 242] voor Regenten van Eer(el. 788.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 243 [158, 238, 240, 151, 243, 242, 242, 239, 102] voor Regenten van Riethoven. 917.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 242 [238, 240, 151, 243, 242, 242, 239, 102, 146] voor Regenten van O[th. 917.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 242 [240, 151, 243, 242, 242, 239, 102, 146, 236] voor Regenten van Keffel. 949.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 239 [151, 243, 242, 242, 239, 102, 146, 236, 236] voor Regenten van Oofterwijck. 955.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 236 [242, 239, 102, 146, 236, 236, 237, 233, 144] oor Regenten van Dungen. 957.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 236 [239, 102, 146, 236, 236, 237, 233, 144, 232] voor Regenten van Weftelbeers. 958.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 237 [102, 146, 236, 236, 237, 233, 144, 232, 229] voor Regenten van Lommel. 959.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 242 [221, 227, 230, 140, 242, 130, 222, 130, 228] van furcheantie voor HWeybern.
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 222 [230, 140, 242, 130, 222, 130, 228, 128, 78] van voorfchryvens voor de Neufville
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 228 [242, 130, 222, 130, 228, 128, 78, 125, 73] voor Zegelaar , cum {uis, aan ’t Hof
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 220 [78, 125, 73, 123, 220, 118, 221, 96, 221] vor Boifanguin, cum {uis, aan het
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 221 [73, 123, 220, 118, 221, 96, 221, 114, 216] voor Brandtjes, cum fuis, aan’t Hof
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 221 [220, 118, 221, 96, 221, 114, 216, 111, 214] voor Loftus cum Íuis aan het Hof
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 216 [221, 96, 221, 114, 216, 111, 214, 108, 59] voo Freher; cum fuis , aan het Hof
# avg_repeat_symbol_length: 99
# DEVIATING LINE: 214 [221, 114, 216, 111, 214, 108, 59, 106] yoór Hammerfteyn aan de Churfarf
# avg_repeat_symbol_length: 99
# 	PAGE_REFS: [387] 	CURR LEMMA: in Vlaanderen
# 0 117 -14 start_stop 	    mem voor Regenten van Palkenswaart.  387.
# 	PAGE_REFS: [588] 	CURR LEMMA: in Vlaanderen
# 1 119 -13 start_stop 	    me voor Regenten van Wintelre. 588.
# 	PAGE_REFS: [488] 	CURR LEMMA: in Vlaanderen
# 2 141 8 continue_stop 	     —— voor Regenten van Ooftelbeers. 488.
# 	PAGE_REFS: [589] 	CURR LEMMA: in Vlaanderen
# 3 140 9 continue_stop 	     —— voor Reventen van Waalre.   589.
# 	PAGE_REFS: [589] 	CURR LEMMA: in Vlaanderen
# 4 138 7 continue_stop 	     —— voor Regenten van Reufel.   589.
# 	PAGE_REFS: [590] 	CURR LEMMA: in Vlaanderen
# 5 139 6 continue_stop 	     —— voor Regenten van Neterfel.  590.
# 	PAGE_REFS: [645] 	CURR LEMMA: in Vlaanderen
# 6 138 3 continue_stop 	     —— voor Regenten van Heech.  645.
# 	PAGE_REFS: [653] 	CURR LEMMA: in Vlaanderen
# 7 117 -17 start_stop 	    mn voor Regenten van Bergheyck.  653.
# 	PAGE_REFS: [64] 	CURR LEMMA: in Vlaanderen
# 8 137 4 continue_stop 	     —— voor Regenten van Vellem.  64.
# 	PAGE_REFS: [654] 	CURR LEMMA: in Vlaanderen
# 9 134 2 continue_stop 	     —— voor Regenten van Udenhout.  654.
# 	PAGE_REFS: [796] 	CURR LEMMA: in Vlaanderen
# 10 133 2 continue_stop 	     —— voor Regenten van Helvosrt.  796.
# 	PAGE_REFS: [756] 	CURR LEMMA: in Vlaanderen
# 11 133 1 continue_stop 	     —— voor Regenten van Drunen, 756.
# 	PAGE_REFS: [757] 	CURR LEMMA: in Vlaanderen
# 12 130 -4 start_stop 	     —— voor Regenten van Moergeftel. 757.
# 	PAGE_REFS: [767] 	CURR LEMMA: in Vlaanderen
# 13 129 -7 start_stop 	    —— voor Regenten van Die{en.   767.
# 14 128 -7 start 	    —_    voor Regenten van Hapert en Cafteren.
# 	PAGE_REFS: [770] 	CURR LEMMA: in Vlaanderen
# 15 154 7 continue_stop 	      770.
# 16 128 -21 start 	    —— voor  Regenten  van Merfeldboven  en
# 	PAGE_REFS: [778] 	CURR LEMMA: in Vlaanderen
# 17 158 10 continue_stop 	      Zeelft.   778.
# 	PAGE_REFS: [788] 	CURR LEMMA: in Vlaanderen
# 18 128 -20 start_stop 	    —— voor Regenten van Eer(el.   788.
# 19 240 93 continue 	          voor Regenten van Hooghloon   Bladel
# 	PAGE_REFS: [914] 	CURR LEMMA: in Vlaanderen
# 20 151 8 continue_stop 	      en Neter[el.   914.
# 	PAGE_REFS: [917] 	CURR LEMMA: in Vlaanderen
# 21 124 -17 start_stop 	    —— voor Regenten van Riethoven. 917.
# 	PAGE_REFS: [917] 	CURR LEMMA: in Vlaanderen
# 22 123 -16 start_stop 	    —— voor Regenten van O[th.   917.
# 	PAGE_REFS: [949] 	CURR LEMMA: in Vlaanderen
# 23 123 -15 start_stop 	    —— voor Regenten van Keffel.   949.
# 	PAGE_REFS: [955] 	CURR LEMMA: in Vlaanderen
# 24 120 -4 start_stop 	    —— voor Regenten van Oofterwijck. 955.
# 25 102 -19 start 	   ms voor Regenten van Berckel, Enfchet en
# 	PAGE_REFS: [955] 	CURR LEMMA: in Vlaanderen
# 26 146 13 continue_stop 	     Huiclom.   955.
# 	PAGE_REFS: [957] 	CURR LEMMA: in Vlaanderen
# 27 117 -18 start_stop 	    —— oor Regenten van Dungen.   957.
# 	PAGE_REFS: [958] 	CURR LEMMA: in Vlaanderen
# 28 117 -30 start_stop 	    —— voor Regenten van Weftelbeers. 958.
# 	PAGE_REFS: [959] 	CURR LEMMA: in Vlaanderen
# 29 118 -41 start_stop 	    —— voor Regenten van Lommel.  959.
# 30 233 60 continue 	          voor  Regenten  van E[ch,  Vught en
# 	PAGE_REFS: [962] 	CURR LEMMA: in Vlaanderen
# HAS LEMMA: Cromvoirt. 962.
# LEMMA: Cromvoirt
# LEMMA: Cromvoirt
# setting lemma: Cromvoirt
# 31 144 -38 start_stop 	     Cromvoirt.   962.
# 	PAGE_REFS: [967] 	CURR LEMMA: Cromvoirt
# 32 232 38 continue_stop 	          voor Regenten van Haren.   967.
# 	PAGE_REFS: [967] 	CURR LEMMA: Cromvoirt
# 33 229 23 continue_stop 	         voor Regenten van Riel.  967.
# 	PAGE_REFS: [158] 	CURR LEMMA: Cromvoirt
# 34 228 19 continue_stop 	         van requifitoir voor de Groote. 158.
# 	PAGE_REFS: [159] 	CURR LEMMA: Cromvoirt
# 35 221 24 continue_stop 	         voor Baache.   159.
# 	PAGE_REFS: [673] 	CURR LEMMA: Cromvoirt
# 36 227 31 continue_stop 	         van revilie voor Heerent[e.  673.
# 37 230 48 continue 	          van fureté du Corps voor de Salis.
# 	PAGE_REFS: [182] 	CURR LEMMA: Cromvoirt
# 38 140 -31 start_stop 	     182.
# 39 130 -27 start 	    —— van   furcheantie  voor   HWeybern.
# 	PAGE_REFS: [97] 	CURR LEMMA: Cromvoirt
# 40 130 -17 start_stop 	     97:
# 41 103 -27 start 	   —— van voorfchryvens  voor de Neufville
# 	PAGE_REFS: [8] 	CURR LEMMA: Cromvoirt
# 42 130 11 continue_stop 	     aan het Hof van Spaigne.   8.
# 43 109 -2 start 	   —— voor Zegelaar, cum {uis, aan ’t Hof
# 	PAGE_REFS: [20] 	CURR LEMMA: Cromvoirt
# 44 128 17 continue_stop 	    van Spaigne.   20.
# 45 78 -29 start 	  veen voor Bofch, Weduwe Boreel aan’t Hof
# 	PAGE_REFS: [37] 	CURR LEMMA: Cromvoirt
# 46 125 16 continue_stop 	    van Portugaal.   37.
# 47 73 -33 start 	  ——  voor van  Dalen  aan  den  Refident
# 	PAGE_REFS: [49] 	CURR LEMMA: Cromvoirt
# 48 123 19 continue_stop 	    Pefters.  49.
# 49 101 -1 start 	   —— vor Boifanguin,  cum {uis,  aan het
# 	PAGE_REFS: [55] 	CURR LEMMA: Cromvoirt
# 50 118 12 continue_stop 	    Hof van Spaigne.   55.
# 51 102 0 start 	   —— voor Brandtjes, cum fuis, aan’t Hof
# 	PAGE_REFS: [149] 	CURR LEMMA: Cromvoirt
# 52 96 -11 start_stop 	   ‘van den Czaar.   149.
# 53 102 -2 start 	   —— voor Loftus   cum Íuis   aan het Hof
# 	PAGE_REFS: [177] 	CURR LEMMA: Cromvoirt
# 54 114 10 continue_stop 	    van den Czaar.   177.
# 55 97 -1 start 	   —— voo Freher; cum fuis, aan het Hof
# 	PAGE_REFS: [248] 	CURR LEMMA: Cromvoirt
# 56 111 13 continue_stop 	    van Deenemarcken.   248.
# 57 95 -4 start 	   —— yoór  Hammerfteyn  aan  de  Churfarf
# 	PAGE_REFS: [273, 481] 	CURR LEMMA: Cromvoirt
# 58 108 10 continue_stop 	   van de Paltz.   273. 481.
# 59 59 -37 start 	 —— voor de Na(Jau aan ‘het Hof van Por-
# 	PAGE_REFS: [295, 764] 	CURR LEMMA: Cromvoirt
# 60 106 11 continue_stop 	   tugaal.   295. 764.
# returned lemma: Cromvoirt
#
#
#  scan-10-even-1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-146d565c5017> in <module>()
#      20         column_hocr = column_info["column_hocr"]
#      21         lines = index_parser.get_index_entry_lines(column_hocr)
# ---> 22         curr_lemma = index_parser.index_lemmata(column_info["column_id"], lines, lemma_index, curr_lemma)
#      23         print("returned lemma:", curr_lemma)
#      24
#
# ~/Code/Huygens/republic-hocr-parser/republic_index_page_parser.py in index_lemmata(column_id, lines, lemma_index, curr_lemma)
#     271         return curr_lemma
#     272     description = ""
# --> 273     fixed_lines = fix_repeat_symbols(lines)
#     274     for line_index, line in enumerate(fixed_lines):
#     275         if len(line["words"]) == 0:
#
# ~/Code/Huygens/republic-hocr-parser/republic_index_page_parser.py in fix_repeat_symbols(lines)
#     265 def fix_repeat_symbols(lines):
#     266     fixed_lines = fix_repeat_symbols_lines(lines)
# --> 267     return find_missing_repeat_symbols(fixed_lines)
#     268
#     269 def index_lemmata(column_id, lines, lemma_index, curr_lemma):
#
# ~/Code/Huygens/republic-hocr-parser/republic_index_page_parser.py in find_missing_repeat_symbols(lines)
#      98
#      99 def find_missing_repeat_symbols(lines):
# --> 100     avg_repeat_symbol_length = get_repeat_symbol_length(lines)
#     101     fixed_lines = []
#     102     for line_index, curr_line in enumerate(lines):
#
# ~/Code/Huygens/republic-hocr-parser/republic_index_page_parser.py in get_repeat_symbol_length(lines)
#      70         if has_repeat_symbol(line):
#      71             repeat_symbol_lengths += [line["words"][0]["width"]]
# ---> 72     return int(sum(repeat_symbol_lengths) / len(repeat_symbol_lengths))
#      73
#      74 def add_repeat_symbol(line, avg_repeat_symbol_length, minimum_start):
#
# ZeroDivisionError: division by zero

# %%
for lemma in lemma_index:
    print("\nTrefwoord:", lemma)
    #print(lemma_index[lemma])
    for entry in lemma_index[lemma]:
        pages = ", ".join([str(page_ref) for page_ref in entry["page_refs"]])
        description = entry["description"][:70]
        print("\tPagina:", pages, "\tBeschrijving:", description)

# %%
# scan 45 uneven is first resolution page
# page num: 91

from fuzzy_context_searcher import FuzzyContextSearcher
import pandas as pd

config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 3,
    "skip_size": 0,
}

fuzzy_searcher = FuzzyContextSearcher(config)

keywords = [
    "Admiraliteyt tot Amfterdam", 
    "Admiraliteyt in het Noorder Quartier", 
    "Admiraliteyt in Vrieslandt", 
    "Admiralteyt in Zeelandt",
    "Varckens"
]

distractor_terms = {
    "Admiraliteyt tot Amfterdam": {
        "Admiraliteyt in het Noorder Quartier", "Admiraliteyt in Vrieslandt", "Admiralteyt in Zeelandt"
    },
    "Admiraliteyt in het Noorder Quartier": {
        "Admiraliteyt tot Amfterdam", "Admiraliteyt in Vrieslandt", "Admiralteyt in Zeelandt"
    },
    "Admiraliteyt in Vrieslandt": {
        "Admiraliteyt tot Amfterdam", "Admiraliteyt in het Noorder Quartier", "Admiralteyt in Zeelandt"
    },
    "Admiralteyt in Zeelandt": {
        "Admiraliteyt tot Amfterdam", "Admiraliteyt in het Noorder Quartier", "Admiraliteyt in Vrieslandt"
    },
}
fuzzy_searcher.index_keywords(keywords)
fuzzy_searcher.index_distractor_terms(distractor_terms)

hocr_resolution_pages = []

# %% [markdown]
# ### Extracting Resolutions From Pages
#
# Identify:
#
# - resolution dates
# - resolution participant lists
# - resolution text blocks

# %%
from fuzzy_context_searcher import FuzzyContextSearcher
from fuzzy_person_name_searcher import FuzzyPersonNameSearcher
from republic_phrase_model import resolution_phrases, participant_list_phrases, spelling_variants

config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
}


fuzzy_searcher = FuzzyContextSearcher(config)
fuzzy_person_searcher = FuzzyPersonNameSearcher(config)

fuzzy_searcher.index_keywords(resolution_phrases)
fuzzy_searcher.index_spelling_variants(spelling_variants)
#fuzzy_searcher.index_distractor_terms(distractor_terms)

# %%
from fuzzy_context_searcher import FuzzyContextSearcher
import republic_elasticsearch as rep_es

config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
    "paragraph_index": "republic_paragraphs",
    "paragraph_doc_type": "paragraph"
}

missing_dates = [
    {"date_string": "Veneris den 5. Januarii 1725.", "page_start": 11, "page_end": 14},
    {"date_string": "Mercuri den 10. Januarii 1725.", "page_start": 21, "page_end": 28},
]

fuzzy_searcher = FuzzyContextSearcher(config)

for missing_date in missing_dates:
    fuzzy_searcher.index_keywords([missing_date["date_string"]])
    for page_num in range(missing_date["page_start"], missing_date["page_end"] + 1):
        paragraphs = rep_es.retrieve_paragraph_by_type_page_number(page_num, config)
        for paragraph in paragraphs:
            matches = fuzzy_searcher.find_candidates(paragraph["text"])
            for match in matches:
                print(match)
                print("page: {}\tDate: {}\tText string: {}\n".format(page_num, match["match_keyword"], match["match_string"]))
                print(paragraph["text"])
# Out:
# {'match_keyword': 'Veneris den 5. Januarii 1725.', 'match_term': 'Veneris den 5. Januarii 1725.', 'match_string': 'Veucris den 5. Januaris 1725', 'match_offset': 9, 'char_match': 0.8620689655172413, 'ngram_match': 0.7666666666666667, 'levenshtein_distance': 0.8620689655172413}
# page: 13	Date: Veneris den 5. Januarii 1725.	Text string: Veucris den 5. Januaris 1725
#
# 1735. ie Veucris den 5. Januaris 1725. PR&ASIDE, Den Heere Bentinck. PRASENTIEBUS, De Heeren Jan Welderen van Dam, Torck met een extraordinaris Gedeputeerde uyt de Provincie van Gelderlandt. Van Maasdam vanden Boeizelaar Raadtpenfionaris van Hoornbeeck met een extraordinaris Gedeputeerde uyt de Provincie van Hollandt ende Welt-Vrieslandt. Velters, Ockere Noey; van Hoorn , met een extraordinaris Gedeputeerde uyt de Provincie van Zeelandt. Van Renswoude van Voor{t. Van Schwartzenbergh, vander Waayen, Vegilin Van I{elmuden. Van Iddekinge van Tamminga.
# {'match_keyword': 'Mercuri den 10. Januarii 1725.', 'match_term': 'Mercuri den 10. Januarii 1725.', 'match_string': 'Mercuri: den 10. Jangarii 1725', 'match_offset': 628, 'char_match': 0.9333333333333333, 'ngram_match': 0.8387096774193549, 'levenshtein_distance': 0.9}
# page: 25	Date: Mercuri den 10. Januarii 1725.	Text string: Mercuri: den 10. Jangarii 1725
#
# de -is goedtgevonden ende verftaan dat gemelde Regenten van'Haltteren en Noordt| geeft {uilen werden gelaft , {oo als gelaft werden mits defen om op aaníchryvinge van gemelden Droffaardt door haare Gecommitteerden óp de Quartiersvergaderinge nevens de andere Dorpen te compareeren, en aldaar als van oudts te helpen rTefolveeren, ende in de Quartierskoften te helpen draagen volgens de gewoone Tepartitie, ten waare redenen hadden tér contrarie, die fy in foodanigen geval alsnoch aan haar Hoogh Mogende {allen hebben bekent te maaken, binnen drie weeken na infinuatie defes, op pcene van haar Hoogh Mogende finaaie difpofitie. Mercuri: den 10. Jangarii 1725. PRESIDE, Den Heere an Iddekinge. PRA&SENTIBUS, De Heeren /an Welderen van Dam, van Wynbergen, Torck, met een extraordinaris Gedeputeerde uyt de Provincie van Gelderland. Van Maasdam Raadtpenfionaris van Hoorn=beeck. Velters, Ockerfe, Noey. Taats van Amerongen, van Renswoude. Vander Waasen Vegilin, Bentinck, van I(elmaden. Van Tamminga. E Refolutien gifteren gengmen, zyn gelefen en gerefumeert, gelijck oock gerefumeert ende gearrefteert zyn de Depeíches daar uyt refulteerende, Ox een Miflive van den Heere Rumpf, haar Hoogh Mogende extraordinaris Envoyé aan het Hof van fijne Majefteyt den Koningh van Sweeden, gefchreven {onder expreflie van plaats of datum, geaddrefleert aan den Grifher Fagel, houdende advertentie: WAAR op geen refolutie is gevallen.

# %%
import datetime
from elasticsearch import Elasticsearch

import republic_paragraph_parser as para_parser
from republic_phrase_model import category_index
import republic_elasticsearch as rep_es


page_index = "republic_hocr_pages"
page_doc_type = "page"

es = Elasticsearch()

def delete_es_index(index):
    if es.indices.exists(index=index):
        print("exists, deleting")
        es.indices.delete(index=index)

base_config = {
    "year": year,
    "base_dir": "../../../Data/Projects/REPUBLIC/hocr/",
    "page_index": "republic_hocr_pages",
    "page_doc_type": "page",
    "paragraph_index": "republic_paragraphs",
    "paragraph_doc_type": "paragraph",
    "tiny_word_width": 15, # pixel width
    "avg_char_width": 20,
    "remove_tiny_words": True,
    "remove_line_numbers": False,
}


year = 1725

year_config = set_config_year(base_config, year)
pages_info = get_pages_info(year_config)

#delete_es_index(year_config["paragraph_index"])

# start on January first

current_date = {
    "month_day": 1,
    "month_name": "Januarii",
    "month": 1,
    "week_day_name": None,
    "year": year
}
    
for page_id in pages_info:
    start_scan = 1
    end_scan = 600
    if pages_info[page_id]["scan_num"] < start_scan or  pages_info[page_id]["scan_num"] > end_scan:
        continue
    page_doc = rep_es.retrieve_page_doc(page_id, year_config)
    #if pages_info[page_id]["page_type"] != "resolution_page":
    if page_doc["page_type"] != "resolution_page":
        continue
    paragraphs, header = para_parser.get_resolution_page_paragraphs(page_doc)
    print("page_id:", page_id, "\ttype:", page_doc["page_type"], "\tnum columns:", len(page_doc["columns"]))
    #print("num columns:", len(page_doc["columns"]), "\theader lines:", [line["line_text"] for line in header])
    for paragraph_order, paragraph in enumerate(paragraphs):
        paragraph_text = para_parser.merge_paragraph_lines(paragraph)
        paragraph["metadata"]["categories"] = set()
        paragraph["text"] = paragraph_text
        paragraph["metadata"]["paragraph_num_on_page"] = paragraph_order
        paragraph["metadata"]["paragraph_id"] = "{}-para-{}".format(page_id, paragraph_order)
        #print(paragraph_text, "\n\n")
        matches = fuzzy_searcher.find_candidates(paragraph_text, include_variants=True)
        if len(matches) == 0 and para_parser.paragraph_starts_with_centered_date(paragraph):
            print("DATE LINE:", paragraph_text)
            current_date = para_parser.extract_meeting_date(paragraph, year, current_date)
            #print("paragraph_text:", paragraph_text)
        if para_parser.matches_participant_list(matches):
            print("DAY START:", paragraph_text)
            #context_match = fuzzy_searcher.get_term_context(paragraph_text, match, context_size=200)
            #print(context_match)
            #person_matches = fuzzy_person_searcher.find_person_names_in_text(context_match["match_term_in_context"])
            if para_parser.paragraph_starts_with_centered_date(paragraph):
                current_date = para_parser.extract_meeting_date(paragraph, year, current_date)
                paragraph["metadata"]["categories"].add("meeting_date")
            paragraph["metadata"]["type"] = "participant_list"
            #print("\n\tCurrent date: {}\n".format(current_date))
            #person_matches = fuzzy_person_searcher.find_person_names_in_context(context_match)
            #for person_match in person_matches:
            #    print("\t", person_match)
        if para_parser.matches_resolution_phrase(matches):
            paragraph["metadata"]["type"] = "resolution"
        paragraph["metadata"]["meeting_date_info"] = current_date
        if current_date:
            paragraph["metadata"]["meeting_date"] = datetime.date(current_date["year"], current_date["month"], current_date["month_day"])
        paragraph["metadata"]["keyword_matches"] = matches
        for match in matches:
            #print("\t{}\t{}".format(match["match_keyword"], match["match_string"]))
            if match["match_keyword"] in category_index:
                category = category_index[match["match_keyword"]]
                match["match_category"] = category
                paragraph["metadata"]["categories"].add(category)
                
        #print(paragraph["metadata"]["categories"])
        #print("\n\n\n")
        paragraph["metadata"]["categories"] = list(paragraph["metadata"]["categories"])
        del paragraph["lines"]
        es.index(index=year_config["paragraph_index"], doc_type=year_config["paragraph_doc_type"], 
                 id=paragraph["metadata"]["paragraph_id"], body=paragraph)
# Out:
# Number of scan files: 2161
# page_id: year-1725-scan-45-odd 	type: resolution_page 	num columns: 2
# DAY START: Martis den 2. Jannarii 1725. PRASIDE, Den Heere Bentinck. PRASENTIBUS, De Heeren Van Dam Torck, Ham, met een extraordinarts Gedeputeerde uyt de Provincie van Gelderlandt. Van Maasdam, vanden Boetzelaar , Boon, Raadtpenfionaris van Hoornbeeck met een extraordinaris Gedeputeerde uyt de Provincie van Hollandt ende Weû-Fries= landt. Velters, Ockerfe 5 Noey van Hoorn, met een extraordinaris Gedeputeerde uyt de Provincie van Zeelandt. Van Renswoude van Voork. Van Schwartzenbergh vander Waayen Vegilin. Van Ifelmuden, Van Iddekinge, van Tamminga.
# page_id: year-1725-scan-46-even 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-46-odd 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-47-even 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-47-odd 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-48-even 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-48-odd 	type: resolution_page 	num columns: 2
# DAY START: Mercuri: den 3. Januaris 1725. PRESIDE, Den Heere Bentinck. PRESENTIBUS, De Heeren Zan Dam, Torck, Ham, met een extraordinaris Gedeputeerde uyt de Provincie van Gelderlandt. Van Maasdam Boon Raadtpenfionaris van Hoornbeeck , met een extraordinaris Gedeputeerde uyt de Provincie van Hollandt ende Weft-Vrieslandt. Velters, Ockerfe , Noey , van Hoorn , met een extraordinaris Gedeputeerde uyt de Provincie van Zeelandt. Van Renswouds , van Voor. Van Schwartzenbergh vander HWaasen Vegilin, Van Ifelmuden.
# page_id: year-1725-scan-49-even 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-49-odd 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-50-even 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-50-odd 	type: resolution_page 	num columns: 2
# DAY START: Jovis den 4. Jannarii 1725. PRASIDE, Den Heere Bentinck. PRASENTIBUS, De Heeren Van Dam Torck, Ham; met een extraordinaris Gedeputecrde uyt de Provincie van Gelderlándt. Van Maasdam, vanden Boetzelaar , Boon , Raadtpenfionaris van Hoornbeeck met ecn extraordinaris Gedeputeerde uyt de Provincie van Hollandt ende Weh-Pries= landt.  Pelters Ockere, Noey, van Hoorn. Van Renswoude van Voort. Pan Schwartzenberg vander Waayen, Vegilin. Van Ifelmuden. Van Iddekinge , van Tamminga.
# page_id: year-1725-scan-51-even 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-51-odd 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan
odd 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-537-even 	type: resolution_page 	num columns: 2
# DAY START: # ominica den 30. December 2 725. - Nibil aftum eff. ad une den 31. December ig] 17254. PRA384ADE, en Heere 241 Maasdam. PRAESENTIBUS,; De Heeren Van Welderen, van Dam, van Wynbergen Umbgroeven met een exiraordinaris Gedeputeerde uyt de Provincie van Gelderlandt.* Eelbo Steyn van Marfeveen Boon, Raadtpenfionaris wan Hoornbeeck met een extraordinaris Gedeputeerde uyt de Provincie van Hollandt en Wef-Vrieslandt. Velters, Noey, met een extraordinaris Gedeputeerde uyt de Provincie van Zeelandt. Taats van Amerongen wan Renswoude, met een extraordinarts Gedeputeerde uyt de Provincie van Utrecht. Vegilin. Pan Haar[olte, van IJelmuden.
# page_id: year-1725-scan-537-odd 	type: resolution_page 	num columns: 2
# page_id: year-1725-scan-538-even 	type: resolution_page 	num columns: 1
# page_id: year-1725-scan-542-even 	type: resolution_page 	num columns: 1

# %%
from collections import Counter

subphrase_searcher = FuzzyContextSearcher(config)
known_phrase_searcher = FuzzyContextSearcher(config)

keywords = [
    "WAAR op",
]

known_phrases = [
    "voor de genomen moeyte bedanckt",
    "waar by goedgevonden is",
    "gehouden voor gecommiteert",
    "WAAR op gedelibereert zijnde",
    "WAAR op geen refolutie is gevallen",
    "WAAR op geen refolutie voor alsnoch is gevallen",
    "WAAR op gedelibereert en in achtinge genomen zynde",
]

known_phrase_searcher.index_keywords(known_phrases)
subphrase_searcher.index_keywords(keywords)
#subphrase_searcher.index_spelling_variants(spelling_variants)

phrase_count = Counter()

for page_id in pages_info:
    current_date = None
    start_page = 44
    end_page = 680
    if pages_info[page_id]["page_type"] != "resolution_page":
        continue
    if pages_info[page_id]["scan_num"] < start_page or  pages_info[page_id]["scan_num"] > end_page:
        continue
    #print(page_id, pages_info[page_id]["page_type"])
    page_doc = retrieve_page_doc(page_id)
    paragraphs, header = get_resolution_page_paragraphs(page_doc)
    #print("num columns:", len(page_doc["columns"]), "\theader lines:", [line["line_text"] for line in header])
    #continue
    for paragraph in paragraphs:
        paragraph_text = merge_paragraph_lines(paragraph)
        #print(paragraph_text, "\n\n")
        matches = subphrase_searcher.find_candidates(paragraph_text, include_variants=True)
        for match in matches:
            context_match = subphrase_searcher.get_term_context(paragraph_text, match, context_size=50)
            match_string = context_match["match_string"]
            context = context_match["match_term_in_context"]
            known_phrase_matches = known_phrase_searcher.find_candidates(context)
            for match in known_phrase_matches:
                phrase_count.update([match["match_keyword"]])
            if len(known_phrase_matches) > 0:
                continue
            parts = context.split(match_string)
            if len(parts) == 2:
                print(page_id, pages_info[page_id]["page_type"])
                print(match_string + parts[1])
            else:
                print("UNEXPECTED NUMBER OF PARTS")
                print(context_match)


for phrase, freq in phrase_count.most_common():
    print(freq, phrase)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-0d5e2e4ea4bf> in <module>()
#      28     start_page = 44
#      29     end_page = 680
# ---> 30     if pages_info[page_id]["page_type"] != "resolution_page":
#      31         continue
#      32     if pages_info[page_id]["scan_num"] < start_page or  pages_info[page_id]["scan_num"] > end_page:
#
# KeyError: 'page_type'

# %%
from collections import Counter

from fuzzy_context_searcher import FuzzyContextSearcher
from fuzzy_person_name_searcher import FuzzyPersonNameSearcher

config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
    "max_lenght_variance": 3,
}


subphrase_searcher = FuzzyContextSearcher(config)
known_phrase_searcher = FuzzyContextSearcher(config)

keywords = [
    #"DE Refolutien, gifteren genomen",
    "BY refumptie gedelibereert zynde",
]

known_phrases = [
]

known_phrase_searcher.index_keywords(known_phrases)
subphrase_searcher.index_keywords(keywords)
#subphrase_searcher.index_spelling_variants(spelling_variants)

phrase_count = Counter()

for page_id in pages_info:
    current_date = None
    start_page = 60
    end_page = 265
    if pages_info[page_id]["page_type"] != "resolution_page":
        continue
    if pages_info[page_id]["scan_num"] < start_page or  pages_info[page_id]["scan_num"] > end_page:
        continue
    #print(page_id, pages_info[page_id]["page_type"])
    page_doc = retrieve_page_doc(page_id)
    paragraphs, header = get_resolution_page_paragraphs(page_doc)
    #print("num columns:", len(page_doc["columns"]), "\theader lines:", [line["line_text"] for line in header])
    #continue
    for paragraph in paragraphs:
        paragraph_text = merge_paragraph_lines(paragraph)
        #print("PARAGRAPH TEXT:", paragraph_text, "\n\n")
        matches = subphrase_searcher.find_candidates(paragraph_text, include_variants=True)
        for match in matches:
            #print(match)
            context_match = subphrase_searcher.get_term_context(paragraph_text, match, context_size=50)
            match_string = context_match["match_string"]
            context = context_match["match_term_in_context"]
            known_phrase_matches = known_phrase_searcher.find_candidates(context)
            for match in known_phrase_matches:
                phrase_count.update([match["match_keyword"]])
            if len(known_phrase_matches) > 0:
                continue
            parts = context.split(match_string)
            if len(parts) == 2:
                print(page_id, pages_info[page_id]["page_type"])
                print("PARAGRAPH TEXT:", paragraph_text, "\n\n")
                print("\tMATCH_STRING:", match_string + parts[1])
            else:
                print("UNEXPECTED NUMBER OF PARTS")
                print(context_match)


for phrase, freq in phrase_count.most_common():
    print(freq, phrase)
# Out:
# scan-65-even resolution_page
# PARAGRAPH TEXT: T° ter Vergaderinge gelefen de Requefte van het meerder gctal der Leden van de Magiftraat der Stadt ’s Hertogenbofch 5 verfoeckende permiflie om ter Griffie van haar Hoogh Mogende te mogen lichten Copie van het bericht door den Prz(ident en vier Scheepenen aân haar Hoogh Mogende overgegeeven op haare voorige Regquelte, raackende her aanftellen van een Marcktíchipper op Rotterdam, en oock op Haarlem. WAAR op gedelibereert zynde, als mede hy refumptie gedelibereert zynde op de voorige Requefte van de Supplianten en op het voorgemelde bericht ; 1s goedtgevonden en verftaan dat de quzftie tuflchen de Supplianten, ter eenre, en: gemelde Praefident ende Scheepenen ter andere zyde, over recht ván aanttellinge van Marckt{chippers, aan wien het felve competeert {al werden gerenvoyeert en gelaten aan den Raadt van Brabandt , om daar op te difponeeren foo als na verhoor van Partyen in goede juftitie fullen vinden te behooren Behouddijek dat Partyen ten wederzyden gehouden {ullen wefen te procedeeren op | eygene koften, en geenfints tot lafte van de Stadt.
#
#
# 	MATCH_STRING: hy refumptie gedelibereert zynde op de voorige Requefte van de Supplianten en op he
# scan-76-odd resolution_page
# PARAGRAPH TEXT: Bt refumptie gedelibereert zynde op de Memorie van den Confal Optennoerth, gelchreven te Cadix den veertienden November des voorleden jaars {eventien hondertivier en twintigh met de Miflive en bygevocghde Declaratie van Ludolf Hameken gefchreven aan hem Conful uyr Tetuan en gedateert den eeríten van de felve maandt November beloopende gemelde Declaratie tot élf hondert vier en tmegentigh rycksdaalders Moors waardigh vier guldens Hollandtfch federt {ijn verblyf in Tetuan van den eerften April {e
#
#
# 	MATCH_STRING: Bt refumptie gedelibereert zynde op de Memorie van den Confal Optennoerth, gelchrev
# scan-79-even resolution_page
# PARAGRAPH TEXT: Bt relumptie gedelibereert zynde op de Requetfte van Jacques Re[plendain Pre dikant van de Vaudoifen in de Colonie vam Balmbaghb in het Hertoghdom van Wirtembergh en nu by haar Hoogh Mogende aangeftelt om te bedienen de Vaudoifche Kercke te Waldorf, in het Landt van Darmttadt ; verfoeckende , dat haar Hoogh Mogende hem eenige penningen tot tranfport van {ijn Perfoon en Meubilen gelieven toe te leggen. 15 goetgevonden ende verftaan, dat aan den Suppliant voor {ijn traníport fal werden toegeleght, foo als hem toegeleght werdt mits defen, hondert en vyftigh guldens eens daar toe den Raadt van Staate verfocht werdt v{ijnen behoeve de noodige Ordonnantie te doen depefcheeren.
#
#
# 	MATCH_STRING: Bt relumptie gedelibereert zynde op de Requetfte van Jacques Re[plendain Pre dikant
# scan-81-odd resolution_page
# PARAGRAPH TEXT: Bt refumptie gedelibereert zynde op de Requefte van Petrus de Spina ‚ haar Hoogh Mog. Rcfident te Franckfort, houdende dat hy in de Plaatfe (ijner refidentie is fonder Predikant dat den Graaf van Hanau te Bockenheym, omtrent een uur van Franckfort gelegen, wel heeft toegeftaan een Kerck voor de Gereformeerden, alwaar in de Franfehe 'Taale den dienft werdt gedaan, en waarin hy Suppliant, op het voorbeeldt van fijne Familie voor defen wel pleegh te gaan; doch dat hy daar van geen gebruyck meer maaken kan, naar dc onhebbelijcke
#
#
# 	MATCH_STRING: Bt refumptie gedelibereert zynde op de Requefte van Petrus de Spina ‚ haar Hoogh Mo
# scan-84-even resolution_page
# PARAGRAPH TEXT: Bt refumptie gedelibereert zynde op de Requefte van de ge/amentlijcke Boodens van de Generaliteyt ‚ houdende dat haar Supplianten den negenden Januari {eventien hondert vier en twintigh door den Agent van haar Hoogh Mog. was geordonneert, dat yeder Sondagh een Boode foude {iaan by de Banck van haar Hoogh Mogende, in dc Kloofter-Kerck alhier 1n den Hage, om te beletten, dat eenige andere als de Leden van haar Hoogh Mogende Vergaderinge aldaar plaat{e nemen verfoeckende {y Supplianten, dat haar deswegens yerwes moge werden toegeleght. IS er gevonden en verftaan, dat aan de Supplianten ter {aacke voorfchreve {al werden toegeleght foo als haar toegeleght werdt mits defen, hondert en vyftigh guldens jaarlijcks, daar toe den Raadt van Staate verfocht werdt t’haaren behoeve voor def veyle de noodige Ordonnantie te doen depefcheeren {ullende voor het toekomende de voorfchreve fomme op de Lijfte van de nieuwejaaren werden gebraght.
#
#
# 	MATCH_STRING: Bt refumptie gedelibereert zynde op de Requefte van de ge/amentlijcke Boodens van d
# scan-93-even resolution_page
# PARAGRAPH TEXT: B refumptie gedelibereert zynde op de Miflive van den Heere Fur{t van OoftVrieslandt gefchreven re Aurick den aght en twintightten December laatftleden, houdende creditif op den Heere Hartman Chriftof Becker, Regeeringhs- en FinantieRaadt van hooghgemelde {fijne Furftelijcke Doorluchtigheydt. IS goedtgevonden en verftaan mits defen te verklaaren , dat gemelden Heere Becker haar Hoogh Mogende aangenaam is. En fal Extraêt van defe haar Hoogh Mogende Refolutie door den Agent van. Baarle aan gemelden Heere Becker werden ter handen geftelt.
#
#
# 	MATCH_STRING: B refumptie gedelibereert zynde op de Miflive van den Heere Fur{t van OoftVrieslan
# scan-112-even resolution_page
# PARAGRAPH TEXT: BY rciomptie gedelibereert zynde op het geproponeerde van de Heeren Gedeputeerden van de Provincie van Zeelandt waar by de felve hebben voorgedraagen ende in oedencken gefteldt of nict in de tegenwoordige toeftandt en tydt van het jaar, een ‘generaale Danck- Vatt- en Bede €=
#
#
# 	MATCH_STRING: BY rciomptie gedelibereert zynde op het geproponeerde van de Heeren Gedeputeerden v
# scan-116-even resolution_page
# PARAGRAPH TEXT: Bt refamptie gedclibereert zynde op de Memorie van den Heere Hop haar Hoogh Mog. Ambafladeur aan het Hof van Vranckryck houdende dat haar Hoogh Mog. hem tot die Ambaflade hadden benoemdt by der felver Refolutie van den vier en twintightften Maart feventien hondert aghtien onder toefegginge dat de felve niet langer foude duuren als uytterlijck
#
#
# 	MATCH_STRING: Bt refamptie gedclibereert zynde op de Memorie van den Heere Hop haar Hoogh Mog. Am
# scan-119-even resolution_page
# PARAGRAPH TEXT: B“ refumptie gedelibereert ende de Retroaûta nagefien zynde op een Miflive van den Refident Sp:r4 , gefchreven te Franckfort den vyftienden defer loopende maandt, houdende advertentie ende onder anderen, dat daaghs naar het afgaan van fijne laatfte, aan hem by exprefle was tocgefonden door de Walfche Gemeente van de Colonie van Waldorp een Brief van den Heere Landt-Graave van Heflen-Darmftadt , nevens de voorfchreve Miflive gevoeght die wel van {eer oude daghrekeninge moghte zijn alfvo de voorfchreve Gemeente het daar voor hadt gehouden, dat door het toeftaan van haar Hoogh Mogende van den Predikant Refplendin op het eygenfte traêtement en reysgeldt als fijne Voorfaten hadden genoten, fy de voorfchreve Brief van voorfchryvens van den Heere Landt- Graave van Heffen Darmttadt niet van noden fouden hebben, doch dat die van. de Darmftadtfche Cancellerye de felve eghter aan haar hadt doen behandigen; dat men by de voorfchreve Gemeente wel van verfchillende meyninge was geweeft ; doch, dat de meefte eghter het daar voor hadden gehouden, dat men een goedt gebruyck van defe Miffive behoorde te maaken , ende die aan hem Refident te fenden om de felve te brengen ter tafel van haar Hoogh Mogende, ten eynde haar Hoogh Mogende ge|ieven aan hooghgemelden Heere Landt
#
#
# 	MATCH_STRING: B“ refumptie gedelibereert ende de Retroaûta nagefien zynde op een Miflive van den
# scan-119-even resolution_page
# PARAGRAPH TEXT: Y refumptie gedelibereert ende de ReB troaéta nagefien zijnde op de Requette. van N. Gaemar, een van de Predikanten der Franfche Colonien in het Wirtenbergefche, en N. Roland, als getrouwt hebbende een Doghrter van den overleden. Predikanr Sion, die mede een van de voornoemde Predikanten is geweeft; houdende, dat
#
#
# 	MATCH_STRING: Y refumptie gedelibereert ende de ReB troaéta nagefien zijnde op de Requette. van
# scan-122-even resolution_page
# PARAGRAPH TEXT: B refumptie gedelibereert zijnde op een Mifhve van den Heere vander Meer, haar Hoogh Mogende Ambaffadeur aan her Hof van fijne Majefteyt den Koningh van Spaigne ‚ gefchreven te Madrid den aghtften Januari laatftleden geaddreffeert aan den Griffier Fagel, houdende , dat de Spaanfche Wacht goedtgevonden hadt den vierden daar te vooren des avondts omtrent negen uuren {ijn Stalmeefter, en een van fijne Knechts te arrefteeren , en gevangen te brengen in het Retiro dat hy Heere vander Meer figh wel geinformeert hebbende op defe faack bevonden hadt, de felve foodanigh te wefen, als vermeldt {taat in de Memorie nevens de voorfchreve Miffive gevoeght, ‘welcke Memorie hy op dat fubjeêt geprzaefenteert hadt aan den Heere Marquis de Grimaldo hebbende daar op tot dic tydt tee noch geen antwoordt gekregen. IS goedtgevonden en ver(taan dat aan gemelden Heere vander Meer fal werden aangefchreven dat hy baar Hoogh Mogende fal berichten wat uytflagh de voorfchreve faake heeft gehad.
#
#
# 	MATCH_STRING: B refumptie gedelibereert zijnde op een Mifhve van den Heere vander Meer, haar Hoog
# scan-128-odd resolution_page
# PARAGRAPH TEXT: B refuinptie gedelibereert Zynde op het rapport van de Heeren de Ja Bafecour, Vegelin van Claarbergen cn Bentinck, haar Hoogh
#
#
# 	MATCH_STRING: B refuinptie gedelibereert Zynde op het rapport van de Heeren de Ja Bafecour, Vegel
# scan-134-odd resolution_page
# PARAGRAPH TEXT: 1735 (17 B refumptie gedelibereert zynde op de Miflive van den Secretaris Rumpf en.  laatítelijck op die van den aghtienden der voorlede maandt waar by aan haar Hoogh Mogende heeft gereprz@fenteert, hoe dat hy by manquement van ander Caradter, niet alleen voor {ijn Perfoon qmam te mi(fen den vrydom van impofitien , maar oock dat niet in {taat was om nevens de Mini{ters van andere Princen en Staaten, het intereft van defen Staat en van de Ingezenen van dien door het bekomen van 4udientien en anderfints met de felve nadruck waar te nemen. IS goetgevonden en verítaan dat aan gemelden Secretaris Rumpf (al werden gegeven de caraêter van Refident, en dat ten dien eynde voor hem een Brief van credentie gedepefcheert ende aan hem toegefonden fal werden en dat aan hem {al werden toegelcght , {oo als hem toegeleght werdt mits defen het ors dinaris traêtement van fes duyfent guldens ’sjaars, te betaalen voor het loopende jaar uyt de poft van de defroyementen, en voor het toekomende op den Staar van oorlogh te brengen, daar toe den Raadt van Staate mits delen werdt verfocht ende geauthorifeert. De Heeren Gedeputeerden van de Provicie van Zeelandt hebben in de bovenf{taande conclufie gecontradiceert op het behagen van de Heeren Staaten haare Principalen,
#
#
# 	MATCH_STRING: B refumptie gedelibereert zynde op de Miflive van den Secretaris Rumpf en.  laatít
# scan-138-odd resolution_page
# PARAGRAPH TEXT: B’ refumptie gedelibereert zynde op de Memorie van den Heere de Debrofe, -  extraordinaris Envoyé van fijne Majefteyt den Koningh van Poolen, Churfurft van Saxen, pratendeerende dat uyt de Quitantie, door den Ontfanger generaal van Hogendorp te geeven voor noch eenige penningen wegens de gedaane negotiatie ten behoeve van hooghitgedachte fijne Majefteyt en Churfurft, uyrgelaten foude werden de claufule van ia mminderinge ende ter goeder reekeninge. Als mede op de Memorie van gemelden Ontfanger generaal houdende {ijn bericht op de voorichreve Memorie van den Heere de Debrofe. IS goedtgevonden en verílaan dat Copic van de voorfchreve Memorie geftelt {al werden in handen van de Heeren van Wyn| bergen, ende andere haar Hoogh Mogende Gedeputeerden tot de {(aacken van de Finantie, om met gemelden Heere de Debrofe daar over te f{preecken , en den felven aan te wyzen dat den Ontfanger generaal (ijne Quitantie gevende ih contformiteyt van haar Hoogh Mogende Refolutie van den tweeden Januarii laarftleden daar mede behoort te volltaan, en dat de voors tchreve claufule aan de cene nochte aan de andere zyde geen przjaditie kan geeven, ende daar van alhier ter Vergaderinge Tap port te doen.
#
#
# 	MATCH_STRING: B’ refumptie gedelibereert zynde op de Memorie van den Heere de Debrofe, -  extraor
# scan-139-odd resolution_page
# PARAGRAPH TEXT: B’ refumptie gedelibereert zynde op de Memorie van den Heere de Debrofe, -  extraordinaris Envoyé van fijne Majefteyt den Koningh van Poolen, Churfurft van Saxen, pratendeerende dat uyt de Quitantie, door den Ontfanger generaal van Hogendorp te geeven voor noch eenige penningen wegens de gedaane negotiatie ten behoeve van hooghttgedachte fijne Majefteyt en Churfurft, uyrgelaten foude werden de claufule van ia mminderinge ende ter goeder reekeninge. Als mede op de Memorie van gemelden Ontfanger generaal houdende {ijn bericht op de voorichreve Memorie van den Heere de Debrofe. IS goedtgevonden en verílaan dat Copie van de voorfchreve Memorie geftelt fal werden in handen van de Heeren van Wynbergen, ende andere haar Hoogh Mogende Gedeputeerden tot de {aacken van de Finantie, om met gemelden Heere de Debrofe daar over te fpreecken, en den felven aan te wyzen dat den Ontfanger generaal (ijne Quitantie gevende in conformiteyt van haar Hoogh Mogende Refolutie van den tweeden Januari laarftleden daar mede behoort te volítaan, en dat de voors tchreve claufule aan de eene nochte aan de andere zyde geen przjuditie kan geeven, ende daar van alhier ter Vergaderinge Taps port te doen.
#
#
# 	MATCH_STRING: B’ refumptie gedelibereert zynde op de Memorie van den Heere de Debrofe, -  extraor
# scan-141-odd resolution_page
# PARAGRAPH TEXT: BT refimpue gedelibereert zijnde op het advis van de Heeren Gecommitteerde Raden in beyde de Quartieren, hebbende in gevolge ende tot voldoeninge van haaf Edele Groot Mog. Refolutie commifloriaal van
#
#
# 	MATCH_STRING: BT refimpue gedelibereert zijnde op het advis van de Heeren Gecommitteerde Raden in
# scan-146-odd resolution_page
#
#
# 	MATCH_STRING: B* refumptie gedelibereert zijnde op een Miffive van den Schout, kleyne en groo= ten
# scan-197-odd resolution_page
# PARAGRAPH TEXT: B refumptie gedelibereert zynde op de Miflive van de Magijtraat der Stadt Dordrecht, gefchreven aldaar den veeriienden defer loopende maandt , houdende dat door het overlijden van Mr. Johan Berck, in fijn leven Contrerolleur van de Convoyen en Licenten tot Hoorn, de Contrerolleursplaatfe aldaar is komen te vaceeren dat de voorfchreve Stadt Dordrecht competeert het recht, om tot vervullinge van dien te defpicieeren een bequaam Perfoon ; dat in achtingh genomen hebbende dc bes uaamheydt van Cornelis de Vries, haar De en Inwoonder, goedtgevonden hadden den felven tot Contrerolleur der Convoyen en Licenten tot Hoorn voornoemdt te defpicieeren ende aan haar Hoogh Mogende voor te draagen ; met verfoeck , dat haar Hoogh Mogendc gemelden Cornelis de Vries ‘als Contrerolleur aldaar gelieven te beëdigen en voor den {elven te doen de pefcheeren Commi{he in forma. Ende oock nagefien zynde haar Hoogh Mogende Refolutien van den twee en twintighften Januatii feftien hondert een en veertigh twee en twintightten December feftien hondert vier en veertigh, dertienden Juli feftien hondert fes en vyftigh en tienden Januari feftien hondert feven en feftigh,
#
#
# 	MATCH_STRING: B refumptie gedelibereert zynde op de Miflive van de Magijtraat der Stadt Dordrech
# scan-199-even resolution_page
# PARAGRAPH TEXT: B relumptie gedelibereert zijnde op de Memorie van den Secretaris Olivier, waarneensende de faaken van de Kroon van Spaigne aan haar Hoogh Mogende op den vierden defer gepr&tenteert met een Translaat van een Miffive van den Koningh van Spaigne „ houdende ‘een Creditif op den Capiteyn Don ‘Bernardo Sala, als Conful wan de Spaanfche Natie te Amtfterdam met macht om ten {ijnen koften Vice-Confuls te mogen aanftellen op foodanige Plaatfen alwaar die te vooren ‘hebben gerefideert. IS goedgevonden en verftmaan den voornoemden Capiteyn Don Ber
#
#
# 	MATCH_STRING: B relumptie gedelibereert zijnde op de Memorie van den Secretaris Olivier, waarneen
# scan-220-even resolution_page
# PARAGRAPH TEXT: Bt refumptie gedelibereert zijnde op de Mifive van de Heeren Paltzgraven van Birckenfelt gefchreven te Gelnhaufen den negentienden der voorlede maandt, houdende „dat haar Vrouwmoeder de Palrzgravinne Douariere tot Birckenfelt overleden zynde, fy by het nafien van haare Papieren, hadden gevonden , dat de {elve den twee en twintighften Julii feventien hondert vier en twintigh fchriftelijke inftantien hadt gedaan, ten eynde de achterftallen van wylen haar Vader den Palrzgraaf’ Johan Carel van Birckenfelt, dewelcke hy als Lieutenant-Generaal in dien{t van den Sraat te praetendeeren hadt eens voldaan moghren werden; dat haar Hoogh Mogende by Refolutie van den vyfden Augufti daar aan volgende, defe faake hadden geftelt in handen van de
#
#
# 	MATCH_STRING: Bt refumptie gedelibereert zijnde op de Mifive van de Heeren Paltzgraven van Bircken
# scan-221-even resolution_page
# PARAGRAPH TEXT: B’ refumptie gedelibereert en de Retroata nagelien zynde, op de Requeíte van de vier Trompctiers van haar Hoogh Mogende , houdende dar fy Supplianten vier achter een volgende dagen op het Huys van Prins Mauritz ter occafie van het defroyement van den Heere Ambafladeur van Vranckryck, op ordre van haar Hoogh Mogende hebben geblaafen verfoeckende „ dat haar Hoogh Mogende ter faacke voorlchreve aan baar Supplianten een recognitie gelieven toe te leggen, foodanigh als haar Hoogh Mogende {ouden oordeclen te behooren, IS goedtgevonden ende ver{laan dat in bet verfoeck , by de voorfchreve Requefte gedaan, niet kan werden getreden en werdt dienvolgende het {elve afgewefen.
#
#
# 	MATCH_STRING: B’ refumptie gedelibereert en de Retroata nagelien zynde, op de Requeíte van de vie
# scan-237-odd resolution_page
# PARAGRAPH TEXT: Bt reflumptie gedelibereert zynde op de Miflive van het Collegie ter Admiraliteyt op de Maaze gefchreven te Rotter
#
#
# 	MATCH_STRING: Bt reflumptie gedelibereert zynde op de Miflive van het Collegie ter Admiraliteyt op
# scan-245-odd resolution_page
# PARAGRAPH TEXT: Y refumptie gedelibereert zijnde op de B Miflive van den Raadt van Staate ge= {chreven alhier in den Hage den vyftienden der voorlede maandt houdende, dat den hondert{len Penningh op de Obligatien en Rentebrieven loopende ten lafte van het Comptoir generaal, en van de {ubalterne Comptoiren in het Diftrit van de Generaliteyt, by haar Hoogh Mogende Refolutie van *den vyftienden Junii teventien hondert twee en twintigh, niet langer gecontinueert zynde als tot het eynde van het voorleden jaar, het dienfligh foude zyn, dat gerefolveert wierdt over de continuatie van die belaftingh dewyl den tydt wanneer de renten en intereflen van het loo= pende jaar {uilen beginnen betaaldt te werden genaackt, hoewel den voet op dewelcke de Provincien furnceren haare contingenten in de {elve renten en intereflen, foude kunnen werden aangelien voor een ftilfwygende continuatie voor haarc vooris ge con{enten. 15 goedtgevonden en verftaan, dat geconfenteert fal werden’, foo als geconfenteert werdt mits defen in de belaftinge van de Obligatien en Rentebrieven , ftaande ten Jatte van het Comptoir generaal, en van de {ubalterne Comptoiren in het Dittriét van de Generaliteyt met een hondertften Penningh jaarlijcks voor den tydt van noch drie jaaren te heffen yeder half jaar een halven hondert{ten Penningb, in te gaan met ‘den eerften Januarii defes jaars feventien hondert vyf en twintigh, en
#
#
# 	MATCH_STRING: Y refumptie gedelibereert zijnde op de B Miflive van den Raadt van Staate ge= {chre

# %% [markdown]
# ## Experimental Corner
#
# Playground for trying fuzzy searching algorithms.

# %%
def score_levenshtein_distance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1
    distances = range(len(s1) + 1)
    #distances = [0] * (len(s1) + 1)
    #print("distances initial:",distances)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        #print("distances_:", distances_)
        #print("i2:", i2, "c2:", c2)
        for i1, c1 in enumerate(s1):
            #print("i1:", i1, "c1:", c1)
            if c1 == c2:
                distances_.append(distances[i1])
                #print(distances_, "equal")
            else:
                #print("\tminimum of:", distances[i1], distances[i1 + 1], distances_[-1])
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
                #print(distances_, "unequal")
        distances = distances_
        #distances = distances_
        #print("distances:", distances, s2[i2:i2+len(s1)])
    return distances[-1]

def get_match(matrix, T):
    match = ""
    col_index = len(matrix) - 1
    distance = matrix[-1][-1]
    row_index = len(matrix[-1]) - 1
    while row_index > 0:
        if col_index < 0:
            print("BREAKING")
            break
        #print("col_index:", col_index, "row_index:", row_index, "distance:", distance)
        if matrix[col_index-1][row_index-1] < distance:
            #print("replacing")
            match = T[col_index] + match
            distance = matrix[col_index-1][row_index-1]
            col_index -= 1
            row_index -= 1
        elif matrix[col_index][row_index-1] < distance:
            #print("inserting")
            #match = T[col_index-1] + match
            distance = matrix[col_index][row_index-1]
            row_index -= 1
        elif matrix[col_index-1][row_index] < distance:
            #print("deleting")
            match = T[col_index] + match
            distance = matrix[col_index-1][row_index]
            col_index -= 1
        elif matrix[col_index-1][row_index-1] == distance:
            #print("copying")
            match = T[col_index] + match
            col_index -= 1
            row_index -= 1
        else:
            print("This should never be printed")
        #print("row_index:", row_index)
        #print("match:", match)
    #print("returning match:", match)
    return (match, col_index+1, matrix[-1][-1])

def search_levenshtein_distance(P, T, threshold=2):
    if len(P) > len(T):
        P, T = T, P
    distances = range(len(P) + 1)
    matches = []
    matrix = []
    #distances = [0] * (len(T) + 1)
    #print("distances initial:",distances)
    for t_j, T_j in enumerate(T):
        distances_ = [0]
        #print("distances_:", distances_)
        #print("t_j:", t_j, "T_j:", T_j)
        for p_i, P_i in enumerate(P):
            #print("p_i:", p_i, "P_i:", P_i)
            if P_i == T_j:
                distances_.append(distances[p_i])
                #print(distances_, "equal")
            else:
                #print("\tminimum of:", distances[p_i], distances[p_i + 1], distances_[-1])
                distances_.append(1 + min((distances[p_i], distances[p_i + 1], distances_[-1])))
                #print(distances_, "unequal")
        distances = distances_
        #distances = distances_
        #print("distances:", distances, T[t_j-len(P):t_j])
        matrix += [distances]
        distance = distances[-1]
        if distance <= threshold:
            match = get_match(matrix, T)
            #print(T[:match[1]])
            #print(T[match[1]:match[1]+len(match[0])])
            #print(T[match[1]+len(match[0]):])
            matches.append(match)
    #for row in matrix:
    #    print(row)
    #for col_index, distance in enumerate(distances):
    return matches

target = "survey"
context = "surgery"
matches = search_levenshtein_distance(target, context)
print(matches)

target = "survey"
context = "the doctor is specialised in surgery of the heart"
matches = search_levenshtein_distance(target, context)
print(matches)
# Out:
# [('surge', 0, 2), ('surger', 0, 2), ('surgery', 0, 2)]
# [('surge', 29, 2), ('surger', 29, 2), ('surgery', 29, 2)]

# %%
texts = [
    "B. dr Bofch Mikelaer, zal op den 11 May , in de Keyzers Kroon verkopen , een uvrmuntënde pirty Schilderyen van de voornaernfte M;efter«; ils van de Oude Pslma extra goed , A'exander Veronecs, Pluweele Breugel , Wouwerman, J. vander Heydc, Laireffe, Bril en ancVc. Nagelaten door een voon.aem Liefhcbb.T ; als mede een fraye parry Teekenmgen en Miniatuur fchoone D'ukke Prenten van de voorn-emfte Mcefters. De Citilogu-zal ir.tyds te bekomen zyn by Jicób Carpi Konft
huvfcn, ftaende nieft mi'k.nrlrien in deGroore aen dl-Vtoord-vde by de dwirsftiact • bieede by 3i,;**rte**i vermeld: lefnanrna-e.'onderri.ti.ig begeerende of geneegen z.ynie degemPi'tcedriaTt ie.__.ad.teko.pen,fpi?eke mei yucru, Mak_liei, by wien de bewyzen .van cyi*j_d-_- S dagen voot de:yeikoop_ag.tc _iea zullen ü\", cv",
    "Job. Haverkamp Mikelaer, zal op Maendag den 11 January 1745, t Amft. in t Oude Heere Logement verkopen, No. 1. Een hegt en fterk Huys; ftaende op de Weesperftraet tuffchen de Hect:n en Keyzersgragt. No.1. Eén dito Huys.ftaende naeft 't voorgaende. No. 3. Een Sdepart in een we! ter nering ftaende Huys en Erve op de N. Z. van de Agterburgwal op de hoek van de Pottebakkersfteeg. Breder by Biüetten gefpecifkeert. De bewyzen van eygendom en de Vylconditien zullen 8 dagen voor en op de Verkoopdag voormiddag» tot J 2 uuren toe te zien zyn ten Compt. van den Notaris E. Haverkamp. Uyt dé huni te Koop een wel beklante Banket en Confiturier» Winkel met deszelfs Gereetfchappen , waer in die affaire» circa SS jaeren met c.\".cd fucces zyn gecontinueert: Te bevragen by Hendrik Bofch en Gomp., in de Kalverftract, tuflehen de Öjjes-flaysen Olyfiigers-fteeg\" t'Amfterdam. Als meede het Huys te hu*r.",
    "J. van Zutphen Mikelaer , zal op Maendag den 14 September , t'Amft. in 't Oude Heeren Logement verkopen , een extra wel geleegen 3-ftreeksLiken-Raem , met zyn Thuyn , Huyzinge en Droogfcheevders Winkel, eertyts genaemt het Varken, en nu Buyren-Ruft, ftaende en aeleegen buyten de Raem-Pooit ren eynde het eerfte Sceene-Pad , zynde Stads Grond , en geteekent met. No! 27, 28 en 29, Alles breder by Biljetten en dagelyks te zien , de bewyzen van Eygendom zullen 8 dagen voor en op de verkoopdag te zien zyn '. ten Compt. van den Nots. Arnoud Roermond in de Krom-Elleboogfteeg , en nader onderrigting by gem. Makelaer. ; Alle die iets te pretendeeren mogten hebben ten.laften van wylen Jean Fredrik Bernard , in zyn Leven Boekverkoper t'Amft. v of die eenige Engagementen met dezelve hebben lopende , uyr wat hoofde het o:)-_zoude mogen zyn, als mede die aen der Boedel fchuJdig mogten wezen , of ook eenige Goederen van hem onder zig hebben , werden verzogt zulks op voor tieu ïsOitcber 1744. .;ten Compt. vanden Notaris Jan Ardinois , op de Cingel t'Amfterdam.",    
]

target = "Makelaar"
target = "Oude Heere Logement"
for text in texts:
    matches = search_levenshtein_distance(target, text)
    print(matches)
# Out:
# [('Oude Heeren Logemen', 568, 2), ('Oude Heeren Logement', 568, 1), ('Oude Heeren Logement ', 568, 2)]
# []
# []
# [('Oude Heeten Logement', 73, 2)]
# [('Oude Heere Logeme', 74, 2), ('Oude Heere Logemen', 74, 1), ('Oude Heere Logement', 74, 0), ('Oude Heere Logement ', 74, 1), ('Oude Heere Logement v', 74, 2)]
# [('Oude Heeren Logemen', 74, 2), ('Oude Heeren Logement', 74, 1), ('Oude Heeren Logement ', 74, 2)]
