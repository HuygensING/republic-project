# %% [markdown]
# # Deduplication Experiment
#
# This notebook implements a non-destructive deduplication strategy using "blocking" and "clustering".
#
# ## Strategy
# 1. **Fetch**: Retrieve all records from the `namen_pydantic` index.
# 2. **Block**: Group records by normalized `geslachtsnaam` to reduce comparisons.
# 3. **Cluster**:
#     - Within each block, compare full names using Levenshtein distance (RapidFuzz).
#     - Apply strict constraints (e.g., birth/death year compatibility).
#     - Group matches into `MergedIndexItem` objects.
# 4. **Result**: A list of merged entities containing references to source IDs.

# %%
uv pip install rapidfuzz elasticsearch pydantic tqdm
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: elasticsearch in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (8.17.0)
# Requirement already satisfied: pydantic in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (2.12.5)
# Requirement already satisfied: tqdm in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: elastic-transport<9,>=8.15.1 in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from elasticsearch) (8.17.1)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from elastic-transport<9,>=8.15.1->elasticsearch) (2.6.3)
# Requirement already satisfied: certifi in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from elastic-transport<9,>=8.15.1->elasticsearch) (2025.11.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rikhoekstra/gensim_env/lib/python3.10/site-packages (from pydantic) (0.4.2)
# Downloading rapidfuzz-3.14.3-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.5 MB/s  0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.3

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan
from pydantic import BaseModel, Field, model_validator
from typing import List, Optional, Dict, Any
import rapidfuzz
from rapidfuzz import fuzz
from tqdm.notebook import tqdm
import collections
import re

# %%
# Initialize Elasticsearch
es = Elasticsearch(['http://localhost:9200'], verify_certs=False, request_timeout=30)
if es.ping():
    print("Connected to Elasticsearch")
else:
    print("Could not connect to Elasticsearch")
# Out:
# Connected to Elasticsearch

# %%
# --- MergedIndexItem Definition ---
class MergedIndexItem(BaseModel):
    canonical_fullname: str
    geslachtsnaam: str
    birth: Optional[str] = None
    death: Optional[str] = None
    ids: List[str]
    source_records: List[Dict] = Field(default_factory=list)
    
    @model_validator(mode='after')
    def set_canonical_name(self):
        if not self.canonical_fullname and self.source_records:
            names = [r.get('fullname', '') for r in self.source_records if r.get('fullname')]
            if names:
                self.canonical_fullname = max(names, key=len)
        return self

# %%
def fetch_all_records(es_client, index_name="namen_pydantic"):
    records = []
    print(f"Fetching records from index '{index_name}'...")
    try:
        # Use scan for efficient retrieval of all documents
        for hit in tqdm(scan(es_client, index=index_name, query={"query": {"match_all": {}}}), desc="Fetching", unit="rec"):
            source = hit['_source']
            source['_id'] = hit['_id']
            records.append(source)
    except Exception as e:
        print(f"Error fetching records: {e}")
    return records

# %%
# Fetch Records
all_records = fetch_all_records(es)
print(f"Total records fetched: {len(all_records)}")
# Out:
# Fetching records from index 'namen_pydantic'...
# Fetching: 0rec [00:00, ?rec/s]
# Total records fetched: 49803

# %%
# --- Collection Metadata Analysis ---
# Calculate date ranges (min/max year) for each collectionID
# This helps us infer possible date ranges for records that lack explicit birth/death years.

collection_stats = {}

print("Analyzing collection date ranges...")
for rec in all_records:
    coll = rec.get('collection')
    # Filter out 0 or None years
    years = []
    if rec.get('by') and rec.get('by') != 0:
        years.append(int(rec['by']))
    if rec.get('dy') and rec.get('dy') != 0:
        years.append(int(rec['dy']))
    
    if not coll:
        continue
        
    if coll not in collection_stats:
        collection_stats[coll] = {'years': []}
    
    collection_stats[coll]['years'].extend(years)

# Compute min/max
for coll, stats in collection_stats.items():
    years = stats['years']
    if years:
        stats['min'] = min(years)
        stats['max'] = max(years)
        stats['mean'] = sum(years) / len(years)
    else:
        # Fallback if a collection has NO valid dates
        stats['min'] = 1000
        stats['max'] = 2000 # broad default
        stats['mean'] = 1500
        
print(f"Computed stats for {len(collection_stats)} collections.")
# Example output
list(collection_stats.items())[:3]
# Out:
# Analyzing collection date ranges...
# Computed stats for 20 collections.
# [('anhalt_dessau_henriette_amalia_von',
#   {'years': [], 'min': 1000, 'max': 2000, 'mean': 1500}),
#  ('archives', {'years': [], 'min': 1000, 'max': 2000, 'mean': 1500}),
#  ('bourbon_charlotte_de',
#   {'years': [], 'min': 1000, 'max': 2000, 'mean': 1500})]

# %%
# --- Blocking and Clustering ---
def normalize_name(name):
    if not name: return ""
    return name.lower().strip()

# 1. Blocking
blocks = collections.defaultdict(list)
for rec in tqdm(all_records, desc="Blocking"):
    gn = rec.get('geslachtsnaam', '')
    if not gn:
        # Fallback if geslachtsnaam is empty, try to extract from fullname
        fullname = rec.get('fullname', '')
        if fullname:
            gn = fullname.split()[-1]
    
    key = normalize_name(gn)
    if key:
        blocks[key].append(rec)

print(f"Created {len(blocks)} blocks.")
# Out:
# Blocking:   0%|          | 0/49803 [00:00<?, ?it/s]
# Created 21027 blocks.

# %%
# 2. Clustering with Weighted Confidence Score (Refined for Name Formatting)
# We use a scoring system to combine name similarity, birth year, and death year compatibility.
# Score range: 0-100. Threshold for merge: 85 (adjustable).

merged_results = []
SCORE_THRESHOLD = 85

def get_year(item, field):
    try:
        val = item.get(field)
        if val is not None and int(val) != 0:
            return int(val)
    except (ValueError, TypeError):
        pass
    return None

def normalize_name_part(part):
    return part.lower().strip().replace('.', '').replace(',', '')

def extract_first_name(fullname):
    """
    Extracts the 'First Name' part using heuristics:
    - If comma present ('Doe, John'), take part AFTER comma.
    - If no comma ('John Doe'), take FIRST part.
    - Handle titles/prefixes.
    """
    if not fullname: return ""
    
    parts = fullname.split(',')
    if len(parts) > 1:
        # Format: "Lastname, Firstname ..."
        # Take the part after the first comma
        segment = parts[1].strip()
        tokens = segment.split()
    else:
        # Format: "Firstname Lastname" or just "Name"
        tokens = fullname.split()
        
    if not tokens: return ""
    
    first = normalize_name_part(tokens[0])
    
    # Skip common titles if the name has more parts
    titles = {'mr', 'dr', 'jhr', 'ds', 'prof', 'baron', 'graaf', 'ir', 'jonkheer', 'mevrouw', 'juffrouw'}
    if first in titles and len(tokens) > 1:
        first = normalize_name_part(tokens[1])
        
    return first

def calculate_match_score(item1, item2, stats):
    """
    Calculates a match confidence score (0-100) between two items.
    Components:
    - Name Similarity (50% weight) - Standard Levenshtein
    - First Name Compatibility (30% weight) - Strict check on extracted first names
    - Year Compatibility (20% weight)
    """
    
    name1 = item1.get('fullname', '')
    name2 = item2.get('fullname', '')
    if not name1 or not name2: return 0
    
    # --- 1. First Name Check (Critical for brothers/fathers) ---
    first1 = extract_first_name(name1)
    first2 = extract_first_name(name2)
    
    first_name_score = 0
    
    if not first1 or not first2:
        # One name is empty/missing first name -> Neutral/Soft Match
        # e.g., "Dussen, van der" (No first name) vs "Jan van der Dussen"
        first_name_score = 50 
    elif first1 == first2:
        first_name_score = 100
    elif len(first1) == 1 or len(first2) == 1:
        # Initial match (e.g., "J" vs "jan")
        if first1[0] == first2[0]:
            first_name_score = 85 # High likelihood
        else:
            return 0 # Mismatching initial (J vs P) = Veto
    else:
        # Fuzzy match first name (e.g. "Joannes" vs "Johannes")
        if fuzz.ratio(first1, first2) > 85:
            first_name_score = 90
        else:
            return 0 # VETO: Distinct first names (likely brothers/relatives)
            
    # --- 2. Full Name Similarity ---
    name_sim = fuzz.token_sort_ratio(name1, name2)
    
    # --- 3. Year Compatibility ---
    by1, by2 = get_year(item1, 'by'), get_year(item2, 'by')
    dy1, dy2 = get_year(item1, 'dy'), get_year(item2, 'dy')
    
    year_score = 50 # Neutral default
    score_contributions = []

    # Hard Vetoes
    if by1 and by2 and abs(by1 - by2) > 3: return 0
    if dy1 and dy2 and abs(dy1 - dy2) > 3: return 0
    if by1 and dy2 and by1 > dy2: return 0
    if by2 and dy1 and by2 > dy1: return 0

    # Birth Year Score
    if by1 and by2:
        score_contributions.append(100 if abs(by1 - by2) <= 1 else 70)
    elif (by1 and not by2) or (not by1 and by2):
        val = by1 if by1 else by2
        target_coll = item2.get('collection') if by1 else item1.get('collection')
        if target_coll in stats:
            s = stats[target_coll]
            score_contributions.append(65 if s['min'] - 20 <= val <= s['max'] + 20 else 10)
    
    # Death Year Score
    if dy1 and dy2:
        score_contributions.append(100 if abs(dy1 - dy2) <= 1 else 70)
    elif (dy1 and not dy2) or (not dy1 and dy2):
        val = dy1 if dy1 else dy2
        target_coll = item2.get('collection') if dy1 else item1.get('collection')
        if target_coll in stats:
            s = stats[target_coll]
            score_contributions.append(65 if s['min'] - 20 <= val <= s['max'] + 20 else 10)

    if score_contributions:
        year_score = sum(score_contributions) / len(score_contributions)
    
    # Final Weighting
    # First Name (30%) + Full Name Context (50%) + Years (20%)
    final_score = (first_name_score * 0.3) + (name_sim * 0.5) + (year_score * 0.2)
    
    return final_score

# --- Clustering Loop ---
for key, block in tqdm(blocks.items(), desc="Clustering"):
    if len(block) == 1:
        item = block[0]
        merged_results.append(MergedIndexItem(
            canonical_fullname=item.get('fullname', ''),
            geslachtsnaam=item.get('geslachtsnaam', ''),
            birth=item.get('birth'),
            death=item.get('death'),
            ids=[item['_id']],
            source_records=[item]
        ))
        continue
    
    processed = set()
    for i, item1 in enumerate(block):
        if i in processed: continue
        
        cluster = [item1]
        processed.add(i)
        
        for j, item2 in enumerate(block):
            if j <= i or j in processed: continue
            
            # Calculate score
            score = calculate_match_score(item1, item2, collection_stats)
            
            if score >= SCORE_THRESHOLD:
                cluster.append(item2)
                processed.add(j)
        
        merged_results.append(MergedIndexItem(
            canonical_fullname=cluster[0].get('fullname', ''),
            geslachtsnaam=cluster[0].get('geslachtsnaam', ''),
            birth=cluster[0].get('birth'),
            death=cluster[0].get('death'),
            ids=[it['_id'] for it in cluster],
            source_records=cluster
        ))

print(f"Total Merged Records: {len(merged_results)}")
# Out:
# Clustering:   0%|          | 0/21027 [00:00<?, ?it/s]
# Total Merged Records: 44390

# %%
# Summary
print("--- Deduplication Summary ---")
print(f"Original Records: {len(all_records)}")
print(f"Merged Entities:  {len(merged_results)}")

# Show an example of a cluster
found_cluster = False
for m in merged_results:
    if len(m.ids) > 1:
        print("\nExample Cluster:")
        print(m.model_dump_json(indent=2))
        found_cluster = True
        break

if not found_cluster:
    print("No duplicates found with current threshold.")
# Out:
# --- Deduplication Summary ---
# Original Records: 49803
# Merged Entities:  44390
#
# Example Cluster:
# {
#   "canonical_fullname": "Dussen, Nicolaas van der",
#   "geslachtsnaam": "Dussen",
#   "birth": null,
#   "death": null,
#   "ids": [
#     "2401",
#     "14841"
#   ],
#   "source_records": [
#     {
#       "fullname": "Dussen, Nicolaas van der",
#       "geslachtsnaam": "Dussen",
#       "birth": null,
#       "death": null,
#       "biography": "",
#       "by": 0,
#       "dy": 0,
#       "reference": null,
#       "collection": "de_witt",
#       "_id": "2401"
#     },
#     {
#       "fullname": "mr. Nicolaas van der Dussen",
#       "geslachtsnaam": "Dussen",
#       "birth": "1718",
#       "death": "1770-01-13",
#       "biography": "",
#       "by": 1718,
#       "dy": 1770,
#       "reference": null,
#       "collection": "raa",
#       "_id": "14841"
#     }
#   ]
# }

# %%
all_records[0]
# Out:
# [MergedIndexItem(canonical_fullname='Dussen, van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['0', '1930'], source_records=[{'fullname': 'Dussen, van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '0'}, {'fullname': 'Dussen, P. van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '1930'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Arende van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['2379'], source_records=[{'fullname': 'Dussen, Arende van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '2379'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Nicolaas van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['2401', '14841'], source_records=[{'fullname': 'Dussen, Nicolaas van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '2401'}, {'fullname': 'mr. Nicolaas van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1718', 'death': '1770-01-13', 'biography': '', 'by': 1718, 'dy': 1770, 'reference': None, 'collection': 'raa', '_id': '14841'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Hendrik Arentsz. van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['4554', '17419'], source_records=[{'fullname': 'Dussen, Hendrik Arentsz. van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '4554'}, {'fullname': 'mr. Hendrik Arentsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1710', 'death': '1765-07-18', 'biography': '', 'by': 1710, 'dy': 1765, 'reference': None, 'collection': 'raa', '_id': '17419'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Hieronymus van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['6739'], source_records=[{'fullname': 'Dussen, Hieronymus van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(1692-1711) Jongste zoon van Bruno van der Dussen; ontvanger van de grafelijke  en Wassenaarse tollen sinds 1709. De Jong, <I>Met goed fatsoen</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '6739'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Elisabeth van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['10451', '10890'], source_records=[{'fullname': 'Dussen, Elisabeth van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(1669-1699) Echtgenote van Mr. Antonis Slicher, raadsheer van het Hof van Holland;  jongere zuster van Bruno. Elias, <I>Vroedschap</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '10451'}, {'fullname': 'Dussen, Elizabeth van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(1657-1730) [geschreven aan Heinsius]  Verwante van Heinsius; weduwe van Mr. Johan van der Does, vroedschap  van Gouda.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '10890'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Jacob van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['10457', '26221'], source_records=[{'fullname': 'Dussen, Jacob van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(*1698) Een van de jongere zonen van Gerard van der Dussen. Engelbrecht, <I>Vroedschap.</i>', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '10457'}, {'fullname': 'Jacob van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1631', 'death': '1701', 'biography': '', 'by': 1631, 'dy': 1701, 'reference': None, 'collection': 'raa', '_id': '26221'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Daniel van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['10656'], source_records=[{'fullname': 'Dussen, Daniel van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(*1701) Derde en jongste zoon van Gerard van der Dussen. Engelbrecht, <I>Vroedschap.</i>', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '10656'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Catharina van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['11313'], source_records=[{'fullname': 'Dussen, Catharina van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(1664-1715) Zuster van Bruno, Gerard en Jacob Adriaan, weduwe van Melchior Gerard  van Rietvelt. De Jong, <I>Met goed fatsoen</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '11313'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Bruno van der (Jr', geslachtsnaam='Dussen', birth=None, death=None, ids=['11503', '43361'], source_records=[{'fullname': 'Dussen, Bruno van der (Jr', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': ').  (1714-1760) Zoon van Jacob en Johanna Clara Pels (1695-1754). Elias, <I>Vroedschap</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '11503'}, {'fullname': 'Dussen, Bruno van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '43361'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Johanna van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['11750'], source_records=[{'fullname': 'Dussen, Johanna van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(1671-1761) Echtgenote van Jan de Mey; jongere zuster van Bruno. De Jong, <I>Met  goed fatsoen</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '11750'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Paulus van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['11942'], source_records=[{'fullname': 'Dussen, Paulus van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '(1658-1707) [geschreven aan Heinsius]  Marine-officier, afkomstig uit Delft; 1700 schout-bij-nacht bij de  Admiraliteit op de Maze. <I>NNBW</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '11942'}]),
#  MergedIndexItem(canonical_fullname='Dussen, (Mr', geslachtsnaam='Dussen', birth=None, death=None, ids=['11947'], source_records=[{'fullname': 'Dussen, (Mr', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': ') Bruno van der.  (1660-1742) [geschreven aan Heinsius]  [beantwoord door Heinsius]  Regent van Gouda en familielid van Heinsius; pensionaris van Gouda  sinds 1688; lid vroedschap 1702; vele malen burgemeester; gecommitteerde raad  van Holland 1715-18 en 1721-24; betrokken bij alle onderhandelingen met Frankrijk;  gevolmachtigde op het vredescongres te Utrecht; gevolmachtigde bij de onderhandelingen  over de Barrière te Antwerpen 1715-18. Van der Aa, <I>Biographisch Woordenboek</I>;  De Jong, <I>Met goed fatsoen</I>. - echtgenote van, zie Pancras, Maria.', 'by': 0, 'dy': 0, 'reference': 'Pancras, Maria', 'collection': 'heinsius', '_id': '11947'}]),
#  MergedIndexItem(canonical_fullname='Dussen, J. van', geslachtsnaam='Dussen', birth=None, death=None, ids=['12892'], source_records=[{'fullname': 'Dussen, J. van', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'huygens_constantijn', '_id': '12892'}]),
#  MergedIndexItem(canonical_fullname='Jan van Dussen', geslachtsnaam='Dussen', birth=None, death=None, ids=['14338'], source_records=[{'fullname': 'Jan van Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '14338'}]),
#  MergedIndexItem(canonical_fullname='Frans Adriaansz. van der Dussen', geslachtsnaam='Dussen', birth=None, death='1630-08-27', ids=['14520'], source_records=[{'fullname': 'Frans Adriaansz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1630-08-27', 'biography': '', 'by': 0, 'dy': 1630, 'reference': None, 'collection': 'raa', '_id': '14520'}]),
#  MergedIndexItem(canonical_fullname='mr. Johan Bruijnsz. van der Dussen', geslachtsnaam='Dussen', birth=None, death='1683-06-07', ids=['14865'], source_records=[{'fullname': 'mr. Johan Bruijnsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1683-06-07', 'biography': '', 'by': 0, 'dy': 1683, 'reference': None, 'collection': 'raa', '_id': '14865'}]),
#  MergedIndexItem(canonical_fullname='mr. Jacob Nicolaesz. van der Dussen', geslachtsnaam='Dussen', birth=None, death='1728-01-11', ids=['15180'], source_records=[{'fullname': 'mr. Jacob Nicolaesz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1728-01-11', 'biography': '', 'by': 0, 'dy': 1728, 'reference': None, 'collection': 'raa', '_id': '15180'}]),
#  MergedIndexItem(canonical_fullname='mr. Dirck Dircksz. van der Dussen', geslachtsnaam='Dussen', birth='1648', death='1689-05-02', ids=['15644'], source_records=[{'fullname': 'mr. Dirck Dircksz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1648', 'death': '1689-05-02', 'biography': '', 'by': 1648, 'dy': 1689, 'reference': None, 'collection': 'raa', '_id': '15644'}]),
#  MergedIndexItem(canonical_fullname='Dirk Bruynsz. van der Dussen', geslachtsnaam='Dussen', birth='1612', death='1668', ids=['19582', '25857', '28520'], source_records=[{'fullname': 'Dirk Bruynsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1612', 'death': '1668', 'biography': '', 'by': 1612, 'dy': 1668, 'reference': None, 'collection': 'raa', '_id': '19582'}, {'fullname': 'Dirk Bruynsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1623', 'biography': '', 'by': 0, 'dy': 1623, 'reference': None, 'collection': 'raa', '_id': '25857'}, {'fullname': 'Dirk Bruynsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1612', 'death': '1668-12-01', 'biography': '', 'by': 1612, 'dy': 1668, 'reference': None, 'collection': 'raa', '_id': '28520'}]),
#  MergedIndexItem(canonical_fullname='mr. Ewout van der Dussen', geslachtsnaam='Dussen', birth='1791-04-15', death='1859-07-08', ids=['19776'], source_records=[{'fullname': 'mr. Ewout van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1791-04-15', 'death': '1859-07-08', 'biography': '', 'by': 1791, 'dy': 1859, 'reference': None, 'collection': 'raa', '_id': '19776'}]),
#  MergedIndexItem(canonical_fullname='A. J. van Dussen', geslachtsnaam='Dussen', birth='1705', death='1791-04-21', ids=['20112'], source_records=[{'fullname': 'A. J. van Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1705', 'death': '1791-04-21', 'biography': '', 'by': 1705, 'dy': 1791, 'reference': None, 'collection': 'raa', '_id': '20112'}]),
#  MergedIndexItem(canonical_fullname='Gerard van der Dussen', geslachtsnaam='Dussen', birth='1636', death='1711-07-17', ids=['20458'], source_records=[{'fullname': 'Gerard van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1636', 'death': '1711-07-17', 'biography': '', 'by': 1636, 'dy': 1711, 'reference': None, 'collection': 'raa', '_id': '20458'}]),
#  MergedIndexItem(canonical_fullname='mr. Arent Bruinsz. van der Dussen', geslachtsnaam='Dussen', birth='1683', death='1742-06-20', ids=['21082'], source_records=[{'fullname': 'mr. Arent Bruinsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1683', 'death': '1742-06-20', 'biography': '', 'by': 1683, 'dy': 1742, 'reference': None, 'collection': 'raa', '_id': '21082'}]),
#  MergedIndexItem(canonical_fullname='mr. François Ewout van der Dussen', geslachtsnaam='Dussen', birth=None, death=None, ids=['22804'], source_records=[{'fullname': 'mr. François Ewout van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '22804'}]),
#  MergedIndexItem(canonical_fullname='Floris van der Dussen', geslachtsnaam='Dussen', birth=None, death='1458', ids=['24195'], source_records=[{'fullname': 'Floris van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1458', 'biography': '', 'by': 0, 'dy': 1458, 'reference': None, 'collection': 'raa', '_id': '24195'}]),
#  MergedIndexItem(canonical_fullname='Ewout Jacobsz. van der Dussen', geslachtsnaam='Dussen', birth='1574', death='1653-05-16', ids=['24777'], source_records=[{'fullname': 'Ewout Jacobsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1574', 'death': '1653-05-16', 'biography': '', 'by': 1574, 'dy': 1653, 'reference': None, 'collection': 'raa', '_id': '24777'}]),
#  MergedIndexItem(canonical_fullname='Bruyn Dirksz. van der Dussen', geslachtsnaam='Dussen', birth='1585', death='1649-11-11', ids=['24839'], source_records=[{'fullname': 'Bruyn Dirksz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1585', 'death': '1649-11-11', 'biography': '', 'by': 1585, 'dy': 1649, 'reference': None, 'collection': 'raa', '_id': '24839'}]),
#  MergedIndexItem(canonical_fullname='mr. Bruno van der Dussen', geslachtsnaam='Dussen', birth='1660', death='1741', ids=['25480'], source_records=[{'fullname': 'mr. Bruno van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1660', 'death': '1741', 'biography': '', 'by': 1660, 'dy': 1741, 'reference': None, 'collection': 'raa', '_id': '25480'}]),
#  MergedIndexItem(canonical_fullname='dr. Adriaan van der Dussen', geslachtsnaam='Dussen', birth='1629', death='1682', ids=['25509'], source_records=[{'fullname': 'dr. Adriaan van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1629', 'death': '1682', 'biography': '', 'by': 1629, 'dy': 1682, 'reference': None, 'collection': 'raa', '_id': '25509'}]),
#  MergedIndexItem(canonical_fullname='Jan ridder van der Dussen', geslachtsnaam='Dussen', birth=None, death='1325', ids=['25893'], source_records=[{'fullname': 'Jan ridder van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1325', 'biography': '', 'by': 0, 'dy': 1325, 'reference': None, 'collection': 'raa', '_id': '25893'}]),
#  MergedIndexItem(canonical_fullname='mr. Ewout Nicolaesz. van der Dussen', geslachtsnaam='Dussen', birth='1669', death='1729-10-17', ids=['26406'], source_records=[{'fullname': 'mr. Ewout Nicolaesz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1669', 'death': '1729-10-17', 'biography': '', 'by': 1669, 'dy': 1729, 'reference': None, 'collection': 'raa', '_id': '26406'}]),
#  MergedIndexItem(canonical_fullname='mr. Jacob van der Dussen', geslachtsnaam='Dussen', birth='1763-12-12', death='1820-12-24', ids=['26589', '28135'], source_records=[{'fullname': 'mr. Jacob van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1763-12-12', 'death': '1820-12-24', 'biography': '', 'by': 1763, 'dy': 1820, 'reference': None, 'collection': 'raa', '_id': '26589'}, {'fullname': 'mr. Jacob van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1686-11-19', 'biography': '', 'by': 0, 'dy': 1686, 'reference': None, 'collection': 'raa', '_id': '28135'}]),
#  MergedIndexItem(canonical_fullname='Abraham van der Dussen', geslachtsnaam='Dussen', birth=None, death=None, ids=['26823'], source_records=[{'fullname': 'Abraham van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '26823'}]),
#  MergedIndexItem(canonical_fullname='Jan van der Dussen', geslachtsnaam='Dussen', birth=None, death=None, ids=['28251'], source_records=[{'fullname': 'Jan van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '28251'}]),
#  MergedIndexItem(canonical_fullname='mr. Pieter Ewoutsz. van der Dussen', geslachtsnaam='Dussen', birth='1632', death='1703-04-14', ids=['28322'], source_records=[{'fullname': 'mr. Pieter Ewoutsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1632', 'death': '1703-04-14', 'biography': '', 'by': 1632, 'dy': 1703, 'reference': None, 'collection': 'raa', '_id': '28322'}]),
#  MergedIndexItem(canonical_fullname='Bruno Arentsz. van der Dussen', geslachtsnaam='Dussen', birth='1588', death='1655-04-27', ids=['28714'], source_records=[{'fullname': 'Bruno Arentsz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1588', 'death': '1655-04-27', 'biography': '', 'by': 1588, 'dy': 1655, 'reference': None, 'collection': 'raa', '_id': '28714'}]),
#  MergedIndexItem(canonical_fullname='Jacob Huygensz. van der Dussen', geslachtsnaam='Dussen', birth='1553', death='1619-01-09', ids=['28856'], source_records=[{'fullname': 'Jacob Huygensz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1553', 'death': '1619-01-09', 'biography': '', 'by': 1553, 'dy': 1619, 'reference': None, 'collection': 'raa', '_id': '28856'}]),
#  MergedIndexItem(canonical_fullname='Ocker van der Dussen', geslachtsnaam='Dussen', birth='1794-05-11', death='1856-06-22', ids=['29601'], source_records=[{'fullname': 'Ocker van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1794-05-11', 'death': '1856-06-22', 'biography': '', 'by': 1794, 'dy': 1856, 'reference': None, 'collection': 'raa', '_id': '29601'}]),
#  MergedIndexItem(canonical_fullname='mr. Arent Hendriksz. van der Dussen', geslachtsnaam='Dussen', birth='1681', death='1760-07-12', ids=['30110'], source_records=[{'fullname': 'mr. Arent Hendriksz. van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1681', 'death': '1760-07-12', 'biography': '', 'by': 1681, 'dy': 1760, 'reference': None, 'collection': 'raa', '_id': '30110'}]),
#  MergedIndexItem(canonical_fullname='mr. Gerard van der Dussen', geslachtsnaam='Dussen', birth='1662', death='1713-03-22', ids=['31568'], source_records=[{'fullname': 'mr. Gerard van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': '1662', 'death': '1713-03-22', 'biography': '', 'by': 1662, 'dy': 1713, 'reference': None, 'collection': 'raa', '_id': '31568'}]),
#  MergedIndexItem(canonical_fullname='Jan heer van der Dussen', geslachtsnaam='Dussen', birth=None, death='1497', ids=['32284'], source_records=[{'fullname': 'Jan heer van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': '1497', 'biography': '', 'by': 0, 'dy': 1497, 'reference': None, 'collection': 'raa', '_id': '32284'}]),
#  MergedIndexItem(canonical_fullname='Adrianus van der Dussen', geslachtsnaam='Dussen', birth=None, death=None, ids=['32342'], source_records=[{'fullname': 'Adrianus van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '32342'}]),
#  MergedIndexItem(canonical_fullname='Arend ridder van der Dussen', geslachtsnaam='Dussen', birth=None, death=None, ids=['33865'], source_records=[{'fullname': 'Arend ridder van der Dussen', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '33865'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Magdalena Jacobsdr. van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['35818'], source_records=[{'fullname': 'Dussen, Magdalena Jacobsdr. van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '35818'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Maria van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['35924'], source_records=[{'fullname': 'Dussen, Maria van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '35924'}]),
#  MergedIndexItem(canonical_fullname='Dussen, Ewout van der', geslachtsnaam='Dussen', birth=None, death=None, ids=['43251'], source_records=[{'fullname': 'Dussen, Ewout van der', 'geslachtsnaam': 'Dussen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '43251'}]),
#  MergedIndexItem(canonical_fullname='Bilderbeeck, Hendrick van', geslachtsnaam='Bilderbeeck', birth=None, death=None, ids=['1', '4247', '12667', '38765', '38960', '43421'], source_records=[{'fullname': 'Bilderbeeck, Hendrick van', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '1'}, {'fullname': 'Bilderbeeck, Hendrick van', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'grotius', '_id': '4247'}, {'fullname': 'Bilderbeeck, Hendrick van', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'huygens_constantijn', '_id': '12667'}, {'fullname': 'Bilderbeeck, Hendrik van', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '38765'}, {'fullname': 'Bilderbeeck, Hendrik van ', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '38960'}, {'fullname': 'Bilderbeeck, Hendrick van ', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '43421'}]),
#  MergedIndexItem(canonical_fullname='Bilderbeeck, Frederik Hendrik van ', geslachtsnaam='Bilderbeeck', birth=None, death=None, ids=['43195'], source_records=[{'fullname': 'Bilderbeeck, Frederik Hendrik van ', 'geslachtsnaam': 'Bilderbeeck', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '43195'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Zerbst, Karl Wilhelm von', geslachtsnaam='Anhalt-Zerbst', birth=None, death=None, ids=['2', '13995'], source_records=[{'fullname': 'Anhalt-Zerbst, Karl Wilhelm von', 'geslachtsnaam': 'Anhalt-Zerbst', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '2'}, {'fullname': 'Anhalt-Zerbst, Karl Wilhelm von', 'geslachtsnaam': 'Anhalt-Zerbst', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13995'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Zerbst, Vorst van, zie Anton Günther', geslachtsnaam='Anhalt-Zerbst', birth=None, death=None, ids=['7914'], source_records=[{'fullname': 'Anhalt-Zerbst, Vorst van, zie Anton Günther', 'geslachtsnaam': 'Anhalt-Zerbst', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '7914'}]),
#  MergedIndexItem(canonical_fullname='Bernhard VII van Anhalt-Zerbst', geslachtsnaam='', birth=None, death=None, ids=['49152'], source_records=[{'fullname': 'Bernhard VII van Anhalt-Zerbst', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '49152'}]),
#  MergedIndexItem(canonical_fullname='Sachsen-Weissenfels-Barby, Heinrich von', geslachtsnaam='Sachsen-Weissenfels-Barby', birth=None, death=None, ids=['3', '13815'], source_records=[{'fullname': 'Sachsen-Weissenfels-Barby, Heinrich von', 'geslachtsnaam': 'Sachsen-Weissenfels-Barby', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '3'}, {'fullname': 'Sachsen-Weissenfels-Barby, Heinrich von', 'geslachtsnaam': 'Sachsen-Weissenfels-Barby', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13815'}]),
#  MergedIndexItem(canonical_fullname='Merignac', geslachtsnaam='', birth=None, death=None, ids=['4'], source_records=[{'fullname': 'Merignac', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '4'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Charles de', geslachtsnaam='Lannoy', birth=None, death=None, ids=['5', '2186', '9605'], source_records=[{'fullname': 'Lannoy, Charles de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '5'}, {'fullname': 'Lannoy, Charles de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '2186'}, {'fullname': 'Lannoy, Charles de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': 'Nederlands officier; 1703-11 kolonel-commandant van het regiment cavalerie Oranje-Friesland.  Ringoir, <I>Afstammingen cavalerie</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '9605'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Samuel', geslachtsnaam='Lannoy', birth=None, death=None, ids=['2255'], source_records=[{'fullname': 'Lannoy, Samuel', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '2255'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Albert Eugène', geslachtsnaam='Lannoy', birth=None, death=None, ids=['2256'], source_records=[{'fullname': 'Lannoy, Albert Eugène', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '2256'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Carel Wijbrandus de', geslachtsnaam='Lannoy', birth=None, death=None, ids=['4644'], source_records=[{'fullname': 'Lannoy, Carel Wijbrandus de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '4644'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Johan Hendrik de', geslachtsnaam='Lannoy', birth=None, death=None, ids=['8708'], source_records=[{'fullname': 'Lannoy, Johan Hendrik de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '(† 1731) Nederlands officier; 1710 majoor van de infanterie; 1712 luitenant-kolonel;  1727 kolonel-commandant. Ringoir, <I>Hoofdofficieren infanterie</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '8708'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Marc-Joseph, Graaf de', geslachtsnaam='Lannoy', birth=None, death=None, ids=['8863'], source_records=[{'fullname': 'Lannoy, Marc-Joseph, Graaf de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': 'Zuid-Nederlands edelman, getrouwd met een gravin Starhemberg. Goethals, <I>Dictionnaire</I>,  3, 640.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '8863'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Jan de', geslachtsnaam='Lannoy', birth=None, death=None, ids=['9743'], source_records=[{'fullname': 'Lannoy, Jan de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': 'Nederlands prijs-commissaris te Hamburg.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '9743'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Adrien-Gérard de, Graaf van Clervaux', geslachtsnaam='Lannoy', birth=None, death=None, ids=['10058'], source_records=[{'fullname': 'Lannoy, Adrien-Gérard de, Graaf van Clervaux', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '(† 1730) [geschreven aan Heinsius]  Zuid-Nederlands edelman; officier in Spaanse, keizerlijke en Brandenburgse  dienst; lid van de Raad van State te Brussel, 1719 gouverneur van Namen. Veenendaal  [sr], <I>Dagboek Cuper</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '10058'}]),
#  MergedIndexItem(canonical_fullname='Jan (III) ridder van Lannoy', geslachtsnaam='Lannoy', birth='1410', death='1493', ids=['15058'], source_records=[{'fullname': 'Jan (III) ridder van Lannoy', 'geslachtsnaam': 'Lannoy', 'birth': '1410', 'death': '1493', 'biography': '', 'by': 1410, 'dy': 1493, 'reference': None, 'collection': 'raa', '_id': '15058'}]),
#  MergedIndexItem(canonical_fullname='Gijsbrecht van Lannoy', geslachtsnaam='Lannoy', birth=None, death=None, ids=['27815'], source_records=[{'fullname': 'Gijsbrecht van Lannoy', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '27815'}]),
#  MergedIndexItem(canonical_fullname='Huge ridder van Lannoy', geslachtsnaam='Lannoy', birth='1384', death='1456', ids=['32927'], source_records=[{'fullname': 'Huge ridder van Lannoy', 'geslachtsnaam': 'Lannoy', 'birth': '1384', 'death': '1456', 'biography': '', 'by': 1384, 'dy': 1456, 'reference': None, 'collection': 'raa', '_id': '32927'}]),
#  MergedIndexItem(canonical_fullname='Lannoy, Adrienne Florence de', geslachtsnaam='Lannoy', birth=None, death=None, ids=['45069'], source_records=[{'fullname': 'Lannoy, Adrienne Florence de', 'geslachtsnaam': 'Lannoy', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '45069'}]),
#  MergedIndexItem(canonical_fullname='Sachsen-Weissenfels, Johann Adolf I von', geslachtsnaam='Sachsen-Weissenfels', birth=None, death=None, ids=['6'], source_records=[{'fullname': 'Sachsen-Weissenfels, Johann Adolf I von', 'geslachtsnaam': 'Sachsen-Weissenfels', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '6'}]),
#  MergedIndexItem(canonical_fullname='Blanche, J. F.', geslachtsnaam='Blanche', birth=None, death=None, ids=['7'], source_records=[{'fullname': 'Blanche, J. F.', 'geslachtsnaam': 'Blanche', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '7'}]),
#  MergedIndexItem(canonical_fullname='Blanche, Marie', geslachtsnaam='Blanche', birth=None, death=None, ids=['38709'], source_records=[{'fullname': 'Blanche, Marie', 'geslachtsnaam': 'Blanche', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '38709'}]),
#  MergedIndexItem(canonical_fullname='Blanche, Isaac (de)', geslachtsnaam='Blanche', birth=None, death=None, ids=['39013'], source_records=[{'fullname': 'Blanche, Isaac (de)', 'geslachtsnaam': 'Blanche', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '39013'}]),
#  MergedIndexItem(canonical_fullname='Friesland, States of', geslachtsnaam='Friesland', birth=None, death=None, ids=['8', '4545', '13859'], source_records=[{'fullname': 'Friesland, States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '8'}, {'fullname': 'Friesland, States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '4545'}, {'fullname': 'Friesland, States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13859'}]),
#  MergedIndexItem(canonical_fullname='Friesland, Members of the States of', geslachtsnaam='Friesland', birth=None, death=None, ids=['59', '4101', '13874', '45994'], source_records=[{'fullname': 'Friesland, Members of the States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '59'}, {'fullname': 'Friesland, Members of the States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'grotius', '_id': '4101'}, {'fullname': 'Friesland, Members of the States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13874'}, {'fullname': 'Friesland, Members of the States of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'solms_braunfels_amalia_von', '_id': '45994'}]),
#  MergedIndexItem(canonical_fullname='Friesland, Academy of', geslachtsnaam='Friesland', birth=None, death=None, ids=['117'], source_records=[{'fullname': 'Friesland, Academy of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '117'}]),
#  MergedIndexItem(canonical_fullname='Friesland, court of', geslachtsnaam='Friesland', birth=None, death=None, ids=['4518', '13854'], source_records=[{'fullname': 'Friesland, court of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '4518'}, {'fullname': 'Friesland, court of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13854'}]),
#  MergedIndexItem(canonical_fullname='Friesland, Admirality of', geslachtsnaam='Friesland', birth=None, death=None, ids=['4558'], source_records=[{'fullname': 'Friesland, Admirality of', 'geslachtsnaam': 'Friesland', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '4558'}]),
#  MergedIndexItem(canonical_fullname='de Staten van Friesland', geslachtsnaam='', birth=None, death=None, ids=['46601', '47847'], source_records=[{'fullname': 'de Staten van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'willemiii', '_id': '46601'}, {'fullname': 'Staten van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47847'}]),
#  MergedIndexItem(canonical_fullname='inwoners van Friesland', geslachtsnaam='', birth=None, death=None, ids=['47014'], source_records=[{'fullname': 'inwoners van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47014'}]),
#  MergedIndexItem(canonical_fullname='steden van Friesland', geslachtsnaam='', birth=None, death=None, ids=['47960'], source_records=[{'fullname': 'steden van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47960'}]),
#  MergedIndexItem(canonical_fullname='president van het Hof van Friesland', geslachtsnaam='', birth=None, death=None, ids=['48395', '49245'], source_records=[{'fullname': 'president van het Hof van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '48395'}, {'fullname': 'raden van het Hof van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '49245'}]),
#  MergedIndexItem(canonical_fullname='kwartieren van Friesland', geslachtsnaam='', birth=None, death=None, ids=['48902'], source_records=[{'fullname': 'kwartieren van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '48902'}]),
#  MergedIndexItem(canonical_fullname='Gedeputeerde Staten van Friesland', geslachtsnaam='', birth=None, death=None, ids=['48954'], source_records=[{'fullname': 'Gedeputeerde Staten van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '48954'}]),
#  MergedIndexItem(canonical_fullname='gedeputeerden van de Staten van Friesland', geslachtsnaam='', birth=None, death=None, ids=['49329'], source_records=[{'fullname': 'gedeputeerden van de Staten van Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '49329'}]),
#  MergedIndexItem(canonical_fullname='Kutsch, Johannes Reinhard', geslachtsnaam='Kutsch', birth=None, death=None, ids=['9', '39723'], source_records=[{'fullname': 'Kutsch, Johannes Reinhard', 'geslachtsnaam': 'Kutsch', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '9'}, {'fullname': 'Kutsch, Johan Reinhard', 'geslachtsnaam': 'Kutsch', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '39723'}]),
#  MergedIndexItem(canonical_fullname='Kutsch, Gabriel', geslachtsnaam='Kutsch', birth=None, death=None, ids=['13829'], source_records=[{'fullname': 'Kutsch, Gabriel', 'geslachtsnaam': 'Kutsch', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13829'}]),
#  MergedIndexItem(canonical_fullname='Jan Carel Kutsch', geslachtsnaam='Kutsch', birth='1745', death='1803', ids=['28040'], source_records=[{'fullname': 'Jan Carel Kutsch', 'geslachtsnaam': 'Kutsch', 'birth': '1745', 'death': '1803', 'biography': '', 'by': 1745, 'dy': 1803, 'reference': None, 'collection': 'raa', '_id': '28040'}]),
#  MergedIndexItem(canonical_fullname='Gabriël Kutsch', geslachtsnaam='Kutsch', birth=None, death=None, ids=['31103'], source_records=[{'fullname': 'Gabriël Kutsch', 'geslachtsnaam': 'Kutsch', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '31103'}]),
#  MergedIndexItem(canonical_fullname='Kutsch, Henric Wilhelm', geslachtsnaam='Kutsch', birth=None, death=None, ids=['39463'], source_records=[{'fullname': 'Kutsch, Henric Wilhelm', 'geslachtsnaam': 'Kutsch', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '39463'}]),
#  MergedIndexItem(canonical_fullname='Nassau-Hadamar, Frans Alexander von', geslachtsnaam='Nassau-Hadamar', birth=None, death=None, ids=['10', '13926'], source_records=[{'fullname': 'Nassau-Hadamar, Frans Alexander von', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '10'}, {'fullname': 'Nassau-Hadamar, Frans Alexander von', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13926'}]),
#  MergedIndexItem(canonical_fullname='Nassau-Hadamar, Johanna Elisabeth von', geslachtsnaam='Nassau-Hadamar', birth=None, death=None, ids=['1330'], source_records=[{'fullname': 'Nassau-Hadamar, Johanna Elisabeth von', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'braunschweig-wolfenbüttel_sophia_hedwig_von', '_id': '1330'}]),
#  MergedIndexItem(canonical_fullname='Nassau-Hadamar, Maurice Henry of', geslachtsnaam='Nassau-Hadamar', birth=None, death=None, ids=['13953', '46116'], source_records=[{'fullname': 'Nassau-Hadamar, Maurice Henry of', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13953'}, {'fullname': 'Nassau-Hadamar, Maurice Henry of', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'stuart_mary_i', '_id': '46116'}]),
#  MergedIndexItem(canonical_fullname='Nassau-Hadamar, Francois Bernhard von', geslachtsnaam='Nassau-Hadamar', birth=None, death=None, ids=['46061'], source_records=[{'fullname': 'Nassau-Hadamar, Francois Bernhard von', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'stuart_mary_ii', '_id': '46061'}]),
#  MergedIndexItem(canonical_fullname='Nassau-Hadamar, Johann Ludwig von', geslachtsnaam='Nassau-Hadamar', birth=None, death=None, ids=['46182'], source_records=[{'fullname': 'Nassau-Hadamar, Johann Ludwig von', 'geslachtsnaam': 'Nassau-Hadamar', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'stuart_mary_i', '_id': '46182'}]),
#  MergedIndexItem(canonical_fullname="Groningen, 'justitiecamer' of", geslachtsnaam='Groningen', birth=None, death=None, ids=['11'], source_records=[{'fullname': "Groningen, 'justitiecamer' of", 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '11'}]),
#  MergedIndexItem(canonical_fullname="Groningen, deputy councils of the 'Rekenkamer'", geslachtsnaam='Groningen', birth=None, death=None, ids=['19', '5157'], source_records=[{'fullname': "Groningen, deputy councils of the 'Rekenkamer'", 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '19'}, {'fullname': "Groningen, deputy councils of the 'Rekenkamer'", 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '5157'}]),
#  MergedIndexItem(canonical_fullname='Groningen, Academy of', geslachtsnaam='Groningen', birth=None, death=None, ids=['22'], source_records=[{'fullname': 'Groningen, Academy of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '22'}]),
#  MergedIndexItem(canonical_fullname='Groningen, city of', geslachtsnaam='Groningen', birth=None, death=None, ids=['176'], source_records=[{'fullname': 'Groningen, city of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '176'}]),
#  MergedIndexItem(canonical_fullname='Groningen, deputy states of', geslachtsnaam='Groningen', birth=None, death=None, ids=['1390', '13965'], source_records=[{'fullname': 'Groningen, deputy states of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'braunschweig-wolfenbüttel_sophia_hedwig_von', '_id': '1390'}, {'fullname': 'Groningen, deputy states of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13965'}]),
#  MergedIndexItem(canonical_fullname='Groningen, burgomasters and city council of', geslachtsnaam='Groningen', birth=None, death=None, ids=['13830'], source_records=[{'fullname': 'Groningen, burgomasters and city council of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13830'}]),
#  MergedIndexItem(canonical_fullname='Groningen, military council of', geslachtsnaam='Groningen', birth=None, death=None, ids=['13841'], source_records=[{'fullname': 'Groningen, military council of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13841'}]),
#  MergedIndexItem(canonical_fullname='Groningen, University of', geslachtsnaam='Groningen', birth=None, death=None, ids=['13875'], source_records=[{'fullname': 'Groningen, University of', 'geslachtsnaam': 'Groningen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13875'}]),
#  MergedIndexItem(canonical_fullname='Borgemeesteren en Raad van Groningen', geslachtsnaam='', birth=None, death=None, ids=['46443'], source_records=[{'fullname': 'Borgemeesteren en Raad van Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'willemiii', '_id': '46443'}]),
#  MergedIndexItem(canonical_fullname='burgemeesters en raad van Groningen', geslachtsnaam='', birth=None, death=None, ids=['46517'], source_records=[{'fullname': 'burgemeesters en raad van Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'willemiii', '_id': '46517'}]),
#  MergedIndexItem(canonical_fullname='Waalse soldaten te Groningen', geslachtsnaam='', birth=None, death=None, ids=['47223'], source_records=[{'fullname': 'Waalse soldaten te Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47223'}]),
#  MergedIndexItem(canonical_fullname='magistraat van Groningen', geslachtsnaam='', birth=None, death=None, ids=['47230'], source_records=[{'fullname': 'magistraat van Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47230'}]),
#  MergedIndexItem(canonical_fullname='Stad en Lande van Groningen', geslachtsnaam='', birth=None, death=None, ids=['47709'], source_records=[{'fullname': 'Stad en Lande van Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47709'}]),
#  MergedIndexItem(canonical_fullname='gedeputeerden van Groningen', geslachtsnaam='', birth=None, death=None, ids=['47831'], source_records=[{'fullname': 'gedeputeerden van Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47831'}]),
#  MergedIndexItem(canonical_fullname='gezworenen van Groningen', geslachtsnaam='', birth=None, death=None, ids=['49583'], source_records=[{'fullname': 'gezworenen van Groningen', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '49583'}]),
#  MergedIndexItem(canonical_fullname='Haarlem, city of', geslachtsnaam='Haarlem', birth=None, death=None, ids=['12'], source_records=[{'fullname': 'Haarlem, city of', 'geslachtsnaam': 'Haarlem', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '12'}]),
#  MergedIndexItem(canonical_fullname='Haarlem, Burgomasters and vroedschap of', geslachtsnaam='Haarlem', birth=None, death=None, ids=['2814'], source_records=[{'fullname': 'Haarlem, Burgomasters and vroedschap of', 'geslachtsnaam': 'Haarlem', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'de_witt', '_id': '2814'}]),
# ...
#  MergedIndexItem(canonical_fullname='Enno III van Oost-Friesland', geslachtsnaam='', birth=None, death=None, ids=['13480', '13504'], source_records=[{'fullname': 'Enno III van Oost-Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oldenbarnevelt', '_id': '13480'}, {'fullname': 'Enno III graaf van Oost-Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oldenbarnevelt', '_id': '13504'}]),
#  MergedIndexItem(canonical_fullname='graven van Oost-Friesland', geslachtsnaam='', birth=None, death=None, ids=['47565'], source_records=[{'fullname': 'graven van Oost-Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47565'}]),
#  MergedIndexItem(canonical_fullname='Christof van Oost-Friesland', geslachtsnaam='', birth=None, death=None, ids=['47732'], source_records=[{'fullname': 'Christof van Oost-Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '47732'}]),
#  MergedIndexItem(canonical_fullname='Johan van Oost-Friesland', geslachtsnaam='', birth=None, death=None, ids=['48664'], source_records=[{'fullname': 'Johan van Oost-Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '48664'}]),
#  MergedIndexItem(canonical_fullname='Edzard II van Oost-Friesland', geslachtsnaam='', birth=None, death=None, ids=['48826'], source_records=[{'fullname': 'Edzard II van Oost-Friesland', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '48826'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Köthen, Emanuel Lebrecht von', geslachtsnaam='Anhalt-Köthen', birth=None, death=None, ids=['138'], source_records=[{'fullname': 'Anhalt-Köthen, Emanuel Lebrecht von', 'geslachtsnaam': 'Anhalt-Köthen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '138'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Köthen, Karl Georg Lebrecht von', geslachtsnaam='Anhalt-Köthen', birth=None, death=None, ids=['5023'], source_records=[{'fullname': 'Anhalt-Köthen, Karl Georg Lebrecht von', 'geslachtsnaam': 'Anhalt-Köthen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '5023'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Köthen, von August Ludwig', geslachtsnaam='Anhalt-Köthen', birth=None, death=None, ids=['5045'], source_records=[{'fullname': 'Anhalt-Köthen, von August Ludwig', 'geslachtsnaam': 'Anhalt-Köthen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '5045'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Köthen, Ludwig van', geslachtsnaam='Anhalt-Köthen', birth=None, death=None, ids=['37097'], source_records=[{'fullname': 'Anhalt-Köthen, Ludwig van', 'geslachtsnaam': 'Anhalt-Köthen', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '37097'}]),
#  MergedIndexItem(canonical_fullname='Anhalt-Bernburg-Harzgerode, Wilhelm Ludwig von', geslachtsnaam='Anhalt-Bernburg-Harzgerode', birth=None, death=None, ids=['139', '13806'], source_records=[{'fullname': 'Anhalt-Bernburg-Harzgerode, Wilhelm Ludwig von', 'geslachtsnaam': 'Anhalt-Bernburg-Harzgerode', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '139'}, {'fullname': 'Anhalt-Bernburg-Harzgerode, Wilhelm Ludwig von', 'geslachtsnaam': 'Anhalt-Bernburg-Harzgerode', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13806'}]),
#  MergedIndexItem(canonical_fullname='Württemberg, Christine Charlotte von', geslachtsnaam='Württemberg', birth=None, death=None, ids=['140', '13834', '46029'], source_records=[{'fullname': 'Württemberg, Christine Charlotte von', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '140'}, {'fullname': 'Württemberg, Christine Charlotte von', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13834'}, {'fullname': 'Württemberg, Christine Charlotte von', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'stuart_mary_ii', '_id': '46029'}]),
#  MergedIndexItem(canonical_fullname='Württemberg, Charles Eugene of', geslachtsnaam='Württemberg', birth=None, death=None, ids=['4677'], source_records=[{'fullname': 'Württemberg, Charles Eugene of', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'hanover_anne_of', '_id': '4677'}]),
#  MergedIndexItem(canonical_fullname='Württemberg, Hertog van, zie Eberhard Ludwig; Friedrich  Karl; Heinrich Friedrich; Karl ALEXANDER; Wilhelm Ludwig', geslachtsnaam='Württemberg', birth=None, death=None, ids=['6747'], source_records=[{'fullname': 'Württemberg, Hertog van, zie Eberhard Ludwig; Friedrich  Karl; Heinrich Friedrich; Karl ALEXANDER; Wilhelm Ludwig', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '- hertogin-moeder van, zie Magdalena Sybille.', 'by': 0, 'dy': 0, 'reference': 'Magdalena Sybille', 'collection': 'heinsius', '_id': '6747'}]),
#  MergedIndexItem(canonical_fullname='Württemberg, Frederik Karel van', geslachtsnaam='Württemberg', birth=None, death=None, ids=['37016'], source_records=[{'fullname': 'Württemberg, Frederik Karel van', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '37016'}]),
#  MergedIndexItem(canonical_fullname='Württemberg, Maria van', geslachtsnaam='Württemberg', birth=None, death=None, ids=['37757'], source_records=[{'fullname': 'Württemberg, Maria van', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '37757'}]),
#  MergedIndexItem(canonical_fullname='Württemberg, Sophie van', geslachtsnaam='Württemberg', birth=None, death=None, ids=['38467'], source_records=[{'fullname': 'Württemberg, Sophie van', 'geslachtsnaam': 'Württemberg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'schutte', '_id': '38467'}]),
#  MergedIndexItem(canonical_fullname='Christof van Württemberg', geslachtsnaam='', birth=None, death=None, ids=['49267'], source_records=[{'fullname': 'Christof van Württemberg', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'wvo', '_id': '49267'}]),
#  MergedIndexItem(canonical_fullname='Schleswig-Holstein-Sonderburg, Sophie Catherine von', geslachtsnaam='Schleswig-Holstein-Sonderburg', birth=None, death=None, ids=['141', '13776'], source_records=[{'fullname': 'Schleswig-Holstein-Sonderburg, Sophie Catherine von', 'geslachtsnaam': 'Schleswig-Holstein-Sonderburg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '141'}, {'fullname': 'Schleswig-Holstein-Sonderburg, Sophie Catherine von', 'geslachtsnaam': 'Schleswig-Holstein-Sonderburg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13776'}]),
#  MergedIndexItem(canonical_fullname='Schleswig-Holstein-Sonderburg, Louise Charlotte von', geslachtsnaam='Schleswig-Holstein-Sonderburg', birth=None, death=None, ids=['13898'], source_records=[{'fullname': 'Schleswig-Holstein-Sonderburg, Louise Charlotte von', 'geslachtsnaam': 'Schleswig-Holstein-Sonderburg', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13898'}]),
#  MergedIndexItem(canonical_fullname='Amama, Joachim van', geslachtsnaam='Amama', birth=None, death=None, ids=['142', '11372'], source_records=[{'fullname': 'Amama, Joachim van', 'geslachtsnaam': 'Amama', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '142'}, {'fullname': 'Amama, Joachim van', 'geslachtsnaam': 'Amama', 'birth': None, 'death': None, 'biography': '(1657-1720) [geschreven aan Heinsius]  Nederlands officier; kolonel van een Fries regiment infanterie sinds  1698; commandeur van Emden 1688; brigadier van de infanterie 1702; generaal-majoor  1709; commandeur van Hulst 1713. <I>NNBW</I>; Ringoir, <I>Hoofdofficieren infanterie</I>.', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'heinsius', '_id': '11372'}]),
#  MergedIndexItem(canonical_fullname='S. van Amama', geslachtsnaam='', birth=None, death=None, ids=['13565'], source_records=[{'fullname': 'S. van Amama', 'geslachtsnaam': '', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oldenbarnevelt', '_id': '13565'}]),
#  MergedIndexItem(canonical_fullname='Amama, Gerrit van', geslachtsnaam='Amama', birth=None, death=None, ids=['13822'], source_records=[{'fullname': 'Amama, Gerrit van', 'geslachtsnaam': 'Amama', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'oranje_nassau_albertine_agnes_van', '_id': '13822'}]),
#  MergedIndexItem(canonical_fullname='Johan Amama', geslachtsnaam='Amama', birth=None, death=None, ids=['15649'], source_records=[{'fullname': 'Johan Amama', 'geslachtsnaam': 'Amama', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '15649'}]),
#  MergedIndexItem(canonical_fullname='Jo(h)annes Hernes Amama', geslachtsnaam='Amama', birth=None, death=None, ids=['21938'], source_records=[{'fullname': 'Jo(h)annes Hernes Amama', 'geslachtsnaam': 'Amama', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '21938'}]),
#  MergedIndexItem(canonical_fullname='Jan van Amama', geslachtsnaam='Amama', birth=None, death=None, ids=['28616'], source_records=[{'fullname': 'Jan van Amama', 'geslachtsnaam': 'Amama', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'raa', '_id': '28616'}]),
#  MergedIndexItem(canonical_fullname='Lycklama à Nijeholt, Lubbert', geslachtsnaam='Lycklama à Nijeholt', birth=None, death=None, ids=['143', '20403'], source_records=[{'fullname': 'Lycklama à Nijeholt, Lubbert', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': None, 'death': None, 'biography': '', 'by': 0, 'dy': 0, 'reference': None, 'collection': 'anhalt_dessau_henriette_amalia_von', '_id': '143'}, {'fullname': 'Lubbert Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1639', 'death': '1697-08-22', 'biography': '', 'by': 1639, 'dy': 1697, 'reference': None, 'collection': 'raa', '_id': '20403'}]),
#  MergedIndexItem(canonical_fullname='dr. Hector Jacob Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1808-05-09', death='1872-06-20', ids=['16268'], source_records=[{'fullname': 'dr. Hector Jacob Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1808-05-09', 'death': '1872-06-20', 'biography': '', 'by': 1808, 'dy': 1872, 'reference': None, 'collection': 'raa', '_id': '16268'}]),
#  MergedIndexItem(canonical_fullname='mr. Tinco Martinus Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1766', death='1844-02-20', ids=['17494', '25678', '27117'], source_records=[{'fullname': 'mr. Tinco Martinus Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1766', 'death': '1844-02-20', 'biography': '', 'by': 1766, 'dy': 1844, 'reference': None, 'collection': 'raa', '_id': '17494'}, {'fullname': 'mr. Tinco Martinus Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1766', 'death': '1844', 'biography': '', 'by': 1766, 'dy': 1844, 'reference': None, 'collection': 'raa', '_id': '25678'}, {'fullname': 'mr. Tinco Martinus Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1766-04-10', 'death': '1844-02-20', 'biography': '', 'by': 1766, 'dy': 1844, 'reference': None, 'collection': 'raa', '_id': '27117'}]),
#  MergedIndexItem(canonical_fullname='Aucke Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1643', death='1715', ids=['19000'], source_records=[{'fullname': 'Aucke Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1643', 'death': '1715', 'biography': '', 'by': 1643, 'dy': 1715, 'reference': None, 'collection': 'raa', '_id': '19000'}]),
#  MergedIndexItem(canonical_fullname='Tinco Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1696', death='1762-03-22', ids=['19171'], source_records=[{'fullname': 'Tinco Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1696', 'death': '1762-03-22', 'biography': '', 'by': 1696, 'dy': 1762, 'reference': None, 'collection': 'raa', '_id': '19171'}]),
#  MergedIndexItem(canonical_fullname='mr. Pierius Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1681', death='1720-09-14', ids=['19203'], source_records=[{'fullname': 'mr. Pierius Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1681', 'death': '1720-09-14', 'biography': '', 'by': 1681, 'dy': 1720, 'reference': None, 'collection': 'raa', '_id': '19203'}]),
#  MergedIndexItem(canonical_fullname='Daniel de Blocq Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1702', death='1781-09-10', ids=['20978'], source_records=[{'fullname': 'Daniel de Blocq Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1702', 'death': '1781-09-10', 'biography': '', 'by': 1702, 'dy': 1781, 'reference': None, 'collection': 'raa', '_id': '20978'}]),
#  MergedIndexItem(canonical_fullname='Augustinus Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1742', death='1789-10-30', ids=['21605'], source_records=[{'fullname': 'Augustinus Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1742', 'death': '1789-10-30', 'biography': '', 'by': 1742, 'dy': 1789, 'reference': None, 'collection': 'raa', '_id': '21605'}]),
#  MergedIndexItem(canonical_fullname='Augustinus Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1670', death='1744-06-22', ids=['22262'], source_records=[{'fullname': 'Augustinus Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1670', 'death': '1744-06-22', 'biography': '', 'by': 1670, 'dy': 1744, 'reference': None, 'collection': 'raa', '_id': '22262'}]),
#  MergedIndexItem(canonical_fullname='Augustinus Lycklama à Nijeholt', geslachtsnaam='Lycklama à Nijeholt', birth='1603', death='1670-01-08', ids=['24121'], source_records=[{'fullname': 'Augustinus Lycklama à Nijeholt', 'geslachtsnaam': 'Lycklama à Nijeholt', 'birth': '1603', 'death': '1670-01-08', 'biography': '', 'by': 1603, 'dy': 1670, 'reference': None, 'collection': 'raa', '_id': '24121'}]),
#  ...]
