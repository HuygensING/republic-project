# %% [markdown]
# # Fuzzy Search and Petitioners' Roles and Professions

# %%
# This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
repo_name = 'republic-project'
repo_dir = os.path.split(os.getcwd())[0].split(repo_name)[0] + repo_name
print(repo_dir)
if repo_dir not in sys.path:
    sys.path.append(repo_dir)
# Out:
# /Users/marijnkoolen/Code/Huygens/republic-project

# %%
# load the Republic Elasticsearch API
from republic.elastic.republic_elasticsearch import initialize_es

rep_es = initialize_es(host_type='external', timeout=60)

# %% [markdown]
# ### Dictionary of resolution-specific terms
#
# During the project we compile lists of terms that are relevant within the corpus of resolutions. The lists of terms are categorised, with lists for persons, organisations, objects, locations, topics, etc.
#
# These terms can be used in fuzzy search to identify and classify different aspects of resolutions. For instance, the opening sentence of a resolution describes a proposition submitted to the States General. This proposition has a source type (often a specific type of document like a missive or a request) and details about who submitted, from when and on what date. Categorising these aspects allows us to add metadata to the individual resolutions with which we can improve information access.

# %%
from republic.model.resolution_phrase_model import read_republic_term_dict

term_dict = read_republic_term_dict()

# What different categories of terms are available?
term_dict.keys()
# Out:
# dict_keys(['action', 'object', 'unit', 'meeting', 'person_reference', 'organisation', 'geographical_name', 'other_name', 'person_name', 'adjective', 'location', 'topic', 'date', 'misc', 'function'])

# %% [markdown]
# Most categories have sub-categories. E.g. the `person_reference` category distinguishes between professions, family relationships, legal status and titles.

# %%
term_dict['person_reference'].keys()
# Out:
# dict_keys(['person_legal_status', 'person_family', 'person_citizen', 'person_title', 'person_other', 'person_profession', 'person_meeting_role', 'person_nationality'])

# %%
# The number of profession terms in the dictionary
len(term_dict['person_reference']['person_profession'])
# Out:
# 1039

# %% [markdown]
# These person reference terms can be added as a lexicon to a fuzzy searcher, so you can search for occurrences of these terms.

# %%
from fuzzy_search.fuzzy_context_searcher import FuzzyContextSearcher
from fuzzy_search.fuzzy_phrase_model import PhraseModel

config = {
    'levenshtein_threshold': 0.8,
    'ngram_threshold': 0.7,
    'ngram_size': 3,
    'skip_size': 1,
    'include_variants': True
}

phrases = []
for category in term_dict['person_reference']:
    for term in term_dict['person_reference'][category]:
        # turn the term into a fuzzy search phrase, and add its categories as labels
        phrase = {
            "phrase": term,
            "label": ["person_reference", category]
        }
        # add the term to the list of phrases
        phrases.append(phrase)
print("number of person reference phrases:", len(phrases))
# Out:
# number of person reference phrases: 1190

# %%
# Create a fuzzy search phrase model from the list of phrases
phrase_model = PhraseModel(phrases, config=config)
# configure a searcher
person_ref_searcher = FuzzyContextSearcher(config)
# Add the phrase model as lexicon to the searcher
person_ref_searcher.index_phrase_model(phrase_model)

# %%
# Create a query to select only resolutions in the year 1672 based 
# on propositions of type request
query = {
    "bool": {
        "must": [
            {"match": {"metadata.type": "resolution"}},
            {"match": {"metadata.session_year": 1672}},
            {"match": {"metadata.proposition_type": "requeste"}}
        ]
    }
}

resolutions = rep_es.retrieve_resolutions_by_query(query, size=1000)

# %% [markdown]
# Each request proposition starts with a fixed formula, followed by details of the proposer, location and date, and then a _proposition verb_ that introduces the content of the proposition. To identify the proposer's role or profession, we use the fuzzy searcher and the `person_reference` lexicon on the text between the opening formula and the _proposition verb_.

# %%
from collections import defaultdict
from collections import Counter

person_ref_freq = Counter()
person_ref_type_freq = Counter()
person_role = defaultdict(Counter)

obs = {
    "res": [],
    "term": [],
    "label": []
}

for res in resolutions:
    # the opening formula is always in the first paragraph
    first_para = res.paragraphs[0]
    
    # The resolution evidence consists of fuzzy search matches based
    # on the resolution opening phrase lexicon.
    # Select only the matches in the first paragraph
    first_para_matches = [match for match in res.evidence if match.text_id == first_para.id]    
    
    # From there, pick the first match phrase that is an opening formula. 
    # The end of the formula is the start of the 
    opening_match = [match for match in first_para_matches if match.has_label('proposition_opening')][0]
    proposition_start = opening_match.end
    
    # Then, pick the first proposition verb as the end of the proposition text,
    # or the end of the paragraph if there is no proposition verb
    verb_matches = [match for match in first_para_matches if match.has_label('proposition_verb')]
    proposition_end = verb_matches[0].end if len(verb_matches) > 0 else len(first_para.text)
    
    # Select the text of the first paragraph between the opening formula and the proposition verb
    proposition_text = first_para.text[proposition_start:proposition_end]
    print(proposition_text, '\n')
    
    # look for person reference terms
    matches = person_ref_searcher.find_matches(proposition_text)
    for match in matches:
        print(f"Phrase: {match.phrase.phrase_string: <30}\tmatch string: {match.string}")
        print(f"\t", match.label)
        person_ref_freq.update([match.phrase.phrase_string])
        # the label can be a single string or a list of strings
        refs = match.label if isinstance(match.label, list) else [match.label]
        for ref in refs:
            person_role[ref].update([match.phrase.phrase_string])
            obs["res"].append(res.id)
            obs["term"].append(match.phrase.phrase_string)
            obs["label"].append(ref)
        person_ref_type_freq.update(refs)
# Out:
# Johan Coorte, ende Gijsbert Zuijlen van Nieuvelt, beijde Schepenen ‛s Lants vanden Vrijen, versoeckende
#
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Jan van Eede geweest hebbende
#
# Johan d'Arbaij, Major van een regiment te voet, ten dienst deser Landen, guarnisoen houdende
#
# Phrase: Major                         	match string: Major
# 	 ['person_reference', 'person_profession']
# Balthasar van geersbergen, Secretaris van Derssel, Wessen & Beersen alle inde Meijerije van s' Hertogenbos, houdende
#
# Phrase: Sekretaris                    	match string: Secretaris
# 	 ['person_reference', 'person_profession']
# Phrase: Secretaris                    	match string: Secretaris
# 	 ['person_reference', 'person_profession']
# N. Cauberecht, Licentiaet inde rechten tot Maestricht, houdende
#
# Phrase: Licentiaat                    	match string: Licentiaet
# 	 ['person_reference', 'person_profession']
# Boulliu, Burgemeesteren ende Schepenen der Stede ende Ambachte van Neuse, houdende
#
# Phrase: Burgemeester                  	match string: Burgemeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeesteren                	match string: Burgemeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Elisabeth van Groningen, Taver„ niester tot Isendijcke, houdende
#
# Adriaen, Grave van Hornes, generael vande Artillerije deser Landen, houdende
#
# Phrase: Grave                         	match string: Grave
# 	 ['person_reference', 'person_title']
# Cornelis Caen Griffier der Stadt Sluijs in Vlaenderen, houdende
#
# Phrase: Griffier                      	match string: Griffier
# 	 ['person_reference', 'person_profession']
# Jeam Barton de mombas, Com„ missaris Generael vande Militie te peerde van desen Staet, houdende
#
# Phrase: Commissaris                   	match string: Com„ missaris
# 	 ['person_reference', 'person_profession']
# Jan ende Rogier van Weert, Coopluijden tot Amsterdam, houdende
#
# Claes Willemsz, woonende tot Goude, houdende
#
# Maria vander Does mater vant Clooster tot Waelwijck, versoeckende
#
# Joris de neve haer Ho:Mo: Consul in Sicilien, houdende
#
# Phrase: Consuls                       	match string: Consul
# 	 ['person_reference', 'person_profession']
# Phrase: Consul                        	match string: Consul
# 	 ['person_reference', 'person_profession']
# Munits Tisholm, houdende
#
# Claes Thijs Otres doende de affaires van Jean vande Wall ende Jean van Stockum, houdende
#
# Ignatius de Berwout, heer van Outel Maistre de Campe in dienst vanden Coningh van Spaigne, als nast hebbende
#
# Phrase: Koningh                       	match string: Coningh
# 	 ['person_reference', 'person_profession']
# Vrouwe Isabella Gravinne tot Limburgh ende Bronckhorst, Vrouwe tot Stirumb ende Geennen, gebooren Gravinne tot Veelen endemegen, versoeckende
#
# Phrase: Vrouwe                        	match string: Vrouwe
# 	 ['person_reference', 'person_title']
# Phrase: Vrouwe                        	match string: Vrouwe
# 	 ['person_reference', 'person_title']
# Johan vander Swalme, ende andere Wijnsteeckers binnen Isendijck, houdende
#
# Dirck Bouche, houdende
#
# David Edij, Coopman tot Aberdeen in Schotlandt, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Nicolaes de Haan, Leendert van Bijlant, Hendrick van Kessel, ende Joachint van Swichem alle vier ordinaris Boden vande Generaliteijt, ende extraordinaris ge,, affecteert ten dienste vande heeren haer Ho:Mo: Gedeputeerden ende Gevolmachtichden te Velde, houdende
#
# Phrase: Bode                          	match string: Boden
# 	 ['person_reference', 'person_profession']
# Phrase: Extraordinaris                	match string: extraordinaris
# 	 ['person_reference', 'person_title']
# Phrase: Gedeputeerde                  	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gedeputeerden                 	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Balthasar van Gijsbergen Secretaris vande dingh bancken van Eerssel, Pessen, ende Beersen, houdende
#
# Phrase: Sekretaris                    	match string: Secretaris
# 	 ['person_reference', 'person_profession']
# Phrase: Secretaris                    	match string: Secretaris
# 	 ['person_reference', 'person_profession']
# Andries Sam, ende Pieter van Gelsdorp Coopluijden tot Dordrecht, houdende
#
# Henrick, Grave van Solms de Colonnel ten dienste deser Landen, houdende
#
# Phrase: Grave                         	match string: Grave
# 	 ['person_reference', 'person_title']
# Jacob van Dorth, Schepen ‛s Lants ght
#
# Phrase: Scheepen                      	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Pieter Lips, Schepen ‛s Lants vanden Vrijen, versoeckende
#
# Phrase: Scheepen                      	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Johan Coorte, ende Gijsbert Zuijlen van Nieuvelt, beijde Schepenen ‛s Lants vanden Vrijen, versoeckende
#
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Adriaen Berner, Baron van Pallandt, Heere van Keppel, Ritmeester, in guarnisoen tot Maestricht, houdende
#
# Phrase: Baron                         	match string: Baron
# 	 ['person_reference', 'person_title']
# Phrase: Heer                          	match string: Heere
# 	 ['person_reference', 'person_title']
# Phrase: Heere                         	match string: Heere
# 	 ['person_reference', 'person_title']
# Phrase: Batmeester                    	match string: Ritmeester
# 	 ['person_reference', 'person_profession']
# Mr. Gerrit Pijl, houdende
#
# Phrase: Mr                            	match string: Mr
# 	 ['person_reference', 'person_title']
# Gerard Biben, poorter der Stadt ‛s Hertogenbosch, medebrengende, dat hij Suppliant sich nu ontrent de twaelff Jaren binnen de voorschreve Stadt met der woon onthouden heeft ende oock van meijninge is, ge,, duijrende sijn leven aldaer te ver„ blijven, gelijck hij oock tot Poorter aldaer is geadmitteert, ende versoec„ kende Acte van naturalisatie, om alsoo erkent te mogen werden als een gebooren Brabander: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voorschreve Requeste gesonden sal werden aenden Raet van Brabant om advis. Is ter Vergaderinge gelesen het memoriael van Resident Huneken, houdende
#
# Phrase: Poorter                       	match string: poorter
# 	 ['person_reference', 'person_profession']
# Phrase: Suppliants                    	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Poorter                       	match string: Poorter
# 	 ['person_reference', 'person_profession']
# Phrase: Resident                      	match string: Resident
# 	 ['person_reference', 'person_citizen']
# Johan vander Does, hooch Bailliu ‛s Lants vanden Vrijen, houdende
#
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# Burgemeesteren ende Schepenen ‛s Lants vanden Vrijen, houdende
#
# Phrase: Burgemeester                  	match string: Burgemeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeesteren                	match string: Burgemeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Cornelis Verheijen, ende Johan Martinel, Borgers der Stadt ‛s Hertogenbosch, houdende
#
# Phrase: Borger                        	match string: Borgers
# 	 ['person_reference', 'person_citizen']
# Phrase: Borgers                       	match string: Borgers
# 	 ['person_reference', 'person_citizen']
# Dirck van Deuverden, Capiteijn ter dienste deser Landen, in huwelick hebbende
#
# Phrase: Capitein                      	match string: Capiteijn
# 	 ['person_reference', 'person_profession']
# Johan Schoock, houdende
#
# Cornelis Verheijen ende Johan Martinel Borgeren der Stadt ‛s Hertogenbosch, houdende
#
# Burgemeesteren ende Schepenen vanden Lande van Hulster Ambacht houdende
# Phrase: Burgemeester                  	match string: Burgemeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeesteren                	match string: Burgemeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Johan Schoock, houdende
#
# Johannes Amilius, Commis Generael vande Convoijen ende Licenten, houdende
#
# Henrick Graham, Lieutenant Colonnel ten dienste deser Landen, houdende
#
# Phrase: Lieutenant                    	match string: Lieutenant
# 	 ['person_reference', 'person_profession']
# Otto Grave van Limburch, ende Bronchorst, Heer van Stierum, houdende
#
# Phrase: Grave                         	match string: Grave
# 	 ['person_reference', 'person_title']
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# francisco van Lisidro, Coopman tot Amsterdam, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Arent van Dalen, Provoost Generael vant Leger, houdende
#
# Mr. Ja. stus Verster, jegen„ woordich Griffier ende Raet der Stadt ‛s hertogenbosch, houdende
#
# Phrase: Mr                            	match string: Mr
# 	 ['person_reference', 'person_title']
# Phrase: Griffier                      	match string: Griffier
# 	 ['person_reference', 'person_profession']
# Abraham franco Meuden, Coop„ man woonende tot Amsterdam, hou„ dende
#
# Belchior Meude Franco, Coop„ man woonende tot Amsterdam, hou„ dende
#
# Christoffel menden franck Coopman tot Amsterdam, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Gosewijn de Oock ende Hieroninne Wollers cum socijs, Coopluijden tot Amsterdam, houdende
#
# Jacomo Florentius, Coopman woonende tot Amsterdam, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Maria Rounieres, woonende tot Amsterdam, houdende
#
# Agneta Leeen, weduwe wijlen Diderick Block, woonende tot Amsterdam, houdende
#
# Arent van Dalen, Prevoost Generael vant Leger, houdende
#
# Elisabeth Maria Musch, Weduwe Buath, houdende
#
# Phrase: Weduwe                        	match string: Weduwe
# 	 ['person_reference', 'person_legal_status']
# Mr. Maxmuliaen Engels, pensionnaris ‛s Lants vanen Vrijen tot Sluijs in Vlaenderen, houdende
#
# Phrase: Mr                            	match string: Mr
# 	 ['person_reference', 'person_title']
# Phrase: Pensionaris                   	match string: pensionnaris
# 	 ['person_reference', 'person_profession']
# Elisabeth van Peenen, weduwe wijlen Louis de Bils, in sijn leven professor Honorarius der Anatoncie binnen ‛s Hertogenbosch, houdende
#
# Allert Coninck, woonende tot Amsterdam, houdende
#
# Roelant Ravens Frambleu„ maecker alhier inden Hage, hou„ dende
#
# Wouter van Swieten, woonende tot Seghwaert, houdende
#
# Schepenen ende regeerders der Dinghbancke van Bercheijck, Ruthoven, Westerhooven, Borckel ende Schaft, Meijerije van ‛s hertogen„ bosch, houdende
#
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# van Jacobsz, Schipper geboortich tot Amsterdam, leggende met sijn Scheepje de fortuijn, gemonteert met ses stuckens voor de Stadt van Embden, versoeckende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Johan Meijer van Hamburch, voerende het Schip de Meijer, waer van alle de Reeders sijn Coopluijden woonende tot Hamburch voornoemt, houdende
#
# verscheijde Coopluijden der Stadt Amsterdam, traffijcquerende op Ita„ lien, houdende
#
# Johan Hallingh, Commissaris Generael van ‛s Lants Leger Schepen, houdende
#
# Phrase: Commissaris                   	match string: Commissaris
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepen                      	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Pieter Claesz Louw, woo„ nende tot Oostvaerdam, Coopman in groote Schepen, masten ende Molenroeden, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepen                      	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Justus Versterre Griffier der Stadt ‛s Hertogenbosch, raedt ende een meede lits vande Politijcque regieringe aldaer houdende
#
# Phrase: Griffier                      	match string: Griffier
# 	 ['person_reference', 'person_profession']
# Gerard enoppert, Capiteijn ten dienste deser Landen, houdende
#
# Phrase: Capitein                      	match string: Capiteijn
# 	 ['person_reference', 'person_profession']
# Josephus van Setelaer, Prior vande Carthuijsen tot Antwerpen houdende
#
# Bondewijn van Soutelande, Colonnel van een regiment paerden ten dienste deser Landen, houdende
#
# Bailliu Burgermeesteren ende regeerders der Stadt ende Schependomme van Aerdenburch, ver„ soeckende
#
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# Phrase: Burgermeester                 	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeester                  	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeesteren                	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Johan van Dalen, Griffier, vanden Advacaet fiscael, ende vanden Crijchkraet deser Landen, houdende
#
# Phrase: Griffier                      	match string: Griffier
# 	 ['person_reference', 'person_profession']
# Baillu, Burgermeesteren ende Schepenen van Oostburch, houdende
#
# Phrase: Burgermeester                 	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeester                  	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeesteren                	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Boudewijn van Zoutelande Colonne van een regiment peerden ten dienste deser Landen, houdende
#
# Engelbrecht vander Mijll, Lieu„ tenant Generaell ende Contrerolleur vande Artillerije, houdende
#
# Phrase: Lieutenant                    	match string: Lieu„ tenant
# 	 ['person_reference', 'person_profession']
# Phrase: Contrarolleur                 	match string: Contrerolleur
# 	 ['person_reference', 'person_profession']
# Anthonij de Valck, Bailliu der Stadt Hulst, versoeckende
#
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# Jacques Miguet, woonende tot Charbourgh in Normandie, schipper van sijne barcke — ofte schip, genaemt de Ste. Marie, groot: ontrent twintich off twee entwintich lasten, houdende
#
# Phrase: schippers                     	match string: schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Ste                           	match string: Ste
# 	 ['person_reference', 'person_title']
# Nicolaes de la bie, Borger tot Nieupoort houdende
#
# Phrase: Borgers                       	match string: Borger
# 	 ['person_reference', 'person_citizen']
# Phrase: Borger                        	match string: Borger
# 	 ['person_reference', 'person_citizen']
# Jacques rijffelare, alias Swart, Schipper
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# pierne Mopin, woonende tot Calais in Vranckrijck, houdende
#
# Arent van Dalen, prevoost Generael een het Leger handende
#
# Andries russel, ende Jacob Gordon beijde schotse Coopluijden, houdende
#
# Frederick de Nassau, heer van Zuijlesteijn, Lieutenant Generael vande Infanterie, houdende
#
# Phrase: Lieutenant                    	match string: Lieutenant
# 	 ['person_reference', 'person_profession']
# Antonio Gomes Core, woonende op het Eijlandt madera, houdende
#
# Paulus reeffkens, houdende
#
# Isaacq foignier, ende authonij Zuland, Coopluijden tot Amsterdam, als gemachtichden vande Nederlandsche Natie, residerende in aleipo, houdende
#
# Gaspar Stedingh van Geluckstadt, schipper vanden Schepe genaemt Christianus quintus, daer reeders van sijn Maria Thomasz, weduwe wijlen Henricus Thomas in sijn leven raadt des Coninghs van Denemarcken, ende president van Pelick„ stadt, Michiel de Burgh, Petrus Rave Andreas Haselboorn, ende den Suppliant, alle Borgers ende Ingesetenen van geluck= stadt voornoemt, houdende
# Phrase: schippers                     	match string: schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: Suppliants                    	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Borger                        	match string: Borgers
# 	 ['person_reference', 'person_citizen']
# Phrase: Borgers                       	match string: Borgers
# 	 ['person_reference', 'person_citizen']
# Phrase: Ingezetenen                   	match string: Ingesetenen
# 	 ['person_reference', 'person_citizen']
# Phrase: Ingeseetenen                  	match string: Ingesetenen
# 	 ['person_reference', 'person_citizen']
# Sijnen plaijonle, Doctor inde Medicine houdende
#
# Phrase: Sijne                         	match string: Sijnen
# 	 ['person_reference', 'person_title']
# Mr. henrick van Brengel, Griffier derstadt s'hertogenbosch, houdende
#
# Phrase: Mr                            	match string: Mr
# 	 ['person_reference', 'person_title']
# Phrase: Griffier                      	match string: Griffier
# 	 ['person_reference', 'person_profession']
# Jan Jacobsz van amsterdam, voerende het fregat de morgenstarre, gemonteert met lestien stucken, zeijlreede leggende voorde vaelen van amsterdam voornoemt, houdende
#
# Johan vander Does, hooch Bailliu s'Landts vanden Vrijen, houdende
#
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# franciscus van pidro, ende Jacob perera Coopluijden ende Borgers der Stadt Amster„ dam, houdende
#
# Phrase: Borger                        	match string: Borgers
# 	 ['person_reference', 'person_citizen']
# Phrase: Borgers                       	match string: Borgers
# 	 ['person_reference', 'person_citizen']
# Nicolaes Steens, Predicant vanden Heer van Strevelshoeck haer Ho:Mo: gedesigneerde resident naer het Hoff van Spaigne, houdende
#
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# Phrase: Resident                      	match string: resident
# 	 ['person_reference', 'person_citizen']
# Cornelis Verheijen, ende Johan Martinel, Borgeren der Stadt ‛s her„ togenbosch, houdende
#
# Joost Roobroeck, Rentmeester van het Capittel van Udenrode Meijen rije van ‛s Hertogenbosch, houdende
#
# Johan Schoock, houdende
#
# Adriaentgen Gillis, Dochter vanden Capiteijn Gillis Leenderts, woonende tot Maeslantsluijs, houdende
#
# Phrase: Dochters                      	match string: Dochter
# 	 ['person_reference', 'person_family']
# Phrase: Dochter                       	match string: Dochter
# 	 ['person_reference', 'person_family']
# Phrase: Capitein                      	match string: Capiteijn
# 	 ['person_reference', 'person_profession']
# Michael van Middelhoven, hou„ dende
#
# Willem Post, woonende tot Antwerpen, houdende
#
# Johannes Kras, houdende
#
# Reijnder Jansz Klieck, Schipper op het Schip het Landt van Beloften, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Jacob Pietersz Luijt, Schipper op het Schip de Swarte Luijt, Jan Jansz Schellinckhout, Schipper op het Schip Schellinckhout, Jan Willems Swaagh, Schipper op het Schip de Wolff ende Claes Pietersz Veer, Schipper op het Schip de Salm, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Hendrick Jansz Kassemaecker tot Sardam, houdende
#
# Cornelis Verheijen, ende Johan Martinel Borgeren der Stadt 's hertogenbosch, houdende
#
# Jacob van Volbergen, Ontfanger Generael der Vereenichde Nederlanden, houdende
#
# Phrase: Ontfanger                     	match string: Ontfanger
# 	 ['person_reference', 'person_meeting_role']
# Cornelis de Boot, Heer van Cadsant, houdende
#
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# Schepenen ende regeerders des Dorps van Vucht, Meijerije van ‛s Hertogenbosch, houden
#
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Mr. Johan van Wouw, Advocaet fiscael over ‛s Lants Vloote ter Zee, houdende
#
# Phrase: Mr                            	match string: Mr
# 	 ['person_reference', 'person_title']
# Maria van Berchem, Weduwe wijlen Jan Budier, in sijn leven Coopman tot Luijck, houdende
#
# Phrase: Weduwe                        	match string: Weduwe
# 	 ['person_reference', 'person_legal_status']
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Martinus Ackersdijck, Stadt,, houder vanden Hooch ende Leeghschout der Stadt ende meijerije van ‛s Hertogen„ bosch, houdende
#
# Jacob van Wassenaer, Heer van Wassenaer, Obdam, & houdende
#
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# Schepenen ende regeerders des Dorps van Vucht: Meijerije van ‛s herto,, genbosch, houdende
#
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Roelant Cau, Bailliu, ende Schout van Hulster Ambacht, houdende
#
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# Phrase: Schout                        	match string: Schout
# 	 ['person_reference', 'person_profession']
# Cornelis Verheijen ende Johan Martinel, Borgeren der Stadt ‛s herto,, genbosch, houdende
#
# Mr. Johan Hallingh, outBurge,, meester van ‛s Gravenhage, houdende
#
# Phrase: Mr                            	match string: Mr
# 	 ['person_reference', 'person_title']
# Phrase: Meester                       	match string: meester
# 	 ['person_reference', 'person_profession']
# Isaacq Oijens, Guilliam Sweeden,, rijck, Pieter Loijens, Jan de Roij, ende francois Kalschuijr, cum Sociis , alle Coopluijden tot Amsterdam houdende
#
# Johan vander Does, hoochbaillen s'landts vanden Vrije, houdende
#
# anna Maria van Gerwen, weduwe wijlen Marcelis vander voll, in sijn leven Drossaert van Hedel, houdende
#
# Burgermeester ende schepenen der Stadt hulst, houdende
#
# Phrase: Burgemeester                  	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Burgermeester                 	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Jordaen van haren, meester slandts vuijrwercker in Guarnisoen tot Maestricht, houdende
#
# Phrase: Meester                       	match string: meester
# 	 ['person_reference', 'person_profession']
# Gijsbrecht Bonaerts, president der vrijheijt van Osch, inden quartiere van Maesslandt Meijerie der Stadt s'hertogenbosch, soo voor hem selven, ende als gemachtichde van Schouteth, Schepenen, Borgermeesters, geswoorens, kerck= meesters, armmeesters, ende geruijme geerffdens ende Inwoonderen der voorschreve vrijheijt van Osch, representerende
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Phrase: Armmeester                    	match string: armmeesters
# 	 ['person_reference', 'person_profession']
# Phrase: Inwoonder                     	match string: Inwoonderen
# 	 ['person_reference', 'person_citizen']
# Phrase: Inwoonders                    	match string: Inwoonderen
# 	 ['person_reference', 'person_citizen']
# Frans Christoffel Muntz, gelicentieert Lieutenant Colonel inden Jaere 1668 houdende
#
# Phrase: Lieutenant                    	match string: Lieutenant
# 	 ['person_reference', 'person_profession']
# Phrase: Collonel                      	match string: Colonel
# 	 ['person_reference', 'person_profession']
# Phrase: Kolonel                       	match string: Colonel
# 	 ['person_reference', 'person_profession']
# Jacques Alvares, ende Joseph frances Burgers ende Coopluijden tot Amsterdam, houdende
#
# Phrase: Burger                        	match string: Burgers
# 	 ['person_reference', 'person_citizen']
# Phrase: Burgers                       	match string: Burgers
# 	 ['person_reference', 'person_citizen']
# Francois Watson Engels Edelman, ende Robbert Custis d Engels Coopman tot Rotterdam houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Wilhelm Wiegel Rentmr van: Commandere binnen Rhijnberck, woonende tot Ardingen getrouwt met een dochter van Jan Asselingh Coopman tot Rotterdam, versoeckende
#
# Phrase: Commandeur                    	match string: Commandere
# 	 ['person_reference', 'person_profession']
# Phrase: Dochter                       	match string: dochter
# 	 ['person_reference', 'person_family']
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Johan grove, voor desen lange Jaren in Engelandt als ritmeester, ende Maijoor gedient hebbende
#
# Phrase: Batmeester                    	match string: ritmeester
# 	 ['person_reference', 'person_profession']
# den Hoogh Bailliu, Burgermeester ende Schepenen s'Landts vanden Vrijen residerende tot Sluijs in Vlaenderen, houdende
#
# Phrase: Hoog                          	match string: Hoogh
# 	 ['person_reference', 'person_title']
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeester                  	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Burgermeester                 	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# d'Erffgenamen van Adriaen ende Cornelis Lampsius, woonende tot Middelburgh ende Vlissingen respective, vertoonende dat sij sekerl bericht sijn, dat de franse jegenwoordigh inde Caribische Eijlanden sijnde, voorgenomen hebben
#
# Adriaen Louff, Coopman tot Gouda, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Bernardus, Waterbeeck, pre„ dicant tot Eersol ende Duijssel inde Meijerije van s' Hertogenborgh, hou„ dende
#
# Ant. Hoevenaer, Coopman tot Amsterdam houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Laurens Willemsz verpoorten, Coopman tot Middelburgh in Zeelant, ende consorten, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Michiel Hens, Ignatius van Eusen, volckert Volckeck, ende Pieter van daaken Coopluijden tot Amsterdam, houden„
#
# Pieter Cornelisz, Bolle van den Hoeff, Schipper vanden Schepe genaemt den Paalham, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Dirck van Schoonderwoert, als Procureur van Amandus Hovelingh Abt van Ste. Pieters nevens Gent mitsgaders de Abdisse van het rijcke gasthuijs aldaer geden bij mandement van arrest ende rauw actie ter eenre op ende jegens Cornelis van Vlooswijck, heer van Vlooswijck Cum suis Impt. in het voors cas ter andere zijde, versoeckende
#
# Phrase: Procureur                     	match string: Procureur
# 	 ['person_reference', 'person_profession']
# Phrase: Ste                           	match string: Ste
# 	 ['person_reference', 'person_title']
# Overhardt van Hees, Lieutenant vande Compagnie van Capiteijn Bedarides, in Guarnisoen gelegen hebbende
#
# Phrase: Lieutenant                    	match string: Lieutenant
# 	 ['person_reference', 'person_profession']
# Phrase: Capitein                      	match string: Capiteijn
# 	 ['person_reference', 'person_profession']
# Jan Motherlij Schipper vanden Schepe marchands desire, Eduarde Rodson, Schipper vanden Schepe Endeavour, ende Thomas Feild Schipper vanden Schepe, oock ge„ naemt Endeavour, alle van Hull houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Cornelis van Damine Schipper ende burger tot Brussel, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Guillianne Lauririsques, houdende
#
# Isacq van Roijesteijn Jacobus van kip, ende Nicolaes Moespas, Ontfanger Contrerolleur ende besiender respective vanden Toll ende het Licent van hetfort gennip, houdende
#
# Phrase: Ontfanger                     	match string: Ontfanger
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Contrarolleur                 	match string: Contrerolleur
# 	 ['person_reference', 'person_profession']
# Jan Verbare Coopman tot Vlissinge, ende consorten, reeders van fregatta Amelia, leggende tot Brugge met laen„ deren, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Joost Caspar van Loen tot borgh Enschede, houdende
#
# Hendrick Bijnen, Weijman ende Valckenier, van Sijne Keijserlijcke Majesteijt, houdende
#
# Phrase: Sijne                         	match string: Sijne
# 	 ['person_reference', 'person_title']
# michiel Adriaens de Prome, hou„ dende
#
# Johan van Wachtendonck, houdende
#
# Nicolaes reeve, Coopman tot Rotterdam, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Andries de Wisser, Commissaris op de Mase, versoeckende
#
# Phrase: Commissaris                   	match string: Commissaris
# 	 ['person_reference', 'person_profession']
# Mannel ende Antano Rodriges, ende Jacob Perera, ende daernevens geexhibeert eenige bijlagen, versoec„ kende om redenen daerin verhaelt, dat den Advocaet fiscael, ende Commis Generael tot Harlingen mach werden gelast de Supplianten haer Goederen cost ende schadeloos te restitueren. immers ende in allen gevalle te declareren, dat de Goederen vande Supplianten voor geen nieuwe ende verbode ladinge sijn te houden
#
# Phrase: Suppliants                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliants                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Guilielmo Swedenrijck ende consorten, Coopluijden tot Amsterdam, versoeckende
#
# Henrick Wenckilick, Dirck de Graeff ende Sammel Hespel versoeckende
#
# Phrase: Graef                         	match string: Graeff
# 	 ['person_reference', 'person_title']
# Jan de Clijver, Impetrant in cas van indemniteijt, contra Adriaen Matheus de Rou nomini uxoris ende consorten Gedaechdens, ver„ soeckende
#
# Phrase: Impetrant                     	match string: Impetrant
# 	 ['person_reference', 'person_meeting_role']
# Adriaen de Tourlon, Consul wegens desen Staet in Biscaijen, houdende
#
# Phrase: Consuls                       	match string: Consul
# 	 ['person_reference', 'person_profession']
# Phrase: Consul                        	match string: Consul
# 	 ['person_reference', 'person_profession']
# Elisabeth Maria Musch, Weduwe Buath, versoec„ kende om redenen daerinne ver„ haelt, dat haer Ho:Mo: gelieven het paspoort haer den derden Maij lestleden verleent, noch voor ses maenden te prolongeren: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, mits desen te consenteren int voorschreve versoeck. Ende wert dienvolgens aende Suppliante de versochte prolongatie vande voornoemde paspoort voor den tijt van ses maenden toegestaen, ende geaccordeert.
# Phrase: Weduwe                        	match string: Weduwe
# 	 ['person_reference', 'person_legal_status']
# Phrase: Suppliants                    	match string: Suppliante
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Suppliante
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Suppliante
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Suppliante
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Suppliante
# 	 ['person_reference', 'person_meeting_role']
# Nicolaes Reve Engelsch Coop„ man tot Rotterdam, versoeckende
#
# Willem Weijt, Schipper van,, den Schepe genaempt de Margriet, ende Jacob Balvert, Schipper vanden Schepe de Jacob uijt Schotlandt, ver„ soeckende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Bernard Heringa van Grovestins, haer Ho:Mo: gewesen extraordinaris Gedeputeerde naer Wunster ende Bij levelt, versoec„ kende om de geallegeerde redenen dat hare Ho:Mo: andere Heeren Commissarissen gelieven te versoec„ ken ende authoriseren, om over des Suppliants declaratie ende stucken met eenige Heeren Gecommitteerden uijt den Raet van State ende Generaliteijts Reeckencamer, bij haer E. E. selffs te nomineren, in conferentie ende besoignes te treden: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, mits desen tot de voorschreve besoignes ende confe„ rentie van nieuws te versoecken ende te committeren de Heeren Hoogendorp ende andere hare Ho:Mo: Gedeputeerden tot de saecken vande finantie, alles op rapport daer van aen dese Vergaderinge te doen.
#
# Phrase: Extraordinaris                	match string: extraordinaris
# 	 ['person_reference', 'person_title']
# Phrase: Gedeputeerden                 	match string: Gedeputeerde
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gedeputeerde                  	match string: Gedeputeerde
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Heere                         	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Heeren                        	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Commissarissen                	match string: Commissarissen
# 	 ['person_reference', 'person_profession']
# Phrase: Suppliantes                   	match string: Suppliants
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Suppliants
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Suppliants
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Suppliants
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliants                    	match string: Suppliants
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Heere                         	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Heeren                        	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Gecommitteerde                	match string: Gecommitteerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gecommitteerden               	match string: Gecommitteerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Heere                         	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Heeren                        	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Gedeputeerde                  	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gedeputeerden                 	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Doctor Cornelis de Montigni de Glarges, Heer van Clesmes haer Ho:Mo: Agent tot Calais versoeckende
#
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# Phrase: Agent                         	match string: Agent
# 	 ['person_reference', 'person_profession']
# Johan Groen, Schipper van Santen, gelegen in het Landt van Cleff, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# eenige Coopluijden, woonende tot Middelburgh in Zeelandt, als geinte„ resseerdens in seecker fregat genaemt het Vliegent hart, gevoert werdende door Capitein Jacques Croll, ver„ soeckende
#
# Phrase: Kapitein                      	match string: Capitein
# 	 ['person_reference', 'person_profession']
# Phrase: Capitein                      	match string: Capitein
# 	 ['person_reference', 'person_profession']
# Pieter Cornelis Balck, Schipper op het fleuijtschip de roemer van Veenhuijsen, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Andries de Visscher, Commissaris van ‛s Lants Brieven op de Maze houdende
#
# Phrase: Eisscher                      	match string: Visscher
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Visscher                      	match string: Visscher
# 	 ['person_reference', 'person_profession']
# Phrase: Commissaris                   	match string: Commissaris
# 	 ['person_reference', 'person_profession']
# Albertus vander Veer, Coopman tot Amsterdam, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Abraham vander Hutten, Consul tot Alicanten, houdende
#
# Phrase: Consuls                       	match string: Consul
# 	 ['person_reference', 'person_profession']
# Phrase: Consul                        	match string: Consul
# 	 ['person_reference', 'person_profession']
# Aert van Sprangh, Borger der Stadt Gornichem, houdende
#
# Phrase: Borgers                       	match string: Borger
# 	 ['person_reference', 'person_citizen']
# Phrase: Borger                        	match string: Borger
# 	 ['person_reference', 'person_citizen']
# Balthasar van Geersberge Secre„ taris van Oinghbaucken van dersel Pessen, ende Beerssen, houdende
#
# Phrase: Secretaris                    	match string: Secre„ taris
# 	 ['person_reference', 'person_profession']
# Paulus Croesbeeck, procureur voor het Collegie ter Admiraliteijt op de Maze, houdende
#
# Phrase: Procureur                     	match string: procureur
# 	 ['person_reference', 'person_profession']
# Pieter Pitet Coopman ende Borger woonende tot Brussel, houden„
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Phrase: Borgers                       	match string: Borger
# 	 ['person_reference', 'person_citizen']
# Phrase: Borger                        	match string: Borger
# 	 ['person_reference', 'person_citizen']
# Anna Boom, Weduwe van Jan van Mortel, woonende tot Brus„ sel, houdende
#
# Phrase: Weduwe                        	match string: Weduwe
# 	 ['person_reference', 'person_legal_status']
# Francoijs Douwert Coopman tot Brugge, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Cornelis van Vlooswijck heer van Vlooswijck, ende Burgermeester der Stadt Amsterdam, Pieternelis, Heer van Sastingen, ende Jacob Pesijn, Ontfanger vande ge„ meene middelen op 't Zas van Rant Impten van mandement van arrest ende rauw actie ter eenre, ende van Amandus Hovelingh, abt van Ste Pieters nevens Gent, ende d'abdisse van het rijcke gasthuijs aldaer geden. int voors: Cas ter andere zijde, versoeckende
# Phrase: Burgemeester                  	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Burgermeester                 	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# Phrase: Ontfanger                     	match string: Ontfanger
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Ste                           	match string: Ste
# 	 ['person_reference', 'person_title']
# Pr. Duijrcant, Stadthouder tot Oosterwijck, houdende
#
# Phrase: Stadhouder                    	match string: Stadthouder
# 	 ['person_reference', 'person_profession']
# Jan van Groen Schipper van santen int Landt van Cleeff, hou„ dende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# mattheus Andresson, Willem Balfour Jacob Balfourt ende Jan Roberts alle Schippers van Schotlandt, houdende
#
# Phrase: schippers                     	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Burgermeesteren ende Schepenen der Stede en Ambachte Ter Reusen, houdende
#
# Phrase: Burgermeester                 	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeester                  	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Burgemeesteren                	match string: Burgermeesteren
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Adriana propheets, Weduwe wijlen Gerrit reijgers houdende
#
# Phrase: Weduwe                        	match string: Weduwe
# 	 ['person_reference', 'person_legal_status']
# Gerrard Kaldenbagh, Capi„ tem onder het regiment vanden Collonel Haesten, Guarnisoen, houdende
#
# Phrase: Collonel                      	match string: Collonel
# 	 ['person_reference', 'person_profession']
# Cornelis Caen, Griffier der Stadt Sluijs, houdende
#
# Phrase: Griffier                      	match string: Griffier
# 	 ['person_reference', 'person_profession']
# Claes Jansz Marinier onder de Compagnie vanden Capiteijn van Zull, gevaren hebbende
#
# Phrase: Capitein                      	match string: Capiteijn
# 	 ['person_reference', 'person_profession']
# Belchior Meudes franco woonende tot Amsterdam, houdende
#
# Maria Raires, woonende tot Amsterdam, houdende
#
# Thomas maijden, Henrij Hamson, Roelant Plat, Maurits van ressensteijn, Jan Paijn, ende Cornelis van alde„ werelt, alle Coopluijden ende Burgers tot Amsterdam, houdende
#
# Phrase: Burger                        	match string: Burgers
# 	 ['person_reference', 'person_citizen']
# Phrase: Burgers                       	match string: Burgers
# 	 ['person_reference', 'person_citizen']
# Gaspar Spechouwer, Coopman woonende tot Antwerven, versoeckende
#
# Phrase: Schouwer                      	match string: Spechouwer
# 	 ['person_reference', 'person_profession']
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']
# Manuel ende Anthonio Rodrigues, ende Jacob Perrera, Coopluijden tot Amsterdam, versoeckende
#
# ...
# Phrase: Prince                        	match string: Prince
# 	 ['person_reference', 'person_title']
# Johan ‛s herwouters ende Hendrick van Heteren, hare Ho:Mo: Camer, bewaerders, houdende
#
# Francois van Ommerick, woo„ nende tot Ronaen, houdende
#
# Pieter Gijsbrechts, houdende
#
# Frans van Heck, houdende
#
# Frans Jansz: Ipelaer borger der Stadt Alckmaer, versoeckende
#
# Dirck van Trechvelt, Schipper met sijn schip hier bevoorens geprest tot Dordrecht, om ten diensten vanden Lande te zeijlen nae Arnhem, versoeckende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Petrus Horrens Predicant op t' biedt in Vrieslandt, houdende
#
# Anna van Weede, suster vanden Commandant van Breda, houdende
#
# Phrase: Commandant                    	match string: Commandant
# 	 ['person_reference', 'person_profession']
# Jan ende Allert van Beecq, Inventeurs van Secrete Bruggens, houdende
#
# Burgermeester ende Schepenen ‛s Landts vanden Vrijen residerende tot Sluijs in Vlaenderen, relatijff tot haren brieff vanden 27e. September ende de requeste den 11en. November beijde lestleden op haren naem aen haer Ho:Mo: gepresenteert daer bij sij Supplianten vertoonen het gevaer daer in de opgesetenen vande Dorpen van St. Cruijs, d'Eede, Heijle, ende Waterlandt haer bevinden als connende het gewelt vanden Vijandt niet ontgaen, ende van den selven gedreijckt werdende niet branden ende blaecken, om hun te divingen tot het betalen van contributie; Waerop, gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voorschreve requeste copielijck gesonden sal werden, aen den heere Prince van Orange, met versoeck dat sijn Hoocheijt haer Ho:Mo: dien aengaende alsnoch ingevolge van derselver resolutie vanden 10en. November lestleden wille laten toecomen desselffs hoochwijse consideratien ende Advis ende sal deselve des niettemin gestelt werden in handen vande Heeren van Hogendorp, ende andere haer Ho:Mo: Gedeputeerden tot de Militaire saecken met ende nevens eenige heeren Gecommitteerden uijt den Raedt van State, bij haer E: selffs te nomineren om te visiteren, examineren, de retroacta nae te sien, ende van alles rapport te doen. Ontfangen een missive vanden Raedt van State, geschreven alhier inden Hage, den 13en. deses, houdende
# Phrase: Burgemeester                  	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Burgermeester                 	match string: Burgermeester
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepenen                    	match string: Schepenen
# 	 ['person_reference', 'person_profession']
# Phrase: Suppliants                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: St                            	match string: St
# 	 ['person_reference', 'person_title']
# Phrase: Princes                       	match string: Prince
# 	 ['person_reference', 'person_title']
# Phrase: Prince                        	match string: Prince
# 	 ['person_reference', 'person_title']
# Phrase: Heere                         	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Heeren                        	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Gedeputeerde                  	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gedeputeerden                 	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Militair                      	match string: Militaire
# 	 ['person_reference', 'person_profession']
# Phrase: Gecommitteerde                	match string: Gecommitteerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gecommitteerden               	match string: Gecommitteerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Ontfanger                     	match string: Ontfangen
# 	 ['person_reference', 'person_meeting_role']
# Adriaen vander Vleuten Landt nieter over de Stadt ende Meijerie van s'Hertogenbosch, ende daernevens eenige bijlage, versoeckende
#
# Jacob van Golsteijn tot Remonie, Colonnel ten dienste deser Landen, versoeckende
#
# Johannes van Goddesberge, Leijlmaecker tot Amsterdam, hou„ dende
#
# Johan Grove, Capiteijn van een vande nieuwe Compagnien ten dienste deser Landen, houdende
#
# Phrase: Capitein                      	match string: Capiteijn
# 	 ['person_reference', 'person_profession']
# Goswijn de Cock ende Jero,, minis Velters, cum socijs, Coop„ luijden tot Amsterdam, houdende
#
# Anthonij de Valck, Bailliu, der Stadt Hulst, houdende
#
# Phrase: Bailliuw                      	match string: Bailliu
# 	 ['person_reference', 'person_profession']
# albert van Ruijtenburgh dergeant Major van het regiment de Marine vandenheer van Wulenburgh, houdende
#
# Phrase: Major                         	match string: Major
# 	 ['person_reference', 'person_profession']
# Willem van vierssen, raadt inde raede van Brabandt residerende alhier inden Hage, versoeckende
#
# Jacob van Golsteijn, Heer van Reijnauwen, Colonnel ten dienste deser Landen, houdende
#
# Phrase: Heer                          	match string: Heer
# 	 ['person_reference', 'person_title']
# Pieter Verdijn, Goutsmith alhier inden Hage, houdende
#
# petronella Groenen, weduwe wijlen Dirck Coemans, ende adriaen Groenen, Vettewariers alhier inden hage, versoeckende
#
# Phrase: Vettewarier                   	match string: Vettewariers
# 	 ['person_reference', 'person_profession']
# Phrase: Vettewarierster               	match string: Vettewariers
# 	 ['person_reference', 'person_profession']
# Pieter Cornelisse Bolle van den Hoeff, Schipper op den Schepe genaemt de Jonatan ende Jacob Corver van Sardam, Schipper op den Schepe genaemt den Blaeuwen Arent Inhoudende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Jan Damels: van Rhijn, gewesen Commandeur op het Brandtschip ge„ naemt de Vrede, houdende
#
# Phrase: Commandeur                    	match string: Commandeur
# 	 ['person_reference', 'person_profession']
# Reijnier Egroas ende consorten, Inwoonders van ‛s Hertogenbosch, henluijden generende met Vetweijden van Brabantsche Beesten, versoec„ kende om geallegeerde redenen, dat hare Ho:Mo: gelieven de Suppli„ anten den uijtvoer van drie handert Brabantsche Beesten, soo koeijen, vaerssen als Ossen te consenteren, onder betalinge van het recht van Licent ende veijlgelt, stellende cautie met suffisante attestatie der Stadts Taeffeliers van Lier te vertoonen, deselve aldaer ter Stapelrecht aengebracht ende vercocht te sijn: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat int voors versoeck niet can werden getreden.
#
# Phrase: Inwoonder                     	match string: Inwoonders
# 	 ['person_reference', 'person_citizen']
# Phrase: Inwoonders                    	match string: Inwoonders
# 	 ['person_reference', 'person_citizen']
# Phrase: Supplianten                   	match string: Suppli„ anten
# 	 ['person_reference', 'person_meeting_role']
# Frederico van Ewijck, Con„ sul tot Genua, versoeckende
#
# Sara L‛Empereur weduwe van wijlen den Raestheer du Tour in sijn leven raedt ordinaris inden raet van Brabant, alhier inden Hage, versoeckende
#
# Willem Whijt Schipper van den Schepe genaemt de margriet, ende Nicolaes Besont Schipper vanden Schepe de providentie alias St. Joris, Schippers soo uijt Engelant als Schotlandt, jegenwoordigh leg, gende ter Veere, ende middelburgh, houdende
#
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schipper
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepe
# 	 ['person_reference', 'person_profession']
# Phrase: St                            	match string: St
# 	 ['person_reference', 'person_title']
# Phrase: schippers                     	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Dionisius Godefroij, ver„ soeckende
#
# Isaacq van Hommerich Cock, man tot Amsterdam, houdende
#
# Elias de Preto, als Erffge„ naem van wijlen Pincente Rodrigues Villa Real, versoeckende
#
# Joan ende Rogier van Weert, Coopluijden tot Amsterdam, houdende
#
# Cornelia vander Nisse, Vrouwe van Cruijningen ende Saemslagh, inhoudende
#
# Phrase: Vrouwe                        	match string: Vrouwe
# 	 ['person_reference', 'person_title']
# Philips van Hoven, te kennen gevende, dat hij Suppliant bij haer Ho:Mo: sijnde aengestelt tot Contrerolleur vande Schepen ende Schippers int Leger dienende
#
# Phrase: Suppliants                    	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Suppliant
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Contrarolleur                 	match string: Contrerolleur
# 	 ['person_reference', 'person_profession']
# Phrase: Scheepen                      	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Phrase: Schepen                       	match string: Schepen
# 	 ['person_reference', 'person_profession']
# Phrase: schippers                     	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Phrase: Schipper                      	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Phrase: Schippers                     	match string: Schippers
# 	 ['person_reference', 'person_profession']
# Isaac fouquier en Anthonij Rijland Coopluijden tot Amsterdam, als Gemachtichde vande Neder, lantsche natie tot Aleppo, versoec„ kende dispositie op hare voorgaende requeste aen hare Ho:Mo: den lesten December 1671. gepresenteert, tende„ zende ten eijnde de directeurs vanden Levantschen handel tot Amsterdam mochten werden geordonneert aende Supplianten binnen Aleppo te voldoen de somme van achtien duijsent acht hondert vier aennes ofte Leeuwendaelders haer bij Sententie van hare Ho:Mo: van date seven„ thienden februarij 1671. geadjudi„ ceert, met den interest vandien tot de effectuele voldoeninge toe ende dat tot dien eijnde de gemelte Directeurs, ende oock de Supplianten bij hare Ho:Mo: mochte werden aengeschreven, om binnen corte dagen te compareren voor de Heeren haer Ho:Mo: Gedeputeerden tot de saecken vande Zee, om parthijen te hooren, ende van hare ondervindinge rapport te doen: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voorschreve Requeste gestelt sal werden in handen vande Heeren vander Graeff, ende andere hare Ho:Mo: Gedeputeerden tot de saecken vande Zee, om te visi„ teren, examineren, de retroacta naer te sien, ende van alles rapport te doen.
# Phrase: Suppliants                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Directeur                     	match string: Directeurs
# 	 ['person_reference', 'person_profession']
# Phrase: Directeuren                   	match string: Directeurs
# 	 ['person_reference', 'person_profession']
# Phrase: Suppliants                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliantes                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliant                     	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Suppliante                    	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Supplianten                   	match string: Supplianten
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Heere                         	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Heeren                        	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Gedeputeerde                  	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gedeputeerden                 	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Heere                         	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Heeren                        	match string: Heeren
# 	 ['person_reference', 'person_title']
# Phrase: Graef                         	match string: Graeff
# 	 ['person_reference', 'person_title']
# Phrase: Gedeputeerde                  	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Phrase: Gedeputeerden                 	match string: Gedeputeerden
# 	 ['person_reference', 'person_meeting_role']
# Johan Nieumeijer gewesene Capi„ teijn ten dienste vanden Coningh van Sweeden, versoeckende
#
# Phrase: Koningh                       	match string: Coningh
# 	 ['person_reference', 'person_profession']
# Seven van Vincelaer, Or mathijs cheren, ende Elisabeth van Vincelaer, echte luijden mitsgaders Derck de beree, gewesene Majoor der Stadt Arnhem, ende desselffs suster Theodora de vree, ende Derck van Wijngaerden te samen Burgeren en ingesetenen van Arnhem, inhoudende
#
# Phrase: Major                         	match string: Majoor
# 	 ['person_reference', 'person_profession']
# Pieter Biscop Commis Generael vande Convoijen ende Licenten, houdende
#
# Jan Daniel Portz voor desen geweest sijnde in dienst van desen Staet ende naderhandt in die vanden Heere Churfurst Phaltz, inhoudende
#
# Phrase: Heer                          	match string: Heere
# 	 ['person_reference', 'person_title']
# Phrase: Heere                         	match string: Heere
# 	 ['person_reference', 'person_title']
# Phrase: Churfurst                     	match string: Churfurst
# 	 ['person_reference', 'person_title']
# Mactum Posthoeck, Coopman tot Rotterdam, houdende
#
# Phrase: Koopman                       	match string: Coopman
# 	 ['person_reference', 'person_profession']

# %% [markdown]
# **Note**: this is a very coarse analysis, containing plenty of mistakes. Check output of especially resolutions where the first paragraph has no proposition verb, because then the entire paragraph is used and many person references will not be about the proposer.

# %%
for person_ref, freq in person_ref_freq.most_common():
    print(f"{person_ref: <30}{freq: >5}")
# Out:
# Schipper                         31
# Schippers                        29
# Koopman                          22
# Schepen                          18
# Supplianten                      18
# Suppliants                       16
# Suppliantes                      16
# Suppliante                       16
# Suppliant                        16
# Scheepenen                       15
# Heer                             14
# Burgemeester                     12
# Heere                            11
# Bailliuw                         11
# Borger                            9
# Borgers                           9
# Burgermeester                     9
# Mr                                8
# Scheepen                          7
# Capitein                          7
# Burger                            7
# Burgers                           7
# Burgemeesteren                    6
# Griffier                          6
# Commissaris                       6
# Gedeputeerde                      6
# Gedeputeerden                     6
# Lieutenant                        6
# Heeren                            6
# Vrouwe                            5
# Weduwe                            5
# schippers                         5
# Sijne                             5
# Ontfanger                         4
# Major                             3
# Secretaris                        3
# Grave                             3
# Consuls                           3
# Consul                            3
# Contrarolleur                     3
# Ste                               3
# Schout                            3
# Meester                           3
# Inwoonder                         3
# Inwoonders                        3
# Procureur                         3
# Graef                             3
# Sekretaris                        2
# Koningh                           2
# Extraordinaris                    2
# Batmeester                        2
# Poorter                           2
# Resident                          2
# Dochter                           2
# Collonel                          2
# Commandeur                        2
# Gecommitteerde                    2
# Gecommitteerden                   2
# Agent                             2
# Eisscher                          2
# Visscher                          2
# Stadhouder                        2
# Wachter                           2
# Princes                           2
# Prince                            2
# St                                2
# Licentiaat                        1
# Bode                              1
# Baron                             1
# Pensionaris                       1
# Ingezetenen                       1
# Ingeseetenen                      1
# Dochters                          1
# Armmeester                        1
# Kolonel                           1
# Hoog                              1
# Impetrant                         1
# Commissarissen                    1
# Kapitein                          1
# Schouwer                          1
# Ridder                            1
# Comptoir                          1
# Praesident                        1
# Commandant                        1
# Militair                          1
# Vettewarier                       1
# Vettewarierster                   1
# Directeur                         1
# Directeuren                       1
# Churfurst                         1

# %%
for person_ref_type, freq in person_ref_type_freq.most_common():
    print(f"{person_ref_type: <30}{freq: >5}")
# Out:
# person_reference                119
# person_profession                75
# person_title                     17
# person_meeting_role              12
# person_citizen                   12
# person_family                     2
# person_legal_status               1

# %%
for ref in person_role:
    if ref == "person_reference":
        continue
    for role, freq in person_role[ref].most_common():
        print(ref, role, freq)
# Out:
# person_profession Schipper 31
# person_profession Schippers 29
# person_profession Koopman 22
# person_profession Schepen 18
# person_profession Scheepenen 15
# person_profession Burgemeester 12
# person_profession Bailliuw 11
# person_profession Burgermeester 9
# person_profession Scheepen 7
# person_profession Capitein 7
# person_profession Burgemeesteren 6
# person_profession Griffier 6
# person_profession Commissaris 6
# person_profession Lieutenant 6
# person_profession schippers 5
# person_profession Major 3
# person_profession Secretaris 3
# person_profession Consuls 3
# person_profession Consul 3
# person_profession Contrarolleur 3
# person_profession Schout 3
# person_profession Meester 3
# person_profession Procureur 3
# person_profession Sekretaris 2
# person_profession Koningh 2
# person_profession Batmeester 2
# person_profession Poorter 2
# person_profession Collonel 2
# person_profession Commandeur 2
# person_profession Agent 2
# person_profession Visscher 2
# person_profession Stadhouder 2
# person_profession Wachter 2
# person_profession Licentiaat 1
# person_profession Bode 1
# person_profession Pensionaris 1
# person_profession Armmeester 1
# person_profession Kolonel 1
# person_profession Commissarissen 1
# person_profession Kapitein 1
# person_profession Schouwer 1
# person_profession Ridder 1
# person_profession Comptoir 1
# person_profession Praesident 1
# person_profession Commandant 1
# person_profession Militair 1
# person_profession Vettewarier 1
# person_profession Vettewarierster 1
# person_profession Directeur 1
# person_profession Directeuren 1
# person_title Heer 14
# person_title Heere 11
# person_title Mr 8
# person_title Heeren 6
# person_title Vrouwe 5
# person_title Sijne 5
# person_title Grave 3
# person_title Ste 3
# person_title Graef 3
# person_title Extraordinaris 2
# person_title Princes 2
# person_title Prince 2
# person_title St 2
# person_title Baron 1
# person_title Hoog 1
# person_title Churfurst 1
# person_meeting_role Supplianten 18
# person_meeting_role Suppliants 16
# person_meeting_role Suppliantes 16
# person_meeting_role Suppliante 16
# person_meeting_role Suppliant 16
# person_meeting_role Gedeputeerde 6
# person_meeting_role Gedeputeerden 6
# person_meeting_role Ontfanger 4
# person_meeting_role Gecommitteerde 2
# person_meeting_role Gecommitteerden 2
# person_meeting_role Eisscher 2
# person_meeting_role Impetrant 1
# person_citizen Borger 9
# person_citizen Borgers 9
# person_citizen Burger 7
# person_citizen Burgers 7
# person_citizen Inwoonder 3
# person_citizen Inwoonders 3
# person_citizen Resident 2
# person_citizen Ingezetenen 1
# person_citizen Ingeseetenen 1
# person_legal_status Weduwe 5
# person_family Dochter 2
# person_family Dochters 1

# %%
import pandas as pd

df = pd.DataFrame(obs)

# %%
df[df.res.str.contains("session-1672-10-29-num-1")]
# Out:
#                                        res      term              label
# 666  session-1672-10-29-num-1-resolution-3  Scheepen   person_reference
# 667  session-1672-10-29-num-1-resolution-3  Scheepen  person_profession
# 668  session-1672-10-29-num-1-resolution-3   Schepen   person_reference
# 669  session-1672-10-29-num-1-resolution-3   Schepen  person_profession
# 670  session-1672-10-29-num-1-resolution-3  Scheepen   person_reference
# 671  session-1672-10-29-num-1-resolution-3  Scheepen  person_profession
# 672  session-1672-10-29-num-1-resolution-3   Schepen   person_reference
# 673  session-1672-10-29-num-1-resolution-3   Schepen  person_profession
