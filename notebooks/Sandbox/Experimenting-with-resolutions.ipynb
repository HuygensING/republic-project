# %% [markdown]
# ## Experimentation Notebook
#
# This notebook is part of the sandbox and is intended to experiment and play around with the REPUBLIC elasticsearch functionalities.

# %%
# This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
repo_name = 'republic-project'
repo_dir = os.path.split(os.getcwd())[0].split(repo_name)[0] + repo_name
print(repo_dir)
if repo_dir not in sys.path:
    sys.path.append(repo_dir)
# Out:
# /Users/marijnkoolen/Code/Huygens/republic-project

# %% [markdown]
# ## Initialise Republic Elasticsearch Instance
#
# This creates a RepublicElasticsearch object that contains an elasticsearch instance for the Republic CAF indexes, as well as a range of retrieval functions.
#
# Check the [README](https://github.com/HuygensING/republic-project#readme) for configuration details that should be placed in `settings.py`.

# %%
from republic.elastic.republic_elasticsearch import initialize_es

rep_es = initialize_es(host_type='external', timeout=60)
rep_es.config['resolutions_index'] = 'resolutions_new'

# %% [markdown]
# ## Keyword in Context
#
# A simple way to start exploring is with the `keyword_in_context` function. It takes words or phrases as input and shows a number of hits with surrounding context in the resolutions.
#
# The `keyword_in_context` function returns `hit`s, which are dictionaries with the search `term`, the `pre` and `post` contextual words, a formatted `context`, as well as the `para_id` and `resolution_id` and `resolution_offset` and `para_offset`.

# %%
# use single word or multi-word phrase
for hit in rep_es.keyword_in_context("tyden", num_hits=20, context_size=5):
    print(hit["context"])
# Out:
#                         gevalle sijn Persoon ten allen tyden te sullen sisteren, daer voor
#                      belofte en borghtochte van tallen tyden sijn Persoon, soo het nodigh
#                              cautie van sigh ten allen tyden weder te sullen sisteren als
#                  Onderdaanen in deese conjuncturen van tyden niet ten hooghite noodsaackelijck soude
#              als hooghstdeselve na omstandigheeden van tyden en saatken sal vinden te
#                             haar Hoog Mog., in voorige tyden by diergelyke ceremonien, gewoon waren
#                                  wel nu als in voorige tyden het gewoole douceur van zes
#                           volgens de gewoonte van alle tyden, maendelijck waren betaeldt geweest van
#                             veel minder als in voorige tyden gereguleert zynde, veele van haer
#               Convoyen en Licenten, sedert immemoriale tyden genoten. Waer op gedelibereert zijnde
#                    by de tegenwoordige constitutie van tyden, in het voorschreve versoeck niet
#                     ses loopende maanden in differente tyden , conform gemelde Resolutie, is het
#                        jaar, ses maanden in differente tyden, uyt sijn voorschreve Commandement te
#                              Mogende haar als van oude tyden met hondert Carolie guldens gelieven
#                           wederom als in de voorgaande tyden, boven anderen uitgemunt. WAAR op
#                      nogh prejudicieeren, om ten allen tyden in haar Hoogh Mogende dienst
#                       sal prejudicieeren, om ten allen tyden in haar Hoogh Mogende dienst
#                     Tournesis, houdende , dat van alle tyden de Huysen, staende omtrent het
#                 in dese tegenwoordige conjuncturen van tyden, om gedachten te laten gaen
#                         anders, oock smet dese Oorlogs-tyden, haer Hoogh Mogende merckelijck meerder
#                                         als in voorige tyden quamen te Vergaderen, dagelijks met
#                        moogen doen, sullende ten allen tyden gereed weesen, om wanneer den
#                       absenteeren, mits sigh ten allen tyden gereed houdende om op de
#          Supplianten , vermits de langhdurige Oorloghs-tyden merckelijcke penningen ten achteren waren
#                            niet alleen op de ordinaris tyden, maar oock op extraordinaris uuren
#                         stellen op soodanige daagen en tyden in de weecke, als na
#                          zynde een belastinge van oude tyden geleght op de Scheepen, van
#                      de Hollandsche Navigatie in deese tyden met behoorlijck Convoy werde gedeckt
#                                 Winter of ook m andere tyden by Helgoland voornoemd Nederlandsche Scheepen
#                            deesen Staat, van alle oude tyden af waaren geweest bevoeght, en
#                          haare Patenten op de bepaalde tyden van daar na haare respective
#                                 sal doen, om ten allen tyden gereed te zyn; om sigh

# %% [markdown]
# The `keyword_in_context` function also has several optional arguments to control the size of the context window (`context_size`, default is 3 words before and after), the number of hits (`num_hits`, default is 10) and query filters to constrain the search space (`filters`, which are added to the query).
#
# **Note**: the `num_hits` argument controls the number of _resolutions_ that are retrieved. Within a resolution, the search keyword may appear multiple times. A context is created for each occurrence of the search keyword, so the number returned of contexts can be (and typically is) higher than the number of hits.

# %%
# use context_size to get fewer or more surrounding words as context
for hit in rep_es.keyword_in_context("secreete", context_size=5):
    print(hit["context"])
# Out:
#                           gedaan op haar Hoogh Mogende secreete commissoriaale Resolutie van den vierden
#                          ontfangen, en gemeld in sijne secreete Mislive van den seven en
#                        besoignes by haar Hoogh Mogende secreete Resolutie van den vierden December
#                         voldoeninge van haar Hoog Mog. secreete Resolutie en Aanschryving van den
#                              in haar Hoog Mog. gemelde secreete - Resolutie van den 12 deeser
#                      nakoominge van haar Hoogh Mogende secreete Resolutie en Aanschryvens van den
#                           vervat in haar Hoogh Mogende secreete Resolutie van den sestienden deeser
#                        ontfangst van haar Hoog Mogende secreete Resolutie van den dertigsten der
#                              in gevolge haar Hoog Mog. secreete Resolutie van den 25 deezer
#                         kraghte van haar Hoogh Mogende secreete Resolutie van den vier en
#                Suppliantes Man waaren uytgegeeven voor secreete diensten ten behoeve van den
#                      ontfanghst van haar Hoogh Mogende secreete Resolutie genoomen op sijn Brief
#                      ontfanghst van haar Hoogh Mogende secreete Missive en Resolutie van den
#                              in gevolge haar Hoog Mog. secreete Resolutie van den 3 November
#                    en Gavino, breeder in boovengemelde secreete Resolutie vermeld; versoekende den Suppliant
#                             Acte van ratificatie in de secreete Casse sal werden geseponeert

# %%
for hit in rep_es.keyword_in_context("periculeuse", context_size=5):
    # First, show paragraph id (which contains session date)
    print(hit["resolution_id"])
    # Second, show the keyword in context
    print(hit["context"])
    # Finally, add newline for readability
    print()
# Out:
# session-1709-02-06-num-1-resolution-10
#                  tot Scheveninge, dolerende over sijne periculeuse ende kostelijke reyse, met een
#
# session-1709-02-06-num-1-resolution-10
#                       Stuyrman Jochem Joppe, voor sijn periculeuse reyse ende schade aen de
#
# session-1720-01-20-num-1-resolution-4
#                             douceur voor de sware ende periculeuse reyse die hy gedaan heeft
#
# session-1733-07-11-num-1-resolution-11
#                           door niet alleen buyten alle periculeuse gevaaren werden gestelt, maar oock
#
# session-1737-12-27-num-1-resolution-16
#                                 van door een swaare en periculeuse sieckte te worden overvallen, in
#
# session-1672-11-21-num-1-resolution-25
#                        Schoonhoven aen eene sware ende periculeuse sieckte het beddehoudende. om hem
#
# session-1711-09-30-num-1-resolution-9
#                       werden, om sulcke moeyelijcke en periculeuse reyse te doen of te
#
# session-1707-11-17-num-1-resolution-14
#                       duyrte veroorsaeckt, soo door de periculeuse - staet van saecken, ende door
#
# session-1787-06-08-num-1-resolution-4
#                                niet alleen by de zelve periculeuse Expeditie niets had kunnen profiteren
#
# session-1780-03-07-num-1-resolution-6
#                         sig deese allesints lastige en periculeuse Commissie wel wilde laten gevallen
#
# session-1794-08-05-num-1-resolution-10
#                         dat alle Bondgenooten in deeze periculeuse ogenblikken elkanderen met alle magt

# %%
# use num_hits to get fewer or more results
for hit in rep_es.keyword_in_context("pestilentie", context_size=500, num_hits=20):
    print(hit["resolution_id"])
    print(hit["context"])
    print()
# Out:
# session-1739-01-07-num-1-resolution-7
# DE Heeren Gedepuleerden van de Provintie van Gelderland, hebben ter Vergaderinge voorgedraagen, en in bedencken gestelt, of niet in het begin van dit aangevangen jaar; behoort te werden uytgeschreven een generaale Danck-, Vasten Beededagh , om God almaghtigh te dancken voor de continuatie van de vreede, en voor alle sijne weldaaden tot hier toe aan den Staat beweesen, en te bidden om sijnen aanhoudenden zeegen over den Staat, ten eynde deselve van Oorlogen, Pestilentie en andere plaagen bevryd mooge blyven. WAAR op gedelibereert zynde, hebben de Heeren Gedeputeerden van de Provintien van Holland en Westvriesland, van Zeeland, van Vriesland, van Overyssel, en van Stad en Lande aangenoomen haar daar op naader te sullen verklaaren
#
# session-1711-09-04-num-1-resolution-16
# DE ondergeschreven Resident van de Loffelijcke Hansche Steden, geeft sich de eere, op expresse ordre van den Senaet der Stadt Dantzich, aen U Hoogh Mogende met alle behoorlijk respect voor te dragen, dat hare goede commercierende Burgers, haer van tydt tot tydt met supplicatien ende sollicitatien komen klaghtigh en moeyelijck vallen, ten eynde de selve by U Hoogh Mogende nochmael moghte intercederen, ende versoecken dat hare Wolle ende andere Koopmanschappen, die sedert soo lange tydt in Texel tot hare grootte schade gearresteert zyn geweest, op suspicie van besmettelijckheydt ende pestilentiale lught, eenmael moghten werden ontslagen, en haer gepermitteert die te mogen verkoopen in dese Landen. Dat gemelde Magistraet al voor meer als een jaer, by Missive van den seventienden Junii seventien hondert tien aen U Hoogh Mogende in de alderbeweeghlijckste ende krachtighste termen soodanigh versoeck gedaen, en dier nevens gevoeght heeft gehadt seecker klagelijcke Requeste by een groot getal harer Ingezetenen ende Kooplieden aen haer gepresenteert, vertoonende daer by, dat de voorschreve Wolle, selfs voor die tijdt dat Godt de Heere hare Stadt met de Pestilentie heeft gelieven te besoecken, was afgescheept geweest, ende oversulcks buyten alle na bedencken van contagie was. Dat U Hoogh Mogende evenwel hadden gelieven goedt te vinden, de voorschreve Missive met de Bylage , by Resolutie van den dertighsten Junii seventien hondert tien, te senden aen de Admiraliteyt tot Amsterdam, om des selfs advis daer op te hebben. Dat sedert die tydt tot nu toe, het selve niet is ingekomen, voor soo veel den Ondergeschreven bewust
elibereert zynde op een Missive van den selven Heer, geschreeven te St. Petersburg den 24 der voorleeden maand, en den 14 deeser ter Vergaderinge ingekoomen, houdende, dat het met de Pestilentiaale Siekte te Mosco van dag tor dag scheen erger te worden, immers dat men wilde dat 'er rapporten souden zyn, die melden dat 'er daagen waaren waar op 'er over de vier honderd Menschen daar aan storven; dat sommige selfs pretendeerden dat die Siekte sig niet alleen na de kant van Jaroslaw, alwaar geheele Dorpen daar aan waaren gestorven, maar ook tot na Twer sig soude hebben uitgebreid, dog waar omtrent niets seekers was te melden. Dat hy inmiddels ter deeser geleegentheid hadde geoordeeld om in het uitgeeven der Certificaten, door de Kooplieden van hem gerequireert over Goederen met liollandsche Scheepen van daar verscheept wordende, met alle mogelyke voorfigtigheid te werk te gaan, en dienvolgende 'er geene verleende als op vertooning van de ncodige Attestatien van Gouverneur, Woywood of Magistraat, als meede van de Directeuren en Opsienders der Quarantaine Huysen, waar uit bleek dat de Goederen, insonderheid Pelteryen, Veeren, Hennip en allerhande andere de besmetting vatbaar zynde Waaren, waar op Certificaat van hem gevraagt wierd, van en over geen Plaats derwaards waaren gebragt, daar eenigerhande besmetting of pestilentie geweest was of tegenwoordig was, en dat deselve Goederen by haar transport de vastgestelde quarantaines uitgestaan hadden, waar by den Requirant dan verder onder eede moeste verklaaren, dat deselve Goederen, het zy voor een gedeelte het zy voor het geheel, werkelyk en met der daad waaren de soodanige die in voorsz door hem gerequireert en door haar geproduceert wordende Attestatie gespecificeert stonden, en dat daar onder geene waaren die van en over besmette Plaatsen, sonder de quarantaines te hebben gehouden, ter sluik door omweegen derwaards waaren gebragt, waar by dan nog tot meerder seekerheid soo veel doenlyk was deede agt geeven en vigileeren, dat deselve Goederen alvoorens op den Tol aldaar behoorlyk aangegeeven, gevisiteert, gebraakt, omgepakt en gestempelt wierden; verhoopende, dat Baar Hoog Mog. sijne gemelde precautien met der selver approbatie souden gelieven te vereeren; en versoekende, dewyl hy sig wat verleegen vond weegens de parthye die hy te kiesen had in geval de Siekte van Mosco derwaards mogt koomen te naderen, haar Hoog Mog. ordres hoe sig in soodanig gev ...

# %%
# use filters to contrain the search space:
# selecting resolutions by year
filters = [
    {"match": {"metadata.session_year": 1672}}
]

for hit in rep_es.keyword_in_context("periculeuse", filters=filters):
    print(hit["para_id"])
    print(hit["context"])
# Out:
# session-1672-11-21-num-1-para-56
#                    eene sware ende periculeuse sieckte het beddehoudende
# session-1672-02-18-num-1-para-10
#            doch voornamentlijck in periculeuse tijden in goede
# session-1672-01-04-num-1-para-63
#             doch voornamentlick in periculeuse tijden, in goede
# session-1672-02-24-num-1-para-13
#             doch voornamentlick in periculeuse tijden in goede

# %%
# use filters to contrain the search space:
# selecting resolutions by date range
filters = [
    {"range": {"metadata.session_date": {"gte": "1672-04-01", "lte": "1672-08-01"}}}
]

for hit in rep_es.keyword_in_context("Vloot", filters=filters):
    print(hit["para_id"], '\n')
    print(hit["context"], '\n')
# Out:
# session-1672-06-16-num-1-para-24
#
#                  dat de Smirnasche Vloot door d'Engelschen
#
# session-1672-05-31-num-1-para-92
#
#                       sigh naer de Vloot te vervoegen: Waerop
#
# session-1672-05-24-num-1-para-20
#
#            gedaen, opde Smirnasche Vloot is gear„ resteert
#
# session-1672-04-02-num-1-para-50
#
#                        Ho:Mo: inde vloot vanden Staat op
#
# session-1672-07-27-num-1-para-83
#
#                    ont„ houden van Vloot der Vijanden van
#
# session-1672-05-31-num-1-para-36
#
#                  dat de Smirnasche Vloot, door d'Engelschen
#
# session-1672-04-06-num-1-para-74
#
#   gevolmachtichde opde voorschreve vloot commanderen sal den

# %%
# use filters to contrain the search space:
# selecting resolutions by date range
filters = [
    {"range": {"metadata.session_date": {"gte": "1672-01-01", "lte": "1672-12-31"}}}
]


phrases = [
    "Marie van Sisburgh",
    "Nicolaes Gouverneur",
    "Wouter van Swieten",
    "Jan van Gulpen",
    "Seghwaert"
]

for phrase in phrases:
    for hit in rep_es.keyword_in_context(phrase, filters=filters, context_size=200):
        print(hit["para_id"], '\n')
        print(hit["context"], '\n')
# Out:
# session-1672-02-06-num-1-para-16
#
# Opde requeste van Marie van Sisburgh, weduwe wijlen Johan Pels, houdende, dat haer Ho:Mo: in consideratie dat den voornoemden haren man met het schip vanden neutenant admirael den heere van Wassenaer, in Zee was opgesprongen, aende Suppliante in Januarij 1671. hadden toegeleijt de somme van hondert twintigh gulden, ende versoeckende dat deselve somme van hondert twintich gulden, aen haer bij continuatie wederom tot haer onderhout in haren hoogen onderdan van drie en t'seventightaren, soude mogen werden toegeleijt; Is naer voergaende deliberatie goetgevonden ende verstaen, dat deselve requeste gestelt sal werden in handen vande heeren Huijgens, ende andere haer Ho:Mo: Gedeputeerdens tot de saecken vande Griffie, om te visiteren, examineren, ende daervan rapport te doen
#
# session-1672-02-17-num-1-para-10
#
# De requeste van Nicolaes Gouverneur Coopman tot Amsterdam, versoeckende dat alsnoch favorabelijck soude mogen werden gedisponeert op sijn vorige requeste den achtsten September lestleden, aen haer Ho: Mo: gepresenteert, tenderende ten einde hij Suppliandt soude mogen inbrengen Bevers, hier te Lande, sonder daervan te betalen de belastinge van vijftigh per cento,, bij het placaet vanden tweeden Januarij 1671. opde fransche manufacturen gestelt, midtsgaders opde advijsen vande respective Collegien ter admiraliteijt opt voorschreve subject alhier ter vergaderinge successivelijck ingecomen; Is naer voorgaende deliberatie goetgevonden ende verstaen, dat gestelt sal werden in handen vande heeren Schimmelpenningh, ende andere hare Ho: Mo: Gedeputeerden tot de precise executie ende naercominge van het voorschreve placaet, om te visiteren, examineren, de voorschreve advijsen vande respective Collegien ter admiraliteijt naer te sien, ende van alles rapport te doen
#
# session-1672-05-07-num-1-para-14
#
# Is ter Vergaderinge gelesen de requeste van Wouter van Swieten, woonende tot Seghwaert, houdende dat hij Suppliant heeft gepractiseert seecker middel, tot voorcominge vande desseijnen, invasien, ende pro,, gressen vanden Coningh van Vranck„ rijck ende andere Vijanden van desen Staet, in ende op dese Vereenichde Nederlanden, ende de onderhoorige Landtschappen vandien, alsmede eenige nootsaeckelickheden, tot affweeringe vanden Coningh van Engelant, Ende dat hij daervan een concept gemaeckt hebbende, presen„ te ende daervan aen haer Ho:Mo: openinge te doen: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voorschre
# %%
filters = [
    {"match": {"metadata.session_year": 1672}}
]

# using a larger context size
for hit in rep_es.keyword_in_context("Vlooten", filters=filters, context_size=20):
    print(hit["resolution_id"], hit["resolution_offset"], '\n')
    print(hit["context"], '\n')
# Out:
# session-1672-05-31-num-1-resolution-1 0
#
# Ontfangen een missive vanden Heer Cornelis de Witt, hare Ho:Mo: Gedepden. ende Gevolmachtichde op 's Lants Vlooten in de jegenwoordige expeditie ter Zee, Jehan ‛s Lants Schip de seven Provincien, laverende voor Walcheren, Brugge & Oost van haer
#
# session-1672-09-01-num-1-resolution-1 583
#
# advertentie ten spoedichsten kennisse sal werden gegeven aenden Lieutenant Admirael de Ruijter om daerop behoorlicke reflexie te nemen, de Vijantlicke vlooten te doen observeren, ingevolge van hare Ho:Mo: resolutie vanden seven„ thienden Augusti laestleden, de desseijnen vande Vijanden vanden Staet
#
# session-1672-09-01-num-1-resolution-1 1366
#
# Welderen, ende Lieutenant Admirael de Ruijter sal werden, aengeschreven, dat deselve haer soo veel mogelick op de voor„ schreve Vijantlicke Vlooten sullen informeren, haer Ho:Mo: sonder eenich tijt versuijm, adverteren vande condtschappen die haer vande voornoemde Vijantlicke Vlooten souden mogen
#
# session-1672-07-15-num-1-resolution-2 29
#
# Commis„ saris Knijff, geschreven op den Helder den 14en. deses, houdende advertentie, ende onder anderen, dat die Engelsche ende fransche Vlooten aldaer voor het Landt waren gesien haer Cours Noortwaerts aen settende: Waerop gedelibereert sijnde, Is goetge„ vonden ende verstaen, dat
#
# session-1672-09-06-num-1-resolution-6 457
#
# alles rapport te doen. Ende dat Extract, uijt de voornoemde Missive, voor soo veel die spreeckt vande fransche ende Engelsche Vlooten, gesonden sal werden aenden Lieutenant Admirael de Ruijter, om te strecken, tot sijn narichtinge
#
# session-1672-06-03-num-1-resolution-4 179
#
# Jan van Gede, hebbende gecommandeert het Brandt schip de Haes, ende inde jonghste Bataille tegens de fransche ende Engelsche Scheeps Vlooten gebrandt, & geruineert het schip de Catrine, gemon„ teert met ontrent 76a 80. stucken, ende alsoo pretenderende de promie daertoe gestelt
#
# session-1672-08-06-num-1-resolution-7 603
#
# aen den voorn. Knijff sal werden geres„ cribeert, dat hij de voors: galiots sal gebruijcken tot het ontdecken van Vijantlijcke Vlooten voor ende ontrent d'Eemse voornt
#
# session-1672-11-03-num-1-resolution-2 135
#
# Commandeur ende Capiteijn Jacob van Neeuwen, ende Sloeps gasten, te kennen gevende, dat sijn luijden in de bataille met de Vlooten vande Coningen van Vranckrijck ende Engelandt, den Vijandt een Capi„ talen Brander hadden affhandich ge,, maeckt, versochten derhalven, dat haer
#
# session-1672-09-05-num-1-resolution-1 558
#
# Petten te zeijlen ende te vernemen naer de contenantie vande Vijant„ licke Vlooten, ende de sterckten vandien, deselve was tenselven dage weder binnen gecomen, met bericht, dat ter gedestineerde
#
# session-1672-09-05-num-1-resolution-1 1049
#
# Vuantlicke Vlooten, welcke vloote lagh voor Borrelton, ende sterck, soo van sijn genomen prijsen sijnde twee int getal, ende beijde Coolhaelders (waer
#
# session-1672-09-09-num-1-resolution-8 75
#
# bij Bodegrave den negenden deses, houdende in effect, dat sijn Hoocheijt geconsidereert hebbende de advertentie aengaende d'Engelsche ende fransche Vlooten, ende het dessein dat deselve soude mogen hebben op Wascheren, vervat in haer Ho: Mo: resolutie vanden achtsten deses, met
#
# session-1672-09-09-num-1-resolution-8 354
#
# anders conde oordeelen, dewijle het gerucht van dat de voor„ schreve Vlooten souden wesen gesien voor ende ontrent Texel, onvaer bevonden wert, Dan dat voor den dienst vanden Lande best soude sijn
#
# session-1672-07-12-num-1-resolution-18 60
#
# Rhijn, gewesen Commandeur op het Brandtschip ge„ naemt de Vrede, houdende dat hij Suppliant in het laetste gevecht tusschen de Vlooten vande Coningen van Vranck„ rijck, ende van groot Brittannien tegens de Vloote van desen Staet in het heerste van het

# %% [markdown]
# ## Retrieving Resolutions
#
# The `rep_es` object has a range of functions to retrieve `resolution` objects.
#
# You can find all available properties and methods of `resolution` objects in `republic_document_model.py`: i.e. in the
# [Resolution](https://github.com/HuygensING/republic-project/blob/bb4cdad7b4cb9fb71378d0dde000fe7725ceb45e/republic/model/republic_document_model.py#L392) class, which inherits several properties and methods from the [ResolutionElementDoc](https://github.com/HuygensING/republic-project/blob/bb4cdad7b4cb9fb71378d0dde000fe7725ceb45e/republic/model/republic_document_model.py#L158)

# %%
resolutions = rep_es.retrieve_resolutions_by_session_date("1672-02-12")
for res in resolutions:
    print(res.session_date.isoformat(), res.id, res.metadata['index_timestamp'])
# Out:
# 1672-02-12 session-1672-02-12-num-1-resolution-15 2022-03-29T15:39:04.587225
# 1672-02-12 session-1672-02-12-num-1-attendance_list 2022-03-29T13:12:35.786221
# 1672-02-12 session-1672-02-12-num-1-resolution-1 2022-03-29T13:12:35.914799
# 1672-02-12 session-1672-02-12-num-1-resolution-2 2022-03-29T13:12:36.879396
# 1672-02-12 session-1672-02-12-num-1-resolution-3 2022-03-29T13:12:38.169285
# 1672-02-12 session-1672-02-12-num-1-resolution-4 2022-03-29T13:12:38.314536
# 1672-02-12 session-1672-02-12-num-1-resolution-5 2022-03-29T13:12:38.663113
# 1672-02-12 session-1672-02-12-num-1-resolution-6 2022-03-29T13:12:39.011344
# 1672-02-12 session-1672-02-12-num-1-resolution-7 2022-03-29T13:12:39.212624
# 1672-02-12 session-1672-02-12-num-1-resolution-8 2022-03-29T13:12:39.406294
# 1672-02-12 session-1672-02-12-num-1-resolution-9 2022-03-29T13:12:39.550528
# 1672-02-12 session-1672-02-12-num-1-resolution-10 2022-03-29T13:12:39.704603
# 1672-02-12 session-1672-02-12-num-1-resolution-11 2022-03-29T13:12:39.895641
# 1672-02-12 session-1672-02-12-num-1-resolution-12 2022-03-29T13:12:40.033017
# 1672-02-12 session-1672-02-12-num-1-resolution-13 2022-03-29T13:12:40.492619
# 1672-02-12 session-1672-02-12-num-1-resolution-14 2022-03-29T13:12:41.046500

# %%
output_file = "resoluties_rampjaar.csv"

with open(output_file, 'wt') as fh:
    headers = ['resolution_id', 'date', 'paragraph_id', 'text', 'iiif_url']
    fh.write('\t'.join(headers) + '\n')
    for res in resolutions:
        for para in res.paragraphs:
            if isinstance(para.metadata['iiif_url'], list):
                url = ', '.join(para.metadata['iiif_url'])
            else:
                url = para.metadata['iiif_url']
            row = [res.id, res.metadata['session_date'], para.id, para.text, url]
            row = [cell if cell is not None else '' for cell in row]
            print(row)
            fh.write('\t'.join(row) + '\n')
# Out:
# ['session-1672-02-12-num-1-attendance_list', '1672-02-12', 'session-1672-02-12-num-1-para-1', 'Veneris den 12. Februarij 1672', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0265.jpg/2609,337,2446,3576/full/0/default.jpg']
# ['session-1672-02-12-num-1-attendance_list', '1672-02-12', 'session-1672-02-12-num-1-para-2', 'Preside den Heere van Coeverden', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0265.jpg/2609,337,2446,3576/full/0/default.jpg']
# ['session-1672-02-12-num-1-attendance_list', '1672-02-12', 'session-1672-02-12-num-1-para-3', 'Præsentibus de Heeren van Gendt, Gellicum, Brakell, Vijgh, Ripperda tot Buirse Schimmelpenningh, Ommeren Werckendam, Goeree, Meerens Odijck, Reijgersbergh, Crommon, Vrijbergen, Mauregnault,', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0265.jpg/2609,337,2446,3576/full/0/default.jpg']
# ['session-1672-02-12-num-1-attendance_list', '1672-02-12', 'session-1672-02-12-num-1-para-4', 'Schade, vander Hoolck, met een Extraord Gedep. van Utrecht Isbrandt van Vierssen, Bouritius, Arnould van Vierssen, Ter Borgh, Gockinga.', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0265.jpg/2609,337,2446,3576/full/0/default.jpg']
# ['session-1672-02-12-num-1-attendance_list', '1672-02-12', 'session-1672-02-12-num-1-para-5', 'De resolutien gisteren genomen, sijn gelesen ende geresumeert, gelijck oock geresumeert, ende gearresteert sijn de depesches daeruijt resulterende.', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0265.jpg/2609,337,2446,3576/full/0/default.jpg']
# ['session-1672-02-12-num-1-resolution-1', '1672-02-12', 'session-1672-02-12-num-1-para-6', 'Ontfangen een Missive vande Ridderschap ende steeden, de Staten van Overijssel, geschreven tot Deventer, den achtsten December 1671. stilo loci, daer bij deselve aen hare Ho:Mo: voordragen de persoon vanden heere Dirck Ludolph van Keppel tot Champherbeeck, omme in plaetse vande heer die laetst uijt het quartier van vollenho, deselve Commissie heeft becleet, te resideren in des Generaliteijts reeckencamer. waerop gedelibereert sijnde, Is den gemeltenheer Ludolph van Keppel gehouden voor gecommitteert, ende vervolgens naer gedaenen eedt, door den heer Ter Bergh, inde gemelte reeckensamer geintroduceert.', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0265.jpg/2609,337,2446,3576/full/0/default.jpg']
# ['session-1672-02-12-num-1-resolution-2', '1672-02-12', 'session-1672-02-12-num-1-para-7', 'Ontfangen een Missive vande heeren Staten van hollandt ende Westvrieslandt, geschreven alhier inden Hage den elffden deser, daerbij deselve aen haer Ho:Mo: voordragen de persoon van Dirck Spiegel, oudt schepen der Stadt amsterdam, om te resideren in het Collegie ter admiraliteijt in Westvrieslandt, ende den Noorderquartiere, in plaetse van Nicolaes — van Opmeer, schepen der selver Stadt: waerop gedelibereert sijnde, Is goetgevonden ende verstaen, d
full/0/default.jpg']
# ['session-1672-02-12-num-1-resolution-15', '1672-02-12', 'session-1672-02-12-num-1-para-50', 'Reijgersbergh, Pieterszon, Crommon, Vrijbergen, Mauregnault, Schade, vander Hoolck, met een Extraords. Gedeputeerde van Utrecht', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0273.jpg/2592,-23,2287,3050/full/0/default.jpg']
# ['session-1672-02-12-num-1-resolution-15', '1672-02-12', 'session-1672-02-12-num-1-para-51', "Isbrandt van Vierssen, Bouricius, Arnould van Vierssen Ter Borch, Gockinga. verdere proceduren voortgeseth mogen werden ende dat den heere Don manuel francisco de Lira, Extraordinaris Envoijé vanden Coningh van Spaigne alhier, voorden agent de heijde inden naeme van haer Ho: Mo: sal werden versocht, t'gunt voorschreve is, met sijne particuliere officien bijden welgemelten heere Grave van Montereij te willen seconderen.", 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0273.jpg/2592,-23,2287,3050/full/0/default.jpg']

# %%
keyword = "pestilentie"

query = {"query": {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},                  # only resolutions, no attendance lists
            {"match": {"metadata.session_year": 1711}},         # only resolutions from 1672
            {"match": {"paragraphs.text": keyword}}, # only resolutions containing 'raet pensionaris'
        ]
    }
}}
resolutions = rep_es.retrieve_resolutions_by_query(query)
output_file = f"resoluties_rampjaar_{keyword.replace(' ','_')}.csv"
with open(output_file, 'wt') as fh:
    headers = ['resolution_id', 'date', 'paragraph_id', 'text', 'iiif_url']
    fh.write('\t'.join(headers) + '\n')
    for res in resolutions:
        print(res.metadata["text_page_num"])
        for para in res.paragraphs:
            if isinstance(para.metadata['iiif_url'], list):
                url = ', '.join(para.metadata['iiif_url'])
            else:
                url = para.metadata['iiif_url']
            row = [res.id, res.metadata['session_date'], para.id, para.text, url]
            row = [cell if cell is not None else '' for cell in row]
            print(row)
            fh.write('\t'.join(row) + '\n')
# Out:
# [1057, 1058]
# ['session-1711-09-04-num-1-resolution-16', '1711-09-04', 'session-1711-09-04-num-1-para-20', 'IS ter Vergaderinge gelesen de Memorie van den Heere Resident Breyer, rakende het ontssaen van de Wollen ende andere Goederen, voor de besmettelijke Sieckte van Dantzick na dese Landen gebraght, volgende de voorschreve Memorie hier naer geinsereert.', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3766/NL-HaNA_1.01.02_3766_0556.jpg/2506,315,1119,3115/full/0/default.jpg']
# ['session-1711-09-04-num-1-resolution-16', '1711-09-04', 'session-1711-09-04-num-1-para-21', 'Hoogh Mog. Heeren.', 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3766/NL-HaNA_1.01.02_3766_0556.jpg/2506,315,1119,3115/full/0/default.jpg']
# ['session-1711-09-04-num-1-resolution-16', '1711-09-04', 'session-1711-09-04-num-1-para-22', 'DE ondergeschreven Resident van de Loffelijcke Hansche Steden, geeft sich de eere, op expresse ordre van den Senaet der Stadt Dantzich, aen U Hoogh Mogende met alle behoorlijk respect voor te dragen, dat hare goede commercierende Burgers, haer van tydt tot tydt met supplicatien ende sollicitatien komen klaghtigh en moeyelijck vallen, ten eynde de selve by U Hoogh Mogende nochmael moghte intercederen, ende versoecken dat hare Wolle ende andere Koopmanschappen, die sedert soo lange tydt in Texel tot hare grootte schade gearresteert zyn geweest, op suspicie van besmettelijckheydt ende pestilentiale lught, eenmael moghten werden ontslagen, en haer gepermitteert die te mog
 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3766/NL-HaNA_1.01.02_3766_0557.jpg/327,312,1119,1026/full/0/default.jpg']

# %%
query = {
    "bool": {
        "must": [
            {"match": {"metadata.session_year": 1711}},
            {"match": {"metadata.text_page_num": 1099}}
        ]
    }
}

resolutions = rep_es.retrieve_resolutions_by_query(query)
for res in resolutions:
    print(res.id)
    for para in res.paragraphs:
        print(para.text)
# Out:
# session-1711-09-16-num-1-resolution-3
# ONtfangen een Missive van de Magistraet der Keyserlycke vrye Rycks-Stadt Bremen, geschreven aldaer den twaelfden deser loopende maendt, houdende, dat de Koopluyden aldaer op de Nederlanden trafiquerenrende, aen haer hadden voorgedragen ende te kennen gegeven, in wat voegen sommige van haer reets in het midden van de maendt Augusti, in verscheyde Schepen hare Packen met Linnen ende andere Waren, alle met beëdigde Pasporten voorsien, dat se uyt geen besmetlijcke, maer uyt gesonde Plaetsen waren gekomen, na Amsterdam hadden laten afgaen, hebbende de selve tegenwoordigh eerst vernomen, dat haer Hoogh Mogende op den vierden September, als wanneer de voorschreve van daer afgevaren Schepen reets te Amsterdam waren aengekomen , een Placaet hadden laten uytgaen , waer by haer Hoogh Mogende de in het Placaet gespecificeerde Goederen verboden in te brengen; dat sy haer Hoogh Mogende konden verseeckeren, dat hare Stadt tot noch toe een gesonde lucht genoodt, ende dat geen contagieusheyt aldaer grasseerde, ja dat selfs op twaelf en meer Duytsche mylen, om haer heen, aen die kant van de Elve, als mede na het Oldenborghsche ende het Landt van Oost-Vrieslandt geen infectie voorhanden was, noch bespeurt wierdt, versoeckende dat haer Hoogh Mogende daer geloof aen geliefden te slaen, ende aen der selver Admiraliteyten laten bekent maecken, dat of schoon in haer Hoogh Mogende voorschreve Placaet van de Stadt Bremen gedaght was geworden, de selve nochtans op ontfangen nader en seeckerder bericht, tot noch toe van alle contagieusheyt gantsch vry waren, hare Goederen met beeedighde Pasporten souden werden ingelaten, ende vervolgens in de Couranten daer van naricht laten geven, dewyl haer Hoogh Mogende door der selver meergemelde Placaet haer niet alleen in de Nederlanden, maer oock in Engelandt, Duytslandt en andere Plaetsen, tot haer onschuldt suspect maeckte, en de Com. mercie stremde, waer door voor hare Stadt een irreparable schade konde ontstaen; dat sy verseeckert waren dat sulcks haer Hoogh Mogende intentie niet was. WAER op gedelibereert zynde, is goetgevonden ende verstaen, dat Copie van de voorschreve Missive gestelt sal werden in handen van de Heeren van Broeckhuysen, ende andere haer Hoogh Mogende Gedeputeerden tot de saecken van de Zee, om te visiteren, examineren, de consideratien ende het advis van de Gecommitteerden van de respective Collegie ter Admiraliteyt daer op in te nemen, ende van alles alhier ter Vergaderinge rapport te doen.
# session-1711-09-16-num-1-resolution-4
# ONtfangen een Missive van de Magistraet der Stadt Hamburgh, geschreven aldaer den elfden deser loopende maendt, houdende, dat haer Hoogh Mogende uyt hare Missive van den achtsten daer te vooren, aen haer Hoogh Mogende geschreven, geliefden te sien, het geen sy, soo raeckende de uyt de Zee, de Elve opwaerts komende Schepen, en de soogenaemde Damschuyten, als wegens het ongegronde gerught, het geen aldaer rughtbaer geworden was, als of sich in hare Nabuerschappen eenige teeckenen van besmettelijke Sieckte lieten bespeuren,
goes, haer Hoogh Mogende extraordinaris Envoyé aen het Hof van Denemarcken, of aen des selfs Secretaris, ten eynde om alle meestkrachtige devoiren en instantien te doen en aen te wenden, soo by hooghstgedachte sijne Majesteyt, als des selfs Raeden ende Ministers, ofte anders daer het van vrucht soude kunnen wesen, ten eynde de ladinge Yser ende Houtwaren, van het voorschreve Schip van Andries Willem, alsnoch kost- en schadeloos mogte werden ontslagen en gerestitueert, ofte wel de waerde van dien voldaen; ende dat wyders den Heere Grave van Ahlefeld, extraordinaris Envoyë van sijne Majesteyt van Denemarcken alhier, mochte werden versocht het selve door sijne goede officien te seconderen. WAER op gedelibereert zijnde , is goetgevonden ende verstaen, dat Copie van de voorschreve Requeste gestelt sal werden in handen van de Heeren van Broeckhuysen, ende andere haer Hoogh Mogende Gedeputeerden tot de saecken van de Zee, om te visiteren, examineren, ende van alles alhier ter Vergaderinge rapport te doen.

# %% [markdown]
# ### The Anatomy of a Resolution
#
# Resolutions in the index consist of `metadata` and `paragraphs`.

# %%
import json

res = resolutions[0]
# Each resolution has metadata
print(json.dumps(res.metadata, indent=4))
# Out:
# {
#     "inventory_num": 3766,
#     "source_id": "session-1711-09-04-num-1",
#     "type": "resolution",
#     "id": "session-1711-09-04-num-1-resolution-16",
#     "session_date": "1711-09-04",
#     "session_id": "session-1711-09-04-num-1",
#     "session_num": 1,
#     "president": null,
#     "session_year": 1711,
#     "session_month": 9,
#     "session_day": 4,
#     "session_weekday": "Veneris",
#     "proposition_type": "memorie",
#     "proposer": null,
#     "decision": null,
#     "resolution_type": "ordinaris",
#     "text_page_num": [
#         1057,
#         1058
#     ],
#     "index_timestamp": "2022-01-10T16:40:43.318944"
# }

# %%
# You can dump all resolution data to JSON
res.json
# Out:
# {'id': 'session-1672-04-01-num-1-resolution-4',
#  'type': ['republic_doc', 'resolution_element', 'resolution'],
#  'metadata': {'inventory_num': 3285,
#   'source_id': 'session-1672-04-01-num-1',
#   'type': 'resolution',
#   'id': 'session-1672-04-01-num-1-resolution-4',
#   'session_date': '1672-04-01',
#   'session_id': 'session-1672-04-01-num-1',
#   'session_num': 1,
#   'president': None,
#   'session_year': 1672,
#   'session_month': 4,
#   'session_day': 1,
#   'session_weekday': 'Veneris',
#   'proposition_type': 'missive',
#   'proposer': None,
#   'decision': None,
#   'resolution_type': 'ordinaris',
#   'text_page_num': [],
#   'index_timestamp': '2022-02-03T09:11:42.940395'},
#  'evidence': [{'type': 'PhraseMatch',
#    'phrase': 'ONtfangen een Missive van',
#    'variant': 'ONtfangen een Missive van',
#    'string': 'Ontfangen een Missive van',
#    'offset': 0,
#    'label': ['proposition_opening',
#     'proposition_from_correspondence',
#     'proposition_type:missive'],
#    'ignorecase': False,
#    'text_id': 'session-1672-04-01-num-1-para-11',
#    'match_scores': {'char_match': 0.96,
#     'ngram_match': 0.88,
#     'levenshtein_similarity': 0.96}},
#   {'type': 'PhraseMatch',
#    'phrase': 'houdende',
#    'variant': 'houdende',
#    'string': 'houdende',
#    'offset': 131,
#    'label': ['proposition_verb',
#     'proposition_opening_end_verb',
#     'proposition_body'],
#    'ignorecase': False,
#    'text_id': 'session-1672-04-01-num-1-para-11',
#    'match_scores': {'char_match': 1.0,
#     'ngram_match': 1.0,
#     'levenshtein_similarity': 1.0}}],
#  'stats': {'lines': 25, 'words': 135, 'text_regions': 0, 'paragraphs': 2},
#  'paragraphs': [{'id': 'session-1672-04-01-num-1-para-11',
#    'type': ['republic_doc', 'resolution_paragraph', 'republic_paragraph'],
#    'metadata': {'inventory_num': 3285,
#     'source_id': 'session-1672-04-01-num-1',
#     'type': 'resolution_paragraph',
#     'id': 'session-1672-04-01-num-1-para-11',
#     'text_page_num': [],
#     'page_num': [1087],
#     'start_offset': 4533,
#     'iiif_url': 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0544.jpg/3236,-8,1830,3874/full/0/default.jpg',
#     'doc_id': 'session-1672-04-01-num-1',
#     'paragraph_index': 0},
#    'text_region_ids': [],
#    'text': 'Ontfangen een Missive van het Collegie ter admiraliteijt tot amsterdam, geschreven aldaer den eenendertichsten Martij lest„ leden, houdende, dat het gemelte Collegie vermits de jegenwoordige ongelegentheijt met den Coningh van Groot Brittannien geerne soude verstaen haer Ho:Mo: intentie ontrent het affsenden van hetschip van Oorlogh voor desen gedestineert tot transport vanden heer van Strevels„ hoeck, haer ho:Mo: gedesigneerde resident aen het hoff van Spamen, uijt dese Landen naer Spaignen, sonderlingh alsoo het voorschreve Schip van oorlogh niet sonder pericul ende ondienst vanden Lande soo verte vande handt gesonden conde werden, ende andersints was gedesigneert onder de schepen die',
#    'line_ranges': [{'start': 0,
#      'end': 39,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3336-770-1530-136',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 39,
#      'end': 83,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3489-875-1436-143',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 83,
#      'end': 124,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3487-949-1443-164',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 124,
#      'end': 166,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3484-1040-1413-155',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 166,
#      'end': 207,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3485-1132-1423-165',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 207,
#      'end': 245,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3485-1219-1409-141',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 245,
#      'end': 279,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3482-1302-1415-148',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 279,
#      'end': 317,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3491-1414-1372-142',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 317,
#      'end': 359,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3478-1485-1418-157',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 359,
#      'end': 399,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3484-1577-1426-164',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 399,
#      'end': 432,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3481-1687-1377-159',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 432,
#      'end': 471,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3487-1782-1392-149',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 471,
#      'end': 510,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3481-1847-1398-182',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 510,
#      'end': 550,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3479-1940-1353-181',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 550,
#      'end': 584,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3482-2049-1272-130',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 584,
#      'end': 619,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3476-2128-1352-159',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 619,
#      'end': 658,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3473-2218-1390-144',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 658,
#      'end': 695,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3477-2323-1394-140',
#      'text_page_num': None,
#      'page_num': 1087}],
#    'scan_versions': None,
#    'stats': {'words': 100, 'lines': 18},
#    'text_regions': []},
#   {'id': 'session-1672-04-01-num-1-para-12',
#    'type': ['republic_doc', 'resolution_paragraph', 'republic_paragraph'],
#    'metadata': {'inventory_num': 3285,
#     'source_id': 'session-1672-04-01-num-1',
#     'type': 'resolution_paragraph',
#     'id': 'session-1672-04-01-num-1-para-12',
#     'text_page_num': [],
#     'page_num': [1087],
#     'start_offset': 5228,
#     'iiif_url': 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3285/NL-HaNA_1.01.02_3285_0544.jpg/3236,-8,1830,3874/full/0/default.jpg',
#     'doc_id': 'session-1672-04-01-num-1',
#     'paragraph_index': 1},
#    'text_region_ids': [],
#    'text': "s'lants vloote souden helpen composeren, Ende is bij die occasie oock gelesen de missive vanden voornoemden heer van Strevelshoeck, mede geschreven tot amsterdam voornoemt, den voorschreven eenendertichsten Martij laestleden t' voorschreve subject concernerende:",
#    'line_ranges': [{'start': 0,
#      'end': 41,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3473-2404-1427-182',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 41,
#      'end': 78,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3468-2496-1390-165',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 78,
#      'end': 113,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3471-2592-1385-161',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 113,
#      'end': 148,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3475-2679-1356-177',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 148,
#      'end': 190,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3480-2775-1475-192',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 190,
#      'end': 225,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3482-2855-1331-182',
#      'text_page_num': None,
#      'page_num': 1087},
#     {'start': 225,
#      'end': 262,
#      'line_id': 'NL-HaNA_1.01.02_3285_0544-line-3477-2973-1359-141',
#      'text_page_num': None,
#      'page_num': 1087}],
#    'scan_versions': None,
#    'stats': {'words': 35, 'lines': 7},
#    'text_regions': []}]}

# %% [markdown]
# ## Using Elasticsearch Queries
#
# See the [Elasticsearch Query DSL](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl.html) for details on how to construct different types of queries.

# %%
query = {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},                  # only resolutions, no attendance lists
            {"match": {"metadata.session_year": 1672}},         # only resolutions from 1672
            {"match": {"paragraphs.text": "raet pensionaris"}}, # only resolutions containing 'raet pensionaris'
        ]
    }
}

resolutions = rep_es.retrieve_resolutions_by_query(query)

for res in resolutions:
    print(res.id)
    for para in res.paragraphs:
        print(f"\t{para.text}\n")
    print('--------------------\n')
# Out:
# session-1672-07-25-num-1-resolution-14
# 	Ontfangen een missive vanden pensionaris Pesters, geschreven tot Maestricht den 23en. deses, houdende advertentie, ende onder anderen rakende de contri„ butie bij de franschen gevordent wer„ ,dende inde Landen van Overmase, Waerop gedelibereert zijnde, Is goetgevonden ende verstaen, dat de voors missive gestelt sal werden in handen vande heeren van Brakel ende andere haer Ho:Mo: Gedepu„ teerden tot de saken vande Landen van Overmaze, met ende nevens eenige Heeren Gecommitteerden uijt den Raet van State bij haer E. selffs te nomineren, om te visi„ teren, examineren, ende daer van rapport te doen
#
# --------------------
#
# session-1672-11-15-num-1-resolution-5
# 	Ontfangen een missive van Alleij Aga, geschreven tot Amsterdam den twaelffden deses, houdende advertentie, dat hij uijt Turckijen was gesonden voor Ambassadeur vanden Grootenheer aenden Coningh van Sweeden dat hij oock een recommandatie Brieff aen haer Ho:Mo: om hem be,, hulpsaem te sijn int geene mochte toebragen, voor desen hadde overge,, levert aenden Raet Pensionaris van Hollandt ende Westvrieslandt en dat hij voorts was vertrocken naer Sweeden, van waer weder gekeert sijnde, versochte dat haer Ho:Mo: hem over Landt wilden te ruijge senden, gelijck den keijsen ende andere Potentaten gedaen hadden ende soo sulcx niet conde geschieden, hem alsdan sijn tractement ende nootdruft besorgen, geduijrende den tijt van sijn vertoeven: Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat
waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voorschreve Missive gestelt sal werden in handen vande Heeren van Gent ende andere hare Ho:Mo: Gedeputeerden tot de saecken vande Triple Alliancie, om te visiteren, examineren, ende daervan rapport te doen.
#
# --------------------
#
# session-1672-08-23-num-1-resolution-16
# 	Ontfangen een Missive vanden Commis„ saris Knijff, geschreven op den Helder den ... deses, houdende advertentie: Waerop egeen resolutie en is gevallen.
#
# 	Opt gerepresenteerde bij de Heeren Gedeputeerden vande Provincie van Hollandt ende Westvrieslandt ter Vergaderinge gedaen: Is naer deliberatie goetgevonden ende verstaen mits desen te committeren den heere Raet Pensionnaris Fagel, tot alle de besoignes daerinne wijlen den Raet Pensionnaris de Witt, met ende nevens d'andere Heeren hare Ho:Mo: Gedeputeerden heeft ge„ vaceert gehadt,
#
# --------------------
#
# session-1672-05-31-num-1-resolution-3
# 	Ontfangen een missive vande Heeren Stuck ende van Aijlua, Gecommitteerden vanden Raet van State Jegenwoordigh tot Rees, ges: aldaer den 31. Maij lestleden, houdende advertentie; Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voors missive gestelt sal werden, in handen vande Heeren van Brakel ende andere haer Ho:Mo: Gedepuden tot de militaire saecken met ende nevens eenige Heeren Gecommitteerden uijt„ den Raet van State, bij haer E. selffs te nomineren, om te visiteren, examineren ende daer van rapport te doen;
#
# --------------------

# %%
# import Counter to do some simple word counting and frequency comparison
from collections import Counter
import re

# %%
query = {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},
            {"match": {"metadata.session_year": 1672}}
        ]
    }
}

resolutions_1672 = rep_es.retrieve_resolutions_by_query(query, size=10000)

all_word_freq = Counter()

for res in resolutions_1672:
    for para in res.paragraphs:
        all_word_freq.update([word for word in re.split(r"\W+", para.text) if word != ''])

for word, freq in all_word_freq.most_common(10):
    print(f"{word: <20}{freq: >6}")
# Out:
# ende                 26487
# van                  23337
# de                   20843
# te                   15032
# dat                  11202
# den                   9404
# haer                  8512
# vande                 8469
# tot                   8431
# in                    8057

# %%
res_missives = [res for res in resolutions_1672 if res.metadata['proposition_type'] == 'missive']

len(res_missives)
# Out:
# 1616

# %%
from collections import Counter
import re

query = {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},
            {"match": {"metadata.session_year": 1672}},
            {"match": {"paragraphs.text": "raet pensionaris"}}
        ]
    }
}

resolutions = rep_es.retrieve_resolutions_by_query(query)


word_freq = Counter()

for res in resolutions:
    for para in res.paragraphs:
        word_freq.update([word for word in re.split(r"\W+", para.text) if word != ''])

rel_freq = {}
min_freq = 3
for word, freq in word_freq.most_common():
    if freq < min_freq:
        continue
    rel_freq[word] = freq / all_word_freq[word]
    
for word in sorted(rel_freq, key = lambda w: rel_freq[w], reverse=True):
# daer                0.0018     4    2231
# resolutie           0.0018     4    2260
# op                  0.0017     6    3523
# in                  0.0016    13    8057
# voorschreve         0.0016     8    5053
# t                   0.0016     3    1903
# haer                0.0015    13    8512
# deselve             0.0014     3    2167
# en                  0.0010     3    2874
# het                 0.0004     3    6909

# %% [markdown]
# ### Resolutions in JSON Format
#
# Resolution objects have a `.json` property to get a JSON representation of the resolution, including metadata, paragraph text and basic statistics. This can be a convenient format for storing and later retrieving them from disk (faster than getting them from the Republic CAF server).
#
# You can also turn them into plain text representations if you want to do extensive text analysis.

# %%
import json
import gzip

resolutions_file = "../../data/resolutions/rampjaar-ordinaris-resolutions.json.gz"

# open a file for storing the JSON representation of resolutions
with gzip.open(resolutions_file, 'wt') as fh:
    # iterate over the resolutions and dump their JSON representations to file
    json.dump([res.json for res in resolutions_1672], fh)

# %%
import json
import gzip

import republic.model.republic_document_model as rdm


resolutions_file = "../../data/resolutions/rampjaar-ordinaris-resolutions.json.gz"

# Reading the JSON representations from file again and turning 
# them into Resolution objects again
with gzip.open(resolutions_file, 'rt') as fh:
    # the document model has a convenience function to turn a JSON representation
    # to a Resolution object: json_to_republic_resolution
    resolutions_1672 = [rdm.json_to_republic_resolution(res) for res in json.load(fh)]

# %%
# Creating plain text representations of resolutions by concatenating paragraph texts
for res in resolutions_1672:
    res_text = '\n'.join([para.text for para in res.paragraphs])
    print(res_text)
    break
# Out:
# Is gehoort het rapport vande heeren van Ommeren, ende andere haer Ho:Mo: Gedeputeerden tot de saken vande Zee, hebbende ingevolge ende tot voldoeninge vander selver resolutie Commis„ soriael, gevisiteert ende geexami„ neert de requeste van Sammel Turcker, woonende tot Rotterdam als d'affaires doende van Thimo„ thens keijser, Coopman tot dublijn in Irlandt, raekende hetschip de providentie wenigh dagen voor dat de Smirnasche Vloot door d'Engelschen is geattacqueert, tot Rotterdam voornoemt gearri„ veert, ende aldaer ontladen Waerop gedelibereert sijnde, Is goetgevonden ende verstaen, dat de voorsr. requeste gesonden sal werden aen het Collegie ter admiraliteyt opde Maze, om haer Ho:Mo: daerop te laten toecomen der selver bericht consi„ deratien en advis.
# Finis van maent Junij
# 1072

# %% [markdown]
# ## Retrieving Aggregate Statistics
#
# You can also directly query the indexes using the elasticsearch instance inside the `rep_es` object, which is stored in the `es_anno` property (so can be addressed via `rep_es.es_anno`).
#
# Below is an example of a query and an aggregation to get the number of resolutions per month in the year 1672:

# %%
# raet pensionaris in resolutions
query = {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},
            {"match": {"metadata.session_year": 1672}},
            {"match": {"paragraphs.text": "raet pensionaris"}}
        ]
    }
}

aggs = {
    "months": {
        "date_histogram": {
            "field": "metadata.session_date",
            "calendar_interval": "month"
        }
    }
}


response = rep_es.es_anno.search(index="resolutions_new", query=query, aggs=aggs, size=0)
buckets = response["aggregations"]["months"]["buckets"]
for bucket in buckets:
    print(bucket["key_as_string"].split("T")[0], bucket["doc_count"])
# Out:
# 1672-01-01 130
# 1672-02-01 36
# 1672-03-01 146
# 1672-04-01 18
# 1672-05-01 142
# 1672-06-01 89
# 1672-07-01 128
# 1672-08-01 113
# 1672-09-01 95
# 1672-10-01 122
# 1672-11-01 73
# 1672-12-01 31

# %% [markdown]
# Results on 2022-02-10:
#
# - 1672-01-01 64
# - 1672-02-01 18
# - 1672-03-01 71
# - 1672-04-01 9
# - 1672-05-01 83
# - 1672-06-01 45
# - 1672-07-01 63
# - 1672-08-01 56
# - 1672-09-01 47
# - 1672-10-01 59
# - 1672-11-01 48
# - 1672-12-01 27

# %%
# raet pensionaris in attendance lists
query = {
    "bool": {
        "must": [
            {"match": {"type": "attendance_list"}},
            {"match": {"metadata.session_year": 1672}},
            {"match": {"paragraphs.text": "raet pensionaris"}}
        ]
    }
}

response = rep_es.es_anno.search(index="resolutions_new", query=query, aggs=aggs, size=0)
buckets = response["aggregations"]["months"]["buckets"]
for bucket in buckets:
    print(bucket["key_as_string"].split("T")[0], bucket["doc_count"])
# Out:
# 1672-01-01 27
# 1672-02-01 14
# 1672-03-01 29
# 1672-04-01 10
# 1672-05-01 15
# 1672-06-01 4
# 1672-07-01 4
# 1672-08-01 7
# 1672-09-01 23
# 1672-10-01 31
# 1672-11-01 19
# 1672-12-01 9

# %%
# raet pensionaris in attendance lists
query = {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},
            {"match": {"paragraphs.text": "pestilentie"}}
        ]
    }
}

aggs = {
    "months": {
        "date_histogram": {
            "field": "metadata.session_date",
            "calendar_interval": "year",
        }
    }
}

response = rep_es.es_anno.search(index="resolutions", query=query, aggs=aggs, size=0)
buckets = response["aggregations"]["months"]["buckets"]
for bucket in buckets:
    print(bucket["key_as_string"].split("T")[0], bucket["doc_count"])
# Out:
# 1711-01-01 1
# 1712-01-01 0
# 1713-01-01 0
# 1714-01-01 0
# 1715-01-01 2
# 1716-01-01 0
# 1717-01-01 0
# 1718-01-01 0
# 1719-01-01 0
# 1720-01-01 0
# 1721-01-01 0
# 1722-01-01 0
# 1723-01-01 0
# 1724-01-01 0
# 1725-01-01 0
# 1726-01-01 0
# 1727-01-01 0
# 1728-01-01 0
# 1729-01-01 0
# 1730-01-01 0
# 1731-01-01 0
# 1732-01-01 0
# 1733-01-01 0
# 1734-01-01 0
# 1735-01-01 0
# 1736-01-01 0
# 1737-01-01 0
# 1738-01-01 0
# 1739-01-01 1
# 1740-01-01 0
# 1741-01-01 0
# 1742-01-01 0
# 1743-01-01 0
# 1744-01-01 0
# 1745-01-01 0
# 1746-01-01 0
# 1747-01-01 0
# 1748-01-01 0
# 1749-01-01 0
# 1750-01-01 0
# 1751-01-01 0
# 1752-01-01 2
# 1753-01-01 0
# 1754-01-01 0
# 1755-01-01 0
# 1756-01-01 0
# 1757-01-01 0
# 1758-01-01 0
# 1759-01-01 0
# 1760-01-01 0
# 1761-01-01 0
# 1762-01-01 0
# 1763-01-01 0
# 1764-01-01 0
# 1765-01-01 0
# 1766-01-01 0
# 1767-01-01 0
# 1768-01-01 0
# 1769-01-01 0
# 1770-01-01 1
# 1771-01-01 2

# %%
# 
query = {
    "bool": {
        "must": [
            {"match": {"type": "resolution"}},
            {"match": {"metadata.session_year": 1672}}
        ]
    }
}

aggs = {
    "prop_types": {
        "terms": {
            "field": "metadata.proposition_type.keyword"
        }
    }
}


response = rep_es.es_anno.search(index="resolutions_new", query=query, aggs=aggs, size=0)
buckets = response["aggregations"]["prop_types"]["buckets"]
for bucket in buckets:
    print(bucket["key"], bucket["doc_count"])
    
print("Total:", sum([bucket["doc_count"] for bucket in buckets]))
# Out:
# missive 2841
# requeste 482
# rapport 404
# voordracht 89
# memorie 51
# declaratie 14
# rekening 2
# Total: 3883

# %%
resolutions = rep_es.retrieve_resolutions_by_query(query, size=2700)
len(resolutions)
# Out:
# 2500

# %%
from collections import Counter

Counter([res.metadata["proposition_type"] for res in resolutions])
for res in resolutions:
    response = rep_es.es_anno.get(index="resolutions", id=res.id)
    res_json = response["_source"]
    if "proposition_type" not in res_json["metadata"] or res_json["metadata"]["proposition_type"] is None:
        print(res.id, res.proposition_type, res.metadata["proposition_type"])
        res_json["metadata"]["proposition_type"] = res.proposition_type
        print('\t', res.paragraphs[0].text[:100], '\n')
        for match in res.evidence:
            print('\t\t', match.phrase.phrase_string, match.label)
        #rep_es.index_resolution(res)
# Out:
# session-1672-01-28-num-1-resolution-24 None None
# 	 Is gehoort het rapport vande heeren van Brakell, ende andere hare Ho:Mo: Gedeputeerdens tot de saeck
#
# 		 in gevolge en tot voldoeninge van der selver Resolutie commissoriaal van den proposition_opening
# 		 hebbende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 dienende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 hebbende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-01-12-num-1-resolution-5 None None
# 	 Op de Requeste van Mr. Louis d' Outrelean, Licentiaet in de rechten woonende tot Middelburch in Zeel
#
# 		 OP de Requeste van  proposition_opening
# 		 versoekende ['proposition_verb', 'request', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-08-num-1-resolution-14 None None
# 	 Op de requeste van Jacob Pesijn, Ontfanger vande gemeijne middelen opt' Sas van Gent, Impt, ende gee
#
# 		 OP de Requeste van  proposition_opening
# 		 versoekende ['proposition_verb', 'request', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-08-num-1-resolution-16 None None
# 	 De requeste van Buijrschap Bokeles gelegen in het Stift van Munster in Westphalen, op de grensen van
#
# 		 De requeste van  proposition_opening
# 		 versoekende ['proposition_verb', 'request', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-11-num-1-resolution-8 None None
# 	 Den Raedt van State heeft ter Vergade„ ringe gecommuniceert een Missive van den Commandeur Wee van W
#
# 		 heeft ter Vergadering gecommuniceert  proposition_opening
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende advertentie. ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-11-num-1-resolution-9 None None
# 	 Den Raedt van State heeft ter Vergaderinge gecommuniceert een missive vanden Com„ missaris vander St
#
# 		 heeft ter Vergadering gecommuniceert  proposition_opening
# 		 houdende advertentie. ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-11-num-1-resolution-10 None None
# 	 Den Raedt van State heeft ter Vergade„ ringe gecommuniceert een Missive van den Capiteijn Lichtenber
#
# 		 heeft ter Vergadering gecommuniceert  proposition_opening
# 		 houdende advertentie. ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 raakende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-14-num-1-resolution-4 None None
# 	 Den Raet van State heeft ter Vergaderinge gedaen communiceren een missive vanden Commandeur Sijghers
#
# 		 heeft aan haar Hoog Mog. voorgedragen proposition_opening
# 		 houdende advertentie. ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-15-num-1-resolution-7 None None
# 	 Den Raet van State heeft ter Verga„ deringe gecommuniceert een missive vanden Capitein Barent Jan va
#
# 		 heeft ter Vergadering gecommuniceert  proposition_opening
# 		 houdende advertentie. ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-16-num-1-resolution-1 None None
# 	 De requeste van Paulus van Alkemade, Lieutenant Colonel van het regiment van den Colonel du Tell in
#
# 		 De requeste van  proposition_opening
# 		 versoekende ['proposition_verb', 'request', 'proposition_opening_end_verb', 'proposition_body']
# session-1672-06-16-num-1-resolution-6 None None
# 	 Den Raet van State heeft ter Vergade„ ringe gecommuniceert een Missive van den Capitein vande Velde,
#
# 		 heeft ter Vergadering gecommuniceert  proposition_opening
# 		 houdende advertentie. ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 hebbende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 dienende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 hebbende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 hebbende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# 		 houdende ['proposition_verb', 'proposition_opening_end_verb', 'proposition_body']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 4>()
#       3 Counter([res.metadata["proposition_type"] for res in resolutions])
#       4 for res in resolutions:
# ----> 5     response = rep_es.es_anno.get(index="resolutions", id=res.id)
#       6     res_json = response["_source"]
#       7     if "proposition_type" not in res_json["metadata"] or res_json["metadata"]["proposition_type"] is None:
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/elasticsearch/client/utils.py:301, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     299     if p in kwargs:
#     300         params[p] = kwargs.pop(p)
# --> 301 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/elasticsearch/client/__init__.py:1026, in Elasticsearch.get(self, index, id, doc_type, params, headers)
#    1023 if doc_type in SKIP_IN_PATH:
#    1024     doc_type = "_doc"
# -> 1026 return self.transport.perform_request(
#    1027     "GET", _make_path(index, doc_type, id), params=params, headers=headers
#    1028 )
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/elasticsearch/transport.py:419, in Transport.perform_request(self, method, url, headers, params, body)
#     416 connection = self.get_connection()
#     418 try:
# --> 419     status, headers_response, data = connection.perform_request(
#     420         method,
#     421         url,
#     422         params,
#     423         body,
#     424         headers=headers,
#     425         ignore=ignore,
#     426         timeout=timeout,
#     427     )
#     429     # Lowercase all the header names for consistency in accessing them.
#     430     headers_response = {
#     431         header.lower(): value for header, value in headers_response.items()
#     432     }
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/elasticsearch/connection/http_urllib3.py:251, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     248     body = self._gzip_compress(body)
#     249     request_headers["content-encoding"] = "gzip"
# --> 251 response = self.pool.urlopen(
#     252     method, url, body, retries=Retry(False), headers=request_headers, **kw
#     253 )
#     254 response_headers = {
#     255     header.lower(): value for header, value in response.headers.items()
#     256 }
#     257 duration = time.time() - start
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/urllib3/connectionpool.py:723, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     720 response_kw["request_method"] = method
#     722 # Import httplib's response into our own wrapper object
# --> 723 response = self.ResponseCls.from_httplib(
#     724     httplib_response,
#     725     pool=self,
#     726     connection=response_conn,
#     727     retries=retries,
#     728     **response_kw
#     729 )
#     731 # Everything went great!
#     732 clean_exit = True
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/urllib3/response.py:604, in HTTPResponse.from_httplib(ResponseCls, r, **response_kw)
#     602 # HTTPResponse objects in Python 3 don't have a .strict attribute
#     603 strict = getattr(r, "strict", 0)
# --> 604 resp = ResponseCls(
#     605     body=r,
#     606     headers=headers,
#     607     status=r.status,
#     608     version=r.version,
#     609     reason=r.reason,
#     610     strict=strict,
#     611     original_response=r,
#     612     **response_kw
#     613 )
#     614 return resp
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/urllib3/response.py:263, in HTTPResponse.__init__(self, body, headers, status, version, reason, strict, preload_content, decode_content, original_response, pool, connection, msg, retries, enforce_content_length, request_method, request_url, auto_close)
#     261 # If requested, preload the body.
#     262 if preload_content and not self._body:
# --> 263     self._body = self.read(decode_content=decode_content)
#
# File ~/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages/urllib3/response.py:518, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     515 with self._error_catcher():
#     516     if amt is None:
#     517         # cStringIO doesn't like amt=None
# --> 518         data = self._fp.read() if not fp_closed else b""
#     519         flush_decoder = True
#     520     else:
#
# File /Applications/anaconda3/envs/pymc3_env/lib/python3.9/http/client.py:475, in HTTPResponse.read(self, amt)
#     473 else:
#     474     try:
# --> 475         s = self._safe_read(self.length)
#     476     except IncompleteRead:
#     477         self._close_conn()
#
# File /Applications/anaconda3/envs/pymc3_env/lib/python3.9/http/client.py:625, in HTTPResponse._safe_read(self, amt)
#     623 s = []
#     624 while amt > 0:
# --> 625     chunk = self.fp.read(min(amt, MAXAMOUNT))
#     626     if not chunk:
#     627         raise IncompleteRead(b''.join(s), amt)
#
# File /Applications/anaconda3/envs/pymc3_env/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Applications/anaconda3/envs/pymc3_env/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Applications/anaconda3/envs/pymc3_env/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Fuzzy Search
#
# Use fuzzy searching with a list of keywords/phrases to find resolutions with spelling variants of those keywords/phrases.
#
# The `fuzzy-search` package has a FuzzyPhraseSearcher, but also a FuzzyContextSearcher, that returns the matched phrase together with the surrounding context, and allows one to search for additional keywords/phrases within those match contexts.
#
# A PhraseMatchInContext object has a `.string` property that contains the string in the text that matches the phrase. In addition, it has the properties `prefix`, `suffix` and `context`. The `prefix` contains the preceding text, the `suffix` the text following the matching string, and the `context` contains the matching string with both `prefix` and `suffix` text. The amount of preceding and following text is controlled in the `.find_matches()` function by optional the `prefix_size` and `suffix_size` arguments.
#
# Requirements:
# - `fuzzy-search` (python package via `pip install fuzzy-search`, but it should already be installed if you installed the required packages to use the Republic code repository).

# %%
from fuzzy_search.fuzzy_context_searcher import FuzzyContextSearcher
from fuzzy_search.fuzzy_phrase_model import PhraseModel

phrase = 'tot de saecken'

config = {
    'levenshtein_threshold': 0.7,
    'ngram_size': 3,
    'skip_size': 1,
    'include_variants': True
}

phrase_model = PhraseModel([phrase], config=config)
saecken_searcher = FuzzyContextSearcher(config)
saecken_searcher.index_phrase_model(phrase_model)

for res in resolutions_1672[:20]:
    for para in res.paragraphs:
        matches = saecken_searcher.find_matches(para.text)
        for match in matches:
            print(f"Phrase: {match.phrase.phrase_string: <30}\tmatch string: {match.string}")
            print(f"\t{match.context}\n")
            print(match.offset, match.end)
# Out:
# Phrase: tot de saecken                	match string: tot de saken
# 	Is gehoort het rapport vande heeren van Ommeren, ende andere haer Ho:Mo: Gedeputeerden tot de saken vande Zee, hebbende ingevolge ende tot voldoeninge vander selver resolutie Commis„ soriael, gevisit
#
# 87 99
# Phrase: tot de saecken                	match string: tot de saecken
# 	Is gehoort het rapport vande Heeren van Ommeren, ende andere hare Ho:Mo: Gedeputeerden tot de saecken vande Zee, hebbende inge, volge, ende tot voldoeninge van der„ selver resolutie Commissoriael van„
#
# 87 101
# Phrase: tot de saecken                	match string: tot de saecken
# 	t gestelt sal werden in handen vande Heeren van Hoogendorp, ende andere hare Ho:Mo: Gedepu„ teerden tot de saecken vande Zee, om te visiteren, examineren, ende van alles rapport te doen, sonder resumptie.
#
# 1128 1142
# Phrase: tot de saecken                	match string: tot de saecken
# 	ns gestelt sullen werden in handen vande Heeren van Hogendorp ende andere haer Ho:Mo: Gedeputeerden tot de saecken vande Triple alliantie, om te visiteren, examineren ende daer van rapport te doen.
#
# 1912 1926
# Phrase: tot de saecken                	match string: tot de saecken
# 	issive gestelt sal werden in handen vande Heeren van Ommeren, ende andere hare Ho:Mo: Gedeputeerden tot de saecken vande Zee, om te visi„ teren, examineren, ende daervan rapport te doen.
#
# 510 524
# Phrase: tot de saecken                	match string: tot de saecken
# 	erde gestelt sal werden in handen vande Heeren van Ommeren, ende andere hare Ho:Mo: Gedepu„ teerden tot de saecken vande finantie, om te visiteren, examineren, de voor„ schreve consideratien vande gemelte Heeren va
#
# 194 208
# Phrase: tot de saecken                	match string: tot de saecken
# 	Is gehoort het rapport vande Heeren Schimmelpenningh ende andere hare Ho:Mo: Gedeputeerden tot de saecken vande Westindische Compagnie, heb„ bende ingevolge ende tot voldoeninge van derselver resolutie Com
#
# 91 105
# Phrase: tot de saecken                	match string: tot de saecken
# 	e Missive gestelt sal werden in handen vande Heeren van Gent, ende andere haer Ho:Mo: Gedeputeerden tot de saecken vande Triple Alliancie, om te visiteren, examineren, en daer van rapport te doen.
#
# 363 377

# %% [markdown]
# Many suffixes start with the name of persons or organisations, followed by a comma. To get an overview of which entities are mentioned after this phrase `tot de saecken`, we can do a simple count of suffixes, cut off at the first comma:

# %%
saecken_entity_freq = Counter()

for res in resolutions_1672:
    for para in res.paragraphs:
        matches = saecken_searcher.find_matches(para.text, suffix_size=50)
        for match in matches:
            saecken_entity = match.suffix.split(',')[0]
            saecken_entity_freq.update([saecken_entity])

for saecken_entity, freq in saecken_entity_freq.most_common(50):
    print(f"{saecken_entity: <40}{freq: >5}")
# Out:
#  vande Zee                                462
#  vande Triple Alliantie                    73
#  van Vlaenderen                            46
#  vande Triple Alliancie                    44
#  vande finantie                            44
#  vande Meijerije van ‛s Hertogenbosch      31
#  van Oostvrieslandt                        23
#  vande Landen van Overmase                 22
#  vande Griffie                             20
#  vande Triple alliantie                    19
#  van Oostvrieslant                         17
#  vande Triple Alliantie om te visiteren    12
#  van Denemarcken                            8
#  van de Zee                                 7
#  vande Triple Alliancie om te visiteren     6
#  vande Westindische Compagnie               6
#  van Oost                                   6
#  van Vlaen„ deren                           6
#  vande Triple alliancie                     6
#  vande Meijerie van s'hertogenbosch         6
#  ken vande Zee                              6
#  vande triple Alliantie                     6
#  vande Landen van Overmaze                  5
#  vande Meijerije van ‛s hertogenbosch       5
#  vande zee                                  5
#  vande Zee om te visiteren                  5
#                                             4
#  vande Meije                                4
#  vande financie                             4
#  van Zee                                    4
#  vande Munte                                3
#  vande Meijerije van ‛s Hertogen„ bosch     3
#  vande Meijerije van ‛s herto               3
#  vande Meijerije van shertogenbosch         3
#  vande triple alliantie                     3
#  vande Octroijen                            3
#  vande Triple Alliancie omme te visiteren    2
#  van Sweeden ende Denemarcken               2
#  aen sijne uijtspraecke ende decisie bij allersijt    2
#  van oostvrieslandt                         2
#  vande voorschreve Meijerije                2
#  vande Triple Alliantie omme te visiteren    2
#  daer annex                                 2
#  vande finantie om te visiteren             2
#  militaire saecken                          2
#  van Vlaenderen voornt                      2
#  van Vlaenderen om te visiteren             2
#  vande Zee hebbende ingevolge ende tot voldoeninge    2
#  vande Triple Allian„ tie                   2
#  vande triple Alliantie om te visiteren     2

# %% [markdown]
# Next, we make second searcher to find the phrase _gestelt sullen werden_ and its singular variant _gestelt sal werden_ in the prefix of `tot de saecken`:

# %%
phrases = [
    {
        'phrase': 'gestelt sullen werden',
        'variants': [
            'gestelt sal werden'
        ]
    }
]

config = {
    'levenshtein_threshold': 0.7,
    'ngram_size': 3,
    'skip_size': 1,
    'include_variants': True
}


phrase_model = PhraseModel(phrases, config=config)
prefix_searcher = FuzzyContextSearcher(config)
prefix_searcher.index_phrase_model(phrase_model)

for res in resolutions_1672[:20]:
    print(res.id)
    for para in res.paragraphs:
        saecken_matches = saecken_searcher.find_matches(para.text, prefix_size=150)
        for saecken_match in saecken_matches:
            # first, get the entity mentioned in the suffix
            saecken_entity = match.suffix.split(',')[0]
            # next, search for the prefix phrase in the prefix of 'tot de saecken'
            prefix_matches = prefix_searcher.find_matches(saecken_match.prefix)
            for prefix_match in prefix_matches:
                print(f"{prefix_match.string}\n\t{prefix_match.suffix}")
                print(f"{saecken_match.string}\n\t{saecken_entity}\n")
# Out:
# session-1672-01-07-num-1-resolution-1
# session-1672-01-07-num-1-resolution-2
# gestelt sal werden
# 	 in handen vande Heeren Schimmelpenningh ende andere haer Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren Schimmelpenningh ende andere haer Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# session-1672-01-07-num-1-resolution-3
# gestelt sal werden
# 	 in handen vande Heeren van Ommeren ende andere hare Ho:Mo: Gede,, puteerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren van Ommeren ende andere hare Ho:Mo: Gede,, puteerden
# tot de saecken
# 	 vande Triple Alliantie
#
# session-1672-01-07-num-1-resolution-4
# gestelt sullen werden
# 	 in handen vande Heeren van Gent ende andere hare Ho:Mo: Gedeputeerden
# tot de saken
# 	 vande Triple Alliantie
#
# session-1672-01-07-num-1-resolution-5
# session-1672-01-07-num-1-resolution-6
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere hare Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere hare Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# session-1672-01-07-num-1-resolution-7
# session-1672-01-07-num-1-resolution-8
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere hare Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere hare Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# session-1672-01-07-num-1-resolution-9
# session-1672-01-07-num-1-resolution-10
# session-1672-01-07-num-1-resolution-11
# session-1672-01-12-num-1-resolution-1
# session-1672-01-12-num-1-resolution-2
# session-1672-01-12-num-1-resolution-3
# session-1672-01-12-num-1-resolution-4
# gestelt sal werden
# 	 in handen vande Heeren Schimmelpenninck, ende andere hare Ho:Mo: Gedepu„ teerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren Schimmelpenninck, ende andere hare Ho:Mo: Gedepu„ teerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren Schimmelpenningh ende andere hare Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren Schimmelpenningh ende andere hare Ho:Mo: Gedeputeerden
# tot de saecken
# 	 vande Triple Alliantie
#
# session-1672-01-12-num-1-resolution-5
# session-1672-01-12-num-1-resolution-6
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere hare Ho:Mo: Gede,, puteerden
# tot de saecken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere hare Ho:Mo: Gede,, puteerden
# tot de saecken
# 	 vande Triple Alliantie
#
# session-1672-01-12-num-1-resolution-7
# session-1672-01-12-num-1-resolution-8
# session-1672-01-12-num-1-resolution-9
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere haer Ho:Mo: Gedeputeerden
# tot de saken
# 	 vande Triple Alliantie
#
# gestelt sal werden
# 	 in handen vande Heeren van Gent, ende andere haer Ho:Mo: Gedeputeerden
# tot de saken
# 	 vande Triple Alliantie
