# %% [markdown]
# # Analysing Index Entries
#
# To get an idea of the quality of the lemma extraction, and of the possibility to link lemmas across books, we do an analysis of 145,000 index entries extracted from the resolution books of 1708-1749 (inventories 3763-3804), as these have the same index page layout, with currently (2021-09-03) mostly high-quality OCR output.
#
# Our approach will be to iteratively extract correct lemmas, analysing the remaining unidentified lemmas in the next iteration to improve the later iterations of extractions.

# %%
# This reload library is just used for developing the REPUBLIC hOCR parser 
# and can be removed once this module is stable.
# %reload_ext autoreload
# %autoreload 2


# This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
repo_name = 'republic-project'
repo_dir = os.path.split(os.getcwd())[0].split(repo_name)[0] + repo_name
print("adding project dir to path:", repo_dir)
if repo_dir not in sys.path:
    sys.path.append(repo_dir)
# Out:
# adding project dir to path: /Users/marijnkoolen/Code/Huygens/republic-project

# %%
import re

# Many lemmas have leading and/or trailing punctuation that is not part of
# the proper lemma. 
# The first step is to add a column with cleaned up lemmas.

def clean_start_end(string):
    if type(string) != str:
        return string
    return re.sub(r'\W+$', '', re.sub(r'^\W+', '', string))

# %%
import pandas as pd

# The file with 140,313 index lemma entries
entries_file = '../../data/indices/index_entries-3763-3804-latest.csv.gz'

df = pd.read_csv(entries_file, sep='\t', compression='gzip')

df.head(2)
# Out:
#                    lemma main_term  \
# 0  nee Winter quartieren       nee
# 1  nee Winter quartieren       nee
#
#                                                 text  \
# 0                        nee Winter quartieren, 918.
# 1  aerte tifthop van Gran Brief van felicitatie o...
#
#                                        first_line_id  \
# 0  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
# 1  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
#
#           first_line_scan_id                   first_line_page_id  \
# 0  NL-HaNA_1.01.02_3763_0626  NL-HaNA_1.01.02_3763_0626-page-1251
# 1  NL-HaNA_1.01.02_3763_0626  NL-HaNA_1.01.02_3763_0626-page-1251
#
#                                 first_line_column_id  \
# 0  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
# 1  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
#
#                                         last_line_id  \
# 0  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
# 1  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
#
#            last_line_scan_id                    last_line_page_id  \
# 0  NL-HaNA_1.01.02_3763_0626  NL-HaNA_1.01.02_3763_0626-page-1251
# 1  NL-HaNA_1.01.02_3763_0626  NL-HaNA_1.01.02_3763_0626-page-1251
#
#                                  last_line_column_id
# 0  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...
# 1  NL-HaNA_1.01.02_3763_0626-column-2471-1318-894...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140313 entries, 0 to 140312
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   lemma                 140198 non-null  object
#  1   main_term             140075 non-null  object
#  2   text                  140313 non-null  object
#  3   first_line_id         140313 non-null  object
#  4   first_line_scan_id    140313 non-null  object
#  5   first_line_page_id    140313 non-null  object
#  6   first_line_column_id  140313 non-null  object
#  7   last_line_id          140313 non-null  object
#  8   last_line_scan_id     140313 non-null  object
#  9   last_line_page_id     140313 non-null  object
#  10  last_line_column_id   140313 non-null  object
# dtypes: object(11)
# memory usage: 11.8+ MB

# %%
df.shape
# Out:
# (140313, 11)

# %%
from republic.elastic.republic_elasticsearch import initialize_es

rep_es = initialize_es(host_type='external', timeout=60)

query = {
    #'size': 0,
    #'track_total_hits': True,
    #'query': {
        'range': {
            'metadata.session_year': {
                'gte': 1708,
                'lte': 1749
            }
        }
    #}
}


response = rep_es.es_anno.search(index='resolutions', query=query, size=0, track_total_hits=True)
print('Total number of resolutions in period 1708-1749:', response['hits']['total']['value'])
# Out:
# Total number of resolutions in period 1708-1749: 157026

# %%
list(df[df.text.str.contains('pestil')].text)
# Out:
# ['te enamineeren de communicatie van Gelderland weegens de pestilentiaale Sieckte in Seevenbergen. 656.']

# %%
from IPython.display import HTML

# check the number of distinct lemmas and how often they occur
print(len(df.lemma.value_counts()))
df.lemma.value_counts().head(20).to_frame(name="# Sublemma's").reset_index().rename(columns={"index": "Hoofdterm"})
# Out:
# 15801
#                      Hoofdterm  # Sublemma's
# 0                    Pasporten          2924
# 1             's Hertogenbosch          2784
# 2                      Holland          2566
# 3              Raad van Staate          1809
# 4                    Militaire          1516
# 5             Militaire saaken          1470
# 6            Militaire saacken          1443
# 7                   Vlaanderen          1368
# 8                  Brieven van          1124
# 9                            E          1064
# 10            Raad van Staate.          1043
# 11            Raadt van Staate           979
# 12                         Hop           956
# 13                    Finantie           903
# 14  Admiraliteyt tot Amsterdam           867
# 15                   Groningen           828
# 16             Raadt van State           794
# 17                  Commissien           709
# 18                    Hollandt           707
# 19                     Zeeland           687

# %% [markdown]
# There are ~~19662~~15801 distinct lemmas, some with more than 2000 entries, many with only a single entry.
#
# The lemmas with many entries are probably correct in the sense that they have no OCR errors, but we need a reasoned approach to identifying the correct lemmas and mapping the lemmas with OCR errors to their correct counterparts.
#
# Repeated entries of the same lemma in a single book don't repeat the lemma itself, so the lemma term is copied in the extraction process. To get an idea of whether a lemma appears multiplle times with the exact same orthography, we should look at how often they occur with that same orthography across books.

# %%
# Rename the lemma column to ocr_lemma, so we know this is the raw extracted text with potential errors.
df = df.rename(columns={'lemma': 'ocr_lemma'})
df.shape
# Out:
# (140313, 11)

# %%
df['clean_lemma'] = df.ocr_lemma.apply(clean_start_end)
df.clean_lemma.value_counts().head(20).to_frame(name="# Sublemma's").reset_index().rename(columns={"index": "Hoofdterm"})
# Out:
#                      Hoofdterm  # Sublemma's
# 0                    Pasporten          3583
# 1                      Holland          3161
# 2              Raad van Staate          2875
# 3              s Hertogenbosch          2856
# 4                   Vlaanderen          1525
# 5                    Militaire          1516
# 6             Militaire saaken          1470
# 7            Militaire saacken          1443
# 8                  Brieven van          1124
# 9                            E          1066
# 10                         Hop          1029
# 11                    Finantie           984
# 12            Raadt van Staate           979
# 13  Admiraliteyt tot Amsterdam           935
# 14                     Zeeland           855
# 15                   Groningen           828
# 16             Raadt van State           794
# 17                  Gelderland           747
# 18                     Utrecht           723
# 19                  Commissien           709

# %% [markdown]
# Cleaning up the OCR lemmas reduced the number of distinct lemmas from ~~19662~~15801 to ~~19182~~15561, so some of the terms with surrounding punctuation are now mapped onto other OCR lemmas.

# %% [markdown]
# ## Creating links from index entries to IIIF images

# %%
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3785/NL-HaNA_1.01.02_3785_0047.jpg/full/full/0/default.jpg

def get_line_iiif_url(line_id, margin=100):
    elements = parse_line_id_elements(line_id)
    return get_iiif_url(elements['inventory_num'], elements['scan_id'], elements['line_coords'], margin=margin)

def get_column_iiif_url(line_id, margin=100):
    elements = parse_line_id_elements(line_id)
    return get_iiif_url(elements['inventory_num'], elements['scan_id'], elements['column_coords'], margin=margin)

def get_iiif_url(inv_num, scan_id, coords, margin=100):
    coords_string = f"{coords[0]-margin},{coords[1]-margin},{coords[2]+2*margin},{coords[3]+2*margin}"
    base_url = 'https://images.diginfra.net/iiif/NL-HaNA_1.01.02/'
    return f"{base_url}{inv_num}/{scan_id}.jpg/{coords_string}/full/0/default.jpg"

def parse_line_id_elements(line_id):
    scan_id, rest = line_id.split('-column-')
    inventory_num = scan_id.split('_')[2]
    column_coords, line_coords = rest.split('-line-')
    return {
        'scan_id': scan_id,
        'inventory_num': inventory_num,
        'column_coords': [int(coord) for coord in column_coords.split('-')],
        'line_coords': [int(coord) for coord in line_coords.split('-')]
    }

for line_id in list(df[df.clean_lemma == 'porten'].first_line_id):
    elements = parse_line_id_elements(line_id)
    line_iiif_url = get_line_iiif_url(line_id, margin=100)
    column_iiif_url = get_column_iiif_url(line_id, margin=100)
    print(elements['inventory_num'], elements['scan_id'], elements['line_coords'])
    print(line_iiif_url)
# Out:
# 3769 NL-HaNA_1.01.02_3769_0013 [1486, 497, 251, 47]
# https://images.diginfra.net/iiif/NL-HaNA_1.01.02/3769/NL-HaNA_1.01.02_3769_0013.jpg/1386,397,451,247/full/0/default.jpg

# %%
df['line_iiif_url'] = df.first_line_id.apply(get_line_iiif_url)
df['column_iiif_url'] = df.first_line_id.apply(get_column_iiif_url)

# %% [markdown]
# ## Add inventory source
#
# Each entries comes from a book that is identified by its inventory number. In these books, each lemma is mentioned only once in the index, but the lemma can have multiple entries, where the lemma term is omitted after the first entry, and replaced by a repeat symbol (`____`).
#
# By adding the inventory number for each entry in a separate column, we can group entries per year.

# %%
# The line IDs contain the inventory number of the book from which the
# entry was extracted.
# We add a column with the inventory number so we can check which lemmas 
# occur in multiple books, therefore need to be linked and are more 
# likely to be correct lemmas (lemmas with OCR errors are less likely
# to occur with precisely the same errors across multiple books)

df['inventory'] = df.first_line_id.apply(lambda x: x.split('_')[2])
df.inventory.nunique()
# Out:
# 42

# %%
df[(df.inventory == '3798') & (df.first_line_page_id == 'NL-HaNA_1.01.02_3798_0034-page-67')]
# Out:
#          ocr_lemma   main_term  \
# 115041       Paltz       Paltz
# 115042       Paltz       Paltz
# 115043       Paltz       Paltz
# 115044       Paltz       Paltz
# 115045       Paltz       Paltz
# 115046       Paltz       Paltz
# 115047       Paltz       Paltz
# 115048       Paltz       Paltz
# 115049  Paraviciny  Paraviciny
# 115050  Paraviciny  Paraviciny
# 115051  Paraviciny  Paraviciny
# 115052  Paraviciny  Paraviciny
# 115053  Paraviciny  Paraviciny
# 115054  Paraviciny  Paraviciny
# 115055      Pardon      Pardon
# 115056   Pasporten   Pasporten
# 115057   Pasporten   Pasporten
# 115058   Pasporten           .
# 115059   Pasporten           .
# 115060   Pasporten           .
# 115061   Pasporten           .
# 115062   Pasporten           .
# 115063   Pasporten           .
# 115064   Pasporten           .
# 115065   Pasporten           .
# 115066   Pasporten           .
# 115067   Pasporten           .
# 115068   Pasporten           .
# 115069   Pasporten           .
# 115070   Pasporten           .
# 115071   Pasporten           .
# 115072   Pasporten           .
# 115073   Pasporten           .
# 115074   Pasporten           .
# 115075   Pasporten           .
# 115076   Pasporten           .
# 115077   Pasporten           .
# 115078   Pasporten           .
# 115079   Pasporten           .
# 115080   Pasporten           .
# 115081   Pasporten           .
# 115082   Pasporten           .
# 115083   Pasporten           .
# 115084   Pasporten           .
# 115085   Pasporten           .
# 115086   Pasporten           .
# 115087   Pasporten           .
#
#                                                      text  \
# 115041  versoeck om den stluen te ontstaan, de Raad va...
# 115042  Creditif op van Asten als Agent, en aangenaam....
# 115043  klaghten over ontireckingh van Jerri- zoir in ...
# 115044  versoght de schuldige aan gepleeghde geweldena...
# 115045  notificeerende dat Meyer afgesonden had om ove...
# 115046  Pasport tot de vrye passagie van duy- Jend las...
# 115047  antwoord weegens quade behandelingh van Bedien...
# 115048  antwoord wegens de passagie vau sis honderd la...
# 115049   Paraviciny advertentie. 279. 302. 420. 588. 589.
# 115050  antwoord weegens bet vijiteeren van Scheepen v...
# 115051                          declaratie. 92. 281. g90.
# 115052  de Groot gelast te betaalen drie dûy- send een...
# 115053  versoeck om aan de Schippers te gelasten niet ...
# 115054  divoir te doen iegens de onordenteliscke proce...
# 115055                    Pardon, net Brieven van Pardon.
# 115056  Pasporten, ad omnes Populos voor Chriftof- fes...
# 115057  voor Lemmens en Graaven tot den uyt- voer van ...
# 115058  . voor Veldman om honderd aght Snap- haanen va...
# 115059  voor Fogliant om eenige Meubilen na Hamburgh t...
# 115060                    ad omnes Populos voor Goge. 52.
# 115061  woor Podewils om eenigh Hout te mvo- gen in- e...
# 115062                 ad omnes Populos voor Hasselaar. D
# 115063  woor Lemmens en Graven tot den uyt- voer van M...
# 115064  woor Sumts tor den uytvoer van Mon- teeringh v...
# 115065  voor Suits rot den uytvoer van Mon- teeringb v...
# 115066  voor Elin en Soonen tot den uytvoer van Muntee...
# 115067  voor Elsacker om de Bagage van den Baron van H...
# 115068  voor de Ofiicieren van Sandouville om ses en t...
# 115069  voor Zeeland om Snaphaanen en Mus- quetten van...
# 115070  woor Feitema tot de passagie van de Bagagie va...
# 115071  voor Togliani om Jijn Goederen na Engeland te ...
# 115072  woor Schack om vier en twintigb Paarden te moo...
# 115073  woor Lingius om cenige Goederen na Yperen te m...
# 115074  voor Praetorius om aght Paarden ie moogen invo...
# 115075  woor Lemmens en Graum rot den uyt- voer van Mo...
# 115076  woor Cornalé tot den uytvoer van Monteeringb v...
# 115077             ad omnes Populos wor Krzidlowsti. 107.
# 115078                 voor Patot om twee Koerspaarden DO
NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...  Paraviciny
# 115054  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...  Paraviciny
# 115055  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...      Pardon
# 115056  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115057  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115058  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115059  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115060  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115061  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115062  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115063  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115064  NL-HaNA_1.01.02_3798_0034-column-2650-472-907-...   Pasporten
# 115065  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115066  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115067  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115068  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115069  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115070  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115071  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115072  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115073  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115074  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115075  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115076  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115077  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115078  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115079  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115080  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115081  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115082  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115083  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115084  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115085  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115086  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
# 115087  NL-HaNA_1.01.02_3798_0034-column-3636-462-922-...   Pasporten
#
#                                             line_iiif_url  \
# 115041  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115042  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115043  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115044  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115045  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115046  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115047  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115048  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115049  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115050  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115051  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115052  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115053  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115054  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115055  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115056  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115057  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115058  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115059  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115060  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115061  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115062  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115063  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115064  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115065  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115066  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115067  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115068  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115069  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115070  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115071  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115072  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115073  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115074  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115075  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115076  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115077  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115078  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115079  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115080  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115081  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115082  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115083  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115084  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115085  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115086  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 115087  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                           column_iiif_url inventory
# 115041  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115042  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115043  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115044  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115045  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115046  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115047  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115048  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115049  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115050  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115051  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115052  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115053  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115054  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115055  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115056  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115057  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115058  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115059  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115060  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115061  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115062  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115063  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115064  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115065  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115066  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115067  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115068  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115069  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115070  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115071  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115072  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115073  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115074  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115075  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115076  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115077  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115078  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115079  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115080  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115081  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115082  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115083  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115084  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115085  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115086  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798
# 115087  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3798

# %%
# There are entries from 42 different books. 

# Next step, count the number of books in which each clean lemma occurs
df[['clean_lemma', 'inventory']].drop_duplicates().clean_lemma.value_counts().head(20).to_frame(name="# Indices").reset_index().rename(columns={"index": "Hoofdterm"})
# Out:
#                      Hoofdterm  # Indices
# 0                        Breda         40
# 1                     Finantie         38
# 2                      Utrecht         35
# 3              s Hertogenbosch         35
# 4                          Hop         34
# 5                    Groningen         34
# 6                   Vlaanderen         33
# 7           Levantschen Handel         32
# 8                     Pruyssen         31
# 9                    Overyssel         31
# 10                    Patenten         31
# 11  Admiraliteyt tot Amsterdam         30
# 12                   van Deurs         30
# 13                       Rumpf         30
# 14               Voorschryvens         30
# 15                   Hochepied         29
# 16                 vander Meer         29
# 17                        Buys         29
# 18               Gedeputeerden         29
# 19                     Lemmens         29

# %%
df[(df.clean_lemma == 'Admiraliteyten in het') & df.text.str.startswith('Admiraliteyten in het') == True]
# Out:
#                     ocr_lemma       main_term  \
# 41865   Admiraliteyten in het  Admiraliteyten
# 49160   Admiraliteyten in het  Admiraliteyten
# 75376   Admiraliteyten in het  Admiraliteyten
# 125079  Admiraliteyten in het  Admiraliteyten
# 125094  Admiraliteyten in het  Admiraliteyten
# 125138  Admiraliteyten in het  Admiraliteyten
# 125159  Admiraliteyten in het  Admiraliteyten
# 125178  Admiraliteyten in het  Admiraliteyten
# 133377  Admiraliteyten in het  Admiraliteyten
# 133400  Admiraliteyten in het  Admiraliteyten
# 133419  Admiraliteyten in het  Admiraliteyten
# 133441  Admiraliteyten in het  Admiraliteyten
https://images.diginfra.net/iiif/NL-HaNA_1.01....      3803

# %% [markdown]
# Of the ~~19,182~~15,561 distinct terms, some occur in the vast majority of books, while many occur in only one. The latter are more likely to contain OCR errors, although there are also rare but correct lemmas among them.
#
# We inspect the lemmas occuring in at least half of the books to see if they contain any obvious OCR errors:

# %%
s1 = df.clean_lemma.value_counts()
s2 = df[['clean_lemma', 'inventory']].drop_duplicates().clean_lemma.value_counts()
#.to_frame().rename(columns={'clean_lemma': 'Entries'}).head(5)

pd.concat([s1.to_frame().rename(columns={'clean_lemma': "# Sublemma's"}), s2.to_frame().rename(columns={'clean_lemma': '# Indices'})], axis=1).reset_index().rename(columns={"index": "Hoofdterm"}).head(20)
# Out:
#                      Hoofdterm  # Sublemma's  # Indices
# 0                    Pasporten          3583         29
# 1                      Holland          3161         24
# 2              Raad van Staate          2875         17
# 3              s Hertogenbosch          2856         35
# 4                   Vlaanderen          1525         33
# 5                    Militaire          1516          9
# 6             Militaire saaken          1470         13
# 7            Militaire saacken          1443         10
# 8                  Brieven van          1124         19
# 9                            E          1066         14
# 10                         Hop          1029         34
# 11                    Finantie           984         38
# 12            Raadt van Staate           979          5
# 13  Admiraliteyt tot Amsterdam           935         30
# 14                     Zeeland           855         20
# 15                   Groningen           828         34
# 16             Raadt van State           794          6
# 17                  Gelderland           747         18
# 18                     Utrecht           723         35
# 19                  Commissien           709         28

# %%
pd.concat([s2.to_frame().rename(columns={'clean_lemma': "# Indices"}), s1.to_frame().rename(columns={'clean_lemma': "# Sublemma's"})], axis=1).reset_index().rename(columns={"index": "Hoofdterm"}).head(20)
# Out:
#                      Hoofdterm  # Indices  # Sublemma's
# 0                        Breda         40           471
# 1                     Finantie         38           984
# 2                      Utrecht         35           723
# 3              s Hertogenbosch         35          2856
# 4                          Hop         34          1029
# 5                    Groningen         34           828
# 6                   Vlaanderen         33          1525
# 7           Levantschen Handel         32           185
# 8                     Pruyssen         31           308
# 9                    Overyssel         31           671
# 10                    Patenten         31           193
# 11  Admiraliteyt tot Amsterdam         30           935
# 12                   van Deurs         30           111
# 13                       Rumpf         30           594
# 14               Voorschryvens         30           209
# 15                   Hochepied         29           114
# 16                 vander Meer         29           664
# 17                        Buys         29           135
# 18               Gedeputeerden         29           386
# 19                     Lemmens         29           214

# %%
s = df[['clean_lemma', 'inventory']].drop_duplicates().clean_lemma.value_counts()

sorted(list(s[s >= 21].index))
# Out:
# ['Admiraliteyt in het Noorder Quartier',
#  'Admiraliteyt tot Amsterdam',
#  'Barbaryen',
#  'Bergen op den Zoom',
#  'Bescheyt',
#  'Beyeren',
#  'Bleyswyck',
#  'Boodens',
#  'Bosch',
#  'Breda',
#  'Bruyninx',
#  'Buys',
#  'Colyear',
#  'Commissien',
#  'Credentie',
#  'Cronstrom',
#  'Finantie',
#  'Gedeputeerden',
#  'Gerbrants',
#  'Groningen',
#  'Grys',
#  'Heysterman',
#  'Hochepied',
#  'Hogendorp',
#  'Holland',
#  'Hompesch',
#  'Hop',
#  'Hoyer',
#  'Hudson',
#  'Instructie',
#  'Keulen',
#  'Lemmens',
#  'Levantschen Handel',
#  'Luyck',
#  'Meyer',
#  'Mol',
#  'Octroyen',
#  'Overduyn',
#  'Overmaze',
#  'Overyssel',
#  'Paltz',
#  'Pardon',
#  'Pasporten',
#  'Patenten',
#  'Pruyssen',
#  'Revisie',
#  'Rumpf',
#  'Serres',
#  'Siet',
#  'Smits',
#  'Spina',
#  'Suriname',
#  'Utrecht',
#  'Vlaanderen',
#  'Voorschryvens',
#  'de Groot',
#  'de Jongh',
#  's Gravesande',
#  's Hertogenbosch',
#  'van Breugel',
#  'van Deurs',
#  'van Hoey',
#  'van Rechteren',
#  'vanden Bergh',
#  'vanden Heuvel',
#  'vander Burgh',
#  'vander Duyn',
#  'vander Goes',
#  'vander Haar',
#  'vander Meer',
#  'vander Meulen',
#  'vander Swaan',
#  'vander Weyde']

# %% [markdown]
# ~~There are a few very short terms with stopwords like *om*, *en*, partial words like *gen* and *ren*~~ and the empty string ''. But the rest looks good.

# %%
non_lemmas = {
    '',
    'en',
    'gen',
    'om',
    'ren',
}

print(df[df.clean_lemma.isin(non_lemmas)].shape)

df[df.clean_lemma.isin(non_lemmas)].head(5)[['clean_lemma', 'text']]
# Out:
# (539, 15)
#      clean_lemma                                               text
# 1950                         ) diers te veranderen in de lauwe Gar-
# 1951                                            des te voet, 12337.
# 3479          om                 om garantie op negotiatie, 1490. Q
# 3483          om                 om een Cômpagnie onder Cars éf wel
# 3631         ren  ren en Waren, 129. Resolutie van haer Hoogh Mo...

# %% [markdown]
# There are also some rows with empty lemma terms. So something went wrong with these entries.

# %%
print(df[df.clean_lemma.isna() == True].shape)
df[df.clean_lemma.isna() == True].head(2)
# Out:
# (115, 15)
#       ocr_lemma main_term                                     text  \
# 62849       NaN       NaN  , teyts Reekenkamer te adviseeren. 7oo.
# 71110       NaN       NaN               , cheeren voor Perez. 438.
#
#                                            first_line_id  \
# 62849  NL-HaNA_1.01.02_3784_0024-column-2560-452-926-...
# 71110  NL-HaNA_1.01.02_3786_0034-column-3446-432-889-...
#
#               first_line_scan_id                 first_line_page_id  \
# 62849  NL-HaNA_1.01.02_3784_0024  NL-HaNA_1.01.02_3784_0024-page-47
# 71110  NL-HaNA_1.01.02_3786_0034  NL-HaNA_1.01.02_3786_0034-page-67
#
#                                     first_line_column_id  \
# 62849  NL-HaNA_1.01.02_3784_0024-column-2560-452-926-...
# 71110  NL-HaNA_1.01.02_3786_0034-column-3446-432-889-...
#
#                                             last_line_id  \
# 62849  NL-HaNA_1.01.02_3784_0024-column-2560-452-926-...
# 71110  NL-HaNA_1.01.02_3786_0034-column-3446-432-889-...
#
#                last_line_scan_id                  last_line_page_id  \
# 62849  NL-HaNA_1.01.02_3784_0024  NL-HaNA_1.01.02_3784_0024-page-47
# 71110  NL-HaNA_1.01.02_3786_0034  NL-HaNA_1.01.02_3786_0034-page-67
#
#                                      last_line_column_id clean_lemma  \
# 62849  NL-HaNA_1.01.02_3784_0024-column-2560-452-926-...         NaN
# 71110  NL-HaNA_1.01.02_3786_0034-column-3446-432-889-...         NaN
#
#                                            line_iiif_url  \
# 62849  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 71110  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                          column_iiif_url inventory
# 62849  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3784
# 71110  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3786

# %% [markdown]
# These short non-lemma entries look like extraction mistakes. Before continuing, we drop them from the list and write them to file as entries with extraction mistakes.

# %%
s = df[df.inventory == '3765'].ocr_lemma.value_counts()
s[s > 10]
# Out:
# mende                                 74
# Lumge-                                73
# Spaeniche Nederlanden Gouvernement    65
# Militaire laken                       56
# Brûsel                                50
# Overquantier van Gelderlandt          49
# Declaratien                           47
# Voorschryvens                         44
# Paltz;                                38
# Denemarcken                           37
# Pruyssen                              36
# Vlaenderen                            34
# Rysel                                 31
# Commiftien                            30
# Doomiek                               26
# Commissien                            26
# Luyek                                 25
# Quinze                                22
# Engelandt                             21
# gelyi                                 20
# s Hertogenbosch                       19
# Ooff-Vrieslandt                       19
# ZZ de Militie                         19
# Geneniiteyt Rekenkamer                18
# Duytiche Hoven                        17
# Octroyen                              17
# na                                    17
# Stockholm                             17
# overysel                              16
# de Pallsseh Treupes                   15
# Commissie van de Militie te Lande     15
# bert                                  14
# Douay                                 14
# Zwitserlandt                          14
# Hamburgh                              13
# Admiraliteyt tot Amsterdam            13
# savoyen                               12
# Tilly                                 12
# Venlo                                 12
# Vrieslandt                            12
# Admiriliteyt op de Maze               12
# Admiraliteyt in Zeelande              12
# Cuyck                                 11
# Breda                                 11
# Groeningen                            11
# Name: ocr_lemma, dtype: int64

# %% [markdown]
# ## Analysing Likely Mistakes

# %%
mistakes_file = '../../data/indices/index_entries-3763-3804-mistakes.csv'

mistakes_df = df[(df.clean_lemma.isin(non_lemmas)) | (df.clean_lemma.isna() == True)]
print(mistakes_df.shape)
mistakes_df.to_csv(mistakes_file, sep='\t')

# Drop the entries of lemmas with mistakes from the main data frame
df = df[(df.clean_lemma.isin(non_lemmas) == False) & (df.clean_lemma.isna() == False)]


df.shape
# Out:
# (654, 15)
# (139659, 15)

# %%
mistakes_df[['ocr_lemma', 'clean_lemma']].value_counts()
# Out:
# ocr_lemma  clean_lemma
# ren        ren            344
# &                          56
# .-                         31
# en         en              20
# /                          18
# )                          13
# om         om              13
# gen        gen             12
# ;                          10
# gen.       gen              5
# |                           3
# ren.       ren              3
# \                           3
# '                           2
# -.                          2
# »                           2
# >                           1
# ).                          1
# dtype: int64

# %%
mistakes_df.inventory.value_counts().head(5)
# Out:
# 3792    127
# 3764    111
# 3786     76
# 3779     68
# 3798     52
# Name: inventory, dtype: int64

# %%
mistakes_df[mistakes_df.inventory == '3792'].first_line_page_id.value_counts()
# Out:
# NL-HaNA_1.01.02_3792_0387-page-772    44
# NL-HaNA_1.01.02_3792_0386-page-770    32
# NL-HaNA_1.01.02_3792_0386-page-771    31
# NL-HaNA_1.01.02_3792_0385-page-769    20
# Name: first_line_page_id, dtype: int64

# %%
df[(df.inventory == '3792') & (df.first_line_page_id == 'NL-HaNA_1.01.02_3792_0385-page-769')]
# Out:
#                ocr_lemma  main_term  \
# 91384  Militaire saacken  Militaire
# 91385  Militaire saacken  Militaire
# 91386  Militaire saacken  Militaire
# 91387  Militaire saacken  Militaire
# 91388  Militaire saacken  Militaire
# 91389  Militaire saacken  Militaire
# 91390  Militaire saacken  Militaire
# 91391  Militaire saacken  Militaire
# 91392  Militaire saacken  Militaire
# 91393  Militaire saacken  Militaire
# 91394  Militaire saacken  Militaire
https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792

# %%
mistakes_df[mistakes_df.inventory == '3792'].first_line_page_id.value_counts()
# Out:
# NL-HaNA_1.01.02_3792_0387-page-772    44
# NL-HaNA_1.01.02_3792_0386-page-770    32
# NL-HaNA_1.01.02_3792_0386-page-771    31
# NL-HaNA_1.01.02_3792_0385-page-769    20
# Name: first_line_page_id, dtype: int64

# %%
mistakes_df[(mistakes_df.inventory == '3792') & (mistakes_df.first_line_page_id == 'NL-HaNA_1.01.02_3792_0385-page-769')]
# Out:
#       ocr_lemma main_term                                               text  \
# 91403       ren       ren      ren weegens het defect in baare Militie. 137-
# 91404       ren       ren  Carel Lodewyck van Wassenaer op sijn versoeck ...
# 91405       ren       ren  consent van Vriesland in den Staat van Oorlogh...
# 91406       ren       ren  Grave van Hompesch aangesteld tot Gouverneur v...
# 91407       ren       ren  Vriesland en Overyssel om vermeer - deringh va...
# 91408       ren       ren  Resolutie van Zeeland raakende de incompleethe...
# 91409       ren       ren  Pasport voor de Officieren van bert Esquadron ...
# 91410       ren       ren     Zeeland consent in den Staat van Oorlogh, 1.9.
# 91411       ren       ren  Passport voor Smits tot den uytvoer van Montee...
# 91412       ren       ren  antwoord van den Bisschop en Prince wan Luyck,...
# 91413       ren       ren                   Colyear ses maanden verlof. 155.
# 91414       ren       ren  van Hambroeck ses maanden verlof, en commando ...
# 91415       ren       ren  Hirzel gepermitteert sigb naar Aken en van daa...
# 91416       ren       ren  Pasport voor Guerin tot den uytvoer van ses hu...
# 91417       ren       ren  Pasport voor Lemmens en Graaven tot den uytvoe...
# 91418       ren       ren  Pasport voor Lemmens en Graaven tot den uytvoe...
# 91419       ren       ren  Pasport voor Lemmens en Graaven tot den uytvoe...
# 91420       ren       ren  Pasport voor Lemmens en Graaven tot den uytvoe...
# 91421       ren       ren  wan Swaanenbergh vier maanden ver- lof, en com...
# 91422       ren       ren  Churfurse van de Paltz versogbt by de verander...
#
#                                            first_line_id  \
# 91403  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91404  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91405  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91406  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91407  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91408  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91409  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91410  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91411  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91412  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91413  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91414  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91415  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91416  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91417  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91418  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91419  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91420  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91421  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91422  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
#
#               first_line_scan_id                  first_line_page_id  \
# 91403  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91404  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91405  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91406  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91407  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91408  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91409  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91410  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91411  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91412  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91413  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91414  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91415  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91416  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91417  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91418  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91419  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91420  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91421  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91422  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
#
#                                     first_line_column_id  \
# 91403  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91404  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91405  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91406  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91407  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91408  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91409  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91410  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91411  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91412  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91413  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91414  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91415  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91416  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91417  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91418  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91419  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91420  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91421  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91422  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
#
#                                             last_line_id  \
# 91403  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91404  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91405  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91406  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91407  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91408  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91409  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91410  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91411  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91412  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91413  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91414  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91415  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91416  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91417  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91418  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91419  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91420  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91421  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...
# 91422  NL-HaNA_1.01.02_3792_0386-column-410-429-913-2...
#
#                last_line_scan_id                   last_line_page_id  \
# 91403  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91404  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91405  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91406  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91407  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91408  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91409  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91410  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91411  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91412  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91413  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91414  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91415  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91416  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91417  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91418  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91419  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91420  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91421  NL-HaNA_1.01.02_3792_0385  NL-HaNA_1.01.02_3792_0385-page-769
# 91422  NL-HaNA_1.01.02_3792_0386  NL-HaNA_1.01.02_3792_0386-page-770
#
#                                      last_line_column_id clean_lemma  \
# 91403  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91404  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91405  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91406  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91407  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91408  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91409  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91410  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91411  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91412  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91413  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91414  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91415  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91416  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91417  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91418  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91419  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91420  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91421  NL-HaNA_1.01.02_3792_0385-column-3561-445-915-...         ren
# 91422  NL-HaNA_1.01.02_3792_0386-column-410-429-913-2892         ren
#
#                                            line_iiif_url  \
# 91403  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91404  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91405  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91406  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91407  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91408  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91409  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91410  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91411  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91412  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91413  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91414  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91415  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91416  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91417  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91418  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91419  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91420  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91421  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 91422  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                          column_iiif_url inventory
# 91403  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91404  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91405  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91406  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91407  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91408  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91409  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91410  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91411  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91412  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91413  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91414  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91415  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91416  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91417  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91418  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91419  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91420  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91421  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792
# 91422  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3792

# %% [markdown]
# ## Extracting Likely Correct Lemmas

# %%
s = df[['clean_lemma', 'inventory']].drop_duplicates().clean_lemma.value_counts()

# Extract the lemmas occuring in at least 21 books as correct lemmas
correct_lemmas =  set(s[s >= 21].index)

# %%
s = df[['clean_lemma', 'inventory']].drop_duplicates().clean_lemma.value_counts()

# Extract the lemmas occuring in at least 21 books as correct lemmas
correct_lemmas =  set(s[s >= 21].index)

correct_file = '../../data/indices/index_entries-3763-3804-correct_lemmas.csv'

# create a new data frame with only the correct lemmas entries
correct_df = df[df.clean_lemma.isin(correct_lemmas)]

# Drop the entries of correct lemmas from the main data frame
df = df[df.clean_lemma.isin(correct_lemmas) == False]

# in the correct lemma data frame, add a new column to explicitly label the correct lemma
correct_df['correct_lemma'] = correct_df.clean_lemma

# write the correct lemma data frame to file for later use
correct_df.to_csv(correct_file, sep='\t')


df.shape
# Out:
# (112813, 15)

# %%
correct_df[correct_df.clean_lemma.str.contains('Bergen op')].head(5)
# Out:
#               ocr_lemma main_term  \
# 189  Bergen op den Zoom    Bergen
# 190  Bergen op den Zoom    Bergen
# 191  Bergen op den Zoom    Bergen
# 192  Bergen op den Zoom    Bergen
# 193  Bergen op den Zoom    Bergen
#
#                                                   text  \
# 189  Bergen op den Zoom, Vilatte versoeckt met het ...
# 190                 item den Grave van Oxenstern, 578.
# 191                         item Paron Friesheym, 581.
# 192           item Dompré, Lieutenant Ge- nerael, 581.
# 193                              item Baron Spar, sor.
#
#                                          first_line_id  \
# 189  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 190  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 191  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 192  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 193  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
#
#             first_line_scan_id                   first_line_page_id  \
# 189  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 190  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 191  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 192  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 193  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
#
#                                   first_line_column_id  \
# 189  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 190  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 191  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 192  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 193  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
#
#                                           last_line_id  \
# 189  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 190  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 191  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 192  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
# 193  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...
#
#              last_line_scan_id                    last_line_page_id  \
# 189  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 190  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 191  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 192  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
# 193  NL-HaNA_1.01.02_3763_0628  NL-HaNA_1.01.02_3763_0628-page-1255
#
#                                    last_line_column_id         clean_lemma  \
# 189  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...  Bergen op den Zoom
# 190  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...  Bergen op den Zoom
# 191  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...  Bergen op den Zoom
# 192  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...  Bergen op den Zoom
# 193  NL-HaNA_1.01.02_3763_0628-column-3442-417-970-...  Bergen op den Zoom
#
#                                          line_iiif_url  \
# 189  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 190  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 191  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 192  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 193  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                        column_iiif_url inventory  \
# 189  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3763
# 190  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3763
# 191  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3763
# 192  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3763
# 193  https://images.diginfra.net/iiif/NL-HaNA_1.01....      3763
#
#           correct_lemma
# 189  Bergen op den Zoom
# 190  Bergen op den Zoom
# 191  Bergen op den Zoom
# 192  Bergen op den Zoom
# 193  Bergen op den Zoom

# %%
#correct_lemmas
import sys

#!{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install sparse_dot_topn
# Out:
# Collecting sparse_dot_topn
#   Downloading sparse_dot_topn-0.3.1.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.2.3 in /Users/marijnkoolen/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages (from sparse_dot_topn) (1.7.3)
# Requirement already satisfied: numpy>=1.16.6 in /Users/marijnkoolen/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages (from sparse_dot_topn) (1.22.1)
# Requirement already satisfied: setuptools>=42 in /Users/marijnkoolen/.local/share/virtualenvs/impfic-review-analysis-r1tSSDnw/lib/python3.9/site-packages (from sparse_dot_topn) (60.10.0)
# Collecting cython>=0.29.15
#   Using cached Cython-0.29.28-py2.py3-none-any.whl (983 kB)
# Building wheels for collected packages: sparse-dot-topn
#   Building wheel for sparse-dot-topn (pyproject.toml) ... done
#   Created wheel for sparse-dot-topn: filename=sparse_dot_topn-0.3.1-cp39-cp39-macosx_10_9_x86_64.whl size=296962 sha256=e6a1cc4ff1b8481a648d17c9b9352b0d4889bbaf0408e4bc9cdcf9b99026117b
#   Stored in directory: /Users/marijnkoolen/Library/Caches/pip/wheels/07/0b/f4/7f1cf4237f41f6eeacfc8f6b1859ee0a51abf369a940c8823c
# Successfully built sparse-dot-topn
# Installing collected packages: cython, sparse-dot-topn
# Successfully installed cython-0.29.28 sparse-dot-topn-0.3.1

# %%
from republic.extraction.extract_index_entries import LemmaGrouper

lemma_grouper = LemmaGrouper(use_lowercase=True, debug_level=1)

ocr_lemmas = list(df.clean_lemma.drop_duplicates())

lemma_grouper.set_idf(ocr_lemmas + list(correct_lemmas))
# Out:
# setting IDF for 15556 terms

# %%
lemma_grouper.group_terms_by_base_terms(ocr_lemmas, correct_lemmas)
# Out:
# setting IDF for 15556 terms
# Term TF-IDF matrix has shape: (15483, 6948)
# Base term TF-IDF matrix has shape: (73, 6948)
# Coord matrix has shape: (15483, 73)
# number of groups: 73
# number of grouped terms: 239

# %% [markdown]
# Make a mapping of each lemma term and the inventories it occurs in, so it's easy to compare which lemmas occur in at least one inventory together.
#
# The insight here is that if two different lemma terms appear in a single inventory, they must be distinct terms no matter how similar they are, otherwise they would have used only a single lemma and repeat symbols.
#
# For example, the terms `Luyck` and `Luycken` are grouped by the lemma grouper, but they are listed as separate lemmas in the index pages of both inventories 3778 and 3780. If `Luycken` were a misrecognition of `Luyck`, they would no co-occur with distinct lemmas within 3778 and 3780.

# %%
from collections import defaultdict

inv_map = defaultdict(set)

temp_df = df[['clean_lemma', 'inventory']].drop_duplicates()

for index, row in temp_df.iterrows():
    inv_map[row['clean_lemma']].add(row['inventory'])

temp_df = correct_df[['clean_lemma', 'inventory']].drop_duplicates()

for index, row in temp_df.iterrows():
    inv_map[row['clean_lemma']].add(row['inventory'])

# %%
import numpy as np

def terms_share_inventory(term1, term2, inv_map):
    return len(inv_map[term1].intersection(inv_map[term2])) > 0

lemma_map = {}

for term in sorted(lemma_grouper.group_lookup):
    correct_lemma = lemma_grouper.group_lookup[term]
    if terms_share_inventory(term, correct_lemma, inv_map):
        continue
    if term == correct_lemma:
        continue
    # m
    lemma_map[term] = correct_lemma

# %%
# add the correct lemma in a separate column to the mapped ocr_lemmas
df['correct_lemma'] = df.clean_lemma.apply(lambda x: lemma_map[x] if x in lemma_map else np.nan)
# add the mapped lemmas to the correct lemma DataFrame
correct_df = pd.concat([correct_df, df[df.correct_lemma.isna() == False]])
# drop the mapped lemmas from the main DataFrame
df = df[df.correct_lemma.isna() == True]

# %%
df.shape
# Out:
# (110763, 16)

# %%
inv_map['Luyck']
# Out:
# {'3763',
#  '3768',
#  '3769',
#  '3770',
#  '3772',
#  '3773',
#  '3778',
#  '3779',
#  '3780',
#  '3782',
#  '3783',
#  '3785',
#  '3786',
#  '3787',
#  '3788',
#  '3789',
#  '3790',
#  '3791',
#  '3792',
#  '3795',
#  '3796',
#  '3797',
#  '3798',
#  '3799',
#  '3800'}

# %%
inv_map['Luycken']
# Out:
# {'3776', '3777', '3778', '3780'}

# %%
df[['clean_lemma','inventory']].drop_duplicates().clean_lemma.value_counts()
# Out:
# Bentinck                        20
# van Dorssele                    20
# Engelandt                       20
# Bededagh                        20
# Zeeland                         20
#                                 ..
# Mexnert                          1
# Mingerssen                       1
# Missche tot                      1
# de Moisan Brieux Brieven van     1
# Zwitzerse Cantons                1
# Name: clean_lemma, Length: 15397, dtype: int64

# %%
s = df[['clean_lemma', 'inventory']].drop_duplicates().clean_lemma.value_counts()

sorted(list(s[s > 10].index))
#s[['Bergh', 'Assendelft']]
s[s >= 10]
# Out:
# Bentinck        20
# van Dorssele    20
# Engelandt       20
# Bededagh        20
# Zeeland         20
#                 ..
# Hoeuft          10
# Vleertman       10
# Ham             10
# van Affelen     10
# Bronckhorst     10
# Name: clean_lemma, Length: 307, dtype: int64

# %%
#df['lemma'] = df.lemma.apply(lambda x: x if type(x) == str else '')
df[df.clean_lemma.str.startswith('Bergh')].clean_lemma.value_counts()
# Out:
# Berghuys              26
# Berghman               8
# Bergh                  6
# Bergheyck              2
# Berghsma               2
# Berghman klagten       1
# Bergh-Hohenzollern     1
# Name: clean_lemma, dtype: int64

# %%
def read_lemmas(lemma_file):
    with open(lemma_file, 'rt') as fh:
        lemmas = []
        for line in fh:
            lemma = line.strip()
            if lemma[-1] == ';':
                lemma = lemma[:-1]
            lemma = lemma.replace(';', ' ')
            lemmas.append(lemma)
    return lemmas


index_lemma_file = '../../analysis/Indices/index_1700_1724_3867.csv'

transcribed_lemmas = read_lemmas(index_lemma_file)
len(transcribed_lemmas)

transcribed_lemmas
# Out:
# ['Abdije van Bern',
#  'Abditte van Thorn',
#  'Admiraal',
#  'Admiraliteiten in t gemeen',
#  'Admiraliteit op de Maze',
#  'Admiraliteit te Amsterdam',
#  'Admiraliteit in Zeeland',
#  'Admiraliteit in Vriesland',
#  'Admiraliteit Noorderquartr',
#  'Aerdenburg',
#  'Agenten',
#  'Agent van Haar Hoog Mogd',
#  'Agent van Haar Hoog Mogd Munster en Paderborn',
#  'Aken',
#  'Algiers',
#  'Almanak',
#  'Almanakkegeld',
#  'Ameland',
#  'Amersfoort',
#  'Ammunitie',
#  'Ampten',
#  'Anholt',
#  'Apperitez',
#  'Armen',
#  'Arnhem',
#  'Artillerij',
#  'Artois',
#  'Auctographa',
#  'Auvergne',
#  'Axel en Neuse',
#  'Barneze',
#  'Bededagen',
#  'Bedelarije',
#  'Bedestonden',
#  'Benthem',
#  'Berbice',
#  'Bergen op Zoom',
#  'Bern',
#  'Besendinge',
#  'Beursen',
#  'Beijeren',
#  'Biervliet',
#  'Bilbao',
#  'Bodens',
#  'Boeken',
#  'Bommel',
#  'Bon',
#  'Boxmeer',
#  'Braband',
#  'Brand',
#  'Brandenburg',
#  'Brandenburg Anspach',
#  'Brandewijnstookers',
#  'Brandspuijt',
#  'Breda en Baronnije',
#  'Breemen',
#  'Breskens',
#  'Brieven',
#  'Brouwers',
#  'Brunswijk Lunenburg',
#  'Brussel',
#  'Canonisijen',
#  'Cartel',
#  'Cel',
#  'Ceremonieel',
#  'Ceulen',
#  'Cleve',
#  'Clerquen',
#  'Coeverden',
#  'Collateraal',
#  'Commercie',
#  'Commisen generaal',
#  'Commissaris van de legerscheepen',
#  'Commissievaarders',
#  'Consraincte',
#  'Consul te Algiers',
#  'Consul te Alicanten',
#  'Consul te Cadix',
#  'Consul in de Corunna',
#  'Consul Lisssabon',
#  'Consul Livorno',
#  'Consul London',
#  'Consul Mallaga',
#  'Consul Noorweegen',
#  'Consul Messina',
#  'Consul Salee',
#  'Consul Salonica',
#  'Consul Smirna',
#  'Consul Tripoli',
#  'Consul Venetien',
#  'Contrabande',
#  'Contributien',
#  'Correspontien',
#  'Courantiers',
#  'Curacao',
#  'Dalem',
#  'Dantzich',
#  'Defroijeeren',
#  'Denemarken',
#  'Doop',
#  'Doornik',
#  'Douay',
#  'Drenthe',
#  'Drukker vant Land',
#  'Duijfsteen',
#  'Duijtsland',
#  'Elseneur',
#  'Elsloo',
#  'Extraordinaris Vergadering',
#  'Finantie',
#  'Fiscaal',
#  'Fortificatien',
#  'Francfort',
#  'Fijnaert',
#  'Gedeputeerdens int Generaal',
#  'Gedeputeerden tot de Barriere',
#  'Gedeputeerden te Brussel',
#  'Gedeputeerden tot het opneemen der Reekeningen van Doornik &c',
#  'Gedeputeerden te Velde',
#  'Gedeputeerden na Vlaanderen',
#  'Gedeputeerden op de Vreedehandel',
#  'Geestelijke Goederen',
#  'Gelderland',
#  'Gemeene Middelen',
#  'Generaals',
#  'Genua',
#  'Gevangene (Krijgs)',
#  'Gevangene',
#  'Giften en Gaven',
#  'Graenen',
#  'Gratificatien',
#  'Grave',
#  'Griffie',
#  'Groot Brittannien',
#  'Guarde du Corps',
#  "Hage (s'Graven-)",
#  'Hamburg',
#  'Helder',
#  'Hessen Cassel',
#  'Herstal',
#  'Hertogenbosch',
#  'Hertogenrade',
#  'Hilverenbeek',
#  'Hofmeester',
#  'Hogen Raad',
#  'Holland',
#  'Holstein',
#  'Holstein Gottorp',
#  'Holstein Pleun',
#  'Hompesch',
#  'Honderste Penning',
#  'Hoppe',
#  'Hulst en Hulsterambagt',
#  'Huwelijken',
#  'Iachten',
#  'Ingenieurs',
#  'Inventien',
#  'Iudicieele Saeken',
#  'Jurisdictie',
#  'Kamerwaarders van Haar Ho: Mogt',
#  'Kessenier',
#  'Keyser',
#  'Keyserswaart',
#  'Krijgsraad',
#  'Leenen',
#  'Leenhof van Valkenburg',
#  'Legitimatie',
#  'Leuven',
#  'Levantse Handel',
#  'Lillo',
#  'Limburg',
#  'Livorno',
#  'Logis',
#  'Lompen',
#  'Loterij',
#  'Lotharinge',
#  'Luijk',
#  'Maestrichte',
#  'Mariniers',
#  'Marocco',
#  'Maze Tollen',
#  'Meckelenburgse Trouppes',
#  'Medaille',
#  'Meubilen',
#  'Meurs',
#  'Meyboomen in den Hage',
#  'Meyerije van den Bosch',
#  'Middelandse Zee',
#  'Middelen',
#  'Middelen te Water',
#  'Militie',
#  'Militaire Saken',
#  'Ministers van Vreemde Mogentheden',
#  'Ministers van den Staat int gemeen',
#  'Minister te Brussel',
#  'Minister te Ceulen',
#  'Minister te Dantzick',
#  'Minister in Denemarken',
#  'Minister in Duytsland',
#  'minister te Elseneur',
#  'Minister in Engeland',
#  'Minister te Francfort',
#  'Minister te Hamburg',
#  'Minister te Munster',
#  'Minister te Muscouw',
#  'Minister bij de Ottomannische Porte',
#  'Minister in Polen',
#  'Minister in Portugal',
#  'Minister in Pruijssen',
#  'Minister te Regensburg',
#  'Minister in Savoyen',
#  'Minster in Spanje',
#  'Minister in Sweeden',
#  'Minister in Vrankrijk',
#  'Minister aant hoff van Weenen',
#  'Minsister in Zwisterland',
#  'Monstering',
#  'Montfoort',
#  'Munster',
#  'Munt',
#  'Muscovien',
#  'Naerden',
#  'Nalatenschap van de Koning',
#  'Namen',
#  'Nassau',
#  'Naturalisatie',
#  'Navagne',
#  'Neder-Rhijn',
#  'Negotieeren',
#  'Neufchatel',
#  'Neuse',
#  'Nieuwe Jaaren',
#  'Nijmegen',
#  'Oirschot',
#  'Ontfangers',
#  'Ontfanger Generaal',
#  'Ontfanger vat Verhoogde Last en Veylgeld',
#  'Oorlog',
#  'Oostenrijkse Nederlanden',
#  'Oosterwijk',
#  'Oost Indische Compagnie',
#  'Ostendische Compagnie',
#  'Oost Vriesland',
#  'Ottomannische Porte',
#  'Overmaze',
#  'Overquartier van gelderland',
#  'Paapse Religie',
#  'Paapse Stoutigheeden',
#  'Paarden',
#  'Paltz',
#  'Panderen',
#  'Pannerdense Vanaal',
#  'Pardon',
#  'Pasporten',
#  'Pasquillen',
#  'Paternten',
#  'Pensioenen',
#  'Pest',
#  'Petitien',
#  'Philppine',
#  'Polen',
#  'Portugal',
#  'Postmeester van de Generaliteit',
#  'Postmeester in den Bosch',
#  'Predicanten',
#  'Presenten',
#  'Pruijssen',
#  'Quote',
#  'Raad van Braband',
#  'Raad van Staten',
#  'Raad van Vlaanderen',
#  'Redemtie',
#  'Rekenkamer van de Generaliteit',
#  'Refugees',
#  'Religie Saaken',
#  'Renten',
#  'Residenten',
#  'Rhijn',
#  'Rhijnbeeck',
#  'Riga ',
#  'Roermonde',
#  'Rouw',
#  'Rundvee',
#  'Rijssel',
#  'Salee',
#  'Salut',
#  'Sas van Gent',
#  'Sauve Garde',
#  'Savoyen',
#  'Savxen',
#  'Sazen Gotha',
#  'Scheeveninge',
#  'Schenkenschans',
#  'Schrijfloonen',
#  'Secretesse',
#  'Sureté de Corps',
#  'Sleuterls',
#  'Sluijs',
#  'Spaanse Nederlanden',
#  'Spanje',
#  'Stad en Lande',
#  'Stadhouder',
#  'Staten Generaal',
#  'Staat van Oorlog',
#  'Steenbergen',
#  'Stevenswaert',
#  'Suriname',
#  'Swabische Kreytz',
#  'Sweeden',
#  'Switserland',
#  'Synode',
#  'Thesaurier Generaal',
#  'Thorn',
#  'Thiel',
#  'Timmerman',
#  'Tituls',
#  'Tollen',
#  'Tollen te Staden',
#  'Tollen te Wimond',
#  'Tonnen',
#  'Tractaten',
#  'Translateeren',
#  'Translateur',
#  'Tripoli',
#  'Trompetters van den Staat',
#  'Tunis',
#  'Turfvoerders vant Hoff',
#  'Turnhout',
#  'Utrecht',
#  'Valkenburg (Leenhoff van)',
#  'Veere en Vlissingen',
#  'Veldmarschalk',
#  'Venetien',
#  'Venias Etatis',
#  'Velo',
#  'Venlo (t Hoff van t overqr van Gelderland te)',
#  'Verhoogde Lasten Veylgeld',
#  'Verkensweert',
#  'Verviers',
#  'Vigos',
#  'Visschen',
#  'Vischerij (Groenlandse)',
#  'Visscherij (Haring)',
#  'Vlaanderen',
#  'Vlissingen',
#  'Vrankrijk',
#  'Vreede',
#  'Vreedehandeling',
#  'Vriesland',
#  'Vrije',
#  'Warneton',
#  'Well',
#  'West Indische Compagnie',
#  'Westphalen',
#  'Wier',
#  'Willemstad',
#  'Winterquartieren',
#  'Wisselbrieven',
#  'Woord',
#  'Wurtenberg',
#  'IJkmeester Generaal',
#  'IJsendijke',
#  'Ijssel',
#  'Ijsselstein',
#  'Ijsequebo',
#  'Zeegel',
#  'Zeeland',
#  'Zeep',
#  'Zutphen']

# %%
print("transcribed lemmas:", len(transcribed_lemmas))
# Out:
# transcribed lemmas: 369

# %%
correct_lemmas = [lemma for lemma in list(correct_df.correct_lemma.drop_duplicates()) if type(lemma) == str]

lemma_grouper = LemmaGrouper(use_lowercase=True, debug_level=0)

gt_lemmas = transcribed_lemmas
all_lemmas = gt_lemmas + correct_lemmas

lemma_grouper.group_terms_by_base_terms(correct_lemmas, gt_lemmas)

gt_tfidf = lemma_grouper._get_tf_idf_matrix(gt_lemmas)
correct_tfidf = lemma_grouper._get_tf_idf_matrix(correct_lemmas)
gt_tfidf.shape
# Out:
# (369, 1379)

# %%
correct_tfidf.shape
# Out:
# (73, 1379)

# %%
for term in sorted(lemma_grouper.group_lookup):
    group_lemma = lemma_grouper.group_lookup[term]
    if term == group_lemma:
        continue
    # m
    print(f'{term: <40}{group_lemma: <40}')
    #lemma_map[term] = correct_lemma
# Out:
# Bergen op den Zoom                      Bergen op Zoom
# s Hertogenbosch                         Hertogenbosch

# %%
transcribed_lemmas
# Out:
# ['Abdije van Bern',
#  'Abditte van Thorn',
#  'Admiraal',
#  'Admiraliteiten in t gemeen',
#  'Admiraliteit op de Maze',
#  'Admiraliteit te Amsterdam',
#  'Admiraliteit in Zeeland',
#  'Admiraliteit in Vriesland',
#  'Admiraliteit Noorderquartr',
#  'Aerdenburg',
#  'Agenten',
#  'Agent van Haar Hoog Mogd',
#  'Agent van Haar Hoog Mogd Munster en Paderborn',
#  'Aken',
#  'Algiers',
#  'Almanak',
#  'Almanakkegeld',
#  'Ameland',
#  'Amersfoort',
#  'Ammunitie',
#  'Ampten',
#  'Anholt',
#  'Apperitez',
#  'Armen',
#  'Arnhem',
#  'Artillerij',
#  'Artois',
#  'Auctographa',
#  'Auvergne',
#  'Axel en Neuse',
#  'Barneze',
#  'Bededagen',
#  'Bedelarije',
#  'Bedestonden',
#  'Benthem',
#  'Berbice',
#  'Bergen op Zoom',
#  'Bern',
#  'Besendinge',
#  'Beursen',
#  'Beijeren',
#  'Biervliet',
#  'Bilbao',
#  'Bodens',
#  'Boeken',
#  'Bommel',
#  'Bon',
#  'Boxmeer',
#  'Braband',
#  'Brand',
#  'Brandenburg',
#  'Brandenburg Anspach',
#  'Brandewijnstookers',
#  'Brandspuijt',
#  'Breda en Baronnije',
#  'Breemen',
#  'Breskens',
#  'Brieven',
#  'Brouwers',
#  'Brunswijk Lunenburg',
#  'Brussel',
#  'Canonisijen',
#  'Cartel',
#  'Cel',
#  'Ceremonieel',
#  'Ceulen',
#  'Cleve',
#  'Clerquen',
#  'Coeverden',
#  'Collateraal',
#  'Commercie',
#  'Commisen generaal',
#  'Commissaris van de legerscheepen',
#  'Commissievaarders',
#  'Consraincte',
#  'Consul te Algiers',
#  'Consul te Alicanten',
#  'Consul te Cadix',
#  'Consul in de Corunna',
#  'Consul Lisssabon',
#  'Consul Livorno',
#  'Consul London',
#  'Consul Mallaga',
#  'Consul Noorweegen',
#  'Consul Messina',
#  'Consul Salee',
#  'Consul Salonica',
#  'Consul Smirna',
#  'Consul Tripoli',
#  'Consul Venetien',
#  'Contrabande',
#  'Contributien',
#  'Correspontien',
#  'Courantiers',
#  'Curacao',
#  'Dalem',
#  'Dantzich',
#  'Defroijeeren',
#  'Denemarken',
#  'Doop',
#  'Doornik',
#  'Douay',
#  'Drenthe',
#  'Drukker vant Land',
#  'Duijfsteen',
#  'Duijtsland',
#  'Elseneur',
#  'Elsloo',
#  'Extraordinaris Vergadering',
#  'Finantie',
#  'Fiscaal',
#  'Fortificatien',
#  'Francfort',
#  'Fijnaert',
#  'Gedeputeerdens int Generaal',
#  'Gedeputeerden tot de Barriere',
#  'Gedeputeerden te Brussel',
#  'Gedeputeerden tot het opneemen der Reekeningen van Doornik &c',
#  'Gedeputeerden te Velde',
#  'Gedeputeerden na Vlaanderen',
#  'Gedeputeerden op de Vreedehandel',
#  'Geestelijke Goederen',
#  'Gelderland',
#  'Gemeene Middelen',
#  'Generaals',
#  'Genua',
#  'Gevangene (Krijgs)',
#  'Gevangene',
#  'Giften en Gaven',
#  'Graenen',
#  'Gratificatien',
#  'Grave',
#  'Griffie',
#  'Groot Brittannien',
#  'Guarde du Corps',
#  "Hage (s'Graven-)",
#  'Hamburg',
#  'Helder',
#  'Hessen Cassel',
#  'Herstal',
#  'Hertogenbosch',
#  'Hertogenrade',
#  'Hilverenbeek',
#  'Hofmeester',
#  'Hogen Raad',
#  'Holland',
#  'Holstein',
#  'Holstein Gottorp',
#  'Holstein Pleun',
#  'Hompesch',
#  'Honderste Penning',
#  'Hoppe',
#  'Hulst en Hulsterambagt',
#  'Huwelijken',
#  'Iachten',
#  'Ingenieurs',
#  'Inventien',
#  'Iudicieele Saeken',
#  'Jurisdictie',
#  'Kamerwaarders van Haar Ho: Mogt',
#  'Kessenier',
#  'Keyser',
#  'Keyserswaart',
#  'Krijgsraad',
#  'Leenen',
#  'Leenhof van Valkenburg',
#  'Legitimatie',
#  'Leuven',
#  'Levantse Handel',
#  'Lillo',
#  'Limburg',
#  'Livorno',
#  'Logis',
#  'Lompen',
#  'Loterij',
#  'Lotharinge',
#  'Luijk',
#  'Maestrichte',
#  'Mariniers',
#  'Marocco',
#  'Maze Tollen',
#  'Meckelenburgse Trouppes',
#  'Medaille',
#  'Meubilen',
#  'Meurs',
#  'Meyboomen in den Hage',
#  'Meyerije van den Bosch',
#  'Middelandse Zee',
#  'Middelen',
#  'Middelen te Water',
#  'Militie',
#  'Militaire Saken',
#  'Ministers van Vreemde Mogentheden',
#  'Ministers van den Staat int gemeen',
#  'Minister te Brussel',
#  'Minister te Ceulen',
#  'Minister te Dantzick',
#  'Minister in Denemarken',
#  'Minister in Duytsland',
#  'minister te Elseneur',
#  'Minister in Engeland',
#  'Minister te Francfort',
#  'Minister te Hamburg',
#  'Minister te Munster',
#  'Minister te Muscouw',
#  'Minister bij de Ottomannische Porte',
#  'Minister in Polen',
#  'Minister in Portugal',
#  'Minister in Pruijssen',
#  'Minister te Regensburg',
#  'Minister in Savoyen',
#  'Minster in Spanje',
#  'Minister in Sweeden',
#  'Minister in Vrankrijk',
#  'Minister aant hoff van Weenen',
#  'Minsister in Zwisterland',
#  'Monstering',
#  'Montfoort',
#  'Munster',
#  'Munt',
#  'Muscovien',
#  'Naerden',
#  'Nalatenschap van de Koning',
#  'Namen',
#  'Nassau',
#  'Naturalisatie',
#  'Navagne',
#  'Neder-Rhijn',
#  'Negotieeren',
#  'Neufchatel',
#  'Neuse',
#  'Nieuwe Jaaren',
#  'Nijmegen',
#  'Oirschot',
#  'Ontfangers',
#  'Ontfanger Generaal',
#  'Ontfanger vat Verhoogde Last en Veylgeld',
#  'Oorlog',
#  'Oostenrijkse Nederlanden',
#  'Oosterwijk',
#  'Oost Indische Compagnie',
#  'Ostendische Compagnie',
#  'Oost Vriesland',
#  'Ottomannische Porte',
#  'Overmaze',
#  'Overquartier van gelderland',
#  'Paapse Religie',
#  'Paapse Stoutigheeden',
#  'Paarden',
#  'Paltz',
#  'Panderen',
#  'Pannerdense Vanaal',
#  'Pardon',
#  'Pasporten',
#  'Pasquillen',
#  'Paternten',
#  'Pensioenen',
#  'Pest',
#  'Petitien',
#  'Philppine',
#  'Polen',
#  'Portugal',
#  'Postmeester van de Generaliteit',
#  'Postmeester in den Bosch',
#  'Predicanten',
#  'Presenten',
#  'Pruijssen',
#  'Quote',
#  'Raad van Braband',
#  'Raad van Staten',
#  'Raad van Vlaanderen',
#  'Redemtie',
#  'Rekenkamer van de Generaliteit',
#  'Refugees',
#  'Religie Saaken',
#  'Renten',
#  'Residenten',
#  'Rhijn',
#  'Rhijnbeeck',
#  'Riga ',
#  'Roermonde',
#  'Rouw',
#  'Rundvee',
#  'Rijssel',
#  'Salee',
#  'Salut',
#  'Sas van Gent',
#  'Sauve Garde',
#  'Savoyen',
#  'Savxen',
#  'Sazen Gotha',
#  'Scheeveninge',
#  'Schenkenschans',
#  'Schrijfloonen',
#  'Secretesse',
#  'Sureté de Corps',
#  'Sleuterls',
#  'Sluijs',
#  'Spaanse Nederlanden',
#  'Spanje',
#  'Stad en Lande',
#  'Stadhouder',
#  'Staten Generaal',
#  'Staat van Oorlog',
#  'Steenbergen',
#  'Stevenswaert',
#  'Suriname',
#  'Swabische Kreytz',
#  'Sweeden',
#  'Switserland',
#  'Synode',
#  'Thesaurier Generaal',
#  'Thorn',
#  'Thiel',
#  'Timmerman',
#  'Tituls',
#  'Tollen',
#  'Tollen te Staden',
#  'Tollen te Wimond',
#  'Tonnen',
#  'Tractaten',
#  'Translateeren',
#  'Translateur',
#  'Tripoli',
#  'Trompetters van den Staat',
#  'Tunis',
#  'Turfvoerders vant Hoff',
#  'Turnhout',
#  'Utrecht',
#  'Valkenburg (Leenhoff van)',
#  'Veere en Vlissingen',
#  'Veldmarschalk',
#  'Venetien',
#  'Venias Etatis',
#  'Velo',
#  'Venlo (t Hoff van t overqr van Gelderland te)',
#  'Verhoogde Lasten Veylgeld',
#  'Verkensweert',
#  'Verviers',
#  'Vigos',
#  'Visschen',
#  'Vischerij (Groenlandse)',
#  'Visscherij (Haring)',
#  'Vlaanderen',
#  'Vlissingen',
#  'Vrankrijk',
#  'Vreede',
#  'Vreedehandeling',
#  'Vriesland',
#  'Vrije',
#  'Warneton',
#  'Well',
#  'West Indische Compagnie',
#  'Westphalen',
#  'Wier',
#  'Willemstad',
#  'Winterquartieren',
#  'Wisselbrieven',
#  'Woord',
#  'Wurtenberg',
#  'IJkmeester Generaal',
#  'IJsendijke',
#  'Ijssel',
#  'Ijsselstein',
#  'Ijsequebo',
#  'Zeegel',
#  'Zeeland',
#  'Zeep',
#  'Zutphen']

# %%
from republic.extraction.extract_index_entries import LemmaGrouper

lemma_grouper = LemmaGrouper(use_lowercase=True, debug_level=1)

ocr_lemmas = list(df.clean_lemma.drop_duplicates())

lemma_grouper.set_idf(ocr_lemmas + transcribed_lemmas)
# Out:
# setting IDF for 15766 terms

# %%
lemma_grouper.group_terms_by_base_terms(ocr_lemmas, transcribed_lemmas)
# Out:
# setting IDF for 15766 terms
# Term TF-IDF matrix has shape: (15397, 7014)
# Base term TF-IDF matrix has shape: (369, 7014)
# Coord matrix has shape: (15397, 369)
# number of groups: 369
# number of grouped terms: 595

# %%
for term in sorted(lemma_grouper.group_lookup):
    group_lemma = lemma_grouper.group_lookup[term]
    if term == group_lemma:
        continue
    # m
    print(f'{term: <40}{group_lemma: <40}')
    #lemma_map[term] = correct_lemma
# Out:
# Aadmiraliteyt in Vrieslandt             Admiraliteit in Vriesland
# Admiraliteyt in Vriesland               Admiraliteit in Vriesland
# Admiraliteyt in Vrieslandt              Admiraliteit in Vriesland
# Admiraliteyt in Vrieslandt te           Admiraliteit in Vriesland
# Admiraliteyt in Zeeland                 Admiraliteit in Zeeland
# Admiraliteyt in Zeelande                Admiraliteit in Zeeland
# Admiraliteyt in Zeelandt                Admiraliteit in Zeeland
# Admiraliteyt op de Maze                 Admiraliteit op de Maze
# Admiraliteyt op de Maze te              Admiraliteit op de Maze
# Algiers Dey                             Algiers
# Armentier                               Armen
# Audenaerde                              Naerden
# Audenaerden                             Naerden
# B Aad van Braband                       Raad van Braband
# BD Aad van Braband                      Raad van Braband
# Bede-dagh                               Bededagen
# Bededag                                 Bededagen
# Bededagh                                Bededagen
# Berbices                                Berbice
# Bodel                                   Bodens
# Boek                                    Boeken
# Bomme                                   Bommel
# Brabandt                                Braband
# Brabant                                 Braband
# Brande                                  Brand
# Brandenburgh                            Brandenburg
# Brands                                  Brand
# Brandt                                  Brand
# Brant                                   Brand
# Brieven van                             Brieven
# Brittannien                             Groot Brittannien
# Brouw                                   Rouw
# Brouwer                                 Brouwers
# Brouwer te                              Brouwers
# Brusset                                 Brussel
# Ceremonieel van                         Ceremonieel
# Commisfie in de Oost Indische Compagnie Oost Indische Compagnie
# Contrabande Waaren                      Contrabande
# D Aad van Braband                       Raad van Braband
# DB Aad van Braband                      Raad van Braband
# Dantzick                                Dantzich
# Deenemarken                             Denemarken
# Denaturalisati                          Naturalisatie
# Denaturalisatie                         Naturalisatie
# Gedeputeerden te                        Gedeputeerden te Velde
# Gedeputeerden te Brusses                Gedeputeerden te Brussel
# Gedeputeerden tot Brussel               Gedeputeerden te Brussel
# Gelderlandt                             Gelderland
# Gelderlanst                             Gelderland
# Graven                                  Grave
# Hamburgh                                Hamburg
# Hollander                               Holland
# Hollandt                                Holland
# Holstein-Gottorp                        Holstein Gottorp
# Holsteyn Gottorp                        Holstein Gottorp
# Keyserin                                Keyser
# Leene                                   Leenen
# Legitimatie. Siet Brieven van DegitimatieLegitimatie
# Legitimatie. Siet Brieven van LegitimatieLegitimatie
# Limburgh                                Limburg
# Lotharingen                             Lotharinge
# Lunenburgh Brunswijk                    Brunswijk Lunenburg
# Maestricht                              Maestrichte
# Middelen te                             Middelen
# Middelen te Waater                      Middelen te Water
# Middelen te waater                      Middelen te Water
# Middelen te water                       Middelen te Water
# Middelen te wauter                      Middelen te Water
# Weede                                   Sweeden
# Wel                                     Well
# Wellee                                  Well
# West-Indische Compagnie                 West Indische Compagnie
# Westindische Compagnie                  West Indische Compagnie
# Westindische Compagnie in Zeeland       West Indische Compagnie
# Westindische Compagnie te               West Indische Compagnie
# Wie                                     Wier
# Winter-quartieren                       Winterquartieren
# Winterquarieren                         Winterquartieren
# Winterquartier                          Winterquartieren
# Zeegelaar                               Zeegel
# Zeegers                                 Zeegel
# Zeelande                                Zeeland
# Zeelands                                Zeeland
# Zeelandt                                Zeeland
# Zuriname                                Suriname
# Zwabischen Kreytz                       Swabische Kreytz
# Zwitserlandt                            Switserland
# aken                                    Aken
# d'Auvergne                              Auvergne
# de Berbice                              Berbice
# de Brabander                            Braband
# de Grave                                Grave
# de Keyser                               Keyser
# de Timmerman                            Timmerman
# den Ontfanger Generaal                  Ontfanger Generaal
# genten                                  Agenten
# gevangenen                              Gevangene
# miraliteyt op de Maze                   Admiraliteit op de Maze
# ooft-Indische Compagnie                 Ostendische Compagnie
# ooftindische Compagnie                  Ostendische Compagnie
# oorlogh                                 Oorlog
# pensioen                                Pensioenen
# pest                                    Pest
# pesters                                 Pest
# petitie                                 Petitien
# polen                                   Polen
# quote in de                             Quote
# sHertogenboseh                          Hertogenbosch
# savoyen                                 Savoyen
# senten                                  Renten
# staat van oorlogh                       Staat van Oorlog
# sweeden                                 Sweeden
# ty de vreedehandelinge                  Vreedehandeling
# van Auvergne                            Auvergne
# van Benthem                             Benthem
# van Bommel                              Bommel
# van Brandenburgh                        Brandenburg
# van Coeverden                           Coeverden
# van Holstein                            Holstein
# van Hompesch                            Hompesch
# van Limburgh                            Limburg
# van Lotharingen                         Lotharinge
# van Munster                             Munster
# van Nassau                              Nassau
# van Roermonde                           Roermonde
# van Vlaanderen                          Vlaanderen
# van Vlissingen                          Vlissingen
# van Vrieslandt                          Vriesland
# van Wurtenbergh                         Wurtenberg
# vigos                                   Vigos
# vilitaire saken                         Militaire Saken
# visscher                                Visschen
# vlaanderen                              Vlaanderen
# vrieslande                              Vriesland
# wenindische Compagnie                   Ostendische Compagnie
# wesindische Compagnie                   West Indische Compagnie
# west-Indische Compagnie                 West Indische Compagnie
# west-indische Compagnie                 West Indische Compagnie
# westindische Compagnie                  West Indische Compagnie
# wier                                    Wier
# willemstad                              Willemstad
# winter-quartieren                       Winterquartieren
# woor                                    Woord
# woord                                   Woord
# wurtenberg                              Wurtenberg
# wurtenbergh                             Wurtenberg

# %%
import json

lemma_correction_map = lemma_grouper.group_lookup

with open('lemma_correction_map.json', 'wt') as fh:
    json.dump(lemma_correction_map, fh)

# %% [markdown]
# ### Correcting lemmata based on transcribed index terms

# %%
import pandas as pd
import re

# Many lemmas have leading and/or trailing punctuation that is not part of
# the proper lemma. 
# The first step is to add a column with cleaned up lemmas.

def clean_start_end(string):
    if type(string) != str:
        return string
    return re.sub(r'\W+$', '', re.sub(r'^\W+', '', string))

# The file with 140,313 index lemma entries
entries_file = '../../data/indices/index_entries-3763-3804-latest.csv.gz'

df = pd.read_csv(entries_file, sep='\t', compression='gzip')

# Rename the lemma column to ocr_lemma, so we know this is the raw extracted text with potential errors.
df = df.rename(columns={'lemma': 'ocr_lemma'})
df.shape


# The line IDs contain the inventory number of the book from which the
# entry was extracted.
# We add a column with the inventory number so we can check which lemmas 
# occur in multiple books, therefore need to be linked and are more 
# likely to be correct lemmas (lemmas with OCR errors are less likely
# to occur with precisely the same errors across multiple books)

df['inventory'] = df.first_line_id.apply(lambda x: x.split('_')[2])
df.inventory.nunique()

df['clean_lemma'] = df.ocr_lemma.apply(clean_start_end)

df['correct_lemma'] = df.clean_lemma.apply(lambda x: lemma_correction_map[x] if x in lemma_correction_map else x)

df.correct_lemma.value_counts()
# Out:
# Militaire Saken               4960
# Holland                       3871
# Pasporten                     3584
# Raad van Staten               3060
# s Hertogenbosch               2856
#                               ...
# van Zievel                       1
# Verbodt                          1
# Verburgh                         1
# de Walsche Kerkenraad            1
# van Ouderkerck Brieven van       1
# Name: correct_lemma, Length: 15381, dtype: int64

# %%
s1 = df.correct_lemma.value_counts()
s2 = df[['correct_lemma', 'inventory']].drop_duplicates().correct_lemma.value_counts()
#.to_frame().rename(columns={'clean_lemma': 'Entries'}).head(5)

pd.concat([s1.to_frame().rename(columns={'correct_lemma': 'Entries'}), s2.to_frame().rename(columns={'correct_lemma': 'Indices'})], axis=1).head(20)
# Out:
#                              Entries  Indices
# Militaire Saken                 4960       38
# Holland                         3871       41
# Pasporten                       3584       29
# Raad van Staten                 3060       18
# s Hertogenbosch                 2856       35
# Vlaanderen                      1554       33
# Overquartier van gelderland     1479       41
# Gelderland                      1375       38
# Zeeland                         1351       35
# Brieven                         1201       19
# E                               1066       14
# Hop                             1029       34
# Finantie                         984       38
# Raadt van Staate                 979        5
# Admiraliteyt tot Amsterdam       935       30
# Groningen                        828       34
# Raadt van State                  794        6
# Vriesland                        777       40
# Utrecht                          723       35
# Commissien                       709       28

# %%
# Next step, count the number of books in which each clean lemma occurs
s = df[['correct_lemma', 'inventory']].drop_duplicates().correct_lemma.value_counts()

s[s > 30].to_frame().rename(columns={'correct_lemma': 'Num indices'})
# Out:
#                              Num indices
# Overquartier van gelderland           41
# Breda                                 40
# Vriesland                             40
# Militaire Saken                       38
# Gelderland                            38
# Finantie                              38
# West Indische Compagnie               38
# s Hertogenbosch                       35
# Utrecht                               35
# Zeeland                               35
# Hop                                   34
# Groningen                             34
# Admiraliteit in Zeeland               33
# Vlaanderen                            33
# Oost Indische Compagnie               33
# Admiraliteit in Vriesland             32
# Levantschen Handel                    32
# Overyssel                             31
# Pruyssen                              31
# Patenten                              31

# %%
ocr_lemmas = [lemma for lemma in list(df.clean_lemma.drop_duplicates()) if type(lemma) == str]

len(ocr_lemmas)
# Out:
# 19475

# %%
ocr_lemmas = [lemma for lemma in list(df.clean_lemma.drop_duplicates()) if type(lemma) == str]

lemma_grouper = LemmaGrouper(use_lowercase=True, debug_level=0)

gt_lemmas = lemmas
all_lemmas = gt_lemmas + ocr_lemmas

#lemma_grouper.set_idf(all_lemmas)
#lemma_grouper.group_terms(ocr_lemmas)
lemma_grouper.group_terms_by_base_terms(ocr_lemmas[:100000], gt_lemmas)

gt_tfidf = lemma_grouper._get_tf_idf_matrix(lemmas)
ocr_tfidf = lemma_grouper._get_tf_idf_matrix(ocr_lemmas)
gt_tfidf.shape
# Out:
# (369, 7512)

# %%
# terms in the OCR lemma list that are similar to some of the correct lemmas
# but are their own lemmas
non_variants = {
    'Oostindische Compagnie',
    'Indische Compagnie',
    'Denaturalisatie',
    'Audenaerden',
    'Aerden',
    'Pesters',
    'Portois',
    'Ratificatie',
    'Thielen',
    'Timmers',
    'Trompetters',
    'Vermaze',
    'Waerdenburgh',
    'Zeegelaar',
    'Zeegers',
}

lemma_map = {}

for term in sorted(lemma_grouper.group_lookup):
    if term in gt_lemmas:
        continue
    #print(term, lemma_grouper.group_lookup[term])
    group_term = lemma_grouper.group_lookup[term]
    print(f"{term: <50}{group_term: <40}")
    if term in lemma_map:
        print('\tDOUBLE MAP:', term, group_term, lemma_map[term])
# Out:
# Aadmiraliteyt in Vrieslandt                       Admiraliteit in Vriesland
# Admiraliteyt in Vriesland                         Admiraliteit in Vriesland
# Admiraliteyt in Vrieslandt                        Admiraliteit in Vriesland
# Admiraliteyt in Vrieslandt te                     Admiraliteit in Vriesland
# Admiraliteyt in Zeeland                           Admiraliteit in Zeeland
# Admiraliteyt in Zeelande                          Admiraliteit in Zeeland
# Admiraliteyt in Zeelandt                          Admiraliteit in Zeeland
# Admiraliteyt op de Maze                           Admiraliteit op de Maze
# Admiraliteyt op de Maze te                        Admiraliteit op de Maze
# Aerden                                            Naerden
# Algiers Dey                                       Algiers
# Ammunitie van                                     Ammunitie
# Armentier                                         Armen
# Audenaerde                                        Naerden
# Audenaerden                                       Naerden
# B Aad van Braband                                 Raad van Braband
# BD Aad van Braband                                Raad van Braband
# Bede-dagh                                         Bededagen
# Bededag                                           Bededagen
# Bededagh                                          Bededagen
# Berbices                                          Berbice
# Bodel                                             Bodens
# Boek                                              Boeken
# Bomme                                             Bommel
# Brabander                                         Braband
# Brabandt                                          Braband
# Brabant                                           Braband
# Brande                                            Brand
# Brandenburgh                                      Brandenburg
# Brands                                            Brand
# Brandt                                            Brand
# Brant                                             Brand
# Brieven van naturalisatie                         Naturalisatie
# Brittannien                                       Groot Brittannien
# Brouw                                             Rouw
# Brouwer                                           Brouwers
# Brouwer te                                        Brouwers
# Brussel te                                        Brussel
# Brusset                                           Brussel
# Ceremonieel van                                   Ceremonieel
# Commisfie in de Oost Indische Compagnie           Oost Indische Compagnie
# Contrabande Waaren                                Contrabande
# D Aad van Braband                                 Raad van Braband
# DB Aad van Braband                                Raad van Braband
# Dantzick                                          Dantzich
# Deenemarken                                       Denemarken
# Denaturalisati                                    Naturalisatie
# Denaturalisatie                                   Naturalisatie
# Drukker                                           Drukker vant Land
# Gedeputeerden te                                  Gedeputeerden te Velde
# Gedeputeerden te Brusses                          Gedeputeerden te Brussel
# Gedeputeerden tot Brussel                         Gedeputeerden te Brussel
# Gelderlandt                                       Gelderland
NL-HaNA_1.01.02_3792_0375-column-3532-429-895-...      porten
# 95215  NL-HaNA_1.01.02_3792_0375-column-3532-429-895-...      porten
# 95216  NL-HaNA_1.01.02_3792_0375-column-3532-429-895-...      porten
#
#       inventory correct_lemma
# 14324      3769           NaN
# 71237      3785           NaN
# 71238      3785           NaN
# 72732      3786           NaN
# 95214      3792           NaN
# 95215      3792           NaN
# 95216      3792           NaN

# %% [markdown]
# ## Analysing page references
#
# We assume that each page reference is a reference to a resolution that starts and/or ends on that page. So each reference is a reference to a single resolution. That means the number of page references is equal to the number of resolution references.
#
# Each term can refer to one or more pages, so to one or more resolutions. Each term can also occur in one or more annual indexes, so refer to resolutions across years.
#
#
# - **linking factor**: the number of resolutions that are linked by the same index term. Index terms are a grouping mechanism that is related to the content or aboutness of the resolutions.
# - **linking specifity**: the specifity of the content with which an index term links resolutions. The specifity varies. A term like *military matters* broadly categorises resolutions related to military matters, but resolutions that are assigned that index term can still be only vaguely related. Whereas a more specific term like a town or person name, is much more specific.
# - **Linking coverage**: the number of resolutions that linked to at least one other resolution by a set of index terms.
#
# The _linking factor_ and _linking specifity_ are inversely, but not necessarily linearly, related.
#
# - The **inverse relationship** is explained by the amount of content that is covered by a set of resolutions, which tends to be larger for larger sets of resolutions. Terms that group many resolutions therefore group a large amount of content, which is likely more heterogeneous than terms that group few resolutions.
# - The **non-linearity** comes from the fact that not all index terms are equally relevant or important for each resolution they apply to. A person might be the sender of two missives leading to two resolutions that are topically unrelated to each other. What unites these resolutions is their sender, but this is not necessarily a relevant connection.

# %%
import pandas as pd
import re

# The file with 145,985 index lemma entries
entries_file = '../../data/indices/index_entries-3763-3804-latest.csv.gz'

df = pd.read_csv(entries_file, sep='\t', compression='gzip')

df = df.rename(columns={'lemma': 'ocr_lemma'})
df['clean_lemma'] = df.ocr_lemma.apply(clean_start_end)

df['inventory'] = df.first_line_id.apply(lambda x: x.split('_')[2])

# %%
import re

import numpy as np

def has_comma_refs(text):
    return get_comma_refs_string(text) is not None

def get_comma_refs_string_type(text):
    if re.search(r'[,\.] \d+', text):
        return 'comma_digit_refs'
    elif ' siet ' in text:
        return 'redirect'
    elif re.search(r'[,\.] \w+\d+', text):
        return 'comma_alpha_digit_refs'
    elif re.search(r'[a-z] \w+\d+', text):
        return 'word_digit_refs'
    elif re.search(r'letter [A-Z]', text):
        return 'redirect'
    elif text[-1] == '-':
        return 'missing_end'
    else:
        return 'unknown'

def get_comma_refs_string(text):
    if re.search(r'[,\.] \d+', text):
        return re.sub(r'.*?[,\.] (\d+)', r'\1', text)
    elif re.search(r'[,\.] \w+\d+', text):
        return re.sub(r'.*?[,\.] (\w+\d+)', r'\1', text)
    elif re.search(r'[a-z] \w+\d+', text):
        return re.sub(r'.*?[a-z] (\w+\d+)', r'\1', text)
    else:
        return np.nan

ref_texts = list(df.head(50).text)

df['ref_string'] = df.text.apply(get_comma_refs_string)
df['ref_string_type'] = df.text.apply(get_comma_refs_string_type)

# %%
df[df.ref_string.isna() == False].inventory.value_counts()
df.ref_string_type.value_counts() / len(df)
# Out:
# comma_digit_refs          0.879370
# unknown                   0.066808
# word_digit_refs           0.029035
# comma_alpha_digit_refs    0.013912
# missing_end               0.006671
# redirect                  0.004205
# Name: ref_string_type, dtype: float64

# %%
def split_ref_string(ref_string):
    return [ref for ref in re.split(r'\W+', ref_string) if ref != '' and ref.isdigit()]

df['num_refs'] = df.ref_string.apply(lambda x: len(split_ref_string(x)) if x is not np.nan else np.nan)
df.num_refs.value_counts()
# Out:
# 1.0    125566
# 0.0      3232
# 2.0       591
# 3.0        19
# 4.0         6
# Name: num_refs, dtype: int64

# %%
df[df.num_refs > 2]
# Out:
#                            ocr_lemma      main_term  \
# 24              adnirdites Rotterdam     adnirdites
# 72            Adniraliteyt Amsterdam   Adniraliteyt
# 99            Aadniraliteyt Zeelandt  Aadniraliteyt
# 140                       Auerquercq     Auerquercq
# 156                        Barcelona      Barcelona
# 204                        Beyersche      Beyersche
# 2375                        Engeland       Engeland
# 5737    Overquantier van Gelderlandt   Overquantier
# 8198    Overquartier van Gelderlande   Overquartier
# 10393                teren in Ryssel          teren
# 10636                            Rue            Rue
# 12371                   C Winentagt)              C
# 12402                   C Winentagt)              -
# 14641                         werden         werden
# 15590                      Barbatyen      Barbatyen
# 19904     Menage in de Generuliteyt.         Menage
# 21176           Christoffers Pasport   Christoffers
# 38403                         len in            len
# 38566                             DE            NaN
# 45325             aannemer van Fardi       aannemer
# 53580                      van Deurs          Deurs
# 77206                       Twissier       Twissier
# 79680                    commisie in       commisie
# 131893                          Pala           Pala
# 135653                             D              D
#
#                                                      text  \
# 24      adnirdites Rotterdam, nopende aen- haien van v...
# 72      wegens een Pinck van Scheve- ningen gesonden, ...
# 99      nopende equipage na Portugael en de Middelandt...
# 140     Auerquercq, advertentie, 17.31-35.62. 97. 123....
# 156                      Barcelona, 608.659. 631.924.988.
# 204     Beyersche interessen en aghterstallen, 266. 29...
# 2375    Hermitage advertentie, 5. 14. 92. 100. 1a6. 13...
# 5737                unt Kesd, u99. rs. 868. 871 914 1083.
# 8198    H stunt, brand aldaer, 183.205. joo. 452. 458....
# 10393   teren in Ryssel gelaten magh werden. 1247. rak...
# 10636   liquidatie met den Intendant Bernieres. 294 50...
# 12371   k narkggen h ui dl Hir pluapn m ae iaate Harsd...
# 12402   Ofkckeren zat hi Reinsm un Dier lagh. 08. sio ...
# 14641    werden 687 363 742. zan Biehl ta Commands van de
# 15590             Baerle om betalinge. 637. 734 735 1033.
# 19904         Menage in de Generuliteyt. 220. 966: 192,4.
# 21176   Brieven van voorschryvens verleent aan het Hof...
# 38403   len in handen van Geinteresseerdens. 766. - WM...
# 38566   wyck. 290. voor Regenten van Waarle, 3114. woo...
# 45325   aannemer van Fardi catien, Tnet on sib- sneu ,...
# 53580   van Deurs, advertentie. 422. 471.489.614- 660....
# 77206   Twissier, Pasport om een reyse na Hamburgh en ...
# 79680   Nurde Pagbangit in Oterislandt. 283. wer Chuss...
# 14641                         werden      3769
# 15590                      Barbatyen      3770
# 19904      Menage in de Generuliteyt      3772
# 21176           Christoffers Pasport      3773
# 38403                         len in      3778
# 38566                             DE      3778
# 45325             aannemer van Fardi      3780
# 53580                      van Deurs      3782
# 77206                       Twissier      3788
# 79680                    commisie in      3789
# 131893                          Pala      3802
# 135653                             D      3803
#
#                                                ref_string   ref_string_type  \
# 24                                         15.59 168 203.  comma_digit_refs
# 72                                           921.948.995.  comma_digit_refs
# 99                                     833.994 1036. nos.  comma_digit_refs
# 140     1797123139201227297303331341347364368416436451...  comma_digit_refs
# 156                                       608631.924.988.  comma_digit_refs
# 204                                   266295.651.657.980.  comma_digit_refs
# 2375    5149210011361452192472582883143493763864034134...  comma_digit_refs
# 5737                                     868871 914 1083.  comma_digit_refs
# 8198                       1834524587707305 433. nei 1364  comma_digit_refs
# 10393   12471322. consent in de Petitie tot de Hagazyn...  comma_digit_refs
# 10636                                        294 507.678.  comma_digit_refs
# 12371                                      388 1279 1418.   word_digit_refs
# 12402                               08. sio 819 867 1138.  comma_digit_refs
# 14641           687 363 742. zan Biehl ta Commands van de   word_digit_refs
# 15590                                    637734 735 1033.  comma_digit_refs
# 19904                                      220966: 192,4.  comma_digit_refs
# 21176                                     463663.757 768.  comma_digit_refs
# 38403   766. - WMarcheed, Bailliuw van Halsteren, 'Pve...  comma_digit_refs
# 38566   2903114. woor Mol, Verdonck ende Danen - 118. ...  comma_digit_refs
# 45325   924. en taan zén ahuyfalku, pr- 755. onder zei...  comma_digit_refs
# 53580                           422471.489.614- 660. gr4.  comma_digit_refs
# 77206   808. K. Amerbewaalders, Onserdyck, declaratie....  comma_digit_refs
# 79680   283. wer Chuss al Guvernar van su- nnane 353. ...  comma_digit_refs
# 131893                                    674677 753 787.  comma_digit_refs
# 135653  437543. spj ray Creutznach aangesteit als Gene...  comma_digit_refs
#
#         num_refs
# 24           4.0
# 72           3.0
# 99           3.0
# 140          3.0
# 156          3.0
# 204          4.0
# 2375         3.0
# 5737         3.0
# 8198         3.0
# 10393        4.0
# 10636        3.0
# 12371        3.0
# 12402        4.0
# 14641        3.0
# 15590        3.0
# 19904        3.0
# 21176        3.0
# 38403        3.0
# 38566        3.0
# 45325        3.0
# 53580        4.0
# 77206        3.0
# 79680        3.0
# 131893       3.0
# 135653       4.0

# %%
s = df.num_refs.value_counts()

print(sum([i*c for i, c in zip (s.index, s)]))
for i, c in zip (s.index, s):
    print(i, c, i * c)
# Out:
# 126829.0
# 1.0 125566 125566.0
# 0.0 3232 0.0
# 2.0 591 1182.0
# 3.0 19 57.0
# 4.0 6 24.0

# %%
# What are the entries with unknown endings?
list(df[df.ref_string_type == 'unknown'].text.head(50))
# Out:
# ['equipage ende onderhoudt van Schepen na de Middelanduche Zee',
#  'nopende aenhalinge van Koets en Paerden van den Ridder Richard simers, sso.',
#  'geen Granen na vyandtlijcke Plaetsen te laten passeren; ror5.',
#  'nopende het verkoopen van eeni- ge onbequame Schepen, Gor.',
#  'nopende het senden van Bus- kruyt na Genua en neutrale Have- nen, sor.',
#  'item Baron Spar, sor.',
#  'Burcard toegestaen voor een maendt van Breda na Amsterdam te mogen vertrecken, roso.',
#  'Conferentie Krijghsgevangenen afgebro- ken, ar.',
#  'der Gedeputeerden tot de Ko- ninghlycke Portugaelsche Bruydt, ES)',
#  'Drakesteyn, toor.',
#  'Druet, tost.',
#  'Bk, Brigadier, versoeckende tot',
#  'Els, Boudewyn Willem , Capiteyn, versoeckende den eedt by procura- tie te mogen doen, gtr.',
#  'Els, Collonel en Brigadier, versoec- kende het Gouvernement van Roer- monde by vacature, toro.',
#  'gelast alle devorren aen te wen- den tot ontslaginge van het Schip de jonge lan, met retorsie na West- Indien varende, door Engelsche ge- nomen, en tot Jamaica opgebraght, tegens de Tractaten, ist.',
#  'wegens senden van noch twee Regimenten uyt Engelandt na Oost- ende, ros.',
#  'wegens Convoy na de Midde- landtiche Zee, int.',
#  'Farinel, Weduwe la Lane, hondert guldens toegeleyt eens, rios.',
#  'Hardi, Bode, toor.',
#  'Hilvarenbeeck door vyandtlijcke Dra- gonders gebrandt, en te overleggen wat daer tegen te doen, tror.',
#  'consent in den ordinaris en ex- traordinaris Staet van oorlogh , DEN',
#  'wegens senden van eenige Bal- lotten en Huysraet na het Keysers Hof, ost.',
#  'Kollen, Canter der Cathedrale Kerck tot Roermonde , versoeckt het De- conaetschap, ris.',
#  'JAcoux , Kryghs-gevangen , uyt te',
#  "Leenmannen van 't Leenhof van Valc- kenburgh, zor.",
#  'Leydeckers Kneghts eens ses guldens te geven, it.',
#  'rapport, rror.',
#  'Maturin , in Vranckrijck gevangen , om vrydom versoeekende, ros.',
#  'Met zelaersKnechts eens ses guldens te geven, it.',
#  'Munter gecommitteert in het Colle- gie ter Admiraliteyt tot Amsterdam» ns. N.',
#  'NJAlatenschap van fijne Majesteyt van',
#  'Megotiatie Roesteren, in het Ampt van Montfort, van twaelf hondert patacons, so.',
#  'van tweemael hondert duysent rijcksdaelders voor den Swabischen Kreytz, ros.',
#  'Octroy voor Pieter Neef en Adriaentje',
#  'Stilde, omme by uyterste wille te',
#  'Eght, om twee duysent patacons',
#  'te mogen opnemen tegens vier ten',
#  'voor Jan Smallengangh om van',
#  'wijck, om alleen binnen den Bosch',
#  'Bogaert, om van hare Goederen in',
#  'vrouw van Jan de Groote, omme',
#  'van hare Goederen in Vlaenderen',
#  'voor Ingelanden van de zuydt-kant',
#  'versoec kende in toekomende al- daer geen Troupes te cantonneren, EN',
#  'P.',
#  'rakende de Frfgenamen van Bel- lerbusch, rors.',
#  'receptie, Gor.',
#  'kennisse gevende van sijn huwe- lijck met de Princesse Maria Louise van Hessen, sor.',
#  'Capitulatie ende veroveringe van Ryssel, tory.',
#  'Ordonnantie van ses duysendt guldens ter goeder reeckeningh , cog.']

# %%
s = df.groupby(['clean_lemma']).num_refs.sum().sort_values()
for index in s[s > 100].index:
    print(f"{index: <40}{s[index]: > 5}")
# Out:
# Bergen op Zoom                           101.0
# vander Duyn                              101.0
# Vranckrijck                              102.0
# weegens                                  102.0
# Commisien                                186.0
# Smissaart                                186.0
# Barbaryen                                187.0
# de Bruyne                                197.0
# Passeporten                              198.0
# Gallieris                                198.0
# Buspulver te                             199.0
# de Groot                                 200.0
# representerende de                       201.0
# Houwens                                  202.0
# Burmania                                 205.0
# Zeesaaken                                206.0
# Lemmens                                  208.0
# Admiraliteyt in Vrieslandt               210.0
# Brieven van Addres                       211.0
# advis                                    214.0
# Westindische Compagnie                   215.0
# West-Indische Compagnie                  217.0
# Raad van Braband                         220.0
# ED                                       221.0
# EVX                                      223.0
# Hogendorp                                231.0
# Generaliteyts Reekenkamer                232.0
# EE                                       234.0
# Bruyninx                                 236.0
# Ginckel                                  236.0
# Oostindische Compagnie                   244.0
# van Assendelft                           246.0
# Admiraliteyten in het                    251.0
# Overquartier van Gelderland              256.0
# van Burmania                             256.0
# Raad                                     257.0
# Brussel                                  262.0
# Declaratien                              268.0
# Admiraliteyt op de Maze                  276.0
# DEX                                      282.0
# sHertogenbosch                           285.0
# Octroyen                                 285.0
# Overmaaze                                286.0
# Admiraliteyt in Zeelandt                 287.0
# de Swart                                 291.0
# Webers                                   291.0
# van Til                                  292.0
# Militaire saken                          293.0
# Pruyssen                                 295.0
# Engelandt                                298.0
# Doornick                                 298.0
# Mauritius                                304.0
# Overmaze                                 309.0
# Beurssen aangaande                       316.0
# Bergen op den Zoom                       320.0
# van Staate te                            323.0
# Denemarcken                              339.0
# Zeelandt                                 348.0
# Gedeputeerden                            366.0
# Vrieslandt                               371.0
# van Kinschot                             372.0
# Zeesaacken                               375.0
# Memorien                                 376.0
# Vriesland                                404.0
# Admiraliteyt in het Noorder Quartier     423.0
# Admiraliteyt op de Maaze                 442.0
# Breda                                    443.0
# Maastricht                               454.0
# Verlooven                                492.0
# Pesters                                  498.0
# Gelderlandt                              560.0
# Hollandt                                 565.0
# Rumpf                                    565.0
# Overquartier van Gelderlandt             568.0
# vander Meer                              629.0
# Overyssel                                644.0
# van Hoey                                 647.0
# Commissien                               673.0
# Gelderland                               684.0
# Zeeland                                  684.0
# EX                                       702.0
# ren                                      713.0
# Utrecht                                  724.0
# Militaire saaken                         753.0
# Raadt van State                          764.0
# Groningen                                773.0
# Raadt van Staate                         780.0
# Finantie                                 786.0
# Admiraliteyt tot Amsterdam               829.0
# Hop                                      930.0
# Militaire saacken                        941.0
# Brieven van                              1029.0
#                                          1050.0
# E                                        1083.0
# Militaire                                1172.0
# Vlaanderen                               1241.0
# s Hertogenbosch                          2018.0
# Raad van Staate                          2254.0
# Pasporten                                2562.0
# Holland                                  2667.0

# %%
df[df.clean_lemma.str.len() < 4].clean_lemma.value_counts()
# Out:
#        1037
# Hop     974
# E       836
# ren     677
# EX      520
#        ...
# iem       1
# cie       1
# Nys       1
# wyk       1
# Eck       1
# Name: clean_lemma, Length: 453, dtype: int64

# %%
temp_df = df[df.clean_lemma.str.len() >= 4]

sample_lemma_num_refs = temp_df.groupby(['clean_lemma']).num_refs.sum().sample(1000)

# %%
sample_df = df[df.clean_lemma.isin(sample_lemma_num_refs.index)]
sample_df.shape
# Out:
# (13638, 16)

# %%
{term: 'person_name' for term in list(sample_df.clean_lemma.drop_duplicates())}
# Out:
# {'nee Winter quartieren': 'person_name',
#  'Autwerpen': 'person_name',
#  'Armaitres tot Duynkercken': 'person_name',
#  'Auvergne': 'person_name',
#  'Backere': 'person_name',
#  'Chevallerie': 'person_name',
#  'Eedt van suyveringe': 'person_name',
#  'Geursen': 'person_name',
#  'Ginu': 'person_name',
#  'Guardemeuble de Lange': 'person_name',
#  's Hertogenbosch': 'person_name',
#  'SI Jacomo Dirix': 'person_name',
#  'Jan Somer': 'person_name',
#  'Langenbergh': 'person_name',
#  'Lillo': 'person_name',
#  'Meuthen': 'person_name',
#  'een Friseer-molen te': 'person_name',
#  'Vlaenderen': 'person_name',
#  'Oostende': 'person_name',
#  'Oyen': 'person_name',
#  'Pasporten-recht': 'person_name',
#  'Plante': 'person_name',
#  'Queisen': 'person_name',
#  'Rumpf': 'person_name',
#  'Seville': 'person_name',
#  'Sichterman': 'person_name',
#  'Tullebardin': 'person_name',
#  'Westwoldingerlandt': 'person_name',
#  'Aken': 'person_name',
#  'Andringa': 'person_name',
#  'Aspremont': 'person_name',
#  'Barbaryen': 'person_name',
#  'Benthein-Steinfurt': 'person_name',
#  'Berckhoffer': 'person_name',
#  'Beyersche interessen': 'person_name',
#  'Blauw Vaendel': 'person_name',
#  'Bodens van den Hucgh': 'person_name',
#  'Brouwêts tot Cortrijck': 'person_name',
#  'Campen; scilder': 'person_name',
#  'Carpenter van Westerbeek': 'person_name',
#  'Commissie in': 'person_name',
#  'Coolin Lambert': 'person_name',
#  'Crammont': 'person_name',
#  'Douglas': 'person_name',
#  'Elnoo': 'person_name',
#  'Engeland': 'person_name',
#  'Fortificatie-werckers': 'person_name',
#  'Glauwenbergh': 'person_name',
#  'Graanara': 'person_name',
#  'Jarges': 'person_name',
#  'kloeckhof': 'person_name',
#  'Leuwen': 'person_name',
#  'Lisibon': 'person_name',
#  'omûmeren': 'person_name',
#  'Overquarter van Gelderlandt': 'person_name',
#  'Portal': 'person_name',
#  'promotie Gereraels': 'person_name',
#  'Rapin': 'person_name',
#  'Roulié': 'person_name',
#  'Scalé': 'person_name',
#  'Schaep tot Winsheyn': 'person_name',
#  'Sourdeau': 'person_name',
#  'Stevenswaert': 'person_name',
#  'vittinghof': 'person_name',
#  'Westrhenen': 'person_name',
#  'Adminiiteyt in Vriesande': 'person_name',
#  'Aken Winter': 'person_name',
#  'Andel': 'person_name',
#  'Bergen in Henegouwen': 'person_name',
#  'Berle': 'person_name',
#  'Bronckhorst': 'person_name',
#  'Brusel': 'person_name',
#  'Cartpfranger': 'person_name',
#  'Eusum Cupiteym': 'person_name',
#  'Fourheau': 'person_name',
#  'prancouille': 'person_name',
#  'Fuicmmersdorf': 'person_name',
#  'sche': 'person_name',
#  'kloot': 'person_name',
#  'Luyek': 'person_name',
#  'Mealingh': 'person_name',
#  'Meulenmeester': 'person_name',
#  'Overquantier van Gelderlandt': 'person_name',
#  'Penia': 'person_name',
#  'pritselwits': 'person_name',
#  'Roon': 'person_name',
#  'savoyen': 'person_name',
#  'Senseif': 'person_name',
#  'Stavelo': 'person_name',
#  'Synodus Deputatie': 'person_name',
#  'Teerhandel in Sweeden': 'person_name',
#  'Warneton': 'person_name',
#  'Willemsdoôrff': 'person_name',
#  'Aennemers van Foriificatien': 'person_name',
#  'Cochet': 'person_name',
#  'Conventie': 'person_name',
#  'Etfgenamen van Maria Elsevier': 'person_name',
#  'Keyser': 'person_name',
#  'Kintichot': 'person_name',
#  'Leipaul': 'person_name',
#  'Lovendegem': 'person_name',
#  'Louis': 'person_name',
#  'Mennoniten': 'person_name',
#  'Gouvemen van Breda': 'person_name',
#  'Oostice': 'person_name',
#  'Pojoh': 'person_name',
#  'Raede van Vlaenderen': 'person_name',
#  'Revisien': 'person_name',
#  'Qalé': 'person_name',
#  'serlee': 'person_name',
#  'Baudclo': 'person_name',
#  'Brieven van': 'person_name',
#  'Commistien': 'person_name',
#  'Belingerwolder Schans': 'person_name',
#  'Consenten Vrieslandt in de': 'person_name',
#  'Hefpén': 'person_name',
#  'Hooghwerf': 'person_name',
#  'Levantschén Handel': 'person_name',
#  'Marocco': 'person_name',
#  'mando': 'person_name',
#  'de kuahe': 'person_name',
#  'Moseôvien': 'person_name',
#  'armeert': 'person_name',
#  'Pierson': 'person_name',
#  'Schats': 'person_name',
#  'Schiller': 'person_name',
#  'Uytwislelen van Gevangenen': 'person_name',
#  'Wegenaers': 'person_name',
#  'Assuer': 'person_name',
#  'BAerle': 'person_name',
#  'Boreel': 'person_name',
#  'Brahe': 'person_name',
#  'Burgh': 'person_name',
#  'Dixmuyden': 'person_name',
#  'ren der Douané': 'person_name',
#  'Jurez van de Magiftraa': 'person_name',
#  'Fynaere': 'person_name',
#  'misen van de Roomsche Religie': 'person_name',
#  'verpondingen': 'person_name',
#  'surcheantie': 'person_name',
#  'dikant Daverveli van': 'person_name',
#  'Thnken': 'person_name',
#  'Klinggraef': 'person_name',
#  'Lours': 'person_name',
#  'Matieof': 'person_name',
#  'Ofmabrugge': 'person_name',
#  'peters': 'person_name',
#  'Satrien': 'person_name',
#  'spitalt': 'person_name',
#  'swabischen Kteyts': 'person_name',
#  'uytwiselen': 'person_name',
#  'Weydentels': 'person_name',
#  'vife': 'person_name',
#  'Batin': 'person_name',
#  'Boursly': 'person_name',
#  'EE) Heer van den Bergh': 'person_name',
#  'Consenten Zeelandt': 'person_name',
#  'Hffren': 'person_name',
#  'Fantoni': 'person_name',
#  'Gedeputeerden te Brusses': 'person_name',
#  'Gossart': 'person_name',
#  'nage': 'person_name',
#  'interesen': 'person_name',
#  'den door de': 'person_name',
#  'naer Engelandt': 'person_name',
#  'dorpen': 'person_name',
#  'penen': 'person_name',
#  'Borchet de': 'person_name',
#  'Hen Huntagh': 'person_name',
#  'Ryers‚ Secretaris van Aerlerixtel': 'person_name',
#  'Sixen Gotha': 'person_name',
#  'van Sommelsdijk': 'person_name',
#  'Weydctfelt': 'person_name',
#  'migen': 'person_name',
#  'Commissien in': 'person_name',
#  'den Dansmeefier': 'person_name',
#  'aduis': 'person_name',
#  'Guluckstadt': 'person_name',
#  'pestch': 'person_name',
#  'den jare': 'person_name',
#  'XZ Quay': 'person_name',
#  'Schlippenbachs Dragouders': 'person_name',
#  'Slype': 'person_name',
#  'DE Thiriard Weduwe': 'person_name',
#  'Yvoy tot Commandant van': 'person_name',
#  'Zevender': 'person_name',
#  'Admiraliteyt in het Noorder Quartier': 'person_name',
#  'Alberts': 'person_name',
#  'Alieanten': 'person_name',
#  'Ardesch tot Predikanm der Ambassude in Spagne': 'person_name',
#  'Barbatsen': 'person_name',
#  'Brieven van executie': 'person_name',
#  'Equipage van': 'person_name',
#  'TDAddenburgh': 'person_name',
#  'Ruysch': 'person_name',
#  'Verbanden': 'person_name',
#  'Verburgh': 'person_name',
#  'Nstructie': 'person_name',
#  'Keppel': 'person_name',
#  'Commissarissen Instructeurs': 'person_name',
#  'bericht op de Requeste van vander Put': 'person_name',
#  'wneieren van': 'person_name',
#  'noiervin Engelandt': 'person_name',
#  'mugh': 'person_name',
#  'gens de': 'person_name',
#  'Munnick': 'person_name',
#  'Overquartier van Gelderlant': 'person_name',
#  'Vlaanderen': 'person_name',
#  'Abrabanel Brieven van': 'person_name',
#  'Bock Pasport verleent': 'person_name',
#  'Champolion': 'person_name',
#  'Claterenbosch': 'person_name',
#  'Clermond': 'person_name',
#  'Fourquin': 'person_name',
#  'Greenwood': 'person_name',
#  'Grindet': 'person_name',
#  'Heron': 'person_name',
#  'de Maré Pasport': 'person_name',
#  'Mordechai': 'person_name',
#  'Pasporten': 'person_name',
#  'Piquet': 'person_name',
#  'Pontu': 'person_name',
#  'gistraat van Hulster Ambacht': 'person_name',
#  'Rynhart de': 'person_name',
#  'van Ryn Pasport verleent': 'person_name',
#  'Sauveguarde': 'person_name',
#  'vander Swaan': 'person_name',
#  'Versterre': 'person_name',
#  'Weyer Brieven van': 'person_name',
#  'oorlogh': 'person_name',
#  'ren tot de': 'person_name',
#  'om Pasport': 'person_name',
#  'eximeert': 'person_name',
#  'Admiraliteyt in het gemeen': 'person_name',
#  'Afferden te': 'person_name',
#  'van Asperen Brieven van': 'person_name',
#  'Bescheyt': 'person_name',
#  'Beys Brieven van': 'person_name',
#  'de Bou Pasport': 'person_name',
#  'Bout': 'person_name',
#  'vander Busse': 'person_name',
#  'Cats': 'person_name',
#  'Confeffeurs van Galeyen': 'person_name',
#  'Constant Ade': 'person_name',
#  'Coorne Brieven van': 'person_name',
#  'van Eys': 'person_name',
#  'de Grys': 'person_name',
#  'Iacq': 'person_name',
#  'Lentz Brieven van': 'person_name',
#  'de Liscontiner': 'person_name',
#  'Lormier': 'person_name',
#  'HPMEA,Maatstricht': 'person_name',
#  'Meurer': 'person_name',
#  'Muntsaken op de Remonstrantie van de Raden': 'person_name',
#  'de sa Naye': 'person_name',
#  'Netten': 'person_name',
#  'dent Magis': 'person_name',
#  'gemet': 'person_name',
#  'de Reboulet': 'person_name',
#  'Romswinkel Pasport': 'person_name',
#  'Sangniez Pagort': 'person_name',
#  'Saysoen Ostroy': 'person_name',
#  'Schoneveld Pusport': 'person_name',
#  'Smulders': 'person_name',
#  'Strom Pasport': 'person_name',
#  'Tscharner Ade van': 'person_name',
#  'Velthuys': 'person_name',
#  'Verschuur Pasport': 'person_name',
#  'vander Wayen': 'person_name',
#  'de Beau Pasport': 'person_name',
#  'Lootsen': 'person_name',
#  'Blanckenhage Paspert': 'person_name',
#  'Cardol Brieven van': 'person_name',
#  'Guerin Brieven van': 'person_name',
#  'Guiton': 'person_name',
#  'Hogeveen': 'person_name',
#  'Houttuyn': 'person_name',
#  'Tsselmuden': 'person_name',
#  'Ilelmuden': 'person_name',
#  'Keetlaar': 'person_name',
#  'Meuleman': 'person_name',
#  'ken van het Regiment van Sixma': 'person_name',
#  'Mulder de Cathedrale Kerck te Doornick': 'person_name',
#  'O Ckerse': 'person_name',
#  'vile': 'person_name',
#  'in de': 'person_name',
#  'Rade': 'person_name',
#  'penen van Breda': 'person_name',
#  'Ritzius': 'person_name',
#  'de Rue': 'person_name',
#  'Schoningh': 'person_name',
#  'Smits': 'person_name',
#  'Snoukaart': 'person_name',
#  'Spreugel Pasport': 'person_name',
#  'Taats van Amerongen': 'person_name',
#  'de Vulson Pasport': 'person_name',
#  'Werber Pasport': 'person_name',
#  'Werkers van Fortificatien': 'person_name',
#  'Wormer': 'person_name',
#  'du Bau Pasport': 'person_name',
#  'Bonhomme Brieven van': 'person_name',
#  'nagel': 'person_name',
#  'Chommel Paspor': 'person_name',
#  'van Coehoorn': 'person_name',
#  'Colyear': 'person_name',
#  'Cuppens': 'person_name',
#  'Doenssen': 'person_name',
#  'Gerbrantz': 'person_name',
#  'de Hamal': 'person_name',
#  'van Hodenpyl': 'person_name',
#  'Hout': 'person_name',
#  'Kerkelyke saaken': 'person_name',
#  'van Keulen': 'person_name',
#  'Luttringhausen': 'person_name',
#  'Makeleyn': 'person_name',
#  'Memorien van Meynertshagen': 'person_name',
#  'van Mengerssen': 'person_name',
#  'Olingius': 'person_name',
#  "voor H'ertmuller": 'person_name',
#  'voor Jerond tot den': 'person_name',
#  'Pieflier': 'person_name',
#  'Roelandts': 'person_name',
#  'Rolijn': 'person_name',
#  'Schermer Pasport': 'person_name',
#  'Velius': 'person_name',
#  'Boheem': 'person_name',
#  'Bouwer': 'person_name',
#  'Brouwer Pasport': 'person_name',
#  'van Campenhout': 'person_name',
#  'LC Bbe': 'person_name',
#  'Fresquet Brieven van': 'person_name',
#  'Grouingen Ommelanden': 'person_name',
#  'met Deencmarken': 'person_name',
#  'over te': 'person_name',
#  'van Kruysselbergen Brieven van': 'person_name',
#  'Mess': 'person_name',
#  'vander Meyde': 'person_name',
#  'de la Motte': 'person_name',
#  'de Potter': 'person_name',
#  'Purnel': 'person_name',
#  'Generaal': 'person_name',
#  'Reffuge': 'person_name',
#  'Restant': 'person_name',
#  'de Salier': 'person_name',
#  'Schuurman': 'person_name',
#  'van Slingelandt te': 'person_name',
#  'baght': 'person_name',
#  'Weis Pasport': 'person_name',
#  'BAaren': 'person_name',
#  'Buchwits Pasport tot den': 'person_name',
#  'Pesters. Gos': 'person_name',
#  'slate te': 'person_name',
#  'Limiten': 'person_name',
#  'de Landeryen': 'person_name',
#  'Holsteyn-Norburgh': 'person_name',
#  'van lsbecq': 'person_name',
#  'Juslamand': 'person_name',
#  'Kluyck': 'person_name',
#  'Landtloopers': 'person_name',
#  'Marcheed': 'person_name',
#  'van Marle': 'person_name',
#  'Nalatensohap;a te': 'person_name',
#  'aghrerstallen der GChaurpaltische Trouppes': 'person_name',
#  'Magistraat van de Grave': 'person_name',
#  'de Retrvacta': 'person_name',
#  'Rentmeestersampt': 'person_name',
#  'Ries Brieven van': 'person_name',
#  'Sainlois': 'person_name',
#  'Stannarius': 'person_name',
#  'Tournay': 'person_name',
#  'Walter': 'person_name',
#  'van Adrichem Brieven van': 'person_name',
#  'Burgers van': 'person_name',
#  'Codyn': 'person_name',
#  'Commissie in het': 'person_name',
#  'de Gumoins Brieven van': 'person_name',
#  'de Jonge Oetroy': 'person_name',
#  'Lemmens Pasport tot den': 'person_name',
#  'Martens Pasport': 'person_name',
#  'za Landen': 'person_name',
#  'van Riel': 'person_name',
#  'Schorer Hitaal van Vlaanderen': 'person_name',
#  'Surceantie. Siet Brieven van Surceantie': 'person_name',
#  'de Vree': 'person_name',
#  'vander Wijck': 'person_name',
#  'wa Aarsen': 'person_name',
#  'Ayen': 'person_name',
#  'Bastie': 'person_name',
#  'Bertlingh': 'person_name',
#  'Colen': 'person_name',
#  'TLabricius': 'person_name',
#  'TH Aack': 'person_name',
#  'de Haan': 'person_name',
#  'het Landt te': 'person_name',
#  'Regenten van JAarlerixtel': 'person_name',
#  'seert': 'person_name',
#  'van Oostenrijck': 'person_name',
#  'Kelkringh': 'person_name',
#  'anderinge der Guarnisoenen': 'person_name',
#  'Moige': 'person_name',
#  'Bacquere': 'person_name',
#  'Schotte': 'person_name',
#  'Steyn Sumuel': 'person_name',
#  'vander Thommen': 'person_name',
#  'Valiez': 'person_name',
#  'Amende': 'person_name',
#  "van 'BAaden": 'person_name',
#  'vander Beeck': 'person_name',
#  'le CAcheur': 'person_name',
#  'den om de Wynen': 'person_name',
#  'voor salaris': 'person_name',
#  'geleerden': 'person_name',
#  'tie van Obligatien': 'person_name',
#  'over Prins Maximiliaan': 'person_name',
#  'de Leydekkers van': 'person_name',
#  'Loef': 'person_name',
#  'woer van Monteeringe': 'person_name',
#  'wan den Kroonprins van Pruyssen': 'person_name',
#  'sumeeren': 'person_name',
#  'Savornin': 'person_name',
#  'schap': 'person_name',
#  'fier vander Haar': 'person_name',
#  'Heeze': 'person_name',
#  'van Postelhout': 'person_name',
#  'ster': 'person_name',
#  'Schmidt': 'person_name',
#  'vinck': 'person_name',
#  'erdres': 'person_name',
#  'approbatie van het': 'person_name',
#  'Aadmiraliteyt in Vrieslandt': 'person_name',
#  'Bedot Brieven van': 'person_name',
#  'de Bois Brieven van': 'person_name',
#  'Brigadiers van de Cavallerye': 'person_name',
#  'de Bruen': 'person_name',
#  'Resolutie': 'person_name',
#  'zepermitteert den': 'person_name',
#  'van Campen': 'person_name',
#  'Consenten van Vrieslendt': 'person_name',
#  'Couwenhoven': 'person_name',
#  's Cravemoer': 'person_name',
#  'de Harder Brieven van Voorschryvéns': 'person_name',
#  'Heeft van Oyen': 'person_name',
#  'Jekerman': 'person_name',
#  'vander Mande': 'person_name',
#  'van Mellingen': 'person_name',
#  'van Munckhausen': 'person_name',
#  'Ockenburgh': 'person_name',
#  'Olmius': 'person_name',
#  'Palm': 'person_name',
#  'Gruneck': 'person_name',
#  'Jau-Siegen': 'person_name',
#  'betalinge van de': 'person_name',
#  'executie te': 'person_name',
#  'de la Roeque': 'person_name',
#  'van Rysingen': 'person_name',
#  'Sonsbeeck': 'person_name',
#  'Verschuur verlof': 'person_name',
#  'watérbeek': 'person_name',
#  'vander Werff': 'person_name',
#  'westerveen': 'person_name',
#  'miraliteyten te': 'person_name',
#  'land': 'person_name',
#  'de la Calmette': 'person_name',
#  'gaande': 'person_name',
#  'Clemens': 'person_name',
#  'Comnkoper': 'person_name',
#  'Danckers': 'person_name',
#  'Del wegens Ihllaudt': 'person_name',
#  'Dubbels': 'person_name',
#  'DCaAtbrie': 'person_name',
#  'contra': 'person_name',
#  'gepermitteert te': 'person_name',
#  'Heer Brandwyk van Blokland': 'person_name',
#  'Irhoren': 'person_name',
#  'Middelen tot Iperen': 'person_name',
#  'Middelen te Iperen': 'person_name',
#  'TVT Akeman': 'person_name',
#  'van Lingen': 'person_name',
#  'van Macheren': 'person_name',
#  'gelukte Militaire Lighamen': 'person_name',
#  'te Dordrecht te': 'person_name',
#  'te seponeren': 'person_name',
#  'B Aad van Braband': 'person_name',
#  'zeetenen van Heeswyck': 'person_name',
#  'genten van Udenbout': 'person_name',
#  'wan Hilvarenbeek': 'person_name',
#  'le Roy Brieven van': 'person_name',
#  'Royers': 'person_name',
#  'Segbroek': 'person_name',
#  'de Veth': 'person_name',
#  'warsinck': 'person_name',
#  'avegens de': 'person_name',
#  'pen te': 'person_name',
#  'en Soon': 'person_name',
#  'Biel': 'person_name',
#  'lateren van Depesches': 'person_name',
#  'Blanck in het Harnas': 'person_name',
#  'Bousart': 'person_name',
#  'van Eppinga': 'person_name',
#  'Heesters': 'person_name',
#  'van Heeteren': 'person_name',
#  'persooneelen omslagh': 'person_name',
#  'pliantens': 'person_name',
#  'van de Magistraat van': 'person_name',
#  'in Huwelyck': 'person_name',
#  'Deoghter': 'person_name',
#  'den Predikant': 'person_name',
#  'Placaat op de Convoyen': 'person_name',
#  'seeker': 'person_name',
#  'de St. Pieter': 'person_name',
#  'van Utrecht op': 'person_name',
#  'schen Deeneniarken': 'person_name',
#  'Staat': 'person_name',
#  'Levantsen Handel': 'person_name',
#  'Matty': 'person_name',
#  'tie van den': 'person_name',
#  'fangen': 'person_name',
#  'soek van Rensonnes': 'person_name',
#  'van Daalem te': 'person_name',
#  'van )Addenburgh': 'person_name',
#  'Jperen': 'person_name',
#  'de door': 'person_name',
#  'van vrydom': 'person_name',
#  'van Ripperda tot Vorden': 'person_name',
#  'Deurs van Assendeft te': 'person_name',
#  'gemoomen': 'person_name',
#  'Teelingh': 'person_name',
#  'landt op de': 'person_name',
#  'en te': 'person_name',
#  'talinge van de': 'person_name',
#  'van Westerholt tot Hackfort': 'person_name',
#  'Willinek': 'person_name',
#  'Wiltman': 'person_name',
#  "d'Averhault te": 'person_name',
#  'Bertrat': 'person_name',
#  'van Boekholt': 'person_name',
#  'Bougy': 'person_name',
#  'vander Bussche': 'person_name',
#  'Commissarissen Deciseurs Commissie': 'person_name',
#  'proceduuren van': 'person_name',
#  'Ellevier': 'person_name',
#  'Envoyé Hop': 'person_name',
#  'Heeteren': 'person_name',
#  'Requeste van Roomsche Ingezeetenen van': 'person_name',
#  'reekeninge te brengen': 'person_name',
#  'kende de': 'person_name',
#  'van Regenten van Vessem': 'person_name',
#  'Beek': 'person_name',
#  'vier op de Requeste van de Haan': 'person_name',
#  'nicten': 'person_name',
#  'accordeert': 'person_name',
#  'de Raad van Staate te': 'person_name',
#  'Propositie van Gelderland': 'person_name',
#  'ritoir van den Abt van St. Hubert': 'person_name',
#  'soignes': 'person_name',
#  'casie': 'person_name',
#  'Houttingh': 'person_name',
#  'Jongbloet': 'person_name',
#  'Meesen': 'person_name',
#  'vander Merck': 'person_name',
#  'Minkelers': 'person_name',
#  'van Naarssen': 'person_name',
#  'Ontslaginge van Fideicommis': 'person_name',
#  'de OVUaay': 'person_name',
#  'genten van de Grave': 'person_name',
#  'Inwoonderen van de Meyerye': 'person_name',
#  'van Braband': 'person_name',
#  'beright op het': 'person_name',
#  'advis op': 'person_name',
#  'le Roux': 'person_name',
#  'Saskerus': 'person_name',
#  'Saxen Hilburghausen Mieuwejaarswensch in': 'person_name',
#  'komende': 'person_name',
#  'ten modt': 'person_name',
#  'bassadeur vander Meer': 'person_name',
#  'Swabe': 'person_name',
#  'Pendevin': 'person_name',
#  'van Hulster Ambaght': 'person_name',
#  'gato': 'person_name',
#  'leen te': 'person_name',
#  'Warry te': 'person_name',
#  'voor de Westindische Compagnie': 'person_name',
#  'Requeste van Regenten van Halsteren': 'person_name',
#  'den 463': 'person_name',
#  'Buckings': 'person_name',
#  'van Buytenheim': 'person_name',
#  'Cuypers': 'person_name',
#  'Feitema': 'person_name',
#  'Frines': 'person_name',
#  'de Gruyter': 'person_name',
#  'de haar Hoogb Mog. Regenten van Borkel': 'person_name',
#  'Suppliant': 'person_name',
#  's Hertogenbosch te': 'person_name',
#  'Heoooningen': 'person_name',
#  'Loeff': 'person_name',
#  'seben Gereghte der Stad Maastrigt': 'person_name',
#  'den herwaants te': 'person_name',
#  'scheydinge': 'person_name',
#  'van Moens': 'person_name',
#  'na Doornik te': 'person_name',
#  "en't Land van Ravestein": 'person_name',
#  'dard': 'person_name',
#  'sertie': 'person_name',
#  'Romein': 'person_name',
#  'de Vassy': 'person_name',
#  'hentie': 'person_name',
#  'trent Oudenaarden aangedaan': 'person_name',
#  'Bartaud': 'person_name',
#  'Bertus': 'person_name',
#  'terigbiem': 'person_name',
#  'Beursse van': 'person_name',
#  'raaiteyts Reckenkamer te': 'person_name',
#  'Commistirisen Initructeurs': 'person_name',
#  'Croes Lycogten': 'person_name',
#  'vander Cruys': 'person_name',
#  'Eed van Secietefe': 'person_name',
#  'Eed van Suyveringe van Radermacher': 'person_name',
#  'Everue': 'person_name',
#  'Festu': 'person_name',
#  'stein': 'person_name',
#  'en de Collatie': 'person_name',
#  'Crayenhof': 'person_name',
#  'na Holland tot': 'person_name',
#  'Gonzal': 'person_name',
#  'de Groulaart': 'person_name',
#  'Haulbeeck': 'person_name',
#  'Tourton': 'person_name',
#  'van den Raadt van Staate': 'person_name',
#  'Kappeyne': 'person_name',
#  'Luchte te': 'person_name',
#  'de Moleron': 'person_name',
#  'Nassauw Averquercq': 'person_name',
#  'Paysen Weduwe': 'person_name',
#  'de Raad': 'person_name',
#  'singel': 'person_name',
#  'Slichers': 'person_name',
#  'ring': 'person_name',
#  'ralitevt in Zeeland': 'person_name',
#  'van Zeeland': 'person_name',
#  'den Beer': 'person_name',
#  'Bockhorst': 'person_name',
#  'Boiteux': 'person_name',
#  'ferentie te': 'person_name',
#  'ninn': 'person_name',
#  'halen van den Dader': 'person_name',
#  'Commisien in Het': 'person_name',
#  'Franco': 'person_name',
#  'om Emigranten te plaatsen': 'person_name',
#  'Hesien-Philipsdal': 'person_name',
#  'schen Bockem': 'person_name',
#  'den Hollanaschen Bockem': 'person_name',
#  'vens in': 'person_name',
#  'Rhabarber': 'person_name',
#  'van Kinschot': 'person_name',
#  'Luissus': 'person_name',
#  'pasagie': 'person_name',
#  'generaale pyrdon': 'person_name',
#  'Offermans': 'person_name',
#  'van Pere': 'person_name',
#  'Aerden': 'person_name',
#  'Vaandel': 'person_name',
#  'van vier': 'person_name',
#  'Scherinx': 'person_name',
#  'Verkroost': 'person_name',
#  'een Huys': 'person_name',
#  'tien Emigranten': 'person_name',
#  'Alvarez': 'person_name',
#  'Concnien Vn Vresndt': 'person_name',
#  'die van Dantzick': 'person_name',
#  'Galaly': 'person_name',
#  'Groeneveldt': 'person_name',
#  'tot tyd': 'person_name',
#  'saonen': 'person_name',
#  'Leendertsz': 'person_name',
#  'Leyendecker': 'person_name',
#  'Maaslandt': 'person_name',
#  'de Mattha': 'person_name',
#  'sterdam te': 'person_name',
#  'derlandtsche Pasporten': 'person_name',
#  'Michel': 'person_name',
#  'de Deserteurs': 'person_name',
#  'en Commando': 'person_name',
#  'Oostvrieslandt Mieuwejaarswensch in': 'person_name',
#  'van Ovenloop': 'person_name',
#  'Pierron': 'person_name',
#  'Churfurst van Keulen': 'person_name',
#  'Magistraat van Sas van Gent': 'person_name',
#  'Rolas': 'person_name',
#  'Rouzier': 'person_name',
#  'Samber': 'person_name',
#  'gley Galey': 'person_name',
#  'het Placaat op de Turcksche Passen': 'person_name',
#  'piteyn Lijnslager': 'person_name',
#  'van Waalwyck': 'person_name',
#  'Jstright': 'person_name',
#  'gifien': 'person_name',
#  'Coers': 'person_name',
#  'DAasdonck': 'person_name',
#  'Delifsen': 'person_name',
#  'van Dopf': 'person_name',
#  'van Euskercken': 'person_name',
#  'reren': 'person_name',
#  'afgewesen': 'person_name',
#  'de Gomar': 'person_name',
#  'de Groulart': 'person_name',
#  'de Requeste van Werther': 'person_name',
#  'van Holbach': 'person_name',
#  'Kerkelijke saacken': 'person_name',
#  'de Meulder': 'person_name',
#  'Muhamet Effendi': 'person_name',
#  'BD Aadt van Brabandt te': 'person_name',
#  'Rappeyne': 'person_name',
#  'de Sariac': 'person_name',
#  'Serlé Octroy': 'person_name',
#  'van Treeesium': 'person_name',
#  'Vinck Pasport': 'person_name',
#  'Vrencken': 'person_name',
#  'Arides': 'person_name',
#  'Hertogh van Sleeswijck Holsteyn': 'person_name',
#  'Chardonnette': 'person_name',
#  'Cloots': 'person_name',
#  'van Cranenburgh': 'person_name',
#  'Crap': 'person_name',
#  'Declaratien van de Vuurstoockster van Dors': 'person_name',
#  'Helingius': 'person_name',
#  'TAeobson': 'person_name',
#  'en Pausselijcke Religie te verbieden': 'person_name',
#  'Maasland Quartier': 'person_name',
#  'Maria de Lille': 'person_name',
#  'Generaal Major': 'person_name',
#  'Muntsaacken te': 'person_name',
#  'Predikanten in de Steeden van de Generali': 'person_name',
#  'Staringh': 'person_name',
#  'van Swanenbergh': 'person_name',
#  'tier te': 'person_name',
#  'Commissauissen Instructeurs': 'person_name',
#  'taris': 'person_name',
#  'Gelleken': 'person_name',
#  'de Hammer': 'person_name',
#  'van recognitie': 'person_name',
#  'Lande te': 'person_name',
#  'bees': 'person_name',
#  'van Heyden': 'person_name',
#  'Heyst': 'person_name',
#  'vander Hoeve te': 'person_name',
#  'wersôeck': 'person_name',
#  'Raymondt': 'person_name',
#  'Sande op': 'person_name',
#  'Schocker Brieven van': 'person_name',
#  'Straatmaackers': 'person_name',
#  'Titchanser': 'person_name',
#  'examinecren': 'person_name',
#  'Regenten van Sluys': 'person_name',
#  'Westerhoek': 'person_name',
#  'de Winter': 'person_name',
#  'Buteux Octroy': 'person_name',
#  'Land': 'person_name',
#  'Compioir van Bassora': 'person_name',
#  'bendeeren der Dieven den Koopman Lyfar': 'person_name',
#  'te Salonichi': 'person_name',
#  'Clarisse': 'person_name',
#  'Commissien in het gemeen': 'person_name',
#  'Commisiën te Waater': 'person_name',
#  'Generaliteyts Reeckenkaamer': 'person_name',
#  'Hanzeesteeden': 'person_name',
#  'Huyslselaar': 'person_name',
#  'der Kinderen': 'person_name',
#  'Mosberger': 'person_name',
#  'van Addenburgh': 'person_name',
#  'Schut': 'person_name',
#  'vanden Berck': 'person_name',
#  'van Beurden': 'person_name',
#  'en Bergb': 'person_name',
#  'Coermans': 'person_name',
#  'Commissies te Waater': 'person_name',
#  'Cruson Oatroy': 'person_name',
#  'versoeck van van Mengerssen': 'person_name',
#  'Schoolen': 'person_name',
#  'Man te de areeren': 'person_name',
#  'wan een Agent te Madrid te': 'person_name',
#  'Gerwen': 'person_name',
#  'Guichenon de Cbhastillon': 'person_name',
#  'Haay': 'person_name',
#  'de Hoy Proces': 'person_name',
#  'Legitimatie. Siet Brieven van Legitimatie': 'person_name',
#  'genten van Berchem': 'person_name',
#  'een Amptgeld': 'person_name',
#  'mandeverenden Officier': 'person_name',
#  'Magistraat der Stad Maastright op de': 'person_name',
#  'Requeste van van Haey': 'person_name',
#  'Railliat': 'person_name',
#  'Reseeuw': 'person_name',
#  'Schaumburgh-Lippe': 'person_name',
#  'Sinke': 'person_name',
#  'TCAisner': 'person_name',
#  'kamer op de Missive van de Admiraliteyt': 'person_name',
#  'Heere van Leeuwen': 'person_name',
#  'neraliteyts Reeckenkaamer': 'person_name',
#  'de Bosly': 'person_name',
#  'Bouquet': 'person_name',
#  'Caubergh': 'person_name',
#  'Comuusstarissen tot Antwerpen': 'person_name',
#  'Engelbreght': 'person_name',
#  'Heirmans': 'person_name',
#  'Mahieu': 'person_name',
#  'wan Leyden': 'person_name',
#  'consent van Utrecht in de': 'person_name',
#  'Richecourt': 'person_name',
#  'Rocquette': 'person_name',
#  'Akefsloot': 'person_name',
#  'Barlo': 'person_name',
#  'van Beresteyn': 'person_name',
#  'Candele': 'person_name',
#  'Grafper': 'person_name',
#  'Kursseboom': 'person_name',
#  'Kokker': 'person_name',
#  'Lansberge': 'person_name',
#  'Middelen te waater': 'person_name',
#  'Mobachius': 'person_name',
#  'van Nimmegen': 'person_name',
#  'tigh Snaphaanen': 'person_name',
#  'Revgersman': 'person_name',
#  'Rheede tot G': 'person_name',
#  'CAcrelaire': 'person_name',
#  'Velsenaar': 'person_name',
#  'Viwliet': 'person_name',
#  'Wielemaker': 'person_name',
#  'Beeckhuysen': 'person_name',
#  'Blonket': 'person_name',
#  'Botin': 'person_name',
#  'Bruynooge': 'person_name',
#  'Oormabé': 'person_name',
#  'Grasseur': 'person_name',
#  'Hongaryen': 'person_name',
#  'Horrent': 'person_name',
#  'schap Benthem van': 'person_name',
#  'te doen ten': 'person_name',
#  'protectie': 'person_name',
#  'te verkenen': 'person_name',
#  'de Lorieux': 'person_name',
#  'do van Steenbergen': 'person_name',
#  'nieuwe Compagnien Switzers': 'person_name',
#  'Mooren': 'person_name',
#  'van NTAssau': 'person_name',
#  'van onkosten': 'person_name',
#  'sehien': 'person_name',
#  'de hooge Overigheyd': 'person_name',
#  'Piliera': 'person_name',
#  'van Pullen': 'person_name',
#  'Sandouwille': 'person_name',
#  'Schueeberger': 'person_name',
#  'Steengraght': 'person_name',
#  'van Straaten': 'person_name',
#  'de Suarz': 'person_name',
#  'Wadsieen': 'person_name',
#  'van Waldeck': 'person_name',
#  'Blume': 'person_name',
#  'Bolte': 'person_name',
#  'Brievingh': 'person_name',
#  'Casteleyn': 'person_name',
#  'Diependaal': 'person_name',
#  'van Eckendonck': 'person_name',
#  'Gosse': 'person_name',
#  'moete': 'person_name',
#  'Aamiruliteyt tot': 'person_name',
#  'duyend': 'person_name',
#  'Hasiungius': 'person_name',
#  'Hastelaart': 'person_name',
#  'lusma': 'person_name',
#  'van Linange': 'person_name',
#  'Monier': 'person_name',
#  'Pous': 'person_name',
#  'Schimmelpenninck vander Oyen': 'person_name',
#  'de Tour': 'person_name',
#  'Veldhuysen': 'person_name',
#  'de vriend': 'person_name',
#  'Sanden': 'person_name',
#  'op de Moorséhe Kust': 'person_name',
#  'Bellanger': 'person_name',
#  'Beth': 'person_name',
#  'de Bochorst': 'person_name',
#  'Bogaats': 'person_name',
#  'Commifsansien Instructeurs': 'person_name',
#  'Eller': 'person_name',
#  'Gieven': 'person_name',
#  'de Hayman': 'person_name',
#  'Janszon': 'person_name',
#  'Visicher': 'person_name',
#  'Aardenburg': 'person_name',
#  'van bat Weeshuys te': 'person_name',
#  'van Westdorpe': 'person_name',
#  'Regenten van Awel': 'person_name',
#  'Magistraat van Hulst te': 'person_name',
#  'Voorichryvens': 'person_name',
#  'Wigersma': 'person_name',
#  'de Woot Frixe': 'person_name',
#  'van Anhalé-Zerbit': 'person_name',
#  'Bededag gepropuneert': 'person_name',
#  'Bosset': 'person_name',
#  'Bucke': 'person_name',
#  'Bulgbant': 'person_name',
#  'Calmette': 'person_name',
#  'Coymaus': 'person_name',
#  'Deneken van Heylande': 'person_name',
#  'de la Faille': 'person_name',
#  'van Freisheym': 'person_name',
#  'le Gachiere': 'person_name',
#  'Gucex de Condray': 'person_name',
#  'Haubenreister': 'person_name',
#  'Houtkooper': 'person_name',
#  'Janien': 'person_name',
#  'lLamok': 'person_name',
#  'van Meiss': 'person_name',
#  'Memorien van Trevor': 'person_name',
#  'tot Collonel': 'person_name',
#  'vacante Compagnie': 'person_name',
#  'de Milleville': 'person_name',
#  'Muntiaacken': 'person_name',
#  'Legerlafen': 'person_name',
#  'voor den Heer Bals': 'person_name',
#  'Parnasiins der Purtugeesthe': 'person_name',
#  'na Braband': 'person_name',
#  'ugsthal': 'person_name',
#  'Monteering': 'person_name',
#  'DD X': 'person_name',
#  'Raine': 'person_name',
#  'van Rosenbergh': 'person_name',
#  'Runnels': 'person_name',
#  'Scharlay': 'person_name',
#  'Tôsiofan': 'person_name',
#  'van Varick': 'person_name',
#  'de Vassy Lyte': 'person_name',
#  'vrydom van Verpondingen': 'person_name',
#  'van Vreeswyck': 'person_name',
#  'Wagentuhrer': 'person_name',
#  'Bededag': 'person_name',
#  'Benink': 'person_name',
#  'Blasiere': 'person_name',
#  'Booden': 'person_name',
#  'Chatry': 'person_name',
#  'Graviset': 'person_name',
#  'vander Luyt': 'person_name',
#  'Popkes': 'person_name',
#  'Rademacher Proces': 'person_name',
#  'Rechteren tot Westerveld': 'person_name',
#  'Silva Curiel': 'person_name',
#  'stockar': 'person_name',
#  'vander Walle': 'person_name',
#  'Attena': 'person_name',
#  'Buras': 'person_name',
#  'Carnin': 'person_name',
#  'Cartilho': 'person_name',
#  'Craght': 'person_name',
#  'Fransen': 'person_name',
#  'Genenaliteyts Reekenkamer': 'person_name',
#  'Glagemans': 'person_name',
#  'de Guy te': 'person_name',
#  'van Heekeren tot Whualien': 'person_name',
#  'Leisius': 'person_name',
#  'Megen': 'person_name',
#  'vander Mieden': 'person_name',
#  'Norden': 'person_name',
#  'Nyvenheim': 'person_name',
#  'Ploos van Amtiel': 'person_name',
#  'Raad van Siaate': 'person_name',
#  'van Reenen': 'person_name',
#  'Steenlack': 'person_name',
#  'Benezet': 'person_name',
#  'Chaufepied': 'person_name',
#  'Oopius': 'person_name',
#  'crip': 'person_name',
#  'Dunick': 'person_name',
#  'Hunter': 'person_name',
#  'Jouum': 'person_name',
#  'VT Ambreghts': 'person_name',
#  'Lichtenbergh': 'person_name',
#  'Proyard': 'person_name',
#  'Roienburgh': 'person_name',
#  'Ryckts': 'person_name',
#  'schemmel': 'person_name',
#  'schidburgh': 'person_name',
#  'Burriere': 'person_name',
#  'Bentinck tot Wittenstein': 'person_name',
#  'Broekman': 'person_name',
#  'Buytenlandsehe saaken': 'person_name',
#  'van DE': 'person_name',
#  'Confesteurs op de Galeyen Ordonnantie van': 'person_name',
#  'Chiispyn': 'person_name',
#  'van Dielen': 'person_name',
#  'Finne': 'person_name',
#  'Hensien': 'person_name',
#  'Holdernesse': 'person_name',
#  'Incour': 'person_name',
#  'Lila': 'person_name',
#  'DEDEN': 'person_name',
#  'Parnasiins van de Portugeesche Jobasche Natie': 'person_name',
#  'DD Aaden van de': 'person_name',
#  'Roode': 'person_name',
#  'Slegers': 'person_name',
#  'Tresiont': 'person_name'}

# %%
term_cat = {
    'Roesteren': 'person_name',
    'Commissie': 'org',
    'Coolen': 'person_name',
    'Delsupéche': 'person_name',
    'opioven': 'person_name',
    'Heemert': 'person_name',
    'Mailboroug': 'person_name',
    'Mealingh': 'person_name',
    'Rouser': 'person_name',
    'Armentiers': 'person_name',
    'Fytingh': 'person_name',
    'Rollané': 'person_name',
    'Thieleman Hulsipe': 'person_name',
    'tuna': 'person_name',
    'Sintsendorff': 'person_name',
    'Martini': 'person_name',
    'wegens': 'person_name',
    'Santen': 'person_name',
    'soodanich in te schicken': 'fout',
    'Mayeux': 'person_name',
    'zZuerins': 'person_name',
    'Auger': 'person_name',
    'Verliege': 'person_name',
    'Noorthey': 'person_name',
    'Schilt': 'person_name',
    'Fourquin': 'person_name',
    'Martyn Pasport verleent': 'person_name',
    'van Rieu': 'person_name',
    'de Wit Brieven van': 'person_name',
    'Bleyswyck': 'person_name',
    'Flinck te': 'person_name',
    'Schoenmakers': 'person_name',
    'Verlooven': 'person_name',
    'van den Bergh': 'person_name',
    'Besmettelycke siekten': 'person_name',
    'Declaratien van de Vuurstoockster van Durs': 'person_name',
    'Lutteken': 'person_name',
    'Calkberner Brieven van': 'person_name',
    'de Groote': 'person_name',
    'van Hoogstraten': 'person_name',
    'de Retroactta': 'person_name',
    'Hallandi': 'person_name',
    'aan den Resident Galliers': 'person_name',
    'Barbut Brieven van': 'person_name',
    'Bertlingh': 'person_name',
    'Carrier': 'person_name',
    'Commistien in den Raadt van Staate': 'person_name',
    'Gylen': 'person_name',
    'van Heusden': 'person_name',
    'van Affelen te': 'person_name',
    'page': 'person_name',
    'lycke Majesteyt': 'person_name',
    'Euskerke': 'person_name',
    'Lerberge': 'person_name',
    'miteert': 'person_name',
    'Bors van Waveren': 'person_name',
    'Middelen tot Iperen': 'person_name',
    'Memorien van den Grave Konigsegg Erps': 'person_name',
    'van Bladel': 'person_name',
    'voorige Traclaaten': 'person_name',
    'Alvares': 'person_name',
    'van Hauxleden': 'person_name',
    'Gerritje': 'person_name',
    'wan Aarlerixtel': 'person_name',
    'de Roomsche Kerken': 'person_name',
    'Algiers Pasport': 'person_name',
    'Gastelaars Brieven van': 'person_name',
    'van Heteren Aitiestatie de': 'person_name',
    'van Moens': 'person_name',
    'Nelleftein': 'person_name',
    'generaale pyrdon': 'person_name',
    'de Wolff': 'person_name',
    'Booreel': 'person_name',
    'van Heyden tot Otmarssen': 'person_name',
    'giment van Hirzel': 'person_name',
    'Goste': 'person_name',
    'koopen': 'person_name',
    'Rotteveel': 'person_name',
    'Lyste van de Nieuwejaaren': 'person_name',
    'Corendyckér': 'person_name',
    'Hummeling': 'person_name',
    'Straatmaackers': 'person_name',
    'Sweers de Landas': 'person_name',
    'Hoeymans': 'person_name',
    'Heer van de Hoeve': 'person_name',
    'van Issem': 'person_name',
    'voor het Regiment van Plotho': 'person_name',
    'Notarissen in de Meyerye': 'person_name',
    'Leewe': 'person_name',
    'overgegeeven': 'person_name',
    'van Aat': 'person_name',
    'Tonis': 'person_name',
    'van Aspremont': 'person_name',
    'van Bleyywyck': 'person_name',
    'Coehoorn van Houwerda': 'person_name',
    'na Braband': 'person_name',
    'BDB Aad van Braband te': 'person_name',
    'Verlaan': 'person_name',
    'van Biesenbroek': 'person_name',
    'Haaften': 'person_name'
}

# %% [markdown]
# The classification of a random sample gives us an estimate of the distribution of classes. Combining this with the count of each term's linking factor gives us in insight in the linking potential of each class and in which class we get the most value out of the required effort to build curated term lists that cover many resolutions.

# %%
list(sample_df.apply(lambda x: ' '.join([x['clean_lemma'], x['text']]), axis=1))
# Out:
# ['nee Winter quartieren nee Winter quartieren, 918.',
#  'nee Winter quartieren aerte tifthop van Gran Brief van felicitatie over het verwisielen van het jaer, 45.',
#  'Autwerpen Autwerpen, Bringius versoeckende haer Hoogh Mog. approbatie als Collo- nel titulair, 896.',
#  'Autwerpen wegens iwee Schepen op de Schelde kruyssende, 1087.',
#  'Autwerpen nopendé het senden van een Bat- talllon na Hulster-Ambacht, 1000.',
#  'Autwerpen wegens het senden van Levens- middelen na den Vyandt, 99. 281.',
#  'Autwerpen nopende vier Compagnien van Junius, leggende op twee Forten by het Vlaemsche Hooft, 1166. 1192.',
#  'Armaitres tot Duynkercken Armaitres tot Duynkercken, 242.252. 274. 344.',
#  'Auvergne Auvergne, Generael Major, omme tot Lieutenant Generael aengestelt te werden, 188.',
#  'Backere Backere, 781.',
#  'Chevallerie Chevallerie versoeckende Montfort tot sijn gevangenisse, 744',
#  'Eedt van suyveringe Eedt van suyveringe, 42.',
#  'Geursen Geursen, Capiteyn om Major de Briga- de aengestelt te werden, 258.',
#  'Ginu Ginu ke remissie van Verpondinge ge- continueert, 1149.',
#  'Sichterman geprolongeert voor ses maen- den, 1020.',
#  'Tullebardin Tullebardin versoeckende een Schip voor sijne Officieren ter recruterin- ge na Schotlandt, 1234-',
#  'Vlaenderen Vlaenderen, 121. 378. 475. sot. 509. 532. 536. 559. 561. 574.578. 587. 602. 605. 659. 703. 731. ties. 1122.',
#  'Vlaenderen Gedeputeerden nopende de se- curiteyt aldaer, 655.',
#  'Vlaenderen rapport, 750.',
#  'Vlaenderen different tusschen den Prelaet van St. Michiel en den Commandeur van Lillo afgedaen, 750.',
#  'Vlaenderen accord over Contributien, 789. 907.',
#  'Westwoldingerlandt Westwoldingerlandt, 666.',
#  'Aken Aken, Fouragie aen het Pruyssische Garnisoen, 38. 204',
#  'Aken Godtsdienf aldaer, 379. t004.',
#  'Aken Chardinel, 140. 267. 884. 05.',
#  'Aken verkoopinge van Canouife tot Maestricht, tor onderhoudt van Predicant en Schoolmeester, 1336.',
#  'Aken Braemt, Agent aldaer, 1347.',
#  'Aken klaghte van verbodt toevoer van Granen uyt de Landen van Overmaze en van Limburgh, 1369.',
#  'Andringa Andringa ter Generaliteyt gecommitieert, 491.',
#  'Aspremont Aspremont, Gravinue Deuariere, klaghten over den oysch van den Generael der Pruyssische , 1379.',
#  'Barbaryen Barbaryen, 30. 32. 185.',
#  'Benthein-Steinfurt Benthein-Steinfurt differenten met Munster, 108. verlof voor zier maenden, 1217.',
#  'Berckhoffer Berckhoffer omme Brigadier, 179.',
#  'Beyersche interessen Beyersche interessen, 733. 1444',
#  'Blauw Vaendel Blauw Vaendel voor planten van de Meytoegeleght honden fivere ducatons, 637.',
#  'Bodens van den Hucgh Bodens van den Hucgh voor een Nieuwejaer acht- tien guldens, 18.',
#  'Bodens van den Hucgh ter Generalieyt, 346.',
#  'Bodens van den Hucgh gelaft reysende de Heeren van de Provin- cien ivaer nafie de selue reysen aen te spreecken, 390.',
#  'Bodens van den Hucgh extraordinaris Bodens yeder ses en twin- lighgulden tuegelen, 1304. 1331.',
#  'Brouwêts tot Cortrijck Brouwêts tot Cortrijck, 147. 330. 449, 550. 669.',
#  'Campen; scilder Campen; scilder, zif en rwintigh guldens toe- geleght, 1252.',
#  'Carpenter van Westerbeek Carpenter van Westerbeek tegens Gresfontaine ut te wisden, 39.',
#  'Carpenter van Westerbeek om jegeus den Lieutenant Collond de la Maue uyigewistit te werden, 393.',
#  'Carpenter van Westerbeek onnie Major de Brigade, 576.',
#  'Commissie in Commissie in des Generaliteyts Rekenkamer, de Heeren Jofias Cos, 127.',
#  'Commissie in B. Getacus, 576.',
#  'Commissie in J. van Beectboit, 585.',
#  'Commissie in H. Blauw wegens Vrielandt, 1234.',
#  'Commissie in Johan van Euh wegen Gelderlandt, 1288',
#  'Commissie in Winckel wegens Gelderlandt, 1359.',
#  'Coolin Lambert Coolin Lambert, Colonel, versieckende , dat fjn Regiment by vrede in deert van Spaigue nagh êyven, iin.',
#  'Coolin Lambert versoeckende T. Oregorie tot fijn Lieute- nant Clone, 959.',
#  'Crammont Crammont, Capiteyn, onme Major de Brigade, 374.',
#  'Jarges Jarges, Vendrigh, wegens alentie gedeporteert, versoeckt daer van haer Hoogh Mog. gratie in plaeise van vigeur van justitie, 464.',
#  'Jarges gemitigeert in twee maenden gage, 594.',
#  'kloeckhof kloeckhof, Weduwe F. Wiesten, 373.',
#  'Leuwen Leuwen omme Major de Brigade, 254. 497.',
#  'Lisibon Lisibon , Schonenbergh advertentie, 92. 247. 530. 534. 687. 1297. 1464.',
#  'Lisibon zetirek van den Vice ddmirael Bings, 93.',
#  'Lisibon antwoordt in faveur van Cruger, 94',
#  'Lisibon Hluminatien aldaer, 221. 1799.',
#  'Lisibon rouw over Prins George, 231.',
#  'Lisibon om nieuwe Credentialen, 1115.',
#  'Lisibon Consul aldaer, 1381.',
#  'Lisibon Hofterman klaghten over de Commisarif- risen der Prinsen, 221.',
#  'Lisibon versieckende Commisie tot Cadix, 409.',
#  'omûmeren omûmeren acgiti tt Verer van Ae Rixtel, XD',
#  'Oostende Oostende, cat aduerientie, 95.',
#  'Oostende verlaien van Plserdae 33.',
#  'Oostende uwer van Graken, 915. loos. 110. 1319. 1498.',
#  'Oostende ltjdinge tegeu benee echtens, 1060.',
#  'Oostende Caris nm he Coumaudenmt van Onfen- de, n38.',
#  'Overquarter van Gelderlandt Overquarter van Gelderlandt, Waghtendonck over een subiten brandt aldaer ontftaen, 3. 429. 485. 495.',
#  'Overquarter van Gelderlandt cxemptie van laften door den Marquis de Schenck ouer fijne Goederen tot Krughten en Bref, 4.',
#  "Overquarter van Gelderlandt prince van Berlepsch, nopende cen pen- fiuen van niee duysen pistoleiten haer door Ko- ningh Karel gegeven, 's.",
#  'Overquarter van Gelderlandt Maria johanna van Varick, Weduwe Brigadier Waes, 15.',
#  'Overquarter van Gelderlandt Heerliyckheyt van Dulkenswaert , 25. 1368.',
#  'Overquarter van Gelderlandt A. Mer tegens die van Beegden, 33.69. 216. 21. 256. 287. 289. 1013.',
#  'Overquarter van Gelderlandt Kruyancker tot Burgermeester van Roer- monde aeigestelt, 38.',
#  'Overquarter van Gelderlandt du Bien, rakende voeren van Artilerye na Rysel, 49. 133. 718.',
#  'Overquarter van Gelderlandt aenschryvinge van den Danckdagh, 57.',
#  'Overquarter van Gelderlandt Geswoorens en Inwoonders van Kesed, ro6. 157. 205. 281-363. 478.',
#  'Overquarter van Gelderlandt Heerlyckheyt Greefraedt, 132.',
#  'Overquarter van Gelderlandt Muufort, 176. 194. 272.952.',
#  'Overquarter van Gelderlandt a. zan Lae en C van Valkenburgh, 183.',
#  'Overquarter van Gelderlandt Inuxonders van Krugbten, 188. 307. 815. 1160.',
#  'Overquarter van Gelderlandt Oosen onder Lin, 211.',
#  'Overquarter van Gelderlandt Raedt en Momboir aldaer, 213.',
#  'Overquarter van Gelderlandt Reglement van ha jaer sefien hondert mee er tachtich, wegens omstan van subfi- dien, 397.',
#  'Overquarter van Gelderlandt Karren en Wagens door le Bien aen fijne Majefiey van Pruysin gelevert, 323.',
#  'Overquarter van Gelderlandt sententie op Hernan Meyers doer die van Greefracht, 351.',
#  'Overquarter van Gelderlandt Maesthippers aldaer, 413',
#  'Overquarter van Gelderlandt het Ef aldaer, 499.',
#  'Overquarter van Gelderlandt negotiatie hoofigerscht van Eght, 586.',
#  'Overquarter van Gelderlandt Weduwe Wilënout, 669.',
#  'Overquarter van Gelderlandt Rochus Joris omme achterfialen, 662. 875. 904-',
#  'Overquarter van Gelderlandt Pallant wegens manslagh door den Grave van Surum begaen, 668 718. 738.',
#  'Overquarter van Gelderlandt Schofftlei, Kofter tot Roerinonde, 712. 904.',
#  'Overquarter van Gelderlandt Vermase, Burger tot Roermonde, 729.',
#  'Overquarter van Gelderlandt agende dat det Gomerneur ondernam re- zife eh surcheantie van exeoutie te verleenen, 807.',
#  'Overquarter van Gelderlandt Heerlyckheyt Elmpt, 897. 1096.',
#  "Overquarter van Gelderlandt Ty Heukem en'som crinenclyck gevan- gen, 8417.",
#  'Overquarter van Gelderlandt proceduren van Mombor Palant , 892. yo1 975. 996. 1458.',
#  'Overquarter van Gelderlandt van pari om verhooginge van tractement, 968.',
#  'Overquarter van Gelderlandt Baren Merwyck, Heer van Kesel, tot Raedtsheer der Conrte Robe aengestelt, 1001.',
#  'Overquarter van Gelderlandt dlbenine van Rheede, Abdié van de Abdye Mumier tt Roermonde, 1005. 1182.',
#  'Overquarter van Gelderlandt overhden van den Marquis de Schenck, Raedt Coftumier, 1014.',
#  'Overquarter van Gelderlandt Ingelanden van Profteren, 1016. 1125.',
#  'Overquarter van Gelderlandt dié van Roermonde wegens halen van Brief- jes by de Onfangers, 1075. 1076. 1213.',
#  'Overquarter van Gelderlandt Heerlichhet Swalmen, sos1.',
#  'Overquarter van Gelderlandt bericht voor J. D. Schoffeten, 1057. 1082. 1236. 1262.',
#  'Overquarter van Gelderlandt umer van Granen, 1113.',
#  'Overquarter van Gelderlandt Heerlyckhbeyt Swalmen on te negotieren, nea.',
#  'Overquarter van Gelderlandt Jermld Coferis, 1267.',
#  'Overquarter van Gelderlandt Latenkooper gilde tot Roermonde, 1253.',
#  'Overquarter van Gelderlandt Princee van Chimay, 1278.',
#  'Overquarter van Gelderlandt Bischip van Roermonde, 1313. 1323. 1343. 1393.',
#  'Overquarter van Gelderlandt Matgarea Herlindis Schers, Weduwe Grouwels; 1298.',
#  'Overquarter van Gelderlandt Gidens van Roermonde, 1333.',
#  'Overquarter van Gelderlandt Johan Coolen, Koopman tot Roermonde, 1415.',
#  'Overquarter van Gelderlandt preiensien van de Princesse van Berlipseh op Weert, Nederweert en Wesem, 1427.',
#  'Plante Plante omme Comuwissie als Cotoucl titmlair, 1033.',
#  'Portal Portal omme Generael Major, 248.',
#  'promotie Gereraels promotie Gereraels, 403.',
#  'Rapin Rapin ome Brigadier, 175.',
#  'Rapin om in ijn rangh berstet te werden, ja1.',
#  'Rapin om General Major, 1385.',
#  'Roulié Roulié, Colonel , om Brigadier, 448. 558. 924.',
#  'Rumpf Rumpf, fi Stockholm, letter S.',
#  'Scalé Scalé, gevlught Predikant, 930.',
#  'Oostende Foriifiatien aldaer, 1388.',
#  'Overquantier van Gelderlandt Overquantier van Gelderlandt, Mederkrughten, zo. 158. 264. 687. 878.',
#  'Overquantier van Gelderlandt Maria Elisabeth Bentingh klagende over de Pater Rectur tôt Roermonde, 30. 83.',
#  'Overquantier van Gelderlandt Koolen, Koopmen tot koermonde, 32. ro.',
#  'Overquantier van Gelderlandt nominatie van drie Schepens, 49.',
#  'Overquantier van Gelderlandt Tieumannen der Gildeas toi Roermonde represeuterende, 52. 961. 1095. 1240.',
#  'Overquantier van Gelderlandt Bischap van Roermonde, 64. y0. 93. 253. 274 4. Schoffelen, Koster en Schoolmeester tot Roernonde, 68. 37.',
#  'Overquantier van Gelderlandt Heertickhen Dalenbroeck, go.',
#  'Overquantier van Gelderlandt Heerijck Ween , 98. 106. bor. éci. 688. 697. 732. 783. 912. 1177.',
#  'Overquantier van Gelderlandt apen hschen Mae en Wat, 112.',
#  'Overquantier van Gelderlandt Zrmondt, Kofler aldaer, 223.',
#  'Overquantier van Gelderlandt Hlaghten over onordentelyckheden van den Cotonel Stael tegen den Heer Correge, 234. 294. 296.',
#  'Overquantier van Gelderlandt Menboir Pallandt, 238. 437. 651. 698. 705. 751. 8oo. 928. 988. 1662. 1229.',
#  'Overquantier van Gelderlandt muiten van ôrdomanien en Reglementen aldaer, 245.',
#  'Overquantier van Gelderlandt Willen Bomgarts, 264.',
#  'Overquantier van Gelderlandt Auth Gerard van Meerheere tot Oosen, 288.',
#  'Overquantier van Gelderlandt Heerlyckkheyt Elmpt, 414. 435. 564. san.',
#  'Overquantier van Gelderlandt W. van Holt, Brouwer tot Roermonde, 416. 536.',
#  'Overquantier van Gelderlandt siverainiteyt aldaer, 422.',
#  'Overquantier van Gelderlandt Jacob van hgeuboven om diguitjt ende emolamenten van le Ridderschap, 433.',
#  'Overquantier van Gelderlandt ampt tot Monfon, 450. 346. si5. 749. 1314.',
#  'Overquantier van Gelderlandt UGnyr tot Krieckenbeck , 451.',
#  'Overquantier van Gelderlandt unt Kesd, u99. rs. 868. 871 914 1083.',
#  'Overquantier van Gelderlandt Maesbraght, Roofteren, Pmftaert, Odilie- bergh en Bede, Offroy om ie negotieren , 540.',
#  'Overquantier van Gelderlandt pensioen or de Princesse van Berlepsch um Haen, ys. 341.',
#  'Overquantier van Gelderlandt Ontfanger m Comrerllur tot Stralen, s65.',
#  'Overquantier van Gelderlandt commercie te Roermonde, 568. 1015.',
#  'Overquantier van Gelderlandt Heerlisckhet Dulckensweert, 641. 698. 705. 728. 1098. 1283.',
#  'Overquantier van Gelderlandt Hof haer i reguleren na de Resolutiem van den vir en twintigifen Jamarien vyftienden Maen stventien honden tien, 675.',
#  'Overquantier van Gelderlandt Heelijckheyt Horst, 687. 924. 1098. 1364.',
#  'Overquantier van Gelderlandt Weduwe van den Baro van Waes, 706.',
#  'Overquantier van Gelderlandt W. de Gem en J. Seyen wegens ontstane brandt, 737. 997.',
#  'Overquantier van Gelderlandt Sinduis, Bouwer tot Roermom, 745.',
#  'Overquantier van Gelderlandt Coserus, Rentmeester tot Weert, 750. 764. 772. 783. 799. 8oo. 8oq. sa8.',
#  'Overquantier van Gelderlandt J. G. Cox prasfderende, Raedt om gratif- catie, 829.',
#  'Overquantier van Gelderlandt Rhie wegens weghuemer van fijn Vaders Wapen uit het Choor van de Kercke van Baarli, o55.',
#  'Overquantier van Gelderlandt Vinkenius, Burger tot Roermondel 549. 1027. 1103.',
#  'Overquantier van Gelderlandt T. al van Aerssen, Licenciaet ût Roer monde, 968. 979. 1000. toro.',
#  'Overquantier van Gelderlandt Jan Joseph de Wagenaer, Griffier der Lee nen, 1006.',
#  'Overquantier van Gelderlandt Jan van Colen wegens Veergeldt, 1063.',
#  'Overquantier van Gelderlandt Herlyckben Keseiigh en Hunsel , 67. 1017. tif. itse. 1157.',
#  'Overquantier van Gelderlandt feielsck weghalen van ezige Karren met Haver en Stroo, 1147.',
#  'Overquantier van Gelderlandt Pachter da Watermalens binnen de Fontif- catien, 1175.',
#  'Overquantier van Gelderlandt Tugenhove om admsse op de comparitie van de Ridderschap, 1196.',
#  "Overquantier van Gelderlandt 'G Varlet Heere van Boendad , 967. 1017. 1150. 1197. 1244.",
#  'Overquantier van Gelderlandt G. G/ van Hier, Here van Oosten, llag- ten over die van Beegden, 1198.',
#  'Overquantier van Gelderlandt arreft op Jan Teunnken, 1283.',
#  'Overquantier van Gelderlandt Heerlyckhey Obbicht, ia91.',
#  'Overquantier van Gelderlandt Goor haar Huogh Mg. ordres en comnif- fe alleen tepareren; 1293.',
#  'Overquantier van Gelderlandt Priorinne der ongeschueyde Carmeliien tet Roermonde, 1356.',
#  'Penia Penia, soo voor hem als de Geintereserden in het Spaensch Schip de Jesus Maria en Joseph, 888.',
#  'Portal Portal om pensioen, 23.',
#  'Portal om verlof voor drie a vier weken, 155.',
#  'pritselwits pritselwits om een commandement, 724:',
#  'Roon Roon, Auduou miliair, om een der twee Commis ambulants-plaasen, 1138.',
#  "Roon om Coutrerolluc'tot Pont aVendin, 1186.",
#  'savoyen savoyen, zander Mur adveriemi, 63. 108. ria las. 137. 198. 233. 243 257.275. 288. 381 401. 494 488. 538. 545.581. 590. 606. 36. 650 Ger 672. 681. 68. 71. 740. 757. 770. 280. 794. 8ié. 817. 82. 61. 874. iss. 895. 910. 923. sso. 956. oto. 596. 1007. io19. 1032 1042. ios7. 1065 1087. iioi 1108. 131. 1147 ticô 1173. ii89. iia5. ia29. 1236. ne7. 1275 iag1 taij.',
#  "savoyen voorsitien van'den dorlagh; 8o.",
#  'savoyen sehaenhen van win en Koom, sio:',
#  'savoyen onenighyt tusthen den Generael Majur Greendoif onde den Calon Goldacke , 23.',
#  'savoyen Haghten over aghterfalen, 253.',
#  'savoyen aenenen van ruat ever Prins Marit van Savoyen, 454.',
#  'savoyen Camhier cen Kneht van den Spaenschen Enmyé ui n fijn Hus vervolgt, 713.',
#  'savoyen Haghten om saxen Gothifeh Offcieren, 1093. Tran.',
#  'savoyen àcuiten van de Rekenkamer van hu- dert veeniigh guldens voor nuintigh rosen naer 2 Veni, 1107.',
#  'Vlaenderen Nieuw- Zuyddorp-Pelder, ita3.',
#  'Vlaenderen Remmeester der Espargues tot Sluys in Vlaen- deren, 1153. 117) ,',
#  'Vlaenderen JAerdenbergh exorbuanten eysch der Vyan- den, 1212.',
#  'Vlaenderen uieuw Reglement aldaer, 1263.',
#  'Vlaenderen Aerdenbérgh aflossen der Capitalen, 1271.',
#  'Vlaenderen Ly van de terdeelinge der Garnisoenen, 1336.',
#  'Warneton Warneton, Schepens-banck aldaer, 591.',
#  'Warneton fourhiturei voor het Garifoen, 1348.',
#  'Willemsdoôrff Willemsdoôrff als Major de Brigade, 485.',
#  'Aennemers van Foriificatien Aennemers van Foriificatien, 802. 831.',
#  'Aken Aken wegens vier Pruysche Battailons voor Win- terquariier, 91. 394.',
#  'Aken om aen het Leenhof van Valckenburgh te inhiberen de appellen te laten vervolgen, 172.',
#  'Aken Hooghduyische Kerckenraedt Jan Borchet en Aken wegen het onderhoudt van Predikant en de Schoolmeefter, 364.',
#  'Aken infinuatie aen Predikant en Voorleer tot Borcht gedaen, om niet meer de Gereformeer- de Religie te exerceren, 1006. s010.',
#  'Aken teswaer wegens de Winter quartieren, 1025.',
#  'Aken Chardinel storeteren van sekeren Brie, 1237.',
#  'Aken Kerckenraedt der Gereformeerden tot Bor- chet en Aken om Ordonnantie van aght hon- den guldens, 1313.',
#  "Aken 'Heerlijckhen Elsoo, 1538.",
#  'Bergen in Henegouwen Bergen in Henegouwen, Gedeputeerden her- wWaerts gesonden, 8.',
#  'Bergen in Henegouwen Dobna wegens servies-geldt, 21.',
#  'Bergen in Henegouwen megentigh duysent guldens voor Broodt en Fouragie voor de Keyserlijcke Trouppes, 125.',
#  'Bergen in Henegouwen Logemeut-gelden, 185. 272. 394.',
#  'Bergen in Henegouwen onardentelijckheden aldaer, 308.',
#  'Bergen in Henegouwen om versthooninge van grooter Garnisven, 321.',
#  "Bergen in Henegouwen Alten en Abdisen, Capittels en Geeftelye- ke Gemeenschappen aldaer, '41.",
#  'Bergen in Henegouwen Haghte Jan executie van den Grave van Bergeyck, 627. 1350.',
#  'Bergen in Henegouwen Pretensien van sijne Majesteyt van Pruysen, nei. 1165. 1240 1315.',
#  'Beyersche interessen Beyersche interessen, 215. 278. 407. 1488.',
#  'Cochet Cochet, Leutenant, ôm voldoeninge van agh- terfallen, 38.',
#  'Conventie Conventie tuschen de Heeren Princen Eugene, Marlboroug en haer Hoogh Mog. Gedepu- teerden te velde, wegens Broodt en Fourage voor de Keysersche Ttoupes, 77.',
#  'Etfgenamen van Maria Elsevier Etfgenamen van Maria Elsevier, Weduwe Cor- zelis de Lange, 670.',
#  'Fortificatie-werckers Fortificatie-werckers en Aennemers, 802.831.',
#  's Hertogenbosch s Hertogenbosch en Meyerye, Alt van Postel gelast dertig vaien Rogge jaerlijcks voor ira- dement te geven aen den Vorsier van Lies- DX',
#  's Hertogenbosch klaghten over de proceduren van den Raedt van Braband, 161. 171. 174. 188. 226.',
#  's Hertogenbosch Repelaer om Brievén van naturalisatie als Brabander, 174.',
#  'Luyek Luyek , Conventie Verviers, 13. 413. 992. 1222.',
#  'Luyek om ontstaginge van een Pruyssich Regi- ment, 31. 1098. 1248.',
#  'Luyek Grave Thomas van Tily gelast na Vranck- rick te keeren, 82. 109.',
#  'Luyek om verschooninge en leverantie van brandt, 315.',
#  'Luyek pretensien van den Westphaelschen Kreytz over de rine van het Prinsdom van Lusck, 331.',
#  'Luyek om verschooninge van brandt in de Cops de Garde tot Huy het versoeck afgeslagen, 393.',
#  'Luyek om relaxatie van tachtigh sacken Tarw Mourin tot Lusct toebehoorende, 404.',
#  'Luyek Pullicatié en Reglement voor die van Ver- viers, 472.',
#  'Luyek Cathedrale Kerck wegens adminiftratie van Regeringe, 573.',
#  'Luyek Publicatie tegens den uytvoer van Gra- nen, 570.',
#  'Luyek klaghten wegens wechhalen van een se- ker Descrieur uyt een Capelle, 741.',
#  'Luyek Herman ôger, Fadoor tot Luyck, 828. 1072.',
#  'Luyek Haghten wegens eerige Granen door die van Naugigne achgebaelt, 851.',
#  "Luyek om intereesié by fijné Majesten van Pruyssen , om aen de Inu'oonders 'van Luyck te doen restitueren het geen haer door Partye is afgenomen, 854-",
#  'Luyek Waghten van Jan Martin over den Ba- ron Keppel , 1035.',
#  'Luyek vernieuwinge van de Magiraa totVer- viers, 1051.',
#  'Luyek wegen voldoeninge van vie hordert rijcksuaeders aen de Erven van wien den Henoch van Hhlfeyn-Plun, 1349.',
#  'Luyek Tnquaniieringe de Pruysen, 1327. 1344 1357. 1504. ile. 1521.',
#  'Luyek om by alfeuie van den Grave van Til- DE) Zan den Sta te laten, 1339.',
#  'Luyek execute van ha Reglenen tt Verviers gemaakt, 1353.',
#  'Mennoniten Mennoniten deser Landen, 397. 756.',
#  'Mennoniten haer Hugh Mag. bedanckende voor haer mteressie in Swuserlandt, 1293.',
#  'Gouvemen van Breda Gouvemen van Breda, 29.',
#  'Gouvemen van Breda Den van Regiuenten Draguders en Tneuudie nt de Girnisienen, 237.',
#  'Gouvemen van Breda ifor cters gelaft fich aa ha oude ge- tm te reguleren; 345.',
#  'Gouvemen van Breda Bul vië weken verbf, 297.',
#  "Gouvemen van Breda Genraedl Hajy Wiffenaer 'on Guuer- mur van Breda, 247.",
#  'Gouvemen van Breda cas on het Cônmandemen van Ofen- de, 27.',
#  'Gouvemen van Breda Baron d Eynatten gedinittoent , en de Compaguie gegeven aen Frangous de Roulie, 265.',
#  'Gouvemen van Breda Grave de Tilly on Govvernur van Bre- da, 281.',
#  'Gouvemen van Breda Rricn, Lieuenant Colon, om een Regi- ment op ie rechten, 282.',
#  'Gouvemen van Breda Jeh. Jacob Brale ut Capite aengefielt, 286.',
#  'Gouvemen van Breda verlof van den Prins van Hesen voor em mahdt gepnongeert, 286.',
#  'Gouvemen van Breda Plenenbargh verlof on wor ses maenden na Alen ie gam, 389.',
#  'Gouvemen van Breda Generae Major Brinborn eedt door den Solciieur afgieght, 294.',
#  'Gouvemen van Breda Gnernuni en Conmandeurs in de Fron- Herren, 296.',
#  'Gouvemen van Breda Geseke te velde, 295.',
#  'Aken Aken, inquartieringe van Pruysische Bataillon. 182.',
#  'Aken Heerlijckhen Elstoo. 678.',
#  'Aken Schardinel wegen het veltrecken van he Predikants Huys. roo.',
#  'Aken Hagende vver de laff der Winterquariie- ren van de Pruyische. 1522.',
#  'Aken Limpens; syndicus van bet Keyerlijck Gerecht. 1370.',
#  'Barbaryen Barbaryen, M. Francken Consul aldaer. 1087.',
#  'Baudclo Baudclo, Prelaet en Conventualen. 849. 850.',
#  'Brieven van Brieven van appel voor Nicolaes Coppens. 140.',
#  'Brieven van voor N. Baert. 143.',
#  'Brieven van van attache voor Jacobus de Vivir- 987.',
#  'Brieven van van atterminatie voor Anna Maria du Pret en Michiel Joseph de Gou. 40.',
#  'Brieven van voor Antony de la Vigne. 190. 281. 533.',
#  'Brieven van voor Nicolaes Moches en Maria Marga- reta Belgrate. 774.',
#  'Brieven van voor Dom Gregoire Damman. 1282.',
#  'Brieven van voor de Vrouwe Marquise van Deuchin. 1410.',
#  "Brieven van voor Jaspar d' Assignies. 1453.",
#  'Brieven van van cxecutoriael oor Hendrick de Bie. s17.',
#  'Brieven van voor de Regeerders en Burgermeefters der',
#  "Commistien Commistien ter Admiraliteyt voor de Heeren M. 3. Hallingh op de Maze. 148. 3. Neurénbergh in Zeeland 148. witte Gevers op de Maze. 261. W. van Borck tot Harlingen. 267. 3J. vander Sprangh tut Ansterdam. 286. 3. van Hes als Contreroeur tot 's Heeren",
#  "Belingerwolder Schans Belingerwolder Schans. 1183. 'voor Hhoyet tot Major van Colin Lam-",
#  'Consenten Vrieslandt in de Consenten Vrieslandt in de subsidie voor wWir- tenbergh en betalinge der ongerepartieerde Trou- pes. 588.',
#  'Consenten Vrieslandt in de in de recruteringe. 1394.',
#  'Consenten Vrieslandt in de in een negotiatie voor den Koyser. 1447.',
#  'Consenten Vrieslandt in de in de Forificatien van Mons en St. Gi- lain. 1447.',
#  "s Hertogenbosch 's Hertogenbosch en Meyerye , die van Hilva- renbecck wegens geven van recognitie aen den Quartierschôut. 38. 69.",
#  's Hertogenbosch Regenten van Stiphout. 34.',
#  's Hertogenbosch Haersolte tot Quartierschout van Oofter- wijck aengestelt. 157.',
#  's Hertogenbosch Canchicken tot Oïrschot. 356.',
#  's Hertogenbosch Moerkercken om betalingé van die van Eerfl. 544.',
#  's Hertogenbosch Helmont en Stiphout. 558. 818. 874. 091.',
#  's Hertogenbosch Ingezeteuen van Helvoirt. 653. 667.',
#  's Hertogenbosch colatie Prabende van Aft op Anna Ma- ria van Thienen. 6756.',
#  's Hertogenbosch alt van Tongerloo, orc. wegens twee bouwvallige Huysens. 748.',
#  's Hertogenbosch Regenten van Hooghloon. 749.',
#  's Hertogenbosch A Loitingh aengéftelt en geapprobeen als Ontfanger van Tilburgh. 750.',
#  "s Hertogenbosch Brins van Hessen w'egens Tilburgh en Goilre. 756.",
#  's Hertogenbosch provisoiren van het Godtshuy op het Hout onder Mierlo. 755.',
#  's Hertogenbosch Oosterwijck, lustensporigheden aldaer ge- pleeght. 768.',
#  's Hertogenbosch Dorp Brakel, cum suis, wegens het ha- len van Turff 829.',
#  's Hertogenbosch Dinghbancké van Scheyndel. 841.',
#  's Hertogenbosch Hlaghten van de Gravinne Widuwe van Maldegem over quade direstie der Rentmee- sers dan het Gastuys van Juffr. Grinselt. 1055.',
# ...
#  'EE) Heer van den Bergh beklagh dat de differenten van inkomende en uytgaende rechten op het Fort Marie niet weghgenomen wierden. 1204.',
#  'Commissie in Commissie in des Generaliteyts Rekenkamer voor de Heeren Pesters wegens Utrecht. 182.',
#  'Commissie in Suermont wegens Gelderlandt. 463.',
#  'Commissie in Becquer wegens Gelderlandt. 475-',
#  'Commissie in Smits wegens Gelderlandt. 867.',
#  'Consenten Zeelandt Consenten Zeelandt, in de Vooghdyschap over den jongen Grave van Bentbem-Steinfurt. 503.',
#  'Consenten Zeelandt in de Ratificatie van de Vreede met Spagne. 812.',
#  'Consenten Zeelandt in de negotiatie voor den Grave van Benthem. 1160.',
#  'Hffren Hffren, fie Paltz, letter P. Elgersma aengestelt tot Ontfanger der Li-',
#  'Hffren tenten tot Hinlopen. 325.',
#  'Fantoni Fantoni, Envoyé van den Hertogh van Gua- fula, om asscheydt van haer Hoogh Mog. 40.',
#  'Fantoni afsecheydt en gevalediteert. 115.',
#  'Gedeputeerden te Brusses Gedeputeerden te Brusses, pet Brusel, lener B.',
#  'Gossart Gossart emme ontsiaginge van arrest. 181. 207.',
#  'nage nage. 65. staet der contributien en der selver em-',
#  "interesen interesen. 402. 'Ingezetenen, welckers Huysen en Gron-",
#  'den door de den door de hieuwe Fortificatien waren door-',
#  'naer Engelandt naer Engelandt. 1259. uegens de Commissie naer Maestricht. 1283.',
#  "s Hertogenbosch 's Hertogenbosch en Meyerye, de Jongh als Drost van Stercksel geapprobeert. 3.",
#  's Hertogenbosch Regenten van Geldorp. 16. 149. 193. 563.',
#  's Hertogenbosch Magistraet voorkominge van confusie tus- schen politique en militaire justitie. 17.',
#  's Hertogenbosch Mr. Rutger Tullekens als Stadthouder geapprobeert. 38. 70.',
#  's Hertogenbosch Regenten van Erps. 68.',
#  's Hertogenbosch inbre gen van besmette Beesten. 107.',
#  's Hertogenbosch differem wegens de Magistraet met de Krijghstaet van het Garnisoen. 138. 173. 192. 319.',
#  's Hertogenbosch Schepenen en Regeerders van Borgloon. 143.',
#  's Hertogenbosch weeringe wegens de besmettinge van het runder Vee. 187. 202.',
#  "s Hertogenbosch die van Stiphout ontslagen van een duy- sent vier hondert vijf en veertigh guldens 's jaers- 120.",
#  's Hertogenbosch Johan Hartogh wegens Acte van ap- probatie. 259.',
#  's Hertogenbosch Haghten der Koopluyden wegens Placaet en verbodt tegens de Philips Daelders, &c. 268.',
#  's Hertogenbosch respective Hoofischouten om Commissien als hare Predecesseurs. 280.',
#  's Hertogenbosch Geldorp die van de Roomsche Religie al- daer. 285 :',
#  's Hertogenbosch Mir. Isaac Vester, Griffier der Leen- en Tolkamer. 286.',
#  's Hertogenbosch Schepenen en Geswoorens wegens beroe- pinge der Dienaren. 292. Regenten en Armmecsers van Rensel.',
#  'dorpen dorpen, territo van ham Hoogh Mog, en',
#  'penen penen. 972.',
#  'penen hominatie en electie van Schepenen. 987.',
#  'penen Regenten van Moergestel. 989. 1219. 1145.',
#  'penen Regenten van Lieshout. 993.',
#  'penen Relenten van Breugel. 997.',
#  'penen Regemen van Rosmalen s001.',
#  'penen Réenten van Enpel. 1007.',
#  'penen Pier de Cort ali Drosaet van Stip-',
#  'Borchet de Borchet de demolieren. 674. 688.',
#  'Keyser Keyser, Soldaet , om pardon wegens desertie. 623.',
#  'Louis Louis, Advocaet, twee duysent guldens toege- leghe voor gedane translatien, en gelast voor het toekomende voor translateren te mogen de- clareren. 1289.',
#  'Hen Huntagh Hen Huntagh zelf vi manden',
#  'Rumpf Rumpf als secretaris op de vreedebandelinge ge- approbeert. 1170.',
#  'Ryers‚ Secretaris van Aerlerixtel Ryers‚ Secretaris van Aerlerixtel, als Drosuert en Schout van Stiphout teapprobeert. 208.',
#  'Ryers‚ Secretaris van Aerlerixtel als Drossaert van de Heerlijckbeyt Breck geapprobeert. 6858.',
#  'savoyen savoyen, le Pla advertentie 5. 36. 42. 53. 64. 86. gy. 106. 148. 181. 210. 226. 253. 272. 284 338. 358. 392. a4i4. 419. 437. 466. 480. 504. 507. 526.',
#  'savoyen B XX 557. 577. Gor. 625. 653. 687. 724 730. 748. 760. 765. 796. 810. 818. 829. Ss. 802. 874. 894. ge3. yin. 930. 942 949. 984. 1000. 1014. 1029. 1056. 1063. 1073. 1085. 1116. 1117. 1124. 1143. 1157. 1172. 1193. 1216. 1239. 1272. 1283.',
#  'savoyen hoe sich te gedragen by de te rugh- komsie van het Hof uyt Sieilien. 111.',
#  'savoyen rouw over den Erfprins van Toscanen te valideren. 149.',
#  'savoyen rouw over de Koninginne van Spagne te valideren. 339',
#  'savoyen vander Meer wegens voldoeninge van twee posten in sijne Declaratie. 385.',
#  'savoyen vander Meer goet te deen het balsemen van sijn Vaders Lijck, loode Kist en ander- halvé maendt tractement. 590.',
#  'savoyen rouw over de Koninginne van Enge- landt. 932.',
#  'Sixen Gotha Sixen Gotha em betalinge volgens Conventie. 299.',
#  'Sixen Gotha he die letalinge te doen. 336.',
#  'Sixen Gotha felicitatie over de gesloten vrede en pre- sentatie van het overdoen van eenige Regi- menten. 987.',
#  'Seville Seville, van Beeck aengesteldt tot Consul. 778.',
#  'Seville duplicaet Commissie voor hem te depe- cheren. 1057.',
#  'Vlaenderen Vlaenderen, het Vrye. 44. 184. 280. 484. 667. 924.',
#  'Vlaenderen erffelijcke Ontfangers der Domeynen om remplaceringe. 60.',
#  'Vlaenderen Hooftmannen van Schoondijck. 168.',
#  'Vlaenderen St. Jans Steen. 234. 264. 368. 524. 653.',
#  'Vlaenderen Hulster Ambacht. 242. go. 1192.',
#  'Vlaenderen Axel en Neuse, 280. 396. 990.',
#  'Vlaenderen Waterrecht en Nieuwmuyden. 287. 584. 667.',
#  'Vlaenderen Ferdinandus Polder. 433. joo. 639. 684. 990.',
#  'Vlaenderen Huif. 448. 827.',
#  'Vlaenderen van Viissegen aengestelt tot Thesaurier van Hilst. 493.',
#  'Vlaenderen Cadsant. 692.',
#  'Vlaenderen St. Anne ter Muyde. 726.',
#  'Vlaenderen Steenbergen, Kerckenraedt aldaer. 765. 766.',
#  'Vlaenderen Steenbergen, Magistraet. 766. 1008. 1042.',
#  'Vlaenderen oudt en jongh Broskens. 830.',
#  'Vlaenderen Heer Anthonis Polder. 895.',
#  'Vlaenderen Aerdenburgh. 924. 939.',
#  'Vlaenderen Sus van Gent. 946. 964. 1139.',
#  'Vlaenderen different tusschen die van het Vrye en Aerdenburgh. 1091.',
#  'Vlaenderen Polder Alsdale. 1191.',
#  'van Sommelsdijk van Sommelsdijk gewonnen. 954.',
#  'van Sommelsdijk devoir te doen tot afdoeninge der be-',
#  'Keyser Keyser en Vranckrijck te mogen declareren.',
#  'Keyser Buy en Goslinga te mogen declareren wegens lufien, die gemodtsoeckt zyn geweest ie Gndergaen. 1188.',
#  'Keyser deur in faveur van den Hee de Hau- coun om fijne aghturfialige ineresen 190. 1256.',
#  'Keyser Ordonnantie van ses dysent guldens ter geeder rekeninge. 1318.',
#  "Keyser Haghtenvan den Chufurst van Keu- len wegens verbodt van inkomen van fijne Gardes'te Bon. 1293.",
#  'Keyser Chastauneuf versoeckende gratie voor drie Pantisans tat Tperen ter doodt gecondemneen. 14. 58. ss.',
#  'Keyser imredel 7.',
#  'Keyser receptie en rapport. 59.',
#  'Keyser audientie 62.',
#  'Keyser aenpraek. 64.',
#  'Keyser nieuwe Haghten wegen Kesserlijcke Par- wen het Landi van Lûxenburgh pastrende. is5. zor.',
#  'Keyser versieckende dat den Partisan de Nivelle en sijn Parte als publique Voleurs te mogen werden gestraft. 332.',
#  'Keyser om voldieninge van aghterstalen aen den Bischap van Tuiulouse, voor desen Bisschop ven Doornik. 358. 382. 380.',
#  'Keyser om conferentie 36.',
#  'Keyser om reffimtie van Schepen soe in de Mid- delandsche Zee als in den Oceaen genomen 513. sig. en. nes.',
#  'Keyser kennisse gevende van het overlijden van den Hertogh van Berm. 5251',
#  'Keyser Panisans de Nelle éen la Matte over- gelevert. 557.',
#  'Keyser lenderende ten eymde haer Hoogh Mig. hare goede officien by fijne Keyerlijeke Ma jesen geliefden aen ie wenden tot de souve- tainiteyt van de Princese van urfins. Si1.',
#  'Keyser Haghen over sekeren Vincent Houzé. 634. 745. 747.',
#  'Keyser confenterande in de overgifie van de Partisans Nele en la Matte aen den Key- ser. 654. 655.',
#  'Keyser tlaghen wegens vischerye in de Leye. 745. 757.',
#  'Keyser wegens de posessie van seker stuck Gacdti DEX',
#  'Keyser versieckende ontflaginge van eenen De- myers, op Ceybn gearrefteen. 278. 1058.',
#  'Keyser rakende seker pensfoen, waer voor den ult van st. Jean ai Mont a ypres voor den Raedt tot Brusel wierd aeigesproten. 975.',
#  'Keyser rakende het verbieden der commercie op de Zuydtzee. 1076. 13323.',
#  'Keyser Ratifeatie van de twe separate Arti- culen. 1132. 1127.',
#  'Keyser wechvoeren van eenige Boeckweyt van het Terrisir van Halewmn dor den Major van Meenen. 1144. 1190.',
#  'Keyser om Copie aubemicq van alle Tims, Testamenten en Documenten tot de sucessie van het Hus van Chalons, 1188. 1302.',
#  'Keyser neonmandaie omtrent den Heere van Haucourt. 1190. 1255.',
#  'Keyser Fransche Barck Louise Vichire de Per- zef 135.',
#  'Weydctfelt Weydctfelt, Droghscheerder tot Aken, den Agen Scharainel y continuatie alle goede offeien in des gei sack by de Maginraë al- daer an te wenden. 393.',
#  'migen migen admiteert 5180.',
#  'Auvergne Auvergne, om voorschryvens aen den Heere vanden Bergh tot Brussel. 645. 693. IX',
#  'Auvergne den Heere Hamel Bruyninx de sake van',
#  'Boreel Boreel, Capiteyn ter Zee, wegens aghterstallen. 31. 44. 83. 137. 384.',
#  'Brieven van Brieven van atterminatie voor de Rgenmen van Reusel. 84.',
#  'Brieven van van executoriael voor den Baron van Rwile. 104.',
#  'Brieven van voor de Regenten des Quartiers van Maeslardt. 480.',
#  'Brieven van Wouter van Velsen om Letteren execu- toriael aen de ordinaris Justitie gerenvoyeert. 532.',
#  'Brieven van voor Herman van Breugel. 7123.',
#  'Brieven van voor Cassumasor. 882.',
#  'Brieven van voor Eenus. 952.',
#  'Brieven van van pardon, Radi van State te advi- seren op het versoeck van den Chirurgyn Ma- jor Vervoort. 278.',
#  'Brieven van Retroacta na te sien op het versoeck van van Ummelen. 349.',
#  'Brieven van Magiftraet van Doornick te adviseren op het versoeck van le Poivre. 381.',
#  'Brieven van van plicet voor Loys. 883.',
#  'Brieven van van provisie voor Dominique Herman. 167.',
#  'Commissien in Commissien in des Generaliteyts Rekenkamer voor de Heeren Meerens wegens Hollandt. 18.',
#  'Commissien in Haren wegens Vriesandt. 419.',
#  'Commissien in Sloot tot Hare wegens Vrieslandt. 508.',
#  'Commissien in Assing wegen Overysel. 519.',
#  'Commissien in van Dan wegens Zuipben. 930.',
#  'Commissien in van Essen wegens Gelderlandt. 1058.',
#  'den Dansmeefier den Dansmeefier le Poivre. 478. beswaer wegens de nominatie door den',
#  'aduis aduis wegens het versoeck van Dordbea',
#  'aduis van Asperen. 456. 563. ddvis op de versoccken van Pefters en',
#  'aduis Kievits. 627. advis wegens Johan Hessel van Din-',
#  'aduis ter. 687. advis wegens de presentatie van de',
#  'aduis Erftenamen van wylen den Heere van Zut-',
#  'aduis phi. 692.',
#  'Guluckstadt Guluckstadt, Gereformeerden aldaer, haer ver- sieck om een jaerlijcks subsidie te examine- ren. 664.',
#  'Guluckstadt het voorschreve versoeck gedeclineert. 692. H..',
#  "s Hertogenbosch 's Hertogenbosch en Meyerye, bericht op de Requesie van de Roomschgesinde tot Boxtel. 73. 83.",
#  's Hertogenbosch reglement voor de Gasthuysen. 16.',
#  's Hertogenbosch Burghgraef van Eersel. 24. 29. 190. 633. 998.',
#  's Hertogenbosch Kerckmeester van Erp. 30. 992. 1039.',
#  's Hertogenbosch Regenten van Lommel. 30.',
#  's Hertogenbosch van Schardenburgh om de Vorstersplaets van Aerle. 45.',
#  's Hertogenbosch Heykoop om de Vorftersplaets van Aerle. 45.',
#  's Hertogenbosch Bles tot Vorster van Esch aengesteldt. 533.',
#  's Hertogenbosch de Vries tot Vorster van Oostel- en Mid- delbeers aengestelt. 594.',
#  's Hertogenbosch Regenten van Tilburg. 537. 797.',
#  's Hertogenbosch Regenten van Hilvarenbeeck. 541. 1095.',
#  's Hertogenbosch Regenten van Kneghtsel. 557. 903.',
#  's Hertogenbosch de Baronnye van Cranendonck. 568. 596.',
#  's Hertogenbosch Inwoonders van Eersel. 579.',
#  's Hertogenbosch Polder vander Eygen. 581.',
#  's Hertogenbosch Regenten van Riethoven. 587.',
#  's Hertogenbosch Magistraet van Helmont. 587. 613. 867. Rentmeester Slingerlandt wegens Canoni-',
#  "Mennoniten Mennoniten en Doopsgefinden deser Landen haer Hoogh Mog. voor haer voorschryvenms aen be Camon Ber bedanckende. '68-",
#  'pestch pestch. 796.',
#  'pestch Orson, Brigadier, ses weken terlef.',
#  'den jare den jare sestien hondert ses en vyftigh tot sesien hondert ses en tachtigh onder den Grif-',
#  'Oostende Oostende, Momeze advertentie. 1058.',
#  'XZ Quay XZ Quay, Scholtui van de Stadt Grave,',
#  'Revisien Revisien. so. 200. 210. 1140.',
#  'Schiller Schiller, wegens pretensie op den Chursurst van de Paltz. 1182.',
#  'Schlippenbachs Dragouders Schlippenbachs Dragouders naer Engelandt 1e senden in plaets van die van Wassenaer. 925.',
#  'Slype Slype wegens vonnisse by Hessels van Diner Jub- en obreftif verkregen. 1088.',
#  'DE Thiriard Weduwe DE Thiriard Weduwe om van gefielde cau-',
#  'DE Thiriard Weduwe tie ontslagen te werden. 320.',
#  'Vlaenderen Vlaenderen, Ferdinandus Polder. 8.405. 492. 668. 719.',
#  'Vlaenderen Halst en Hulster-Ambacht. 27. 200. 228. 346. 360. 420. 497. 508. 577. 791. 8o6 8ji. 8068. 874.',
#  'Vlaenderen Steenbergen, Kerckenraedt der Gere- formeerden aldaer. 107. 454.',
#  'Vlaenderen Ingelanden van den Fyraert. 113.',
#  'Vlaenderen het Vrye van Sluys. 176. 187. 226. 307. 450. 553. 593. 719. sooo. 1059. 1080. 1083. 1159. 1181.',
#  'Vlaenderen Aerdenbergh. 176.',
#  'Vlaenderen Axel. 177. 812. 1056.',
#  'Vlaenderen Veurne. 198.',
#  'Vlaenderen Schoondijcke. 276.',
#  'Vlaenderen Klinge Polder. 318. 468. 470. 498. 513.',
#  'Vlaenderen Pelder van Cambron. 334.',
#  'Vlaenderen Clara Polder. 360.',
#  'Vlaenderen St. Jans Steen. 399. 823.',
#  ...]

# %%
sample_df.first_line_id.apply(get_line_iiif_url, margin=100)
# Out:
# 1285      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2025      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2026      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2027      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2028      https://images.diginfra.net/iiif/NL-HaNA_1.01....
#                                 ...
# 143801    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 143983    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 143984    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 143985    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145581    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Name: first_line_id, Length: 1142, dtype: object

# %%
temp_df = sample_df.groupby('clean_lemma').head(1)

temp_df = temp_df[['inventory', 'clean_lemma', 'text', 'first_line_id', 'first_line_column_id']]
temp_df['line_iiif_url'] = temp_df.first_line_id.apply(get_line_iiif_url)
temp_df['column_iiif_url'] = temp_df.first_line_id.apply(get_column_iiif_url)
temp_df = temp_df.drop(['first_line_id','first_line_column_id'], axis=1)
temp_df
# Out:
#        inventory                                    clean_lemma  \
# 0           3763                          nee Winter quartieren
# 129         3763                                      Autwerpen
# 138         3763                      Armaitres tot Duynkercken
# 148         3763                                       Auvergne
# 153         3763                                        Backere
# ...          ...                                            ...
# 144833      3804  Parnasiins van de Portugeesche Jobasche Natie
# 145009      3804                                DD Aaden van de
# 145420      3804                                          Roode
# 145492      3804                                        Slegers
# 145587      3804                                       Tresiont
#
#                                                      text  \
# 0                             nee Winter quartieren, 918.
# 129     Autwerpen, Bringius versoeckende haer Hoogh Mo...
# 138         Armaitres tot Duynkercken, 242.252. 274. 344.
# 148     Auvergne, Generael Major, omme tot Lieutenant ...
# 153                                         Backere, 781.
# ...                                                   ...
# 144833  Parnasiins van de Portugeesche Jobasche Natie ...
# 145009               DD Aaden van de gemeene drie Bonden,
# 145420  Roode om aangefielt te werden als Scheepen van...
# 145492  Slegers om seekere Sententie tegens baar bui- ...
# 145587  Tresiont, Pasport voor fijn Goederen na Maastr...
#
#                                             line_iiif_url  \
# 0       https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 129     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 138     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 148     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 153     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ...                                                   ...
# 144833  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145009  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145420  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145492  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145587  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                           column_iiif_url
# 0       https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 129     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 138     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 148     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 153     https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ...                                                   ...
# 144833  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145009  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145420  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145492  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 145587  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
# [1000 rows x 5 columns]

# %%
import os

data_dir = '../../analysis/Indices/'
sample_file = os.path.join(data_dir, 'entries-sample-categorise.csv')
temp_df.to_csv(sample_file)

# %% [markdown]
# ### Observations
#
# - Person names link fewer resolutions (low frequency of occurrence: low token/type rate)
# - Person names are difficult to curate (high number of distinct names: many types)
#
#
# ### Conclusions
#
# - Person names are less valuable in linking and faceting resolutions because of their lower linking potential and the higher effort required to operationalise them well.
# - Topics are low in number so easier to curate and operationalise, and have very high linking potential.
# - Topics and geographical locations have hierarchical structure (in the case of topic, it is not tree-like structure but a DAG with partially overlapping topics and sub-topics connected to multiple parents.

# %%
data_dir = '../../analysis/Indices/'
categorised_sample_file = os.path.join(data_dir, 'entries-sample-categorised-Rik.tsv')

categorised_sample_df = pd.read_csv(categorised_sample_file, sep='\t')
categorised_sample_df
# Out:
#      inventory category                                    clean_lemma  \
# 0         3763        e                          nee Winter quartieren
# 1         3763        l                                      Autwerpen
# 2         3763        p                      Armaitres tot Duynkercken
# 3         3763        p                                       Auvergne
# 4         3763        p                                        Backere
# ..         ...      ...                                            ...
# 995       3804      NaN  Parnasiins van de Portugeesche Jobasche Natie
# 996       3804      NaN                                DD Aaden van de
# 997       3804      NaN                                          Roode
# 998       3804      NaN                                        Slegers
# 999       3804      NaN                                       Tresiont
#
#                                                   text  \
# 0                          nee Winter quartieren, 918.
# 1    Autwerpen, Bringius versoeckende haer Hoogh Mo...
# 2        Armaitres tot Duynkercken, 242.252. 274. 344.
# 3    Auvergne, Generael Major, omme tot Lieutenant ...
# 4                                        Backere, 781.
# ..                                                 ...
# 995  Parnasiins van de Portugeesche Jobasche Natie ...
# 996               DD Aaden van de gemeene drie Bonden,
# 997  Roode om aangefielt te werden als Scheepen van...
# 998  Slegers om seekere Sententie tegens baar bui- ...
# 999  Tresiont, Pasport voor fijn Goederen na Maastr...
#
#                                          line_iiif_url  \
# 0    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 1    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 3    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 4    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ..                                                 ...
# 995  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 996  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 997  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 998  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 999  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                        column_iiif_url
# 0    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 1    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 3    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 4    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ..                                                 ...
# 995  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 996  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 997  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 998  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 999  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
# [1000 rows x 6 columns]

# %%
s = categorised_sample_df.category.apply(lambda x: x.replace('?', '') if x is not np.nan else np.nan).value_counts()

print(sum(s))
s
# Out:
# 200
# p      97
# l      34
# z      30
# e      24
# f       7
# i       7
# i;l     1
# Name: category, dtype: int64

# %%
s / sum(s)
# Out:
# p      0.485
# l      0.170
# z      0.150
# e      0.120
# f      0.035
# i      0.035
# i;l    0.005
# Name: category, dtype: float64

# %%
s[[i for i in s.index if i != 'e']] / sum(s[[i for i in s.index if i != 'e']])
# Out:
# p      0.551136
# l      0.193182
# z      0.170455
# f      0.039773
# i      0.039773
# i;l    0.005682
# Name: category, dtype: float64

# %% [markdown]
# In the sample of 200 lemmas, there are 24 entries incorrectly identified as lemmas (12%).  Of the remaining 176 lemmas, there are:
#
# - 97 person names (55%)
# - 35 place names (20%)
# - 30 topics (17%)
# - 8 institutes/organisations (5%)
# - 7 person roles/functions (4%)

# %%
categorised_sample_df
# Out:
#      inventory category                                    clean_lemma  \
# 0         3763        e                          nee Winter quartieren
# 1         3763        l                                      Autwerpen
# 2         3763        p                      Armaitres tot Duynkercken
# 3         3763        p                                       Auvergne
# 4         3763        p                                        Backere
# ..         ...      ...                                            ...
# 995       3804      NaN  Parnasiins van de Portugeesche Jobasche Natie
# 996       3804      NaN                                DD Aaden van de
# 997       3804      NaN                                          Roode
# 998       3804      NaN                                        Slegers
# 999       3804      NaN                                       Tresiont
#
#                                                   text  \
# 0                          nee Winter quartieren, 918.
# 1    Autwerpen, Bringius versoeckende haer Hoogh Mo...
# 2        Armaitres tot Duynkercken, 242.252. 274. 344.
# 3    Auvergne, Generael Major, omme tot Lieutenant ...
# 4                                        Backere, 781.
# ..                                                 ...
# 995  Parnasiins van de Portugeesche Jobasche Natie ...
# 996               DD Aaden van de gemeene drie Bonden,
# 997  Roode om aangefielt te werden als Scheepen van...
# 998  Slegers om seekere Sententie tegens baar bui- ...
# 999  Tresiont, Pasport voor fijn Goederen na Maastr...
#
#                                          line_iiif_url  \
# 0    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 1    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 3    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 4    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ..                                                 ...
# 995  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 996  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 997  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 998  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 999  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                        column_iiif_url
# 0    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 1    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 2    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 3    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 4    https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ..                                                 ...
# 995  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 996  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 997  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 998  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# 999  https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
# [1000 rows x 6 columns]

# %%
temp_df = df[['clean_lemma', 'num_refs']].drop_duplicates()#.set_index('clean_lemma')

temp_df = pd.merge(temp_df, categorised_sample_df, on=['clean_lemma'], how='right')

# %%
temp_df['category'] = temp_df.category.apply(lambda x: np.nan if x is np.nan else x.replace('?',''))
temp_df['num_links'] = temp_df.num_refs.apply(lambda x: 0 if x == 0.0 else (x * (x-1))/2)

# %%
temp_df[temp_df.category.isna() == False][['category', 'num_refs']]
temp_df = temp_df[temp_df.category.isna() == False][['category', 'num_refs', 'num_links']]

s = temp_df.groupby(['category']).num_links.value_counts()
t = s.unstack('category').fillna(0.0)

t = t.reset_index()

# How many links does each category generate?
t[['p', 'l', 'i', 'f', 'z']].apply(lambda x: x * t.num_links).sum()
# Out:
# category
# p     20.0
# l    281.0
# i    232.0
# f     23.0
# z    227.0
# dtype: float64

# %%
categorised_sample_df.category.apply(lambda x: np.nan if x is np.nan else x.replace('?','')).value_counts()
# Out:
# p      97
# l      34
# z      30
# e      24
# f       7
# i       7
# i;l     1
# Name: category, dtype: int64

# %%
# Out:
#                                                inventory category  \
# clean_lemma
# nee Winter quartieren                               3763        e
# Autwerpen                                           3763        l
# Armaitres tot Duynkercken                           3763        p
# Auvergne                                            3763        p
# Backere                                             3763        p
# ...                                                  ...      ...
# Parnasiins van de Portugeesche Jobasche Natie       3804      NaN
# DD Aaden van de                                     3804      NaN
# Roode                                               3804      NaN
# Slegers                                             3804      NaN
# Tresiont                                            3804      NaN
#
#                                                                                             text  \
# clean_lemma
# nee Winter quartieren                                                nee Winter quartieren, 918.
# Autwerpen                                      Autwerpen, Bringius versoeckende haer Hoogh Mo...
# Armaitres tot Duynkercken                          Armaitres tot Duynkercken, 242.252. 274. 344.
# Auvergne                                       Auvergne, Generael Major, omme tot Lieutenant ...
# Backere                                                                            Backere, 781.
# ...                                                                                          ...
# Parnasiins van de Portugeesche Jobasche Natie  Parnasiins van de Portugeesche Jobasche Natie ...
# DD Aaden van de                                             DD Aaden van de gemeene drie Bonden,
# Roode                                          Roode om aangefielt te werden als Scheepen van...
# Slegers                                        Slegers om seekere Sententie tegens baar bui- ...
# Tresiont                                       Tresiont, Pasport voor fijn Goederen na Maastr...
#
#                                                                                    line_iiif_url  \
# clean_lemma
# nee Winter quartieren                          https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Autwerpen                                      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Armaitres tot Duynkercken                      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Auvergne                                       https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Backere                                        https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ...                                                                                          ...
# Parnasiins van de Portugeesche Jobasche Natie  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# DD Aaden van de                                https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Roode                                          https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Slegers                                        https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Tresiont                                       https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
#                                                                                  column_iiif_url
# clean_lemma
# nee Winter quartieren                          https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Autwerpen                                      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Armaitres tot Duynkercken                      https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Auvergne                                       https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Backere                                        https://images.diginfra.net/iiif/NL-HaNA_1.01....
# ...                                                                                          ...
# Parnasiins van de Portugeesche Jobasche Natie  https://images.diginfra.net/iiif/NL-HaNA_1.01....
# DD Aaden van de                                https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Roode                                          https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Slegers                                        https://images.diginfra.net/iiif/NL-HaNA_1.01....
# Tresiont                                       https://images.diginfra.net/iiif/NL-HaNA_1.01....
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Searching in the index entries
