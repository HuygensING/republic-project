# %% [markdown]
# # Republic frase modellen
#
# Doel:
#
# - informatie extractie uit de resoluties, gebruik makend van de repetitieve aspecten van de teksten, formulaische uitdrukkingen, signaalwoorden en onderwerpstermen.
# - het opbouwen van collectie-specifieke frase-modellen (lijstjes met termen en frasen, varianten daarvan en metadata categorieën en labels) zodat we informatie kunnen extraheren en om kunnen vormen tot inhoudelijke metadata voor ontsluiting van de individuele resoluties.
#
# Aanpak: harvesting phrases o.b.v. frequentielijsten
#
# Overlap/verschil tussen jaren:
#
# - tussen twee opvolgende jaren
# - tussen twee jaren met een decennium ertussen
# - tussen twee jaren met X jaren ertussen
#
# Overlap tussen resoluties en respectenlijsten:
#
# - in hoeverre komen termen uit de respecten letterlijk voor in de resoluties?
# - vergelijk e.g. automatische extractie en respecten. Dit vergt ook interactie met Team Text en hun NER activiteiten
#
# ## Overlap analyseren
#
# **doel:** bepalen welke termen structureel vaak voorkomen en hoe ze kunnen worden gebruikt om de inhoud van resoluties te analyseren
#
# Lijstjes:
#
# - hoedanigheden, rollen (ambassadeur, graaf, suppliant)
#     - dit kan gebruikt worden om o.a. persoonsnamen te spotten (dus nuttig voor NER trainen of resultaten opschonen)
#     - signaalwoorden/-frasen:
#         - <ambassadeur> in, uit, van, bij <land/hof>
#         - uit, naar, tot, te <plaats>
#         - gecommiteerd/commissie
# - documenten:
#     - Placaat
#     - Rapport
#     - Paspoort
# - onderwerpen:
#     - financiën
#     - rechten

# %%
# This reload library is just used for developing the REPUBLIC hOCR parser 
# and can be removed once this module is stable.
# %reload_ext autoreload
# %autoreload 2


# This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
repo_dir = os.path.split(os.getcwd())[0]
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# %%
# Laad de benodigde modules in
import re
from collections import Counter
from collections import defaultdict
from typing import Union
from republic.model.inventory_mapping import get_inventory_by_num
from republic.config.republic_config import base_config, set_config_inventory_num
import republic.elastic.republic_elasticsearch as rep_es

# Een handige 'Key Word In Context' functie om keywords/frasen en omringende tekst te zien
def get_keyword_context(text: str, keyword: str, 
                        context_size: int = 3, 
                        prefix_size: Union[None, int] = None, 
                        suffix_size: Union[None, int] = None):
    if not prefix_size:
        prefix_size = context_size
    if not suffix_size:
        suffix_size = context_size
    text = re.sub(r'\s+',' ', text)
    prefix_pattern = r'(\w*\W*){' + f'{prefix_size}' + '}$'
    suffix_pattern = r'^(\w*\W*){' + f'{suffix_size}' + '}'
    contexts = []
    for match in re.finditer(r'\b' + keyword + r'\b', text):
        prefix_window = text[:match.start()]
        suffix_window = text[match.end():]
        prefix_terms = prefix_window.strip().split(' ')
        suffix_terms = suffix_window.strip().split(' ')
        prefix = ' '.join(prefix_terms[-prefix_size:])# re.search(prefix_pattern, prefix_window)
        suffix = ' '.join(suffix_terms[:suffix_size])# re.search(suffix_pattern, suffix_window)
        context = {
            'keyword': keyword,
            'prefix': prefix,
            'suffix': suffix,
            'keyword_offset': match.start(),
            'prefix_offset': match.start() - len(prefix),
            'suffix_offset': match.end()
        }
        contexts.append(context)
    return contexts


es_republic = rep_es.initialize_es(host_type='external', timeout=60)

# %%
# kies een inventaris nummer om te doorzoeken
inv_num = 3761
# de base_dir is niet relevant maar wel nodig voor het maken van een config object
base_dir = "/Users/marijnkoolen/Data/Projects/REPUBLIC/"
# genereer een config object voor het specifieke inventaris nummer dat je wilt doorzoeken
inv_config = set_config_inventory_num(base_config, inv_num, base_dir, ocr_type='pagexml')

# haal alle paragraphs van het inventaris op uit de index
#docs = rep_es.retrieve_paragraphs_by_inventory(es_republic, inv_num, inv_config)

print('number of paragraphs:', len(docs))

# hoe ziet een paragraph document eruit?
print(json.dumps(docs[0], indent=4))
# Out:
# number of paragraphs: 5729
# {
#     "metadata": {
#         "id": "NL-HaNA_3761_0005-page-9-col-0-tr-0",
#         "inventory_num": 3761,
#         "scan_num": 5,
#         "scan_id": "NL-HaNA_3761_0005",
#         "page_num": 9,
#         "page_id": "NL-HaNA_3761_0005-page-9",
#         "column_index": 0,
#         "column_id": "NL-HaNA_3761_0005-page-9-col-0",
#         "scan_type": "pagexml",
#         "page_type": "resolution_page"
#     },
#     "lines": [
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-0",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-1",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-2",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-4",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-3",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-5",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-6",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-7",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-8",
#         "NL-HaNA_3761_0005-page-9-col-0-tr-0-line-9"
#     ],
#     "text": "W)/Dmirael van deni Sta\u00ebt in haer IJ Hoogh Mogende Vergade: Tinge comparerende Ja. ten fitten op een ordinaris Stoel, pag. 280. Abdiffe van Toor haer Goederen ge. arrefteert in de Meyerye van den Bofch, pag. 1331. ",
#     "coords": {
#         "left": 2561,
#         "right": 3451,
#         "top": 1253,
#         "bottom": 1723,
#         "height": 470,
#         "width": 890
#     }
# }

# %% [markdown]
# ## Simpele frequentielijsten
#
# Een eerste stap is kijken wat de frequente woorden zijn in de resoluties van een specifiek inventaris.
#
# In de resoluties beginnen veel domeinspecifieke inhoudstermen met een hoofdletter. Dat is een goed eerste filter om inzicht te krijgen in de inhoud.

# %%
# maak een nieuwe counter aan
term_freq = Counter()

# itereer over all documenten (= paragraphs)
for doc in docs:
    # splits de tekst op alles wat geen alpha-numerical character is
    terms = re.split(r'\W+', doc['text'])
    # een 'list comprehension' om termen te filteren die met een hoofdletter te beginnen
    terms = [term for term in terms if term != '' and term[0].isupper()]
    # update de counter met de lijst van termen in dit document
    term_freq.update(terms)

# print een overzicht van de 100 meest frequente termen
for term, freq in term_freq.most_common(100):
    # print term (links uitgelijnd met een breedte van 30 karakters) en frequentie (rechts uitgelijnd met 6 karakters)
    print(f'{term: <30}{freq: >6}')
# Out:
# Hoogh                           8959
# Mogende                         8926
# Heeren                          5087
# Waer                            4534
# Vergaderinge                    3010
# Heere                           2978
# Gedeputeerden                   2595
# Suppliant                       2186
# Raedt                           2160
# Is                              2157
# Requeste                        1928
# Ontfangen                       1644
# Requefte                        1609
# State                           1534
# Missive                         1423
# Provincie                       1414
# Miflive                         1319
# Paerden                         1306
# Staten                          1241
# De                              1164
# Op                              1137
# Supplianten                     1126
# Regiment                        1111
# Refolutie                       1065
# A                               1047
# Resolutie                        935
# Copie                            932
# Generael                         909
# Stadt                            889
# Staet                            874
# Memorie                          861
# E                                830
# Landts                           784
# Hof                              757
# Heer                             714
# Copye                            703
# Pasport                          702
# Admiraliteyt                     693
# Zeelandt                         681
# Militaire                        677
# Schip                            675
# Gecommitteerden                  672
# Leger                            645
# Collegie                         628
# Troupes                          606
# Koningh                          596
# Pafport                          566
# Hooeh                            557
# Grave                            554
# Miffive                          549
# Envoyé                           549
# Collonel                         540
# Groot                            536
# P                                536
# Landen                           534
# Capiteyn                         533
# Schepen                          524
# Provincien                       507
# Lieutenant                       499
# Landt                            494
# Hooch                            489
# Lande                            487
# Hautes                           473
# Pafpoort                         463
# Majefteyt                        455
# Hage                             445
# Requelte                         438
# Ontfanger                        431
# Vos                              428
# Majesteyt                        426
# Comptoir                         425
# Gedeputeerde                     423
# Fagel                            402
# B                                401
# Hollandt                         395
# Velde                            390
# Goederen                         384
# Van                              379
# Zee                              372
# Ende                             370
# Brittannien                      368
# Baron                            356
# Re                               356
# Vrieslandt                       355
# Mog                              351
# Major                            351
# Maze                             350
# Utrecht                          346
# Gelderlandt                      344
# Movende                          342
# Hertogh                          341
# D                                337
# Koopman                          335
# Hoog                             333
# Griffier                         331
# Hoosh                            329
# Ie                               316
# Brigadier                        310
# Moeende                          310
# St                               309

# %% [markdown]
# Termen hoeven geen individuele woorden te zijn, maar kunnen ook woord bi-grammen of groter woord n-grammen zijn.

# %%
# maak een nieuwe counter aan
term_freq = Counter()

ngram_size = 3

# itereer over all documenten (= paragraphs)
for doc in docs:
    # splits de tekst op alles wat geen alpha-numerical character is
    terms = re.split(r'\W+', doc['text'])
    # creeër ngrammen door elk woor te verbinden met de n-1 opvolgende woorden
    ngram_terms = [' '.join(terms[ti:ti+ngram_size]) for ti, term in enumerate(terms[:-(ngram_size-1)])]
    # een 'list comprehension' om termen te filteren die met een hoofdletter te beginnen
    terms = [term for term in ngram_terms if term != '' and term[0].isupper()]
    # update de counter met de lijst van termen in dit document
    term_freq.update(terms)

# print een overzicht van de 100 meest frequente termen
for term, freq in term_freq.most_common(100):
    # print term (links uitgelijnd met een breedte van 30 karakters) en frequentie (rechts uitgelijnd met 6 karakters)
    print(f'{term: <30}{freq: >6}')
# Out:
# Waer op gedelibereert           1842
# Raedt van State                 1292
# Is ter Vergaderinge             1231
# Gedeputeerden tot de            1143
# Waer op geen                    1038
# Hoogh Mogende Gedeputeerden     1013
# Hoogh Mogende geliefden          961
# Mogende Gedeputeerden tot        920
# Vergaderinge rapport te          817
# Copie van de                     759
# Vergaderinge gelefen de          703
# Missive van den                  647
# Miflive van den                  570
# Copye van de                     570
# Ontfangen een Missive            567
# Vergaderinge gelesen de          500
# Heeren Staten van                492
# Gedeputeerden van de             453
# Heeren Gedeputeerden van         442
# Ontfangen een Miflive            417
# Gecommitteerden uyt den          392
# Collegie ter Admiraliteyt        388
# Paerden op het                   388
# Heeren Gecommitteerden uyt       376
# Refolutie van den                331
# Comptoir op het                  331
# Mogende geliefden aen            330
# Waer op gedelibereerdt           325
# Resolutie van den                314
# State by haer                    313
# Regiment van den                 306
# Op de Requeste                   302
# Memorie van den                  300
# Op de Requefte                   284
# Staten van de                    255
# Hoogh Mogende extraordinaris     250
# De Heeren Gedeputeerden          241
# Hoogh Mogende te                 234
# Hoogh Mogende Resolutie          231
# Hoogh Mogende Refolutie          230
# Heeren van Welderen              221
# Miffive van den                  219
# Heeren haer Hoogh                219
# Heeren de Laet                   218
# Hof van den                      215
# Gedeputeerden te Velde           213
# Koninginne van Groot             207
# Envoyé aen het                   207
# Is naer voorgaende               203
# Provincie van Zeelandt           196
# Provincie van Utrecht            196
# Gedeputeerde uyt de              194
# Heere Hertogh van                186
# Mogende extraordinaris Envoyé    186
# Griffier Fagel houdende          184
# De Heeren van                    179
# Meyerye van s                    172
# Requeste geëxprimeert dat        170
# Heeren van Lamsweerde            167
# Raedt van Staten                 166
# Requeste van den                 165
# Provincie van Hollandt           163
# Mogende geliefden hem            160
# Heeren van Effen                 159
# Hoogh Mogende der                157
# Is gehoort het                   156
# Mogende Refolutie van            153
# Fagel houdende advertentie       153
# Leger te mogen                   149
# Admiraliteyt op de               148
# Mogende Resolutie van            146
# Heeren Gedeputeerden te          143
# Hoogh Mogende de                 137
# Laet ende andere                 137
# Missive van de                   136
# Admiraliteyt in Zeelandt         135
# Ontfangen een Miffive            134
# E selfs te                       132
# Hof van hare                     128
# Effen ende andere                128
# Landts gerechtigheydt midts      126
# Mogende Gedeputeerden te         126
# Requefte geëxprimeert dat        125
# Miflive van de                   125
# Ontfangen cen Miflive            123
# Requeste van de                  123
# Heeren van Essen                 123
# Requefte van den                 122
# Mogende geliefden de             122
# Hoogh Mo gende                   121
# Militaire saecken om             120
# Pafport al moeten                119
# E elfs te                        118
# De Heer van                      112
# Welderen ende andere             112
# Is na voorgaende                 112
# Heeren Tulleken ende             111
# Tulleken ende andere             110
# Suppliant te accorderen          109
# Zee om te                        108

# %% [markdown]
# ## Zoeken met Keywords
#
# Als je interessante woorden/ngrammen hebt gevonden, kun je ze in context zoeken om te kijken wat frequente frasen zijn.

# %%
# maak counters voor de tekst voorafgaand en volgend op een keyword
prefix_freq = Counter()
suffix_freq = Counter()

# zomaar een lijstje veel voorkomende woorden/frasen
term = 'Schip'
term = 'Collegie'
term = 'Gecommitteerden'
term = 'Regiment'
term = 'Regenten'
term = 'Pafport'
term = 'Placaat'
term = 'ophef'
term = 'Raedt'
term = 'Hoogh Mogende extraordinaris'
term = 'Collegie ter Admiraliteyt'
term = 'Heeren Gedeputeerden van'
term = 'Generaliteyts Reeckenkamer'
term = 'Compagnie'
term = 'Magistraet' # van
term = 'Ambaffadeur' # (van|aan het hof van|tot)
term = 'Hoogh Mogende Gedeputeerden'

# itereer over de documenten
for doc in docs:
    # zoek de term en bijbehorende context op in het document
    for context in get_keyword_context(doc['text'], term, context_size=5):
        # tel hoe vaak elke prefix/suffix voorkomt
        prefix_freq.update([context['prefix']])
        suffix_freq.update([context['suffix']])
    
# toont een overzicht van de meest frequente prefixes en suffixes
for prefix, freq in prefix_freq.most_common(10):
    print(f'{prefix: <30}{freq: >6}')

print('\n')

for suffix, freq in suffix_freq.most_common(100):
    print(f'{suffix: <30}{freq: >6}')
# Out:
# de Laet, ende andere haer         37
# van Effen, ende andere haer       36
# van Welderen, ende andere haer    29
# van Essen, ende andere haer       22
# van Lamsweerde, ende andere haer    22
# Heeren Tulleken, ende andere haer    21
# Welderen , ende andere haer       16
# Essen , ende andere haer          16
# Tulleken , ende andere haer       16
# van Essen ende andere haer        14
#
#
# tot de saecken van de             91
# tot de faecken van de             57
# tot de Militaire saecken ,        32
# tot de Militaire saecken, om      21
# tot de Militaire faecken ,        21
# tot de {aecken van de             20
# tot de Militaire faecken ‚        16
# tot de Militaire faecken, om      13
# tot de Militaire {aecken, om      12
# tot de Militaire saecken ‚        11
# tot de Buytenlandtsche saecken ,    11
# tot de Militaire {aecken ,         9
# tot de faecken van het             9
# tot de Militaire {aecken ‚         9
# tot de Buytenlandtsche saecken, om     8
# tot de saecken van het             7
# tot de faccken van de              7
# tot de Militaire faccken ,         5
# tot de Militaire faccken, om       5
# tot de Militaire faecken, hebbende     5
# tot de Militaire {aecken, hebbende,     5
# tot de Militaire saecken, hebbende,     4
# tot de Militaire saecken ;         4
# tot de Militaire saecken om        4
# tot de {aecken van het             4
# tot de {aken van de                4
# tot de Militaire saecken, hebbende     4
# tot de Militaire faccken ‚         4
# te Velde, gefchreven in het        4
# te Brussel, geschreven aldaer den     4
# te Bruffel, gefchreven aldaer den     4
# tot de saken van de                3
# tot de Buytenlandt{che faecken ‚     3
# te Velde, geschreven in het        3
# tot de Buytenlandtsche saecken ‚     3
# tot de Buytenlandt{che faccken ‚     2
# tot de faccken van Vlaenderen,     2
# tot de Militaire saecken’, om      2
# tot de Militaire {aecken; om       2
# tot de Militaire {aken, om         2
# met den Raedt van Staten           2
# tot de Militaire saecken -         2
# tot de faecken vande Zee,          2
# tot de Militaire faecken ;         2
# tot de Mili. taire saecken         2
# tot de Buytenlandtsche saecken, midts     2
# tot de Buytenlandtfche faecken ‚     2
# tot de Militaire {accken, om       2
# tot de Buytenlandtfche faecken ,     2
# tot de saecken van den             2
# , om met ende nevens               2
# tot de Militaire saeeken ‚         2
# te Velde, van dato den             2
# tot de Buytenlandtsche saken ,     2
# ot de saecken van de               2
# tot de Buytenlandtsche saecken om     2
# tot de Militaire saecken .         2
# te Velde ‚ gefchreven in           2
# tot de Buy. tenlandtsche saecken     2
# tot de faken van gemelde           2
# tot de Mili taire faecken          2
# tot de Buytenlandtsche saecken, hebbende     2
# tot de Buytenlandesche saecken ,     2
# te Brussel sal werden aengeschreven     2
# , geweeft zijnde in het            2
# tot de Militaire faecken; om       2
# tot de Buytenlandtfche {aecken ,     2
# tot de Buytenlandt{che {aecken ,     2
# , jonghst in het Overquartier      2
# te Brussel , geschreven aldaer     2
# tot de Militaire saeeken, om       2
# tot de saec ken van                2
# , tot de Militaire {aecken,        1
# tot-de:faéeken van de: Welt-Indifche Compagnie’     1
# tot de Militaire {acchen ,         1
# tot de Buytenlandiche faecken, hebbende     1
# tot de Militaire saecken, in       1
# tot >de Militaire saecken ,        1
# tot de buytenlandtsche saecken, om     1
# tot de Militaire faccken ;         1
# tot de Militaire saecken hebbende     1
# tot de Militaire saecken 5         1
# tot de Militaire saechen, om       1
# tot de Militairetaecken ‚ om       1
# tot de Militaire {aceken 5         1
# tot de {aken van dé                1
# tot de Militaire faeeken hebbende     1
# tot de Buytenlandtfche faccken ,     1
# tot-de faecken van de gemelde      1
# tot de Buytenlandesche saecken, om     1
# tot de Militaire saecken ei        1
# tot de’ Militaire {aecken ,        1
# tot de Buytenlandt{che faccken, om     1
# tot de Militaire faccken!, hebbende     1
# tot de Buyten: landtfche faccken     1
# tot de (aecken van de              1
# tot de Milicaire saecken ‚         1
# tot de ’faec‘ken van de            1
# tot de Militaire faecken. hebbende     1
# tot de faecvan de Finantie         1

# %% [markdown]
# ## Fuzzy zoeken
#
# Omdat er allerlei OCR fouten en spellingsvarianten voorkomen van een keyword/frase, mis je met exact zoeken allerlei voorkomens. De Fuzzy search module biedt mogelijkheden om inexact te zoeken naar tekst strings die lijken op een geven set van keywords/frasen.
#
# In de configuratie kun je aangeven hoeveel een string van een keyword mag afwijken om als match te tellen.

# %%
# importeer de fuzzy keyword searcher class en de phrase model class
from republic.fuzzy.fuzzy_keyword_searcher import FuzzyKeywordSearcher
from republic.fuzzy.fuzzy_phrase_model import PhraseModel

# configuratie van de fuzzy searcher
fuzzy_search_config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
}

# creeër een nieuwe fuzzy searcher met bovenstaande configuratie 
fuzzy_searcher = FuzzyKeywordSearcher(fuzzy_search_config)


# keywords mag een lijst van strings zijn:
keywords = [
    'Raedt van State',
    'Ambaffadeur aan het hof van',
    'Generaliteyts Reeckenkamer'
]

# of je kunt per keyword extra gegevens toevoegen:
# 'variants': variante voorkomens die je onder hetzelfde keyword wilt tellen
# 'label': een categorizerend label
# 'distractors': keywords die qua tekst-afstand op het keyword lijken maar toch echt iets anders zijn
keywords = [
    {
        'keyword': 'Raedt van State',
    },
    {
        'keyword': 'Hoogh Mogende Gedeputeerden tot de Militaire saecken'
    },
    {
        'keyword': 'Hoogh Mogende Gedeputeerden tot de Buytenlandtsche saecken'
    },
    {
        'keyword': 'Ambaffadeur aan het hof van',
        'variants': [
            'Ambaffadeur van hare'
        ]
    },
    {
        'keyword': 'Generaliteyts Reeckenkamer'
    }
]

# transformeer je lijst met keywords in een phrase model
phrase_model = PhraseModel(model=keywords)
# indexeer de keywords uit het phrase model met de fuzzy searcher
fuzzy_searcher.index_keywords(phrase_model.get_keywords())
# indexeer eventuele varianten van de keywords
fuzzy_searcher.index_spelling_variants(phrase_model.variants)

# %%
import json

# itereer over de documenten
for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = fuzzy_searcher.find_candidates(doc['text'], use_word_boundaries=True, include_variants=True)
    # check of er matches zijn en print de tekst en de match objecten
    if len(matches) > 0:
        print(doc['text'])
        for match in matches:
            print(json.dumps(match, indent=4))
        break
# Out:
# Ontfangen cen Mifliye. van den’ Refidendt Bilderbeeck , gefchreven tor Keulen den negen en twintighiten der voorlede macndt December, hpudende, dat behalren het geene hy zedert den vier en twintigh{ten December {eventien hondegdt vier tot den eerften Julii {gventien hondefdt vijf aen arme Paffagters haddeverfehooien, ende oock in fijn voorige Dêclatatic was goedtgedaen , dat haer Hoogh Mogende hadde gelieft hem by der fclver Refolutie van den vierden December laetítleden te authoriferen, om noch tot {eltigh rijcxdaelders of hondert en vijftigh guldens toe aen arme Paflagiers te mogen uytgeven , dát nu bléëeuft de Specikd catie nevens de“op®emclde Refolutie by (jn halfjarige Declaratie gewoaght , dat hy zedert den eerlten Julii voorfchr@%e tt den {es en twintigh ften December 176% defcfhonderd vijfieh ed nensaen arme Paflig<isioch hadde verfchooren vier en feftislrgulf®hs acht ftuyvers, de welcke hy mede in de-opgemelde Declaratie inbraghte, op hoope , dat.haer Hoogh Mogende {ouden gelievengoet te vinden dat defe5Pof-van hondert vieren feftigh-&ûldens acht &uyvers hef oock foude werden gevalideert, als pallerentot Keulen ; noch dickwils {90 Hollindts-deels verminckte ‚én deels by den Vyandt gevangén geweeft zynde Soldaten ende Matroofen ; als Vlug: telingen ende andere arme Paflagiers ‚ hebbende gebreck van alles; sverloeckende op het geene voor{chreve te mogen- hebben haer Hoogh Mogende favorable Refíolutie. . Waer op gedelibereert;zynde ‚is goedtgevonden: Gjde: verltaen, dat aen gemelden Refident Bilderbeeck de voor= Schreve Poft van vier enfeltigh-guldens-acht (uy-vers in fijne Declaratie {al werden-gevalideert; Endé {al-Exraât van defe hacr-Hoóogh Mogcride Refolutie- gefonden’ werden aen, ‘den Raedt van Staten ‚ ende des Generaliteyts Reeckenkamer ‚ om te ftrecken tot der {clver narichvitgebnaf o:b asv sv 095 nogndin0 Ontfangen een Miflive van den -Ootfanget Pefters ,- gefchreven tot Maeftricht den ‘dertighften der voörledemmaendt December , geaddreffeert aen den Griffier Fagel, houdende daer nevens ‘Copye van den Brief, die hy in gevolge van haer Hoogh Mogende  Refolutie van den cen:en twintigh{ten daer te vooren, aen de Magiftraet van Luyck hadde gefchreven; racckende: de continuatie van de gevorderde betalinge der
# {
#     "match_keyword": "Raedt van State",
#     "match_term": "Raedt van State",
#     "match_string": "Raedt van Staten",
#     "match_offset": 1726,
#     "levenshtein_distance": 0.9375,
#     "char_match": 1.0,
#     "ngram_match": 0.9375
# }
# {
#     "match_keyword": "Generaliteyts Reeckenkamer",
#     "match_term": "Generaliteyts Reeckenkamer",
#     "match_string": "Generaliteyts Reeckenkamer",
#     "match_offset": 1754,
#     "levenshtein_distance": 1.0,
#     "char_match": 1.0,
#     "ngram_match": 1.0
# }

# %%
# creeër counters voor de varianten van elk keyword
variants = defaultdict(Counter)

# itereer over de documenten
for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = fuzzy_searcher.find_candidates(doc['text'], use_word_boundaries=True, include_variants=True)
    # voor elke match, tel de matchende string als variant van het matchende keyword
    for match in matches:
        variants[match['match_keyword']].update([match['match_string']])

# toon voor elk van de gevonden keywords een overzicht van de meest frequente varianten
for keyword in variants:
    print('Keyword:', keyword)
    print('------------------------------------')
    for variant, freq in variants[keyword].most_common():
        print(f'{variant: <20}\t{freq: >6}')
    print('\n')
# Out:
# Keyword: Raedt van State
# ------------------------------------
# Raedt van State     	  1251
# Raedt van Staten    	   163
# Raede van State     	    40
# Racdt van State     	    25
# Raed van State      	    19
# Raedt van Stare     	    11
# Raedr van State     	     8
# Raedt van Státe     	     8
# Raede van Staten    	     7
# Raedt van Sate      	     6
# Raedt van. State    	     6
# Raedt van’ State    	     6
# Rade van State      	     5
# Raedt van $tate     	     5
# Raedt van Srate     	     5
# Raedt. van State    	     5
# Raedt ran State     	     4
# Raedrvan State      	     3
# Raedt van Stite     	     3
# Raedt ‘van State    	     3
# Raédt van State     	     3
# Ráedt van State     	     3
# Raede van Stare     	     3
# Raeden van State    	     3
# Raedt van Stater    	     2
# Rúáedt van State    	     2
# Raedt’van State     	     2
# Rede van State      	     2
# Raédt van Staten    	     2
# Redt van State      	     2
# Raedt van'State     	     2
# Raedt’ van State    	     2
# Racdr van State     	     2
# Raedt van Stas      	     2
# Raden van State     	     2
# Raedt van Staee     	     2
# Raedtvan State      	     2
# Raedt var State     	     2
# Raedt van Stâte     	     2
# Raedt Van State     	     2
# Raedt van ‘State    	     2
# Raedt ván State     	     2
# Raedt van Stäten    	     2
# Raedt! van State    	     2
# R edt van State     	     2
# Raed: van State     	     2
# Racde van State     	     2
# Raedt San State     	     2
# Raedt ven State     	     2
# Rade van Staten     	     1
# Ráedt van'State     	     1
# Raedt,van State     	     1
# Raedt van-Staten    	     1
# Raedt vanStaten     	     1
# Riedt van State     	     1
# Raeds. van State    	     1
# Raedt vau State     	     1
# Raedt van StaA      	     1
# Raedt vafi State    	     1
# Raedt van Sta7      	     1
# Raede van Staee     	     1
# Raedt Van Staten    	     1
# Raédt van: State    	     1
# Racdt vanStaté      	     1
# Raedt van Statcn    	     1
# Raedt va Staten     	     1
# Raedt-van Sate      	     1
# Raedt, van Stare    	     1
# Raedt, van State    	     1
# Raedt Man oStatd    	     1
# Raed t Van State    	     1
# Ráedt-van State     	     1
# Raedt yan State     	     1
# Raédt van-Staten    	     1
# Kaáedtvan State     	     1
# Raedt:van Staten    	     1
# Ratdt van Stäte3    	     1
# Raedt van <tute     	     1
# Raedt van:State     	     1
# Raedt van; Start    	     1
# Raed vant State     	     1
# Räede vant State    	     1
# Ráedtvan State      	     1
# Raedt van Statej    	     1
# Reede Yan State     	     1
# Räedt ván State     	     1
# Raedt van-State     	     1
# Raedt van Starch    	     1
# Raedt van Ctate     	     1
# Raedtvan State;     	     1
# Raedt varfStaten    	     1
# Wäedt van State     	     1
# Raedt vân State     	     1
# Raedt van:Srate     	     1
# Raedt: van State    	     1
# Raedt van Stnte     	     1
# Raedéván State      	     1
# Raedt van Styte     	     1
# Waedr van Sate      	     1
# Raedt van Staie     	     1
# Raedt vanrStite     	     1
# Raedt van rite      	     1
# Raedt van Sta1e     	     1
# Racdtivan States    	     1
# Roede van Staten    	     1
# Raed Van State      	     1
# Redt van State;     	     1
# Raedt an Stare      	     1
# Raedt ven Stare     	     1
# Rsedivan State      	     1
# Raedt van States    	     1
# Raedt van Statèn    	     1
# Raedt ‚vafiState    	     1
# Raedt- van State    	     1
# Raedt van Stdte     	     1
# Raedt van Stat;     	     1
# Raedt van staren    	     1
# Raedt van Ctuten    	     1
# aedt. van State     	     1
# Raedewan State      	     1
# R aedt van State    	     1
# aedt van State      	     1
# R edt. van State    	     1
# Raedt vanState      	     1
# Raedt van rate      	     1
# Raedt van Crate     	     1
# Raedt-van State     	     1
# Raede van” State    	     1
# R ede van State     	     1
# Racdt van Staten    	     1
# Raedt van Corte     	     1
# Raedt uanState      	     1
# Raedt vankiSgate    	     1
# Roodt ivan State    	     1
# Idedt van Stats     	     1
# Kaedt van State     	     1
# Raédt van Statên    	     1
# Racdt van:Staté     	     1
# Ruedt van State     	     1
# Raedt van Stat      	     1
# eedt van State      	     1
# Raedt van Sta‘ve    	     1
# raedt var State     	     1
# Bnedt van State     	     1
# Raedt van Seite     	     1
# vaede van State     	     1
# Raedt vaniStates    	     1
# Raed? van. State    	     1
# Roedr van State     	     1
# Raedt van deute     	     1
# Raedt van Sfâte     	     1
# Rácdt van State     	     1
# Racdt an State      	     1
# Raedt van stie      	     1
# Raedt ‚van State    	     1
# Raedt wan State     	     1
# Raedt vansState     	     1
# Raedt vaa Stâte     	     1
# Raedt van eeste     	     1
# Racdt van Sfite     	     1
# Racde'van State     	     1
# Raede van Seate     	     1
# Raedt van Stute     	     1
# Raede van/State     	     1
# Raede van. State    	     1
# Raedt vangState     	     1
# R odt van State     	     1
# Roede van State     	     1
# Raedi’yan State     	     1
# Redt van Staten     	     1
# Raedt van tate      	     1
# vaedt van State     	     1
# Raedt van” Ste      	     1
# Raedevan Stare      	     1
# Raedt van Stafé     	     1
# Raedt van StaDE     	     1
# Raedt van Szite     	     1
# Raedt vaa Staten    	     1
# Radt van State      	     1
# Raed van State’     	     1
# Raed. Van State     	     1
# Raedt van Seat      	     1
# Raedt vn State      	     1
# Raedts van State    	     1
# Raed! van State     	     1
# R edt Yvan State    	     1
# Raéd van State      	     1
# Raedt van Seaten    	     1
# Raede"van State     	     1
# Raedt van Stacen    	     1
# Ra ede van State    	     1
# Ráedt van Staten    	     1
# Raedtj van State    	     1
# Raedt van’'State    	     1
# Raed: van Stare     	     1
# Eaed van Stare      	     1
# Rae at van State    	     1
# Raedt van state     	     1
# Ruedtv an State     	     1
# Raed ‚van State     	     1
# Raet Yan State      	     1
# Raedt van Sta:      	     1
# Kaede van State     	     1
# Raedeván State      	     1
# Raedevan “State     	     1
# Raedt vaa State     	     1
# Raet van State      	     1
# Raedt Sn State      	     1
# Raéút van State     	     1
# Raede van, State    	     1
#
#
# Keyword: Generaliteyts Reeckenkamer
# ------------------------------------
# Generaliteyts Reeckenkamer	    68
# Generaliteyts Reecken-kamer	    31
# Generalitevts Reeckenkamer	     6
# Generaliteyes Reecken-kamer	     3
# Generaliteyes Reeckenkamer	     3
# Generaliteyts Reecken kamer	     3
# Generaliteyts Reken-kamer	     2
# Genereliteyts Reeckenkamer	     2
# Generaliteyrs Reeckenkamer	     2
# Gcherdliteyts ReëckEnkamer	     1
# Generáliteyts Reecken-kamër	     1
# Generaliteyts: Reeckenkamer	     1
# Generaliceyts Reecken-kamer	     1
# Generaliteyes Reeekenkamer	     1
# Generaliteyts Réeckenkamer	     1
# Geherliteyts Reet ken-kamer	     1
# Generaliteyrs Reecken-kamer	     1
# Generaliteyts Reecken-Kamer	     1
# Gencraliteyts Reeckeikamer	     1
# Generaliteyts Reecken-kamet	     1
# Generaliteyts ReecKenkarmer	     1
# Generaliteyes Reecken kamer	     1
# Generalitevts Reeckénkamer	     1
# Generaliteyts- Reeckenkamer	     1
# Gengraliteyts Reecken:kamer	     1
# Generaliteyts. Reeckenkamer	     1
# Ceneralitevts Reecken-kamer	     1
# Generalirerts: Reeckenkam	     1
# Ge neraliteyes Reeckenkamer	     1
# Gencraliteyts Reeckenkamer	     1
# Ceneraliteyrs Reeckenkamer	     1
# Ceneralitevts Reeckenkamer	     1
# Generaltéyts Reeckenkamer	     1
# Generaliteyts Reeckenka mer	     1
# Gene raliteyts Reeckenkamer	     1
# Generaliteyis Reeckenkamer	     1
# Generaliteyts Rekenkamer,by	     1
# Generaliteyts R eken kamer	     1
# Generaliteyt Reeckenkamer	     1
# Generäliteyts Reeckenkamer	     1
# Generasiteyte Reeckenkamer	     1
# Gederdliteyts Reeckenkamer	     1
# Generaliteyte Reecken-kamer	     1
# Generaliteyts Reken kamer	     1
# Generakitevts Reeckenkamer	     1
# Generaliteyts Reeckenkame	     1
# Generaliteyts Recckenkamer	     1
# Generalteyts Reeckenkamer	     1
# Generaliteyts Reeckenikamer	     1
# Genefaliteyts Reeckenkamer	     1
#
#
# Keyword: Ambaffadeur aan het hof van
# ------------------------------------
# Ambassadeur van hare	     4
# Ambassadeur aen het Hof van	     3
# Ambafladeur van hare	     2
# Ambaffadear van, hare	     1
# Ambaffadeur van, hare	     1
# Ambaffadéur van hare	     1
# Ambaffadeur acn het Hof van	     1
# Ambaffadeur van hoogh	     1
# A mbaffidedr van hare	     1
# mbaffidedr van hare 	     1
# Ambafladeursvan hire	     1
# Ambafladeur van haere	     1
# Ambafladear van bare	     1
# Ambaffadeuf? van bare	     1
# A mbafTadeur aen het Hof van	     1
# mbafTadeur aen het Hof van	     1
# Ambaffadeur aen het Hof van	     1
# Ambaffadeur van fijne	     1
# A mbassadeur aen het Hof van	     1
# mbassadeur aen het Hof van	     1
# Ambaffadeurs van ‘de	     1
# Ambafsadeur van hare	     1
# Ambáffadeur aen. het Hof van	     1
#
#
# Keyword: Hoogh Mogende Gedeputeerden tot de Militaire saecken
# ------------------------------------
# Hoogh Mogende Gedeputeerden tot de Militaire saecken	    95
# Hoogh Mogende Gedeputeerden tot de Militaire faecken	    66
# Hoogh Mogende Gedeputeerden tot de Militaire {aecken	    43
# Hoogh Mogende Gedeputeerden tot de Militaire faccken	    19
# Hooeh Mogende Gedeputeerden tot de Militaire saecken	    12
# Hoog Mogende Gedeputeerden tot de Militaire saecken	     6
# Hoogh Mogende Gedeputeerden tot de Militaire {accken	     5
# Hoogh Moeende Gedeputeerden tot de Militaire saecken	     5
# Hoog Mogende Gedeputeerden tot de Militaire faecken	     5
# Hoogh Mogende Gedeputeerden tot de Militaire saeeken	     4
# Hooch Mogende Gedeputeerden tot de Militaire faecken	     4
# Hoogh Mogende Gedepueerden tot de Militaire faecken	     3
# Hoogh Movende Gedeputeerden tot de Militaire faecken	     3
# Hoosh Mogende Gedeputeerden tot de Militaire faecken	     3
# Hooe Mogende Gedeputeerden tot de Militaire saecken	     3
# Hoogh Mogende Gedeputeerden tot de Militaire faeeken	     2
# Hoogh Movende Gedeputeerden tot de Militaire saecken	     2
# Hoogh Mogende. Gedeputeerden tot de Militaire saecken	     2
# Hoogh Mogende Gedeputcerden tot de Militaire faecken	     2
# Hoogh Mogende Gedeputeerden tot de Militaire Taecken	     2
# Hoogh Mogende Gedeputeerden tot de Militaire (aecken	     2
# Hoooh Mogende Gedeputeerden tot de Militaire saecken	     2
# Hoogh Mogende Gedeputeerden tot de Militaire taecken	     2
# Hoogh Moeende Gedeputeerden tot de Militaire faecken	     2
# Hoogh Mogende Gedeputeerden tor de Militaire faccken	     2
# Hoogh Mogende Gedeputeerden tot de Militaire f{aecken	     2
# Hoogh Mooende Gedeputeerden tot de Militaire saecken	     2
# Hoogh Mogende Gedeputeerden tot de Mili taire faecken	     2
# Hoogh Mogende Gedeputeerden tot de Militaire faceken	     2
# Hoogh Mogende Gedeputeerden tot de Militaire aecken	     2
# Hoogh Mogende Gedeputeerden, tot de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {acchen	     1
# Hoogh Mogende Gedeputeerden tot >de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire saechen	     1
# Hoogh Morende Gedeoureerden tot de Militaire {accken	     1
# Hoogh: Mogende Gedeputeerden tot de Militaire taecken	     1
# Hoogh Mogende Gedeputeerden tot de Militairetaecken	     1
# Hoogh Mozende Gedeputeerden tot>de Militaire fzecken	     1
# Hoogh Mogende Gedeputeerdèn tot de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {aceken	     1
# Hoogl Mogende Gedeputeerden tot de Militaire saecken	     1
# Hoos Mogende Gedeputeerden tot de Militaire taecken	     1
# Hooeh Mogende Gedeputeerden tot de Militaire fdecken	     1
# Hooch Mosende Gedeputeerden tot de Militaire Txecken	     1
# Hoogh Mogende Gedeputeerden tot de’ Militaire {aecken	     1
# Hoogh Movende Gedeputeerden tot de Militaire faccken	     1
# ‘Hoogh Movende Gedeputeerden tot de Militaire faccken	     1
# Hoosh Mogende Gedeputeerden tot de Miltrire faecken	     1
# Hoogh Mogende Gedeputeerden tot de Milicaire saecken	     1
# Hoogh Mogende Gedeputeerde tot de Milieaire gfaecken	     1
# Hooeh Mogen de Gedebuteerden tot de Militaire saecken	     1
# Hooeh Mogende Cedevuteerden tot de Militaire saecken	     1
# Hooeh Mogende Gedeputeerden tot de Militaire shecken	     1
# Hoogh Mogende Gedeputeerden tot de Militare saecken	     1
# Hoogh Moende Gedeputeerden tot de Militaire saecken	     1
# Hoooh Moeende Gedeputeerden tot de Militaire saecken	     1
# Hoogh Mogende Ce evuteerden tot de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden torde Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Miliraire faecken	     1
# Hooch Mogende ‘Gedeputeerden tot de Militairefaccken	     1
# Hoog’ Mogende Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tok de Mi. taire faccken	     1
# Hooeh Morsende Gedeputeerden tot de Militaire faccken	     1
# Hoogh. Mogende Gedeputeerden tot de Militaire faccken	     1
# Hoogh Mogende Gedepmeerden tor de Militaire faecken	     1
# Hoogh Mogende Gedepueerden ‘tót de Militaire faécken	     1
# Hoogh Mogende Gedeputeerden ‘tot ‘dé’ Militaire {acc	     1
# Hoooh Mogende Gedeputeerden tot de Militate saecken	     1
# Hoogh Mogende’ Gedeputeerden tot de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tor de Militaire'faecken	     1
# Hoogh Mogende: Gedeputeerden tot de Militaire {aecken	     1
# Hoogh Mogende G edeputeerden tot de Militaire saecken	     1
# Hooeh Mogende Geédeputeerden tat:de Militaire {acékew	     1
# ‘Hoogh Mogende “Gedepiteerden “tor de Militaire [ec	     1
# Hoogh Mogende Gedeputeerden tor de Militaire {aecken	     1
# Hoosh Mogénde ‘Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden toe de Militaire saecken	     1
# Hooch MogendeGedeputeer‘den tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot dé Militaire {aecken	     1
# Hoógh Mogende Gedeputeerden tot de Militaire faccken	     1
# HoeghMevende Gedeputeerden tot de Militaire {aeeken	     1
# Hóogh Mogende Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden ‘tot de Militaire {aecken	     1
# Hoogh Mozende: Gedeputeerden tot de Militaire faecken	     1
# Hoogh Movende Gedeputeerden tot de Militaire saeeFen	     1
# Hoogh Mogende Gedeputeerden tot'de Militaire faecken	     1
# Hoogh Mogende Gedenuteerden. tot de Militaire saeeken	     1
# Hoogh Mogende GeIemuteerden tot de Militaire saecken	     1
# Hoogh Mogende GeIenuteerden 200- de Militaire saecken	     1
# Hoogh: Mogende Gedeputeerden tot de/Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {aeeken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire faécken	     1
# Hoogh Mogendé Gedeputeerden tot de Militaire faecken	     1
# Hoogh  Mogende Gedeputeerden tot de Militaire faecken	     1
# Ho0h Movende Gedeputeerden tot de Militaire saecken	     1
# Hoogh Moeende Gedeputeerden tot de Militaire laecken	     1
# Hoooh Mooende Gedeputeerden tot de Milieaive saecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {aeëken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire fact ken	     1
# Hoogh Mogende Gedeviteerden tot de Militaire Jaecken	     1
# Hoogh Mogende GedeputeerAen tot de Militaife faccken	     1
# Hoogh Movoende Gedeputeerden tot de Militaire saecken	     1
# Hoogh:; Mos vende Gedeputeerden tot de Militaire 4aec	     1
# Hoogh Mogende Gedeputeerden tot de Milftaife faecken	     1
# Hoogh Mocende Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tet de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden- tot-de Militaire taecken	     1
# Hoogh Mö@gende Gedepúteenden tot de Miliraife{aecken	     1
# Hoogh Mogende Geeerden tot de Militaire saecken , in	     1
# Hoogh Mogende Gedeputeerden tot- de Militaire Jaecken	     1
# Hoogh Mogende Gedepuúteerden tot de Militaire {aecken	     1
# Hoogh Movende Gedeouteerden tot de Militaire faecken	     1
# Hooelt Mooende Gedeputeerden tot de Militaire saken	     1
# Hoogh Mo gende Gedeputeerden tot de Militaire faecken	     1
# Hoogh Movende Gedeputeerden tor de Militaire saecken	     1
# Hoogh Megende Gedeputeerden tot de Militaire {laecken	     1
# Hoog. Mogende Gedepureerden tot de Militaire faccken	     1
# Hoogh Mogende Gedeputeerden aot de Militaire faecken	     1
# Hooeh Mogende Gedepúteerden tot de Militaire Taecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {laecken	     1
# Hoosh: Mogénde Gedepûteerden tot de Militairefaecken	     1
# Hoogh Mogen: de Gedeputeerden tot de Militaire {aec:	     1
# Hoogh Moande Gedeputeerden tot de Militaire saecken	     1
# Hooch Mosende Gedeputeerden tot de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Miliraire {aecken	     1
# Hoogh Movende Gedeputeerden tot de Milirair®1aecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire. {accken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire faec Ken	     1
# Hoosh Mogende Gedeputeerden tot de Militaire Taecken	     1
# Hoogh Moen de Cedeputeerden tot de Miliraire saecken	     1
# Hogeh Mogende Gedepuúteerden tot de Militaire faccken	     1
# Hooeh Moeende Gedeputeerden tot de Militaire saecken	     1
# Hoogh Movende Gedeputeerden tot de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {aeckeri	     1
# Hoogh Moeende Gedeputeerden tot de Militaire faec ken	     1
# Hooch Mogende Gedepateerder tot de Militaire saecken	     1
# Hoogh Mogende Gedepnteerden tot de Militaire saecken	     1
# Hoog *Mogendé Gedeputeerden tot de Militaire faecken	     1
# ‘Hoog *Mogendé Gedeputeerden tot de Militaire faecken	     1
# Hoogh Moo. Gedeputeerden tot de Militaire-faecken am	     1
# Höosh’ Mogende Gedeputeerden at des Militaire Täecken	     1
# Hoogh Mogende Gedêputeerden tot de Militaire {aecken	     1
# Hoooh Movende Gedeputeerden tot de Militaire uecken	     1
# “Mo-: gende [Gedeputeerden tot dé Militaire faecken;	     1
# Hoorh- Moeéhde Gedeputeerden tot de Militaire faecken	     1
# Hoogh. Movgende Gedeputeerden tot de Militaire aecken	     1
# Hoooh Mogende  Cedeputeeren tot de Militaire daecken	     1
# Hoogh Mo14e Gedeputeerden tot de Militaire saee7 om	     1
# Hoogh Moeende Gedeputeerden tot de Militaire saeeken	     1
# Hoogh Mooende Gedeputeerden tor de Militare Ciecken	     1
# Hoogh Mogende Gedeputeerden tot de Militairev{accken	     1
# Hoogh Mogende Gedeputeerden tot de: Militaire {aecken	     1
# Hooeh Mogende Gedeputeerden or de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot de .Militaire faecken	     1
# Hoogh Mogende Gedenuteerden tor de Militaire faecken	     1
# Hoogh Movende Gedeputeerden tot de Militatre saecken	     1
# Hoogh” Mogende Gedeputeerden tot de Militaire fiecken	     1
# Hoorh Mogende Gedeputeerden tot de Militaire {accken	     1
# Hoogh Mogende Gedeputeerden tot. de Militaire faccken	     1
# Hoogh -Movende Gedeputeerden tot de Miliraire {aecen	     1
# Hoooh Mosende Gedeputeerden or Ae Militaire faecken	     1
# Hoogh Mogende 6ecdepsteerden tot de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden tot de Mi litaire saecken	     1
# Hooch Moaende Gedeputeerden tot de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire laecken	     1
# Hoogh Mogende Gedenureerden tot de Militaire faecken	     1
# Hoogh MôgenAad emuteerden ‘tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot:de Militaire faecken	     1
# HooshsMozende Gedeputeerdentor de Militaire -faecken	     1
# Hooch Movende Gedeputéerden tor de Militaire faecken	     1
# Hooeh Mogende Gedeputeerden tot de Militaire {aecken	     1
# Hoosh Mogende Gedeputeerden tot de Militaire {aecken	     1
# Hoogh Mogende Gedenuteerdel tot de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden tot Je’ Militaire saecken	     1
# Hoogh*Magende Gedeputeerden. fotde Militaire {accken	     1
# Hoosh Mogende Gedebutcerden tot de Militaire {aecken	     1
# Hoogh Moagende Gedeputeerden tot de Militaire saecen	     1
# Höögh Mogende Gedenuteerden tot dé Militaire {accken	     1
# Hoogh Mooende Gedeputeerden tot de Militaire saeckene	     1
# Hoogh Moeende. Gedeputeerden tot de Militaire faecte	     1
# Hoosh Mogende Gedéputeerden tot Ae Miliraire faccken	     1
# Hoogh Mozende Gedeputeerden tot Ae Militaire faccken	     1
# Hoon. 1de Gedeputeerden tot de Militaire saecken om	     1
# Hooch Moeende Gedeputeerden tot de Militire {decken	     1
# Hoogh Mogende Gedeputeerden tot de Militire {aecken	     1
# Hooch Mogende Gedeputeerden tot de Militaire faeckeni	     1
# Hoooh Moeende Gedeputeerden tot 4 Miliraire a ecken	     1
# Hoogh Mozende Gedeputeerden tot de Militaire faecken	     1
# Hoorh Mogende Gedeputeerden tot de Militire faccken	     1
# Hoogh Morgende Gedeputeerden tot de Militaire faecken	     1
# Hooch Movende Gedeputeerden tot de Mili ires: ecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire’ {aeckcn	     1
# Hooeh Mooende Gedeputeerden tot de Militire saecken	     1
# Hoooh Movende Gedeputeerden tot de Milseaire saccken	     1
# Hoogh Moende Gedeputeerden tot de Militaire {aecken	     1
# Hoosh Mogende Gedepueerden tot de Militaire faecken	     1
# Hooch Mogen de Gedeputeerden tot de Militaire saecken	     1
# Hoogl Movgende Gedeputeerden tot de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden tot de Miicaire faecken	     1
# Hoogh Mogende Gedeputeerden tot de Miitairel fiecken	     1
# Hoor Mogende Gedeputeerden tot de Militaire facck@l;	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {aec ken	     1
# Hoogh Mogende Gedeputeerden tor de Miliaire faecken	     1
# Hoogh Mogende Gedepuserden tor de Mi. Vraire feeken	     1
# Hooch Mosende Gedeputeerden tot de -Militaire faecken	     1
# Hooch Moeende Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot de Milttaire faecken	     1
# Hooch Moeende Gedeputeerden tot de Militaire faccken	     1
# Hoogh Mogende Gedeputeerden tot de Mili. qire faecken	     1
# Hoogh Mogenide Gedeputeerden tot de Mi aire faccken	     1
# Hoogh Mogende Gedeputeerden tot de Mi liraire faccken	     1
# Toogh Mogende Gedeputeerden tot de Miitaire faecken	     1
# Hooch Mosende Ge deputeerden tot de Militaireiiecken	     1
# Hoogh Mogende Gedeputeerden tot’ de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de MiAiaire faecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire. saecken	     1
# Hoogh Mogerde Gedenuteerdentot de Militaire (aecken	     1
# Hooeh Moeende Gedeputeerden tot de MiIitaire saecken	     1
# Hoogh Mogende Gedeputeerden tor de Militaire faecken	     1
# Hoogh Mogende Ge. deputeerden tofde Militaire faecken	     1
# Hoogh Mo gende Gedeputeerden tot de Militaire Taecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire Îaccken	     1
# Hoogh Mogende Gedepu teerden tot de Militaire faccken	     1
# Hoogh MogendefGedeputeerden tot de Milicaire faecken	     1
# Hoosh Mogende Gedeputeerden tor. de Militaire Taecken	     1
# Hoogh Mogende'Gedeputeerden tot de Militaire faecken	     1
# Hooeh Mogende Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot dé Militaire {aczken	     1
# Hoogh Mogende Ge. deputeerden to de Militaire faecken	     1
# Hoosh Morende Gedeputeerden tot de Militaire faechen	     1
# Hoogh Mogende Gedeputeerden vn de Militaire saecken	     1
# Hoogh Mogende Gedeputeerden tor de Militaire saecken	     1
# Hooch Mooende Gedeputeerden tor de Militire faecken	     1
# Hoosh Mogende Gedeputeerden tot ‘de Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot de Milataire {aecken	     1
# Hoogh Mogen1 Gedeputeerden tot de Militaire saecken	     1
# Hooch Movende Gedeputeerden tot de Milidire faecken	     1
# Hoogh Mogende Ge. deputeerden tot de Militaire seeken	     1
# Hoogh -Mogende Gedeputeerden tot 2de’ Militaire {aken	     1
# Hoogh Mogende Gedeputeerden to: de Militaire faecken	     1
# Hoogh Mogende Gedepateerden tot-de „Militaire faecken	     1
# Hoosh Moeende Gedeputeerden tot de Militaire faccken	     1
# Hoogh Mogende Ge‘deputeerden tot de Militaire {decken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {zecken	     1
# Hoogh Mogende Gedeputeerden tot de Militairefaecken	     1
# Hoogh Mogende Gedeputeerden tot de Misitaire saccken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire {aécken	     1
# Hoogh MOverde Cedenuteerden tot de Militaire saecken	     1
# Hoogh Moen de Gedenuteerden toe de Militaire saecee	     1
# Hoogh Mogende Gedeputéerden tot de Militaire {aecken	     1
# Hoogh Mog. Gedeputeerden tot de Militaire saken, on1	     1
# Hoooh Mogende Gedeputeerden tot de Militaire saëeken	     1
# Hóosh Mogende Gedeputeerden tot de Militaire {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Mi. itaine faccken	     1
# Hoogh Mogende Gedepuceerden tot de Militaire saecken	     1
# Hoogh Mogende Gedenuteerden tot de Militaire faecken	     1
# Hoogh Mo gende Gedeputeerden tot de Militaire saecken	     1
# Mo gende Gedeputeerden tot de Militaire saecken; om	     1
# Hool Moeende Gedeputeerden tot de Militiite saecken	     1
# Hoogh MogendeGedeputeerden tot de’ Militaire faecken	     1
# Hoogh Mogende Gedeputeerden tot de Militaire taccken	     1
# Hooch Mogende Gedeputeerden tot de Militaire saecken	     1
# Hoogh Mogende Ge deputeerden tot de Militaire faccken	     1
# Hoog Mo. gende Gedeputeerden tot de Militaire faecken	     1
# Mo. gende Gedeputeerden tot de Militaire faecken om	     1
# Hoog Mogende Gedeputeerden tot de Militaire saceken	     1
# Hoogh, Mogénde Gedeputeerden tot de Militaire faecken	     1
# Hoogh Mogerde Gedeputeerden tot de Militaire saecken	     1
# Hoogh Mogende Gedepureerden tot de Militaire saecken	     1
#
#
# Keyword: Hoogh Mogende Gedeputeerden tot de Buytenlandtsche saecken
# ------------------------------------
# Hoogh Mogende Gedeputeerden tot de Buytenlandtsche saecken	    36
# Mogende Gedeputeerden tot de Buytenlandtsche saecken , om	     8
# Hoogh Mogende Gedeputeerden tot de Buytenlandt{che faecken	     6
# Hoogh Mogende Gedeputeerden tot de Buytenlandesche saecken	     5
# Hoogh Mogende Gedeputeerden tot de Buytenlandtfche faecken	     5
# Hoogh Mogende Gedeputeerden tot de Buytenlandt{che faccken	     3
# Hoogh Mogende Gedeputeerden tot de Buytenlandefche faecken	     3
# Hoogh Mogende Gedeputeerden tot de Buytenlandifche faecken	     3
# Hoogh Mogende Gedeputeerden tot de Buytenlandt{che {aecken	     3
# Hoogh Mogende Gedeputeerden tot de buytenlandtsche saecken	     2
# Hoogh Mogende Gedeputeerden tot de Buytenlandtíche faecken	     2
# Hooeh Mogende Gedeputeerden tot de Buytenlandtsche saecken	     2
# Mogende Gedeputeerden tot de Buytenlandtsche saecken ‚ om	     2
# Mogende Gedeputeerden tot de Buytenlandtsche saecken ; om	     2
# Hoogh Mogende Gedeputeerden tot de Buytenlandtfche {aecken	     2
# Hoogh Mogende Gedeputeerden tot de Buytenlandiche faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtfche faccken	     1
# Hoogh Mogende Gedeputcerden tot de Buytenlandt{che  {aecken	     1
# Hoogh Mogeunde Gedeputeerden tot de BuytenInndt{che {aecken	     1
# Hooch Mogende Gedeputeerden tot de Buytenlandt{che faecken	     1
# Hooeh Movende Cedeputeerden tot de Buytenlande che saecken	     1
# Hoogh Mogende Gedeputeerden. tot de Buytenlandtfche {aecken	     1
# Hooch Mogende Gedeputeerden ‘tot de Buytenlandtfche faccken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlantfche faecken	     1
# Hooekh Mosende Gedeputeerdéh tot’de Buvtenlandtche fzecken	     1
# Hooeh Movende Gedeputeerden tot de buytenlandtsche saecken	     1
# Hoogh Mosende Gedeputeerden tor de Buytenlandtiche {zecken	     1
# Hoorh Mogende Gedeputeerden «ot de Buvtenlandt{che faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtfaccken, omte	     1
# Hoogh Moeende Gedeputeerden tot de Buytenlandesche saecken	     1
# Hoogh Mogende Gedeputeerden tot de Buyten: Jantfchefaecken	     1
# Hooch Morende Gedeputeerden tot "de Buvtenlan It{che decken	     1
# Hoogh, Mogende Gedeputeerden tot de Buytenlandt{che {accken	     1
# Hoogh Mogende Gedeputeerde tot de Buytenlandtfche {aecken	     1
# Hoogh Mogende Gedeputeerden tot de Búytenlandtfehe {acc ken	     1
# Hoogh: Mogende Gedeputeerden tor de Buytenlandtfche faccken	     1
# Hoogh Mogende Gedeputeerden tôt de Buytcmland{ehe f2ecken	     1
# Hoogh Mogen de Gedeputeerden tot de Buytenlandt{che faccken	     1
# Hoogh Movgende Gedeputeerden tor de Buytenlandu che laecken	     1
# Hoogh Mogende Gedeputeerden tot de’ Buytenlandtfche faecken	     1
# ‘Hoogh Mogende Gedeputeerden tot de Buytenlandifche faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlant(che faecken	     1
# Hoogh Mooende Gedeputeerden tot de buyzenlandtseche saecken	     1
# Mogende Gedeputeerden tot de Buytenlandtsche saecken 5 om	     1
# Hooch Mogende Gedeputeerden tot de buytenland. che faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buyten= landtíche {aken	     1
# Hoogh Mocende Gedeputeerden tot de Buytenlandt{che (iecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtiche faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buyten landt{che {aken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandt{che {accken	     1
# Hoogh’ Mogende Gedeputeerden tot de Buytenlandtfche faecken	     1
# Hoogh Mogende Gedeputeerden tot de BuytenJandt{che {aecken	     1
# Mogende Gedeputeerden tot de Buy. tenlandtsche saecken om	     1
# HWooeh Movende Gedeputeerden tot de Buyvenlandesche saecken	     1
# Hoogh Mogende ‘Gedeveteerden tot de Buytenlandt{che {aecken	     1
# Hooeh Mogende Gedeputeerden tot de Buvtenlandtsche saecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtsche siecken	     1
# Hoogh Mogende Gedevuteerdén tor de Buytenlanditche faecken	     1
# Hooeh Mogende Gedevuteerden tot de Buytenlandtsche saecken	     1
# Hoogh Moeende Gedeputeerden tot de Buytenlandt{che faccken	     1
# Hooeh Mogende Gedenuteerden tot de Buytenlandtsche saecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytesslandtsche saecken	     1
# Hoogh Movgende Gedeputeerden tot de Buytenlandtsche saecken	     1
# Movgende Gedeputeerden tot de Buytenlandtsche saecken, om	     1
# Hoogh Mooende Cedepugeerden tot de Buytenlandtshe saecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtsche laecken	     1
# Hoosh Mogende Gedeputeerden tot de Buytenlandtsche saecken	     1
# Hooeh Mogende Gedeputeerden tot défBiytenlandttche faecken	     1
# Hoogh Mosegde Gedeputeerden tot de Buytenlandtfche ficken	     1
# Hoogh Mogende Gedcputeerdcn téfiide Buyrenlandesche faecken	     1
# Hoogh Mosende Gedeputeerden tot de Buytcnlandr{eht fiecken	     1
# Hoogh Mooende Gedeputeerden tot de Buytenlandtfche laecken	     1
# Hoogh Mogende Gedeputeerden toz de Buytenlandifche {accken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtlche (laecken	     1
# Hoogh Mogende Gedeput®@rden tot de Buytenlandtfche faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buycenland{che taecken	     1
# Hoogh Mogende Gedeputeerden tot de Buyvtenlandesche saecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandt. Íche aken	     1
# Hoogh Mog. Gedeputeer. den tot de Buytenlandefche {accken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtfche Íaecken	     1
# Hoogh Movende Gedeputeerden tot de Buytenlandesche saecken	     1
# Hoogh Mogende Gedeputeerden tot de Buyrenlandt(che faecken	     1
# Hoosh Mogende Gedeputeerden tot de Buytenlandt(che faecken	     1
# Hoosh Mogende Gedeputeerden tot de Buvtenlandt{che faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buvtenlandtíche faecken	     1
# Hooeh Mogende Gèdepù: eerden tot de Buytenlaadtfche faccken	     1
# Mogende Ge. deputeerden tot de Buytenlandtsche saecken om	     1
# Hoodh Mooende Gedeputeerden tor de Buytenlandtsche saecken	     1
# Hoogh Mogende Gedepueeerden tot de Buytenlandtfche faecken	     1
# Hoogh Mogende Gedeputeerden tot de Butenlandtfche {aecken	     1
# Hoogh Mogende Gedevuteerden tot de Buytenlandtíche fatcken	     1
# Hoogh Moeende Gedeputeerden tot de Buytenlandtsche saecken	     1
# Hoogh Mogen. de Gedeputeerden tot de Buytenlandt{che {a ken	     1
# Hoogh Mogende Gedeputeerden tot de Buytefilandtfche faecken	     1
# Hoogh Mòvende Gedevuteerden tot de Buytenlandtíche Zen om	     1
# Hoogh Mogende Gedepureerden tot de Buytenlandt{che’ faecken	     1
# Mogende Gedeputeerden tot de Buytenlandtsche saecken 2 om	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandt (che {1ecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtche faecken	     1
# Hloogh Mogende Gedeputeerden to: de Buytenlandtíche {aecken	     1
# Hoogh Mogende Gedepureerden tot de Buytenlandtche laecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtche faken ‚*	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlendtsche saecken	     1
# Hoogh Mogende Gedeputeerden tot ‘de Buytenlandefche-{faken	     1
# Hoogh Mogende Gedeputecrden tot de Buyjtenlandtfche faecken	     1
# Hoogh Mogendé Gedeputeerde tot de Buytenlandt(che faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtíche faccken	     1
# Hoogh Mogende Gedeputeerden ì orde Buyten landtsche siecken	     1
# Hooeh Mooende Gedeputeerden tot de Buytenlandtsche saecken	     1
# Hoog Mogende Gedeputeerden tot de Buytenlandefche fiecken	     1
# Hoógh Mogende Gedeputeerden tot ‘de Buytenlandt(che faecken	     1
# Hoogh Mogende' Gedeputeerden tor‘de Buyténlandtfe facëken	     1
# Hoogh Mogende 'Gedeputeerden tot de Buytenlandrfche fiecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenlandtlche faecken	     1
# Hoogh Mogende Gedeputeerden tot de Buytenland:{che {accken	     1
# Hoogh Moeende Gedeputeerden tot de Buytenlandt{che {aecken	     1
# Hoogh Mogende Gedepüteerden ‘tot de Buytenlandtfche fiecken	     1
# ooh Moe ende Gedeputeerden tot de Buytenlnid sche sac. ken	     1
