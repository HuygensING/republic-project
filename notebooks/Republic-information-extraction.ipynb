# %% [markdown]
# # Republic frase modellen
#
# Doel:
#
# - informatie extractie uit de resoluties, gebruik makend van de repetitieve aspecten van de teksten, formulaische uitdrukkingen, signaalwoorden en onderwerpstermen.
# - het opbouwen van collectie-specifieke frase-modellen (lijstjes met termen en frasen, varianten daarvan en metadata categorieën en labels) zodat we informatie kunnen extraheren en om kunnen vormen tot inhoudelijke metadata voor ontsluiting van de individuele resoluties.
#
# Aanpak: harvesting phrases o.b.v. frequentielijsten
#
# Overlap/verschil tussen jaren:
#
# - tussen twee opvolgende jaren
# - tussen twee jaren met een decennium ertussen
# - tussen twee jaren met X jaren ertussen
#
# Overlap tussen resoluties en respectenlijsten:
#
# - in hoeverre komen termen uit de respecten letterlijk voor in de resoluties?
# - vergelijk e.g. automatische extractie en respecten. Dit vergt ook interactie met Team Text en hun NER activiteiten
#
# ## Overlap analyseren
#
# **doel:** bepalen welke termen structureel vaak voorkomen en hoe ze kunnen worden gebruikt om de inhoud van resoluties te analyseren
#
# Lijstjes:
#
# - hoedanigheden, rollen (ambassadeur, graaf, suppliant)
#     - dit kan gebruikt worden om o.a. persoonsnamen te spotten (dus nuttig voor NER trainen of resultaten opschonen)
#     - signaalwoorden/-frasen:
#         - <ambassadeur> in, uit, van, bij <land/hof>
#         - uit, naar, tot, te <plaats>
#         - gecommiteerd/commissie
# - documenten:
#     - Placaat
#     - Rapport
#     - Paspoort
# - onderwerpen:
#     - financiën
#     - rechten

# %%
# This reload library is just used for developing the REPUBLIC hOCR parser 
# and can be removed once this module is stable.
# %reload_ext autoreload
# %autoreload 2


# This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
repo_name = 'republic-project'
repo_dir = os.path.split(os.getcwd())[0].split(repo_name)[0] + repo_name
print(repo_dir)
if repo_dir not in sys.path:
    sys.path.append(repo_dir)
# Out:
# /Users/marijnkoolen/Code/Huygens/republic-project

# %%
# Laad de benodigde modules in
import re
import json
from collections import Counter
from collections import defaultdict
from typing import Union
from republic.model.inventory_mapping import get_inventory_by_num
from republic.config.republic_config import base_config, set_config_inventory_num
import republic.elastic.republic_elasticsearch as rep_es

# Een handige 'Key Word In Context' functie om keywords/frasen en omringende tekst te zien
def get_keyword_context(text: str, keyword: str, 
                        context_size: int = 3, 
                        prefix_size: Union[None, int] = None, 
                        suffix_size: Union[None, int] = None):
    if not prefix_size:
        prefix_size = context_size
    if not suffix_size:
        suffix_size = context_size
    text = re.sub(r'\s+',' ', text)
    prefix_pattern = r'(\w*\W*){' + f'{prefix_size}' + '}$'
    suffix_pattern = r'^(\w*\W*){' + f'{suffix_size}' + '}'
    contexts = []
    for match in re.finditer(r'\b' + keyword + r'\b', text):
        prefix_window = text[:match.start()]
        suffix_window = text[match.end():]
        prefix_terms = prefix_window.strip().split(' ')
        suffix_terms = suffix_window.strip().split(' ')
        prefix = ' '.join(prefix_terms[-prefix_size:])# re.search(prefix_pattern, prefix_window)
        suffix = ' '.join(suffix_terms[:suffix_size])# re.search(suffix_pattern, suffix_window)
        context = {
            'keyword': keyword,
            'prefix': prefix,
            'suffix': suffix,
            'keyword_offset': match.start(),
            'prefix_offset': match.start() - len(prefix),
            'suffix_offset': match.end()
        }
        contexts.append(context)
    return contexts


es_republic = rep_es.initialize_es(host_type='external', timeout=60)

# %%
# kies een inventaris nummer om te doorzoeken
inv_num = 3825
# de base_dir is niet relevant maar wel nodig voor het maken van een config object
base_dir = "/Users/marijnkoolen/Data/Projects/REPUBLIC/"
# genereer een config object voor het specifieke inventaris nummer dat je wilt doorzoeken
inv_config = set_config_inventory_num(inv_num, ocr_type='pagexml')

# haal alle paragraphs van het inventaris op uit de index
#docs = rep_es.retrieve_paragraphs_by_inventory(es_republic, inv_num, inv_config)
paragraph_index = 'pagexml_meeting_paragraphs'
query = {'query': {'match': {'metadata.inventory_num': inv_num}}, 'size': 10000}
response = es_republic.search(index=paragraph_index, body=query)
docs = [hit['_source'] for hit in response['hits']['hits']]

print('number of paragraphs:', len(docs))

if len(docs) > 0:
    # hoe ziet een paragraph document eruit?
    print(json.dumps(docs[0], indent=4))
# Out:
# number of paragraphs: 4408
# {
#     "metadata": {
#         "textregion_id": "NL-HaNA_3825_0088-page-175-col-0-tr-0",
#         "inventory_num": 3825,
#         "scan_num": 88,
#         "scan_id": "NL-HaNA_3825_0088",
#         "page_num": 175,
#         "page_id": "NL-HaNA_3825_0088-page-175",
#         "column_index": 0,
#         "column_id": "NL-HaNA_3825_0088-page-175-col-0",
#         "meeting_date": "1770-01-01",
#         "meeting_id": "meeting-1770-01-01-session-1",
#         "id": "NL-HaNA_3825_0088-page-175-col-0-tr-0",
#         "scan_type": "pagexml",
#         "page_type": "resolution_page"
#     },
#     "coords": {
#         "left": 2423,
#         "right": 3306,
#         "top": 3004,
#         "bottom": 3167,
#         "height": 163,
#         "width": 883
#     },
#     "lines": [
#         "NL-HaNA_3825_0088-page-175-col-0-tr-0-line-0",
#         "NL-HaNA_3825_0088-page-175-col-0-tr-0-line-1",
#         "NL-HaNA_3825_0088-page-175-col-0-tr-0-line-2"
#     ],
#     "text": "Tumeert en. te\u00fbrrefteert  zvn>:de;dDepsches daat iuit refulteerendg coicnimnll snsebop bil 9e: caisse ob nav ToslmesVl 294 "
# }

# %% [markdown]
# ## Simpele frequentielijsten
#
# Een eerste stap is kijken wat de frequente woorden zijn in de resoluties van een specifiek inventaris.
#
# In de resoluties beginnen veel domeinspecifieke inhoudstermen met een hoofdletter. Dat is een goed eerste filter om inzicht te krijgen in de inhoud.

# %%
# maak een nieuwe counter aan
term_freq = Counter()

# itereer over all documenten (= paragraphs)
for doc in docs:
    # splits de tekst op alles wat geen alpha-numerical character is
    terms = re.split(r'\W+', doc['text'])
    # een 'list comprehension' om termen te filteren die met een hoofdletter te beginnen
    terms = [term for term in terms if term != '' and term[0].isupper()]
    # update de counter met de lijst van termen in dit document
    term_freq.update(terms)

# print een overzicht van de 100 meest frequente termen
for term, freq in term_freq.most_common(100):
    # print term (links uitgelijnd met een breedte van 30 karakters) en frequentie (rechts uitgelijnd met 6 karakters)
    print(f'{term: <30}{freq: >6}')
# Out:
# Hoog                            5856
# Mog                             5442
# Heeren                          2277
# WAAR                            1926
# Heere                           1476
# Dat                             1307
# Provincie                       1197
# Gedeputeerden                   1049
# Suppliant                       1004
# Vergaderinge                     961
# Ntfangen                         960
# Raad                             933
# Hof                              887
# Missive                          804
# Stad                             798
# En                               749
# Supplianten                      693
# Refolutie                        678
# Staaten                          672
# Resolutie                        633
# Mos                              623
# Copie                            587
# Staate                           579
# Admiraliteit                     572
# Requeste                         548
# Mogende                          546
# Lynden                           526
# Zeeland                          518
# E                                497
# Koning                           496
# Holland                          473
# Miflive                          470
# Collegie                         467
# Requefte                         450
# Miffive                          448
# S                                429
# Scheepen                         425
# Hoogheid                         423
# Envoyé                           421
# Van                              419
# Lande                            418
# A                                411
# Grave                            404
# Provincien                       393
# Schip                            393
# Edele                            389
# Heer                             372
# Staat                            365
# De                               359
# Gecommitteerden                  357
# Goederen                         334
# Vriesland                        329
# Landen                           328
# J                                308
# Majefteit                        308
# Generaal                         306
# Mey                              302
# Majesteit                        284
# P                                270
# Den                              263
# Mr                               253
# Gedeputeerde                     252
# Lands                            250
# B                                247
# April                            245
# Land                             245
# Gelderland                       237
# Plenipotentiaris                 235
# Depeches                         235
# Maart                            231
# Ingezeetenen                     231
# Hoos                             229
# Colonie                          227
# Collegien                        226
# D                                225
# Bergsma                          219
# Hemmen                           213
# December                         212
# Meyerye                          210
# IS                               208
# Pasport                          208
# Steyn                            208
# July                             207
# Refolutien                       206
# November                         205
# Zee                              205
# Jan                              204
# Placaat                          198
# Sloet                            198
# Fagel                            192
# I                                192
# Compagnie                        191
# Generaliteits                    190
# R                                186
# Haer                             185
# Suppliants                       185
# Groot                            184
# Generaliteit                     182
# Cau                              180
# January                          179

# %% [markdown]
# Termen hoeven geen individuele woorden te zijn, maar kunnen ook woord bi-grammen of groter woord n-grammen zijn.

# %%
# maak een nieuwe counter aan
term_freq = Counter()

ngram_size = 3

# itereer over all documenten (= paragraphs)
for doc in docs:
    # splits de tekst op alles wat geen alpha-numerical character is
    terms = re.split(r'\s+', doc['text'])
    # creeër ngrammen door elk woor te verbinden met de n-1 opvolgende woorden
    ngram_terms = [' '.join(terms[ti:ti+ngram_size]) for ti, term in enumerate(terms[:-(ngram_size-1)])]
    # een 'list comprehension' om termen te filteren die met een hoofdletter te beginnen
    terms = [term for term in ngram_terms if term != '' and term[0].isupper()]
    # update de counter met de lijst van termen in dit document
    term_freq.update(terms)

# print een overzicht van de 100 meest frequente termen
for term, freq in term_freq.most_common(100):
    # print term (links uitgelijnd met een breedte van 30 karakters) en frequentie (rechts uitgelijnd met 6 karakters)
    print(f'{term: <30}{freq: >6}')
# Out:
# WAAR op gedelibereert            806
# WAAR op geen                     642
# Ntfangen een Missive             364
# Copie van de                     358
# Missive van den                  349
# Gedeputeerden van de             303
# Gedeputeerden tot de             300
# Heeren Gedeputeerden van         294
# Heeren Staaten van               279
# Raad van Staate                  251
# Resolutie van den                235
# Hoog Mog. te                     228
# Miffive van den                  226
# Hoog Mog. Gedeputeerden          223
# Mog. Gedeputeerden tot           218
# Collegie ter Admiraliteit        205
# Raad van Staate,                 203
# Refolutie van den                202
# Vergaderinge rapport te          190
# Depeches daar uit                184
# Hof van fijne                    181
# Majesteit den Koning             166
# Envoyé aan het                   162
# Miflive van den                  157
# Heeren van Lynden                156
# Majefteit den Koning             155
# Ntfangen een Miffive             153
# Gedeputeerde uit de              151
# Hof van sijne                    149
# Hoog Mog. Refolutie              147
# Vergaderinge geleefen de         146
# Sloet tot de                     142
# Hoog Mog. Resolutie              142
# Hoog Mog. extraordinaris         141
# De Heeren van                    134
# Provincie van Holland            134
# Ntfangen een Miflive             126
# Mog. extraordinaris Envoyé       123
# IS na voorgaande                 120
# Gecommitteerden uit den          120
# Provincie van Vriesland.         117
# Vergaderinge geleesen de         115
# Hof van haare                    113
# Mog. Resolutie van               113
# Gedeputeerden uit de             113
# Hoog Mog. aan                    112
# Mog. Refolutie van               112
# Heeren Gecommitteerden uit       109
# Plenipotentiaris aan het         104
# Heere Grave van                   99
# Admiraliteit op de                98
# Meyerye van ’s                    95
# Lynden tot Hemmen,                92
# S ter Vergaderinge                90
# Hoog Mog. Minifter                88
# Staaten van de                    85
# TS ter Vergaderinge               85
# Griffier Fagel, houdende          77
# Envoyé en Plenipotentiaris        75
# Collegien ter Admiraliteit        75
# Hoogheid den Heere                74
# Hoog Mog. Minister                72
# Staate, by haar                   72
# Van Palland tot                   71
# Provincie van Zeeland             69
# Hoog Mog. in                      67
# Holland en Westvriesland          67
# Staaten van Holland               66
# Hoog Mog. hem                     65
# Mog. te laaten                    64
# Placaat van den                   63
# Hoog Mog. de                      63
# E, Den Heere                      63
# Vergaderinge van haar             63
# Generaal van de                   61
# Grave van Welderen,               61
# Staaten van hooggemelde           61
# Extract van deese                 60
# Hoog Mog. den                     60
# Prins Carel van                   59
# Stad en Lande                     59
# Heere Prince van                  58
# Gecommitteerden uit de            57
# Hoog Mog. by                      56
# Dat haar Hoog                     56
# Staate en de                      55
# Lynden tot Hemmen                 55
# Welderen, haar Hoog               55
# En is dien                        55
# Hoog Mogende Resolutie            55
# Hoog Mog. daar                    55
# Provincie van Gelderland.         54
# En sal Extract                    53
# Hoog Mogende extraordinaris       53
# Hoogheid Prins Carel              52
# Prince van Orange                 52
# U S, De                           51
# Mogende extraordinaris Envoyé     51
# Pasport in behoorlyke             49
# Grave van Degenfeld               49

# %% [markdown]
# ## Zoeken met Keywords
#
# Als je interessante woorden/ngrammen hebt gevonden, kun je ze in context zoeken om te kijken wat frequente frasen zijn.

# %%
# maak counters voor de tekst voorafgaand en volgend op een keyword
prefix_freq = Counter()
suffix_freq = Counter()

# zomaar een lijstje veel voorkomende woorden/frasen
term = 'Schip'
term = 'Collegie'
term = 'Gecommitteerden'
term = 'Regiment'
term = 'Regenten'
term = 'Pafport'
term = 'Placaat'
term = 'ophef'
term = 'Raad'
term = 'Hoogh Mogende extraordinaris'
term = 'Collegie ter Admiraliteyt'
term = 'Heeren Gedeputeerden van'
term = 'Generaliteyts Reeckenkamer'
term = 'Compagnie'
term = 'Magistraet' # van
term = 'Ambaffadeur' # (van|aan het hof van|tot)
term = 'Hoog Mog. Gedeputeerden'
term = 'Hoog Mogende Gedeputeerden'
term = 'Edele Mog. Gecommmitteerden'
term = 'Edele Mogende Gecommmitteerden'
term = 'en andere haar Hoog Mog. Gedeputeerden'
term = 'van de Heeren'
term = 'van de Heeren Staaten'
term = 'en andere haar'
term = 'Staaten van'
term = 'Groningen en Ommelanden'
term = 'de Provincie van'
term = 'Heeren'
term = 'gefchreeven te' # followed by location
term = 'Ntfangen een Missive van'
#term = 'met een extraordinaris Gedeputeerde uit'



# itereer over de documenten
for doc in docs:
    # zoek de term en bijbehorende context op in het document
    for context in get_keyword_context(doc['text'], term, context_size=4):
        # tel hoe vaak elke prefix/suffix voorkomt
        prefix_freq.update([context['prefix']])
        suffix_freq.update([context['suffix']])
    
# toont een overzicht van de meest frequente prefixes en suffixes
for prefix, freq in prefix_freq.most_common(10):
    print(f'{prefix: <30}{freq: >6}')

print('\n')

for suffix, freq in suffix_freq.most_common(100):
    print(f'{suffix: <30}{freq: >6}')

staten = [
    'Holland en Westvriesland',
    'Vriesland',
    'Overyssel',
    'Zeeland',
    'Utrecht',
    'Stad en Lande',
    'Stad Groningen en Ommelanden',
    'Gelderland'
]
# Out:
#                                  132
# geen resolutie is gevallen.       12
# a                                  7
# ‚                                  5
# A                                  5
# resolutie is gevallen. 5           3
# u                                  3
# »                                  3
# 1                                  3
# t                                  3
#
#
# den Heere J Grave                 22
# den Heere JJ Grave                10
# den Heere J Lestevenon             8
# den Heere J van                    5
# de Heeren J Staaten                5
# den SecreJ taris van               5
# den Heere XJ Grave                 4
# den Heere JI Grave                 4
# het Collegie ter Admiraliteit      4
# den Heere J Hop                    3
# den Heere XJ van                   3
# den ConJ sul de                    3
# den Heere Grave van                3
# den SeereJJ taris van              3
# den Secre. J taris                 3
# het Colle. gie ter                 2
# den Heere LJ Geelvinck,            2
# den Heere LJ Grave                 2
# Burgermeester en Scheepenen der     2
# de Heeren JV Staaten               2
# de Heeren Staaten van              2
# den Raad J van                     2
# den Heere XJ Lestevenon            2
# den Heere JV Lestevenon            2
# den Heere J Saurin                 2
# het ColleJ gie ter                 2
# den Heere XJ Gallieris,            2
# den Consul J Gildemeester          1
# den Heere Hop ‚                    1
# C. H. Jun, kers,                   1
# den Confut geschreeven te          1
# den ComJ mis Generaal              1
# het Colleee Admiraliteit in        1
# den Heere J GCaullieris,           1
# den LieuteJ nant- Drossard         1
# de CommisJ arissen Instructeurs     1
# A. la ForJ me,                     1
# den SeecreJ taris Bosch,           1
# 3. IW. D. de                       1
# den Heere J Leste                  1
# den Heere J Gallieris,             1
# den Heere J op,                    1
# den Heere J Gall                   1
# den SeereJ ris de                  1
# den Heere IT stevenon              1
# den Heere AJ Graué                 1
# den Heere Lestevenon van,          1
# den Secre7, taris van              1
# den Heere 7 {                      1
# den ConJ sal Ellinckhuysen,        1
# den Heere -{ Mogende               1
# den Consul XJ Generaal             1
# den Consul Gildemeester, geschreven     1
# de Heeren XV Staaten               1
# & JV Gesner ,                      1
# Johan Nico. JJ laas                1
# een nonim Persoon, geschreeven     1
# den Heere | XJ                     1
# den Heere JJ Lestevenon            1
# den Heere A Grave                  1
# den Seere. JJ taris                1
# den Heere q O                      1
# den Heere J Grau;                  1
# sijne HoogJ beid den               1
# Johan Rau, i Meester               1
# Dhefteun en JV Raaden              1
# Job. Anth. Winckler, geschreven     1
# . W. van JV                        1
# den Heere JJ Isstevenon            1
# den Heere & van                    1
# den Heere 19 Geelvinck,            1
# den Repre‚ sentant van             1
# Johan Chris. tiaan Risbitter       1
# den Heere J Ceelvinck,             1
# den Heere AJ Crave                 1
# den Heere 7 Grave                  1
# de Heeren UJ Gedeputeerde          1
# den Heere | CJ                     1
# de Heeren 7 Cedemteerde            1
# de Heeren AJ Staaten               1
# de Het en 7)                       1
# . de Heeren J                      1
# de Heeren WJ Gedeputeerde          1
# de Heeren -) Staaten               1
# de Heeren JJ Staaten               1
# de Heeren LJ Gedeputeerde          1
# het Colle\J gie ter                1
# Directeur en Vi Raaden             1
# den Heere ( J                      1
# den ConJD sul de                   1
# den Heere J Gallierie,             1
# den SeereJ taris van               1
# de Heeren CH staaten               1
# den Heere J Bose                   1
# den eere van Haeften.              1
# den Heere ; Geelvinck              1
# de Heeren J Gedeputeerde           1
# Bailliuw , / Burgermeester         1
# den eere / Crate                   1
# den Heere JJ Saurin                1

# %%
patterns = [
    {
        'type': 'infix_template',
        'label': 'single_person',
        'start': 'van den Heere',
        'end': ' haar Hoog',
        'infix_max_chars': 40
    },
    {
        'type': 'infix_template',
        'label': 'multiple_persons',
        'start': 'van de Heeren',
        'end': 'en andere haar Hoog',
        'infix_max_chars': 40
    },
    {
        'type': 'suffix',
        'start': ['Staaten van hooggemelde Provincie', 'Staaten van', 'Staaten van de Provincie van']
    },
    {
        'type': 'infix_template',
        'label': 'prev_date_curr_month',
        'start': 'den',
        'end': 'deeser loopende maand',
        'infix_max_chars': 5
    },
    {
        'type': 'infix_template',
        'label': 'prev_date_prev_month',
        'start': 'den',
        'end': 'der voorleeden maand',
        'infix_max_chars': 5
    },
    {
        'type': 'suffix',
        'start': 'Heeren',
        'end_distractors': [
            'Gedeputeerde',
            'Gecommitteerde',
            'Staaten'
        ]
    }
]

def get_infix_context(infix_pattern, text):
    regex = infix_pattern['start'] + r'\b(.{,' + str(infix_pattern['infix_max_chars']) + r'})\b' + infix_pattern['end']
    for match in re.finditer(regex, text):
        yield match.group(1)

infix_pattern = patterns[2]
term = 'van de Heeren'
infix_freq = Counter()
# itereer over de documenten
for di, doc in enumerate(docs):
    #print(doc['text'])
    # zoek de term en bijbehorende context op in het document
    for context in get_infix_context(infix_pattern, doc['text']):
        infix_freq.update([context])

# toont een overzicht van de meest frequente prefixes en suffixes
for prefix, freq in infix_freq.most_common(10):
    print(f'{prefix: <30}{freq: >6}')

print('\n')
# Out:
#  18                               11
#  6                                11
#  9                                 9
#  8                                 8
#  12                                8
#  5                                 8
#  II                                8
#  16                                7
#  4                                 6
#  22                                6

# %% [markdown]
# ## Fuzzy zoeken
#
# Omdat er allerlei OCR fouten en spellingsvarianten voorkomen van een keyword/frase, mis je met exact zoeken allerlei voorkomens. De Fuzzy search module biedt mogelijkheden om inexact te zoeken naar tekst strings die lijken op een geven set van keywords/frasen.
#
# In de configuratie kun je aangeven hoeveel een string van een keyword mag afwijken om als match te tellen.

# %%
# importeer de fuzzy keyword searcher class en de phrase model class
from republic.fuzzy.fuzzy_keyword_searcher import FuzzyKeywordSearcher
from republic.fuzzy.fuzzy_phrase_model import PhraseModel

# configuratie van de fuzzy searcher
fuzzy_search_config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
}

# creeër een nieuwe fuzzy searcher met bovenstaande configuratie 
fuzzy_searcher = FuzzyKeywordSearcher(fuzzy_search_config)


# keywords mag een lijst van strings zijn:
keywords = [
    'Raad van Staate',
    'Ambaffadeur aan het hof van',
    'Generaliteyts Reeckenkamer'
]

# of je kunt per keyword extra gegevens toevoegen:
# 'variants': variante voorkomens die je onder hetzelfde keyword wilt tellen
# 'label': een categorizerend label
# 'distractors': keywords die qua tekst-afstand op het keyword lijken maar toch echt iets anders zijn
keywords = [
    {
        'keyword': 'Raad van Staate',
        'variants': [
            'Raedt van State'
        ],
        'label': 'raad'
    },
    {
        'keyword': 'Hoogh Mogende Gedeputeerden tot de Militaire saecken',
        'label': 'gedeputeerden'
    },
    {
        'keyword': 'Hoogh Mogende Gedeputeerden tot de Buytenlandtsche saecken',
        'label': 'gedeputeerden',
        'variants': [
            'Hoog Mog. Gedeputeerden tot de buitenlandsche saaken'
        ]
    },
    {
        'keyword': 'Ambassadeur aan het hof van',
        'label': 'ambassadeur',
        'variants': [
            'Ambassadeur van hare'
        ]
    },
    {
        'keyword': 'Generaliteyts Reeckenkamer',
        'label': 'organisatie'
    }
]

# transformeer je lijst met keywords in een phrase model
phrase_model = PhraseModel(model=keywords)
# indexeer de keywords uit het phrase model met de fuzzy searcher
fuzzy_searcher.index_keywords(phrase_model.get_keywords())
# indexeer eventuele varianten van de keywords
fuzzy_searcher.index_spelling_variants(phrase_model.variants)

# %%
import json

# itereer over de documenten
for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = fuzzy_searcher.find_candidates(doc['text'], use_word_boundaries=True, include_variants=True)
    # check of er matches zijn en print de tekst en de match objecten
    if len(matches) > 0:
        print(doc['text'])
        for match in matches:
            print(json.dumps(match, indent=4))
        break
# Out:
# derfeeft van St. ’Cätharina, ‘en de inaugura tie van dênieu we Ridderorder van St. George, haar Hoog Mog. permiffie om de koften daat van ‘in declaratie te brengen. WAAR op gedelibereert zynde, is goed gevonden en verftaan ‚ dat aan gemelde Îleere Grave van Rechteren fal worden gerefcribeert, dat haar Hoog Mog. 2an-hem permitteeren om de kolten van’ gemelde [Ilaminatien te mogen brengen ín fijne. De: catatúie, alwaar defelve aan hem fullen worTs 9755 Dogs den gevalideert. En fal Extra van deefe haar Hoog Mog. Refolutie gefonden worden aan den Räad van Staate en de Generaliteit ReeKenkamer, om te {trekken tot der {elver narigtinge. eb: Rn Ntfansen een Miffive van den Heere CN Bijchop en Purft te Paderborn; ge fchreeven te Neuhaus den 20 der voörleeden maand, houdéhde een Nieuwe: jaarswenfch. WAAR ‘op gedelibereert zynde, is goedgevonden en verftaan, dat de vooffë’ Mis. five met een Röfcriptie in civilé ‘termen {àl boshotr sb ge worden beantwoord. En Heer Bergsma; ‘ter Vergaderinge EJ orefidezrende, heeft aan haar Hoog Mos, ‘vöorgedraagef ‘en’ bekent ‘ge maakt, dat den Heer van “Heeckeren van Brantfenburg , ’by haar Hoog Mos. 'Refolutie‘van den 27 der voorleeden maand’ aaf: gefteld tot der {elver extraórdinaris ‘Envoyé en Plenipotentiaris: aan‘ het Hof van Spagoe, by Hem was geweeft,- om  kéfinis / te ‘geeven dat hy de voorfz Commiflie met dank: fegging accepteerde; dat hy fig géreed {oude maaken de reife derwaards {00- ras: doenlyk áán te neemen, maar dewyl’ nög’”èenigen tyd daar toe vereifcht foude worden, en dftueel niemand fig ‘in Spagte bevond die de faaken vanden Staat waarnam; hy aan haar:Hoog; Mog. in bedenken’ moett gee. ven, of Hoogitdefelven ook fouden kunnen goedvinden den Perfoon van Godfried: Eyland, welke hy: als Secretaris hadde aangenoomen, ‘vooraf derwaards te”fenden, en, by aldien het felve- dienftig mogten oordee: lem, ‘of niet “alsdan” geregulcert’ foude kunmen worden den voet op: welke ‘hy de faakenr”aldaar tor op de aankomft ‘van’ hem Heer extraordinaris Envoyé {oude waarnecmensa (13 nBsbss ze7iosM sb 1004 WAAR ‘op’ gedelibereert zynde; is goed: gevonden en verftaan,:dat: Copie van: het ‘voorfthreeve geproponeerde gefteld. {al wor: den in hande van de Heeren ván Lyn:
# {
#     "match_keyword": "Raad van Staate",
#     "match_term": "Raad van Staate",
#     "match_string": "R\u00e4ad van Staate",
#     "match_offset": 549,
#     "levenshtein_distance": 0.9333333333333333,
#     "char_match": 0.9333333333333333,
#     "ngram_match": 0.875
# }

# %%
# creeër counters voor de varianten van elk keyword
variants = defaultdict(Counter)

# itereer over de documenten
for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = fuzzy_searcher.find_candidates(doc['text'], use_word_boundaries=True, include_variants=True)
    # voor elke match, tel de matchende string als variant van het matchende keyword
    for match in matches:
        variants[match['match_keyword']].update([match['match_string']])

# toon voor elk van de gevonden keywords een overzicht van de meest frequente varianten
for keyword in variants:
    print('Keyword:', keyword)
    print('------------------------------------')
    for variant, freq in variants[keyword].most_common():
        print(f'{variant: <20}\t{freq: >6}')
    print('\n')
# Out:
# Keyword: Raad van Staate
# ------------------------------------
# Raad van Staate     	   477
# Raad van State      	    14
# Raad van Staat      	     5
# Raad van’ Staate    	     5
# Raad van Staaté     	     4
# Raad’ van Staate    	     4
# Generalitcits Reekénkaamer	     1
# Ge neraliteits Reekenkamer	     1
# Generaliteits Ree. kenkamet	     1
# Generaliteits Ree. Kenkamer	     1
# Geweraliteits Reekénkamer	     1
# Generaliteics Reekenkaamer	     1
# Generatiteits Reekenkamer	     1
# Generaliteits Rebkerkamer	     1
# Generzliteits Reekenkamer	     1
# Generaliteits Reekerikaamer	     1
# Generaliteits  Reekenkaamer	     1
# Generaliteits Ree. kenkamer	     1
# Generaliteits Reekenkamer’	     1
# Generaliteit. Reekenkamer	     1
# Generaliteit i Reekenk amer	     1
# Ges neraliceits Reekenkamer	     1
# Generaliteirs Reekenkamer	     1
# Gencraliteits Reekenkamer	     1
# Generaliteits Reêkenkamer	     1
# Generaliteits’ Reekenkamer	     1
# Generzliteits Reekeikamer;	     1
# Generaliteits Reeken: kamer	     1
# Generaliteits * Reekenkamer	     1
# Generaliteits  Reekenkamer	     1
# Generaliteits Reekénkamer	     1
# Gencraliteits Reeken. kamer	     1
# Generaliteite Reekenkamer	     1
# Generalitcits Reelkenkaamer	     1
# Gencraliteits: Reekenkamer	     1
# Gencraliteits Reckenkaamer	     1
# Generaltteits Reekenkamer	     1
# Generalircits Reekenkaamer	     1
# Generaliteits Reeken‘amer	     1
# Generaiiteits Reckenkamer	     1
# Genera. liteits Reekenkamer	     1
# Genetaliteits Reekenkamer	     1
# Generaliteitss Reekenkamer	     1
# Generaliteits ReeKenkdamer	     1
# Generalitêits’ Roekenkamer	     1
# Generali. teits Reekenkamer	     1
# Gencraliteits. Reckenkaamer	     1
# Generaliteits Reeken‘kamer	     1
# Generaliteits Reekenkaame	     1
# Generaliteits Reekenkaa mer	     1
# Ceneraliteits Reeken. kamer	     1
# Generaliteits Reekenk4mer	     1
# Generüliteits Ree. kenkam?r	     1
# Generali teïts Reekenkamer	     1
#
#
# Keyword: Ambassadeur aan het hof van
# ------------------------------------
# Ambassadeur aan het Hof van	    34
# Ambaffadeur aan het Hof van	    13
# Ambafladeur aan het Hof van	     9
# AmbafTadeur aan het Hof van	     5
# Ambassadeur van den 	     5
# Ambassadeur van sijne	     5
# Ambassadeur aan het Hos van	     3
# Ambafladeur aan het Hot van	     2
# Ambassadeur aan het Hot van	     2
# Ambafladeur aan bet Hof van	     2
# Ambalfadeur aan het Hof van	     2
# Ambafladeur -aan‘het Hof van	     1
# Ambafladeur aan het, Hof van	     1
# Aanbassadeur aan het Hof van	     1
# Ambassadeur aan het 	     1
# Ambafladeur aan het Hof vau	     1
# Ambaffadeur aan hét Hof wan	     1
# Ambafladeur aan het Hof. van	     1
# Ambasfadeur aan het Hof van	     1
# Ambaffadeur ‘aan bet Hof van	     1
# Amibaffadeur aan het Hof van	     1
# AmbafTadeur -aanhet Hof van	     1
# Amballadeur aan het Hof van	     1
# Ambafladeur aan:het Hof van	     1
# Ambaffadeuf aan het Hof van	     1
# Ambafladeur aaf het Hof van	     1
# Ambafladcur ‘aan het Hof van	     1
# Ambaffadeur 2an het Hof van	     1
# Ambafladcur aan het Hof van	     1
# Ambaffzdeur aan het Hof van	     1
#
#
# Keyword: Hoogh Mogende Gedeputeerden tot de Militaire saecken
# ------------------------------------
# Hoog: Mogende Gedeputeerden tot ‚ de Militaire saken	     1
# Hoog Mogende ‘ Gedeputeerden:tot’ de Militare ’faaken	     1
#
#
# Keyword: Hoogh Mogende Gedeputeerden tot de Buytenlandtsche saecken
# ------------------------------------
# Hoog Mog. Gedeputeerden tot de buitenlandsche saaken	     4
# Hoog Mog. Gedeputeerden tot de buitenlandfche faaken	     2
# Mog. Gedeputeerden tot de buitenlandsche saaken, om	     2
# Hoog Mos. Gedepu keerden Tot de buitenlandfche faaken	     1
# Hoog Mog: Gedeputeerden tot de buitenlandfche faaken	     1
# Hoog Mog. Gedeputeerden tot de buitenlandfehg. faaken	     1
# Hoog Mog. Gedeputeerden tot de buitenlandíche faaken	     1
# Hoog Mog. Gedeputeerden tot de buitenlandsche soaken	     1
# Mog. Gedeputeerden tot de buitenlandsche soaken, om	     1
# Hoog Mog. Gedeputeerden tot de buitenlandfche. faaken	     1
# Hoog Mog, Gedeputeerden tot, de buitenlandfché faaken	     1
# Hoog Mog. Gedeputeerden tot de buitenlandsche saaker	     1
# Mog. Gedeputeerden tot de buitenlandsche saaker, on	     1
# Hoog Mog. Gedeputeerden tot de- buitenlandfehe faaken	     1
# Hoog Mog. Gedeputeerden tot de buitenlandfehe faaken	     1
# Hoog Mog. Gedeputeerden “tot dé buitenlandfche faaken	     1
# Hoog Mog. Gedeputeerden tot“ de buitenland{che faaken	     1
# toor Moe Gedeputeerden tot de buitenlandfehe {aaken	     1
# Mog. Gedeputeerden tot de buitenlandsche saaken , om	     1
# Hoog Mog. Gedeputeerden ‘tot dé buitenlandfehe faaken	     1
# Hoog Mog.. Gedeputeerden tot de buitenlandfche faaken	     1
# Hoog Mog. Gedeputeerden tot de buitenlandfche’ faaken	     1
# Hoog Mog. Gedeputcerden tot de buitenlandsche saaken	     1
# Mog. Gedeputeerden tot de buitenlands. che saaken om	     1

# %%
# controleer of je pandas geinstalleerd hebt
import pandas as pd


labels = {keyword['keyword']: keyword['label'] for keyword in keywords}

# houdt voor alle matches metadata bij
hits = []

# itereer over de documenten
for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = fuzzy_searcher.find_candidates(doc['text'], use_word_boundaries=True, include_variants=True)
    # voor elke match, tel de matchende string als variant van het matchende keyword
    for match in matches:
        hit = {
            'meeting_date': doc['metadata']['meeting_date'], 
            'inventory_num': doc['metadata']['inventory_num'], 
            'page_num': doc['metadata']['page_num'],
            'keyword': match['match_keyword'],
            'variant': match['match_term'],
            'match_string': match['match_string'],
            'label': labels[match['match_keyword']]
        }
        hits.append(hit)
        
columns = list(hits[0].keys())
data = {column: [hit[column] for hit in hits] for column in columns}
df = pd.DataFrame(data)

# %%
from datetime import datetime

dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')

# voeg de kolommen samen in een pandas data frame
df = pd.DataFrame(data)
# interpreteer de meeting_date kolom als datum object
df.meeting_date = df.meeting_date.apply(dateparse)
# toon de overzicht van het data frame
df
# Out:
#     meeting_date  inventory_num  page_num                      keyword  \
# 0     1770-01-01           3825       177              Raad van Staate
# 1     1770-01-01           3825       177              Raad van Staate
# 2     1770-01-01           3825       177   Generaliteyts Reeckenkamer
# 3     1770-01-01           3825       178  Ambassadeur aan het hof van
# 4     1770-01-01           3825       179              Raad van Staate
# ..           ...            ...       ...                          ...
# 946   1770-12-31           3825      1102              Raad van Staate
# 947   1770-12-31           3825      1103              Raad van Staate
# 948   1770-12-31           3825      1103   Generaliteyts Reeckenkamer
# 949   1770-12-31           3825      1103              Raad van Staate
# 950   1770-12-31           3825      1103   Generaliteyts Reeckenkamer
#
#                          variant                  match_string        label
# 0                Raad van Staate               Räad van Staate         raad
# 1                Raad van Staate               Raad van Staate         raad
# 2     Generaliteyts Reeckenkamer     Generaliteits Reekenkamer  organisatie
# 3    Ambassadeur aan het hof van  Ambafladeur -aan‘het Hof van  ambassadeur
# 4                Raad van Staate               Raad van Staate         raad
# ..                           ...                           ...          ...
# 946              Raad van Staate               Raad van Staate         raad
# 947              Raad van Staate               Raad van Staate         raad
# 948   Generaliteyts Reeckenkamer   Generüliteits Ree. kenkam?r  organisatie
# 949              Raad van Staate               Raad van Staate         raad
# 950   Generaliteyts Reeckenkamer    Generali teïts Reekenkamer  organisatie
#
# [951 rows x 7 columns]

# %%
# tel hoe vaak elk label voorkomt
df.label.value_counts()
# Out:
# raad             616
# organisatie      203
# ambassadeur      101
# gedeputeerden     31
# Name: label, dtype: int64

# %%
# Groepeer per maand en per label en tel hoe vaak elke combinatie voorkomt.
df.groupby([df.meeting_date.dt.month, 'label']).count()
# Out:
#                             meeting_date  inventory_num  page_num  keyword  \
# meeting_date label
# 1            ambassadeur               9              9         9        9
#              gedeputeerden             1              1         1        1
#              organisatie              31             31        31       31
#              raad                     69             69        69       69
# 2            ambassadeur               8              8         8        8
#              organisatie              11             11        11       11
#              raad                     43             43        43       43
# 3            ambassadeur               7              7         7        7
#              gedeputeerden             1              1         1        1
#              organisatie              17             17        17       17
#              raad                     53             53        53       53
# 4            ambassadeur               7              7         7        7
#              gedeputeerden             4              4         4        4
#              organisatie              21             21        21       21
#              raad                     44             44        44       44
# 5            ambassadeur               8              8         8        8
#              gedeputeerden             7              7         7        7
#              organisatie              36             36        36       36
#              raad                     57             57        57       57
# 6            ambassadeur               7              7         7        7
#              gedeputeerden             4              4         4        4
#              organisatie               4              4         4        4
#              raad                     63             63        63       63
# 7            ambassadeur              10             10        10       10
#              gedeputeerden             7              7         7        7
#              organisatie              23             23        23       23
#              raad                     77             77        77       77
# 8            ambassadeur               8              8         8        8
#              gedeputeerden             3              3         3        3
#              organisatie              20             20        20       20
#              raad                     72             72        72       72
# 9            ambassadeur               9              9         9        9
#              gedeputeerden             4              4         4        4
#              organisatie              10             10        10       10
#              raad                     15             15        15       15
# 10           ambassadeur               9              9         9        9
#              organisatie              12             12        12       12
#              raad                     34             34        34       34
# 11           ambassadeur               5              5         5        5
#              organisatie              12             12        12       12
#              raad                     32             32        32       32
# 12           ambassadeur              14             14        14       14
#              organisatie               6              6         6        6
#              raad                     57             57        57       57
#
#                             variant  match_string
# meeting_date label
# 1            ambassadeur          9             9
#              gedeputeerden        1             1
#              organisatie         31            31
#              raad                69            69
# 2            ambassadeur          8             8
#              organisatie         11            11
#              raad                43            43
# 3            ambassadeur          7             7
#              gedeputeerden        1             1
#              organisatie         17            17
#              raad                53            53
# 4            ambassadeur          7             7
#              gedeputeerden        4             4
#              organisatie         21            21
#              raad                44            44
# 5            ambassadeur          8             8
#              gedeputeerden        7             7
#              organisatie         36            36
#              raad                57            57
# 6            ambassadeur          7             7
#              gedeputeerden        4             4
#              organisatie          4             4
#              raad                63            63
# 7            ambassadeur         10            10
#              gedeputeerden        7             7
#              organisatie         23            23
#              raad                77            77
# 8            ambassadeur          8             8
#              gedeputeerden        3             3
#              organisatie         20            20
#              raad                72            72
# 9            ambassadeur          9             9
#              gedeputeerden        4             4
#              organisatie         10            10
#              raad                15            15
# 10           ambassadeur          9             9
#              organisatie         12            12
#              raad                34            34
# 11           ambassadeur          5             5
#              organisatie         12            12
#              raad                32            32
# 12           ambassadeur         14            14
#              organisatie          6             6
#              raad                57            57

# %%
# Groepeer per maand en per label en tel hoe vaak elke combinatie voorkomt.
df[['keyword', 'meeting_date']]
# Out:
#                          keyword meeting_date
# 0                Raad van Staate   1770-01-01
# 1                Raad van Staate   1770-01-01
# 2     Generaliteyts Reeckenkamer   1770-01-01
# 3    Ambassadeur aan het hof van   1770-01-01
# 4                Raad van Staate   1770-01-01
# ..                           ...          ...
# 946              Raad van Staate   1770-12-31
# 947              Raad van Staate   1770-12-31
# 948   Generaliteyts Reeckenkamer   1770-12-31
# 949              Raad van Staate   1770-12-31
# 950   Generaliteyts Reeckenkamer   1770-12-31
#
# [951 rows x 2 columns]

# %% [markdown]
# ## Fuzzy Context Search
#
# Gradually structuring resolutions:
#
# - identify opening phrase with proposition type
# - use opening phrase post-context to identify proposer
# - use post-context of opening phrase + proposer to identify topic

# %%
# importeer de fuzzy keyword searcher class en de phrase model class
from republic.fuzzy.fuzzy_context_searcher import FuzzyContextSearcher
from republic.fuzzy.fuzzy_phrase_model import PhraseModel

# configuratie van de fuzzy searcher
fuzzy_search_config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "ngram_size": 2,
    "skip_size": 2,
}

# creeër een nieuwe fuzzy searcher met bovenstaande configuratie 
fuzzy_searcher = FuzzyContextSearcher(fuzzy_search_config)

keyword_dicts = [
    {
        'keyword': 'de Provincie van Holland en Westvriesland',
        'label': 'province',
        'variants': [
            'de Provincie van Stad en Lande',
            'de Provincie van Gelderland',
            'de Provincie van Zeeland',
            'de Provincie van Utrecht',
            'de Provincie van Overyssel',
            'de Provincie van Vriesland',
        ]
    },
]

# transformeer je lijst met keywords in een phrase model
phrase_model = PhraseModel(model=keyword_dicts)
# indexeer de keywords uit het phrase model met de fuzzy searcher
fuzzy_searcher.index_keywords(phrase_model.get_keywords())
# indexeer eventuele varianten van de keywords
fuzzy_searcher.index_spelling_variants(phrase_model.variants)

# %%
for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = fuzzy_searcher.find_candidates_with_context(doc['text'], 
                                                          use_word_boundaries=True,
                                                          include_variants=True)
    # voor elke match, tel de matchende string als variant van het matchende keyword
    for match in matches:
        print(match['match_term_in_context'])
# Out:
#  den Brink, weegens de Provincie van Gelderland, als Bewindhebberen
# s Gedeputeerde’ uit de Provincie van Over viel. an Hoorn, Trip.
# is Gedeputeerde uit de Provîncie van Over viel. Van Hoorn, Trip.
# eeren # Staaten van de Provincie van Utrecht. gefchreeven te Utre
# n Gedeputeerden van de Provincie van Holland eh Weftvriesland, de voorz Miflive en
# . teerde Raaden van de Provincie van Holland ‘en Weftvriesland fullen wordenf vet.
# n Gedeputeerden van de Pravincie van Holland en- Weftvriesland, ‚en van Zeeland, de
# n Gedeputeerden van de Provincie van Holland en Westvriesland de voorsz Mis. sive,
# n Gedeputeerden van de Provincie van Zeeland het voorsz gepropone
# is Gedeputeerde uit de Provincie van Vriesland. Sloet tot‘de Haer,
# n Gedeputeerden van de Provincie van Zeeland het voorfchreeve ger
# is Gedeputeerde uit de Provincie van. Vriesland. Sloet ‘tot de Haer,
# s Gedepe7 eerde vit de Provincie van Vriesland. 7 on Pa asid rot Ì
# is Gedeputeerde uit de Provincie van Overyssel. Goot vha Trip. 2 co
# is Gedeputeerde uit de Provincie van Vriesland. Van Palland tot Gli
# is Gedeputeerde uit de Provincie van Overv(Jel.
# r Gedeputéerdeh van dé Pr& vindie Van Holland én Weltvriesland-de voorleiresve twee
# is Gedeputeerde uit de Provincie van Vriesland. Van Palland tot Gli
# n Gedeputeerden van de Provincien van Holland ‘en  Weftvriesland v
# Gedeputeer. den van dt Provincie van Zeeland, op den 11 deefer lo
# is Gedeputeerde uit de Provincie. van Vriesland. Van Palland tot Gli
# is Gedeputeerde uit de Provincie van Vriesland. Van Palland tot Gli
# ie Gedeputeerde uit de Provincie van Overy sel. 5 Van Hoorn, Trip.)
# eeren J Staaten van de Provincie van Overys-sel, geschreeven te Camp
# is Gederuteerde uit de Provincie van Gelderland. Ouarles ‚ Raadpen/i
# is Gedeputeerde uit de Provincie van Vriesland. Van Palland tot Gli
# is Gedeputeerde uit de Provincie van Overy/]el. Van Hoorn, Trip.
# is Gedeputeerde uit de Provincie van Overy{el. Trip
# iy Gedeputeerde uit de Provincie van V riesland. Van Palland tot Cli
# is Gedeputeerde uit de Provincie van Priesland. Van Palland tot Gli
# is Gedeputeerde vit de Provincie van Overy[Jel. Trip.
# s Gedeputeerden uit de Provincie van Gelderland. u Bentinck, van Ble
# is Gedeputeerde uit de Provincie van Friesland. Sloet tot de Haer,
# is Gede teerde uit ‘de Provincie van Overy{]el, Pan Hoorn, Trip.
# eren AJ Staaten van de Provintië van. Stad en Lande, gefchreeven te Gron
# s Gedeputeerden uit de Provincie van Gelderland. Cau, van Lynden. Va
# n Gedenuteerden van de Provincie van Holland en Weftviiesland de voorfz MisÎve. vo
# s Gedeputeerden uit de Provincie van Gelderland. 0 Ion 19 Van Wassen
# is Gedeputeerde uit de Provincie van Vriesland. V an Hambroick. Tri
# Gedeputeerde JV van de Provincie van Overyssel , heeft ter Vergader
# p de repartitie van de Provincie van Holland uitgetrokken tegen d
# de rc. partitie van de Provincië van Holland uitgetrokken {nl Com
# met goedvinden van’ dé Provincie van Holland, die voor alle de an
# ehuldvordering, die de Provincie van Holland ten lafte der andere
# deputeerde \ NM van de Provincie van Overy{]el; heeft ter Vergaderi
# e: deputeerden ‘uit de Provincie van Gelderland. Bentinck ‚ Ouarles
# is Gedeputeerde uit de Provincie van Vriesland. Van Hambroick. Trip
# ren: _D Staaten van de Provincie van Holland: en Weftvriesland , gefchreeven. alhie
# de reeden waarom op de Provincie van Stad en Lande diesweegens in veele
# n en ver flaan, dat de Provincie van Stad en Lande der felver aangepref
# en en betaalen aan: de Provincie van Holland en Wettvriesland, als die geene
# p de repartitie van de Provincie van Holland en Westvriesland tot hier toe is oebr
#  betaalde quote van de Provincie van Stad en Lande, en oversulks ter so
# en ten behoeven van de Provincie van Stad en Lande voornoemd.
# van de Ingezeetenen der Provincie van Zeeland tot de’ Navigatie op
# culiere relatie tot de Provincien van Holland of Zeeland hebbende;
# orfz delatie; door: de Provincie van Holländ by: de voorfz Refolu
# e Ingezeetenen van. de Provincie van Zeeland het regt en de bevoe
#  na het oordeel van de Provincie van Holland ten deefen gémoveert
# ens het ‘advis’ van de Pro vincie van Holland foude kunnen wor: de
# yke'przjuditie voor de Provincie van Zeeland en haare Ingezeetene
# de Colonie, dat aan de Provincie van Zeeland volgens den voorslag
# amer Amsterdam door de Provincie van Holland by voornoemde Resolu
# de Ingezeetenen van de Provincie van Holland, of van Amsterdam ,
# en. Dat vind men in de Provincie van Holland nogtans goed ‚ resol
# ilswygende aan, dat de Provincie van Zeeland via facti deese geno
# ke preejuditie voor de Provincie van Zeeland en haare Ingezeetene
# lste schikking voor de Provincie van Zeeland soude zyn, die men s
# s binnen korten tyd de Provincie van Zeeland uit soodanig eene in
# les alleen transito de Provincie van Zeeland soude passeeren, son
# r zyn foude dan aan de Provincie van Zeeland een proportioneel en
#  kan oordeelen; dat de Provincie van Zeeland door. eene particuli
# heeden in welke sig de Provineie van Zeeland ten opsigte van haar
# een eenig Schip uit de Provincie van Zeeland meer op die Colonien
#  met alle regt voor de Provincie van Zeeland allernadeeligst geoo
# is Gedeputeerde uit de Provincie van Gelderland. Ouarles, de Mey, Bo
# deputeerden van dei Pre DB vincie van Holland en Weftertesland. hebben tér Vergader
# is Gedeputeerde uit de Provincie van Gelderland. Vunden Santheuvel ‚
# is Gedeputeerde uit de Provincie van Vriesland. V. an Hambroick.
# s Gedepúteerden uit de Provincie van ‘Gelderland. Quarles, Bogaert; R
# Gedeputeer den uit’ de'Provincie van Vriesland. Van Hambroick. Trip
# is Gedeputeerde uit de Provincie van Gelder and. Bentinck, vanden Sa
# is Gedeputeerde uit de Provincie van Vriesland, Van -Palland ‘tot G
# ‚ Gedeputeerden uit de Provincie van Gelderland.
# de Ingézeetenen van de Provincie van Zeeland „uit krdgte van eene
# Gedeputeerde UJ van de Provincie van Overyijet , heeft ter Vergader
# van ‘dien, tuflchen de Provincien van Gelderland, Holland en Úuecht ‚
# n Gedeputeerden van de Provinien van Gelderland, van Holland en Weft
# er Gedeputeerde van de Provincie van Overyssel heeft sig met het bo
#  Feeren Staaten van de Provincie van Stad en Lande geconformeert.
# Gedeputeerde JJ van de Provincie van Stad en Lande, heeft ter Vergaderi
# s Gedeputeerden uit de Provincie van Gelderland. Bentinck, Ouarles;
# s Gedeputeerden uit de Provincie van Gelderland. uaa Bentinck, Cruci
# defiu“7 cteerde uit de Provincie van Overvijel.
# n Gedeputeerden van de Provincie van Zeeland, de voorfz Miflive c
# ris deputeerden uit de Provincie van Gelderland. Van Walfenaer, vand
# is Gedeputeerde uit de Provincie van Overy[Jel. Trip.
# Gedeputeerde DP van de Provincie van Utrecht , heeft ter Vergader
#  Gedeputeerden. van de Provincien van Gelderland en van Stad en Lande
# s Gedeputeerden uit de Provincie van Gelderland. Bentinck ‚ Quarles
# s Gedepu teerde uit de Provincie van Overyssel. Trip.
# n Gedeputeerden van de Provincie van Holland en Westvriesland verklaard, dat van w
#  de Ridderfchap van de Provincie van Holland en Westvriesland, en hoogst der selve
#  Gede. puteerde van de Provincie van Utrecht de voorsz Memorie co
# Gedeputeer. den van de Provincie van Overyssel insgelyks geinheeree
#  Heeren Staacen van de Provincie van Gelderland sullen worden versog
# s Gedeputeerden uit de Provincie van Gelderland, Bentinck, Crucius ‚
# is Gedeputeerde uit de Provincie van, Overy[Jel. Trip.
# Gedeputeerde van A) ze Provincie van Utrecht, heeft ter Vergaderi
# n Gedeputeerden van de Províncien van Gelderland, Holland en Weftvrië
# s Gedeputeerde uit. de Provincie van Overyi]el.
# liaw van de Wateren der Provincie van Zeeland, woonênde te Middelb
# eren AN Staaten dan de Provincie van Utrecht gefchreeven te Utrec
# is Gedeputeerde uit de Provincie van Overyssel.
# uteerde Staaten van de Provincie van Vriesland, geschreeven te Leeu
#  Gedeputeerde 1 van de Provincie van Stad en Lande, heeft ter Vergaderi
# eeren Staar ten van de Provincie van Holland en Westvriesland van dato den 26 Janu
#  Gede. puteerde van de Provincie van Gelderland, welke sig op het vo
#  Gedeputeerden “uit de Provincië ‘van Utrecht. heg Van Walenaer -
# s Gedeputeerden uit de Provincie van. Vriesland. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van Overyijel. 6u: A Gockinga, Tri
#  foo als reeds door de Provincie van Holland en Wettvriesland was gefchied, insgel
# eren JI Staaten van de>Provincie van Stad en Lande, gefchreeven: te Gro
# en i ND Staaten van de Provincie van Stad en Lande ‚  gefchreeven te Gr
# eren AJ Staaten van de Provincie van Stad en Lande, gefchreeven te Gron
# c Heeren Staten van de Provincie van Utrecht 3 gefchreeven aldaar
# eten LP Staaten van de Provincie van OverysJel, gefchreeven te Zwol
# Heerch Straaten van de Provimcie van Hóllapd-en Weflvriesland, van, den-11-deëfer
#  Gedepu teerden uit de Provincie van Vriesland. Sloet tot de Hatr,
# ris Gedeputeerde ui de Provincie van Overyfel. Gockinga.
# n Gedeputeerden van de Provincie van Holland en Wetftvriesland de voorfz Mis.
# n Gedeputeerden van de Provincie van Holland en Westvriesland, de voorsz Missive e
# is Gedeputeerde uit de Provincie van Gelderland. 55777 Paauvs ‚ Huyd
# is Gedeputeerde uit de Provincie van Overvfel., Gockinga.
# n Gedeputeerden van de Provincien van Zeeland en Utrecht, hebben g
#  te verminderen, in de Provincie van Hol land en elders sig weeder
# n Gedeputeerden van de Provin cie van Holland en Westvriesland het voorsz gepropone
# s Gedeputeerden uit de Provincie van Vriesland. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van Over. viel. Gockinga.
# s. Gedeputeerde uit de Provincie van Over: viel. Gockinga.
# ‚de :tourbeurte van de Provincie van Gelderland > Arnoldus) Goris,
# s Gedepnteerden’uit de Provincie van Vriesland. Sloet tot de Haer.
# s Gedeputeerden uit de Provincie van Vriesland Gockinga.
# n Gedeputeerden van de Provincie van Holland en Wettvriesland de voorfz Mis(ive en
# is Gedeputeerde uit de Provincie van Gelderland. Bentinck , vanden S
# is Gedeputeerde uit de Provincie van Vriesland. Een extraordinaris
# is Gedeputeerde uit de Provincie van Overyssel. Gockinga.
#  Heeren Staaten van de Provincien van Holland en Weftvriesland en van Zeeland, en a
# n Gedeputeerden van de Provincien van Holland en Weftvriesland ei van Zeeland; hebb
# n Gedeputeerden van de Provincie van Zeeland de voorsz Memorie co
# ’ Gedeputeerden van de Provincievan "Zeeland; ‘hebben ‘het voorlz
# is Gedeputeerde uit de Provincie van Utrecht. Bergsma, van Wassen
# is Gedeputeerde uit de Provincie van Overqysfel.
#  Gedepateerden- van de Provincie van Holland-en Weftvriesland op deefe ma terie op
# aden gaan uit en ha de Provincie van Zeeland, en"vervolgens op di
# an de Commercie bor de Provincie van Zeeland in het oog gehouden,
#  Cedepu. teerde uit de Provincie van Utrecht. Bergsma, van Grovof
# is Gedeputeerde uit de Provincie ván Vriesland. Slaet tot de Haer,
# n Gedeputeerden van de Provincie van Overy(]el, hebben ter Vergader
# estabilieert ‚en in de Provincie van Holland geadmitteert, en tot
# n Gedeputeerden van de Provincie van Holland en Westvriesland de voorsz Resolutie
# n Gedeputeerden van de Provincien van Holland en Westvriesland , van Zeeland, van U
# n Gedeputeerden van de Provincie van Zeeland hebben verklaard exp
# , indien onverhoopt de Provincie van Holland en Westvriesland alsdan nog mogt goed
# Ge: deputeerdén uit de Provincie van Vriesland. ofoored deb. deni S
# n Gedeputeerden van de Pro: vince van Zeeland, hebben het gunt voo
#  Erflladhouder door de Provincie van Holland en ‘Zeeland behoorde
# euw{ehe Scheepen na de Provincie van Zeeland , in roportie van he
# en verfendinge voor de Provincie van Zeeland in de voorfz proport
#  Heeren Staaten van de Provincie van, Zeeland daarenteegens ; by d
# iculiere relatie ot de Provincien van Holland of Zeeland hebbende,
# t de Resolutien van de Provineien van Holland en Zeeland vooraf so
# s Gedeputeerden uit de Provincie van Vriesland. Sloet tot de Haer ,
# is Gedeputeerde uit de Provincie van Over5 ysel.
# n Gedeputeerden van de Provincie van Vriesland den 29 Mey bevoorens
#  te verminderen, in de Provincie van Holland en elde rs sig weede
# n Gedeputeerden van de Provincie van Overyssel hebben in den voor s
# p de instantie door de Provincie van Zeeland gedaan, tot ver bod
# aane inftantien van de Provincie van Zee: land met op{igt tor den w
# orfz inftantien van de Provincie van Zeeland hebbende geconformee
# n Gedeputeerden van de Provincien van Gelderland en Overyssel aangeno
# n Gedeputeerden van de Provincien van Utrecht, Vriesland en Stad e
# s Gedeputeerden uit de Provincie van Vriesland. Van Palland tot Gli
# is Gedeputeerde uit de Provincie van Overyssel. Coekinga.
# n Gedeputeerden van de Provincie van Gelderland aangenoomen, hun daa
# is Gedeputeerde uit de Provincië van Vriesland. Van Palland tot Gli
# is Gedeputeerde uit de Provincie van Overy[Jel: Gockinga.
# eren JI Staaten van de Provincie van Stad en Lande ‚ gefchreeven te Gro
# n Gedeputeerden van de Provincie van Zeeland, als sig in deese sa
# is Gedeputeerde uit de Provincie van Vriesland. Van Palland tot Gli
# s Cedeputeerde uit. de Provincie van Overyssel. Gockinga.
# n Gedeputeerden van de Provincie van Holland en Westvriesland de voorsz. Missive c
# s Gedeputeerden uit de Provincie van Vriesland. SD Tan Palland tot
# Gedepu93 teerde uìt de Provincie van. Overy(Jel. on „Gockinga.
# ris Gedeputeerde at de Provincie van OveryfJel. Gockinga.
# n Gedeputeerden van de Provincie van Zeeland ‘de vòorfz Miffive e
# s Gedeputeerden uit de Proointie gan Vrieslaan, Seo Sloet 19t de, H
# is Gedeputeerde uit de Provincie van OverAlet er re Gockinga,
# n Gedeputeerden van de Provincie van Holland en Westvriesland en van Zeeland, de v
#  “Gedeputeerde ‘uit de Provincie van Vriesland. Sloet tot de Haer,
# ts Gedepúteerde uit de Provincie van Over. viel: Gockinga:
#  Heeren Staaten van de Provincie van Gelderland, raakende de afloffi
# n oo de auotens van de Provincie van Gelderland in beide de voorfz h
# n ‘en verltaan; dat de Province van Gelderland der felver aangepref
# op de teartitie van de Provincie van Holland uitgetrokken tegens
# 6, fal betaalen aan de Provincie van Holland ei Wettvriesland, en dat defelve vold
# aalde . quotens van de Provincie van Gelderland, en over falks ter f
# p de repartitie van de Provincie van Gelderland voornoemd.
#  Heeren Staaten van de Provincie van Utrecht, raa: kende de aflof
# en en verftaan, lat de Provincie van Ütrecht der felver aanvepref
#  ter repartitie van de Provincie van Utrecht op denjStaat van Oor
# fal betaalen. aan j Je Provincie van Holland en Wettvriesland efeftive, en dat def
# etaalde quotens van de Provincie van Utrecht, en overfulk ter fom
# ni ten behoeve van. de Provincie van Utrecht voornoemt:
# a "op: de 4dote van de Provincie van Staden Lande wah a5plichtië gemaa
# e tót de quote’ van de Provicie ‘Van  Overysfel, in dercboovenseniel
#  ei vorftaan , “dat de Provincie van Over vifel: der {eiser darsepre
# 5 de Yepariitie van ce Provincie. van Holland en Wefvriesland tot hier toe zyn geb
# n ten De: hoeve van de Provincie van Overylfel voor19% € noemt, iin
# n Gedeputeerden van de Provincie van Zeeland, als sig in deese sa
# e Vrint, bedienende de Provincie van Gelderland, ter Versaderinge va
# is Gedeputeerde uit de Provincie van Vriesland. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van’ Overysfel. Gockinga.
# n Gedeputeerden van de Provincie van Holland en Westvriesland de voorsz Requeste e
# is Gedeputeerde uit de Provincie van Vriesland. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van Over: el. Gockinga.
# n Gedeputeerden van de Provincie van Holland en Wefteriesland, hebben ter Vergader
# nomen hebbendé, dat de Provincien van Gelderland, Vriesland,
# er Gedeputeerde van de Provincie van Stad en Lande, welke fig op het vo
# is Gedeputeerde uit de Pro vincie van Zeeland. Wieling. Bergsma, m
# s Gedeputeerden uit de Provincie van Vriesland. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van Over. el. Gockinga.
# eren KJ Staaten van de Provincie van Zeelands gêfchteeven ’te * Mi
# n Gedeputeerden van de Provincie van Zeeland de voorsz Resolutie
# n Gedeputeerden van de Provincie van Zeeland, welke sie op het vo
# n Gedeputeerden van de Provincie van Holland en Westyriesland, hebben geinheereert
#  Gedeputeerden van. de Provincie van Hollana en Westvriesland ‚ de voorsz Missive,
# n Gedeputeerden van de Provincie van Zeeland de voorsz Missive co
# n Gedeputeerden van de Provincie van Zeeland, als zynde nu de een
# n Gedeputeerden van de Provincie van Vriesland ter Vergadering van
# Gedeputeer. den van de Provincie van Vriesland den 29 Mey bevoorens
#  te verminderen, in de Provincie van Holland en elders fig weeder
# n Gedeputeerden van de Provincien van Gelderland, van Zeeland, van Üt
#  Cedepu teerde ‘uit de’ Provincie van Vricsland. Sloet tot de: Haer,
# is Gedeputeerde uit de Provincie van Overviel. Gockinga.
# n Gedeputeerden van de Provincien van Holland en Weflvtiesland, ‘en van Zeeland, de
#  Gedeputeerden ‘van de Provincie van Holland en Weftvriesland, de voorfz Memorie c
# is Gedeputeerde uit de Provincie van Vriesland. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van Overysfel. Gockinga,
# en dat de quote van de Provincie van Zeeland voor, ditmaal wierde
#  te demandeeren, en de Provincie van- Holland om de Gelden te avan
#  of dat, in gevalle de Provincie van Vriesland tot deefe Equipage g
# it te Amfterdam, en de Provincie van Holland verfogt om de koften
# foo men de Laft van de Provincie van Zeeland foude willeu afneeme
# en, en de quote van de ProvinGe van Zeeland onbetaalt blyvende,
# arles, als hebbende de Provincie van Holland en Weftvriesland in de voorgaande wee
# van de Provincie van Zeeland, heeft verfogt en ge
# n Gedeputeerden van de Provincien van Holland en Weftvriesland en van Zeeland. de v
# n Gedeputeerden van de Provincie van Zeeland, ‘welke fig op het v
# mmitteerden wegens ‘de Pro vincie van Holland reede ‘ter Genera: l
# n Gedeputeerden van de Provincie van Zeeland de voorfz Refolutie
#  Heeren Staaten van de Provincie van Hollähd en Weftvriesland, den 15 der voorléed
# aar vermindert, in: de Provincie van Holland en elders {ig weeder
# de inftantien ‘van ‘de Provincie van Zeeland, ‘tot verbod van’ de
#  Gedeputeerden van: de Provincie van Holland en’ Weftvriësland’ de voorfz Refolutie
# Gedeputeerde BD van de Provincie van Stad en, Lande; heeft ter Vergaderi
# elangt de quote van de Provincie van Zeeland ‚ U Edele Mog. ‚uit
#  Cede puteerden uit de Provincie van Fries land. Sloet tot de Haer,
# is Gedeputeerde uit de Provincie van Over: viel. Zockinga.
# n Gedeputeerden van de Provincie van Holland en Weltvriesland ‚ de voorfz Misfive,
# n Gedeputeerden van de Provincien van Gelderland ; Vriesland en Stad
# n Gedeputeerden van de Provincien van Holland en Weftvriesland ‚ Zeeland, Utrecht e
# n Gedeputeerden van de Provincie van Holland en Woeftvriesland, de voorfz Miflive e
# s ‚Gedeputeerde nit de Provincie ‘van Gelderland, ‘Paatiw ‚ Quarles,
# s Gedepu teerde uit de Provincie van Vriesland. Sloet tot de Haer,
#  | Gedeputeerde uit de Provincie van Over vfel. Gockitiga. na TAB R
# n Gedeputeerden van de Provincie van Zeeland ‚ hebben. voor :hun
# s Gedepu teerde uit de Provincie van Vriesland. Sloet tot de Haer,
# P Gedeputeerden van de Provincie var Overyl]el , gefchreeven te Swo
# n Gedeputeerden van de Provincien van Gelderland, Holland en Wettvrie
# e en tourbeurte van de Provincie van Vriesland fal worden geconfere
#  Gedeputeerden uit, de Provincie van: VriesTand. Sloet töt de Haer ,
# is Gedeputeerde uit desProvincie van Overqfel. HEIST Gockingas in
#  Gedepu: teerde uit de, Provincie van Vriesland. Sloet 1ot de Haer ,
# s Gedeputeerde uit ‘dz Provincie van Over vel. Gockinga
# holdi, - bedienende de Provincie van Utrecht 3 ter Vergaderinge v
# s Gedeputeerde. uit de Provincie van: Gelderland. oniad a Pauw, Cruci
# s Gedeputeerden uit de Provincie ‘van Vrieslard. Sloet tot de Haer,
# is Gedeputeerde nit de Provincie van Gelderland. 2 194 Bentinck ; va
# s Gedeputeerden uit dé Provincie van Vriesland. Sloet tot de Haer.
# is Gedeputeerde uit de Provincie von Vriesland, Sloet tor de Haer.
# is Gedeputeerde uit de Provincie van Vriesland. Sloet tot de Haer.
# is Gedeputeerde uit de Provincie van Vriesland. Gockinga.
# cureur Generaal van de Provincie van Vriesland, als Grootvader Mate
# n Gedeputeerden van de Provincien van Gelderland, Holland en Wet vrie
# is Gedepurèerde uit de Provincie van Gelderland. ‘Ouarles ‚ Bogaert;
# : Cedepateerden uit de Provincie van Vriesland. Gockinga,
# Gedeputeerden uit | de Provincie van Vriesland,
# n Gedeputeerden van de Provincie van Holland en Westvriesland , de voorsz Missive,
# is Gedeputeerde uit de Provincie van Gelderland. Ouarles, Bogaert ‚
# is Gedeputeerde uit de Provincie van Vriesland. Sloet tot de Haer.
# ‚Gedeputeerde Hoven de Provincie van Stad en „Lande, heeft ter. Vergader
# n Gedeputeerden van de Provincien van Holland en Westvriesland en van Zeeland, de v
# Gedeputeerde 17 van de Provincie van Stad en Lande, heeft ter Vergaderi
# Gedeputeerde IP van de Provincie van Stad en Lande, heeft ter Vergaderi
# Gêiepiteerde van BD de Provincie van Utrecht. heeft ter Vergaderi
# Cadel teerdeit ‘uit de Proviieie Vai Vriesland!” Sloet tot’de Haer,
# s Gedepu teerde uit de Provincie van Vriesland. Sloet tot de Haer ,
# edenuteerde | W oan de Provincie van Utrecht, heeft ter Vervaderi
# s Gedeputeerde uit, de Provincie van Vriesland. Sloet tot de Haer.
# n Gedeputeerden van de Provincie van Holland Jen. Westvrieslend o
#  Ge deputeerden van de Provincie van Vriesland, den 29 Mey daar te
# n Gedeputeerden van de Provincie van Holland en Westvriesland was ingebragt een Re
# e Gedeputeerden van de Provincien van Utrecht, Vriesland ‚ Overyss
# n Gedeputeerden van de Provincien van Holland en Westvriesland en van Zeeland, de v
#  Gedepu. teerde uit de Provincie van Vriesland. Sloet tot de Haer.
#  Gedepu. teerde uit de Provincie van Vriesland. Sloet tot de Haer.
# s Gedept teerde uit de Provincie van Vriesland. Sloet tot de Haer.
#  de 7 instantie van de Proviricie van Zeeland am tot hervatting va
# n Gedeputeerden van de Provincien van Holland en Wes. vriesland en
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-c8180a2f9885> in <module>
#       1 for doc in docs:
#       2     # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
# ----> 3     matches = fuzzy_searcher.find_candidates_with_context(doc['text'],
#       4                                                           use_word_boundaries=True,
#       5                                                           include_variants=True)
#
# ~/Code/Huygens/republic-hocr-parser/republic/fuzzy/fuzzy_context_searcher.py in find_candidates_with_context(self, text, keyword, ngram_size, context_size, use_word_boundaries, match_initial_char, include_variants, filter_distractors)
#      64                                      include_variants=False, filter_distractors=False):
#      65         """Find candidates in text and add context around the match candidates."""
# ---> 66         self.find_candidates(text, keyword=keyword, ngram_size=ngram_size,
#      67                              use_word_boundaries=use_word_boundaries,
#      68                              match_initial_char=match_initial_char,
#
# ~/Code/Huygens/republic-hocr-parser/republic/fuzzy/fuzzy_keyword_searcher.py in find_candidates(self, text, keyword, ngram_size, use_word_boundaries, match_initial_char, include_variants, filter_distractors, allow_overlapping_matches)
#     720             self.use_word_boundaries = use_word_boundaries
#     721         self.find_all_candidates(text, keyword)
# --> 722         self.filter_all_candidates(ngram_size, allow_overlapping_matches=allow_overlapping_matches)
#     723         if self.track_candidates:
#     724             self.set_known_candidate_status()
#
# ~/Code/Huygens/republic-hocr-parser/republic/fuzzy/fuzzy_keyword_searcher.py in filter_all_candidates(self, ngram_size, allow_overlapping_matches)
#     476     def filter_all_candidates(self, ngram_size: int, allow_overlapping_matches: bool = True):
#     477         if self.include_variants:
# --> 478             self.filter_variant_candidates()
#     479         self.filter_candidates(filter_type="char_match")
#     480         self.filter_candidates(filter_type="ngram_match", ngram_size=ngram_size)
#
# ~/Code/Huygens/republic-hocr-parser/republic/fuzzy/fuzzy_keyword_searcher.py in filter_variant_candidates(self)
#     507         for candidate in self.candidates["filter"]:
#     508             if "levenshtein_distance" not in candidate:
# --> 509                 levenshtein_distance = score_levenshtein_distance_ratio(candidate["match_term"],
#     510                                                                         candidate["match_string"])
#     511                 candidate["levenshtein_distance"] = levenshtein_distance
#
# ~/Code/Huygens/republic-hocr-parser/republic/fuzzy/fuzzy_keyword_searcher.py in score_levenshtein_distance_ratio(term1, term2)
#      57 def score_levenshtein_distance_ratio(term1, term2):
#      58     max_distance = max(len(term1), len(term2))
# ---> 59     distance = score_levenshtein_distance(term1, term2)
#      60     return 1 - distance / max_distance
#      61
#
# ~/Code/Huygens/republic-hocr-parser/republic/fuzzy/fuzzy_keyword_searcher.py in score_levenshtein_distance(s1, s2, use_confuse, max_distance)
#      75         for i1, c1 in enumerate(s1):
#      76             if c1 == c2:
# ---> 77                 distances_.append(distances[i1])
#      78             else:
#      79                 dist = confuse_distance(c1, c2) if use_confuse else 1
#
# KeyboardInterrupt:

# %%
phrases = [
    'in handen van de Heeren',
    'een Missive van de Heeren',
    'het rapport van de Heeren',
    'het Verbaal van de Heeren'
]

pattern = {
    'type': 'suffix',
    'start': 'Heeren',
    'end_distractors': [
        'Gedeputeerde',
        'Gecommitteerde',
        'Staaten'
    ]
}

heeren_searcher = FuzzyContextSearcher(fuzzy_search_config)
# transformeer je lijst met keywords in een phrase model
phrase_model = PhraseModel(keywords=[pattern['start']])
# indexeer de keywords uit het phrase model met de fuzzy searcher
heeren_searcher.index_keywords(phrase_model.get_keywords())
distractor_searcher = FuzzyContextSearcher(fuzzy_search_config)
phrase_model = PhraseModel(keywords=pattern['end_distractors'])
distractor_searcher.index_keywords(phrase_model.get_keywords())

context_size = 40
post_context_size = 20

for doc in docs:
    # gebruik 'find_candidates' om kandidaat matches te vinden in de tekst
    matches = heeren_searcher.find_candidates_with_context(doc['text'], 
                                                          use_word_boundaries=True,
                                                          include_variants=True,
                                                          context_size=context_size)
    # voor elke match, tel de matchende string als variant van het matchende keyword
    for match in matches:
        match_end = match['match_offset'] + len(match['match_string'])
        post_context = doc['text'][match_end:match_end+post_context_size]
        distractor_matches = distractor_searcher.find_candidates(post_context)
        if len(distractor_matches) > 0:
            continue
        print(match['match_term_in_context'])
# Out:
# . ikeazO Ntfangen een Mifiive van. den: Heere Grave van Rechteren , haar Hoog Mog. ext
# ge. eb: Rn Ntfansen een Miffive van den Heere CN Bijchop en Purft te Paderborn; ge fch
# e gefteld. {al wor: den in hande van de Heeren ván Lyn:
# ogendé, om aan ‘de Supplianten uit te : keeren fes ‘guldens, die: aan hun tegens behóor
# g Mogende;“om:aan de Supplianten uit te keeren fes’ guldens ‚die. aan hun tegens behoër
# gensí de, om aan de Sopplianten-uit: te:keeren: vier filvere Ducatons, dewelke aan hun
# ende; om aan = dei:Supplianten Tuit ter keeren fes guides) dewelke raaf hun tegens:beho
# sbamd 91 09y PR E:SE:N:T dB: Ssnisw Des Heeren wai Lynden-teto Hemrtën , eb Piek sderPa
#  16b: Hoy Ntfanger; een Miffjve:yan den Heere Jo van: Haeften 5:haart, Hoog Mog: :e%1
# , dat qa den Se cretaris, van. gemelde. Heere Geelvinck Tal worden gereferibeert, dat
# verfoekende, dat haar Hoog Mog. gemelde Heere Carel Johan van Lichtenberg met dè gewoo
# n ; mits deefen te committeeren gemelde Heere van Lichtenberg tot Raad in den Raad van
# elegt. En is den felve daar op doof den Heere Cau in den Raad van Staate geintoduceert
# L Ntfangen een Miffive van den Heere OD van Heeckeren, haar Hoog Mogende extr
# dgevonden en verftaan ; dat aan gemelde Heere van. Heeckeren fal worden gereftribeert,
# brad Ntfangen een Miffive van den Heere WD Ceeluink, haar Hoog Mog, Minitter Ple
#  permiffie, om op exempel van wylen den Heere van Haren, in leeven haar Hoog Mos. Gede
#  1752 en 5 July 1758 dan wylen” gèmelde Heere van Harèn hadden geliëven toe te ftaan.
# age sefteld {al worden in handen van de Heeren’ van Lynden tor Hemmen, en andere haar H
# s Reekenkamer, by haar E. felfs te nom. neeren, te viliteeren, examineeren, en van alle
# Admiraliteit op de Maaze, mitsgaders de Heeren Adjunéten Revifeurs in de voorfz fake ov

# %% [markdown]
# ## Co-occurrence

# %%
from itertools import combinations

# maak een nieuwe counter aan
term_freq = Counter()

# itereer over all documenten (= paragraphs)
for doc in docs:
    # splits de tekst op alles wat geen alpha-numerical character is
    terms = re.split(r'\W+', doc['text'])
    # een 'list comprehension' om termen te filteren die met een hoofdletter te beginnen
    terms = [term for term in terms if term != '' and term[0].isupper() and len(term) > 1]
    # update de counter met de lijst van termen in dit document
    sorted_set = set(sorted(terms))
    coocs = [cooc for cooc in combinations(sorted_set, 2)]
    term_freq.update(coocs)

# print een overzicht van de 100 meest frequente termen
for cooc, freq in term_freq.most_common(100):
    # print term (links uitgelijnd met een breedte van 30 karakters) en frequentie (rechts uitgelijnd met 6 karakters)
    term1, term2 = cooc
    print(f'{term1: <20}{term2: <20}{freq: >6}')
# Out:
# Hoog                Mog                   2013
# WAAR                Mog                   1196
# Hoog                WAAR                  1084
# Heeren              Mog                    803
# Gedeputeerden       Heeren                 718
# Hoog                Heeren                 682
# Heere               Mog                    662
# Hoog                Vergaderinge           658
# Ntfangen            Hoog                   634
# Mog                 Dat                    618
# Hoog                Dat                    604
# Ntfangen            WAAR                   587
# Ntfangen            Mog                    580
# Gedeputeerden       Mog                    554
# Heeren              Provincie              529
# Raad                Mog                    504
# WAAR                Heere                  503
# Hoog                Heere                  489
# Mog                 Vergaderinge           479
# Hoog                Gedeputeerden          478
# WAAR                Heeren                 467
# Hoog                Raad                   460
# En                  Mog                    455
# Hoog                Copie                  453
# WAAR                Vergaderinge           448
# Ntfangen            Heere                  445
# Hoog                En                     436
# Staate              Raad                   423
# Missive             Mog                    419
# Mos                 Hoog                   409
# Hoog                Hof                    393
# Hoog                Stad                   391
# WAAR                Copie                  388
# Mog                 Hof                    386
# Mog                 Copie                  381
# Heeren              Vergaderinge           380
# Stad                Mog                    377
# Heere               Heeren                 370
# Staaten             Heeren                 366
# Hoog                Mogende                361
# Hoog                Refolutie              360
# Missive             WAAR                   359
# WAAR                Gedeputeerden          358
# Mos                 Mog                    357
# Hoog                Provincie              353
# Mog                 Refolutie              350
# Staate              Mog                    350
# Hoog                Missive                350
# Ntfangen            Hof                    349
# Raad                Heeren                 345
# Gedeputeerden       Provincie              333
# Resolutie           Mog                    332
# Gedeputeerden       Vergaderinge           330
# Koning              Hof                    329
# Hoog                Resolutie              325
# Koning              Mog                    324
# Mog                 Provincie              324
# Hoog                Envoyé                 322
# WAAR                Raad                   321
# Miflive             Mog                    320
# Koning              WAAR                   319
# Hoog                Staate                 314
# Koning              Heere                  308
# Hoog                Miffive                301
# Mogende             Mog                    301
# Ntfangen            Missive                297
# Heeren              Copie                  296
# Holland             Heeren                 293
# WAAR                Dat                    292
# Heere               Hof                    290
# Hoog                Suppliant              290
# WAAR                Hof                    285
# Envoyé              Mog                    285
# Hoog                Admiraliteit           283
# Staaten             Mog                    282
# Grave               Mog                    280
# En                  Heeren                 276
# Mog                 Suppliant              276
# Lynden              Heeren                 275
# Heere               Provincie              274
# Heeren              De                     273
# Hoog                Miflive                272
# Gecommitteerden     Heeren                 272
# Mog                 Admiraliteit           272
# Heeren              Dat                    271
# Grave               Heere                  270
# Gecommitteerden     Mog                    270
# WAAR                En                     269
# Requeste            Mog                    269
# Staate              Heeren                 266
# Lande               Mog                    262
# Holland             Mog                    262
# Grave               Hof                    260
# Hoog                Requefte               260
# Requefte            Mog                    259
# Hoog                Supplianten            257
# Holland             Hoog                   256
# Grave               WAAR                   255
# Staate              WAAR                   254
# Hoog                Requeste               254

# %% [markdown]
# ## Locally Storing Paragraphs

# %%
import gzip
import json

es_republic = rep_es.initialize_es(host_type='external', timeout=60)

# kies een inventaris nummer om te doorzoeken
inv_num = 3825
inv_nums = [x for x in range(3820,3830)]

# de base_dir is niet relevant maar wel nodig voor het maken van een config object
base_dir = "/Users/marijnkoolen/Data/Projects/REPUBLIC/"
paragraph_index = 'pagexml_meeting_paragraphs'

def get_inventory_paragraphs(inv_num):
    """Retrieve all PageXML paragraphs for a given inventory number"""
    query = {'query': {'match': {'metadata.inventory_num': inv_num}}, 'size': 10000}
    response = es_republic.search(index=paragraph_index, body=query)
    return [hit['_source'] for hit in response['hits']['hits']]

dump_file = '../data/paragraphs-3820-3829.json.gz'

# %%
with gzip.open(dump_file, 'wt') as fh:
    for inv_num in inv_nums:
        # genereer een config object voor het specifieke inventaris nummer dat je wilt doorzoeken
        inv_config = set_config_inventory_num(base_config, inv_num, base_dir, ocr_type='pagexml')
        docs = get_inventory_paragraphs(inv_num)
        print(inv_num, 'number of paragraphs:', len(docs))
        for doc in docs:
            fh.write(json.dumps(doc) + '\n')
# Out:
# 3820 number of paragraphs: 3702
# 3821 number of paragraphs: 3638
# 3822 number of paragraphs: 3354
# 3823 number of paragraphs: 3376
# 3824 number of paragraphs: 4129
# 3825 number of paragraphs: 4408
# 3826 number of paragraphs: 4564
# 3827 number of paragraphs: 4390
# 3828 number of paragraphs: 4618
# 3829 number of paragraphs: 4270

# %%
# importeer de fuzzy keyword searcher class en de phrase model class
from republic.fuzzy.fuzzy_context_searcher import FuzzyContextSearcher
from republic.fuzzy.fuzzy_phrase_model import PhraseModel

def read_paragraphs_from_dump(dump_file):
    with gzip.open(dump_file, 'rt') as fh:
        for line in fh:
            yield json.loads(line)

# configuratie van de fuzzy searcher
fuzzy_search_config = {
    "char_match_threshold": 0.8,
    "ngram_threshold": 0.6,
    "levenshtein_threshold": 0.8,
    "ignorecase": False,
    "max_length_variance": 3,
    "ngram_size": 2,
    "skip_size": 2,
}

# creeër een nieuwe fuzzy searcher met bovenstaande configuratie 
missive_searcher = FuzzyContextSearcher(fuzzy_search_config)

proposition_opening_phrases = [
    {
        'keyword': 'Ntfangen een Missive van',
        'label': 'proposition_opening',
        'proposition_type': 'missive'
    },
    {
        'keyword': 'hebben ter Vergaderinge ingebraght', 
        'label': 'proposition_opening',
        'proposition_type': None
    },
    {
        'keyword': 'Is ter Vergaderinge gelesen de Requeste van ', 
        'label': 'proposition_opening',
        'proposition_type': None
    },
    {
        'keyword': 'IS gehoort het rapport van ', 
        'label': 'proposition_opening',
        'proposition_type': 'rapport'
    },
    {
        'keyword': 'Op de Requeste van ', 
        'label': 'proposition_opening',
        'proposition_type': 'requeste'
    },
    {
        'keyword': 'Zynde ter Vergaderinge getoont en geëxhibeert de Declaratie van ',
        'label': 'proposition_opening',
        'proposition_type': None
    },
]

# transformeer je lijst met keywords in een phrase model
phrase_model = PhraseModel(model=proposition_opening_phrases)
missive_searcher.index_phrase_model(phrase_model)
# indexeer de keywords uit het phrase model met de fuzzy searcher
#missive_searcher.index_keywords(phrase_model.get_keywords())
# indexeer eventuele varianten van de keywords
#missive_searcher.index_spelling_variants(phrase_model.variants)



for di, doc in enumerate(read_paragraphs_from_dump(dump_file)):
    matches = missive_searcher.find_candidates_with_context(doc['text'], use_word_boundaries=True,
                                                            allow_overlapping_matches=False,
                                                            context_size=40)
    for match in matches:
        print(match['match_term_in_context'], match['start_offset'], '#' + doc['metadata']['textregion_id'] + '#')
        print(match['match_label'])
        
    print()
    if di > 43:
        break
# Out:
# Ntfangen een Missive van den Heere \ JJ Lestevenon van Berckenrod 0 #NL-HaNA_3820_0079-page-157-col-0-tr-2#
# proposition_opening
#
#
# Ntfangen een Missive van den Heere CN van Haren, haar Hoog Mogend 0 #NL-HaNA_3820_0079-page-157-col-1-tr-1#
# proposition_opening
#
# Ntfangen een Mifssive van sijne Fur. stelyke Doorlugtigheid den He 0 #NL-HaNA_3820_0079-page-157-col-1-tr-2#
# proposition_opening
#
#
#
# a Ntfangen een Miffive van C. vander UD Hoop, en Auguftinus van Son 0 #NL-HaNA_3820_0080-page-158-col-0-tr-1#
# proposition_opening
#
#
# ‚ Ntfangen een Miflive van den Secretaris de Swart, gefchreeven te  0 #NL-HaNA_3820_0080-page-158-col-1-tr-1#
# proposition_opening
#
# Ntfangen een Miffive van den Secretaris de Swart , gefchreeven te 0 #NL-HaNA_3820_0080-page-158-col-1-tr-2#
# proposition_opening
#
# ‚Ntfangen een Miflive van den SecreP taris de Swart, gefchreeven t 0 #NL-HaNA_3820_0080-page-158-col-1-tr-3#
# proposition_opening
#
#
# YS tet Verzaderinge geleefen de Requefte Evan Bailliuw, Bursermeefter en Scheevenen va 0 #NL-HaNA_3820_0080-page-159-col-0-tr-1#
# proposition_opening
#
#
# S tef Vergaderinge geleefen de Requelte van Hendrik Rietveld, Capitein ter Zee onder 0 #NL-HaNA_3820_0080-page-159-col-1-tr-1#
# proposition_opening
#
# nformiteit van de ordres van den Lande. Ntfangen een Missive van J. Kien, 7 Stadhouder van den Quartierst 75 #NL-HaNA_3820_0081-page-160-col-0-tr-0#
# proposition_opening
# tienden daar te vooren, desselfs berigt op de Requeste van Tosenh van Vorsteldonk V en Jan Konings  405 #NL-HaNA_3820_0081-page-160-col-0-tr-0#
# proposition_opening
#
# YS ter Vergaderinge geleesen de Requeste 7 an Francois de Kanter Capitein van de Burge 0 #NL-HaNA_3820_0081-page-160-col-0-tr-1#
# proposition_opening
#
#
# P de Requeste van de gesaamentlijke Leydekkers Knegts van  0 #NL-HaNA_3820_0081-page-160-col-1-tr-1#
# proposition_opening
#
# * P de Requeste van de vier StraatJV maakers van het Hof ; v 0 #NL-HaNA_3820_0081-page-160-col-1-tr-2#
# proposition_opening
#
#
# AP de Requeste van Willem van WaerU mond, woonende alhier i 0 #NL-HaNA_3820_0081-page-161-col-0-tr-1#
# proposition_opening
#
# P de Requeste van de gesaamentlijke AJ EKnegts van den Tim 0 #NL-HaNA_3820_0081-page-161-col-0-tr-2#
# proposition_opening
#
# P de Requeste van de gesaamentiijke J Knegt van den Metsel 0 #NL-HaNA_3820_0081-page-161-col-0-tr-3#
# proposition_opening
#
# P de Requeste van Carolina Rosemond . JI Weduwe van Mr. Ca 0 #NL-HaNA_3820_0081-page-161-col-0-tr-4#
# proposition_opening
#
#
# IJ Ynde ter Vergaderinge getoond en ss. geëxhibeert de Declaratie van á Fohan Adam Vaupell, i Kamerbewaard 0 #NL-HaNA_3820_0081-page-161-col-1-tr-1#
# proposition_opening
#
#
#
#
# \ Ntfiigen een Mifive van de Heeren KJ} Steaten van de Protintie v 0 #NL-HaNA_3820_0082-page-162-col-0-tr-1#
# proposition_opening
#
#
#
#
#
#
# Ntfangen een Miflive van de Heeren U) Steaten van de Provincie va 0 #NL-HaNA_3820_0082-page-163-col-0-tr-2#
# proposition_opening
#
# Ntfangen &en Miflive van den Raad CQ) oan State, gefchréeven alhi 0 #NL-HaNA_3820_0082-page-163-col-0-tr-3#
# proposition_opening
#
#
# S ter Vergaderinge geleefen de Requefte M van Albert Crouwel, Oppalfer van het Geftoel 0 #NL-HaNA_3820_0082-page-163-col-1-tr-1#
# proposition_opening

# %%
def label_lists_align(candidate_labels, known_formula) -> bool:
    """Check if set of candidate labels aligns with known formula labels."""
    if len(candidate_labels) != len(known_formula['elements']):
        raise ValueError('compare element lists of unequal length')
    is_candidate = True
    for ci, candidate_label in enumerate(candidate_labels):
        if candidate_label is None and known_formula['elements'][ci] not in known_formula['variable']:
            # found label is unknown element that does not align
            # with one of the formula's variable elements
            is_candidate = False
            break
        if candidate_label and candidate_label != known_formula['elements'][ci]:
            # candidate label does not align with formula label
            is_candidate = False
            break
    return is_candidate

def find_candidate_formulas(found_elements, known_formulas):
    candidates = []
    found_labels = [element['match_label'] for element in found_elements]
    for known_formula in known_formulas:
        is_candidate = True
        candidate_alignment = {}
        if len(known_formula['elements']) > len(found_elements):
            # the known formula has more elements than were found, 
            # so the found pattern cannot be a match
            is_candidate = False
            continue
        for fi, found_label in enumerate(found_labels[:len(found_labels) - len(known_formula['elements']) + 1]):
            candidate_labels = found_labels[fi:fi+len(known_formula['elements'])]
            if label_lists_align(candidate_labels, known_formula):
                candidates.append({'element_offset': fi, 'formula': known_formula})
    return candidates
            

def make_proposition_phrases(proposition_opening_phrases, proposer_titles):
    proposition_phrases = []
    for opening_phrase in proposition_opening_phrases:
        for title in proposer_titles:
            phrase = {'keyword': opening_phrase['keyword'] + ' ' + title['keyword']}
            for field in opening_phrase:
                if field == 'keyword':
                    continue
                phrase[field] = opening_phrase[field]
            for field in title:
                if field == 'keyword':
                    continue
                phrase[field] = title[field]
            proposition_phrases.append(phrase)
    return proposition_phrases


def configure_searcher(phrase_dict, fuzzy_search_config):
    # transformeer je lijst met keywords in een phrase model
    phrase_model = PhraseModel(model=phrase_dict)
    searcher = FuzzyContextSearcher(fuzzy_search_config)
    searcher.index_phrase_model(phrase_model)
    # indexeer de keywords uit het phrase model met de fuzzy searcher
    #searcher.index_keywords(phrase_model.get_keywords())
    # indexeer eventuele varianten van de keywords
    #searcher.index_spelling_variants(phrase_model.variants)
    return searcher


def chunk_and_label(text, matches):
    matches.sort(key = lambda x: x["match_offset"], reverse=True)
    chunks = []
    for match in matches:
        start = match["match_offset"]
        end = match["match_offset"] + len(match["match_string"])
        prefix = text[:start]
        suffix = text[end:]
        chunk = {
            "match_keyword": None,
            "match_string": text[end:],
            "match_offset": end,
            "match_label": None
        }
        if len(chunk['match_string'].strip()) > 3 and chunk['match_string'] not in [' de ']:
            chunks.append(chunk)
        chunks.append(match)
        text = prefix
    return chunks[::-1]


proposer_titles = [
    {
        'keyword': 'den Heere',
        'label': 'proposer_title',
        'cardinality': 'single',
        'proposer_type': 'person',
        'variable_type': 'suffix',
    },
    {
        'keyword': 'de Heeren',
        'label': 'proposer_title',
        'cardinality': 'multi',
        'proposer_type': 'person',
    },
    {
        'keyword': 'den Secretaris',
        'label': 'proposer_title',
        'cardinality': 'single',
        'proposer_type': 'person',
    },
    {
        'keyword': 'den Commissaris',
        'label': 'proposer_title',
        'cardinality': 'single',
        'proposer_type': 'person',
    },
    {
        'keyword': 'sijne Fur. stelyke Doorlugtigheid',
        'label': 'proposer_title',
        'cardinality': 'single',
        'proposer_type': 'person',
    },
    {
        'keyword': 'de Heeren Staaten van de Provincie',
        'label': 'proposer_title',
        'cardinality': 'multi',
        'proposer_type': 'organisation',
    },
    {
        'keyword': 'Staaten van de Provincie',
        'label': 'proposer_title',
    },
    {
        'keyword': 'den Raad van Staate',
        'label': 'proposer_title',
        'cardinality': 'single',
        'proposer_type': 'organisation',
    },
]

esteem_titles = [
    {
        'keyword': 'haar Hoog Mogende',
        'label': 'esteemed',
    },
    {
        'keyword': 'Ambassadeur aan het Hof van ',
        'label': 'person_role',
        'role': 'ambassadeur_royal'
    },
    {
        'keyword': 'Gedeputeerde by sijne Hoogheid',
        'label': 'deputy_royal'
    },
    {
        'keyword': 'Staaten van de Provincie',
        'label': 'organisation',
    },
    {
        'keyword': 'het Collegie ter Admiraliteit',
        'label': 'organisation',
    },
    {
        'keyword': 'Gouverneur Generaal',
        'label': 'person_role',
        'role': 'governor_general'
    },
    {
        'keyword': 'Advocaaten van ',
        'label': 'person_role',
        'role': 'advocate_multi_of'
    },
    {
        'keyword': 'Stadhouder van ',
        'label': 'person_role',
        'role': 'stadholder'
    },
    {
        'keyword': 'Ooftindifche Compagnie',
        'label': 'organisation'
    },
    {
        'keyword': 'den Griffier',
        'label': 'person_role',
        'role': 'registrar'
    },
    {
        'keyword': 'Bisschop te',
        'label': 'person_role',
        'role': 'bisshop'
    },
    {
        'keyword': 'Capitein ter Zee',
        'label': 'person_role',
        'role': 'captain_at_sea'
    },
    {
        'keyword': 'Capitein van de Burgerye',
        'label': 'person_role',
        'role': 'captain_of_company'
    },
    {
        'keyword': 'van Balliuw, Burgermeester en Scheepenen',
        'label': 'representatives',
        'role': 'magistrate_multi'
    },
    {
        'keyword': 'Kamerbewaarder van',
        'label': 'person_role',
        'role': 'entourage'
    }
    
]

misc = [
    {
        'keyword': 'geschreeven te',
        'label': 'correspondence_location',
    },
    {
        'keyword': 'geschreeven alhier in Den Hage',
        'label': 'correspondence_the_hague',
    },
    {
        'keyword': 'woonende te',
        'label': 'residence_location',
    },
    {
        'keyword': 'woonende alhier in den Hage',
        'label': 'residence_the_hague',
    },
    {
        'keyword': 'deeser loopende maand',
        'label': 'current_month',
    },
    {
        'keyword': 'der voorleeden maand',
        'label': 'previous_month'
    },
    {
        'keyword': 'houdende advertentie.',
        'label': 'on_hold',
    },
    {
        'keyword': 'WAAR op geen resolutie is gevallen.',
        'label': 'no_decision'
    },
    {
        'keyword': 'Weftvriesland en den Noorder Quartiere',
        'label': 'location'
    },
    {
        'keyword': 'geaddreffeert aan ',
        'label': 'addressed_to'
    },
    {
        'keyword': 'Heerlijkheid ',
        'label': 'region_type'
    },
    {
        'keyword': 'Quartiere ',
        'label': 'region_type'
    },
    {
        'keyword': 'Majorie ',
        'label': 'region_type'
    },
    {
        'keyword': 'Quartierschout ',
        'label': 'person_role'
    },
    {
        'keyword': 'het Quartier van Peelland',
        'label': 'location'
    },
    {
        'keyword': "'s Lands Oorlogschip",
        'label': 'ship_type'
    },
    {
        'keyword': "een Nieuwejaars-Gifte van",
        'label': 'finance_gift'
    },
    {
        'keyword': "de gewoonlijke Nieuwejaars-Gifte van",
        'label': 'finance_gift'
    },
    {
        'keyword': "versoekende",
        'label': 'request_verb'
    }
    
]

provinces = [
    {
        'keyword': ' van Holland en Westvriesland',
        'label': 'of_province'
    },
    {
        'keyword': ' van Stad en Lande',
        'label': 'of_province'
    },
    {
        'keyword': ' van Gelderland',
        'label': 'of_province'
    },
    {
        'keyword': ' van Zeeland',
        'label': 'of_province'
    },
    {
        'keyword': ' van Utrecht',
        'label': 'of_province'
    },
    {
        'keyword': ' van Overyssel',
        'label': 'of_province'
    },
    {
        'keyword': ' van Vriesland',
        'label': 'of_province'
    },
]



proposition_phrases = make_proposition_phrases(proposition_opening_phrases, proposer_titles)
proposer_searcher = configure_searcher(proposition_phrases, fuzzy_search_config)
esteem_searcher = configure_searcher(esteem_titles, fuzzy_search_config)
chunk_searcher = configure_searcher(proposer_titles + esteem_titles + provinces + misc, fuzzy_search_config)
opening_formulas = [
    {
        'elements': ['proposition_opening', 'proposer_title', 'proposer_name', 'esteemed'],
        'variable': ['proposer_name']
    },
    {
        'elements': ['proposition_opening', 'proposer_title', 'proposer_name', 'written_in_location'],
        'variable': ['proposer_name']
    },
    {
        'elements': ['proposition_opening', 'proposer_name', 'person_role', 'organisation'],
        'variable': ['proposer_name']
    },
    {
        'elements': ['proposition_opening', 'proposer_title', 'proposer_title', 'proposer_name', 'written_in_location'],
        'variable': ['proposer_name']
    },
    
]

for di, doc in enumerate(read_paragraphs_from_dump(dump_file)):
    if (di+1) <= 4:
        continue
    missive_matches = missive_searcher.find_candidates_with_context(doc['text'], use_word_boundaries=True,
                                                                    context_size=250)
    if len(missive_matches) == 0:
        continue
    print()
    for missive_match in missive_matches:
        print(doc['metadata']['textregion_id'], len(missive_matches), missive_match['start_offset'])
        chunk_matches = chunk_searcher.find_candidates_with_context(missive_match['match_term_in_context'], use_word_boundaries=True,
                                                             context_size=250)
        #proposer_matches = proposer_searcher.find_candidates_with_context(missive_match['match_term_in_context'], use_word_boundaries=True,
        #                                                     context_size=150)
        post_context = missive_match['match_term_in_context'].split(missive_match['match_string'])[1]
        #print(missive_match['match_term_in_context'])
        #print('\t', missive_match['match_keyword'], missive_match['match_offset'], missive_match['match_offset'] + len(missive_match['match_string']))
        #print('\t', post_context)
        #for chunk_match in chunk_matches:
        #    print('\t', chunk_match['match_keyword'], chunk_match['match_offset'], chunk_match['match_offset'] + len(chunk_match['match_string']))
        chunks = chunk_and_label(doc['text'], [missive_match] + chunk_matches)
        #for chunk in chunks:
            #print(chunk["match_label"], '\t',chunk["match_string"])
        candidate_formulas = find_candidate_formulas(chunks, opening_formulas)
        if len(candidate_formulas) == 1:
            candidate_formula = candidate_formulas[0]
            for variable_element in candidate_formula['formula']["variable"]:
                element_index = candidate_formula['formula']['elements'].index(variable_element) + candidate_formula['element_offset']
                if chunks[element_index]['match_label'] == None:
                    chunks[element_index]['match_label'] = variable_element
        label_pattern = [chunk["match_label"] for chunk in chunks]
        print(label_pattern)
        print([chunk["match_string"] for chunk in chunks])
    
    if (di+1) > 34:
        break
        #if len(proposer_matches) == 0:
        #    print("UNKNOWN CONTINUATION:", missive_match['match_term_in_context'])
# Out:
# NL-HaNA_3820_0079-page-157-col-1-tr-1 1 0
# ['proposition_opening', 'proposer_title', 'proposer_name', 'esteemed', 'deputy_royal', None, 'person_role', None, 'correspondence_location', None, 'previous_month', None]
# ['Ntfangen een Miflive van', 'den Secretaris', ' de Swart, ', 'gefchreeven te', ' St. Petersburg den vierden ', 'der voorleede maand', 'geaddreffeert aan', 'den Griffier', ' Farel, ', 'houdende advertentie', ' ‚ en fendende daat neevens Copie van een Memorie; welke de Gedeputeerden der Diflidenten in de maand Oétober laatftleeden weederom p het fubjeft van haar belangens aan het Ruffifche Minifterie hadden geprefenteert gehad. WAAR op gedelibereert zynde, is goed: gevonden en verftaan, dat ‘Copie van de voorfchreeve Miflive en Bylaage gefteld fal worden in handen van de Heeren van Lynden tot Hemmen, en andere haar Hoog Mogende Gedeputeerden tot de buitenlandfche faaken, om te Vifiteeren, examineeren, en van alles alhier ter Vergadering rapport te doen. ']
#
# NL-HaNA_3820_0080-page-158-col-1-tr-2 1 0
# ['proposition_opening', 'proposer_title', None, 'correspondence_location', None, 'previous_month', 'addressed_to', 'person_role', None, 'on_hold', None]
# ['Ntfangen een Miffive van', 'den Secretaris', ' de Swart , ', 'gefchreeven te', ' St. Petersburg den vierden ', 'der voorleede maand', 'geaddreffeert aan', 'den Griffier', ' Fagel, ', 'houdende advertentie', ', en onder anderen van het geene hem voorgekoomen en door hem gedaan was in de faak van de Kooplieden Pels te Amíterdam, weegens hun Teercontraêt met de Kroon van Rusland. WAAR op gedelibereert zynde, hebben de Heeren Gedeputeerden van de Provintie van Holland en Weftvriesland, de voorchreeve Miffive, voor foo. veel het gemelle point aangaat, copielijk overgenoomen , om in den haaren breeder gecommuniceert te worden. ']
#
# NL-HaNA_3820_0080-page-158-col-1-tr-3 2 0
# ['proposition_opening', 'proposer_title', None, 'correspondence_location', None, 'previous_month', 'addressed_to', 'person_role', None, 'on_hold', None]
# ['Ntfangen een Miflive van', 'den SecreP taris', ' de Swart, ', 'gefchreeven te', ' St. Petersburg den feevenden ', 'der voorleede maand', 'geaddreffeert aan', 'den Griffier', ' Fagel, ', 'houdende advertentie', ', en onder anderen, dat het Hof Dingsdags te vooren den grooten Rouw, welke het felve ter geleegentheid van het affterven van de Princeile vau Holftein, AbditTe te Herforden, omtrent vier weeken gedragen had de, afgelegt had, en daarentegen ten felven daage weederom ter felve geleegentheid voor veertien daagen aangelegt den kleinen Rouw; dat fig daar meede op het exempel van de andere Heeren uitheem']
# NL-HaNA_3820_0080-page-158-col-1-tr-3 2 0
# ['proposition_opening', 'proposer_title', None, 'correspondence_location', None, 'previous_month', 'addressed_to', 'person_role', None, 'on_hold', None]
# ['‚Ntfangen een Miflive van', 'den SecreP taris', ' de Swart, ', 'gefchreeven te', ' St. Petersburg den feevenden ', 'der voorleede maand', 'geaddreffeert aan', 'den Griffier', ' Fagel, ', 'houdende advertentie', ', en onder anderen, dat het Hof Dingsdags te vooren den grooten Rouw, welke het felve ter geleegentheid van het affterven van de Princeile vau Holftein, AbditTe te Herforden, omtrent vier weeken gedragen had de, afgelegt had, en daarentegen ten felven daage weederom ter felve geleegentheid voor veertien daagen aangelegt den kleinen Rouw; dat fig daar meede op het exempel van de andere Heeren uitheem']
#
# NL-HaNA_3820_0080-page-159-col-0-tr-1 1 0
# ['proposition_opening', 'representatives', None, 'esteemed', None]
Collegië ter Admiraliteit waar te neemen, gelieven te voorfien. WAAR op gedelibereert zynde, is goedgevonden en verftaan, mits deefen te committeeren gemelde Heere Jacob van Cats, tot Raad in het Collegië ‘ter Admiraliteit in Weftyriesland en het Noorder Quartier daáf toe ten fijnen behoeve Comthiffie. in behöorlijké forma {al worden gedepecheert, doënde ‘den behoorlijken eed; die hy nog taande Vérgaderinge heeft afgelegt ']
#
# NL-HaNA_3820_0082-page-163-col-0-tr-2 1 0
# ['proposition_opening', 'proposer_title', 'organisation', 'of_province', 'correspondence_location', None, 'proposer_title', None]
# ['Ntfangen een Miflive van', 'de Heeren', 'Steaten van de Provincie', 'van Gel derland', 'gefthreeven te', ' Arnhem den dertienden Oëtober feeventien honderd drie en fette houdende creditf op ‘', 'den Heer', ' Mr. Tan van Leeuwen, Burgermeefter der Stad Nymégen , als exträórdmaris  Getorhmitteerde tet Vetgaderinge van haar Hoof Mogende. WAAR op gedelibereert, en by haar Hoog  Mogende verklaart zynde, dat ge: melde Heere van Leeuwen haâr aángênaam was, is den fälve verwelkomt, en heeft dienvolgende feffie genomen: ']

# %%
text = 'den Heere CN van Haren, haar Hoog Mogende '
re.search(r'\b, haar Hoog Mogende\b', text)
# Out:
# <re.Match object; span=(22, 41), match=', haar Hoog Mogende'>

# %%
test_formulas = [
    {
        'elements': ['a', 'b', 'c', 'd'],
        'variable': ['c']
    }
]

found_elements = [
    {
        'match_label': 'e'
    },
    {
        'match_label': 'a'
    },
    {
        'match_label': 'b'
    },
    {
        'match_label': None
    },
    {
        'match_label': 'd'
    },
    {
        'match_label': 'f'
    },
    {
        'match_label': 'g'
    },
]

find_candidate_formulas(found_elements, test_formulas)
# Out:
# [{'element_offset': 1,
#   'formula': {'elements': ['a', 'b', 'c', 'd'], 'variable': ['c']}}]

# %%
a = [1,2,3,4,5,6]
b = [1,2,3,4]

for i in a[:len(a) - len(b) + 1]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
from republic.model.republic_phrase_model import resolution_categories, category_index, spelling_variants

category_variants = defaultdict(list)

match_categories = [
    "resolution_opening",
    "resolution_considered",
    #"resolution_decision",
    "resolution_accepted",
    "resolution_not_accepted"
]

for match_category in match_categories:
    for keyword in resolution_categories[match_category]:
        print(match_category)
        print(resolution_categories[match_category])
        print(keyword)
        category_variants[match_category] += [keyword]
        if keyword in spelling_variants:
            category_variants[match_category] += [variant for variant in spelling_variants[keyword]]

category_variants
# Out:
# resolution_opening
# ['hebben ter Vergaderinge ingebraght', 'Is ter Vergaderinge gelesen', 'IS gehoort het rapport van', 'Ontvangen een Missive van', 'Op de Requeste van', 'Zynde ter Vergaderinge getoont']
# hebben ter Vergaderinge ingebraght
# resolution_opening
# ['hebben ter Vergaderinge ingebraght', 'Is ter Vergaderinge gelesen', 'IS gehoort het rapport van', 'Ontvangen een Missive van', 'Op de Requeste van', 'Zynde ter Vergaderinge getoont']
# Is ter Vergaderinge gelesen
# resolution_opening
# ['hebben ter Vergaderinge ingebraght', 'Is ter Vergaderinge gelesen', 'IS gehoort het rapport van', 'Ontvangen een Missive van', 'Op de Requeste van', 'Zynde ter Vergaderinge getoont']
# IS gehoort het rapport van
# resolution_opening
# ['hebben ter Vergaderinge ingebraght', 'Is ter Vergaderinge gelesen', 'IS gehoort het rapport van', 'Ontvangen een Missive van', 'Op de Requeste van', 'Zynde ter Vergaderinge getoont']
# Ontvangen een Missive van
# resolution_opening
# ['hebben ter Vergaderinge ingebraght', 'Is ter Vergaderinge gelesen', 'IS gehoort het rapport van', 'Ontvangen een Missive van', 'Op de Requeste van', 'Zynde ter Vergaderinge getoont']
# Op de Requeste van
# resolution_opening
# ['hebben ter Vergaderinge ingebraght', 'Is ter Vergaderinge gelesen', 'IS gehoort het rapport van', 'Ontvangen een Missive van', 'Op de Requeste van', 'Zynde ter Vergaderinge getoont']
# Zynde ter Vergaderinge getoont
# resolution_considered
# ['WAAR op gedelibereert en in achtinge genomen zynde', 'WAAR op gedelibereert zijnde', 'WAAR op gedelibereert']
# WAAR op gedelibereert en in achtinge genomen zynde
# resolution_considered
# ['WAAR op gedelibereert en in achtinge genomen zynde', 'WAAR op gedelibereert zijnde', 'WAAR op gedelibereert']
# WAAR op gedelibereert zijnde
# resolution_considered
# ['WAAR op gedelibereert en in achtinge genomen zynde', 'WAAR op gedelibereert zijnde', 'WAAR op gedelibereert']
# WAAR op gedelibereert
# resolution_accepted
# ['is goedgevonden ende verstaan', 'IS naar voorgaande deliberatie goedgevonden ende verstaan', 'de voorfchreve Missive copielijck overgenomen']
# is goedgevonden ende verstaan
# resolution_accepted
# ['is goedgevonden ende verstaan', 'IS naar voorgaande deliberatie goedgevonden ende verstaan', 'de voorfchreve Missive copielijck overgenomen']
# IS naar voorgaande deliberatie goedgevonden ende verstaan
# resolution_accepted
# ['is goedgevonden ende verstaan', 'IS naar voorgaande deliberatie goedgevonden ende verstaan', 'de voorfchreve Missive copielijck overgenomen']
# de voorfchreve Missive copielijck overgenomen
# resolution_not_accepted
# ['WAAR op geen resolutie is gevallen']
# WAAR op geen resolutie is gevallen
# defaultdict(list,
#             {'resolution_opening': ['hebben ter Vergaderinge ingebraght',
#               'Is ter Vergaderinge gelesen',
#               'IS gehoort het rapport van',
#               'Ontvangen een Missive van',
#               'ON een Missive van',
#               'Ontfangen een Missive van',
#               'Ontfangen twee Missiven van',
#               'Op de Requeste van',
#               'Zynde ter Vergaderinge getoont'],
#              'resolution_considered': ['WAAR op gedelibereert en in achtinge genomen zynde',
#               'WAAR op gedelibereert zijnde',
#               'Waer op gedelibereert zynde',
#               'WAAR op gedelibereert'],
#              'resolution_accepted': ['is goedgevonden ende verstaan',
#               'IS goedgevonden ende verstaan',
#               'Is goedgevonden en verstaan',
#               'IS naar voorgaande deliberatie goedgevonden ende verstaan',
#               'de voorfchreve Missive copielijck overgenomen'],
#              'resolution_not_accepted': ['WAAR op geen resolutie is gevallen',
#               'Waer op geen resolutie is gevallen',
#               'WAAR op geen resolutie voor alsnoch is gevallen',
#               'Waer op geen resolutie voor alsnoch is gevallen']})
